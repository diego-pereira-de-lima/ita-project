# %%
from google.colab import drive
from pysus.online_data import SINAN
from src import SinanDownloader

# Conectando ao drive
drive.mount('/content/drive')

# Instancia a classe com o caminho no Drive
downloader = SinanDownloader('/content/drive/MyDrive/dados_tcc_ita')

# Lista de doenças e anos
list_doenca = ["FTIF", "HEPA", "TUBE", "LEPT", "MENI"]
list_year = list(range(2013, 2025))

# Chama a função para baixar os dados
df_completo = downloader.baixar_doencas(list_doenca, list_year, SINAN)
# Out:
# 🔄 Baixando dados de: ESQU
# Arquivo salvo: SINAN_ESQU.parquet

# %%
df_completo
# Out:
#      TP_NOT ID_AGRAVO  DT_NOTIFIC SEM_NOT NU_ANO SG_UF_NOT ID_MUNICIP  \
# 0         2      B659  2020-01-02  202001   2020        31     315050
# 1         2      B659  2020-01-02  202001   2020        26     261550
# 2         2      B659  2020-01-02  202001   2020        35     355100
# 3         2      B659  2020-01-02  202001   2020        29     290600
# 4         2      B659  2020-01-03  202001   2020        51     510622
# ...     ...       ...         ...     ...    ...       ...        ...
# 2554      2      B659  2024-12-27  202452   2024        31     316860
# 2555      2      B659  2024-12-27  202452   2024        31     312160
# 2556      2      B659  2024-12-29  202501   2024        29     291080
# 2557      2      B659  2024-12-30  202501   2024        31     310620
# 2558      2      B659  2024-12-30  202501   2024        27     270430
#
#      ID_REGIONA ID_UNIDADE  DT_SIN_PRI  ... DT_TRANSSM DT_TRANSRS DT_TRANSSE  \
# ...
