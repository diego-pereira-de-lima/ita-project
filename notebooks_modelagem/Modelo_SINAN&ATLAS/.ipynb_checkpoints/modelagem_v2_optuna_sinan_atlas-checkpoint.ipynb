# %%
#!pip uninstall xgboost

# %%
# !pip install optuna xgboost==3.1.1 lightgbm fastparquet imbalanced-learn torch rapidfuzz
# Out:
# Collecting optuna
#   Downloading optuna-4.6.0-py3-none-any.whl.metadata (17 kB)
# Collecting xgboost==3.1.1
#   Downloading xgboost-3.1.1-py3-none-manylinux_2_28_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.12/dist-packages (4.6.0)
# Collecting fastparquet
#   Downloading fastparquet-2024.11.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.12/dist-packages (0.14.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.9.0+cu126)
# Collecting rapidfuzz
#   Downloading rapidfuzz-3.14.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from xgboost==3.1.1) (2.0.2)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.12/dist-packages (from xgboost==3.1.1) (2.27.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from xgboost==3.1.1) (1.16.3)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.17.2)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.44)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: pandas>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from fastparquet) (2.2.2)
# Requirement already satisfied: cramjam>=2.3 in /usr/local/lib/python3.12/dist-packages (from fastparquet) (2.11.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from fastparquet) (2025.3.0)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (1.6.1)
# Requirement already satisfied: joblib<2,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.5.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->fastparquet) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->fastparquet) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->fastparquet) (2025.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->fastparquet) (1.17.0)
# Downloading xgboost-3.1.1-py3-none-manylinux_2_28_x86_64.whl (115.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 MB 7.3 MB/s eta 0:00:00
# Downloading optuna-4.6.0-py3-none-any.whl (404 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.7/404.7 kB 25.7 MB/s eta 0:00:00
# Downloading fastparquet-2024.11.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 68.9 MB/s eta 0:00:00
# Downloading rapidfuzz-3.14.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 74.8 MB/s eta 0:00:00
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Installing collected packages: rapidfuzz, colorlog, xgboost, optuna, fastparquet
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 3.1.2
#     Uninstalling xgboost-3.1.2:
#       Successfully uninstalled xgboost-3.1.2
# Successfully installed colorlog-6.10.1 fastparquet-2024.11.0 optuna-4.6.0 rapidfuzz-3.14.3 xgboost-3.1.1

# %%
import numpy as np
import pandas as pd
import os, joblib,time


from sklearn.model_selection import StratifiedKFold, cross_val_score,train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.calibration import CalibratedClassifierCV

import optuna
from optuna.pruners import SuccessiveHalvingPruner
from optuna.exceptions import TrialPruned

#from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.impute import SimpleImputer
from functools import partial
from sklearn.calibration import calibration_curve

from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, confusion_matrix, matthews_corrcoef,
    cohen_kappa_score, balanced_accuracy_score,
    classification_report, brier_score_loss, log_loss,
    confusion_matrix, ConfusionMatrixDisplay,
    precision_recall_curve, RocCurveDisplay,roc_curve,auc
)

from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE

import matplotlib.pyplot as plt
import seaborn as sns

import subprocess
import xgboost as xgb
import lightgbm as lgb
import torch

import re
from rapidfuzz import fuzz, process

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Carregando base de dados

# %%
df =pd.read_parquet('df_lept_atlas.parquet',engine='fastparquet')

# %% [markdown]
# ### Selecionar variáveis relevantes para triagem

# %%
df.columns
# Out:
# Index(['id_municipio', 'nu_idade_n', 'cs_sexo', 'cs_gestant', 'cs_raca',
#        'cs_escol_n', 'sg_uf', 'id_ocupa_n', 'ant_cb_lam', 'ant_cb_cri',
#        'ant_cb_sin', 'ant_cb_cor', 'ant_cb_roe', 'ant_cb_ter', 'ant_cb_lix',
#        'ant_cb_out', 'ant_humano', 'ant_animai', 'cli_febre', 'cli_mialgi',
#        'cli_cefale', 'cli_prost', 'cli_conges', 'cli_pantur', 'cli_vomito',
#        'cli_diarre', 'cli_icteri', 'cli_renal', 'cli_respir', 'cli_cardia',
#        'cli_hemopu', 'cli_hemorr', 'cli_mening', 'cli_outros', 'classi_fin',
#        'con_area', 'con_ambien', 'baixa_escolaridade', 'raca_vulneravel',
#        'faixa_vulneravel', 'vulnerabilidade_social', 'nivel_vulnerabilidade',
#        'mes_sintomas', 'estacao', 'periodo_chuvoso', 'expectativa_vida',
#        'fecundidade_total', 'prob_sobrevivencia_40', 'prob_sobrevivencia_60',
#        'taxa_freq_bruta_basico', 'taxa_freq_bruta_fundamental',
#        'taxa_freq_bruta_medio', 'taxa_freq_liquida_superior',
#        'prop_pobreza_extrema', 'prop_vulner_pobreza', 'taxa_agua_encanada',
#        'taxa_banheiro_agua_encanada', 'taxa_coleta_lixo',
#        'taxa_energia_eletrica', 'taxa_agua_esgoto_inadequados',
#        'taxa_paredes_inadequados', 'populacao', 'indice_escolaridade',
#        'indice_frequencia_escolar', 'idhm', 'idhm_e', 'idhm_l', 'idhm_r'],
#       dtype='object')

# %%
triage_features = ['id_municipio', 'nu_idade_n', 'cs_sexo', 'cs_gestant', 'cs_raca',
       'cs_escol_n', 'sg_uf', 'id_ocupa_n', 'ant_cb_lam', 'ant_cb_cri',
       'ant_cb_sin', 'ant_cb_cor', 'ant_cb_roe', 'ant_cb_ter',
       'ant_cb_lix', 'ant_cb_out', 'ant_humano', 'ant_animai',
       'cli_febre', 'cli_mialgi', 'cli_cefale', 'cli_prost', 'cli_conges',
       'cli_pantur', 'cli_vomito', 'cli_diarre', 'cli_icteri',
       'cli_renal', 'cli_respir', 'cli_cardia', 'cli_hemopu',
       'cli_hemorr', 'cli_mening', 'cli_outros', 'con_area', 'con_ambien',
       'baixa_escolaridade', 'raca_vulneravel', 'faixa_vulneravel',
       'vulnerabilidade_social', 'nivel_vulnerabilidade', 'mes_sintomas',
       'estacao', 'periodo_chuvoso', 'expectativa_vida',
       'fecundidade_total', 'prob_sobrevivencia_40',
       'prob_sobrevivencia_60', 'taxa_freq_bruta_basico',
       'taxa_freq_bruta_fundamental', 'taxa_freq_bruta_medio',
       'taxa_freq_liquida_superior', 'prop_pobreza_extrema',
       'prop_vulner_pobreza', 'taxa_agua_encanada',
       'taxa_banheiro_agua_encanada', 'taxa_coleta_lixo',
       'taxa_energia_eletrica', 'taxa_agua_esgoto_inadequados',
       'taxa_paredes_inadequados', 'populacao', 'indice_escolaridade',
       'indice_frequencia_escolar', 'idhm', 'idhm_e', 'idhm_l', 'idhm_r']


target_col = 'classi_fin'  # rótulo: confirmado vs descartado

if target_col == 'classi_fin':
    df = df[df['classi_fin'].isin(['Confirmado', 'Descartado'])].copy()

    # Criar variável alvo binária
    df['alvo'] = df['classi_fin'].map({
        'Confirmado': 1,
        'Descartado': 0
    })

## Amostragem estratificada
amostragem = df.groupby("alvo").sample(frac=0.05, random_state=42).copy()

X_data=amostragem[triage_features]
y_data = amostragem['alvo']

# %% [markdown]
# ## Train framework

# %% [markdown]
# ### Funções de apoio

# %%
def detect_gpu():
    """
    Detecta corretamente suporte a GPU para CUDA, XGBoost e LightGBM.
    Retorna um dicionário completo.
    """

    # 1. Verificar CUDA geral
    try:
        cuda_available = torch.cuda.is_available()
    except:
        cuda_available = False


    # 2. Testar LightGBM GPU

    try:
        # Testa se LightGBM foi compilado com suporte a GPU
        lgb_gpu = lgb.register_logger(lambda x: x)  # dummy
        booster = lgb.LGBMClassifier(device="gpu")
        lgb_gpu = True
    except:
        lgb_gpu = False


    # 3. Detalhes da GPU via nvidia-smi

    try:
        smi_output = subprocess.check_output("nvidia-smi", shell=True).decode()
        gpu_info = smi_output.split("\n")[2].strip()
    except:
        gpu_info = "Nenhuma GPU detectada (nvidia-smi não disponível)"

    return {
        "cuda_available": cuda_available,
        "lightgbm_gpu": lgb_gpu,
        "gpu_info": gpu_info
    }

# %%
def get_model_params_gpu(model_name, gpu_info):
    """
    Retorna hiperparâmetros base apropriados para CPU ou GPU.
    """
    use_gpu = gpu_info["cuda_available"]

    if model_name == "xgboost":
        if use_gpu:
            return {
                "tree_method": "gpu_hist",
                "predictor": "gpu_predictor"
            }
        else:
            return {
                "tree_method": "hist",
                "predictor": "cpu_predictor"
            }

    elif model_name == "lightgbm":
        if use_gpu:
            return {
                "device": "gpu",
                "gpu_platform_id": 0,
                "gpu_device_id": 0
            }
        else:
            return {
                "device": "cpu"
            }

    elif model_name in ["random_forest", "svm"]:
        # sklearn não usa GPU
        return {}

    return {}

# %%
def get_feature_types(df):
    """
    Identifica automaticamente colunas categóricas e numéricas de um dataframe.

    Retorna:
        cat_cols  -> lista de colunas categóricas
        num_cols  -> lista de colunas numéricas
    """

    # CATEGÓRICAS: object, category ou boolean
    cat_cols = df.select_dtypes(include=['object', 'category', 'bool']).columns.tolist()

    # NUMÉRICAS: int, float
    num_cols = df.select_dtypes(include=['int', 'float', 'int64', 'float64']).columns.tolist()

    return cat_cols, num_cols

# %% [markdown]
# ###  1. FUNÇÃO PARA CRIAR O MODELO A PARTIR DO TRIAL (Optuna)

# %%
def create_model(trial, gpu_info):
    model_name = trial.suggest_categorical(
        "model_name", ["svm","xgboost", "lightgbm", "random_forest"]
    )

    gpu_params = get_model_params_gpu(model_name, gpu_info)

    # RANDOM FOREST
    if model_name == "random_forest":
        return RandomForestClassifier(
            n_estimators=trial.suggest_int("n_estimators", 5, 30),
            max_depth=trial.suggest_int("max_depth", 3, 9),
            min_samples_split=trial.suggest_int("min_samples_split", 2, 10),
            min_samples_leaf=trial.suggest_int("min_samples_leaf", 1, 5),
            random_state=42,
            class_weight= 'balanced',
            **gpu_params
        )

    # SVM
    elif model_name == "svm":
        svm= LinearSVC(
            C=trial.suggest_float("C", 0.1, 3.0),
            max_iter=5000,
            class_weight= 'balanced'
        )
        return CalibratedClassifierCV(svm, method="sigmoid")

    # XGBOOST
    elif model_name == "xgboost":
        return XGBClassifier(
            n_estimators=trial.suggest_int("n_estimators", 5, 30),
            max_depth=trial.suggest_int("max_depth", 3, 9),
            learning_rate=trial.suggest_float("learning_rate", 0.01, 0.3),
            subsample=trial.suggest_float("subsample", 0.5, 1.0),
            colsample_bytree=trial.suggest_float("colsample_bytree", 0.5, 1.0),
            eval_metric="logloss",
            random_state=42,
            class_weight= 'balanced',
            n_jobs=-1,
            #**gpu_params
        )

    # LIGHTGBM
    elif model_name == "lightgbm":
        return LGBMClassifier(
            n_estimators=trial.suggest_int("n_estimators", 5, 30),
            learning_rate=trial.suggest_float("learning_rate", 0.01, 0.3),
            max_depth=trial.suggest_int("max_depth", 3, 9),
            subsample=trial.suggest_float("subsample", 0.5, 1.0),
            colsample_bytree=trial.suggest_float("colsample_bytree", 0.5, 1.0),
            random_state=42,
            is_unbalance=True,
           force_col_wise=True,
            **gpu_params
        )

# %% [markdown]
# ### 2. FUNÇÃO OBJETIVO DO OPTUNA (COM CROSS-VALIDATION)

# %%
def build_pipeline(model, cat_cols, num_cols):

    # construindo o preprocessor
    num_preprocessor = Pipeline(steps=[
        ("imputer", SimpleImputer(strategy="median")),
        ("scaler", StandardScaler())
    ])

    cat_preprocessor = Pipeline(steps=[
        ("imputer", SimpleImputer(strategy="most_frequent")),
        ("onehot", OneHotEncoder(handle_unknown='infrequent_if_exist'))
    ])

    preprocessor = ColumnTransformer(
        transformers=[
            ("num", num_preprocessor, num_cols),
            ("cat", cat_preprocessor, cat_cols)
        ]
    )

    # construindo pipe
    pipe = Pipeline([
        ("preprocessor", preprocessor),
        ("smote", SMOTE(random_state=42)),
        ("model", model)
    ])

    return pipe

# %%
def objective(trial, X_train, y_train, cat_cols, num_cols,feature_names, gpu_info):

    model = create_model(trial, gpu_info)

    pipe = build_pipeline(model ,cat_cols, num_cols)


    cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

    scores = []
    for step, (train_idx, val_idx) in enumerate(cv.split(X_train, y_train)):

        X_tr, X_val = X_train.iloc[train_idx], X_train.iloc[val_idx]
        y_tr, y_val = y_train.iloc[train_idx], y_train.iloc[val_idx]


        pipe.fit(X_tr, y_tr)
        fold_auc = roc_auc_score(y_val, pipe.predict_proba(X_val)[:, 1])
        scores.append(fold_auc)

        #  reporta o valor parcial ao Optuna
        trial.report(fold_auc, step=step)

        #  aborta a tentativa dado a avaliação do pruner
        if trial.should_prune():
            raise TrialPruned()


    return np.mean(scores)

# %%
# salva os logs das tentativas com métricas, tempo de treinamento, e parametros utilizados pelos modelos
def dump_trials(study, trial):
    df_metrics = study.trials_dataframe(attrs=("number", "value", "params", "state","duration"))
    df_metrics.to_csv("log_opt/trials_log_v2.csv", index=False)

# %% [markdown]
# ### 3. VALIDAÇÃO EXTERNA (OUTER CV) + OPTUNA INTERNO

# %%
def outer_cv_training_with_results(
    X, y, cat_cols, num_cols, n_trials=30, n_splits=5
):

    gpu_info = detect_gpu()
    print("\n🔍 GPU detectada:", gpu_info)

    outer_cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
    results = []
    feature_names = X.columns
    fold = 1
    for train_idx, test_idx in outer_cv.split(X, y):

        print(f"\n==============================")
        print(f"  Fold Externo {fold}/{n_splits}")
        print(f"==============================")

        X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

        pruner = SuccessiveHalvingPruner(min_resource=1,
                                 reduction_factor=3,
                                 min_early_stopping_rate=1)

        study = optuna.create_study(direction="maximize")

        objective_fixed = partial(objective,
                          X_train=X_train,
                          y_train=y_train,
                          cat_cols=cat_cols,
                          num_cols=num_cols,
                          feature_names=feature_names,
                          gpu_info=gpu_info)

        study.optimize(objective_fixed,
                      n_trials=n_trials,
                      callbacks=[dump_trials],
                      timeout=1800,
                      n_jobs=-1,
                      )

        best_params = study.best_params
        best_model_name = best_params["model_name"]
        best_model = create_model(study.best_trial, gpu_info)


        pipe = build_pipeline(best_model ,cat_cols, num_cols)

        # treino com timer
        start_time = time.time()
        pipe.fit(X_train, y_train)
        train_time = time.time() - start_time

        # CHECKPOINT
        checkpoint_dir = "checkpoints_best_models"
        if not os.path.exists(checkpoint_dir):
            os.makedirs(checkpoint_dir)

        checkpoint_path = os.path.join(
            checkpoint_dir, f"best_model_fold_{fold}.pkl"
        )
        joblib.dump(pipe, checkpoint_path)

        # predição
        y_pred = pipe.predict(X_test)
        y_pred_prob = pipe.predict_proba(X_test)[:, 1]

        # métricas
        auc = roc_auc_score(y_test, y_pred_prob)
        acc = accuracy_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)
        rec = recall_score(y_test, y_pred)
        prec = precision_score(y_test, y_pred)

        # salvar dados do fold
        results.append({
            "fold": fold,
            "best_model": best_model_name,
            "auc": auc,
            "accuracy": acc,
            "f1": f1,
            "recall": rec,
            "precision": prec,
            "hyperparameters": best_params,
            "checkpoint_path": checkpoint_path,
            "train_time_seconds": train_time,
            #"test_data": {
            #    "X_test": X_test.copy(),
            #    "y_test": y_test.reset_index(drop=True),
            #    "y_pred": pd.Series(y_pred)
            #}
        })

        fold += 1

    return results

# %% [markdown]
# # Execute Framework

# %%
# ================================================
# CRIA DIRETÓRIO DE CHECKPOINTS (se não existir)
# ================================================
import os, joblib
checkpoint_dir = "checkpoints_best_models"

if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)

checkpoint_dir = "log_opt"
if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)


# ================================================

# %%
cat_cols, num_cols = get_feature_types(X_data)
df_results = outer_cv_training_with_results(
    X_data, y_data,
    cat_cols=cat_cols,
    num_cols=num_cols,
    n_trials=30,
    n_splits=5
)
# Out:
# [I 2025-12-08 02:50:12,949] A new study created in memory with name: no-name-1f064c2c-442f-46e7-a4c4-8bdbe0563d89
# 🔍 GPU detectada: {'cuda_available': False, 'lightgbm_gpu': False, 'gpu_info': 'Nenhuma GPU detectada (nvidia-smi não disponível)'}
#
# ==============================
#   Fold Externo 1/5
# ==============================
# [I 2025-12-08 02:50:15,518] Trial 0 finished with value: 0.877089679571785 and parameters: {'model_name': 'random_forest', 'n_estimators': 9, 'max_depth': 5, 'min_samples_split': 10, 'min_samples_leaf': 5}. Best is trial 0 with value: 0.877089679571785.
# [I 2025-12-08 02:50:18,195] Trial 2 finished with value: 0.9297662177141293 and parameters: {'model_name': 'lightgbm', 'n_estimators': 20, 'learning_rate': 0.25080352319157057, 'max_depth': 3, 'subsample': 0.854653019858217, 'colsample_bytree': 0.6573648660611067}. Best is trial 2 with value: 0.9297662177141293.
# [I 2025-12-08 02:50:24,751] Trial 1 finished with value: 0.9262812526926427 and parameters: {'model_name': 'xgboost', 'n_estimators': 22, 'max_depth': 7, 'learning_rate': 0.07252330843916083, 'subsample': 0.5926556753766443, 'colsample_bytree': 0.9592237863347167}. Best is trial 2 with value: 0.9297662177141293.
# [I 2025-12-08 02:50:31,828] Trial 3 finished with value: 0.9039035436529502 and parameters: {'model_name': 'svm', 'C': 2.80319957091853}. Best is trial 2 with value: 0.9297662177141293.
# [I 2025-12-08 02:50:32,798] Trial 4 finished with value: 0.907399722329368 and parameters: {'model_name': 'svm', 'C': 0.6065465323582371}. Best is trial 2 with value: 0.9297662177141293.
# [I 2025-12-08 02:50:33,028] Trial 5 pruned.
# [I 2025-12-08 02:50:37,130] Trial 7 finished with value: 0.915040326845146 and parameters: {'model_name': 'random_forest', 'n_estimators': 17, 'max_depth': 8, 'min_samples_split': 3, 'min_samples_leaf': 3}. Best is trial 2 with value: 0.9297662177141293.
# [I 2025-12-08 02:50:37,400] Trial 6 finished with value: 0.9321944076871564 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.165025969898394, 'max_depth': 5, 'subsample': 0.7878582513758825, 'colsample_bytree': 0.9961178975410104}. Best is trial 6 with value: 0.9321944076871564.
# [I 2025-12-08 02:50:38,143] Trial 9 pruned.
# [I 2025-12-08 02:50:38,171] Trial 8 pruned.
# [I 2025-12-08 02:50:40,903] Trial 10 pruned.
# [I 2025-12-08 02:50:40,984] Trial 11 finished with value: 0.9309526293672205 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.18958878218748218, 'max_depth': 3, 'subsample': 0.9931766435550998, 'colsample_bytree': 0.5111959825902431}. Best is trial 6 with value: 0.9321944076871564.
# [I 2025-12-08 02:50:43,431] Trial 12 finished with value: 0.9299763326225389 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.25566227714665357, 'max_depth': 3, 'subsample': 0.9180215678600008, 'colsample_bytree': 0.5962596625620666}. Best is trial 6 with value: 0.9321944076871564.
# [I 2025-12-08 02:50:43,608] Trial 13 finished with value: 0.9316037313820361 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.19792189101116284, 'max_depth': 3, 'subsample': 0.9825794497423433, 'colsample_bytree': 0.5047561897633552}. Best is trial 6 with value: 0.9321944076871564.
# [I 2025-12-08 02:50:46,119] Trial 14 finished with value: 0.9312815318536757 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.16834329142516416, 'max_depth': 4, 'subsample': 0.9954275345431974, 'colsample_bytree': 0.5113869058976467}. Best is trial 6 with value: 0.9321944076871564.
# [I 2025-12-08 02:50:46,494] Trial 15 finished with value: 0.9320372393968798 and parameters: {'model_name': 'lightgbm', 'n_estimators': 25, 'learning_rate': 0.15470034032493402, 'max_depth': 5, 'subsample': 0.7957639705575358, 'colsample_bytree': 0.7655145536435003}. Best is trial 6 with value: 0.9321944076871564.
# [I 2025-12-08 02:50:47,781] Trial 17 pruned.
# [I 2025-12-08 02:50:49,508] Trial 18 pruned.
# [I 2025-12-08 02:50:50,631] Trial 16 finished with value: 0.9321330565119851 and parameters: {'model_name': 'lightgbm', 'n_estimators': 23, 'learning_rate': 0.12911833609286427, 'max_depth': 9, 'subsample': 0.8025227988985583, 'colsample_bytree': 0.7834251865802764}. Best is trial 6 with value: 0.9321944076871564.
# [I 2025-12-08 02:50:51,773] Trial 20 pruned.
# [I 2025-12-08 02:50:52,417] Trial 19 finished with value: 0.9316517600086992 and parameters: {'model_name': 'lightgbm', 'n_estimators': 20, 'learning_rate': 0.21321511441948285, 'max_depth': 5, 'subsample': 0.8146326541756751, 'colsample_bytree': 0.7090908619573606}. Best is trial 6 with value: 0.9321944076871564.
# [I 2025-12-08 02:50:52,654] Trial 21 pruned.
# [I 2025-12-08 02:50:53,524] Trial 22 pruned.
# [I 2025-12-08 02:50:53,762] Trial 23 pruned.
# [I 2025-12-08 02:50:54,488] Trial 24 pruned.
# [I 2025-12-08 02:50:54,680] Trial 25 pruned.
# [I 2025-12-08 02:50:55,394] Trial 26 pruned.
# [I 2025-12-08 02:50:58,320] Trial 27 pruned.
# [I 2025-12-08 02:50:59,253] Trial 28 pruned.
# [I 2025-12-08 02:51:01,687] Trial 29 pruned.
# [LightGBM] [Info] Number of positive: 5032, number of negative: 5032
# [LightGBM] [Info] Total Bins 32046
# [LightGBM] [Info] Number of data points in the train set: 10064, number of used features: 219
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [I 2025-12-08 02:51:02,918] A new study created in memory with name: no-name-96c5f20d-4532-44d7-9a76-2784369f71c0
# ==============================
#   Fold Externo 2/5
# ==============================
# [I 2025-12-08 02:51:07,087] Trial 1 finished with value: 0.8590024281990957 and parameters: {'model_name': 'xgboost', 'n_estimators': 12, 'max_depth': 5, 'learning_rate': 0.032755168398707395, 'subsample': 0.6683523082625853, 'colsample_bytree': 0.9760586823965525}. Best is trial 1 with value: 0.8590024281990957.
# [I 2025-12-08 02:51:10,130] Trial 2 finished with value: 0.9234640741695754 and parameters: {'model_name': 'lightgbm', 'n_estimators': 17, 'learning_rate': 0.28903995879222616, 'max_depth': 8, 'subsample': 0.7294954398758908, 'colsample_bytree': 0.727932597552903}. Best is trial 2 with value: 0.9234640741695754.
# [I 2025-12-08 02:51:12,712] Trial 0 finished with value: 0.9035963466581981 and parameters: {'model_name': 'svm', 'C': 2.0376331586285596}. Best is trial 2 with value: 0.9234640741695754.
# [I 2025-12-08 02:51:13,140] Trial 3 finished with value: 0.9279054753399582 and parameters: {'model_name': 'lightgbm', 'n_estimators': 16, 'learning_rate': 0.2456046239794583, 'max_depth': 6, 'subsample': 0.8511898496058137, 'colsample_bytree': 0.5216192646047908}. Best is trial 3 with value: 0.9279054753399582.
# [I 2025-12-08 02:51:16,376] Trial 4 finished with value: 0.9183821809955394 and parameters: {'model_name': 'lightgbm', 'n_estimators': 9, 'learning_rate': 0.10652998316433232, 'max_depth': 5, 'subsample': 0.731457553517827, 'colsample_bytree': 0.9291290989695329}. Best is trial 3 with value: 0.9279054753399582.
# [I 2025-12-08 02:51:16,600] Trial 5 pruned.
# [I 2025-12-08 02:51:17,374] Trial 7 pruned.
# [I 2025-12-08 02:51:17,552] Trial 6 pruned.
# [I 2025-12-08 02:51:18,885] Trial 8 pruned.
# [I 2025-12-08 02:51:19,677] Trial 10 pruned.
# [I 2025-12-08 02:51:21,554] Trial 9 pruned.
# [I 2025-12-08 02:51:22,250] Trial 11 finished with value: 0.925956366451269 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.19305703383884049, 'max_depth': 3, 'subsample': 0.9724261084527629, 'colsample_bytree': 0.5067844868158244}. Best is trial 3 with value: 0.9279054753399582.
# [I 2025-12-08 02:51:24,051] Trial 12 finished with value: 0.9255198616910737 and parameters: {'model_name': 'lightgbm', 'n_estimators': 23, 'learning_rate': 0.27489717908320016, 'max_depth': 3, 'subsample': 0.9362523538175693, 'colsample_bytree': 0.572385555729837}. Best is trial 3 with value: 0.9279054753399582.
# [I 2025-12-08 02:51:24,709] Trial 13 finished with value: 0.9272017423533331 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.20036910568533978, 'max_depth': 3, 'subsample': 0.9840198753147974, 'colsample_bytree': 0.5130197088197911}. Best is trial 3 with value: 0.9279054753399582.
# [I 2025-12-08 02:51:27,700] Trial 14 finished with value: 0.9259429327458518 and parameters: {'model_name': 'lightgbm', 'n_estimators': 29, 'learning_rate': 0.1871466133040754, 'max_depth': 3, 'subsample': 0.9888604529435892, 'colsample_bytree': 0.504993435547706}. Best is trial 3 with value: 0.9279054753399582.
# [I 2025-12-08 02:51:29,542] Trial 15 finished with value: 0.9264660549834461 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.21262203793773643, 'max_depth': 4, 'subsample': 0.872765979166071, 'colsample_bytree': 0.6159050416368452}. Best is trial 3 with value: 0.9279054753399582.
# [I 2025-12-08 02:51:29,628] Trial 16 pruned.
# [I 2025-12-08 02:51:30,898] Trial 17 pruned.
# [I 2025-12-08 02:51:32,699] Trial 19 pruned.
# [I 2025-12-08 02:51:33,505] Trial 20 pruned.
# [I 2025-12-08 02:51:37,286] Trial 21 finished with value: 0.9271744749460463 and parameters: {'model_name': 'lightgbm', 'n_estimators': 25, 'learning_rate': 0.1507587619927701, 'max_depth': 6, 'subsample': 0.8027699803391161, 'colsample_bytree': 0.5706761485549545}. Best is trial 3 with value: 0.9279054753399582.
# [I 2025-12-08 02:51:38,677] Trial 18 finished with value: 0.9249437998528279 and parameters: {'model_name': 'xgboost', 'n_estimators': 21, 'max_depth': 9, 'learning_rate': 0.14014964176460548, 'subsample': 0.5599843162898054, 'colsample_bytree': 0.6995472509059557}. Best is trial 3 with value: 0.9279054753399582.
# [I 2025-12-08 02:51:40,730] Trial 22 finished with value: 0.9268807874455129 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.15045163729976524, 'max_depth': 6, 'subsample': 0.8085841344600615, 'colsample_bytree': 0.5503149982766727}. Best is trial 3 with value: 0.9279054753399582.
# [I 2025-12-08 02:51:42,296] Trial 24 pruned.
# [I 2025-12-08 02:51:42,994] Trial 23 finished with value: 0.9246851889534793 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.24303275813718972, 'max_depth': 7, 'subsample': 0.8048396436978752, 'colsample_bytree': 0.5598330021273863}. Best is trial 3 with value: 0.9279054753399582.
# [I 2025-12-08 02:51:44,978] Trial 25 finished with value: 0.924104925748987 and parameters: {'model_name': 'lightgbm', 'n_estimators': 19, 'learning_rate': 0.1835142665205173, 'max_depth': 4, 'subsample': 0.9277685199740134, 'colsample_bytree': 0.5079125207152715}. Best is trial 3 with value: 0.9279054753399582.
# [I 2025-12-08 02:51:45,374] Trial 26 finished with value: 0.9234646404803423 and parameters: {'model_name': 'lightgbm', 'n_estimators': 19, 'learning_rate': 0.17605440685145043, 'max_depth': 4, 'subsample': 0.9227671175683245, 'colsample_bytree': 0.5047796622434235}. Best is trial 3 with value: 0.9279054753399582.
# [I 2025-12-08 02:51:45,766] Trial 27 pruned.
# [I 2025-12-08 02:51:47,065] Trial 29 pruned.
# [I 2025-12-08 02:51:47,196] Trial 28 pruned.
# [LightGBM] [Info] Number of positive: 5032, number of negative: 5032
# [LightGBM] [Info] Total Bins 32334
# [LightGBM] [Info] Number of data points in the train set: 10064, number of used features: 220
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-12-08 02:51:48,056] A new study created in memory with name: no-name-80873292-b518-4324-a299-7f71b75815b9
# ==============================
#   Fold Externo 3/5
# ==============================
# [I 2025-12-08 02:51:57,775] Trial 1 finished with value: 0.9146119966089419 and parameters: {'model_name': 'svm', 'C': 0.8526683347706002}. Best is trial 1 with value: 0.9146119966089419.
# [I 2025-12-08 02:51:59,744] Trial 2 finished with value: 0.8641634780044208 and parameters: {'model_name': 'random_forest', 'n_estimators': 9, 'max_depth': 3, 'min_samples_split': 5, 'min_samples_leaf': 5}. Best is trial 1 with value: 0.9146119966089419.
# [I 2025-12-08 02:52:00,358] Trial 0 finished with value: 0.9132118961844009 and parameters: {'model_name': 'svm', 'C': 2.7377374616609518}. Best is trial 1 with value: 0.9146119966089419.
# [I 2025-12-08 02:52:03,172] Trial 3 finished with value: 0.9194759258213748 and parameters: {'model_name': 'random_forest', 'n_estimators': 29, 'max_depth': 6, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.9194759258213748.
# [I 2025-12-08 02:52:09,572] Trial 5 finished with value: 0.9254505410427242 and parameters: {'model_name': 'random_forest', 'n_estimators': 30, 'max_depth': 9, 'min_samples_split': 5, 'min_samples_leaf': 3}. Best is trial 5 with value: 0.9254505410427242.
# [I 2025-12-08 02:52:12,912] Trial 6 finished with value: 0.9225103686631275 and parameters: {'model_name': 'lightgbm', 'n_estimators': 29, 'learning_rate': 0.03258590585364227, 'max_depth': 5, 'subsample': 0.6072503089764572, 'colsample_bytree': 0.7537766367384581}. Best is trial 5 with value: 0.9254505410427242.
# [I 2025-12-08 02:52:13,190] Trial 4 finished with value: 0.9267560065171138 and parameters: {'model_name': 'xgboost', 'n_estimators': 24, 'max_depth': 9, 'learning_rate': 0.09507322592339713, 'subsample': 0.6131192611021691, 'colsample_bytree': 0.68999446773742}. Best is trial 4 with value: 0.9267560065171138.
# [I 2025-12-08 02:52:15,490] Trial 7 pruned.
# [I 2025-12-08 02:52:16,358] Trial 8 pruned.
# [I 2025-12-08 02:52:17,415] Trial 10 pruned.
# [I 2025-12-08 02:52:24,726] Trial 9 finished with value: 0.9250087052420909 and parameters: {'model_name': 'xgboost', 'n_estimators': 28, 'max_depth': 8, 'learning_rate': 0.05404430807905, 'subsample': 0.7738063611055586, 'colsample_bytree': 0.6627553299377101}. Best is trial 4 with value: 0.9267560065171138.
# [I 2025-12-08 02:52:24,964] Trial 11 pruned.
# [I 2025-12-08 02:52:27,025] Trial 12 pruned.
# [I 2025-12-08 02:52:27,371] Trial 13 pruned.
# [I 2025-12-08 02:52:29,921] Trial 14 finished with value: 0.9278877046905495 and parameters: {'model_name': 'lightgbm', 'n_estimators': 24, 'learning_rate': 0.17356661287142, 'max_depth': 8, 'subsample': 0.7038733676275393, 'colsample_bytree': 0.5079568610149597}. Best is trial 14 with value: 0.9278877046905495.
# [I 2025-12-08 02:52:30,314] Trial 15 finished with value: 0.9281719357135492 and parameters: {'model_name': 'lightgbm', 'n_estimators': 25, 'learning_rate': 0.16756544177132265, 'max_depth': 7, 'subsample': 0.7204825207372091, 'colsample_bytree': 0.5038533120494004}. Best is trial 15 with value: 0.9281719357135492.
# [I 2025-12-08 02:52:32,969] Trial 17 finished with value: 0.9251447883860395 and parameters: {'model_name': 'lightgbm', 'n_estimators': 15, 'learning_rate': 0.18426104738490268, 'max_depth': 7, 'subsample': 0.7733286649765455, 'colsample_bytree': 0.513777693984728}. Best is trial 15 with value: 0.9281719357135492.
# [I 2025-12-08 02:52:32,991] Trial 16 finished with value: 0.9266132918530331 and parameters: {'model_name': 'lightgbm', 'n_estimators': 24, 'learning_rate': 0.1636563172215662, 'max_depth': 7, 'subsample': 0.7074865785281139, 'colsample_bytree': 0.5016692515645556}. Best is trial 15 with value: 0.9281719357135492.
# [I 2025-12-08 02:52:35,851] Trial 18 pruned.
# [I 2025-12-08 02:52:35,883] Trial 19 pruned.
# [I 2025-12-08 02:52:36,913] Trial 20 pruned.
# [I 2025-12-08 02:52:36,948] Trial 21 pruned.
# [I 2025-12-08 02:52:43,540] Trial 23 finished with value: 0.9282617774430539 and parameters: {'model_name': 'xgboost', 'n_estimators': 23, 'max_depth': 8, 'learning_rate': 0.11315751309043776, 'subsample': 0.5958926905863006, 'colsample_bytree': 0.5949007476250479}. Best is trial 23 with value: 0.9282617774430539.
# [I 2025-12-08 02:52:44,342] Trial 22 finished with value: 0.9264787185904302 and parameters: {'model_name': 'xgboost', 'n_estimators': 26, 'max_depth': 8, 'learning_rate': 0.11491878937857633, 'subsample': 0.6073609288077538, 'colsample_bytree': 0.6270828272797301}. Best is trial 23 with value: 0.9282617774430539.
# [I 2025-12-08 02:52:47,141] Trial 25 pruned.
# [I 2025-12-08 02:52:48,855] Trial 24 pruned.
# [I 2025-12-08 02:52:50,677] Trial 27 pruned.
# [I 2025-12-08 02:52:52,746] Trial 28 pruned.
# [I 2025-12-08 02:52:53,325] Trial 26 finished with value: 0.9286149571878773 and parameters: {'model_name': 'xgboost', 'n_estimators': 22, 'max_depth': 8, 'learning_rate': 0.14520615797953018, 'subsample': 0.6307031136229213, 'colsample_bytree': 0.5034854785114284}. Best is trial 26 with value: 0.9286149571878773.
# [I 2025-12-08 02:52:54,042] Trial 29 pruned.
# [I 2025-12-08 02:52:55,635] A new study created in memory with name: no-name-4eac63eb-7e61-4b5b-8d47-f308b0e254e4
# ==============================
#   Fold Externo 4/5
# ==============================
# [I 2025-12-08 02:52:58,424] Trial 1 finished with value: 0.9109513446953809 and parameters: {'model_name': 'random_forest', 'n_estimators': 24, 'max_depth': 6, 'min_samples_split': 6, 'min_samples_leaf': 5}. Best is trial 1 with value: 0.9109513446953809.
# [I 2025-12-08 02:52:58,719] Trial 0 finished with value: 0.9251619490527202 and parameters: {'model_name': 'lightgbm', 'n_estimators': 24, 'learning_rate': 0.1913218919817659, 'max_depth': 9, 'subsample': 0.807172124116228, 'colsample_bytree': 0.5902539158102358}. Best is trial 0 with value: 0.9251619490527202.
# [I 2025-12-08 02:53:07,819] Trial 2 finished with value: 0.9088437430903529 and parameters: {'model_name': 'svm', 'C': 0.7931269825025722}. Best is trial 0 with value: 0.9251619490527202.
# [I 2025-12-08 02:53:10,265] Trial 3 finished with value: 0.9067635620077564 and parameters: {'model_name': 'svm', 'C': 2.465761015984502}. Best is trial 0 with value: 0.9251619490527202.
# [I 2025-12-08 02:53:11,163] Trial 4 finished with value: 0.9220870337145429 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.24200087448040106, 'max_depth': 8, 'subsample': 0.6432260493691718, 'colsample_bytree': 0.5727431626285934}. Best is trial 0 with value: 0.9251619490527202.
# [I 2025-12-08 02:53:13,698] Trial 5 finished with value: 0.9250674912072151 and parameters: {'model_name': 'xgboost', 'n_estimators': 18, 'max_depth': 3, 'learning_rate': 0.2917169000503536, 'subsample': 0.6230948262144378, 'colsample_bytree': 0.7024626505407512}. Best is trial 0 with value: 0.9251619490527202.
# [I 2025-12-08 02:53:14,873] Trial 6 pruned.
# [I 2025-12-08 02:53:15,322] Trial 7 pruned.
# [I 2025-12-08 02:53:15,675] Trial 8 pruned.
# [I 2025-12-08 02:53:17,745] Trial 9 pruned.
# [I 2025-12-08 02:53:20,061] Trial 11 finished with value: 0.9220025682220393 and parameters: {'model_name': 'lightgbm', 'n_estimators': 13, 'learning_rate': 0.012236861882499284, 'max_depth': 9, 'subsample': 0.9565242880577012, 'colsample_bytree': 0.5095360128933106}. Best is trial 0 with value: 0.9251619490527202.
# [I 2025-12-08 02:53:20,564] Trial 10 finished with value: 0.9242260094549822 and parameters: {'model_name': 'xgboost', 'n_estimators': 30, 'max_depth': 5, 'learning_rate': 0.2811600753858591, 'subsample': 0.7592173578546885, 'colsample_bytree': 0.6968592185588798}. Best is trial 0 with value: 0.9251619490527202.
# [I 2025-12-08 02:53:21,473] Trial 13 pruned.
# [I 2025-12-08 02:53:22,611] Trial 12 finished with value: 0.9243543972571194 and parameters: {'model_name': 'xgboost', 'n_estimators': 17, 'max_depth': 3, 'learning_rate': 0.28963162881095833, 'subsample': 0.5218696005567993, 'colsample_bytree': 0.6881874709895897}. Best is trial 0 with value: 0.9251619490527202.
# [I 2025-12-08 02:53:23,538] Trial 15 pruned.
# [I 2025-12-08 02:53:24,223] Trial 14 finished with value: 0.9229667440632311 and parameters: {'model_name': 'lightgbm', 'n_estimators': 18, 'learning_rate': 0.15750250962827972, 'max_depth': 5, 'subsample': 0.8450783430095559, 'colsample_bytree': 0.9996281660797636}. Best is trial 0 with value: 0.9251619490527202.
# [I 2025-12-08 02:53:27,079] Trial 16 finished with value: 0.9231678851953132 and parameters: {'model_name': 'lightgbm', 'n_estimators': 13, 'learning_rate': 0.20740158264493555, 'max_depth': 7, 'subsample': 0.6397655424727772, 'colsample_bytree': 0.8276192316962818}. Best is trial 0 with value: 0.9251619490527202.
# [I 2025-12-08 02:53:27,784] Trial 17 finished with value: 0.9262049660670058 and parameters: {'model_name': 'lightgbm', 'n_estimators': 14, 'learning_rate': 0.22835610265051226, 'max_depth': 7, 'subsample': 0.6608143349201483, 'colsample_bytree': 0.5977940029474059}. Best is trial 17 with value: 0.9262049660670058.
# [I 2025-12-08 02:53:28,589] Trial 19 pruned.
# [I 2025-12-08 02:53:29,460] Trial 18 pruned.
# [I 2025-12-08 02:53:30,367] Trial 21 pruned.
# [I 2025-12-08 02:53:30,999] Trial 20 finished with value: 0.9240381368533898 and parameters: {'model_name': 'lightgbm', 'n_estimators': 11, 'learning_rate': 0.22520786236199933, 'max_depth': 7, 'subsample': 0.9393957496249706, 'colsample_bytree': 0.5820006368923274}. Best is trial 17 with value: 0.9262049660670058.
# [I 2025-12-08 02:53:31,692] Trial 23 pruned.
# [I 2025-12-08 02:53:32,585] Trial 22 finished with value: 0.9254684775953524 and parameters: {'model_name': 'lightgbm', 'n_estimators': 10, 'learning_rate': 0.2628514742109294, 'max_depth': 4, 'subsample': 0.5906950604360545, 'colsample_bytree': 0.6339990411757077}. Best is trial 17 with value: 0.9262049660670058.
# [I 2025-12-08 02:53:33,352] Trial 25 pruned.
# [I 2025-12-08 02:53:34,510] Trial 24 pruned.
# [I 2025-12-08 02:53:36,027] Trial 26 finished with value: 0.9242810466273416 and parameters: {'model_name': 'lightgbm', 'n_estimators': 15, 'learning_rate': 0.17924372305667458, 'max_depth': 8, 'subsample': 0.7088017652505247, 'colsample_bytree': 0.7920287201529109}. Best is trial 17 with value: 0.9262049660670058.
# [I 2025-12-08 02:53:36,707] Trial 28 pruned.
# [I 2025-12-08 02:53:37,040] Trial 27 finished with value: 0.9261523467468699 and parameters: {'model_name': 'lightgbm', 'n_estimators': 15, 'learning_rate': 0.17706924928686957, 'max_depth': 6, 'subsample': 0.7046246147297391, 'colsample_bytree': 0.6304598768000477}. Best is trial 17 with value: 0.9262049660670058.
# [I 2025-12-08 02:53:38,234] Trial 29 finished with value: 0.9241418093460485 and parameters: {'model_name': 'lightgbm', 'n_estimators': 10, 'learning_rate': 0.256670264455548, 'max_depth': 4, 'subsample': 0.5822715446305166, 'colsample_bytree': 0.635636929614149}. Best is trial 17 with value: 0.9262049660670058.
# [LightGBM] [Info] Number of positive: 5032, number of negative: 5032
# [LightGBM] [Info] Total Bins 32193
# [LightGBM] [Info] Number of data points in the train set: 10064, number of used features: 213
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-12-08 02:53:39,436] A new study created in memory with name: no-name-9eb573a6-c88a-4a37-9667-a899e2e1a78d
# ==============================
#   Fold Externo 5/5
# ==============================
# [I 2025-12-08 02:53:42,234] Trial 1 finished with value: 0.9156229917785758 and parameters: {'model_name': 'lightgbm', 'n_estimators': 10, 'learning_rate': 0.14238482612463485, 'max_depth': 3, 'subsample': 0.8389046596313314, 'colsample_bytree': 0.8013314452057849}. Best is trial 1 with value: 0.9156229917785758.
# [I 2025-12-08 02:53:50,252] Trial 0 finished with value: 0.9104303039838485 and parameters: {'model_name': 'svm', 'C': 2.1047084644348018}. Best is trial 1 with value: 0.9156229917785758.
# [I 2025-12-08 02:53:53,214] Trial 2 finished with value: 0.9105192220488648 and parameters: {'model_name': 'svm', 'C': 1.9659761118286065}. Best is trial 1 with value: 0.9156229917785758.
# [I 2025-12-08 02:53:59,141] Trial 3 finished with value: 0.9059411852523529 and parameters: {'model_name': 'xgboost', 'n_estimators': 23, 'max_depth': 7, 'learning_rate': 0.03469035736451792, 'subsample': 0.9380565968957606, 'colsample_bytree': 0.9275723580394767}. Best is trial 1 with value: 0.9156229917785758.
# [I 2025-12-08 02:54:01,149] Trial 5 finished with value: 0.8964260566187644 and parameters: {'model_name': 'random_forest', 'n_estimators': 15, 'max_depth': 3, 'min_samples_split': 9, 'min_samples_leaf': 5}. Best is trial 1 with value: 0.9156229917785758.
# [I 2025-12-08 02:54:03,359] Trial 4 finished with value: 0.910393601190625 and parameters: {'model_name': 'svm', 'C': 2.160308893743821}. Best is trial 1 with value: 0.9156229917785758.
# [I 2025-12-08 02:54:04,161] Trial 6 finished with value: 0.9242380762283063 and parameters: {'model_name': 'lightgbm', 'n_estimators': 19, 'learning_rate': 0.10937735011903779, 'max_depth': 6, 'subsample': 0.9584736270678689, 'colsample_bytree': 0.8311820215050114}. Best is trial 6 with value: 0.9242380762283063.
# [I 2025-12-08 02:54:04,389] Trial 7 pruned.
# [I 2025-12-08 02:54:05,877] Trial 8 pruned.
# [I 2025-12-08 02:54:08,648] Trial 10 finished with value: 0.9177072731949276 and parameters: {'model_name': 'lightgbm', 'n_estimators': 7, 'learning_rate': 0.08459922541172644, 'max_depth': 6, 'subsample': 0.9359159234756222, 'colsample_bytree': 0.8296871119260685}. Best is trial 6 with value: 0.9242380762283063.
# [I 2025-12-08 02:54:08,831] Trial 9 finished with value: 0.9204588160278805 and parameters: {'model_name': 'xgboost', 'n_estimators': 27, 'max_depth': 3, 'learning_rate': 0.12430511544197961, 'subsample': 0.8336066336641987, 'colsample_bytree': 0.7178035325606696}. Best is trial 6 with value: 0.9242380762283063.
# [I 2025-12-08 02:54:11,963] Trial 11 finished with value: 0.9238481291141661 and parameters: {'model_name': 'lightgbm', 'n_estimators': 29, 'learning_rate': 0.23788275421079352, 'max_depth': 9, 'subsample': 0.6138932963150614, 'colsample_bytree': 0.5532646330698499}. Best is trial 6 with value: 0.9242380762283063.
# [I 2025-12-08 02:54:12,173] Trial 12 finished with value: 0.9222170089921283 and parameters: {'model_name': 'lightgbm', 'n_estimators': 29, 'learning_rate': 0.2534949337107574, 'max_depth': 9, 'subsample': 0.6834090785583423, 'colsample_bytree': 0.6481835206411121}. Best is trial 6 with value: 0.9242380762283063.
# [I 2025-12-08 02:54:15,205] Trial 13 finished with value: 0.923323536799112 and parameters: {'model_name': 'lightgbm', 'n_estimators': 29, 'learning_rate': 0.2530884156749351, 'max_depth': 9, 'subsample': 0.5966365094085597, 'colsample_bytree': 0.50852805803523}. Best is trial 6 with value: 0.9242380762283063.
# [I 2025-12-08 02:54:15,298] Trial 14 finished with value: 0.9252696450690653 and parameters: {'model_name': 'lightgbm', 'n_estimators': 22, 'learning_rate': 0.23653491774376956, 'max_depth': 9, 'subsample': 0.5010156720023777, 'colsample_bytree': 0.507388575730016}. Best is trial 14 with value: 0.9252696450690653.
# [I 2025-12-08 02:54:16,060] Trial 16 pruned.
# [I 2025-12-08 02:54:19,058] Trial 15 finished with value: 0.927059293139513 and parameters: {'model_name': 'lightgbm', 'n_estimators': 22, 'learning_rate': 0.2030351832650196, 'max_depth': 6, 'subsample': 0.5112951098006145, 'colsample_bytree': 0.9940585059956877}. Best is trial 15 with value: 0.927059293139513.
# [I 2025-12-08 02:54:19,237] Trial 17 finished with value: 0.9227883926781772 and parameters: {'model_name': 'lightgbm', 'n_estimators': 14, 'learning_rate': 0.17665760676579767, 'max_depth': 7, 'subsample': 0.5455392529731474, 'colsample_bytree': 0.966210944541998}. Best is trial 15 with value: 0.927059293139513.
# [I 2025-12-08 02:54:23,236] Trial 19 finished with value: 0.9261904973942011 and parameters: {'model_name': 'lightgbm', 'n_estimators': 24, 'learning_rate': 0.1970251274271735, 'max_depth': 8, 'subsample': 0.5043451133347038, 'colsample_bytree': 0.9985154935533147}. Best is trial 15 with value: 0.927059293139513.
# [I 2025-12-08 02:54:23,440] Trial 18 finished with value: 0.9265041530368262 and parameters: {'model_name': 'lightgbm', 'n_estimators': 24, 'learning_rate': 0.19850524364401884, 'max_depth': 8, 'subsample': 0.5056760077513304, 'colsample_bytree': 0.9689559871972833}. Best is trial 15 with value: 0.927059293139513.
# [I 2025-12-08 02:54:24,262] Trial 21 pruned.
# [I 2025-12-08 02:54:25,613] Trial 20 pruned.
# [I 2025-12-08 02:54:27,768] Trial 22 finished with value: 0.9256648742492531 and parameters: {'model_name': 'lightgbm', 'n_estimators': 24, 'learning_rate': 0.19044325879677468, 'max_depth': 8, 'subsample': 0.5248254509355377, 'colsample_bytree': 0.9997596674160812}. Best is trial 15 with value: 0.927059293139513.
# [I 2025-12-08 02:54:29,113] Trial 23 finished with value: 0.92603543751507 and parameters: {'model_name': 'lightgbm', 'n_estimators': 23, 'learning_rate': 0.19044751603662602, 'max_depth': 8, 'subsample': 0.5015539326428077, 'colsample_bytree': 0.9993009501355128}. Best is trial 15 with value: 0.927059293139513.
# [I 2025-12-08 02:54:30,993] Trial 24 finished with value: 0.9233736775029328 and parameters: {'model_name': 'lightgbm', 'n_estimators': 21, 'learning_rate': 0.29581438562048346, 'max_depth': 8, 'subsample': 0.5946135511542933, 'colsample_bytree': 0.9076555936417713}. Best is trial 15 with value: 0.927059293139513.
# [I 2025-12-08 02:54:33,040] Trial 25 finished with value: 0.923810111550139 and parameters: {'model_name': 'lightgbm', 'n_estimators': 21, 'learning_rate': 0.29865502471538247, 'max_depth': 7, 'subsample': 0.5957482247940898, 'colsample_bytree': 0.9082108885018891}. Best is trial 15 with value: 0.927059293139513.
# [I 2025-12-08 02:54:35,130] Trial 26 finished with value: 0.9263099060313147 and parameters: {'model_name': 'lightgbm', 'n_estimators': 16, 'learning_rate': 0.21246950867232703, 'max_depth': 7, 'subsample': 0.6833978116257787, 'colsample_bytree': 0.9053710051223147}. Best is trial 15 with value: 0.927059293139513.
# [I 2025-12-08 02:54:36,507] Trial 27 finished with value: 0.9273609127666184 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.221486454257907, 'max_depth': 5, 'subsample': 0.6753402059985969, 'colsample_bytree': 0.9482414595404713}. Best is trial 27 with value: 0.9273609127666184.
# [I 2025-12-08 02:54:37,630] Trial 28 finished with value: 0.9265706012570823 and parameters: {'model_name': 'lightgbm', 'n_estimators': 15, 'learning_rate': 0.20825042365638072, 'max_depth': 5, 'subsample': 0.6987391044023069, 'colsample_bytree': 0.8809834510872974}. Best is trial 27 with value: 0.9273609127666184.
# [I 2025-12-08 02:54:38,319] Trial 29 pruned.
# [LightGBM] [Info] Number of positive: 5032, number of negative: 5032
# [LightGBM] [Info] Total Bins 32510
# [LightGBM] [Info] Number of data points in the train set: 10064, number of used features: 220
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %% [markdown]
# #### Conferir checkpoints intermediarios

# %%
df_results=pd.DataFrame(df_results)

# %%
df_results.to_parquet('df_results.parquet')

# %%
df_metrics = pd.read_csv('log_opt/trials_log_v2.csv')
display(df_metrics)
# Out:
#     number     value  params_C  params_colsample_bytree  params_learning_rate  \
# 0        0  0.910430  2.104708                      NaN                   NaN
# 1        1  0.915623       NaN                 0.801331              0.142385
# 2        2  0.910519  1.965976                      NaN                   NaN
# 3        3  0.905941       NaN                 0.927572              0.034690
# 4        4  0.910394  2.160309                      NaN                   NaN
# 5        5  0.896426       NaN                      NaN                   NaN
# 6        6  0.924238       NaN                 0.831182              0.109377
# 7        7  0.904468       NaN                 0.833155              0.109921
# 8        8  0.860768       NaN                 0.629464              0.032521
# 9        9  0.920459       NaN                 0.717804              0.124305
# 10      10  0.917707       NaN                 0.829687              0.084599
# 11      11  0.923848       NaN                 0.553265              0.237883
# 12      12  0.922217       NaN                 0.648184              0.253495
# 13      13  0.923324       NaN                 0.508528              0.253088
# 14      14  0.925270       NaN                 0.507389              0.236535
# 15      15  0.927059       NaN                 0.994059              0.203035
# 16      16  0.913684       NaN                      NaN                   NaN
# 17      17  0.922788       NaN                 0.966211              0.176658
# 18      18  0.926504       NaN                 0.968956              0.198505
# 19      19  0.926190       NaN                 0.998515              0.197025
# 20      20  0.924082       NaN                      NaN                   NaN
# 21      21  0.914008       NaN                      NaN                   NaN
# 22      22  0.925665       NaN                 0.999760              0.190443
# 23      23  0.926035       NaN                 0.999301              0.190448
# 24      24  0.923374       NaN                 0.907656              0.295814
# 25      25  0.923810       NaN                 0.908211              0.298655
# 26      26  0.926310       NaN                 0.905371              0.212470
# 27      27  0.927361       NaN                 0.948241              0.221486
# 28      28  0.926571       NaN                 0.880983              0.208250
# 29      29  0.914230  0.317648                      NaN                   NaN
#
#     params_max_depth  params_min_samples_leaf  params_min_samples_split  \
# 0                NaN                      NaN                       NaN
# 1                3.0                      NaN                       NaN
# 2                NaN                      NaN                       NaN
# 3                7.0                      NaN                       NaN
# 4                NaN                      NaN                       NaN
# 5                3.0                      5.0                       9.0
# 6                6.0                      NaN                       NaN
# 7                7.0                      NaN                       NaN
# 8                4.0                      NaN                       NaN
# 9                3.0                      NaN                       NaN
# 10               6.0                      NaN                       NaN
# 11               9.0                      NaN                       NaN
# 12               9.0                      NaN                       NaN
# 13               9.0                      NaN                       NaN
# 14               9.0                      NaN                       NaN
# 15               6.0                      NaN                       NaN
# 16               5.0                      1.0                       2.0
# 17               7.0                      NaN                       NaN
# 18               8.0                      NaN                       NaN
# 19               8.0                      NaN                       NaN
# 20               8.0                      3.0                       4.0
# 21               5.0                      3.0                       4.0
# 22               8.0                      NaN                       NaN
# 23               8.0                      NaN                       NaN
# 24               8.0                      NaN                       NaN
# 25               7.0                      NaN                       NaN
# 26               7.0                      NaN                       NaN
# 27               5.0                      NaN                       NaN
# 28               5.0                      NaN                       NaN
# 29               NaN                      NaN                       NaN
#
#    params_model_name  params_n_estimators  params_subsample     state  \
# 0                svm                  NaN               NaN  COMPLETE
# 1           lightgbm                 10.0          0.838905  COMPLETE
# 2                svm                  NaN               NaN  COMPLETE
# 3            xgboost                 23.0          0.938057  COMPLETE
# 4                svm                  NaN               NaN  COMPLETE
# 5      random_forest                 15.0               NaN  COMPLETE
# 6           lightgbm                 19.0          0.958474  COMPLETE
# 7            xgboost                  5.0          0.972424    PRUNED
# 8            xgboost                 18.0          0.902481    PRUNED
# 9            xgboost                 27.0          0.833607  COMPLETE
# 10          lightgbm                  7.0          0.935916  COMPLETE
# 11          lightgbm                 29.0          0.613893  COMPLETE
# 12          lightgbm                 29.0          0.683409  COMPLETE
# 13          lightgbm                 29.0          0.596637  COMPLETE
# 14          lightgbm                 22.0          0.501016  COMPLETE
# 15          lightgbm                 22.0          0.511295  COMPLETE
# 16     random_forest                 20.0               NaN    PRUNED
# 17          lightgbm                 14.0          0.545539  COMPLETE
# 18          lightgbm                 24.0          0.505676  COMPLETE
# 19          lightgbm                 24.0          0.504345  COMPLETE
# 20     random_forest                 25.0               NaN    PRUNED
# 21     random_forest                 25.0               NaN    PRUNED
# 22          lightgbm                 24.0          0.524825  COMPLETE
# 23          lightgbm                 23.0          0.501554  COMPLETE
# 24          lightgbm                 21.0          0.594614  COMPLETE
# 25          lightgbm                 21.0          0.595748  COMPLETE
# 26          lightgbm                 16.0          0.683398  COMPLETE
# 27          lightgbm                 26.0          0.675340  COMPLETE
# 28          lightgbm                 15.0          0.698739  COMPLETE
# 29               svm                  NaN               NaN    PRUNED
#
#                   duration
# 0   0 days 00:00:10.808315
# 1   0 days 00:00:02.786003
# 2   0 days 00:00:10.969289
# 3   0 days 00:00:08.875986
# 4   0 days 00:00:10.123704
# 5   0 days 00:00:01.998935
# 6   0 days 00:00:03.001261
# 7   0 days 00:00:01.019491
# 8   0 days 00:00:01.698765
# 9   0 days 00:00:04.426358
# 10  0 days 00:00:02.749617
# 11  0 days 00:00:03.305684
# 12  0 days 00:00:03.330227
# 13  0 days 00:00:03.229935
# 14  0 days 00:00:03.116537
# 15  0 days 00:00:03.839646
# 16  0 days 00:00:00.752225
# 17  0 days 00:00:03.167419
# 18  0 days 00:00:04.362157
# 19  0 days 00:00:03.976481
# 20  0 days 00:00:02.366755
# 21  0 days 00:00:00.811191
# 22  0 days 00:00:03.494273
# 23  0 days 00:00:03.490444
# 24  0 days 00:00:03.214006
# 25  0 days 00:00:03.914308
# 26  0 days 00:00:04.125537
# 27  0 days 00:00:03.455484
# 28  0 days 00:00:02.488984
# 29  0 days 00:00:01.804149

# %% [markdown]
# Carregando o pkl

# %%
import joblib

modelo = joblib.load("checkpoints_best_models/best_model_fold_1.pkl")

# %%
modelo
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['id_municipio', 'nu_idade_n',
#                                                    'baixa_escolaridade',
#                                                    'raca_vulneravel',
#                                                    'faixa_vulneravel',
#                                                    'vulnerabilidade_social',
#                                                    'mes_sintomas',
#                                                    'periodo_chuvoso',
#                                                    'expectativa_vida',
#                                                    'fecundidade_total',
#                                                    'pro...
#                                                    'cli_vomito', 'cli_diarre',
#                                                    'cli_icteri', 'cli_renal',
#                                                    'cli_respir', 'cli_cardia',
#                                                    'cli_hemopu', 'cli_hemorr', ...])])),
#                 ('smote', SMOTE(random_state=42)),
#                 ('model',
#                  LGBMClassifier(colsample_bytree=0.9961178975410104,
#                                 device='cpu', force_col_wise=True,
#                                 is_unbalance=True,
#                                 learning_rate=0.165025969898394, max_depth=5,
#                                 n_estimators=27, random_state=42,
#                                 subsample=0.7878582513758825))])

# %%
modelo.named_steps["preprocessor"].get_feature_names_out()
# Out:
# array(['num__id_municipio', 'num__nu_idade_n', 'num__baixa_escolaridade',
#        'num__raca_vulneravel', 'num__faixa_vulneravel',
#        'num__vulnerabilidade_social', 'num__mes_sintomas',
#        'num__periodo_chuvoso', 'num__expectativa_vida',
#        'num__fecundidade_total', 'num__prob_sobrevivencia_40',
#        'num__prob_sobrevivencia_60', 'num__taxa_freq_bruta_basico',
#        'num__taxa_freq_bruta_fundamental', 'num__taxa_freq_bruta_medio',
#        'num__taxa_freq_liquida_superior', 'num__prop_pobreza_extrema',
#        'num__prop_vulner_pobreza', 'num__taxa_agua_encanada',
#        'num__taxa_banheiro_agua_encanada', 'num__taxa_coleta_lixo',
#        'num__taxa_energia_eletrica', 'num__taxa_agua_esgoto_inadequados',
#        'num__taxa_paredes_inadequados', 'num__populacao',
#        'num__indice_escolaridade', 'num__indice_frequencia_escolar',
#        'num__idhm', 'num__idhm_e', 'num__idhm_l', 'num__idhm_r',
#        'cat__cs_sexo_Feminino', 'cat__cs_sexo_Masculino',
#        'cat__cs_gestant_1º Trimestre', 'cat__cs_gestant_2º Trimestre',
#        'cat__cs_gestant_3º Trimestre',
#        'cat__cs_gestant_Idade gestacional ignorada',
#        'cat__cs_gestant_Não', 'cat__cs_gestant_Não informado',
#        'cat__cs_gestant_Não se aplica', 'cat__cs_raca_Amarela',
#        'cat__cs_raca_Branca', 'cat__cs_raca_Indígena',
#        'cat__cs_raca_Não informado', 'cat__cs_raca_Parda',
#        'cat__cs_raca_Preta', 'cat__cs_escol_n_10',
#        'cat__cs_escol_n_1ª a 4ª série incompleta do EF',
#        'cat__cs_escol_n_4ª série completa do EF',
#        'cat__cs_escol_n_5ª a 8ª série incompleta do EF',
#        'cat__cs_escol_n_Ensino fundamental completo',
#        'cat__cs_escol_n_Ensino médio completo',
#        'cat__cs_escol_n_Ensino médio incompleto',
#        'cat__cs_escol_n_Não informado',
#        'cat__cs_escol_n_Sem escolaridade',
#        'cat__cs_escol_n_Superior completo',
#        'cat__cs_escol_n_Superior incompleto', 'cat__sg_uf_AC',
#        'cat__sg_uf_AL', 'cat__sg_uf_AM', 'cat__sg_uf_AP', 'cat__sg_uf_BA',
#        'cat__sg_uf_CE', 'cat__sg_uf_DF', 'cat__sg_uf_ES', 'cat__sg_uf_GO',
#        'cat__sg_uf_MA', 'cat__sg_uf_MG', 'cat__sg_uf_MS', 'cat__sg_uf_MT',
#        'cat__sg_uf_Não informado', 'cat__sg_uf_PA', 'cat__sg_uf_PB',
#        'cat__sg_uf_PE', 'cat__sg_uf_PI', 'cat__sg_uf_PR', 'cat__sg_uf_RJ',
#        'cat__sg_uf_RN', 'cat__sg_uf_RO', 'cat__sg_uf_RR', 'cat__sg_uf_RS',
#        'cat__sg_uf_SC', 'cat__sg_uf_SE', 'cat__sg_uf_SP', 'cat__sg_uf_TO',
#        'cat__id_ocupa_n_Acabador de superfícies de concreto',
#        'cat__id_ocupa_n_Agente de higiene e segurança',
#        'cat__id_ocupa_n_Agente de polícia federal',
#        'cat__id_ocupa_n_Analista de crédito (instituições financeiras)',
#        'cat__id_ocupa_n_Analista de recursos humanos',
#        'cat__id_ocupa_n_Analista de sistemas de automação',
#        'cat__id_ocupa_n_Analista de suporte técnico',
#        'cat__id_ocupa_n_Apontador de cartões de ponto',
#        'cat__id_ocupa_n_Armador de estrutura de concreto',
#        'cat__id_ocupa_n_Artesão com material reciclável',
#        'cat__id_ocupa_n_Assistente Jurídico',
#        'cat__id_ocupa_n_Assistente social',
#        'cat__id_ocupa_n_Assistente técnico - no serviço público',
#        'cat__id_ocupa_n_Atendente de agência',
#        'cat__id_ocupa_n_Atendente de farmácia - balconista',
#        'cat__id_ocupa_n_Atendente em agência de correios',
#        'cat__id_ocupa_n_Auxiliar de judiciário',
#        'cat__id_ocupa_n_Auxiliar de lavanderia',
#        'cat__id_ocupa_n_Auxiliar de manutenção predial',
#        'cat__id_ocupa_n_Auxiliar de produção de fumo',
#        'cat__id_ocupa_n_Auxiliar de produção farmacêutica',
#        'cat__id_ocupa_n_Auxiliar de prótese dentária',
#        'cat__id_ocupa_n_Auxiliar de serviços gerais - na confecção de roupas',
#        'cat__id_ocupa_n_Auxiliar de veterinário',
#        'cat__id_ocupa_n_Auxiliar em hemotransfusão',
#        'cat__id_ocupa_n_Auxiliar em saúde bucal',
#        'cat__id_ocupa_n_Auxiliar técnico em laboratório de farmácia',
#        'cat__id_ocupa_n_Auxiliar técnico em patologia cínica',
#        'cat__id_ocupa_n_Barbeiro',
#        'cat__id_ocupa_n_Bombeiro de aeroporto',
#        'cat__id_ocupa_n_Bombeiro de posto de gasolina',
#        'cat__id_ocupa_n_Bombeiro de segurança do trabalho',
#        'cat__id_ocupa_n_Cabeleireiro unissex',
#        'cat__id_ocupa_n_Cabo bombeiro militar',
#        'cat__id_ocupa_n_Cabo da polícia militar',
#        'cat__id_ocupa_n_Caixa de banco',
#        'cat__id_ocupa_n_Caldeireiro (chapas de cobre)',
#        'cat__id_ocupa_n_Camareiro de hotel',
#        'cat__id_ocupa_n_Capitão porteiro',
#        'cat__id_ocupa_n_Carregador (armazém)',
#        'cat__id_ocupa_n_Carreteiro (caminhoneiro de caminhão-carreta)',
#        'cat__id_ocupa_n_Chapa de caminhão',
#        'cat__id_ocupa_n_Churrasqueiro',
#        'cat__id_ocupa_n_Conferente de exportação',
#        'cat__id_ocupa_n_Conferente portuário',
#        'cat__id_ocupa_n_Controlador de mão-de-obra',
#        'cat__id_ocupa_n_Copeiro de hospital',
#        'cat__id_ocupa_n_Corretor de imóveis',
#        'cat__id_ocupa_n_Costureiro na confecção em série',
#        'cat__id_ocupa_n_Costureiro; a máquina na confecção em série',
#        'cat__id_ocupa_n_Cozinhador de carnes',
#        'cat__id_ocupa_n_Cozinheiro industrial',
#        'cat__id_ocupa_n_Cuidador em saúde', 'cat__id_ocupa_n_Dançarino',
#        'cat__id_ocupa_n_Dançarinos populares',
#        'cat__id_ocupa_n_Defensor público federal',
#        'cat__id_ocupa_n_Desenhista técnico (artes gráficas)',
#        'cat__id_ocupa_n_Designer de interiores',
#        'cat__id_ocupa_n_Diretor de mídia (publicidade)',
#        'cat__id_ocupa_n_Dramaturgista',
#        'cat__id_ocupa_n_Eletricista de manutenção de linhas telefônicas',
#        'cat__id_ocupa_n_Eletromecânico de manutenção de elevadores',
#        'cat__id_ocupa_n_Empregado doméstico arrumador',
#        'cat__id_ocupa_n_Empregado doméstico diarista',
#        'cat__id_ocupa_n_Empregado doméstico nos serviços gerais',
#        'cat__id_ocupa_n_Encarregado de corte na confecção do vestuário',
#        'cat__id_ocupa_n_Encarregado de seção de controle de produção',
#        'cat__id_ocupa_n_Enfardador de sucata (cooperativa)',
#        'cat__id_ocupa_n_Enfermeiro',
#        'cat__id_ocupa_n_Engenheiro horticultor',
#        'cat__id_ocupa_n_Engenheiro metalurgista',
#        'cat__id_ocupa_n_Engenheiro projetista',
#        'cat__id_ocupa_n_Entregador de gás (ajudante de caminhão)',
#        'cat__id_ocupa_n_Escriturário',
#        'cat__id_ocupa_n_Escriturário de banco',
#        'cat__id_ocupa_n_Estampador de tecido',
#        'cat__id_ocupa_n_Esteireiro', 'cat__id_ocupa_n_Estoquista',
#        'cat__id_ocupa_n_Farmacêutico magistral',
#        'cat__id_ocupa_n_Faxineiro no serviço doméstico',
#        'cat__id_ocupa_n_Feirante', 'cat__id_ocupa_n_Fiscal de caixa',
#        'cat__id_ocupa_n_Fiscal rodoviário',
#        'cat__id_ocupa_n_Fisioterapeuta geral',
#        'cat__id_ocupa_n_Fotógrafo industrial',
#        'cat__id_ocupa_n_Gerente nacional de compras',
#        'cat__id_ocupa_n_Gerente regional de vendas',
#        'cat__id_ocupa_n_Gerente técnico comercial',
#        'cat__id_ocupa_n_Gero-sitter',
#        'cat__id_ocupa_n_Gestor público (administrador)',
#        'cat__id_ocupa_n_Guarda-civil municipal',
#        'cat__id_ocupa_n_Guia de turismo especializado em turismo regional',
#        'cat__id_ocupa_n_Inspetor de saneamento',
#        'cat__id_ocupa_n_Inspetor técnico de qualidade',
#        'cat__id_ocupa_n_Instalador de antenas de televisão',
#        'cat__id_ocupa_n_Instalador de tubulações',
#        'cat__id_ocupa_n_Instalador hidráulico',
#        'cat__id_ocupa_n_Instalador reparador de equipamento de força',
#        'cat__id_ocupa_n_Instrutor de auto-escola',
#        'cat__id_ocupa_n_Instrutor de equitação para equoterapia',
#        'cat__id_ocupa_n_Laboratorista de solos',
#        'cat__id_ocupa_n_Lavador de peças',
#        'cat__id_ocupa_n_Limpador de frutas e legumes para conserva',
#        'cat__id_ocupa_n_Lixeiro', 'cat__id_ocupa_n_Manicuro',
#        'cat__id_ocupa_n_Marcador de chapas',
#        'cat__id_ocupa_n_Marcador de produtos (siderúrgico e metalúrgico)',
#        'cat__id_ocupa_n_Marinheiro de convés (marítimo e fluviário)',
#        'cat__id_ocupa_n_Marinheiro de máquinas',
#        'cat__id_ocupa_n_Matrizeiro', 'cat__id_ocupa_n_Mecânico ajustador',
#        'cat__id_ocupa_n_Mecânico de manutenção de instalações mecânicas de edifícios',
#        'cat__id_ocupa_n_Mecânico de motores agrícolas',
#        'cat__id_ocupa_n_Mecânico diesel (exceto de veículos automotores)',
#        'cat__id_ocupa_n_Mecânico eletricista de diesel (veículos automotores)',
#        'cat__id_ocupa_n_Mecânico eletricista de veículos automotores',
#        'cat__id_ocupa_n_Mensageiro (correios e telégrafos)',
#        'cat__id_ocupa_n_Merendeiro',
#        'cat__id_ocupa_n_Metrologista auxiliar',
#        'cat__id_ocupa_n_Miniaturista (artesão de vidros)',
#        'cat__id_ocupa_n_Modelista',
#        'cat__id_ocupa_n_Modelista de madeira',
#        'cat__id_ocupa_n_Monitor de transporte escolar',
#        'cat__id_ocupa_n_Monitorador de sistemas e suporte ao usuário',
#        'cat__id_ocupa_n_Montador de andaimes (edificações)',
#        'cat__id_ocupa_n_Montador de embalagens',
#        'cat__id_ocupa_n_Montador de equipamentos elétricos',
#        'cat__id_ocupa_n_Montador de equipamentos elétricos (elevadores e equipamentos similares)   Ocupação',
#        'cat__id_ocupa_n_Montador de estruturas metálicas',
#        'cat__id_ocupa_n_Montador de máquinas-ferramentas (usinagem de metais)',
#        'cat__id_ocupa_n_Montador de paletes',
#        'cat__id_ocupa_n_Montador de pneus',
#        'cat__id_ocupa_n_Montador mecânico (máquinas industriais)',
#        'cat__id_ocupa_n_Motofretista',
#        'cat__id_ocupa_n_Motorista de ônibus rodoviário',
#        'cat__id_ocupa_n_Motorista de ônibus urbano',
#        'cat__id_ocupa_n_Motorista manipulador',
#        'cat__id_ocupa_n_Motorista operacional de guincho',
#        'cat__id_ocupa_n_Motorista operador de caminhão-betoneira',
#        'cat__id_ocupa_n_Motorista segurança',
#        'cat__id_ocupa_n_Nao informado',
#        'cat__id_ocupa_n_Negociante (comércio atacadista )',
#        'cat__id_ocupa_n_Niquelador', 'cat__id_ocupa_n_Odontólogo',
#        'cat__id_ocupa_n_Oficial carpinteiro',
#        'cat__id_ocupa_n_Operador de carregadeira',
#        'cat__id_ocupa_n_Operador de desbobinadeiras de tiras a quente e a frio',
#        'cat__id_ocupa_n_Operador de escória e sucata',
#        'cat__id_ocupa_n_Operador de fulão',
#        'cat__id_ocupa_n_Operador de manobras (auxiliar de ferrovias)',
#        'cat__id_ocupa_n_Operador de microcomputador',
#        'cat__id_ocupa_n_Operador de máquina cortadora (minas e pedreiras)',
#        'cat__id_ocupa_n_Operador de máquina de escarnar',
#        'cat__id_ocupa_n_Operador de máquina de fabricação de produtos de higiene e limpeza (sabão; sabonete; detergente;   Ocupação',
#        'cat__id_ocupa_n_Operador de máquina de moldar lingoteira',
#        'cat__id_ocupa_n_Operador de máquina empilhadeira',
#        'cat__id_ocupa_n_Operador de máquina pneumática',
#        'cat__id_ocupa_n_Operador de máquinas fixas; em geral',
#        'cat__id_ocupa_n_Operador de ponte rolante',
#        'cat__id_ocupa_n_Operador de processo de produção',
#        'cat__id_ocupa_n_Operador de produção (química; petroquímica e afins)',
#        'cat__id_ocupa_n_Operador de retro-escavadeira',
#        'cat__id_ocupa_n_Operador de seccionadeira na usinagem de madeira',
#        'cat__id_ocupa_n_Operador de telemarketing receptivo',
#        'cat__id_ocupa_n_Operador de tráfego',
#        'cat__id_ocupa_n_Operador mecânico (cigarros)',
#        'cat__id_ocupa_n_Ornamentador de eventos',
#        'cat__id_ocupa_n_Orquestrador',
#        'cat__id_ocupa_n_Padeiro confeiteiro',
#        'cat__id_ocupa_n_Pajém (baby-sitter em início de carreira)',
#        'cat__id_ocupa_n_Panificador',
#        'cat__id_ocupa_n_Passadeira de peças confeccionadas',
#        'cat__id_ocupa_n_Passador de guarnição',
#        'cat__id_ocupa_n_Pedagogo',
#        'cat__id_ocupa_n_Pedreiro de edificações',
#        'cat__id_ocupa_n_Pedreiro de reforma geral',
#        'cat__id_ocupa_n_Pescador profissional',
#        'cat__id_ocupa_n_Pesquisador de informações de rede',
#        'cat__id_ocupa_n_Pintor (artes visuais)',
#        'cat__id_ocupa_n_Pintor a pincel e rolo (exceto obras e estruturas metálicas)',
#        'cat__id_ocupa_n_Pintor de paredes',
#        'cat__id_ocupa_n_Pintor de veículos (reparação)',
#        'cat__id_ocupa_n_Pintor industrial', 'cat__id_ocupa_n_Pirangueiro',
#        'cat__id_ocupa_n_Piscineiro', 'cat__id_ocupa_n_Planejador urbano',
#        'cat__id_ocupa_n_Policial rodoviário federal',
#        'cat__id_ocupa_n_Polidor de rodas dentadas a máquina',
#        'cat__id_ocupa_n_Polidor de veículos',
#        'cat__id_ocupa_n_Porteiro de locais de diversão',
#        'cat__id_ocupa_n_Porteiro industrial', 'cat__id_ocupa_n_Portuário',
#        'cat__id_ocupa_n_Preparador de ingredientes (conservação de alimentos)',
#        'cat__id_ocupa_n_Primeiro oficial de manutenção eletromecânica (utilidades)',
#        'cat__id_ocupa_n_Produtor cultural',
#        'cat__id_ocupa_n_Produtor de fumo',
#        'cat__id_ocupa_n_Produtor na olericultura de legumes',
#        'cat__id_ocupa_n_Professor de artes no ensino médio',
#        'cat__id_ocupa_n_Professor de disciplinas pedagógicas no ensino médio',
#        'cat__id_ocupa_n_Professor de educação artística do ensino fundamental',
#        'cat__id_ocupa_n_Professor de educação física no ensino médio',
#        'cat__id_ocupa_n_Professor de educação física no ensino superior',
#        'cat__id_ocupa_n_Professor de geografia na educação de jovens e adultos do ensino fundamental de 5ª a 8ª série   Sinônimo',
#        'cat__id_ocupa_n_Professor de nível superior na educação infantil (quatro a seis anos)',
#        'cat__id_ocupa_n_Professor de português',
#        'cat__id_ocupa_n_Professor de pré-escola',
#        'cat__id_ocupa_n_Professor de suplência do ensino fundamental (primeira a quarta série)',
#        'cat__id_ocupa_n_Professor de teoria da administração',
#        'cat__id_ocupa_n_Professor i - ensino fundamental',
#        'cat__id_ocupa_n_Professor universitário na área de prática de ensino',
#        'cat__id_ocupa_n_Profissional de atletismo',
#        'cat__id_ocupa_n_Projetista (arquiteto)',
#        'cat__id_ocupa_n_Projetista de moldes',
#        'cat__id_ocupa_n_Promotor de justiça',
#        'cat__id_ocupa_n_Promotor de vendas',
#        'cat__id_ocupa_n_Proprietário - na criação de gado bovino - empregador',
#        'cat__id_ocupa_n_Prototipista (marceneiro)',
#        'cat__id_ocupa_n_Protético dentário',
#        'cat__id_ocupa_n_Quarteador em matadouro',
#        'cat__id_ocupa_n_Ralador de mandioca',
#        'cat__id_ocupa_n_Rancheiro - na cultura',
#        'cat__id_ocupa_n_Rebordadeira',
#        'cat__id_ocupa_n_Recepcionista; em geral',
#        'cat__id_ocupa_n_Recreador',
#        'cat__id_ocupa_n_Reformadora de roupas',
#        'cat__id_ocupa_n_Regente interno',
#        'cat__id_ocupa_n_Reparador de bicicletas',
#        'cat__id_ocupa_n_Reparador de máquinas',
#        'cat__id_ocupa_n_Repositor de mercadorias',
#        'cat__id_ocupa_n_Representante comercial autônomo',
#        'cat__id_ocupa_n_Retificador de motores de veículos',
#        'cat__id_ocupa_n_Revisor contábil',
#        'cat__id_ocupa_n_Revisor de aparelhos eletrônicos',
#        'cat__id_ocupa_n_Revisor de texto',
#        'cat__id_ocupa_n_Rizipiscicultor',
#        'cat__id_ocupa_n_Rondante de guarda portuária',
#        'cat__id_ocupa_n_Salgadeiro',
#        'cat__id_ocupa_n_Salsicheiros na conservação de alimentos',
#        'cat__id_ocupa_n_Sapateiro montador',
#        'cat__id_ocupa_n_Sargento da policia militar',
#        'cat__id_ocupa_n_Secretário estadual e distrital (serviço público estadual e distrital)',
#        'cat__id_ocupa_n_Secretário municipal (serviço público municipal)',
#        'cat__id_ocupa_n_Secretário senior bilíngüe',
#        'cat__id_ocupa_n_Segurança pessoal',
#        'cat__id_ocupa_n_Serrador (usinagem da madeira)',
#        'cat__id_ocupa_n_Serrador de lenha',
#        'cat__id_ocupa_n_Serrador de toras',
#        'cat__id_ocupa_n_Serralheiro preparador',
#        'cat__id_ocupa_n_Servente de lanche',
#        'cat__id_ocupa_n_Servente de pedreiro', 'cat__id_ocupa_n_Sileiro',
#        'cat__id_ocupa_n_Soldado bombeiro militar',
#        'cat__id_ocupa_n_Soldado da polícia militar',
#        'cat__id_ocupa_n_Soldador de veículos',
#        'cat__id_ocupa_n_Soldador mecânico',
#        'cat__id_ocupa_n_Sondador de poços (exceto de petróleo e gás)',
#        'cat__id_ocupa_n_Subgerente de loja (operações comerciais)',
#        'cat__id_ocupa_n_Subgerente de oficina (assistência técnica)',
#        'cat__id_ocupa_n_Subgerente de restaurante',
#        'cat__id_ocupa_n_Subtenente da policia militar',
#        'cat__id_ocupa_n_Supervisor de bar',
#        'cat__id_ocupa_n_Supervisor de construções e manutenção',
#        'cat__id_ocupa_n_Supervisor de vigilantes',
#        'cat__id_ocupa_n_Síndico (edifícios)',
#        'cat__id_ocupa_n_Sócio-proprietário na agropecuária - conta própria',
#        'cat__id_ocupa_n_Sócio-proprietário polivalente na agricultura - empregador',
#        'cat__id_ocupa_n_Talabarteiro - empregador (selas)',
#        'cat__id_ocupa_n_Talhador em açougue',
#        'cat__id_ocupa_n_Talhador em matadouro',
#        'cat__id_ocupa_n_Tarrafeador na pesca de peixes e camarões',
#        'cat__id_ocupa_n_Taverneiro', 'cat__id_ocupa_n_Taxista',
#        'cat__id_ocupa_n_Tecelão (tear automático)',
#        'cat__id_ocupa_n_Tecelão de malhas (máquina circular)',
#        'cat__id_ocupa_n_Tecnólogo em gestão financeira',
#        'cat__id_ocupa_n_Tecnólogo em secretariado',
#        'cat__id_ocupa_n_Tecnólogo em segurança do trabalho',
#        'cat__id_ocupa_n_Teleoperador ativo (telemarketing)',
#        'cat__id_ocupa_n_Telheiro',
#        'cat__id_ocupa_n_Tenente-coronel do exército',
#        'cat__id_ocupa_n_Terapeuta',
#        'cat__id_ocupa_n_Terapeuta naturalista',
#        'cat__id_ocupa_n_Terceiro-sargento do exército',
#        'cat__id_ocupa_n_Teólogo',
#        'cat__id_ocupa_n_Tirador de leite - produtor',
#        'cat__id_ocupa_n_Toqueiro - seringueiro',
#        'cat__id_ocupa_n_Torneiro (lavra de pedra)',
#        'cat__id_ocupa_n_Torneiro mecânico',
#        'cat__id_ocupa_n_Tosador de animais domésticos',
#        'cat__id_ocupa_n_Trabalhador da avicultura de corte',
#        'cat__id_ocupa_n_Trabalhador da cultura de arroz',
#        'cat__id_ocupa_n_Trabalhador da cultura de café',
#        'cat__id_ocupa_n_Trabalhador da cultura de fumo',
#        'cat__id_ocupa_n_Trabalhador da exploração de açaí',
#        'cat__id_ocupa_n_Trabalhador da exploração de pupunha',
#        'cat__id_ocupa_n_Trabalhador da exploração de sucuruba',
#        'cat__id_ocupa_n_Trabalhador da suinocultura',
#        'cat__id_ocupa_n_Trabalhador de fabricação de bolas de couro',
#        'cat__id_ocupa_n_Trabalhador de preparação de pescados (limpeza)',
#        'cat__id_ocupa_n_Trabalhador de serviços de limpeza e conservação de áreas públicas',
#        'cat__id_ocupa_n_Trabalhador de tratamento do leite e fabricação de laticínios e afins',
#        'cat__id_ocupa_n_Trabalhador do acabamento de artefatos de tecidos e couros',
#        'cat__id_ocupa_n_Trabalhador do beneficiamento de fumo',
#        'cat__id_ocupa_n_Trabalhador do plantio e trato de árvores ornamentais',
#        'cat__id_ocupa_n_Trabalhador na lavra de ouro',
#        'cat__id_ocupa_n_Trabalhador na olericultura (legumes)',
#        'cat__id_ocupa_n_Trabalhador na operação de sistema de irrigação localizada (microaspersão e gotejamento)   Ocupação',
#        'cat__id_ocupa_n_Trabalhador na operação de sistemas de irrigação por superfície e drenagem',
#        'cat__id_ocupa_n_Trabalhador no cultivo de árvores frutíferas',
#        'cat__id_ocupa_n_Trabalhador polivalente da confecção de calçados',
#        'cat__id_ocupa_n_Trabalhador portuário de bloco',
#        'cat__id_ocupa_n_Trabalhador rural - na agropecuária - exclusive empregador',
#        'cat__id_ocupa_n_Tradutor simultâneo',
#        'cat__id_ocupa_n_Tratorista florestal',
#        'cat__id_ocupa_n_Tratorista operador de semeadeira',
#        'cat__id_ocupa_n_Traçador de caldeiraria',
#        'cat__id_ocupa_n_Treinador de animais (circense)',
#        'cat__id_ocupa_n_Triador de material reciclável',
#        'cat__id_ocupa_n_Trocador', 'cat__id_ocupa_n_Turismólogo',
#        'cat__id_ocupa_n_Técnico de controladoria',
#        'cat__id_ocupa_n_Técnico de laboratório industrial',
#        'cat__id_ocupa_n_Técnico de manutenção de sistemas e instrumentos',
#        'cat__id_ocupa_n_Técnico de manutenção industrial',
#        'cat__id_ocupa_n_Técnico de operação eletrotécnica',
#        'cat__id_ocupa_n_Técnico de operações e serviços bancários - leasing',
#        'cat__id_ocupa_n_Técnico de orientação profissional',
#        'cat__id_ocupa_n_Técnico de refrigeração (instalação)',
#        'cat__id_ocupa_n_Técnico de telefonia',
#        'cat__id_ocupa_n_Técnico de utilidade (produção e distribuição de vapor; gases; óleos; combustíveis; energia)   Ocupação',
#        'cat__id_ocupa_n_Técnico eletricista',
#        'cat__id_ocupa_n_Técnico em atendimento e vendas',
#        'cat__id_ocupa_n_Técnico em hemotransfusão',
#        'cat__id_ocupa_n_Técnico em instalação de equipamentos de áudio',
#        'cat__id_ocupa_n_Técnico em laboratório de farmácia',
#        'cat__id_ocupa_n_Técnico em manutenção de equipamentos de informática',
#        'cat__id_ocupa_n_Técnico em manutenção de máquinas',
#        'cat__id_ocupa_n_Técnico em ovinocaprinocultura',
#        'cat__id_ocupa_n_Técnico em programação de computador',
#        'cat__id_ocupa_n_Técnico em projeto de aúdio',
#        'cat__id_ocupa_n_Técnico em segurança industrial',
#        'cat__id_ocupa_n_Técnico em sondagem (obras de saneamento)',
#        'cat__id_ocupa_n_Técnico em tomografia',
#        'cat__id_ocupa_n_Técnico em vitivinicultura',
#        'cat__id_ocupa_n_Vacinador',
#        'cat__id_ocupa_n_Valeteiro - exclusive na agropecuária',
#        'cat__id_ocupa_n_Vaqueiro inseminador',
#        'cat__id_ocupa_n_Vaqueiro inseminador (bovinos corte)',
#        'cat__id_ocupa_n_Varredor de rua',
#        'cat__id_ocupa_n_Vendedor de cachorro quente',
#        'cat__id_ocupa_n_Vendedor em comércio atacadista',
#        'cat__id_ocupa_n_Vendedor interno',
#        'cat__id_ocupa_n_Vendedor porta a porta',
#        'cat__id_ocupa_n_Vendedor pracista', 'cat__id_ocupa_n_Vereador',
#        'cat__id_ocupa_n_Veterinário', 'cat__id_ocupa_n_Vice-prefeito',
#        'cat__id_ocupa_n_Vidraceiro colocador de vidros',
#        'cat__id_ocupa_n_Vidraceiro de quadros e molduras (comércio varejista)',
#        'cat__id_ocupa_n_Vigia noturno',
#        'cat__id_ocupa_n_Vigilante bancário',
#        'cat__id_ocupa_n_Virador em matadouro',
#        'cat__id_ocupa_n_Visitador de saúde em domicílio',
#        'cat__id_ocupa_n_Vistoriador de risco de auto',
#        'cat__id_ocupa_n_Vistoriador naval',
#        'cat__id_ocupa_n_Volante na agricultura',
#        'cat__id_ocupa_n_Zelador de edifício',
#        'cat__id_ocupa_n_Zootecnista', 'cat__ant_cb_lam_Não',
#        'cat__ant_cb_lam_Não informado', 'cat__ant_cb_lam_Sim',
#        'cat__ant_cb_cri_Não', 'cat__ant_cb_cri_Não informado',
#        'cat__ant_cb_cri_Sim', 'cat__ant_cb_sin_Não',
#        'cat__ant_cb_sin_Não informado', 'cat__ant_cb_sin_Sim',
#        'cat__ant_cb_cor_Não', 'cat__ant_cb_cor_Não informado',
#        'cat__ant_cb_cor_Sim', 'cat__ant_cb_roe_Não',
#        'cat__ant_cb_roe_Não informado', 'cat__ant_cb_roe_Sim',
#        'cat__ant_cb_ter_Não', 'cat__ant_cb_ter_Não informado',
#        'cat__ant_cb_ter_Sim', 'cat__ant_cb_lix_Não',
#        'cat__ant_cb_lix_Não informado', 'cat__ant_cb_lix_Sim',
#        'cat__ant_cb_out_Não', 'cat__ant_cb_out_Não informado',
#        'cat__ant_cb_out_Sim', 'cat__ant_humano_Não',
#        'cat__ant_humano_Não informado', 'cat__ant_humano_Sim',
#        'cat__ant_animai_Não', 'cat__ant_animai_Não informado',
#        'cat__ant_animai_Sim', 'cat__cli_febre_Não',
#        'cat__cli_febre_Não informado', 'cat__cli_febre_Sim',
#        'cat__cli_mialgi_Não', 'cat__cli_mialgi_Não informado',
#        'cat__cli_mialgi_Sim', 'cat__cli_cefale_Não',
#        'cat__cli_cefale_Não informado', 'cat__cli_cefale_Sim',
#        'cat__cli_prost_Não', 'cat__cli_prost_Não informado',
#        'cat__cli_prost_Sim', 'cat__cli_conges_Não',
#        'cat__cli_conges_Não informado', 'cat__cli_conges_Sim',
#        'cat__cli_pantur_Não', 'cat__cli_pantur_Não informado',
#        'cat__cli_pantur_Sim', 'cat__cli_vomito_Não',
#        'cat__cli_vomito_Não informado', 'cat__cli_vomito_Sim',
#        'cat__cli_diarre_Não', 'cat__cli_diarre_Não informado',
#        'cat__cli_diarre_Sim', 'cat__cli_icteri_Não',
#        'cat__cli_icteri_Não informado', 'cat__cli_icteri_Sim',
#        'cat__cli_renal_Não', 'cat__cli_renal_Não informado',
#        'cat__cli_renal_Sim', 'cat__cli_respir_Não',
#        'cat__cli_respir_Não informado', 'cat__cli_respir_Sim',
#        'cat__cli_cardia_Não', 'cat__cli_cardia_Não informado',
#        'cat__cli_cardia_Sim', 'cat__cli_hemopu_Não',
#        'cat__cli_hemopu_Não informado', 'cat__cli_hemopu_Sim',
#        'cat__cli_hemorr_Não', 'cat__cli_hemorr_Não informado',
#        'cat__cli_hemorr_Sim', 'cat__cli_mening_Não',
#        'cat__cli_mening_Não informado', 'cat__cli_mening_Sim',
#        'cat__cli_outros_Não', 'cat__cli_outros_Não informado',
#        'cat__cli_outros_Sim', 'cat__con_area_Não informado',
#        'cat__con_area_Periurbana', 'cat__con_area_Rural',
#        'cat__con_area_Urbana', 'cat__con_ambien_Domicílio',
#        'cat__con_ambien_Lazer', 'cat__con_ambien_Não informado',
#        'cat__con_ambien_Outro', 'cat__con_ambien_Trabalho',
#        'cat__nivel_vulnerabilidade_Alta',
#        'cat__nivel_vulnerabilidade_Baixa',
#        'cat__nivel_vulnerabilidade_Moderada', 'cat__estacao_Inverno',
#        'cat__estacao_Outono', 'cat__estacao_Primavera',
#        'cat__estacao_Verão'], dtype=object)

# %%
modelo.predict(X_data.iloc[-10:])
# Out:
# array([0, 1, 1, 1, 1, 1, 1, 1, 0, 1])

# %% [markdown]
# ## Avaliando modelo

# %%
# 2. Basic overview
print("=== Shape of DataFrame ===")
print(df_metrics.shape)

display(df_metrics)
# Out:
# === Shape of DataFrame ===
# (30, 13)
#     number     value  params_C  params_colsample_bytree  params_learning_rate  \
# 0        0  0.910430  2.104708                      NaN                   NaN
# 1        1  0.915623       NaN                 0.801331              0.142385
# 2        2  0.910519  1.965976                      NaN                   NaN
# 3        3  0.905941       NaN                 0.927572              0.034690
# 4        4  0.910394  2.160309                      NaN                   NaN
# 5        5  0.896426       NaN                      NaN                   NaN
# 6        6  0.924238       NaN                 0.831182              0.109377
# 7        7  0.904468       NaN                 0.833155              0.109921
# 8        8  0.860768       NaN                 0.629464              0.032521
# 9        9  0.920459       NaN                 0.717804              0.124305
# 10      10  0.917707       NaN                 0.829687              0.084599
# 11      11  0.923848       NaN                 0.553265              0.237883
# 12      12  0.922217       NaN                 0.648184              0.253495
# 13      13  0.923324       NaN                 0.508528              0.253088
# 14      14  0.925270       NaN                 0.507389              0.236535
# 15      15  0.927059       NaN                 0.994059              0.203035
# 16      16  0.913684       NaN                      NaN                   NaN
# 17      17  0.922788       NaN                 0.966211              0.176658
# 18      18  0.926504       NaN                 0.968956              0.198505
# 19      19  0.926190       NaN                 0.998515              0.197025
# 20      20  0.924082       NaN                      NaN                   NaN
# 21      21  0.914008       NaN                      NaN                   NaN
# 22      22  0.925665       NaN                 0.999760              0.190443
# 23      23  0.926035       NaN                 0.999301              0.190448
# 24      24  0.923374       NaN                 0.907656              0.295814
# 25      25  0.923810       NaN                 0.908211              0.298655
# 26      26  0.926310       NaN                 0.905371              0.212470
# 27      27  0.927361       NaN                 0.948241              0.221486
# 28      28  0.926571       NaN                 0.880983              0.208250
# 29      29  0.914230  0.317648                      NaN                   NaN
#
#     params_max_depth  params_min_samples_leaf  params_min_samples_split  \
# 0                NaN                      NaN                       NaN
# 1                3.0                      NaN                       NaN
# 2                NaN                      NaN                       NaN
# 3                7.0                      NaN                       NaN
# 4                NaN                      NaN                       NaN
# 5                3.0                      5.0                       9.0
# 6                6.0                      NaN                       NaN
# 7                7.0                      NaN                       NaN
# 8                4.0                      NaN                       NaN
# 9                3.0                      NaN                       NaN
# 10               6.0                      NaN                       NaN
# 11               9.0                      NaN                       NaN
# 12               9.0                      NaN                       NaN
# 13               9.0                      NaN                       NaN
# 14               9.0                      NaN                       NaN
# 15               6.0                      NaN                       NaN
# 16               5.0                      1.0                       2.0
# 17               7.0                      NaN                       NaN
# 18               8.0                      NaN                       NaN
# 19               8.0                      NaN                       NaN
# 20               8.0                      3.0                       4.0
# 21               5.0                      3.0                       4.0
# 22               8.0                      NaN                       NaN
# 23               8.0                      NaN                       NaN
# 24               8.0                      NaN                       NaN
# 25               7.0                      NaN                       NaN
# 26               7.0                      NaN                       NaN
# 27               5.0                      NaN                       NaN
# 28               5.0                      NaN                       NaN
# 29               NaN                      NaN                       NaN
#
#    params_model_name  params_n_estimators  params_subsample     state  \
# 0                svm                  NaN               NaN  COMPLETE
# 1           lightgbm                 10.0          0.838905  COMPLETE
# 2                svm                  NaN               NaN  COMPLETE
# 3            xgboost                 23.0          0.938057  COMPLETE
# 4                svm                  NaN               NaN  COMPLETE
# 5      random_forest                 15.0               NaN  COMPLETE
# 6           lightgbm                 19.0          0.958474  COMPLETE
# 7            xgboost                  5.0          0.972424    PRUNED
# 8            xgboost                 18.0          0.902481    PRUNED
# 9            xgboost                 27.0          0.833607  COMPLETE
# 10          lightgbm                  7.0          0.935916  COMPLETE
# 11          lightgbm                 29.0          0.613893  COMPLETE
# 12          lightgbm                 29.0          0.683409  COMPLETE
# 13          lightgbm                 29.0          0.596637  COMPLETE
# 14          lightgbm                 22.0          0.501016  COMPLETE
# 15          lightgbm                 22.0          0.511295  COMPLETE
# 16     random_forest                 20.0               NaN    PRUNED
# 17          lightgbm                 14.0          0.545539  COMPLETE
# 18          lightgbm                 24.0          0.505676  COMPLETE
# 19          lightgbm                 24.0          0.504345  COMPLETE
# 20     random_forest                 25.0               NaN    PRUNED
# 21     random_forest                 25.0               NaN    PRUNED
# 22          lightgbm                 24.0          0.524825  COMPLETE
# 23          lightgbm                 23.0          0.501554  COMPLETE
# 24          lightgbm                 21.0          0.594614  COMPLETE
# 25          lightgbm                 21.0          0.595748  COMPLETE
# 26          lightgbm                 16.0          0.683398  COMPLETE
# 27          lightgbm                 26.0          0.675340  COMPLETE
# 28          lightgbm                 15.0          0.698739  COMPLETE
# 29               svm                  NaN               NaN    PRUNED
#
#                   duration
# 0   0 days 00:00:10.808315
# 1   0 days 00:00:02.786003
# 2   0 days 00:00:10.969289
# 3   0 days 00:00:08.875986
# 4   0 days 00:00:10.123704
# 5   0 days 00:00:01.998935
# 6   0 days 00:00:03.001261
# 7   0 days 00:00:01.019491
# 8   0 days 00:00:01.698765
# 9   0 days 00:00:04.426358
# 10  0 days 00:00:02.749617
# 11  0 days 00:00:03.305684
# 12  0 days 00:00:03.330227
# 13  0 days 00:00:03.229935
# 14  0 days 00:00:03.116537
# 15  0 days 00:00:03.839646
# 16  0 days 00:00:00.752225
# 17  0 days 00:00:03.167419
# 18  0 days 00:00:04.362157
# 19  0 days 00:00:03.976481
# 20  0 days 00:00:02.366755
# 21  0 days 00:00:00.811191
# 22  0 days 00:00:03.494273
# 23  0 days 00:00:03.490444
# 24  0 days 00:00:03.214006
# 25  0 days 00:00:03.914308
# 26  0 days 00:00:04.125537
# 27  0 days 00:00:03.455484
# 28  0 days 00:00:02.488984
# 29  0 days 00:00:01.804149

# %%
df_metrics
# Out:
#     number     value  params_C  params_colsample_bytree  params_learning_rate  \
# 0        0  0.910430  2.104708                      NaN                   NaN
# 1        1  0.915623       NaN                 0.801331              0.142385
# 2        2  0.910519  1.965976                      NaN                   NaN
# 3        3  0.905941       NaN                 0.927572              0.034690
# 4        4  0.910394  2.160309                      NaN                   NaN
# 5        5  0.896426       NaN                      NaN                   NaN
# 6        6  0.924238       NaN                 0.831182              0.109377
# 7        7  0.904468       NaN                 0.833155              0.109921
# 8        8  0.860768       NaN                 0.629464              0.032521
# 9        9  0.920459       NaN                 0.717804              0.124305
# 10      10  0.917707       NaN                 0.829687              0.084599
# 11      11  0.923848       NaN                 0.553265              0.237883
# 12      12  0.922217       NaN                 0.648184              0.253495
# 13      13  0.923324       NaN                 0.508528              0.253088
# 14      14  0.925270       NaN                 0.507389              0.236535
# 15      15  0.927059       NaN                 0.994059              0.203035
# 16      16  0.913684       NaN                      NaN                   NaN
# 17      17  0.922788       NaN                 0.966211              0.176658
# 18      18  0.926504       NaN                 0.968956              0.198505
# 19      19  0.926190       NaN                 0.998515              0.197025
# 20      20  0.924082       NaN                      NaN                   NaN
# 21      21  0.914008       NaN                      NaN                   NaN
# 22      22  0.925665       NaN                 0.999760              0.190443
# 23      23  0.926035       NaN                 0.999301              0.190448
# 24      24  0.923374       NaN                 0.907656              0.295814
# 25      25  0.923810       NaN                 0.908211              0.298655
# 26      26  0.926310       NaN                 0.905371              0.212470
# 27      27  0.927361       NaN                 0.948241              0.221486
# 28      28  0.926571       NaN                 0.880983              0.208250
# 29      29  0.914230  0.317648                      NaN                   NaN
#
#     params_max_depth  params_min_samples_leaf  params_min_samples_split  \
# 0                NaN                      NaN                       NaN
# 1                3.0                      NaN                       NaN
# 2                NaN                      NaN                       NaN
# 3                7.0                      NaN                       NaN
# 4                NaN                      NaN                       NaN
# 5                3.0                      5.0                       9.0
# 6                6.0                      NaN                       NaN
# 7                7.0                      NaN                       NaN
# 8                4.0                      NaN                       NaN
# 9                3.0                      NaN                       NaN
# 10               6.0                      NaN                       NaN
# 11               9.0                      NaN                       NaN
# 12               9.0                      NaN                       NaN
# 13               9.0                      NaN                       NaN
# 14               9.0                      NaN                       NaN
# 15               6.0                      NaN                       NaN
# 16               5.0                      1.0                       2.0
# 17               7.0                      NaN                       NaN
# 18               8.0                      NaN                       NaN
# 19               8.0                      NaN                       NaN
# 20               8.0                      3.0                       4.0
# 21               5.0                      3.0                       4.0
# 22               8.0                      NaN                       NaN
# 23               8.0                      NaN                       NaN
# 24               8.0                      NaN                       NaN
# 25               7.0                      NaN                       NaN
# 26               7.0                      NaN                       NaN
# 27               5.0                      NaN                       NaN
# 28               5.0                      NaN                       NaN
# 29               NaN                      NaN                       NaN
#
#    params_model_name  params_n_estimators  params_subsample     state  \
# 0                svm                  NaN               NaN  COMPLETE
# 1           lightgbm                 10.0          0.838905  COMPLETE
# 2                svm                  NaN               NaN  COMPLETE
# 3            xgboost                 23.0          0.938057  COMPLETE
# 4                svm                  NaN               NaN  COMPLETE
# 5      random_forest                 15.0               NaN  COMPLETE
# 6           lightgbm                 19.0          0.958474  COMPLETE
# 7            xgboost                  5.0          0.972424    PRUNED
# 8            xgboost                 18.0          0.902481    PRUNED
# 9            xgboost                 27.0          0.833607  COMPLETE
# 10          lightgbm                  7.0          0.935916  COMPLETE
# 11          lightgbm                 29.0          0.613893  COMPLETE
# 12          lightgbm                 29.0          0.683409  COMPLETE
# 13          lightgbm                 29.0          0.596637  COMPLETE
# 14          lightgbm                 22.0          0.501016  COMPLETE
# 15          lightgbm                 22.0          0.511295  COMPLETE
# 16     random_forest                 20.0               NaN    PRUNED
# 17          lightgbm                 14.0          0.545539  COMPLETE
# 18          lightgbm                 24.0          0.505676  COMPLETE
# 19          lightgbm                 24.0          0.504345  COMPLETE
# 20     random_forest                 25.0               NaN    PRUNED
# 21     random_forest                 25.0               NaN    PRUNED
# 22          lightgbm                 24.0          0.524825  COMPLETE
# 23          lightgbm                 23.0          0.501554  COMPLETE
# 24          lightgbm                 21.0          0.594614  COMPLETE
# 25          lightgbm                 21.0          0.595748  COMPLETE
# 26          lightgbm                 16.0          0.683398  COMPLETE
# 27          lightgbm                 26.0          0.675340  COMPLETE
# 28          lightgbm                 15.0          0.698739  COMPLETE
# 29               svm                  NaN               NaN    PRUNED
#
#                   duration
# 0   0 days 00:00:10.808315
# 1   0 days 00:00:02.786003
# 2   0 days 00:00:10.969289
# 3   0 days 00:00:08.875986
# 4   0 days 00:00:10.123704
# 5   0 days 00:00:01.998935
# 6   0 days 00:00:03.001261
# 7   0 days 00:00:01.019491
# 8   0 days 00:00:01.698765
# 9   0 days 00:00:04.426358
# 10  0 days 00:00:02.749617
# 11  0 days 00:00:03.305684
# 12  0 days 00:00:03.330227
# 13  0 days 00:00:03.229935
# 14  0 days 00:00:03.116537
# 15  0 days 00:00:03.839646
# 16  0 days 00:00:00.752225
# 17  0 days 00:00:03.167419
# 18  0 days 00:00:04.362157
# 19  0 days 00:00:03.976481
# 20  0 days 00:00:02.366755
# 21  0 days 00:00:00.811191
# 22  0 days 00:00:03.494273
# 23  0 days 00:00:03.490444
# 24  0 days 00:00:03.214006
# 25  0 days 00:00:03.914308
# 26  0 days 00:00:04.125537
# 27  0 days 00:00:03.455484
# 28  0 days 00:00:02.488984
# 29  0 days 00:00:01.804149

# %%
# Total de trials por modelo
total_trials = (df_metrics.groupby("params_model_name").size().reset_index(name="total_trials"))

plt.figure(figsize=(8, 6))
sns.barplot(data=total_trials,x="params_model_name",y="total_trials",)
plt.title("Total de tentativas por modelo")
plt.xlabel("Modelo")
plt.ylabel("Tentativas")
plt.tight_layout()
plt.show()

# %%
# Gráfico das tentativas de modelos completas e abortadas
counts_state = df_metrics.groupby(["params_model_name", "state"]).size().reset_index(name="count")

plt.figure(figsize=(8, 6))
sns.barplot(data=counts_state,x="params_model_name",y="count",hue="state",)
plt.title("Resultado das tentativas entre Pruned e Complete")
plt.xlabel("Modelo")
plt.ylabel("Número de tentativas")
plt.tight_layout()
plt.show()

# %%
# Distribuição de performance (value) por modelo
plt.figure(figsize=(8, 6))
sns.boxplot(data=df_metrics, x="params_model_name", y="value")
plt.title("Desempenho por modelo")
plt.xlabel("Modelo")
plt.ylabel("Área por baixo da curva ROC (AUC)")
plt.tight_layout()
plt.show()

# %%
# Duração média de treino por modelo
df_metrics["duration_sec"] = pd.to_timedelta(df_metrics["duration"]).dt.total_seconds()
mean_duration = df_metrics.groupby("params_model_name")["duration_sec"].mean().reset_index()

# Distribuição do tempo de processamento por modelo

plt.figure(figsize=(8, 6))
sns.boxplot(data=df_metrics, x="params_model_name", y="duration_sec")
plt.title("Média do tempo de treinamento por modelo")
plt.xlabel("Modelo")
plt.ylabel("Segundos")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Treinamento do modelo final

# %%
df_hyper =pd.DataFrame(df_results['hyperparameters'].to_list())
df_hyper
# Out:
#   model_name  n_estimators  learning_rate  max_depth  subsample  \
# 0   lightgbm            27       0.165026          5   0.787858
# 1   lightgbm            16       0.245605          6   0.851190
# 2    xgboost            22       0.145206          8   0.630703
# 3   lightgbm            14       0.228356          7   0.660814
# 4   lightgbm            26       0.221486          5   0.675340
#
#    colsample_bytree
# 0          0.996118
# 1          0.521619
# 2          0.503485
# 3          0.597794
# 4          0.948241

# %%
final_params=df_hyper.iloc[:,1:].median().to_dict()
final_params
# Out:
# {'n_estimators': 22.0,
#  'learning_rate': 0.221486454257907,
#  'max_depth': 6.0,
#  'subsample': 0.6753402059985969,
#  'colsample_bytree': 0.5977940029474059}

# %%
final_params = {'n_estimators': 26,
 'learning_rate': 0.226,
 'max_depth': 7,
 'subsample': 0.662,
 'colsample_bytree': 0.6968}

# %%
# Dicionário base para reconstrução
models = {
    'RandomForest': RandomForestClassifier(random_state=42),
    'XGBoost': xgb.XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42),
    'LightGBM': lgb.LGBMClassifier(random_state=42),
    'SVM': CalibratedClassifierCV(LinearSVC( random_state=42))
}

# %%
# Reconstruir modelo
final_model = models['LightGBM']
final_model.set_params(**final_params)

cat_cols, num_cols = get_feature_types(X_data)

final_pipeline = build_pipeline(final_model, cat_cols, num_cols)

# %% [markdown]
# ### Avaliando modelo final

# %%
# 1. FUNÇÃO PARA EXTRAIR NOMES DAS FEATURES PÓS-OHE
def get_feature_names(column_transformer):
    """
    Extrai nomes finais das features após ColumnTransformer,
    incluindo OneHotEncoder e transformações numéricas.
    """
    output_features = []

    for name, transformer, features in column_transformer.transformers_:

        # Caso 'remainder=passthrough'
        if name == "remainder":
            output_features.extend(features)
            continue

        # Transformers com get_feature_names_out() (OneHotEncoder, etc)
        if hasattr(transformer, "get_feature_names_out"):
            try:
                names = transformer.get_feature_names_out(features)
            except:
                names = transformer.get_feature_names_out()
            output_features.extend(names)

        # Caso não possua o método
        else:
            output_features.extend(features)

    return output_features

# 4. FUNÇÃO FUZZY PARA MATCH COM VARIÁVEIS ORIGINAIS
def fuzzy_match_original(feature_name, triage_features, threshold=70):
    """
    Realiza fuzzy matching buscando qual variável ORIGINAL
    está mais relacionada com o nome da feature pós-OHE.
    """
    best_match, score, _ = process.extractOne(
        feature_name,
        triage_features,
        scorer=fuzz.partial_ratio
    )
    return best_match if score >= threshold else None

# %%
n_splits = 4
outer_cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
results = []
fold = 1
for train_idx, test_idx in outer_cv.split(X_data, y_data):

    print(f"\n==============================")
    print(f"  Fold Externo {fold}/{n_splits}")
    print(f"==============================")

    X_train, X_test = X_data.iloc[train_idx], X_data.iloc[test_idx]
    y_train, y_test = y_data.iloc[train_idx], y_data.iloc[test_idx]

    # Treinando o pipeline final com todo o conjunto de dados
    final_pipeline.fit(X_train,y_train)


    # 1. Recuperar nomes das features após o ColumnTransformer
    preproc  = final_pipeline.named_steps['preprocessor']
    model    = final_pipeline.named_steps['model']
    top_k=20



    # num_features
    num_features = preproc.transformers_[0][2]

    # cat_features (expandidos pelo OneHot)
    cat_encoder      = preproc.named_transformers_['cat'].get_feature_names_out()

    cat_features_raw  = preproc.transformers_[1][2]
    cat_feature_names = preproc.named_transformers_["cat"].get_feature_names_out(cat_features_raw)

    feature_names = np.concatenate([num_features, cat_feature_names])

    # 2. Extrair importâncias
    if hasattr(model, "feature_importances_"):
        # RandomForest, XGBClassifier, LGBMClassifier
        importances = model.feature_importances_

    elif isinstance(model, SVC) and model.kernel == "linear":
        # |coef_| para SVM linear
        importances = np.abs(model.coef_).flatten()

    else:
        # Qualquer modelo sem atributo nativo → permutação
        perm = permutation_importance(
            final_pipeline, X_val, y_val,
            n_repeats=10, scoring="roc_auc",
            n_jobs=-1, random_state=42
        )
        importances = perm.importances_mean

    # 3. Organizar e selecionar as k variáveis mais relevantes
    imp_df = (pd.DataFrame({"feature": feature_names,
                            "importance": importances})
                .sort_values("importance", ascending=False)
                .head(top_k))

    #Plotando o gráfico
    plt.figure(figsize=(6, 4))
    plt.barh(imp_df["feature"][::-1],
            imp_df["importance"][::-1])
    plt.xlabel("Importância")
    plt.title(f"Top- {top_k} importâncias – {type(model).__name__}")
    plt.tight_layout()
    plt.show()



    # Gerar previsões finais
    y_pred = final_pipeline.predict(X_test)
    y_proba = final_pipeline.predict_proba(X_test)[:, 1] if hasattr(final_model, "predict_proba") else None

    # Matriz de confusão
    cm = confusion_matrix(y_test, y_pred)

    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.title("Matriz de Confusão - Dados Completos")
    plt.xlabel("Predito")
    plt.ylabel("Real")
    plt.show()

    # Barplot com métricas
    metrics_dict = {
        "Accuracy": accuracy_score(y_test, y_pred),
        "Precision": precision_score(y_test, y_pred),
        "Recall": recall_score(y_test, y_pred),
        "F1 Score": f1_score(y_test, y_pred),
        "AUC": roc_auc_score(y_test, y_proba) if y_proba is not None else np.nan
    }

    plt.figure(figsize=(8, 5))
    sns.barplot(x=list(metrics_dict.keys()), y=list(metrics_dict.values()), palette="Set2")
    plt.ylim(0, 1.05)
    plt.title("Métricas de Classificação - Dados Completos")
    for i, v in enumerate(metrics_dict.values()):
        plt.text(i, v + 0.02, f"{v:.2f}", ha='center')
    plt.grid(True)
    plt.show()

    # Curva ROC
    if y_proba is not None:
        fpr, tpr, _ = roc_curve(y_test, y_proba)
        roc_auc = auc(fpr, tpr)

        plt.figure(figsize=(6, 5))
        plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.2f}")
        plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
        plt.xlabel("Falso Positivo")
        plt.ylabel("Verdadeiro Positivo")
        plt.title("Curva ROC")
        plt.legend(loc='lower right')
        plt.grid(True)
        plt.show()

    # Curva Precision-Recall
    if y_proba is not None:
        precision, recall, _ = precision_recall_curve(y_test, y_proba)
        auprc_trap = auc(recall, precision)
        plt.figure(figsize=(6, 5))
        plt.plot(recall, precision, label=f"AUPRC = {auprc_trap:.2f}")
        plt.xlabel("Recall")
        plt.ylabel("Precision")
        plt.title("Curva Precision-Recall")
        plt.legend(loc='lower right')
        plt.grid(True)
        plt.show()

    ## Curva de calibração
    if y_proba is not None:

        # --- Calcular curva de calibração ---
        prob_true, prob_pred = calibration_curve(y_test, y_proba, n_bins=10, strategy='uniform')

        # --- Plotar ---
        plt.figure(figsize=(6,6))
        plt.plot(prob_pred, prob_true, marker='o', linewidth=2, label='Modelo calibrado')
        plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Calibração perfeita')
        plt.title("Curva de Calibração (Isotonic Regression)")
        plt.xlabel("Probabilidade prevista (modelo)")
        plt.ylabel("Frequência real observada")
        plt.legend()
        plt.grid(True, linestyle='--', alpha=0.6)
        plt.show()

    ## Análise de falso positio e falso negativo
    if y_proba is not None:
        # ---  Avaliar FP e FN para thresholds de 0.0 a 1.0 ---
        thresholds = np.linspace(0, 1, 101)
        fp_list, fn_list = [], []

        for t in thresholds:
            y_pred = (y_proba >= t).astype(int)
            tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
            fp_list.append(fp)
            fn_list.append(fn)

        # ---  Montar DataFrame ---
        df_threshold = pd.DataFrame({
            'threshold': thresholds,
            'false_positives': fp_list,
            'false_negatives': fn_list
        })

        # --- Plotar ---
        plt.figure(figsize=(8,5))
        plt.plot(df_threshold['threshold'], df_threshold['false_positives'], label='Falsos Positivos (FP)', color='tab:red')
        plt.plot(df_threshold['threshold'], df_threshold['false_negatives'], label='Falsos Negativos (FN)', color='tab:blue')
        plt.xlabel('Threshold (Probabilidade de Corte)')
        plt.ylabel('Quantidade de Casos')
        plt.title('Variação de FP e FN conforme o Threshold de Decisão')
        plt.legend()
        plt.grid(True, linestyle='--', alpha=0.6)
        plt.show()
# Out:
# ==============================
#   Fold Externo 1/4
# ==============================
# [LightGBM] [Info] Number of positive: 4717, number of negative: 4717
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.016650 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 31921
# [LightGBM] [Info] Number of data points in the train set: 9434, number of used features: 220
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# ==============================
#   Fold Externo 1/4
# ==============================
# [LightGBM] [Info] Number of positive: 4717, number of negative: 4717
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.016396 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 32121
# [LightGBM] [Info] Number of data points in the train set: 9434, number of used features: 216
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# ==============================
#   Fold Externo 1/4
# ==============================
# [LightGBM] [Info] Number of positive: 4718, number of negative: 4718
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.035735 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 31926
# [LightGBM] [Info] Number of data points in the train set: 9436, number of used features: 210
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# ==============================
#   Fold Externo 1/4
# ==============================
# [LightGBM] [Info] Number of positive: 4718, number of negative: 4718
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.016294 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 31978
# [LightGBM] [Info] Number of data points in the train set: 9436, number of used features: 213
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000

# %%
n_splits = 4
outer_cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

results = []
fold = 1

### ADICIONADO — lista para guardar métricas dos folds externos
metrics_all_folds = []

for train_idx, test_idx in outer_cv.split(X_data, y_data):

    print(f"\n==============================")
    print(f"  Fold Externo {fold}/{n_splits}")
    print(f"==============================")

    X_train, X_test = X_data.iloc[train_idx], X_data.iloc[test_idx]
    y_train, y_test = y_data.iloc[train_idx], y_data.iloc[test_idx]

    # Treinando o pipeline final com todo o conjunto de dados
    final_pipeline.fit(X_train,y_train)

    # 1. Recuperar nomes das features após o ColumnTransformer
    preproc  = final_pipeline.named_steps['preprocessor']
    model    = final_pipeline.named_steps['model']
    top_k=20

    num_features = preproc.transformers_[0][2]

    cat_encoder      = preproc.named_transformers_['cat'].get_feature_names_out()
    cat_features_raw  = preproc.transformers_[1][2]
    cat_feature_names = preproc.named_transformers_["cat"].get_feature_names_out(cat_features_raw)

    feature_names = np.concatenate([num_features, cat_feature_names])

    # 2. Extrair importâncias
    if hasattr(model, "feature_importances_"):
        importances = model.feature_importances_
    elif isinstance(model, SVC) and model.kernel == "linear":
        importances = np.abs(model.coef_).flatten()
    else:
        perm = permutation_importance(
            final_pipeline, X_val, y_val,
            n_repeats=10, scoring="roc_auc",
            n_jobs=-1, random_state=42
        )
        importances = perm.importances_mean

    # 3. Importâncias
    imp_df = (pd.DataFrame({"feature": feature_names,
                            "importance": importances})
                .sort_values("importance", ascending=False)
                .head(top_k))

    plt.figure(figsize=(6, 4))
    plt.barh(imp_df["feature"][::-1],
            imp_df["importance"][::-1])
    plt.xlabel("Importância")
    plt.title(f"Top- {top_k} importâncias – {type(model).__name__}")
    plt.tight_layout()
    plt.show()

    # Previsões
    y_pred = final_pipeline.predict(X_test)
    y_proba = final_pipeline.predict_proba(X_test)[:, 1] if hasattr(final_model, "predict_proba") else None

    # Matriz de confusão
    cm = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.title("Matriz de Confusão - Dados Completos")
    plt.xlabel("Predito")
    plt.ylabel("Real")
    plt.show()

    # Métricas
    metrics_dict = {
        "Accuracy": accuracy_score(y_test, y_pred),
        "Precision": precision_score(y_test, y_pred),
        "Recall": recall_score(y_test, y_pred),
        "F1 Score": f1_score(y_test, y_pred),
        "AUC": roc_auc_score(y_test, y_proba) if y_proba is not None else np.nan
    }

    ### ADICIONADO — guardar métricas deste fold
    metrics_all_folds.append(metrics_dict)

    plt.figure(figsize=(8, 5))
    sns.barplot(x=list(metrics_dict.keys()), y=list(metrics_dict.values()), palette="Set2")
    plt.ylim(0, 1.05)
    plt.title("Métricas de Classificação - Dados Completos")
    for i, v in enumerate(metrics_dict.values()):
        plt.text(i, v + 0.02, f"{v:.2f}", ha='center')
    plt.grid(True)
    plt.show()

    # Curvas ROC, PR, Calibração e Thresholds (mantido)
    if y_proba is not None:
        fpr, tpr, _ = roc_curve(y_test, y_proba)
        roc_auc = auc(fpr, tpr)
        plt.figure(figsize=(6, 5))
        plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.2f}")
        plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
        plt.xlabel("Falso Positivo")
        plt.ylabel("Verdadeiro Positivo")
        plt.title("Curva ROC")
        plt.legend(loc='lower right')
        plt.grid(True)
        plt.show()

        precision, recall, _ = precision_recall_curve(y_test, y_proba)
        auprc_trap = auc(recall, precision)
        plt.figure(figsize=(6, 5))
        plt.plot(recall, precision, label=f"AUPRC = {auprc_trap:.2f}")
        plt.xlabel("Recall")
        plt.ylabel("Precision")
        plt.title("Curva Precision-Recall")
        plt.legend(loc='lower right')
        plt.grid(True)
        plt.show()

        prob_true, prob_pred = calibration_curve(y_test, y_proba, n_bins=10, strategy='uniform')

        plt.figure(figsize=(6,6))
        plt.plot(prob_pred, prob_true, marker='o', linewidth=2, label='Modelo calibrado')
        plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Calibração perfeita')
        plt.title("Curva de Calibração (Isotonic Regression)")
        plt.xlabel("Probabilidade prevista (modelo)")
        plt.ylabel("Frequência real observada")
        plt.legend()
        plt.grid(True, linestyle='--', alpha=0.6)
        plt.show()

        thresholds = np.linspace(0, 1, 101)
        fp_list, fn_list = [], []
        for t in thresholds:
            y_pred_t = (y_proba >= t).astype(int)
            tn, fp, fn, tp = confusion_matrix(y_test, y_pred_t).ravel()
            fp_list.append(fp)
            fn_list.append(fn)

        df_threshold = pd.DataFrame({
            'threshold': thresholds,
            'false_positives': fp_list,
            'false_negatives': fn_list
        })

        plt.figure(figsize=(8,5))
        plt.plot(df_threshold['threshold'], df_threshold['false_positives'], label='Falsos Positivos (FP)')
        plt.plot(df_threshold['threshold'], df_threshold['false_negatives'], label='Falsos Negativos (FN)')
        plt.xlabel('Threshold (Probabilidade de Corte)')
        plt.ylabel('Quantidade de Casos')
        plt.title('Variação de FP e FN conforme o Threshold de Decisão')
        plt.legend()
        plt.grid(True, linestyle='--', alpha=0.6)
        plt.show()

    fold += 1


# ===============================================
#   RESUMO FINAL DAS MÉTRICAS DOS FOLDS EXTERNOS
# ===============================================
df_metrics = pd.DataFrame(metrics_all_folds)

summary = pd.DataFrame({
    "Média": df_metrics.mean(),
    "Mediana": df_metrics.median(),
    "Desvio Padrão": df_metrics.std()
})

print("\n=====================================")
print(" RESUMO FINAL DAS MÉTRICAS (OUTER CV)")
print("=====================================\n")
print(summary)

# (Opcional) gráfico do resumo
plt.figure(figsize=(10, 6))
summary.T.plot(kind='bar')
plt.title("Resumo das Métricas dos Folds Externos")
plt.xticks(rotation=0)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# ==============================
#   Fold Externo 1/4
# ==============================
# [LightGBM] [Info] Number of positive: 4717, number of negative: 4717
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.038689 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 31921
# [LightGBM] [Info] Number of data points in the train set: 9434, number of used features: 220
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# ==============================
#   Fold Externo 2/4
# ==============================
# [LightGBM] [Info] Number of positive: 4717, number of negative: 4717
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.052440 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 32121
# [LightGBM] [Info] Number of data points in the train set: 9434, number of used features: 216
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# ==============================
#   Fold Externo 3/4
# ==============================
# [LightGBM] [Info] Number of positive: 4718, number of negative: 4718
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.016147 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 31926
# [LightGBM] [Info] Number of data points in the train set: 9436, number of used features: 210
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# ==============================
#   Fold Externo 4/4
# ==============================
# [LightGBM] [Info] Number of positive: 4718, number of negative: 4718
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.016135 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 31978
# [LightGBM] [Info] Number of data points in the train set: 9436, number of used features: 213
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# =====================================
#  RESUMO FINAL DAS MÉTRICAS (OUTER CV)
# =====================================
#
#               Média   Mediana  Desvio Padrão
# Accuracy   0.922520  0.923293       0.006548
# Precision  0.859045  0.859217       0.018039
# Recall     0.735299  0.733586       0.022088
# F1 Score   0.792293  0.794969       0.018693
# AUC        0.928638  0.928075       0.004404
