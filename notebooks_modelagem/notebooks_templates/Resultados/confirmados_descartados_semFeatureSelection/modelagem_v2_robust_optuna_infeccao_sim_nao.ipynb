# %%
# !pip uninstall xgboost -y
# Out:
# Found existing installation: xgboost 3.1.1
# Uninstalling xgboost-3.1.1:
#   Successfully uninstalled xgboost-3.1.1

# %%
# !pip install optuna xgboost==3.1.1 lightgbm fastparquet imbalanced-learn torch rapidfuzz
# Out:
# Requirement already satisfied: optuna in /usr/local/lib/python3.12/dist-packages (4.7.0)
# Collecting xgboost==3.1.1
#   Using cached xgboost-3.1.1-py3-none-manylinux_2_28_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.12/dist-packages (4.6.0)
# Requirement already satisfied: fastparquet in /usr/local/lib/python3.12/dist-packages (2025.12.0)
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.12/dist-packages (0.14.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.9.0+cpu)
# Requirement already satisfied: rapidfuzz in /usr/local/lib/python3.12/dist-packages (3.14.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from xgboost==3.1.1) (2.0.2)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.12/dist-packages (from xgboost==3.1.1) (2.29.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from xgboost==3.1.1) (1.16.3)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.18.3)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.12/dist-packages (from optuna) (6.10.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (26.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.46)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.2)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: pandas>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from fastparquet) (2.2.2)
# Requirement already satisfied: cramjam>=2.3 in /usr/local/lib/python3.12/dist-packages (from fastparquet) (2.11.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from fastparquet) (2025.3.0)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (1.6.1)
# Requirement already satisfied: sklearn-compat<0.2,>=0.1.5 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (0.1.5)
# Requirement already satisfied: joblib<2,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->fastparquet) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->fastparquet) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->fastparquet) (2025.3)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->fastparquet) (1.17.0)
# Using cached xgboost-3.1.1-py3-none-manylinux_2_28_x86_64.whl (115.9 MB)
# Installing collected packages: xgboost
# Successfully installed xgboost-3.1.1

# %%
# !pip install rapidfuzz
# Out:
# Collecting rapidfuzz
#   Downloading rapidfuzz-3.14.3-cp310-cp310-win_amd64.whl.metadata (12 kB)
# Downloading rapidfuzz-3.14.3-cp310-cp310-win_amd64.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    -------------------- ------------------- 0.8/1.5 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 4.1 MB/s  0:00:00
# Installing collected packages: rapidfuzz
# Successfully installed rapidfuzz-3.14.3
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import os, joblib,time
from functools import partial

from sklearn.model_selection import StratifiedKFold, cross_val_score,train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.calibration import CalibratedClassifierCV

import optuna
from optuna.pruners import SuccessiveHalvingPruner
from optuna.exceptions import TrialPruned

#from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.impute import SimpleImputer
from functools import partial


from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, confusion_matrix, matthews_corrcoef,
    cohen_kappa_score, balanced_accuracy_score,
    classification_report, brier_score_loss, log_loss,
    confusion_matrix, ConfusionMatrixDisplay,
    precision_recall_curve, RocCurveDisplay,roc_curve,auc
)

from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE

import matplotlib.pyplot as plt
import seaborn as sns

import subprocess
import xgboost as xgb
import lightgbm as lgb
#import torch

import re
from rapidfuzz import fuzz, process

import os
import re
import glob
import pandas as pd

import shutil
import os
#from google.colab import drive


import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Configurando salvamento de checkpoints no Drive
#
# Montando o drive e acessando a conta para poder conseguir salvar os checkpoints ao final do processamento

# %%
drive.mount('/content/drive')
experimento = 'confirmados_descartados_semFeatureSelection'

# %% [markdown]
# ### Carregando base de dados

# %% [markdown]
# Carregamento do conjunto de dados processado a partir de um arquivo no formato Parquet.
# Esse formato colunar é otimizado para leitura eficiente, reduz uso de memória e preserva os tipos de dados,
# sendo adequado para pipelines analíticos e etapas posteriores de modelagem.

# %%
df =pd.read_parquet('df_hepat_processed_v1.parquet',engine='fastparquet')

# %% [markdown]
# ### Selecionar variáveis relevantes para triagem

# %% [markdown]
# Definição das variáveis explicativas e da variável alvo utilizadas no modelo.
# As features incluem características sociodemográficas, condições ambientais, antecedentes clínicos e sintomas,
# além de variáveis derivadas de vulnerabilidade social e sazonalidade, enquanto a variável alvo representa a severidade do caso.

# %%
triage_features = [
    'NU_IDADE_N','CS_SEXO','CS_GESTANT','CS_RACA','CS_ESCOL_N',
    'ID_OCUPA_N','CON_AREA','CON_AMBIEN',
    'ANT_CB_LAM','ANT_CB_CRI','ANT_CB_SIN','ANT_CB_COR','ANT_CB_ROE',
    'ANT_CB_TER','ANT_CB_LIX','ANT_CB_OUT','ANT_ANIMAI','ANT_HUMANO',
    'CLI_FEBRE','CLI_MIALGI','CLI_CEFALE','CLI_PROST','CLI_CONGES',
    'CLI_PANTUR','CLI_VOMITO','CLI_DIARRE','CLI_ICTERI','CLI_RENAL',
    'CLI_RESPIR','CLI_CARDIA','CLI_HEMOPU','CLI_HEMORR','CLI_MENING',
    'CLI_OUTROS','SG_UF', 'baixa_escolaridade','raca_vulneravel','faixa_vulneravel',
    'vulnerabilidade_social', 'nivel_vulnerabilidade','mes_sintomas','estacao', 'periodo_chuvoso'
]



target_col = 'CLASSI_FIN'  # rótulo: confirmado vs descartado

if target_col == 'CLASSI_FIN':
    df = df[df['CLASSI_FIN'].isin(['Confirmado', 'Descartado'])].copy()

    # Criar variável alvo binária
    df['alvo'] = df['CLASSI_FIN'].map({
        'Confirmado': 1,
        'Descartado': 0
    })

# %% [markdown]
# ### Amostragem estratificada dos dados
#
# Nesta etapa é realizada uma amostragem estratificada da base de dados,
# preservando a proporção das classes da variável alvo.
# O procedimento consiste em aplicar uma amostragem aleatória dentro de cada classe,
# extraindo uma fração representativa do conjunto original.
#
# Em seguida, a base amostrada é separada em variáveis explicativas (X)
# e variável resposta (y), que serão utilizadas nas etapas subsequentes de modelagem.
#
# Essa abordagem reduz o volume de dados processados,
# mantendo a representatividade estatística das classes e garantindo reprodutibilidade
# por meio do uso de uma semente aleatória fixa.

# %%
## Amostragem estratificada
amostragem = df.groupby("alvo").sample(frac=0.35, random_state=42).copy()

X_data=amostragem[triage_features]
y_data = amostragem['alvo']

# %%
X_data.shape
# Out:
# (55110, 43)

# %% [markdown]
# ## Train framework

# %% [markdown]
# ### Funções de apoio

# %% [markdown]
# Detecta automaticamente a disponibilidade de GPU no ambiente,
# verificando suporte a CUDA, compatibilidade do LightGBM com GPU
# e informações do hardware via `nvidia-smi`.

# %%
def detect_gpu():
    """
    Detecta corretamente suporte a GPU para CUDA, XGBoost e LightGBM.
    Retorna um dicionário completo.
    """

    # 1. Verificar CUDA geral
    try:
        cuda_available = torch.cuda.is_available()
    except:
        cuda_available = False


    # 2. Testar LightGBM GPU

    try:
        # Testa se LightGBM foi compilado com suporte a GPU
        lgb_gpu = lgb.register_logger(lambda x: x)  # dummy
        booster = lgb.LGBMClassifier(device="gpu")
        lgb_gpu = True
    except:
        lgb_gpu = False


    # 3. Detalhes da GPU via nvidia-smi

    try:
        smi_output = subprocess.check_output("nvidia-smi", shell=True).decode()
        gpu_info = smi_output.split("\n")[2].strip()
    except:
        gpu_info = "Nenhuma GPU detectada (nvidia-smi não disponível)"

    return {
        "cuda_available": cuda_available,
        "lightgbm_gpu": lgb_gpu,
        "gpu_info": gpu_info
    }

# %%
def get_model_params_gpu(model_name, gpu_info):
    """
    Retorna hiperparâmetros base apropriados para CPU ou GPU.
    """
    use_gpu = gpu_info["cuda_available"]

    if model_name == "xgboost":
        if use_gpu:
            return {
                "tree_method": "gpu_hist",
                "predictor": "gpu_predictor"
            }
        else:
            return {
                "tree_method": "hist",
                "predictor": "cpu_predictor"
            }

    elif model_name == "lightgbm":
        if use_gpu:
            return {
                "device": "gpu",
                "gpu_platform_id": 0,
                "gpu_device_id": 0
            }
        else:
            return {
                "device": "cpu"
            }

    elif model_name in ["random_forest", "svm"]:
        # sklearn não usa GPU
        return {}

    return {}

# %%
def get_feature_types(df):
    """
    Identifica automaticamente colunas categóricas e numéricas de um dataframe.

    Retorna:
        cat_cols  -> lista de colunas categóricas
        num_cols  -> lista de colunas numéricas
    """

    # CATEGÓRICAS: object, category ou boolean
    cat_cols = df.select_dtypes(include=['object', 'category', 'bool']).columns.tolist()

    # NUMÉRICAS: int, float
    num_cols = df.select_dtypes(include=['int', 'float', 'int64', 'float64']).columns.tolist()

    return cat_cols, num_cols

# %% [markdown]
# ###  1. FUNÇÃO PARA CRIAR O MODELO A PARTIR DO TRIAL (Optuna)

# %% [markdown]
# Esta função encapsula a criação do modelo a ser otimizado por uma *trial* do Optuna,
# permitindo que diferentes famílias de classificadores sejam avaliadas dentro do mesmo processo de busca.
#
# O fluxo é composto por duas decisões principais:
#
# 1) **Seleção do algoritmo**
# A cada iteração, o Optuna escolhe o modelo a ser testado (`svm`, `xgboost`, `lightgbm` ou `random_forest`)
# por meio de uma variável categórica (`model_name`). Isso viabiliza uma busca conjunta que compara
# arquiteturas distintas sob o mesmo protocolo de avaliação.
#
# 2) **Amostragem de hiperparâmetros e configuração dinâmica de GPU**
# Para cada algoritmo, são sugeridos hiperparâmetros relevantes (ex.: profundidade, número de árvores, taxa de aprendizado,
# subsample e colsample), definindo um espaço de busca controlado e reproduzível.
# Em paralelo, a função consulta `get_model_params_gpu(model_name, gpu_info)` para injetar automaticamente
# parâmetros específicos de aceleração (CPU/GPU) quando suportado pelo ambiente, garantindo portabilidade do pipeline.
#
# Além disso, é aplicada uma estratégia de mitigação de desbalanceamento:
# - `class_weight="balanced"` para Random Forest e SVM,
# - `is_unbalance=True` para LightGBM,
# visando reduzir viés em cenários com classes minoritárias.
#
# No caso da SVM, utiliza-se `LinearSVC` com calibração (`CalibratedClassifierCV`),
# permitindo a obtenção de probabilidades calibradas, úteis para métricas baseadas em ranking (ex.: ROC-AUC)
# e para tomada de decisão com limiar de classificação.

# %%
def create_model(trial, gpu_info):
    model_name = trial.suggest_categorical(
        "model_name", ["svm","xgboost", "lightgbm", "random_forest"]
    )

    gpu_params = get_model_params_gpu(model_name, gpu_info)

    # RANDOM FOREST
    if model_name == "random_forest":
        return RandomForestClassifier(
            n_estimators=trial.suggest_int("n_estimators", 5, 30),
            max_depth=trial.suggest_int("max_depth", 3, 9),
            min_samples_split=trial.suggest_int("min_samples_split", 2, 10),
            min_samples_leaf=trial.suggest_int("min_samples_leaf", 1, 5),
            random_state=42,
            class_weight= 'balanced',
            **gpu_params
        )

    # SVM
    elif model_name == "svm":
        svm= LinearSVC(
            C=trial.suggest_float("C", 0.1, 3.0),
            max_iter=5000,
            class_weight= 'balanced'
        )
        return CalibratedClassifierCV(svm, method="sigmoid")

    # XGBOOST
    elif model_name == "xgboost":
        return XGBClassifier(
            n_estimators=trial.suggest_int("n_estimators", 5, 30),
            max_depth=trial.suggest_int("max_depth", 3, 9),
            learning_rate=trial.suggest_float("learning_rate", 0.01, 0.3),
            subsample=trial.suggest_float("subsample", 0.5, 1.0),
            colsample_bytree=trial.suggest_float("colsample_bytree", 0.5, 1.0),
            eval_metric="logloss",
            random_state=42,
            class_weight= 'balanced',
            n_jobs=-1,
            #**gpu_params
        )

    # LIGHTGBM
    elif model_name == "lightgbm":
        return LGBMClassifier(
            n_estimators=trial.suggest_int("n_estimators", 5, 30),
            learning_rate=trial.suggest_float("learning_rate", 0.01, 0.3),
            max_depth=trial.suggest_int("max_depth", 3, 9),
            subsample=trial.suggest_float("subsample", 0.5, 1.0),
            colsample_bytree=trial.suggest_float("colsample_bytree", 0.5, 1.0),
            random_state=42,
            is_unbalance=True,
           force_col_wise=True,
            **gpu_params
        )

# %% [markdown]
# ### 2. FUNÇÃO OBJETIVO DO OPTUNA (COM CROSS-VALIDATION)

# %% [markdown]
# ### Função `build_pipeline`: pré-processamento, balanceamento e modelagem em um fluxo único
#
# Esta função constrói um pipeline completo de treinamento, integrando pré-processamento dos dados,
# tratamento de desbalanceamento e ajuste do modelo em uma única estrutura reprodutível.
#
# O pipeline é organizado em três blocos sequenciais:
#
# 1) **Pré-processamento por tipo de variável**
# - Variáveis numéricas passam por imputação da mediana, reduzindo sensibilidade a outliers,
# seguida de padronização (`StandardScaler`), garantindo escalas compatíveis para modelos sensíveis à magnitude.
# - Variáveis categóricas passam por imputação do valor mais frequente e codificação via `OneHotEncoder`,
# com tratamento explícito de categorias raras (`handle_unknown='infrequent_if_exist'`),
# o que reduz dimensionalidade excessiva e melhora estabilidade do modelo.
#
# 2) **Balanceamento de classes (SMOTE)**
# Após o pré-processamento, aplica-se o SMOTE para gerar amostras sintéticas da classe minoritária
# exclusivamente no conjunto de treino dentro do pipeline,
# evitando vazamento de informação (*data leakage*) e melhorando a capacidade do modelo
# em aprender fronteiras de decisão mais equilibradas.
#
# 3) **Modelo preditivo**
# O estimador final é injetado de forma modular, permitindo que diferentes algoritmos
# (Random Forest, SVM, XGBoost, LightGBM, etc.) sejam testados sob exatamente o mesmo fluxo de dados.
#
# Ao encapsular todas as etapas em um único objeto `Pipeline`,
# a função garante consistência entre treino, validação e inferência,
# além de facilitar integração com validação cruzada e otimização de hiperparâmetros.

# %%
def build_pipeline(model, cat_cols, num_cols):

    # construindo o preprocessor
    num_preprocessor = Pipeline(steps=[
        ("imputer", SimpleImputer(strategy="median")),
        ("scaler", StandardScaler())
    ])

    cat_preprocessor = Pipeline(steps=[
        ("imputer", SimpleImputer(strategy="most_frequent")),
        ("onehot", OneHotEncoder(handle_unknown='infrequent_if_exist'))
    ])

    preprocessor = ColumnTransformer(
        transformers=[
            ("num", num_preprocessor, num_cols),
            ("cat", cat_preprocessor, cat_cols)
        ]
    )

    # construindo pipe
    pipe = Pipeline([
        ("preprocessor", preprocessor),
        ("smote", SMOTE(random_state=42)),
        ("model", model)
    ])

    return pipe

# %% [markdown]
# ### Função `objective`: avaliação do modelo por validação cruzada e otimização com Optuna (com pruning)
#
# Esta função define a métrica objetivo utilizada pelo Optuna durante a busca de hiperparâmetros.
# Para cada `trial`, ela instancia um modelo candidato (via `create_model`) e o encapsula em um pipeline completo
# de pré-processamento + balanceamento (via `build_pipeline`), garantindo que todas as transformações
# sejam aplicadas corretamente dentro de cada fold e evitando *data leakage*.
#
# A avaliação é realizada com **validação cruzada estratificada** (`StratifiedKFold`),
# preservando a proporção de classes em treino e validação. Em cada fold:
# - o pipeline é treinado no subconjunto de treino (`fit`),
# - e a performance é medida no subconjunto de validação por **ROC-AUC** calculado a partir de probabilidades (`predict_proba`).
#
# Para suportar cenários multiclasse, o AUC é calculado com `multi_class='ovr'`
# e agregação `average='weighted'`, o que pondera o desempenho pelo suporte de cada classe
# e reduz distorções em bases desbalanceadas.
#
# Além disso, a função utiliza mecanismos de *early stopping* do Optuna:
# - `trial.report` comunica a métrica parcial por fold,
# - `trial.should_prune()` permite interromper tentativas com desempenho fraco,
# economizando tempo computacional e acelerando a convergência do processo de otimização.
#
# Ao final, a função retorna a média do AUC entre os folds, que é o valor maximizado pelo Optuna.

# %%
def objective(trial, X_train, y_train, cat_cols, num_cols,feature_names, gpu_info):

    model = create_model(trial, gpu_info)

    pipe = build_pipeline(model ,cat_cols, num_cols)


    cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

    scores = []
    for step, (train_idx, val_idx) in enumerate(cv.split(X_train, y_train)):

        X_tr, X_val = X_train.iloc[train_idx], X_train.iloc[val_idx]
        y_tr, y_val = y_train.iloc[train_idx], y_train.iloc[val_idx]


        pipe.fit(X_tr, y_tr)
        fold_auc = roc_auc_score(y_val, pipe.predict_proba(X_val)[:, 1])
        scores.append(fold_auc)

        #  reporta o valor parcial ao Optuna
        trial.report(fold_auc, step=step)

        #  aborta a tentativa dado a avaliação do pruner
        if trial.should_prune():
            raise TrialPruned()


    return np.mean(scores)

# %% [markdown]
# Salva o histórico das trials do Optuna (métrica, parâmetros, estado e duração)
# em arquivo CSV para análise e rastreabilidade do processo de otimização.

# %%
# salva os logs das tentativas com métricas, tempo de treinamento, e parametros utilizados pelos modelos
def dump_trials(study, trial, out_path):
    df_metrics = study.trials_dataframe(
        attrs=("number", "value", "params", "state", "duration")
    )
    df_metrics.to_csv(out_path, index=False)

# %% [markdown]
# ### 3. VALIDAÇÃO EXTERNA (OUTER CV) + OPTUNA INTERNO

# %% [markdown]
# ### Função `outer_cv_training_with_results`: nested CV com Optuna, checkpoint e métricas por fold
#
# Esta função executa um processo completo de treinamento e avaliação com **validação cruzada externa**
# (*outer cross-validation*), integrando **otimização de hiperparâmetros com Optuna** dentro de cada fold
# e registrando resultados detalhados (modelo escolhido, métricas, tempo e artefatos salvos).
#
# O fluxo segue a lógica de *nested cross-validation*:
#
# 1) **Diagnóstico do ambiente (GPU)**
# Antes do treinamento, a função identifica a disponibilidade de GPU (`detect_gpu`), permitindo que a criação dos modelos
# ative parâmetros específicos de aceleração quando suportado.
#
# 2) **Validação cruzada externa (generalização)**
# É aplicada uma `StratifiedKFold` externa com `n_splits`, garantindo que a proporção das classes seja preservada em cada divisão.
# Em cada fold externo, o conjunto é particionado em `X_train/y_train` (para otimização e treino) e `X_test/y_test` (avaliação final).
#
# 3) **Otimização interna com Optuna (seleção de modelo + hiperparâmetros)**
# Para cada fold externo, um `study` é criado com objetivo de maximizar a métrica definida na função `objective`.
# A função `objective` é “fixada” via `partial`, injetando os dados do fold e metadados do pipeline (colunas numéricas e categóricas,
# GPU, etc.), de forma que cada trial avalie modelos e hiperparâmetros sob o mesmo protocolo.
#
# O estudo é executado com:
# - `n_trials` tentativas,
# - controle de tempo (`timeout`),
# - paralelismo (`n_jobs=-1`),
# - callback de logging (`dump_trials`) para persistir histórico das trials.
#
# 4) **Treinamento final do melhor modelo no fold e checkpoint**
# Após a otimização, a melhor configuração é recuperada (`study.best_params`) e o melhor modelo é reconstruído (`create_model`),
# sendo então encapsulado em um pipeline (`build_pipeline`) com pré-processamento e SMOTE.
# O pipeline é treinado no conjunto de treino do fold com medição de tempo, e o artefato final é salvo em disco (`joblib.dump`)
# como checkpoint (`best_model_fold_k.pkl`), garantindo reprodutibilidade e possibilidade de reuso posterior.
#
# 5) **Avaliação no conjunto de teste do fold (métricas completas)**
# O modelo treinado é avaliado no `X_test/y_test` do fold externo usando:
# - **ROC-AUC multiclasse** com estratégia OvR e média ponderada (`average='weighted'`),
# - além de `accuracy`, `f1`, `recall` e `precision` (também ponderadas), adequadas para cenários desbalanceados.
#
# Ao final, a função retorna uma lista de dicionários com os resultados de cada fold,
# incluindo o modelo vencedor, hiperparâmetros, métricas, tempo de treino e caminho do checkpoint.
# Isso permite comparar estabilidade do desempenho entre folds e estimar capacidade real de generalização.

# %%
def outer_cv_training_with_results(
    X, y, cat_cols, num_cols,
    n_trials=30, n_splits=5,
    log_dir="log_opt",
    model_ckpt_dir="checkpoints_best_models"
):
    gpu_info = detect_gpu()
    print("\n🔍 GPU detectada:", gpu_info)


    outer_cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
    results = []
    feature_names = X.columns

    for fold, (train_idx, test_idx) in enumerate(outer_cv.split(X, y), start=1):

        print(f"\n==============================")
        print(f"  Fold Externo {fold}/{n_splits}")
        print(f"==============================")

        X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

        pruner = SuccessiveHalvingPruner(
            min_resource=1, reduction_factor=3, min_early_stopping_rate=1
        )

        study = optuna.create_study(direction="maximize", pruner=pruner)

        objective_fixed = partial(
            objective,
            X_train=X_train,
            y_train=y_train,
            cat_cols=cat_cols,
            num_cols=num_cols,
            feature_names=feature_names,
            gpu_info=gpu_info
        )

        # log por fold (arquivo diferente)
        log_path = os.path.join(log_dir, f"trials_log_fold_{fold}.csv")
        dump_trials_cb = partial(dump_trials, out_path=log_path)

        study.optimize(
            objective_fixed,
            n_trials=n_trials,
            callbacks=[dump_trials_cb],
            timeout=1800,
            n_jobs=-1,
        )

        best_params = study.best_params
        best_model_name = best_params.get("model_name", "unknown")
        best_model = create_model(study.best_trial, gpu_info)

        pipe = build_pipeline(best_model, cat_cols, num_cols)

        start_time = time.time()
        pipe.fit(X_train, y_train)
        train_time = time.time() - start_time

        # checkpoint do melhor modelo do fold
        checkpoint_path = os.path.join(model_ckpt_dir, f"best_model_fold_{fold}.pkl")
        joblib.dump(pipe, checkpoint_path)

        # predição
        y_pred = pipe.predict(X_test)
        y_pred_prob = pipe.predict_proba(X_test)[:, 1]

        # métricas
        auc = roc_auc_score(y_test, y_pred_prob)
        acc = accuracy_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)
        rec = recall_score(y_test, y_pred)
        prec = precision_score(y_test, y_pred)

        results.append({
            "fold": fold,
            "best_model": best_model_name,
            "auc": auc,
            "accuracy": acc,
            "f1": f1,
            "recall": rec,
            "precision": prec,
            "hyperparameters": best_params,
            "checkpoint_path": checkpoint_path,
            "train_time_seconds": train_time,
            "trials_log_path": log_path,
        })

    return results

# %% [markdown]
# # Execute Framework

# %% [markdown]
# Cria os diretórios de checkpoints de modelos e logs de otimização,
# caso não existam, garantindo persistência e organização dos artefatos do experimento.

# %%
import os, joblib
checkpoint_dir = "checkpoints_best_models"

if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)

checkpoint_dir = "log_opt"
if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)


# ================================================

# %% [markdown]
# ### Execução do treinamento com validação cruzada externa e otimização de hiperparâmetros
#
# Nesta etapa, o conjunto de dados é preparado para o processo completo de treinamento e avaliação.
# Inicialmente, as colunas são classificadas em **categóricas** e **numéricas** por meio da função
# `get_feature_types`, garantindo que o pré-processamento subsequente seja aplicado de forma adequada
# a cada tipo de variável.
#
# Em seguida, é executado o procedimento de **validação cruzada externa** (*outer cross-validation*),
# no qual, para cada fold, ocorre uma otimização interna de hiperparâmetros via Optuna.
# Esse desenho experimental permite avaliar o desempenho dos modelos de forma mais realista,
# uma vez que o conjunto de teste de cada fold permanece completamente isolado do processo de tuning.
#
# Os parâmetros utilizados (`n_trials=30` e `n_splits=5`) definem, respectivamente,
# o orçamento de busca de hiperparâmetros em cada fold e o número de partições externas,
# balanceando custo computacional e robustez estatística.
#
# O resultado final (`df_results`) contém métricas, hiperparâmetros selecionados,
# tempos de treinamento e caminhos dos checkpoints para cada fold,
# servindo como base para análises comparativas e seleção do modelo final.

# %%
cat_cols, num_cols = get_feature_types(X_data)
df_results = outer_cv_training_with_results(
    X_data, y_data,
    cat_cols=cat_cols,
    num_cols=num_cols,
    n_trials=50,
    n_splits=5
)
# Out:
# [I 2026-02-08 17:17:05,655] A new study created in memory with name: no-name-9cf35a3f-fcdf-4076-9c80-f7535f03c4b7
# 🔍 GPU detectada: {'cuda_available': False, 'lightgbm_gpu': False, 'gpu_info': 'Nenhuma GPU detectada (nvidia-smi não disponível)'}
#
# ==============================
#   Fold Externo 1/5
# ==============================
# [I 2026-02-08 17:17:55,845] Trial 0 finished with value: 0.8886317994555698 and parameters: {'model_name': 'random_forest', 'n_estimators': 8, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 2}. Best is trial 0 with value: 0.8886317994555698.
# [I 2026-02-08 17:18:00,595] Trial 1 finished with value: 0.9055219856149814 and parameters: {'model_name': 'xgboost', 'n_estimators': 7, 'max_depth': 6, 'learning_rate': 0.20715946497813825, 'subsample': 0.5820980322838762, 'colsample_bytree': 0.8584512839930134}. Best is trial 1 with value: 0.9055219856149814.
# [I 2026-02-08 17:18:28,791] Trial 2 finished with value: 0.9301336374056386 and parameters: {'model_name': 'lightgbm', 'n_estimators': 25, 'learning_rate': 0.28573470161954295, 'max_depth': 9, 'subsample': 0.7553594830234649, 'colsample_bytree': 0.6020567130538907}. Best is trial 2 with value: 0.9301336374056386.
# [I 2026-02-08 17:18:41,276] Trial 3 finished with value: 0.9049908587054606 and parameters: {'model_name': 'xgboost', 'n_estimators': 27, 'max_depth': 7, 'learning_rate': 0.03892566801288956, 'subsample': 0.9883637251623031, 'colsample_bytree': 0.7480976412351862}. Best is trial 2 with value: 0.9301336374056386.
# [I 2026-02-08 17:20:18,553] Trial 4 finished with value: 0.9191484702006479 and parameters: {'model_name': 'svm', 'C': 0.6789879154987678}. Best is trial 2 with value: 0.9301336374056386.
# [I 2026-02-08 17:20:48,832] Trial 6 finished with value: 0.9124270969341013 and parameters: {'model_name': 'random_forest', 'n_estimators': 26, 'max_depth': 8, 'min_samples_split': 8, 'min_samples_leaf': 4}. Best is trial 2 with value: 0.9301336374056386.
# [I 2026-02-08 17:21:13,068] Trial 7 finished with value: 0.8957591994277491 and parameters: {'model_name': 'random_forest', 'n_estimators': 8, 'max_depth': 7, 'min_samples_split': 6, 'min_samples_leaf': 5}. Best is trial 2 with value: 0.9301336374056386.
# [I 2026-02-08 17:21:22,093] Trial 5 finished with value: 0.9181998201819926 and parameters: {'model_name': 'svm', 'C': 2.497994779225292}. Best is trial 2 with value: 0.9301336374056386.
# [I 2026-02-08 17:21:40,770] Trial 8 finished with value: 0.9246892442697519 and parameters: {'model_name': 'lightgbm', 'n_estimators': 16, 'learning_rate': 0.15373301073586246, 'max_depth': 9, 'subsample': 0.522582160673193, 'colsample_bytree': 0.9905683655000028}. Best is trial 2 with value: 0.9301336374056386.
# [I 2026-02-08 17:21:43,705] Trial 9 finished with value: 0.8637043298362403 and parameters: {'model_name': 'random_forest', 'n_estimators': 6, 'max_depth': 3, 'min_samples_split': 9, 'min_samples_leaf': 3}. Best is trial 2 with value: 0.9301336374056386.
# [I 2026-02-08 17:22:11,283] Trial 11 finished with value: 0.9303965325364837 and parameters: {'model_name': 'lightgbm', 'n_estimators': 20, 'learning_rate': 0.2997902994242031, 'max_depth': 9, 'subsample': 0.8269511408456379, 'colsample_bytree': 0.5302480378982111}. Best is trial 11 with value: 0.9303965325364837.
# [I 2026-02-08 17:22:39,504] Trial 12 finished with value: 0.9303560156668005 and parameters: {'model_name': 'lightgbm', 'n_estimators': 20, 'learning_rate': 0.2978142879618469, 'max_depth': 9, 'subsample': 0.8309264964381117, 'colsample_bytree': 0.5457678461375424}. Best is trial 11 with value: 0.9303965325364837.
# [I 2026-02-08 17:23:07,377] Trial 13 finished with value: 0.9296412001353414 and parameters: {'model_name': 'lightgbm', 'n_estimators': 19, 'learning_rate': 0.2948936520194864, 'max_depth': 9, 'subsample': 0.842660748296852, 'colsample_bytree': 0.5011526914552937}. Best is trial 11 with value: 0.9303965325364837.
# [I 2026-02-08 17:23:34,813] Trial 14 finished with value: 0.9257366345241292 and parameters: {'model_name': 'lightgbm', 'n_estimators': 19, 'learning_rate': 0.22535884908735743, 'max_depth': 5, 'subsample': 0.8613028719268593, 'colsample_bytree': 0.518703637153609}. Best is trial 11 with value: 0.9303965325364837.
# [I 2026-02-08 17:23:51,839] Trial 10 finished with value: 0.9186614559505625 and parameters: {'model_name': 'svm', 'C': 1.1928589512351864}. Best is trial 11 with value: 0.9303965325364837.
# [I 2026-02-08 17:24:01,963] Trial 15 finished with value: 0.9283528829741124 and parameters: {'model_name': 'lightgbm', 'n_estimators': 15, 'learning_rate': 0.29741444160315533, 'max_depth': 8, 'subsample': 0.8086753968478761, 'colsample_bytree': 0.6702858050970429}. Best is trial 11 with value: 0.9303965325364837.
# [I 2026-02-08 17:24:19,522] Trial 16 finished with value: 0.9276425116643275 and parameters: {'model_name': 'lightgbm', 'n_estimators': 15, 'learning_rate': 0.29101222115143743, 'max_depth': 8, 'subsample': 0.8219224373253758, 'colsample_bytree': 0.6449679250157203}. Best is trial 11 with value: 0.9303965325364837.
# [I 2026-02-08 17:24:32,176] Trial 17 finished with value: 0.9290697308795778 and parameters: {'model_name': 'lightgbm', 'n_estimators': 22, 'learning_rate': 0.21592312753293674, 'max_depth': 8, 'subsample': 0.6571075336682992, 'colsample_bytree': 0.6161488912273835}. Best is trial 11 with value: 0.9303965325364837.
# [I 2026-02-08 17:24:47,795] Trial 18 finished with value: 0.9290985590180441 and parameters: {'model_name': 'lightgbm', 'n_estimators': 23, 'learning_rate': 0.2169186032116809, 'max_depth': 7, 'subsample': 0.6721840389916776, 'colsample_bytree': 0.5768640357357149}. Best is trial 11 with value: 0.9303965325364837.
# [I 2026-02-08 17:24:59,773] Trial 19 finished with value: 0.9211101283668156 and parameters: {'model_name': 'lightgbm', 'n_estimators': 12, 'learning_rate': 0.10628855902894022, 'max_depth': 6, 'subsample': 0.9431895496867396, 'colsample_bytree': 0.5515054968168259}. Best is trial 11 with value: 0.9303965325364837.
# [I 2026-02-08 17:25:16,094] Trial 20 finished with value: 0.9067958995288263 and parameters: {'model_name': 'xgboost', 'n_estimators': 12, 'max_depth': 6, 'learning_rate': 0.12043319048505469, 'subsample': 0.9290339064871707, 'colsample_bytree': 0.7447917612447089}. Best is trial 11 with value: 0.9303965325364837.
# [I 2026-02-08 17:25:39,828] Trial 21 finished with value: 0.9300609678401384 and parameters: {'model_name': 'xgboost', 'n_estimators': 30, 'max_depth': 9, 'learning_rate': 0.25299862152167213, 'subsample': 0.9300376936991976, 'colsample_bytree': 0.7010454267933067}. Best is trial 11 with value: 0.9303965325364837.
# [I 2026-02-08 17:25:46,292] Trial 22 finished with value: 0.9307342600645416 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.25972221921870287, 'max_depth': 9, 'subsample': 0.7724959677806928, 'colsample_bytree': 0.5907450266072762}. Best is trial 22 with value: 0.9307342600645416.
# [I 2026-02-08 17:26:08,350] Trial 23 finished with value: 0.9303054477385341 and parameters: {'model_name': 'lightgbm', 'n_estimators': 22, 'learning_rate': 0.25659969352900713, 'max_depth': 9, 'subsample': 0.743454954756815, 'colsample_bytree': 0.5873474741218643}. Best is trial 22 with value: 0.9307342600645416.
# [I 2026-02-08 17:26:16,186] Trial 24 finished with value: 0.9306054959496689 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.25147609318888214, 'max_depth': 9, 'subsample': 0.7535400870126749, 'colsample_bytree': 0.5624678011925589}. Best is trial 22 with value: 0.9307342600645416.
# [I 2026-02-08 17:26:38,129] Trial 25 finished with value: 0.930399402216695 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.25431933200796225, 'max_depth': 8, 'subsample': 0.7502978525724807, 'colsample_bytree': 0.5021014354229048}. Best is trial 22 with value: 0.9307342600645416.
# [I 2026-02-08 17:26:44,295] Trial 26 finished with value: 0.9302427178939192 and parameters: {'model_name': 'lightgbm', 'n_estimators': 29, 'learning_rate': 0.2516960533782978, 'max_depth': 8, 'subsample': 0.7345024846267465, 'colsample_bytree': 0.8184030553169654}. Best is trial 22 with value: 0.9307342600645416.
# [I 2026-02-08 17:27:07,750] Trial 27 finished with value: 0.9311700564655879 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.2509336946488207, 'max_depth': 8, 'subsample': 0.7240563986296447, 'colsample_bytree': 0.5023503925350862}. Best is trial 27 with value: 0.9311700564655879.
# [I 2026-02-08 17:27:13,154] Trial 28 finished with value: 0.9292614891946841 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.17920566616941014, 'max_depth': 7, 'subsample': 0.6919818300263381, 'colsample_bytree': 0.5008292314582887}. Best is trial 27 with value: 0.9311700564655879.
# [I 2026-02-08 17:30:12,737] Trial 30 finished with value: 0.9181525645720828 and parameters: {'model_name': 'svm', 'C': 2.7589040158441556}. Best is trial 27 with value: 0.9311700564655879.
# [I 2026-02-08 17:30:16,866] Trial 29 finished with value: 0.9181633168973993 and parameters: {'model_name': 'svm', 'C': 2.689614146876564}. Best is trial 27 with value: 0.9311700564655879.
# [I 2026-02-08 17:30:41,888] Trial 31 finished with value: 0.9145360731982389 and parameters: {'model_name': 'random_forest', 'n_estimators': 25, 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 27 with value: 0.9311700564655879.
# [I 2026-02-08 17:30:46,327] Trial 32 finished with value: 0.9307556414914884 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.2544086390680787, 'max_depth': 8, 'subsample': 0.7740414232903486, 'colsample_bytree': 0.562091586308828}. Best is trial 27 with value: 0.9311700564655879.
# [I 2026-02-08 17:31:10,755] Trial 33 finished with value: 0.9311307291669421 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.2559460353411284, 'max_depth': 8, 'subsample': 0.7694190131299522, 'colsample_bytree': 0.5671140098295339}. Best is trial 27 with value: 0.9311700564655879.
# [I 2026-02-08 17:31:15,913] Trial 34 finished with value: 0.9301430820349997 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.1851348097708633, 'max_depth': 9, 'subsample': 0.7807091705137564, 'colsample_bytree': 0.6382544999851865}. Best is trial 27 with value: 0.9311700564655879.
# [I 2026-02-08 17:31:39,477] Trial 35 finished with value: 0.9290992376364051 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.18943808762349382, 'max_depth': 7, 'subsample': 0.7018180992827724, 'colsample_bytree': 0.640835997673488}. Best is trial 27 with value: 0.9311700564655879.
# [I 2026-02-08 17:31:48,093] Trial 36 finished with value: 0.928469920962844 and parameters: {'model_name': 'xgboost', 'n_estimators': 27, 'max_depth': 7, 'learning_rate': 0.2685949377252034, 'subsample': 0.6991757377748968, 'colsample_bytree': 0.5973373625434587}. Best is trial 27 with value: 0.9311700564655879.
# [I 2026-02-08 17:32:15,084] Trial 37 finished with value: 0.9293252166808 and parameters: {'model_name': 'xgboost', 'n_estimators': 24, 'max_depth': 8, 'learning_rate': 0.26964902381114225, 'subsample': 0.8871009935666547, 'colsample_bytree': 0.5808137902173737}. Best is trial 27 with value: 0.9311700564655879.
# [I 2026-02-08 17:32:15,418] Trial 38 finished with value: 0.9275836154156107 and parameters: {'model_name': 'lightgbm', 'n_estimators': 24, 'learning_rate': 0.23374381958480386, 'max_depth': 5, 'subsample': 0.6290342901290926, 'colsample_bytree': 0.6851196592699929}. Best is trial 27 with value: 0.9311700564655879.
# [I 2026-02-08 17:32:42,181] Trial 39 finished with value: 0.9288190169047269 and parameters: {'model_name': 'lightgbm', 'n_estimators': 29, 'learning_rate': 0.2408080041863272, 'max_depth': 5, 'subsample': 0.6355567383466381, 'colsample_bytree': 0.7019156911000264}. Best is trial 27 with value: 0.9311700564655879.
# [I 2026-02-08 17:32:45,466] Trial 40 finished with value: 0.9306740182350935 and parameters: {'model_name': 'lightgbm', 'n_estimators': 29, 'learning_rate': 0.27300610278446424, 'max_depth': 8, 'subsample': 0.7938385383673855, 'colsample_bytree': 0.5468424151399274}. Best is trial 27 with value: 0.9311700564655879.
# [I 2026-02-08 17:33:11,286] Trial 41 finished with value: 0.912205678131771 and parameters: {'model_name': 'random_forest', 'n_estimators': 26, 'max_depth': 8, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 27 with value: 0.9311700564655879.
# [I 2026-02-08 17:33:15,007] Trial 42 finished with value: 0.9304936909028738 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.2753072600637391, 'max_depth': 8, 'subsample': 0.7877477408941446, 'colsample_bytree': 0.5422858275339805}. Best is trial 27 with value: 0.9311700564655879.
# [I 2026-02-08 17:33:39,722] Trial 43 finished with value: 0.9309552121521354 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.2724123187045011, 'max_depth': 7, 'subsample': 0.7947773732746655, 'colsample_bytree': 0.5486057517457865}. Best is trial 27 with value: 0.9311700564655879.
# [I 2026-02-08 17:33:45,404] Trial 44 finished with value: 0.9303701250770775 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.20360111803326225, 'max_depth': 7, 'subsample': 0.7847228757158079, 'colsample_bytree': 0.5537985527593456}. Best is trial 27 with value: 0.9311700564655879.
# [I 2026-02-08 17:34:08,567] Trial 45 finished with value: 0.9292739964975918 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.20109138629509124, 'max_depth': 7, 'subsample': 0.7754596788660638, 'colsample_bytree': 0.6159590958906382}. Best is trial 27 with value: 0.9311700564655879.
# [I 2026-02-08 17:34:35,111] Trial 47 finished with value: 0.9060072543563873 and parameters: {'model_name': 'random_forest', 'n_estimators': 26, 'max_depth': 6, 'min_samples_split': 10, 'min_samples_leaf': 5}. Best is trial 27 with value: 0.9311700564655879.
# [I 2026-02-08 17:35:07,290] Trial 46 finished with value: 0.920540556559807 and parameters: {'model_name': 'svm', 'C': 0.19915444394292336}. Best is trial 27 with value: 0.9311700564655879.
# [I 2026-02-08 17:35:33,938] Trial 49 finished with value: 0.9252312172552236 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.234816777851961, 'max_depth': 3, 'subsample': 0.728066959838964, 'colsample_bytree': 0.8845348789989698}. Best is trial 27 with value: 0.9311700564655879.
# [I 2026-02-08 17:35:52,749] Trial 48 finished with value: 0.9202829856071273 and parameters: {'model_name': 'svm', 'C': 0.24669809157338318}. Best is trial 27 with value: 0.9311700564655879.
# [LightGBM] [Info] Number of positive: 35224, number of negative: 35224
# [LightGBM] [Info] Total Bins 41900
# [LightGBM] [Info] Number of data points in the train set: 70448, number of used features: 340
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2026-02-08 17:36:04,992] A new study created in memory with name: no-name-f43ab5ee-6498-41a7-beab-c2a1699607ba
# ==============================
#   Fold Externo 2/5
# ==============================
# [I 2026-02-08 17:36:32,011] Trial 1 finished with value: 0.8881073641571878 and parameters: {'model_name': 'random_forest', 'n_estimators': 21, 'max_depth': 4, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 1 with value: 0.8881073641571878.
# [I 2026-02-08 17:36:46,913] Trial 0 finished with value: 0.8989967706086204 and parameters: {'model_name': 'xgboost', 'n_estimators': 30, 'max_depth': 8, 'learning_rate': 0.020189519863905225, 'subsample': 0.8357705950689126, 'colsample_bytree': 0.6291184978126678}. Best is trial 0 with value: 0.8989967706086204.
# [I 2026-02-08 17:36:57,414] Trial 2 finished with value: 0.8630011862943356 and parameters: {'model_name': 'random_forest', 'n_estimators': 12, 'max_depth': 3, 'min_samples_split': 6, 'min_samples_leaf': 4}. Best is trial 0 with value: 0.8989967706086204.
# [I 2026-02-08 17:37:12,994] Trial 3 finished with value: 0.9194702650832708 and parameters: {'model_name': 'lightgbm', 'n_estimators': 10, 'learning_rate': 0.03322968552843617, 'max_depth': 8, 'subsample': 0.9150785396043813, 'colsample_bytree': 0.6600065939659454}. Best is trial 3 with value: 0.9194702650832708.
# [I 2026-02-08 17:37:23,672] Trial 4 finished with value: 0.9089418145081027 and parameters: {'model_name': 'xgboost', 'n_estimators': 12, 'max_depth': 3, 'learning_rate': 0.28627590588590757, 'subsample': 0.804802809724839, 'colsample_bytree': 0.7889971297506013}. Best is trial 3 with value: 0.9194702650832708.
# [I 2026-02-08 17:37:42,113] Trial 5 finished with value: 0.9274044860990892 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.2852472812552151, 'max_depth': 6, 'subsample': 0.5512370229601535, 'colsample_bytree': 0.9246429244567977}. Best is trial 5 with value: 0.9274044860990892.
# [I 2026-02-08 17:38:10,721] Trial 7 finished with value: 0.8935515777546993 and parameters: {'model_name': 'random_forest', 'n_estimators': 8, 'max_depth': 6, 'min_samples_split': 8, 'min_samples_leaf': 2}. Best is trial 5 with value: 0.9274044860990892.
# [I 2026-02-08 17:38:39,157] Trial 8 finished with value: 0.9283743599656226 and parameters: {'model_name': 'lightgbm', 'n_estimators': 25, 'learning_rate': 0.27897224532526843, 'max_depth': 7, 'subsample': 0.5122254704510472, 'colsample_bytree': 0.5414976828518203}. Best is trial 8 with value: 0.9283743599656226.
# [I 2026-02-08 17:39:38,767] Trial 6 finished with value: 0.9170515288188347 and parameters: {'model_name': 'svm', 'C': 1.203984872855924}. Best is trial 8 with value: 0.9283743599656226.
# [I 2026-02-08 17:41:09,331] Trial 9 finished with value: 0.9166355165623669 and parameters: {'model_name': 'svm', 'C': 2.218367244143582}. Best is trial 8 with value: 0.9283743599656226.
# [I 2026-02-08 17:41:37,191] Trial 11 finished with value: 0.926403592142328 and parameters: {'model_name': 'lightgbm', 'n_estimators': 21, 'learning_rate': 0.17964577269086243, 'max_depth': 9, 'subsample': 0.5208512854738078, 'colsample_bytree': 0.5071906209087955}. Best is trial 8 with value: 0.9283743599656226.
# [I 2026-02-08 17:42:06,209] Trial 12 finished with value: 0.9279537937871711 and parameters: {'model_name': 'lightgbm', 'n_estimators': 29, 'learning_rate': 0.2971134206410894, 'max_depth': 6, 'subsample': 0.5146956482976296, 'colsample_bytree': 0.9943314723865799}. Best is trial 8 with value: 0.9283743599656226.
# [I 2026-02-08 17:42:21,962] Trial 10 finished with value: 0.9165491764068284 and parameters: {'model_name': 'svm', 'C': 2.6098260685782995}. Best is trial 8 with value: 0.9283743599656226.
# [I 2026-02-08 17:42:34,577] Trial 13 finished with value: 0.9272591501275208 and parameters: {'model_name': 'lightgbm', 'n_estimators': 25, 'learning_rate': 0.21027681325589664, 'max_depth': 7, 'subsample': 0.6431378451020029, 'colsample_bytree': 0.9829359309061907}. Best is trial 8 with value: 0.9283743599656226.
# [I 2026-02-08 17:42:49,469] Trial 14 finished with value: 0.9276385550142523 and parameters: {'model_name': 'lightgbm', 'n_estimators': 25, 'learning_rate': 0.2133097161989497, 'max_depth': 7, 'subsample': 0.6559070242100484, 'colsample_bytree': 0.985598344070733}. Best is trial 8 with value: 0.9283743599656226.
# [I 2026-02-08 17:43:02,965] Trial 15 finished with value: 0.9275820137312358 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.2377221427171603, 'max_depth': 5, 'subsample': 0.6526660958254958, 'colsample_bytree': 0.8370453313623176}. Best is trial 8 with value: 0.9283743599656226.
# [I 2026-02-08 17:43:17,041] Trial 16 finished with value: 0.9272250334174817 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.29283275493673555, 'max_depth': 5, 'subsample': 0.5023749272242672, 'colsample_bytree': 0.8287464557638382}. Best is trial 8 with value: 0.9283743599656226.
# [I 2026-02-08 17:43:30,193] Trial 17 finished with value: 0.9212080358143299 and parameters: {'model_name': 'lightgbm', 'n_estimators': 18, 'learning_rate': 0.1288576328942723, 'max_depth': 5, 'subsample': 0.5000069219235104, 'colsample_bytree': 0.5288858756017573}. Best is trial 8 with value: 0.9283743599656226.
# [I 2026-02-08 17:43:45,020] Trial 18 finished with value: 0.9227694653914114 and parameters: {'model_name': 'lightgbm', 'n_estimators': 18, 'learning_rate': 0.10828567169470685, 'max_depth': 7, 'subsample': 0.5909513839402117, 'colsample_bytree': 0.5035625018861914}. Best is trial 8 with value: 0.9283743599656226.
# [I 2026-02-08 17:44:03,567] Trial 19 finished with value: 0.9198499243203706 and parameters: {'model_name': 'xgboost', 'n_estimators': 23, 'max_depth': 7, 'learning_rate': 0.1254137804920051, 'subsample': 0.5994436912981675, 'colsample_bytree': 0.6846613569706514}. Best is trial 8 with value: 0.9283743599656226.
# [I 2026-02-08 17:44:23,795] Trial 20 finished with value: 0.926898237617039 and parameters: {'model_name': 'xgboost', 'n_estimators': 23, 'max_depth': 9, 'learning_rate': 0.2514538027004343, 'subsample': 0.7323842677124541, 'colsample_bytree': 0.709560152242356}. Best is trial 8 with value: 0.9283743599656226.
# [I 2026-02-08 17:44:34,750] Trial 21 finished with value: 0.928678437411516 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.25079642752557246, 'max_depth': 9, 'subsample': 0.7323757173742772, 'colsample_bytree': 0.5993965768282279}. Best is trial 21 with value: 0.928678437411516.
# [I 2026-02-08 17:44:52,056] Trial 22 finished with value: 0.9288505090251497 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.2393995757566425, 'max_depth': 7, 'subsample': 0.713366348919713, 'colsample_bytree': 0.9704146600331482}. Best is trial 22 with value: 0.9288505090251497.
# [I 2026-02-08 17:45:03,762] Trial 23 finished with value: 0.928839069550353 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.2525729387026523, 'max_depth': 8, 'subsample': 0.9585594797362924, 'colsample_bytree': 0.5979860341713961}. Best is trial 22 with value: 0.9288505090251497.
# [I 2026-02-08 17:45:19,913] Trial 24 finished with value: 0.9288368652642204 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.24775843187201618, 'max_depth': 8, 'subsample': 0.7317389672841096, 'colsample_bytree': 0.5897410892417546}. Best is trial 22 with value: 0.9288505090251497.
# [I 2026-02-08 17:45:32,878] Trial 25 finished with value: 0.9290854825206454 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.2380936275114841, 'max_depth': 8, 'subsample': 0.7386563518227348, 'colsample_bytree': 0.5836868017188486}. Best is trial 25 with value: 0.9290854825206454.
# [I 2026-02-08 17:45:46,037] Trial 26 finished with value: 0.9248482053000395 and parameters: {'model_name': 'lightgbm', 'n_estimators': 15, 'learning_rate': 0.18156624122254045, 'max_depth': 8, 'subsample': 0.983972898971316, 'colsample_bytree': 0.5855021573239798}. Best is trial 25 with value: 0.9290854825206454.
# [I 2026-02-08 17:45:59,707] Trial 27 finished with value: 0.9262969910137436 and parameters: {'model_name': 'lightgbm', 'n_estimators': 20, 'learning_rate': 0.18391907662945986, 'max_depth': 8, 'subsample': 0.9873215778329848, 'colsample_bytree': 0.7311725261575923}. Best is trial 25 with value: 0.9290854825206454.
# [I 2026-02-08 17:46:13,890] Trial 28 finished with value: 0.9115573091745043 and parameters: {'model_name': 'random_forest', 'n_estimators': 21, 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 5}. Best is trial 25 with value: 0.9290854825206454.
# [I 2026-02-08 17:46:24,222] Trial 29 finished with value: 0.8966689485884493 and parameters: {'model_name': 'random_forest', 'n_estimators': 5, 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 5}. Best is trial 25 with value: 0.9290854825206454.
# [I 2026-02-08 17:47:30,787] Trial 30 finished with value: 0.9189864039800678 and parameters: {'model_name': 'svm', 'C': 0.1916993159225493}. Best is trial 25 with value: 0.9290854825206454.
# [I 2026-02-08 17:47:32,662] Trial 31 finished with value: 0.9192789820399726 and parameters: {'model_name': 'svm', 'C': 0.1483053222863131}. Best is trial 25 with value: 0.9290854825206454.
# [I 2026-02-08 17:48:03,518] Trial 32 finished with value: 0.9286793295803619 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.22869875597149758, 'max_depth': 8, 'subsample': 0.788092064055799, 'colsample_bytree': 0.567378150608786}. Best is trial 25 with value: 0.9290854825206454.
# [I 2026-02-08 17:48:08,047] Trial 33 finished with value: 0.9285343097580724 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.2293325556198566, 'max_depth': 8, 'subsample': 0.78421518916091, 'colsample_bytree': 0.5904568962881142}. Best is trial 25 with value: 0.9290854825206454.
# [I 2026-02-08 17:48:31,743] Trial 34 finished with value: 0.9275341338231141 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.2546206975372296, 'max_depth': 7, 'subsample': 0.700475992513911, 'colsample_bytree': 0.6321556734748118}. Best is trial 25 with value: 0.9290854825206454.
# [I 2026-02-08 17:48:36,056] Trial 35 finished with value: 0.9274680172730511 and parameters: {'model_name': 'lightgbm', 'n_estimators': 23, 'learning_rate': 0.2644548049382946, 'max_depth': 7, 'subsample': 0.6955946047547648, 'colsample_bytree': 0.6344871150940813}. Best is trial 25 with value: 0.9290854825206454.
# [I 2026-02-08 17:49:09,229] Trial 36 finished with value: 0.926233532971291 and parameters: {'model_name': 'xgboost', 'n_estimators': 24, 'max_depth': 8, 'learning_rate': 0.20755044747994636, 'subsample': 0.8560821475377061, 'colsample_bytree': 0.6578603801876455}. Best is trial 25 with value: 0.9290854825206454.
# [I 2026-02-08 17:49:15,283] Trial 37 finished with value: 0.9262604553495164 and parameters: {'model_name': 'xgboost', 'n_estimators': 24, 'max_depth': 8, 'learning_rate': 0.20585643608322496, 'subsample': 0.8587263692925056, 'colsample_bytree': 0.9268362145885144}. Best is trial 25 with value: 0.9290854825206454.
# [I 2026-02-08 17:49:38,289] Trial 38 finished with value: 0.9280971630250385 and parameters: {'model_name': 'lightgbm', 'n_estimators': 29, 'learning_rate': 0.19894974300821638, 'max_depth': 9, 'subsample': 0.7600885709903963, 'colsample_bytree': 0.7573884446203788}. Best is trial 25 with value: 0.9290854825206454.
# [I 2026-02-08 17:49:45,279] Trial 39 finished with value: 0.9278963519298097 and parameters: {'model_name': 'lightgbm', 'n_estimators': 29, 'learning_rate': 0.15451768689140646, 'max_depth': 9, 'subsample': 0.6898703084503104, 'colsample_bytree': 0.558874114994501}. Best is trial 25 with value: 0.9290854825206454.
# [I 2026-02-08 17:50:08,105] Trial 40 finished with value: 0.9122631044030532 and parameters: {'model_name': 'random_forest', 'n_estimators': 26, 'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 3}. Best is trial 25 with value: 0.9290854825206454.
# [I 2026-02-08 17:50:14,075] Trial 41 finished with value: 0.9122631044030532 and parameters: {'model_name': 'random_forest', 'n_estimators': 26, 'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 3}. Best is trial 25 with value: 0.9290854825206454.
# [I 2026-02-08 17:50:36,873] Trial 42 finished with value: 0.9284169281806743 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.2262185111976782, 'max_depth': 8, 'subsample': 0.9281706507036633, 'colsample_bytree': 0.5870325186929457}. Best is trial 25 with value: 0.9290854825206454.
# [I 2026-02-08 17:50:42,610] Trial 43 finished with value: 0.9286826673526661 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.23392656823675512, 'max_depth': 8, 'subsample': 0.9179871355350222, 'colsample_bytree': 0.569549355165819}. Best is trial 25 with value: 0.9290854825206454.
# [I 2026-02-08 17:51:06,768] Trial 44 finished with value: 0.92814890034918 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.26704226115197904, 'max_depth': 7, 'subsample': 0.8053866950392485, 'colsample_bytree': 0.5589691980629321}. Best is trial 25 with value: 0.9290854825206454.
# [I 2026-02-08 17:51:10,816] Trial 45 finished with value: 0.9277166054348974 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.26942742477675125, 'max_depth': 7, 'subsample': 0.9282069419446493, 'colsample_bytree': 0.6148839681640409}. Best is trial 25 with value: 0.9290854825206454.
# [I 2026-02-08 17:51:34,079] Trial 46 finished with value: 0.9278290182020584 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.24433721703512765, 'max_depth': 6, 'subsample': 0.925865445007845, 'colsample_bytree': 0.6192243763121607}. Best is trial 25 with value: 0.9290854825206454.
# [I 2026-02-08 17:51:37,440] Trial 47 finished with value: 0.919203581957791 and parameters: {'model_name': 'lightgbm', 'n_estimators': 15, 'learning_rate': 0.07080345851581, 'max_depth': 6, 'subsample': 0.8948993012110255, 'colsample_bytree': 0.666366555363899}. Best is trial 25 with value: 0.9290854825206454.
# [I 2026-02-08 17:52:01,612] Trial 48 finished with value: 0.9211787763366868 and parameters: {'model_name': 'lightgbm', 'n_estimators': 25, 'learning_rate': 0.06380223226435824, 'max_depth': 6, 'subsample': 0.8768421645005987, 'colsample_bytree': 0.6681340710835221}. Best is trial 25 with value: 0.9290854825206454.
# [I 2026-02-08 17:53:12,043] Trial 49 finished with value: 0.9169144657949944 and parameters: {'model_name': 'svm', 'C': 1.4401134041924883}. Best is trial 25 with value: 0.9290854825206454.
# [LightGBM] [Info] Number of positive: 35224, number of negative: 35224
# [LightGBM] [Info] Total Bins 41588
# [LightGBM] [Info] Number of data points in the train set: 70448, number of used features: 348
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2026-02-08 17:53:24,285] A new study created in memory with name: no-name-04bbd09f-95e8-47f0-b73f-792be23b97ee
# ==============================
#   Fold Externo 3/5
# ==============================
# [I 2026-02-08 17:53:50,730] Trial 1 finished with value: 0.9075849615411326 and parameters: {'model_name': 'random_forest', 'n_estimators': 19, 'max_depth': 7, 'min_samples_split': 8, 'min_samples_leaf': 1}. Best is trial 1 with value: 0.9075849615411326.
# [I 2026-02-08 17:54:20,040] Trial 2 finished with value: 0.9292814093527207 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.2804978397188773, 'max_depth': 7, 'subsample': 0.913380409725316, 'colsample_bytree': 0.5144316540075108}. Best is trial 2 with value: 0.9292814093527207.
# [I 2026-02-08 17:55:05,200] Trial 0 finished with value: 0.9188289505407229 and parameters: {'model_name': 'svm', 'C': 0.6667397806438164}. Best is trial 2 with value: 0.9292814093527207.
# [I 2026-02-08 17:55:33,927] Trial 4 finished with value: 0.926379539501374 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.1211305446601979, 'max_depth': 7, 'subsample': 0.8344206267906266, 'colsample_bytree': 0.7079463386978695}. Best is trial 2 with value: 0.9292814093527207.
# [I 2026-02-08 17:55:56,347] Trial 5 finished with value: 0.8598875883865705 and parameters: {'model_name': 'random_forest', 'n_estimators': 11, 'max_depth': 4, 'min_samples_split': 9, 'min_samples_leaf': 2}. Best is trial 2 with value: 0.9292814093527207.
# [I 2026-02-08 17:56:07,131] Trial 3 finished with value: 0.9187285520696288 and parameters: {'model_name': 'svm', 'C': 0.7452367529788426}. Best is trial 2 with value: 0.9292814093527207.
# [I 2026-02-08 17:56:42,763] Trial 6 finished with value: 0.9176511060505469 and parameters: {'model_name': 'xgboost', 'n_estimators': 28, 'max_depth': 8, 'learning_rate': 0.06705608624306886, 'subsample': 0.563600346611218, 'colsample_bytree': 0.7971710207437563}. Best is trial 2 with value: 0.9292814093527207.
# [I 2026-02-08 17:58:00,447] Trial 8 finished with value: 0.920252157823688 and parameters: {'model_name': 'svm', 'C': 0.14932739594166639}. Best is trial 2 with value: 0.9292814093527207.
# [I 2026-02-08 17:59:04,068] Trial 7 finished with value: 0.9178004451944973 and parameters: {'model_name': 'svm', 'C': 2.8906214907676886}. Best is trial 2 with value: 0.9292814093527207.
# [I 2026-02-08 17:59:30,595] Trial 10 finished with value: 0.9218893944475264 and parameters: {'model_name': 'xgboost', 'n_estimators': 30, 'max_depth': 3, 'learning_rate': 0.2898448841110271, 'subsample': 0.5215144236942196, 'colsample_bytree': 0.5217769471750615}. Best is trial 2 with value: 0.9292814093527207.
# [I 2026-02-08 17:59:58,825] Trial 11 finished with value: 0.9286612503534298 and parameters: {'model_name': 'lightgbm', 'n_estimators': 20, 'learning_rate': 0.2989941797265038, 'max_depth': 9, 'subsample': 0.9562989071625823, 'colsample_bytree': 0.5008666373843806}. Best is trial 2 with value: 0.9292814093527207.
# [I 2026-02-08 18:00:08,956] Trial 9 finished with value: 0.9182416346298706 and parameters: {'model_name': 'svm', 'C': 1.3565722586778821}. Best is trial 2 with value: 0.9292814093527207.
# [I 2026-02-08 18:00:26,580] Trial 12 finished with value: 0.9288807351970562 and parameters: {'model_name': 'lightgbm', 'n_estimators': 20, 'learning_rate': 0.29977530043015804, 'max_depth': 9, 'subsample': 0.9939444590940233, 'colsample_bytree': 0.5238779252068474}. Best is trial 2 with value: 0.9292814093527207.
# [I 2026-02-08 18:00:37,556] Trial 13 finished with value: 0.9289830392024448 and parameters: {'model_name': 'lightgbm', 'n_estimators': 20, 'learning_rate': 0.29288931293050946, 'max_depth': 9, 'subsample': 0.9798843539601191, 'colsample_bytree': 0.5018194224559863}. Best is trial 2 with value: 0.9292814093527207.
# [I 2026-02-08 18:00:53,885] Trial 14 finished with value: 0.9267888846702551 and parameters: {'model_name': 'lightgbm', 'n_estimators': 23, 'learning_rate': 0.22085427409936295, 'max_depth': 5, 'subsample': 0.9773034937370613, 'colsample_bytree': 0.6343408748589185}. Best is trial 2 with value: 0.9292814093527207.
# [I 2026-02-08 18:01:04,543] Trial 15 finished with value: 0.9220512470167445 and parameters: {'model_name': 'lightgbm', 'n_estimators': 12, 'learning_rate': 0.2027781419134711, 'max_depth': 5, 'subsample': 0.8379045858775666, 'colsample_bytree': 0.9946631842657002}. Best is trial 2 with value: 0.9292814093527207.
# [I 2026-02-08 18:01:20,455] Trial 16 finished with value: 0.9256020715801041 and parameters: {'model_name': 'lightgbm', 'n_estimators': 14, 'learning_rate': 0.21393937498002502, 'max_depth': 6, 'subsample': 0.8297218399195382, 'colsample_bytree': 0.9864683737747966}. Best is trial 2 with value: 0.9292814093527207.
# [I 2026-02-08 18:01:30,566] Trial 17 finished with value: 0.919769186120671 and parameters: {'model_name': 'lightgbm', 'n_estimators': 5, 'learning_rate': 0.22552890793420924, 'max_depth': 7, 'subsample': 0.8484700504322562, 'colsample_bytree': 0.6445308807399572}. Best is trial 2 with value: 0.9292814093527207.
# [I 2026-02-08 18:01:45,318] Trial 18 finished with value: 0.9202981372278195 and parameters: {'model_name': 'lightgbm', 'n_estimators': 5, 'learning_rate': 0.24145149666903468, 'max_depth': 8, 'subsample': 0.6827636334289742, 'colsample_bytree': 0.6220942260757004}. Best is trial 2 with value: 0.9292814093527207.
# [I 2026-02-08 18:01:58,867] Trial 19 finished with value: 0.9277380582696951 and parameters: {'model_name': 'lightgbm', 'n_estimators': 24, 'learning_rate': 0.15692617271457748, 'max_depth': 8, 'subsample': 0.7102884536353697, 'colsample_bytree': 0.6044579177453091}. Best is trial 2 with value: 0.9292814093527207.
# [I 2026-02-08 18:02:26,049] Trial 20 finished with value: 0.9258788514758111 and parameters: {'model_name': 'xgboost', 'n_estimators': 24, 'max_depth': 8, 'learning_rate': 0.14721032458279643, 'subsample': 0.9080564045279408, 'colsample_bytree': 0.8421599515968583}. Best is trial 2 with value: 0.9292814093527207.
# [I 2026-02-08 18:02:26,802] Trial 21 finished with value: 0.9047035464352944 and parameters: {'model_name': 'random_forest', 'n_estimators': 16, 'max_depth': 9, 'min_samples_split': 3, 'min_samples_leaf': 5}. Best is trial 2 with value: 0.9292814093527207.
# [I 2026-02-08 18:02:52,716] Trial 22 finished with value: 0.9282783051628861 and parameters: {'model_name': 'lightgbm', 'n_estimators': 16, 'learning_rate': 0.2715621590004048, 'max_depth': 9, 'subsample': 0.9913126017597144, 'colsample_bytree': 0.5513210417662544}. Best is trial 2 with value: 0.9292814093527207.
# [I 2026-02-08 18:02:55,497] Trial 23 finished with value: 0.9291554551962129 and parameters: {'model_name': 'lightgbm', 'n_estimators': 21, 'learning_rate': 0.26502562015126613, 'max_depth': 9, 'subsample': 0.9989075357054835, 'colsample_bytree': 0.5534610150732822}. Best is trial 2 with value: 0.9292814093527207.
# [I 2026-02-08 18:03:19,781] Trial 24 finished with value: 0.9295373121665472 and parameters: {'model_name': 'lightgbm', 'n_estimators': 21, 'learning_rate': 0.2599738023384741, 'max_depth': 9, 'subsample': 0.9225248291760304, 'colsample_bytree': 0.5521074349866103}. Best is trial 24 with value: 0.9295373121665472.
# [I 2026-02-08 18:03:23,705] Trial 25 finished with value: 0.9273716147680316 and parameters: {'model_name': 'lightgbm', 'n_estimators': 22, 'learning_rate': 0.2552146885758199, 'max_depth': 6, 'subsample': 0.9178613480591143, 'colsample_bytree': 0.5756003256873891}. Best is trial 24 with value: 0.9295373121665472.
# [I 2026-02-08 18:03:53,955] Trial 26 finished with value: 0.9278345293792943 and parameters: {'model_name': 'lightgbm', 'n_estimators': 22, 'learning_rate': 0.25465055545245363, 'max_depth': 6, 'subsample': 0.9040899272920513, 'colsample_bytree': 0.5816987733103346}. Best is trial 24 with value: 0.9295373121665472.
# [I 2026-02-08 18:03:58,410] Trial 27 finished with value: 0.9284795545954555 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.18444172997846053, 'max_depth': 7, 'subsample': 0.9052439913177075, 'colsample_bytree': 0.7239828725300153}. Best is trial 24 with value: 0.9295373121665472.
# [I 2026-02-08 18:04:24,748] Trial 28 finished with value: 0.9290102575492453 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.18430861707507748, 'max_depth': 8, 'subsample': 0.8895177119769886, 'colsample_bytree': 0.6806195855731393}. Best is trial 24 with value: 0.9295373121665472.
# [I 2026-02-08 18:04:39,357] Trial 29 finished with value: 0.9112634688234656 and parameters: {'model_name': 'xgboost', 'n_estimators': 30, 'max_depth': 8, 'learning_rate': 0.042507879697453496, 'subsample': 0.7729865303087152, 'colsample_bytree': 0.688660221084336}. Best is trial 24 with value: 0.9295373121665472.
# [I 2026-02-08 18:04:55,169] Trial 30 finished with value: 0.9114735695256808 and parameters: {'model_name': 'random_forest', 'n_estimators': 29, 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 5}. Best is trial 24 with value: 0.9295373121665472.
# [I 2026-02-08 18:05:08,272] Trial 31 finished with value: 0.9079896201897423 and parameters: {'model_name': 'random_forest', 'n_estimators': 18, 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 5}. Best is trial 24 with value: 0.9295373121665472.
# [I 2026-02-08 18:05:23,250] Trial 32 finished with value: 0.9296577297547054 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.2671664005932564, 'max_depth': 9, 'subsample': 0.9353194301278447, 'colsample_bytree': 0.560754106296107}. Best is trial 32 with value: 0.9296577297547054.
# [I 2026-02-08 18:05:37,114] Trial 33 finished with value: 0.9293131301151797 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.2598487921322453, 'max_depth': 8, 'subsample': 0.9342141088546246, 'colsample_bytree': 0.5543846263290498}. Best is trial 32 with value: 0.9296577297547054.
# [I 2026-02-08 18:05:51,826] Trial 34 finished with value: 0.9294257856665474 and parameters: {'model_name': 'lightgbm', 'n_estimators': 25, 'learning_rate': 0.2678728741084556, 'max_depth': 9, 'subsample': 0.949895297284616, 'colsample_bytree': 0.5590604209147872}. Best is trial 32 with value: 0.9296577297547054.
# [I 2026-02-08 18:06:05,648] Trial 35 finished with value: 0.9294782083945575 and parameters: {'model_name': 'lightgbm', 'n_estimators': 25, 'learning_rate': 0.24211203451933833, 'max_depth': 7, 'subsample': 0.9410699516193172, 'colsample_bytree': 0.5604785885351498}. Best is trial 32 with value: 0.9296577297547054.
# [I 2026-02-08 18:06:20,354] Trial 36 finished with value: 0.9294194820199791 and parameters: {'model_name': 'lightgbm', 'n_estimators': 24, 'learning_rate': 0.23952281163039804, 'max_depth': 9, 'subsample': 0.947305000436131, 'colsample_bytree': 0.5861374252172952}. Best is trial 32 with value: 0.9296577297547054.
# [I 2026-02-08 18:06:34,006] Trial 37 finished with value: 0.9294075397904943 and parameters: {'model_name': 'lightgbm', 'n_estimators': 24, 'learning_rate': 0.23703196106197494, 'max_depth': 9, 'subsample': 0.8732256340888376, 'colsample_bytree': 0.6023417075881667}. Best is trial 32 with value: 0.9296577297547054.
# [I 2026-02-08 18:06:48,129] Trial 38 finished with value: 0.9292860449906977 and parameters: {'model_name': 'lightgbm', 'n_estimators': 25, 'learning_rate': 0.23242073922002854, 'max_depth': 7, 'subsample': 0.8818778734662055, 'colsample_bytree': 0.6570166964587899}. Best is trial 32 with value: 0.9296577297547054.
# [I 2026-02-08 18:09:04,053] Trial 39 finished with value: 0.9178692125338371 and parameters: {'model_name': 'svm', 'C': 2.518179683796216}. Best is trial 32 with value: 0.9296577297547054.
# [I 2026-02-08 18:09:25,363] Trial 40 finished with value: 0.917794583713985 and parameters: {'model_name': 'svm', 'C': 2.933202954560278}. Best is trial 32 with value: 0.9296577297547054.
# [I 2026-02-08 18:09:39,401] Trial 41 finished with value: 0.9283692255695716 and parameters: {'model_name': 'xgboost', 'n_estimators': 28, 'max_depth': 7, 'learning_rate': 0.2728145304172487, 'subsample': 0.7838182503503648, 'colsample_bytree': 0.876160107945705}. Best is trial 32 with value: 0.9296577297547054.
# [I 2026-02-08 18:09:53,879] Trial 42 finished with value: 0.9299700892622784 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.24894903003922547, 'max_depth': 9, 'subsample': 0.9590260642100061, 'colsample_bytree': 0.5783210195283013}. Best is trial 42 with value: 0.9299700892622784.
# [I 2026-02-08 18:10:07,380] Trial 43 finished with value: 0.9298283466628284 and parameters: {'model_name': 'lightgbm', 'n_estimators': 23, 'learning_rate': 0.25123094215098163, 'max_depth': 9, 'subsample': 0.9440250644904612, 'colsample_bytree': 0.5806291742879206}. Best is trial 42 with value: 0.9299700892622784.
# [I 2026-02-08 18:10:22,675] Trial 44 finished with value: 0.9302285765031147 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.2780582280305969, 'max_depth': 9, 'subsample': 0.9447921534076492, 'colsample_bytree': 0.5484535479353517}. Best is trial 44 with value: 0.9302285765031147.
# [I 2026-02-08 18:10:35,798] Trial 45 finished with value: 0.927279965480705 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.20003063896349765, 'max_depth': 5, 'subsample': 0.9390048970056499, 'colsample_bytree': 0.5422445997527958}. Best is trial 44 with value: 0.9302285765031147.
# [I 2026-02-08 18:10:51,344] Trial 46 finished with value: 0.9293273195134226 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.2799503960155028, 'max_depth': 9, 'subsample': 0.867487726791349, 'colsample_bytree': 0.5377404027675653}. Best is trial 44 with value: 0.9302285765031147.
# [I 2026-02-08 18:11:09,038] Trial 47 finished with value: 0.9141890305239241 and parameters: {'model_name': 'random_forest', 'n_estimators': 27, 'max_depth': 9, 'min_samples_split': 6, 'min_samples_leaf': 3}. Best is trial 44 with value: 0.9302285765031147.
# [I 2026-02-08 18:11:15,279] Trial 48 finished with value: 0.8591385734848037 and parameters: {'model_name': 'random_forest', 'n_estimators': 22, 'max_depth': 3, 'min_samples_split': 6, 'min_samples_leaf': 3}. Best is trial 44 with value: 0.9302285765031147.
# [I 2026-02-08 18:11:27,367] Trial 49 finished with value: 0.918101356824745 and parameters: {'model_name': 'lightgbm', 'n_estimators': 22, 'learning_rate': 0.10091457945424648, 'max_depth': 3, 'subsample': 0.9628385206819522, 'colsample_bytree': 0.6119460240790717}. Best is trial 44 with value: 0.9302285765031147.
# [LightGBM] [Info] Number of positive: 35224, number of negative: 35224
# [LightGBM] [Info] Total Bins 41696
# [LightGBM] [Info] Number of data points in the train set: 70448, number of used features: 344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2026-02-08 18:11:39,766] A new study created in memory with name: no-name-05fa0030-cd2c-4625-ad87-d412c9c218ca
# ==============================
#   Fold Externo 4/5
# ==============================
# [I 2026-02-08 18:12:05,631] Trial 0 finished with value: 0.8833136143980034 and parameters: {'model_name': 'random_forest', 'n_estimators': 6, 'max_depth': 7, 'min_samples_split': 7, 'min_samples_leaf': 2}. Best is trial 0 with value: 0.8833136143980034.
# [I 2026-02-08 18:12:15,700] Trial 1 finished with value: 0.9235641271212257 and parameters: {'model_name': 'xgboost', 'n_estimators': 13, 'max_depth': 9, 'learning_rate': 0.24723307372423073, 'subsample': 0.9625490594985668, 'colsample_bytree': 0.7594433215244081}. Best is trial 1 with value: 0.9235641271212257.
# [I 2026-02-08 18:12:37,704] Trial 2 finished with value: 0.9202287390301223 and parameters: {'model_name': 'xgboost', 'n_estimators': 19, 'max_depth': 6, 'learning_rate': 0.1801156064192637, 'subsample': 0.58603953463675, 'colsample_bytree': 0.8650442046566963}. Best is trial 1 with value: 0.9235641271212257.
# [I 2026-02-08 18:13:09,085] Trial 4 finished with value: 0.920491397188575 and parameters: {'model_name': 'xgboost', 'n_estimators': 12, 'max_depth': 7, 'learning_rate': 0.22630693245180689, 'subsample': 0.8154010541055581, 'colsample_bytree': 0.9592945512296034}. Best is trial 1 with value: 0.9235641271212257.
# [I 2026-02-08 18:13:41,614] Trial 5 finished with value: 0.9120859144195411 and parameters: {'model_name': 'xgboost', 'n_estimators': 13, 'max_depth': 9, 'learning_rate': 0.11472026823712114, 'subsample': 0.8342169782867042, 'colsample_bytree': 0.631326267720695}. Best is trial 1 with value: 0.9235641271212257.
# [I 2026-02-08 18:14:12,930] Trial 6 finished with value: 0.9266731106254181 and parameters: {'model_name': 'xgboost', 'n_estimators': 23, 'max_depth': 7, 'learning_rate': 0.2524411730391089, 'subsample': 0.5358692307634456, 'colsample_bytree': 0.5461557166891753}. Best is trial 6 with value: 0.9266731106254181.
# [I 2026-02-08 18:14:13,577] Trial 3 finished with value: 0.91982052829182 and parameters: {'model_name': 'svm', 'C': 1.08397250041457}. Best is trial 6 with value: 0.9266731106254181.
# [I 2026-02-08 18:14:39,635] Trial 8 finished with value: 0.8994864407551902 and parameters: {'model_name': 'xgboost', 'n_estimators': 6, 'max_depth': 7, 'learning_rate': 0.16060616265703231, 'subsample': 0.7203665603158463, 'colsample_bytree': 0.8155888556864246}. Best is trial 6 with value: 0.9266731106254181.
# [I 2026-02-08 18:15:03,456] Trial 9 finished with value: 0.8973355035262206 and parameters: {'model_name': 'random_forest', 'n_estimators': 16, 'max_depth': 6, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 6 with value: 0.9266731106254181.
# ...
# [I 2026-02-08 18:28:06,901] Trial 48 finished with value: 0.9294926036313677 and parameters: {'model_name': 'lightgbm', 'n_estimators': 29, 'learning_rate': 0.22925939817006985, 'max_depth': 7, 'subsample': 0.6443282980335658, 'colsample_bytree': 0.6049069426883715}. Best is trial 42 with value: 0.9296136491804076.
# [I 2026-02-08 18:28:14,513] Trial 49 finished with value: 0.9267543237401324 and parameters: {'model_name': 'lightgbm', 'n_estimators': 15, 'learning_rate': 0.2384577933671736, 'max_depth': 7, 'subsample': 0.6494144623155385, 'colsample_bytree': 0.7628273921253567}. Best is trial 42 with value: 0.9296136491804076.
# [LightGBM] [Info] Number of positive: 35224, number of negative: 35224
# [LightGBM] [Info] Total Bins 41891
# [LightGBM] [Info] Number of data points in the train set: 70448, number of used features: 343
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2026-02-08 18:28:26,585] A new study created in memory with name: no-name-3f36cc8a-7f6b-40bf-bc10-744ba1879335
# ==============================
#   Fold Externo 5/5
# ==============================
# [I 2026-02-08 18:28:55,314] Trial 1 finished with value: 0.9202630477886068 and parameters: {'model_name': 'xgboost', 'n_estimators': 18, 'max_depth': 4, 'learning_rate': 0.26545146761469224, 'subsample': 0.5777384568152666, 'colsample_bytree': 0.847670545806308}. Best is trial 1 with value: 0.9202630477886068.
# [I 2026-02-08 18:30:09,910] Trial 0 finished with value: 0.9185279004997507 and parameters: {'model_name': 'svm', 'C': 0.7248630399744238}. Best is trial 1 with value: 0.9202630477886068.
# [I 2026-02-08 18:30:38,283] Trial 2 finished with value: 0.9185249021848237 and parameters: {'model_name': 'svm', 'C': 0.7266229565019803}. Best is trial 1 with value: 0.9202630477886068.
# [I 2026-02-08 18:30:38,351] Trial 3 finished with value: 0.929812157483286 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.2044682467443756, 'max_depth': 7, 'subsample': 0.9495661600125441, 'colsample_bytree': 0.7176431670102377}. Best is trial 3 with value: 0.929812157483286.
# [I 2026-02-08 18:31:02,860] Trial 5 finished with value: 0.9052206285673728 and parameters: {'model_name': 'xgboost', 'n_estimators': 9, 'max_depth': 4, 'learning_rate': 0.19995898394640205, 'subsample': 0.7568135139912372, 'colsample_bytree': 0.7970666906032383}. Best is trial 3 with value: 0.929812157483286.
# [I 2026-02-08 18:31:06,067] Trial 4 finished with value: 0.92597213055334 and parameters: {'model_name': 'lightgbm', 'n_estimators': 15, 'learning_rate': 0.18542854100147402, 'max_depth': 9, 'subsample': 0.5448670369547866, 'colsample_bytree': 0.9910820442095742}. Best is trial 3 with value: 0.929812157483286.
# [I 2026-02-08 18:31:33,019] Trial 7 finished with value: 0.9133242452551863 and parameters: {'model_name': 'xgboost', 'n_estimators': 8, 'max_depth': 6, 'learning_rate': 0.2692399234720226, 'subsample': 0.8839854169366659, 'colsample_bytree': 0.8894828249861926}. Best is trial 3 with value: 0.929812157483286.
# [I 2026-02-08 18:32:32,961] Trial 6 finished with value: 0.9190147728352205 and parameters: {'model_name': 'svm', 'C': 0.43786792597059043}. Best is trial 3 with value: 0.929812157483286.
# [I 2026-02-08 18:32:57,758] Trial 9 finished with value: 0.9090532938364314 and parameters: {'model_name': 'xgboost', 'n_estimators': 11, 'max_depth': 3, 'learning_rate': 0.21449815236551667, 'subsample': 0.6621728897344072, 'colsample_bytree': 0.7729368702410604}. Best is trial 3 with value: 0.929812157483286.
# [I 2026-02-08 18:33:22,538] Trial 10 finished with value: 0.9088587222666891 and parameters: {'model_name': 'random_forest', 'n_estimators': 10, 'max_depth': 9, 'min_samples_split': 10, 'min_samples_leaf': 3}. Best is trial 3 with value: 0.929812157483286.
# [I 2026-02-08 18:33:53,059] Trial 11 finished with value: 0.9242629502177563 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.06824423473858184, 'max_depth': 7, 'subsample': 0.9760306554235789, 'colsample_bytree': 0.5225914421599475}. Best is trial 3 with value: 0.929812157483286.
# [I 2026-02-08 18:34:11,343] Trial 8 finished with value: 0.9176293859376071 and parameters: {'model_name': 'svm', 'C': 2.7748148707492892}. Best is trial 3 with value: 0.929812157483286.
# [I 2026-02-08 18:34:20,562] Trial 12 finished with value: 0.9251029875957529 and parameters: {'model_name': 'lightgbm', 'n_estimators': 20, 'learning_rate': 0.12092339837583346, 'max_depth': 9, 'subsample': 0.5070657409226713, 'colsample_bytree': 0.9866342573458526}. Best is trial 3 with value: 0.929812157483286.
# [I 2026-02-08 18:34:39,406] Trial 13 finished with value: 0.9260577196937817 and parameters: {'model_name': 'lightgbm', 'n_estimators': 21, 'learning_rate': 0.13030741623099762, 'max_depth': 9, 'subsample': 0.5112954475338216, 'colsample_bytree': 0.60301286210437}. Best is trial 3 with value: 0.929812157483286.
# [I 2026-02-08 18:34:48,098] Trial 14 finished with value: 0.9277491128155416 and parameters: {'model_name': 'lightgbm', 'n_estimators': 25, 'learning_rate': 0.16668443183259077, 'max_depth': 7, 'subsample': 0.8032843920526259, 'colsample_bytree': 0.6350639878692318}. Best is trial 3 with value: 0.929812157483286.
# [I 2026-02-08 18:35:08,461] Trial 15 finished with value: 0.925966867556648 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.11272370744531279, 'max_depth': 7, 'subsample': 0.802634886529447, 'colsample_bytree': 0.6105049866243746}. Best is trial 3 with value: 0.929812157483286.
# [I 2026-02-08 18:35:15,891] Trial 16 finished with value: 0.9227310457435381 and parameters: {'model_name': 'lightgbm', 'n_estimators': 29, 'learning_rate': 0.04957799708138384, 'max_depth': 7, 'subsample': 0.8434489082087181, 'colsample_bytree': 0.6633866295042443}. Best is trial 3 with value: 0.929812157483286.
# [I 2026-02-08 18:35:37,524] Trial 17 finished with value: 0.9118937326196647 and parameters: {'model_name': 'random_forest', 'n_estimators': 25, 'max_depth': 7, 'min_samples_split': 2, 'min_samples_leaf': 5}. Best is trial 3 with value: 0.929812157483286.
# [I 2026-02-08 18:35:41,471] Trial 18 finished with value: 0.905275342229085 and parameters: {'model_name': 'random_forest', 'n_estimators': 24, 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.929812157483286.
# [I 2026-02-08 18:36:04,177] Trial 19 finished with value: 0.9271651756586031 and parameters: {'model_name': 'lightgbm', 'n_estimators': 24, 'learning_rate': 0.17086135527511645, 'max_depth': 6, 'subsample': 0.9398469216405019, 'colsample_bytree': 0.7039873458275816}. Best is trial 3 with value: 0.929812157483286.
# [I 2026-02-08 18:36:08,485] Trial 20 finished with value: 0.9252130064485055 and parameters: {'model_name': 'lightgbm', 'n_estimators': 23, 'learning_rate': 0.17127579445520788, 'max_depth': 5, 'subsample': 0.9786396560688271, 'colsample_bytree': 0.7026203443780213}. Best is trial 3 with value: 0.929812157483286.
# [I 2026-02-08 18:36:30,558] Trial 21 finished with value: 0.9261833450078605 and parameters: {'model_name': 'lightgbm', 'n_estimators': 14, 'learning_rate': 0.23439980043956943, 'max_depth': 8, 'subsample': 0.6717269386541376, 'colsample_bytree': 0.501005224988061}. Best is trial 3 with value: 0.929812157483286.
# [I 2026-02-08 18:36:35,917] Trial 22 finished with value: 0.92945879622939 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.22989977901719916, 'max_depth': 6, 'subsample': 0.9128820734889509, 'colsample_bytree': 0.7007707266851354}. Best is trial 3 with value: 0.929812157483286.
# [I 2026-02-08 18:36:58,835] Trial 23 finished with value: 0.9270204203996726 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.1544630312643261, 'max_depth': 6, 'subsample': 0.9211929768395251, 'colsample_bytree': 0.7004556211376065}. Best is trial 3 with value: 0.929812157483286.
# [I 2026-02-08 18:37:03,932] Trial 24 finished with value: 0.9296912337027248 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.231200144977265, 'max_depth': 8, 'subsample': 0.9064646431905968, 'colsample_bytree': 0.6342923103982657}. Best is trial 3 with value: 0.929812157483286.
# [I 2026-02-08 18:37:27,880] Trial 25 finished with value: 0.9297385388554694 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.23606149362365542, 'max_depth': 8, 'subsample': 0.86437623588005, 'colsample_bytree': 0.6350899565935384}. Best is trial 3 with value: 0.929812157483286.
# [I 2026-02-08 18:37:32,822] Trial 26 finished with value: 0.9290992515780102 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.29967681747617353, 'max_depth': 8, 'subsample': 0.8863043552963814, 'colsample_bytree': 0.5640025282653565}. Best is trial 3 with value: 0.929812157483286.
# [I 2026-02-08 18:37:57,011] Trial 27 finished with value: 0.9295059897483102 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.28242616304373186, 'max_depth': 8, 'subsample': 0.8472150375914052, 'colsample_bytree': 0.5763490942949635}. Best is trial 3 with value: 0.929812157483286.
# [I 2026-02-08 18:38:01,755] Trial 28 finished with value: 0.9291666345618017 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.2533468239271849, 'max_depth': 8, 'subsample': 0.9971052122447908, 'colsample_bytree': 0.570954219387207}. Best is trial 3 with value: 0.929812157483286.
# [I 2026-02-08 18:38:25,275] Trial 29 finished with value: 0.9126196964626018 and parameters: {'model_name': 'random_forest', 'n_estimators': 21, 'max_depth': 8, 'min_samples_split': 8, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.929812157483286.
# [I 2026-02-08 18:38:30,120] Trial 30 finished with value: 0.9122766412956375 and parameters: {'model_name': 'random_forest', 'n_estimators': 21, 'max_depth': 8, 'min_samples_split': 8, 'min_samples_leaf': 5}. Best is trial 3 with value: 0.929812157483286.
# [I 2026-02-08 18:38:58,187] Trial 32 finished with value: 0.929372941760306 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.2966142112680346, 'max_depth': 8, 'subsample': 0.8668593618109329, 'colsample_bytree': 0.6483440255550466}. Best is trial 3 with value: 0.929812157483286.
# [I 2026-02-08 18:39:23,256] Trial 33 finished with value: 0.918505358428949 and parameters: {'model_name': 'lightgbm', 'n_estimators': 5, 'learning_rate': 0.2412687049168118, 'max_depth': 7, 'subsample': 0.8154806634321698, 'colsample_bytree': 0.5606753401556869}. Best is trial 3 with value: 0.929812157483286.
# [I 2026-02-08 18:41:04,893] Trial 31 finished with value: 0.9176831833247036 and parameters: {'model_name': 'svm', 'C': 2.480129895365118}. Best is trial 3 with value: 0.929812157483286.
# [I 2026-02-08 18:41:33,415] Trial 35 finished with value: 0.9295890739349364 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.2093261933332225, 'max_depth': 8, 'subsample': 0.9484139837173328, 'colsample_bytree': 0.7356032700766421}. Best is trial 3 with value: 0.929812157483286.
# [I 2026-02-08 18:41:59,071] Trial 34 finished with value: 0.9177039275586362 and parameters: {'model_name': 'svm', 'C': 2.3724810985340867}. Best is trial 3 with value: 0.929812157483286.
# [I 2026-02-08 18:42:14,934] Trial 36 finished with value: 0.9288803268408797 and parameters: {'model_name': 'xgboost', 'n_estimators': 28, 'max_depth': 9, 'learning_rate': 0.20750050916823104, 'subsample': 0.950289058172299, 'colsample_bytree': 0.7556148777410804}. Best is trial 3 with value: 0.929812157483286.
# [I 2026-02-08 18:42:39,823] Trial 37 finished with value: 0.9288296315344713 and parameters: {'model_name': 'xgboost', 'n_estimators': 28, 'max_depth': 9, 'learning_rate': 0.21143426652666641, 'subsample': 0.9395783517104479, 'colsample_bytree': 0.7432643275143785}. Best is trial 3 with value: 0.929812157483286.
# [I 2026-02-08 18:42:43,063] Trial 38 finished with value: 0.9276459254377668 and parameters: {'model_name': 'lightgbm', 'n_estimators': 18, 'learning_rate': 0.22143098523893734, 'max_depth': 8, 'subsample': 0.9123355183502301, 'colsample_bytree': 0.8106965937423175}. Best is trial 3 with value: 0.929812157483286.
# [I 2026-02-08 18:43:07,446] Trial 39 finished with value: 0.9299648115290466 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.22999856982973255, 'max_depth': 8, 'subsample': 0.893434530411553, 'colsample_bytree': 0.6825115504902691}. Best is trial 39 with value: 0.9299648115290466.
# [I 2026-02-08 18:43:09,621] Trial 40 finished with value: 0.9224086709445212 and parameters: {'model_name': 'lightgbm', 'n_estimators': 15, 'learning_rate': 0.19414777071276237, 'max_depth': 5, 'subsample': 0.9687356188544167, 'colsample_bytree': 0.6746843318252576}. Best is trial 39 with value: 0.9299648115290466.
# [I 2026-02-08 18:43:37,691] Trial 42 finished with value: 0.9299050043922946 and parameters: {'model_name': 'lightgbm', 'n_estimators': 23, 'learning_rate': 0.25118431360447135, 'max_depth': 8, 'subsample': 0.8942072292103078, 'colsample_bytree': 0.7322006259928424}. Best is trial 39 with value: 0.9299648115290466.
# [I 2026-02-08 18:44:05,268] Trial 43 finished with value: 0.9297843031010649 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.2566628660390823, 'max_depth': 7, 'subsample': 0.8928120455141633, 'colsample_bytree': 0.6289654391887742}. Best is trial 39 with value: 0.9299648115290466.
# [I 2026-02-08 18:44:32,772] Trial 44 finished with value: 0.9291212122523412 and parameters: {'model_name': 'lightgbm', 'n_estimators': 23, 'learning_rate': 0.2623981464824445, 'max_depth': 7, 'subsample': 0.8399891287794347, 'colsample_bytree': 0.6775325687567907}. Best is trial 39 with value: 0.9299648115290466.
# [I 2026-02-08 18:45:00,683] Trial 45 finished with value: 0.9293765642102839 and parameters: {'model_name': 'lightgbm', 'n_estimators': 25, 'learning_rate': 0.24996508531476727, 'max_depth': 7, 'subsample': 0.7528256328393126, 'colsample_bytree': 0.7314673512426142}. Best is trial 39 with value: 0.9299648115290466.
# [I 2026-02-08 18:45:14,274] Trial 41 finished with value: 0.9179554935745324 and parameters: {'model_name': 'svm', 'C': 1.52072469315448}. Best is trial 39 with value: 0.9299648115290466.
# [I 2026-02-08 18:45:47,193] Trial 47 finished with value: 0.9279481988196331 and parameters: {'model_name': 'xgboost', 'n_estimators': 23, 'max_depth': 7, 'learning_rate': 0.2716169007715009, 'subsample': 0.8603737328709135, 'colsample_bytree': 0.8421813364598543}. Best is trial 39 with value: 0.9299648115290466.
# [I 2026-02-08 18:46:15,396] Trial 48 finished with value: 0.9294957618241423 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.24910925257265912, 'max_depth': 9, 'subsample': 0.8907413683135316, 'colsample_bytree': 0.6237879022023858}. Best is trial 39 with value: 0.9299648115290466.
# [I 2026-02-08 18:46:40,917] Trial 49 finished with value: 0.924185054212185 and parameters: {'model_name': 'lightgbm', 'n_estimators': 19, 'learning_rate': 0.2790805735037601, 'max_depth': 3, 'subsample': 0.7056436002330381, 'colsample_bytree': 0.7819920021258181}. Best is trial 39 with value: 0.9299648115290466.
# [I 2026-02-08 18:47:01,123] Trial 46 finished with value: 0.917933106012739 and parameters: {'model_name': 'svm', 'C': 1.5748303878626122}. Best is trial 39 with value: 0.9299648115290466.
# [LightGBM] [Info] Number of positive: 35224, number of negative: 35224
# [LightGBM] [Info] Total Bins 41571
# [LightGBM] [Info] Number of data points in the train set: 70448, number of used features: 343
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000

# %% [markdown]
# #### Conferir checkpoints intermediarios

# %% [markdown]
# Consolida os resultados da validação cruzada externa em um DataFrame,
# salva o resumo em formato Parquet e carrega os logs das trials do Optuna
# para inspeção e análise do processo de otimização.

# %%
df_results=pd.DataFrame(df_results)
display(df_results)
# Out:
#    fold best_model       auc  accuracy        f1    recall  precision  \
# 0     1   lightgbm  0.927729  0.923698  0.790012  0.713899   0.884293
# 1     2   lightgbm  0.934901  0.921974  0.788490  0.723375   0.866486
# 2     3   lightgbm  0.930093  0.920795  0.784604  0.717509   0.865542
# 3     4   lightgbm  0.930426  0.918254  0.775143  0.700812   0.867113
# 4     5   lightgbm  0.931398  0.923244  0.791420  0.724278   0.872283
#
#                                      hyperparameters  \
# 0  {'model_name': 'lightgbm', 'n_estimators': 30,...
# 1  {'model_name': 'lightgbm', 'n_estimators': 27,...
# 2  {'model_name': 'lightgbm', 'n_estimators': 27,...
# 3  {'model_name': 'lightgbm', 'n_estimators': 29,...
# 4  {'model_name': 'lightgbm', 'n_estimators': 26,...
#
#                                  checkpoint_path  train_time_seconds  \
# 0  checkpoints_best_models/best_model_fold_1.pkl           11.875103
# 1  checkpoints_best_models/best_model_fold_2.pkl           11.883286
# 2  checkpoints_best_models/best_model_fold_3.pkl           12.042369
# 3  checkpoints_best_models/best_model_fold_4.pkl           11.492089
# 4  checkpoints_best_models/best_model_fold_5.pkl           10.899890
#
#                  trials_log_path
# 0  log_opt/trials_log_fold_1.csv
# 1  log_opt/trials_log_fold_2.csv
# 2  log_opt/trials_log_fold_3.csv
# 3  log_opt/trials_log_fold_4.csv
# 4  log_opt/trials_log_fold_5.csv

# %%
df_results.to_parquet('df_results.parquet')

# %% [markdown]
# Carregando o pkl

# %%
import joblib

modelo = joblib.load("checkpoints_best_models/best_model_fold_1.pkl")

# %%
modelo
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['NU_IDADE_N',
#                                                    'baixa_escolaridade',
#                                                    'raca_vulneravel',
#                                                    'faixa_vulneravel',
#                                                    'vulnerabilidade_social',
#                                                    'mes_sintomas',
#                                                    'periodo_chuvoso']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy...
#                                                    'CLI_PANTUR', 'CLI_VOMITO',
#                                                    'CLI_DIARRE', 'CLI_ICTERI',
#                                                    'CLI_RENAL', 'CLI_RESPIR',
#                                                    'CLI_CARDIA', 'CLI_HEMOPU', ...])])),
#                 ('smote', SMOTE(random_state=42)),
#                 ('model',
#                  LGBMClassifier(colsample_bytree=0.5023503925350862,
#                                 device='cpu', force_col_wise=True,
#                                 is_unbalance=True,
#                                 learning_rate=0.2509336946488207, max_depth=8,
#                                 n_estimators=30, random_state=42,
#                                 subsample=0.7240563986296447))])

# %%
modelo.named_steps["preprocessor"].get_feature_names_out()
# Out:
# array(['num__NU_IDADE_N', 'num__baixa_escolaridade',
#        'num__raca_vulneravel', ..., 'cat__estacao_Outono',
#        'cat__estacao_Primavera', 'cat__estacao_Verão'], dtype=object)

# %%
modelo.predict(X_data.iloc[-10:])
# Out:
# array([1, 1, 0, 0, 1, 1, 1, 0, 1, 1])

# %% [markdown]
# ## Avaliação de desempenho e custo computacional
#
# Nesta seção são avaliados os modelos selecionados ao longo dos folds da validação cruzada externa,
# considerando simultaneamente **qualidade preditiva** e **custo computacional**.
# Essa análise conjunta é fundamental para evitar escolhas baseadas apenas em desempenho,
# desconsiderando viabilidade prática de treinamento e manutenção do modelo.
#
# ### Métricas de desempenho preditivo
#
# O desempenho dos modelos é avaliado por meio de múltiplas métricas,
# permitindo uma análise abrangente do comportamento preditivo:
#
# - **ROC-AUC (OvR, weighted)**: métrica principal de comparação, pois avalia a capacidade de separação entre classes
# em cenários multiclasse e desbalanceados, utilizando probabilidades preditas.
# - **Accuracy**: fornece uma visão global de acerto, mas pode ser influenciada por classes majoritárias.
# - **F1-score (weighted)**: equilibra precisão e recall, sendo mais informativo quando há assimetria entre classes.
# - **Recall (weighted)**: mede a capacidade do modelo em identificar corretamente instâncias relevantes,
# importante em contextos onde falsos negativos possuem maior custo.
# - **Precision (weighted)**: avalia a confiabilidade das predições positivas,
# sendo relevante quando falsos positivos impactam decisões downstream.
#
# A análise por fold permite verificar não apenas o valor médio das métricas,
# mas também sua **estabilidade**, reduzindo o risco de overfitting a uma partição específica dos dados.

# %%
def read_and_consolidate_optuna_logs(
    log_dir: str = "log_opt",
    pattern: str = "trials_log_fold_*.csv",
    fold_col_name: str = "outer_fold",
    keep_only_complete: bool = False,
) -> pd.DataFrame:
    """
    Lê todos os arquivos de log do Optuna (1 por fold) e consolida em um único DataFrame.

    Espera arquivos no formato: trials_log_fold_{k}.csv (gerados por dump_trials).

    Parâmetros
    ----------
    log_dir : str
        Diretório onde os logs estão salvos.
    pattern : str
        Padrão dos arquivos dentro do log_dir.
    fold_col_name : str
        Nome da coluna que será criada para identificar o fold externo.
    keep_only_complete : bool
        Se True, mantém apenas trials com state == 'COMPLETE' (quando existir essa coluna).

    Retorna
    -------
    pd.DataFrame
        DataFrame consolidado com colunas originais + coluna de fold.
    """
    path_pattern = os.path.join(log_dir, pattern)
    files = sorted(glob.glob(path_pattern))

    if not files:
        raise FileNotFoundError(f"Nenhum arquivo encontrado em: {path_pattern}")

    dfs = []
    for fp in files:
        df = pd.read_csv(fp)

        # Extrai fold do nome do arquivo (ex.: trials_log_fold_3.csv -> 3)
        m = re.search(r"fold_(\d+)", os.path.basename(fp))
        fold = int(m.group(1)) if m else None

        df[fold_col_name] = fold
        df["source_file"] = os.path.basename(fp)


        # Normaliza duration se estiver como string do tipo "0 days 00:00:12.345"
        if "duration" in df.columns:
            try:
                df["duration"] = pd.to_timedelta(df["duration"])
                df["duration_seconds"] = df["duration"].dt.total_seconds()
            except Exception:
                pass

        dfs.append(df)

    df_all = pd.concat(dfs, ignore_index=True)

    # Ordenação útil (se existir)
    sort_cols = [c for c in [fold_col_name, "number"] if c in df_all.columns]
    if sort_cols:
        df_all = df_all.sort_values(sort_cols).reset_index(drop=True)

    return df_all


df_metrics = read_and_consolidate_optuna_logs(log_dir="log_opt", keep_only_complete=True)

# 2. Basic overview
print("=== Shape of DataFrame ===")
print(df_metrics.shape)

display(df_metrics)
# Out:
# === Shape of DataFrame ===
# (250, 16)
#      number     value  params_C  params_colsample_bytree  \
# 0         0  0.902987  1.937640                      NaN
# 1         1  0.913791       NaN                 0.597656
# 2         2  0.872469       NaN                      NaN
# 3         3  0.918423       NaN                 0.732875
# 4         4  0.903050  1.774259                      NaN
# ..      ...       ...       ...                      ...
# 245      45  0.923744       NaN                 0.686037
# 246      46  0.923039       NaN                 0.821371
# 247      47  0.911751       NaN                 0.844710
# 248      48  0.892001       NaN                      NaN
# 249      49  0.888393       NaN                      NaN
#
#      params_learning_rate  params_max_depth  params_min_samples_leaf  \
# 0                     NaN               NaN                      NaN
# 1                0.274162               5.0                      NaN
# 2                     NaN               3.0                      3.0
# 3                0.254940               7.0                      NaN
# 4                     NaN               NaN                      NaN
# ..                    ...               ...                      ...
# 245              0.267563               9.0                      NaN
# 246              0.268063               9.0                      NaN
# 247              0.111253               8.0                      NaN
# 248                   NaN               9.0                      3.0
# 249                   NaN               9.0                      3.0
#
#      params_min_samples_split params_model_name  params_n_estimators  \
# 0                         NaN               svm                  NaN
# 1                         NaN          lightgbm                  5.0
# 2                         5.0     random_forest                  9.0
# 3                         NaN          lightgbm                  6.0
# 4                         NaN               svm                  NaN
# ..                        ...               ...                  ...
# 245                       NaN          lightgbm                 22.0
# 246                       NaN          lightgbm                 22.0
# 247                       NaN          lightgbm                 16.0
# 248                       6.0     random_forest                 21.0
# 249                       6.0     random_forest                 18.0
#
#      params_subsample     state               duration  outer_fold  \
# 0                 NaN    PRUNED 0 days 00:00:26.320657           1
# 1            0.934180  COMPLETE 0 days 00:00:06.163832           1
# 2                 NaN    PRUNED 0 days 00:00:03.508771           1
# 3            0.714496  COMPLETE 0 days 00:00:07.972074           1
# 4                 NaN    PRUNED 0 days 00:00:36.880087           1
# ..                ...       ...                    ...         ...
# 245          0.630674  COMPLETE 0 days 00:00:07.385986           5
# 246          0.616913  COMPLETE 0 days 00:00:09.302671           5
# 247          0.621377    PRUNED 0 days 00:00:06.005342           5
# 248               NaN    PRUNED 0 days 00:00:06.341821           5
# 249               NaN    PRUNED 0 days 00:00:04.829168           5
#
#                source_file  duration_seconds
# 0    trials_log_fold_1.csv         26.320657
# 1    trials_log_fold_1.csv          6.163832
# 2    trials_log_fold_1.csv          3.508771
# 3    trials_log_fold_1.csv          7.972074
# 4    trials_log_fold_1.csv         36.880087
# ..                     ...               ...
# 245  trials_log_fold_5.csv          7.385986
# 246  trials_log_fold_5.csv          9.302671
# 247  trials_log_fold_5.csv          6.005342
# 248  trials_log_fold_5.csv          6.341821
# 249  trials_log_fold_5.csv          4.829168
#
# [250 rows x 16 columns]

# %%
# Total de trials por modelo
total_trials = (df_metrics.groupby("params_model_name").size().reset_index(name="total_trials"))

plt.figure(figsize=(8, 6))
sns.barplot(data=total_trials,x="params_model_name",y="total_trials",)
plt.title("Total de tentativas por modelo")
plt.xlabel("Modelo")
plt.ylabel("Tentativas")
plt.tight_layout()
plt.show()

# %%
# Gráfico das tentativas de modelos completas e abortadas
counts_state = df_metrics.groupby(["params_model_name", "state"]).size().reset_index(name="count")

plt.figure(figsize=(8, 6))
sns.barplot(data=counts_state,x="params_model_name",y="count",hue="state",)
plt.title("Resultado das tentativas entre Pruned e Complete")
plt.xlabel("Modelo")
plt.ylabel("Número de tentativas")
plt.tight_layout()
plt.show()

# %%
# Distribuição de performance (value) por modelo
plt.figure(figsize=(8, 6))
sns.boxplot(data=df_metrics, x="params_model_name", y="value")
plt.title("Desempenho por modelo")
plt.xlabel("Modelo")
plt.ylabel("Área por baixo da curva ROC (AUC)")
plt.tight_layout()
plt.show()

# %%
# Duração média de treino por modelo
df_metrics["duration_sec"] = pd.to_timedelta(df_metrics["duration"]).dt.total_seconds()
mean_duration = df_metrics.groupby("params_model_name")["duration_sec"].mean().reset_index()

# Distribuição do tempo de processamento por modelo

plt.figure(figsize=(8, 6))
sns.boxplot(data=df_metrics, x="params_model_name", y="duration_sec")
plt.title("Média do tempo de treinamento por modelo")
plt.xlabel("Modelo")
plt.ylabel("Segundos")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Treinamento do modelo final

# %%
df_hyper =pd.DataFrame(df_results['hyperparameters'].to_list())
df_hyper
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [12], line 1
# ----> 1 df_hyper =pd.DataFrame(df_results['hyperparameters'].to_list())
#       2 df_hyper
#
# NameError: name 'df_results' is not defined

# %%
final_params=df_hyper.iloc[:,1:].median().to_dict()
final_params
# Out:
# {'n_estimators': 27.0,
#  'learning_rate': 0.2380936275114841,
#  'max_depth': 8.0,
#  'subsample': 0.7386563518227348,
#  'colsample_bytree': 0.5836868017188486}
# {'n_estimators': 27.0,
#  'learning_rate': 0.2380936275114841,
#  'max_depth': 8.0,
#  'subsample': 0.7386563518227348,
#  'colsample_bytree': 0.5836868017188486}

# %%
def cast_params(params: dict) -> dict:
    p = dict(params)  # cópia

    # chaves que devem ser int no LightGBM
    int_keys = {
        "n_estimators", "num_iterations",
        "max_depth", "num_leaves",
        "min_child_samples", "min_data_in_leaf",
        "max_bin",
        "bagging_freq",
    }

    for k in list(p.keys()):
        if k in int_keys and p[k] is not None and not (isinstance(p[k], bool)):
            p[k] = int(round(float(p[k])))

    # max_depth: LightGBM aceita -1 como "sem limite"
    if "max_depth" in p and p["max_depth"] is not None:
        p["max_depth"] = int(p["max_depth"])

    return p

final_params = cast_params(final_params)
final_params
# Out:
# {'n_estimators': 27,
#  'learning_rate': 0.2380936275114841,
#  'max_depth': 8,
#  'subsample': 0.7386563518227348,
#  'colsample_bytree': 0.5836868017188486}
# {'n_estimators': 27,
#  'learning_rate': 0.2380936275114841,
#  'max_depth': 8,
#  'subsample': 0.7386563518227348,
#  'colsample_bytree': 0.5836868017188486}

# %%
# Dicionário base para reconstrução
models = {
    'RandomForest': RandomForestClassifier(random_state=42),
    'XGBoost': xgb.XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42),
    'LightGBM': lgb.LGBMClassifier(random_state=42),
    'SVM': CalibratedClassifierCV(LinearSVC( random_state=42))
}

# %%
# Reconstruir modelo
final_model = models['LightGBM']
final_model.set_params(**final_params)

cat_cols, num_cols = get_feature_types(X_data)

final_pipeline = build_pipeline(final_model, cat_cols, num_cols)

# %% [markdown]
# ### Avaliando modelo final

# %% [markdown]
# ## Interpretabilidade: importância de variáveis após pré-processamento (OHE) e mapeamento para colunas originais
#
# Modelos treinados sobre pipelines com `ColumnTransformer` e `OneHotEncoder` operam em um espaço de features
# expandido (múltiplas colunas por variável categórica). Para manter interpretabilidade, esta seção:
# 1) recupera os nomes finais das features no espaço transformado,
# 2) extrai uma medida de importância/coeficiente do modelo treinado,
# 3) mapeia as features transformadas de volta para as variáveis originais,
# 4) consolida a importância no nível da coluna original.
#
# Isso permite reportar resultados em termos das variáveis do dataset original, facilitando comunicação e análise.

# %% [markdown]
# ### Extração de nomes das features pós-`ColumnTransformer`
#
# A função `get_feature_names` reconstrói o vetor de nomes de features gerado após o pré-processamento,
# incluindo:
# - variáveis numéricas (após imputação/escala),
# - variáveis categóricas expandidas via One-Hot Encoding,
# - e, opcionalmente, colunas passadas via `remainder='passthrough'`.
#
# Essa etapa é necessária porque, após o `fit_transform`, a matriz final perde o vínculo direto com o nome
# das colunas originais, e a identificação correta das features é condição para qualquer análise de importância.

# %%
# 1. FUNÇÃO PARA EXTRAIR NOMES DAS FEATURES PÓS-OHE
def get_feature_names(column_transformer):
    """
    Extrai nomes finais das features após ColumnTransformer,
    incluindo OneHotEncoder e transformações numéricas.
    """
    output_features = []

    for name, transformer, features in column_transformer.transformers_:

        # Caso 'remainder=passthrough'
        if name == "remainder":
            output_features.extend(features)
            continue

        # Transformers com get_feature_names_out() (OneHotEncoder, etc)
        if hasattr(transformer, "get_feature_names_out"):
            try:
                names = transformer.get_feature_names_out(features)
            except:
                names = transformer.get_feature_names_out()
            output_features.extend(names)

        # Caso não possua o método
        else:
            output_features.extend(features)

    return output_features

# %% [markdown]
# ### Mapeamento para variáveis originais via fuzzy matching
#
# Após o One-Hot Encoding, uma mesma variável categórica pode gerar dezenas de colunas com nomes derivados.
# Para consolidar resultados no nível da variável original, é aplicado *fuzzy matching* entre o nome da feature
# pós-OHE e a lista de variáveis originais de interesse (`features_explicativas`).
#
# O objetivo do fuzzy matching é lidar com diferenças de sufixos/prefixos criados pelo encoding e manter
# um vínculo prático entre “feature transformada” e “coluna original”. O parâmetro `threshold`
# controla o quão estrita é a correspondência:
# - valores maiores reduzem falsos positivos (match errado),
# - valores menores aumentam cobertura, mas elevam risco de mapeamentos incorretos.
#
# Após o matching, apenas features com correspondência válida são mantidas para agregação.

# %%
def fuzzy_match_original(feature_name, triage_features, threshold=70):
    """
    Realiza fuzzy matching buscando qual variável ORIGINAL
    está mais relacionada com o nome da feature pós-OHE.
    """
    best_match, score, _ = process.extractOne(
        feature_name,
        triage_features,
        scorer=fuzz.partial_ratio
    )
    return best_match if score >= threshold else None

# %% [markdown]
# ## Validação cruzada externa: avaliação e interpretabilidade por fold
#
# Nesta etapa, aplica-se uma `StratifiedKFold` externa para avaliar o desempenho do pipeline e também
# inspecionar a importância de variáveis por fold. A estratificação preserva a proporção das classes,
# reduzindo instabilidade em bases desbalanceadas.
#
# Para cada fold:
# - o pipeline final é treinado no conjunto de treino,
# - a importância das features é extraída do modelo treinado,
# - as importâncias são consolidadas no nível da variável original e visualizadas,
# - e o desempenho é medido no conjunto de teste com métricas e curvas.

# %%
# =========================
# Parâmetros
# =========================
n_splits = 4
top_k = 20        # top features por fold (para tabelas)
top_overall = 30  # top features gerais (para tabela final)

outer_cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

# =========================
# Coletores (tabelas)
# =========================
fold_metrics = []          # 1 linha por fold com métricas + conf matrix flatten
fold_top_features = []     # top_k features por fold (já agrupadas em original_var)
all_features_long = []     # todas features (agrupadas) por fold -> resumo geral

fold = 1
for train_idx, test_idx in outer_cv.split(X_data, y_data):

    print(f"\n==============================")
    print(f"  Fold Externo {fold}/{n_splits}")
    print(f"==============================")

    X_train, X_test = X_data.iloc[train_idx], X_data.iloc[test_idx]
    y_train, y_test = y_data.iloc[train_idx], y_data.iloc[test_idx]

    # =========================
    # 1) Fit do pipeline no fold
    # =========================
    final_pipeline.fit(X_train, y_train)

    # =========================
    # 2) Importâncias
    # =========================
    model = final_pipeline.named_steps["model"]

    if hasattr(model, "feature_importances_"):
        importances = model.feature_importances_
    elif hasattr(model, "coef_"):
        coef = model.coef_
        # binary: (n_features,) ou (1, n_features)
        # multiclass: (n_classes, n_features) -> agregamos por média do abs
        importances = coef.ravel() if coef.ndim == 1 else np.mean(np.abs(coef), axis=0)
    else:
        raise ValueError("Este modelo não possui atributo de importância (feature_importances_ ou coef_).")

    # =========================
    # 3) Nomes pós-preprocessamento
    # =========================
    preproc = final_pipeline.named_steps["preprocessor"]
    feature_names = get_feature_names(preproc)

    if len(feature_names) != len(importances):
        raise ValueError(
            f"Mismatch: {len(feature_names)} nomes de features vs {len(importances)} importâncias. "
            "Cheque get_feature_names() / preprocessor."
        )

    df_imp = pd.DataFrame({"feature": feature_names, "importance": importances})

    # =========================
    # 4) Fuzzy match para variáveis originais e agregação
    # =========================
    df_imp["original_var"] = df_imp["feature"].apply(lambda x: fuzzy_match_original(x, triage_features))
    df_imp = df_imp[df_imp["original_var"].notna()].copy()

    df_grouped = (
        df_imp.groupby("original_var", as_index=False)["importance"]
              .sum()
              .sort_values("importance", ascending=False)
              .rename(columns={"original_var": "feature"})
              .reset_index(drop=True)
    )

    # =========================
    # 4.1) Plot: Feature importance (por fold)
    # =========================
    plt.figure(figsize=(6, 14))
    plt.barh(df_grouped["feature"][::-1], df_grouped["importance"][::-1])
    plt.xlabel("Importância (agregada por variável original)")
    plt.title(f"Feature importance – {type(model).__name__} – Fold {fold}")
    plt.tight_layout()
    plt.show()

    # guarda top features do fold (top_k)
    df_top = df_grouped.head(top_k).copy()
    df_top["fold"] = fold
    df_top["rank_in_fold"] = np.arange(1, len(df_top) + 1)
    fold_top_features.append(df_top)

    # guarda TODAS as features agregadas do fold (para resumo geral)
    df_grouped_long = df_grouped.copy()
    df_grouped_long["fold"] = fold
    all_features_long.append(df_grouped_long)

    # =========================
    # 5) Predições / probabilidades
    # =========================
    y_pred = final_pipeline.predict(X_test)

    y_proba = None
    if hasattr(final_pipeline, "predict_proba"):
        try:
            y_proba = final_pipeline.predict_proba(X_test)[:, 1]
        except Exception:
            y_proba = None

    # =========================
    # 6) Matriz de confusão (plot)
    # =========================
    cm = confusion_matrix(y_test, y_pred)

    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.title(f"Matriz de Confusão – Fold {fold}")
    plt.xlabel("Predito")
    plt.ylabel("Real")
    plt.tight_layout()
    plt.show()

    # =========================
    # 7) Métricas (plot + tabela)
    # =========================
    metrics_dict_plot = {
        "Accuracy": accuracy_score(y_test, y_pred),
        "Precision": precision_score(y_test, y_pred, zero_division=0),
        "Recall": recall_score(y_test, y_pred, zero_division=0),
        "F1 Score": f1_score(y_test, y_pred, zero_division=0),
        "AUC": roc_auc_score(y_test, y_proba) if y_proba is not None else np.nan
    }

    plt.figure(figsize=(8, 5))
    sns.barplot(x=list(metrics_dict_plot.keys()), y=list(metrics_dict_plot.values()), palette="Set2")
    plt.ylim(0, 1.05)
    plt.title(f"Métricas de Classificação – Fold {fold}")
    for i, v in enumerate(metrics_dict_plot.values()):
        if np.isfinite(v):
            plt.text(i, v + 0.02, f"{v:.2f}", ha='center')
        else:
            plt.text(i, 0.02, "NA", ha='center')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    # salva métricas estruturadas (para df_metrics)
    fold_metrics.append({
        "fold": fold,
        "n_train": len(train_idx),
        "n_test": len(test_idx),
        "accuracy": metrics_dict_plot["Accuracy"],
        "precision": metrics_dict_plot["Precision"],
        "recall": metrics_dict_plot["Recall"],
        "f1": metrics_dict_plot["F1 Score"],
        "auc": metrics_dict_plot["AUC"],
        "tn": cm[0, 0], "fp": cm[0, 1], "fn": cm[1, 0], "tp": cm[1, 1],
        "model_name": type(model).__name__,
    })

    # =========================
    # 8) Curva ROC (plot)
    # =========================
    if y_proba is not None:
        fpr, tpr, _ = roc_curve(y_test, y_proba)
        roc_auc = auc(fpr, tpr)

        plt.figure(figsize=(6, 5))
        plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.2f}")
        plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
        plt.xlabel("Falso Positivo")
        plt.ylabel("Verdadeiro Positivo")
        plt.title(f"Curva ROC – Fold {fold}")
        plt.legend(loc='lower right')
        plt.grid(True)
        plt.tight_layout()
        plt.show()

    # =========================
    # 9) Curva Precision-Recall (plot)
    # =========================
    if y_proba is not None:
        precision, recall, _ = precision_recall_curve(y_test, y_proba)
        auprc_trap = auc(recall, precision)

        plt.figure(figsize=(6, 5))
        plt.plot(recall, precision, label=f"AUPRC = {auprc_trap:.2f}")
        plt.xlabel("Recall")
        plt.ylabel("Precision")
        plt.title(f"Curva Precision-Recall – Fold {fold}")
        plt.legend(loc='lower right')
        plt.grid(True)
        plt.tight_layout()
        plt.show()

    fold += 1


# =========================
# 10) DF: métricas por fold
# =========================
df_metrics = pd.DataFrame(fold_metrics).sort_values("fold").reset_index(drop=True)

# resumo (média e desvio padrão) das métricas
metric_cols = ["accuracy", "precision", "recall", "f1", "auc"]
df_metrics_summary = (
    df_metrics[metric_cols]
    .agg(["mean", "std"])
    .T
    .rename(columns={"mean": "mean", "std": "std"})
    .reset_index()
    .rename(columns={"index": "metric"})
)

# =========================
# 11) DF: top features por fold
# =========================
df_top_by_fold = pd.concat(fold_top_features, ignore_index=True)

# =========================
# 12) DF: resumo geral das features (média/std + rank)
# =========================
df_all_features_long = pd.concat(all_features_long, ignore_index=True)

df_feature_summary = (
    df_all_features_long
    .groupby("feature", as_index=False)
    .agg(
        mean_importance=("importance", "mean"),
        std_importance=("importance", "std"),
        folds_present=("fold", "nunique"),
    )
)

# ranking médio por fold (quanto menor, mais importante)
df_ranks = (
    df_all_features_long
    .assign(rank_in_fold=lambda d: d.groupby("fold")["importance"].rank(ascending=False, method="average"))
)

df_rank_summary = (
    df_ranks.groupby("feature", as_index=False)
            .agg(mean_rank=("rank_in_fold", "mean"), std_rank=("rank_in_fold", "std"))
)

df_feature_summary = (
    df_feature_summary.merge(df_rank_summary, on="feature", how="left")
                      .sort_values(["mean_importance", "folds_present"], ascending=[False, False])
                      .reset_index(drop=True)
)

df_top_features_overall = df_feature_summary.head(top_overall).copy()

# =========================
# 13) OUTPUT final (tabelas)
# =========================
print("\n\n==============================")
print("MÉTRICAS POR FOLD")
print("==============================")
display(df_metrics)

print("\n\n==============================")
print("RESUMO GERAL DAS MÉTRICAS (média e desvio padrão)")
print("==============================")
display(df_metrics_summary)

print("\n\n==============================")
print(f"TOP {top_k} FEATURES POR FOLD (agregadas em variável original)")
print("==============================")
display(df_top_by_fold.sort_values(["fold", "rank_in_fold"]))

print("\n\n==============================")
print(f"TOP {top_overall} FEATURES GERAIS (média/std das importâncias + estabilidade via rank)")
print("==============================")
display(df_top_features_overall)

# Se quiser salvar:
# df_metrics.to_csv("cv_metrics_by_fold.csv", index=False)
# df_metrics_summary.to_csv("cv_metrics_summary.csv", index=False)
# df_top_by_fold.to_csv("cv_top_features_by_fold.csv", index=False)
# df_feature_summary.to_csv("cv_feature_importance_summary.csv", index=False)
# Out:
# ==============================
#   Fold Externo 1/4
# ==============================
# [LightGBM] [Info] Number of positive: 33022, number of negative: 33022
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.177421 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 41480
# [LightGBM] [Info] Number of data points in the train set: 66044, number of used features: 338
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# ==============================
#   Fold Externo 2/4
# ==============================
# [LightGBM] [Info] Number of positive: 33022, number of negative: 33022
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.175804 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 41269
# [LightGBM] [Info] Number of data points in the train set: 66044, number of used features: 337
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# ==============================
#   Fold Externo 3/4
# ==============================
# [LightGBM] [Info] Number of positive: 33023, number of negative: 33023
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.171773 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 41126
# [LightGBM] [Info] Number of data points in the train set: 66046, number of used features: 336
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# ==============================
#   Fold Externo 4/4
# ==============================
# [LightGBM] [Info] Number of positive: 33023, number of negative: 33023
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.193962 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 41338
# [LightGBM] [Info] Number of data points in the train set: 66046, number of used features: 337
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# ==============================
# MÉTRICAS POR FOLD
# ==============================
#    fold  n_train  n_test  accuracy  precision    recall        f1       auc  \
# 0     1    41332   13778  0.921034   0.876455  0.706859  0.782574  0.926357
# 1     2    41332   13778  0.921832   0.863461  0.725993  0.788782  0.934471
# 2     3    41333   13777  0.920012   0.865469  0.712996  0.781869  0.930768
# 3     4    41333   13777  0.921608   0.871592  0.715523  0.785884  0.930353
#
#       tn   fp   fn    tp      model_name
# 0  10732  276  812  1958  LGBMClassifier
# 1  10690  318  759  2011  LGBMClassifier
# 2  10700  307  795  1975  LGBMClassifier
# 3  10715  292  788  1982  LGBMClassifier
# ==============================
# RESUMO GERAL DAS MÉTRICAS (média e desvio padrão)
# ==============================
#       metric      mean       std
# 0   accuracy  0.921121  0.000813
# 1  precision  0.869244  0.005922
# 2     recall  0.715343  0.007978
# 3         f1  0.784777  0.003193
# 4        auc  0.930487  0.003318
# ==============================
# TOP 20 FEATURES POR FOLD (agregadas em variável original)
# ==============================
#        feature  importance  fold  rank_in_fold
# 0        SG_UF         186     1             1
# 1   CON_AMBIEN          53     1             2
# 2   CLI_ICTERI          50     1             3
# 3   ID_OCUPA_N          41     1             4
# 4     CON_AREA          38     1             5
# ..         ...         ...   ...           ...
# 75  ANT_HUMANO          16     4            16
# 76  CLI_VOMITO          16     4            17
# 77     CS_RACA          15     4            18
# 78  ANT_CB_COR          14     4            19
# 79  ANT_CB_CRI          13     4            20
#
# [80 rows x 4 columns]
# ==============================
# TOP 30 FEATURES GERAIS (média/std das importâncias + estabilidade via rank)
# ==============================
#          feature  mean_importance  std_importance  folds_present  mean_rank  \
# 0          SG_UF           186.75       10.210289              4      1.000
# 1     CON_AMBIEN            54.25        5.057997              4      2.000
# 2     CLI_ICTERI            47.00        3.559026              4      4.250
# 3       CON_AREA            46.50        6.027714              4      3.500
# 4     ID_OCUPA_N            40.50        6.658328              4      4.250
# 5     CS_ESCOL_N            32.75        3.095696              4      6.375
# 6     ANT_CB_LAM            28.50        4.123106              4      8.000
# 7     NU_IDADE_N            28.00        3.915780              4      8.625
# 8        CS_SEXO            27.50        3.109126              4      8.750
# 9     CLI_PANTUR            27.25        1.500000              4      8.500
# 10     CLI_RENAL            22.75        0.957427              4     11.375
# 11    CLI_VOMITO            20.75        4.425306              4     12.750
# 12    CLI_MIALGI            19.75        2.362908              4     13.250
# 13       estacao            18.50        5.066228              4     15.125
# 14     CLI_FEBRE            18.00        1.414214              4     14.875
# 15    ANT_ANIMAI            14.50        2.645751              4     17.750
# 16    ANT_HUMANO            14.50        3.000000              4     17.625
# 17    ANT_CB_COR            14.00        1.414214              4     18.375
# 18       CS_RACA            14.00        2.581989              4     18.375
# 19     CLI_PROST            12.00        3.559026              4     21.750
# 20    CLI_CEFALE            11.25        1.258306              4     21.875
# 21    ANT_CB_CRI            10.75        1.707825              4     22.625
# 22    ANT_CB_SIN            10.50        4.795832              4     23.625
# 23    CLI_CONGES            10.50        2.516611              4     23.750
# 24    CLI_OUTROS            10.25        0.500000              4     23.500
# 25    CLI_RESPIR            10.00        0.816497              4     23.875
# 26  mes_sintomas             9.75        2.217356              4     24.375
# 27    ANT_CB_LIX             6.00        1.632993              4     29.750
# 28    CS_GESTANT             6.00        2.160247              4     30.625
# 29    ANT_CB_OUT             5.75        3.862210              4     31.250
#
#     std_rank
# 0   0.000000
# 1   0.000000
# 2   0.957427
# 3   1.000000
# 4   0.500000
# 5   0.478714
# 6   1.825742
# 7   2.212653
# 8   0.866025
# 9   0.408248
# 10  0.750000
# 11  2.598076
# 12  0.957427
# 13  4.327721
# 14  0.478714
# 15  3.926406
# 16  1.931105
# 17  1.887459
# 18  2.839454
# 19  4.213075
# 20  1.887459
# 21  2.393568
# 22  6.675515
# 23  4.518481
# 24  1.080123
# 25  1.493039
# 26  4.607512
# 27  1.190238
# 28  3.198307
# 29  6.224950
# ==============================
#   Fold Externo 1/4
# ==============================
# [LightGBM] [Info] Number of positive: 33022, number of negative: 33022
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.186901 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 41480
# [LightGBM] [Info] Number of data points in the train set: 66044, number of used features: 338
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# ==============================
#   Fold Externo 2/4
# ==============================
# [LightGBM] [Info] Number of positive: 33022, number of negative: 33022
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.174256 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 41269
# [LightGBM] [Info] Number of data points in the train set: 66044, number of used features: 337
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# ==============================
#   Fold Externo 3/4
# ==============================
# [LightGBM] [Info] Number of positive: 33023, number of negative: 33023
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.186266 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 41126
# [LightGBM] [Info] Number of data points in the train set: 66046, number of used features: 336
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# ==============================
#   Fold Externo 4/4
# ==============================
# [LightGBM] [Info] Number of positive: 33023, number of negative: 33023
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.183207 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 41338
# [LightGBM] [Info] Number of data points in the train set: 66046, number of used features: 337
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# ==============================
# MÉTRICAS POR FOLD
# ==============================
#    fold  n_train  n_test  accuracy  precision    recall        f1       auc  \
# 0     1    41332   13778  0.921034   0.876455  0.706859  0.782574  0.926357
# 1     2    41332   13778  0.921832   0.863461  0.725993  0.788782  0.934471
# 2     3    41333   13777  0.920012   0.865469  0.712996  0.781869  0.930768
# 3     4    41333   13777  0.921608   0.871592  0.715523  0.785884  0.930353
#
#       tn   fp   fn    tp      model_name
# 0  10732  276  812  1958  LGBMClassifier
# 1  10690  318  759  2011  LGBMClassifier
# 2  10700  307  795  1975  LGBMClassifier
# 3  10715  292  788  1982  LGBMClassifier
# ==============================
# RESUMO GERAL DAS MÉTRICAS (média e desvio padrão)
# ==============================
#       metric      mean       std
# 0   accuracy  0.921121  0.000813
# 1  precision  0.869244  0.005922
# 2     recall  0.715343  0.007978
# 3         f1  0.784777  0.003193
# 4        auc  0.930487  0.003318
# ==============================
# TOP 20 FEATURES POR FOLD (agregadas em variável original)
# ==============================
#        feature  importance  fold  rank_in_fold
# 0        SG_UF         186     1             1
# 1   CON_AMBIEN          53     1             2
# 2   CLI_ICTERI          50     1             3
# 3   ID_OCUPA_N          41     1             4
# 4     CON_AREA          38     1             5
# ..         ...         ...   ...           ...
# 75  ANT_HUMANO          16     4            16
# 76  CLI_VOMITO          16     4            17
# 77     CS_RACA          15     4            18
# 78  ANT_CB_COR          14     4            19
# 79  ANT_CB_CRI          13     4            20
#
# [80 rows x 4 columns]
# ==============================
# TOP 30 FEATURES GERAIS (média/std das importâncias + estabilidade via rank)
# ==============================
#          feature  mean_importance  std_importance  folds_present  mean_rank  \
# 0          SG_UF           186.75       10.210289              4      1.000
# 1     CON_AMBIEN            54.25        5.057997              4      2.000
# 2     CLI_ICTERI            47.00        3.559026              4      4.250
# 3       CON_AREA            46.50        6.027714              4      3.500
# 4     ID_OCUPA_N            40.50        6.658328              4      4.250
# 5     CS_ESCOL_N            32.75        3.095696              4      6.375
# 6     ANT_CB_LAM            28.50        4.123106              4      8.000
# 7     NU_IDADE_N            28.00        3.915780              4      8.625
# 8        CS_SEXO            27.50        3.109126              4      8.750
# 9     CLI_PANTUR            27.25        1.500000              4      8.500
# 10     CLI_RENAL            22.75        0.957427              4     11.375
# 11    CLI_VOMITO            20.75        4.425306              4     12.750
# 12    CLI_MIALGI            19.75        2.362908              4     13.250
# 13       estacao            18.50        5.066228              4     15.125
# 14     CLI_FEBRE            18.00        1.414214              4     14.875
# 15    ANT_ANIMAI            14.50        2.645751              4     17.750
# 16    ANT_HUMANO            14.50        3.000000              4     17.625
# 17    ANT_CB_COR            14.00        1.414214              4     18.375
# 18       CS_RACA            14.00        2.581989              4     18.375
# 19     CLI_PROST            12.00        3.559026              4     21.750
# 20    CLI_CEFALE            11.25        1.258306              4     21.875
# 21    ANT_CB_CRI            10.75        1.707825              4     22.625
# 22    ANT_CB_SIN            10.50        4.795832              4     23.625
# 23    CLI_CONGES            10.50        2.516611              4     23.750
# 24    CLI_OUTROS            10.25        0.500000              4     23.500
# 25    CLI_RESPIR            10.00        0.816497              4     23.875
# 26  mes_sintomas             9.75        2.217356              4     24.375
# 27    ANT_CB_LIX             6.00        1.632993              4     29.750
# 28    CS_GESTANT             6.00        2.160247              4     30.625
# 29    ANT_CB_OUT             5.75        3.862210              4     31.250
#
#     std_rank
# 0   0.000000
# 1   0.000000
# 2   0.957427
# 3   1.000000
# 4   0.500000
# 5   0.478714
# 6   1.825742
# 7   2.212653
# 8   0.866025
# 9   0.408248
# 10  0.750000
# 11  2.598076
# 12  0.957427
# 13  4.327721
# 14  0.478714
# 15  3.926406
# 16  1.931105
# 17  1.887459
# 18  2.839454
# 19  4.213075
# 20  1.887459
# 21  2.393568
# 22  6.675515
# 23  4.518481
# 24  1.080123
# 25  1.493039
# 26  4.607512
# 27  1.190238
# 28  3.198307
# 29  6.224950

# %% [markdown]
# ### Salvando checkpoints do colab no drive

# %% [markdown]
# Salvar metricas

# %%
src = "/content/checkpoints_best_models"
dst = f"/content/drive/MyDrive/ITA/TCC/Resultados/{experimento}/checkpoints_best_models"

os.makedirs(os.path.dirname(dst), exist_ok=True)
shutil.copytree(src, dst, dirs_exist_ok=True)
# Out:
# '/content/drive/MyDrive/ITA/TCC/Resultados/confirmados_descartados_semFeatureSelection/checkpoints_best_models'

# %% [markdown]
# Salvar modelos

# %%
src = "/content/log_opt"
dst = f"/content/drive/MyDrive/ITA/TCC/Resultados/{experimento}/log_opt"

os.makedirs(os.path.dirname(dst), exist_ok=True)
shutil.copytree(src, dst, dirs_exist_ok=True)
# Out:
# '/content/drive/MyDrive/ITA/TCC/Resultados/confirmados_descartados_semFeatureSelection/log_opt'
