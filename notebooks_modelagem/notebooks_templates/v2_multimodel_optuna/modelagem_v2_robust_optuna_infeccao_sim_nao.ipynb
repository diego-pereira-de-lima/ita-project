# %%
# !pip uninstall xgboost -y

# %%
# !pip install optuna xgboost==3.1.1 lightgbm fastparquet imbalanced-learn torch rapidfuzz
# Out:
# Requirement already satisfied: optuna in /usr/local/lib/python3.12/dist-packages (4.6.0)
# Requirement already satisfied: xgboost==3.1.1 in /usr/local/lib/python3.12/dist-packages (3.1.1)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.12/dist-packages (4.6.0)
# Requirement already satisfied: fastparquet in /usr/local/lib/python3.12/dist-packages (2024.11.0)
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.12/dist-packages (0.14.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from xgboost==3.1.1) (2.0.2)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.12/dist-packages (from xgboost==3.1.1) (2.27.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from xgboost==3.1.1) (1.16.3)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.17.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.12/dist-packages (from optuna) (6.10.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.44)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: pandas>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from fastparquet) (2.2.2)
# Requirement already satisfied: cramjam>=2.3 in /usr/local/lib/python3.12/dist-packages (from fastparquet) (2.11.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from fastparquet) (2025.3.0)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (1.6.1)
# Requirement already satisfied: joblib<2,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->fastparquet) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->fastparquet) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->fastparquet) (2025.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->fastparquet) (1.17.0)

# %%
import numpy as np
import pandas as pd
import os, joblib,time


from sklearn.model_selection import StratifiedKFold, cross_val_score,train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.calibration import CalibratedClassifierCV

import optuna
from optuna.pruners import SuccessiveHalvingPruner
from optuna.exceptions import TrialPruned

#from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.impute import SimpleImputer
from functools import partial


from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, confusion_matrix, matthews_corrcoef,
    cohen_kappa_score, balanced_accuracy_score,
    classification_report, brier_score_loss, log_loss,
    confusion_matrix, ConfusionMatrixDisplay,
    precision_recall_curve, RocCurveDisplay,roc_curve,auc
)

from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE

import matplotlib.pyplot as plt
import seaborn as sns

import subprocess
import xgboost as xgb
import lightgbm as lgb
import torch

import re
from rapidfuzz import fuzz, process

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Carregando base de dados

# %% [markdown]
# Carregamento do conjunto de dados processado a partir de um arquivo no formato Parquet.
# Esse formato colunar é otimizado para leitura eficiente, reduz uso de memória e preserva os tipos de dados,
# sendo adequado para pipelines analíticos e etapas posteriores de modelagem.

# %%
df =pd.read_parquet('df_hepat_processed_v1.parquet',engine='fastparquet')

# %% [markdown]
# ### Selecionar variáveis relevantes para triagem

# %% [markdown]
# Definição das variáveis explicativas e da variável alvo utilizadas no modelo.
# As features incluem características sociodemográficas, condições ambientais, antecedentes clínicos e sintomas,
# além de variáveis derivadas de vulnerabilidade social e sazonalidade, enquanto a variável alvo representa a severidade do caso.

# %%
triage_features = [
    'NU_IDADE_N','CS_SEXO','CS_GESTANT','CS_RACA','CS_ESCOL_N',
    'ID_OCUPA_N','CON_AREA','CON_AMBIEN',
    'ANT_CB_LAM','ANT_CB_CRI','ANT_CB_SIN','ANT_CB_COR','ANT_CB_ROE',
    'ANT_CB_TER','ANT_CB_LIX','ANT_CB_OUT','ANT_ANIMAI','ANT_HUMANO',
    'CLI_FEBRE','CLI_MIALGI','CLI_CEFALE','CLI_PROST','CLI_CONGES',
    'CLI_PANTUR','CLI_VOMITO','CLI_DIARRE','CLI_ICTERI','CLI_RENAL',
    'CLI_RESPIR','CLI_CARDIA','CLI_HEMOPU','CLI_HEMORR','CLI_MENING',
    'CLI_OUTROS','SG_UF', 'baixa_escolaridade','raca_vulneravel','faixa_vulneravel',
    'vulnerabilidade_social', 'nivel_vulnerabilidade','mes_sintomas','estacao', 'periodo_chuvoso'
]



target_col = 'CLASSI_FIN'  # rótulo: confirmado vs descartado

if target_col == 'CLASSI_FIN':
    df = df[df['CLASSI_FIN'].isin(['Confirmado', 'Descartado'])].copy()

    # Criar variável alvo binária
    df['alvo'] = df['CLASSI_FIN'].map({
        'Confirmado': 1,
        'Descartado': 0
    })

# %% [markdown]
# ### Amostragem estratificada dos dados
#
# Nesta etapa é realizada uma amostragem estratificada da base de dados,
# preservando a proporção das classes da variável alvo.
# O procedimento consiste em aplicar uma amostragem aleatória dentro de cada classe,
# extraindo uma fração representativa do conjunto original.
#
# Em seguida, a base amostrada é separada em variáveis explicativas (X)
# e variável resposta (y), que serão utilizadas nas etapas subsequentes de modelagem.
#
# Essa abordagem reduz o volume de dados processados,
# mantendo a representatividade estatística das classes e garantindo reprodutibilidade
# por meio do uso de uma semente aleatória fixa.

# %%
## Amostragem estratificada
amostragem = df.groupby("alvo").sample(frac=0.15, random_state=42).copy()

X_data=amostragem[triage_features]
y_data = amostragem['alvo']

# %% [markdown]
# ## Train framework

# %% [markdown]
# ### Funções de apoio

# %% [markdown]
# Detecta automaticamente a disponibilidade de GPU no ambiente,
# verificando suporte a CUDA, compatibilidade do LightGBM com GPU
# e informações do hardware via `nvidia-smi`.

# %%
def detect_gpu():
    """
    Detecta corretamente suporte a GPU para CUDA, XGBoost e LightGBM.
    Retorna um dicionário completo.
    """

    # 1. Verificar CUDA geral
    try:
        cuda_available = torch.cuda.is_available()
    except:
        cuda_available = False


    # 2. Testar LightGBM GPU

    try:
        # Testa se LightGBM foi compilado com suporte a GPU
        lgb_gpu = lgb.register_logger(lambda x: x)  # dummy
        booster = lgb.LGBMClassifier(device="gpu")
        lgb_gpu = True
    except:
        lgb_gpu = False


    # 3. Detalhes da GPU via nvidia-smi

    try:
        smi_output = subprocess.check_output("nvidia-smi", shell=True).decode()
        gpu_info = smi_output.split("\n")[2].strip()
    except:
        gpu_info = "Nenhuma GPU detectada (nvidia-smi não disponível)"

    return {
        "cuda_available": cuda_available,
        "lightgbm_gpu": lgb_gpu,
        "gpu_info": gpu_info
    }

# %%
def get_model_params_gpu(model_name, gpu_info):
    """
    Retorna hiperparâmetros base apropriados para CPU ou GPU.
    """
    use_gpu = gpu_info["cuda_available"]

    if model_name == "xgboost":
        if use_gpu:
            return {
                "tree_method": "gpu_hist",
                "predictor": "gpu_predictor"
            }
        else:
            return {
                "tree_method": "hist",
                "predictor": "cpu_predictor"
            }

    elif model_name == "lightgbm":
        if use_gpu:
            return {
                "device": "gpu",
                "gpu_platform_id": 0,
                "gpu_device_id": 0
            }
        else:
            return {
                "device": "cpu"
            }

    elif model_name in ["random_forest", "svm"]:
        # sklearn não usa GPU
        return {}

    return {}

# %%
def get_feature_types(df):
    """
    Identifica automaticamente colunas categóricas e numéricas de um dataframe.

    Retorna:
        cat_cols  -> lista de colunas categóricas
        num_cols  -> lista de colunas numéricas
    """

    # CATEGÓRICAS: object, category ou boolean
    cat_cols = df.select_dtypes(include=['object', 'category', 'bool']).columns.tolist()

    # NUMÉRICAS: int, float
    num_cols = df.select_dtypes(include=['int', 'float', 'int64', 'float64']).columns.tolist()

    return cat_cols, num_cols

# %% [markdown]
# ###  1. FUNÇÃO PARA CRIAR O MODELO A PARTIR DO TRIAL (Optuna)

# %% [markdown]
# Esta função encapsula a criação do modelo a ser otimizado por uma *trial* do Optuna,
# permitindo que diferentes famílias de classificadores sejam avaliadas dentro do mesmo processo de busca.
#
# O fluxo é composto por duas decisões principais:
#
# 1) **Seleção do algoritmo**
# A cada iteração, o Optuna escolhe o modelo a ser testado (`svm`, `xgboost`, `lightgbm` ou `random_forest`)
# por meio de uma variável categórica (`model_name`). Isso viabiliza uma busca conjunta que compara
# arquiteturas distintas sob o mesmo protocolo de avaliação.
#
# 2) **Amostragem de hiperparâmetros e configuração dinâmica de GPU**
# Para cada algoritmo, são sugeridos hiperparâmetros relevantes (ex.: profundidade, número de árvores, taxa de aprendizado,
# subsample e colsample), definindo um espaço de busca controlado e reproduzível.
# Em paralelo, a função consulta `get_model_params_gpu(model_name, gpu_info)` para injetar automaticamente
# parâmetros específicos de aceleração (CPU/GPU) quando suportado pelo ambiente, garantindo portabilidade do pipeline.
#
# Além disso, é aplicada uma estratégia de mitigação de desbalanceamento:
# - `class_weight="balanced"` para Random Forest e SVM,
# - `is_unbalance=True` para LightGBM,
# visando reduzir viés em cenários com classes minoritárias.
#
# No caso da SVM, utiliza-se `LinearSVC` com calibração (`CalibratedClassifierCV`),
# permitindo a obtenção de probabilidades calibradas, úteis para métricas baseadas em ranking (ex.: ROC-AUC)
# e para tomada de decisão com limiar de classificação.

# %%
def create_model(trial, gpu_info):
    model_name = trial.suggest_categorical(
        "model_name", ["svm","xgboost", "lightgbm", "random_forest"]
    )

    gpu_params = get_model_params_gpu(model_name, gpu_info)

    # RANDOM FOREST
    if model_name == "random_forest":
        return RandomForestClassifier(
            n_estimators=trial.suggest_int("n_estimators", 5, 30),
            max_depth=trial.suggest_int("max_depth", 3, 9),
            min_samples_split=trial.suggest_int("min_samples_split", 2, 10),
            min_samples_leaf=trial.suggest_int("min_samples_leaf", 1, 5),
            random_state=42,
            class_weight= 'balanced',
            **gpu_params
        )

    # SVM
    elif model_name == "svm":
        svm= LinearSVC(
            C=trial.suggest_float("C", 0.1, 3.0),
            max_iter=5000,
            class_weight= 'balanced'
        )
        return CalibratedClassifierCV(svm, method="sigmoid")

    # XGBOOST
    elif model_name == "xgboost":
        return XGBClassifier(
            n_estimators=trial.suggest_int("n_estimators", 5, 30),
            max_depth=trial.suggest_int("max_depth", 3, 9),
            learning_rate=trial.suggest_float("learning_rate", 0.01, 0.3),
            subsample=trial.suggest_float("subsample", 0.5, 1.0),
            colsample_bytree=trial.suggest_float("colsample_bytree", 0.5, 1.0),
            eval_metric="logloss",
            random_state=42,
            class_weight= 'balanced',
            n_jobs=-1,
            #**gpu_params
        )

    # LIGHTGBM
    elif model_name == "lightgbm":
        return LGBMClassifier(
            n_estimators=trial.suggest_int("n_estimators", 5, 30),
            learning_rate=trial.suggest_float("learning_rate", 0.01, 0.3),
            max_depth=trial.suggest_int("max_depth", 3, 9),
            subsample=trial.suggest_float("subsample", 0.5, 1.0),
            colsample_bytree=trial.suggest_float("colsample_bytree", 0.5, 1.0),
            random_state=42,
            is_unbalance=True,
           force_col_wise=True,
            **gpu_params
        )

# %% [markdown]
# ### 2. FUNÇÃO OBJETIVO DO OPTUNA (COM CROSS-VALIDATION)

# %% [markdown]
# ### Função `build_pipeline`: pré-processamento, balanceamento e modelagem em um fluxo único
#
# Esta função constrói um pipeline completo de treinamento, integrando pré-processamento dos dados,
# tratamento de desbalanceamento e ajuste do modelo em uma única estrutura reprodutível.
#
# O pipeline é organizado em três blocos sequenciais:
#
# 1) **Pré-processamento por tipo de variável**
# - Variáveis numéricas passam por imputação da mediana, reduzindo sensibilidade a outliers,
# seguida de padronização (`StandardScaler`), garantindo escalas compatíveis para modelos sensíveis à magnitude.
# - Variáveis categóricas passam por imputação do valor mais frequente e codificação via `OneHotEncoder`,
# com tratamento explícito de categorias raras (`handle_unknown='infrequent_if_exist'`),
# o que reduz dimensionalidade excessiva e melhora estabilidade do modelo.
#
# 2) **Balanceamento de classes (SMOTE)**
# Após o pré-processamento, aplica-se o SMOTE para gerar amostras sintéticas da classe minoritária
# exclusivamente no conjunto de treino dentro do pipeline,
# evitando vazamento de informação (*data leakage*) e melhorando a capacidade do modelo
# em aprender fronteiras de decisão mais equilibradas.
#
# 3) **Modelo preditivo**
# O estimador final é injetado de forma modular, permitindo que diferentes algoritmos
# (Random Forest, SVM, XGBoost, LightGBM, etc.) sejam testados sob exatamente o mesmo fluxo de dados.
#
# Ao encapsular todas as etapas em um único objeto `Pipeline`,
# a função garante consistência entre treino, validação e inferência,
# além de facilitar integração com validação cruzada e otimização de hiperparâmetros.

# %%
def build_pipeline(model, cat_cols, num_cols):

    # construindo o preprocessor
    num_preprocessor = Pipeline(steps=[
        ("imputer", SimpleImputer(strategy="median")),
        ("scaler", StandardScaler())
    ])

    cat_preprocessor = Pipeline(steps=[
        ("imputer", SimpleImputer(strategy="most_frequent")),
        ("onehot", OneHotEncoder(handle_unknown='infrequent_if_exist'))
    ])

    preprocessor = ColumnTransformer(
        transformers=[
            ("num", num_preprocessor, num_cols),
            ("cat", cat_preprocessor, cat_cols)
        ]
    )

    # construindo pipe
    pipe = Pipeline([
        ("preprocessor", preprocessor),
        ("smote", SMOTE(random_state=42)),
        ("model", model)
    ])

    return pipe

# %% [markdown]
# ### Função `objective`: avaliação do modelo por validação cruzada e otimização com Optuna (com pruning)
#
# Esta função define a métrica objetivo utilizada pelo Optuna durante a busca de hiperparâmetros.
# Para cada `trial`, ela instancia um modelo candidato (via `create_model`) e o encapsula em um pipeline completo
# de pré-processamento + balanceamento (via `build_pipeline`), garantindo que todas as transformações
# sejam aplicadas corretamente dentro de cada fold e evitando *data leakage*.
#
# A avaliação é realizada com **validação cruzada estratificada** (`StratifiedKFold`),
# preservando a proporção de classes em treino e validação. Em cada fold:
# - o pipeline é treinado no subconjunto de treino (`fit`),
# - e a performance é medida no subconjunto de validação por **ROC-AUC** calculado a partir de probabilidades (`predict_proba`).
#
# Para suportar cenários multiclasse, o AUC é calculado com `multi_class='ovr'`
# e agregação `average='weighted'`, o que pondera o desempenho pelo suporte de cada classe
# e reduz distorções em bases desbalanceadas.
#
# Além disso, a função utiliza mecanismos de *early stopping* do Optuna:
# - `trial.report` comunica a métrica parcial por fold,
# - `trial.should_prune()` permite interromper tentativas com desempenho fraco,
# economizando tempo computacional e acelerando a convergência do processo de otimização.
#
# Ao final, a função retorna a média do AUC entre os folds, que é o valor maximizado pelo Optuna.

# %%
def objective(trial, X_train, y_train, cat_cols, num_cols,feature_names, gpu_info):

    model = create_model(trial, gpu_info)

    pipe = build_pipeline(model ,cat_cols, num_cols)


    cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

    scores = []
    for step, (train_idx, val_idx) in enumerate(cv.split(X_train, y_train)):

        X_tr, X_val = X_train.iloc[train_idx], X_train.iloc[val_idx]
        y_tr, y_val = y_train.iloc[train_idx], y_train.iloc[val_idx]


        pipe.fit(X_tr, y_tr)
        fold_auc = roc_auc_score(y_val, pipe.predict_proba(X_val)[:, 1])
        scores.append(fold_auc)

        #  reporta o valor parcial ao Optuna
        trial.report(fold_auc, step=step)

        #  aborta a tentativa dado a avaliação do pruner
        if trial.should_prune():
            raise TrialPruned()


    return np.mean(scores)

# %% [markdown]
# Salva o histórico das trials do Optuna (métrica, parâmetros, estado e duração)
# em arquivo CSV para análise e rastreabilidade do processo de otimização.

# %%
# salva os logs das tentativas com métricas, tempo de treinamento, e parametros utilizados pelos modelos
def dump_trials(study, trial):
    df_metrics = study.trials_dataframe(attrs=("number", "value", "params", "state","duration"))
    df_metrics.to_csv("log_opt/trials_log_v2.csv", index=False)

# %% [markdown]
# ### 3. VALIDAÇÃO EXTERNA (OUTER CV) + OPTUNA INTERNO

# %% [markdown]
# ### Função `outer_cv_training_with_results`: nested CV com Optuna, checkpoint e métricas por fold
#
# Esta função executa um processo completo de treinamento e avaliação com **validação cruzada externa**
# (*outer cross-validation*), integrando **otimização de hiperparâmetros com Optuna** dentro de cada fold
# e registrando resultados detalhados (modelo escolhido, métricas, tempo e artefatos salvos).
#
# O fluxo segue a lógica de *nested cross-validation*:
#
# 1) **Diagnóstico do ambiente (GPU)**
# Antes do treinamento, a função identifica a disponibilidade de GPU (`detect_gpu`), permitindo que a criação dos modelos
# ative parâmetros específicos de aceleração quando suportado.
#
# 2) **Validação cruzada externa (generalização)**
# É aplicada uma `StratifiedKFold` externa com `n_splits`, garantindo que a proporção das classes seja preservada em cada divisão.
# Em cada fold externo, o conjunto é particionado em `X_train/y_train` (para otimização e treino) e `X_test/y_test` (avaliação final).
#
# 3) **Otimização interna com Optuna (seleção de modelo + hiperparâmetros)**
# Para cada fold externo, um `study` é criado com objetivo de maximizar a métrica definida na função `objective`.
# A função `objective` é “fixada” via `partial`, injetando os dados do fold e metadados do pipeline (colunas numéricas e categóricas,
# GPU, etc.), de forma que cada trial avalie modelos e hiperparâmetros sob o mesmo protocolo.
#
# O estudo é executado com:
# - `n_trials` tentativas,
# - controle de tempo (`timeout`),
# - paralelismo (`n_jobs=-1`),
# - callback de logging (`dump_trials`) para persistir histórico das trials.
#
# 4) **Treinamento final do melhor modelo no fold e checkpoint**
# Após a otimização, a melhor configuração é recuperada (`study.best_params`) e o melhor modelo é reconstruído (`create_model`),
# sendo então encapsulado em um pipeline (`build_pipeline`) com pré-processamento e SMOTE.
# O pipeline é treinado no conjunto de treino do fold com medição de tempo, e o artefato final é salvo em disco (`joblib.dump`)
# como checkpoint (`best_model_fold_k.pkl`), garantindo reprodutibilidade e possibilidade de reuso posterior.
#
# 5) **Avaliação no conjunto de teste do fold (métricas completas)**
# O modelo treinado é avaliado no `X_test/y_test` do fold externo usando:
# - **ROC-AUC multiclasse** com estratégia OvR e média ponderada (`average='weighted'`),
# - além de `accuracy`, `f1`, `recall` e `precision` (também ponderadas), adequadas para cenários desbalanceados.
#
# Ao final, a função retorna uma lista de dicionários com os resultados de cada fold,
# incluindo o modelo vencedor, hiperparâmetros, métricas, tempo de treino e caminho do checkpoint.
# Isso permite comparar estabilidade do desempenho entre folds e estimar capacidade real de generalização.

# %%
def outer_cv_training_with_results(
    X, y, cat_cols, num_cols, n_trials=30, n_splits=5
):

    gpu_info = detect_gpu()
    print("\n🔍 GPU detectada:", gpu_info)

    outer_cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
    results = []
    feature_names = X.columns
    fold = 1
    for train_idx, test_idx in outer_cv.split(X, y):

        print(f"\n==============================")
        print(f"  Fold Externo {fold}/{n_splits}")
        print(f"==============================")

        X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

        pruner = SuccessiveHalvingPruner(min_resource=1,
                                 reduction_factor=3,
                                 min_early_stopping_rate=1)

        study = optuna.create_study(direction="maximize")

        objective_fixed = partial(objective,
                          X_train=X_train,
                          y_train=y_train,
                          cat_cols=cat_cols,
                          num_cols=num_cols,
                          feature_names=feature_names,
                          gpu_info=gpu_info)

        study.optimize(objective_fixed,
                      n_trials=n_trials,
                      callbacks=[dump_trials],
                      timeout=1800,
                      n_jobs=-1,
                      )

        best_params = study.best_params
        best_model_name = best_params["model_name"]
        best_model = create_model(study.best_trial, gpu_info)


        pipe = build_pipeline(best_model ,cat_cols, num_cols)

        # treino com timer
        start_time = time.time()
        pipe.fit(X_train, y_train)
        train_time = time.time() - start_time

        # CHECKPOINT
        checkpoint_dir = "checkpoints_best_models"
        if not os.path.exists(checkpoint_dir):
            os.makedirs(checkpoint_dir)

        checkpoint_path = os.path.join(
            checkpoint_dir, f"best_model_fold_{fold}.pkl"
        )
        joblib.dump(pipe, checkpoint_path)

        # predição
        y_pred = pipe.predict(X_test)
        y_pred_prob = pipe.predict_proba(X_test)[:, 1]

        # métricas
        auc = roc_auc_score(y_test, y_pred_prob)
        acc = accuracy_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)
        rec = recall_score(y_test, y_pred)
        prec = precision_score(y_test, y_pred)

        # salvar dados do fold
        results.append({
            "fold": fold,
            "best_model": best_model_name,
            "auc": auc,
            "accuracy": acc,
            "f1": f1,
            "recall": rec,
            "precision": prec,
            "hyperparameters": best_params,
            "checkpoint_path": checkpoint_path,
            "train_time_seconds": train_time,
            #"test_data": {
            #    "X_test": X_test.copy(),
            #    "y_test": y_test.reset_index(drop=True),
            #    "y_pred": pd.Series(y_pred)
            #}
        })

        fold += 1

    return results

# %% [markdown]
# # Execute Framework

# %% [markdown]
# Cria os diretórios de checkpoints de modelos e logs de otimização,
# caso não existam, garantindo persistência e organização dos artefatos do experimento.

# %%
import os, joblib
checkpoint_dir = "checkpoints_best_models"

if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)

checkpoint_dir = "log_opt"
if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)


# ================================================

# %% [markdown]
# ### Execução do treinamento com validação cruzada externa e otimização de hiperparâmetros
#
# Nesta etapa, o conjunto de dados é preparado para o processo completo de treinamento e avaliação.
# Inicialmente, as colunas são classificadas em **categóricas** e **numéricas** por meio da função
# `get_feature_types`, garantindo que o pré-processamento subsequente seja aplicado de forma adequada
# a cada tipo de variável.
#
# Em seguida, é executado o procedimento de **validação cruzada externa** (*outer cross-validation*),
# no qual, para cada fold, ocorre uma otimização interna de hiperparâmetros via Optuna.
# Esse desenho experimental permite avaliar o desempenho dos modelos de forma mais realista,
# uma vez que o conjunto de teste de cada fold permanece completamente isolado do processo de tuning.
#
# Os parâmetros utilizados (`n_trials=30` e `n_splits=5`) definem, respectivamente,
# o orçamento de busca de hiperparâmetros em cada fold e o número de partições externas,
# balanceando custo computacional e robustez estatística.
#
# O resultado final (`df_results`) contém métricas, hiperparâmetros selecionados,
# tempos de treinamento e caminhos dos checkpoints para cada fold,
# servindo como base para análises comparativas e seleção do modelo final.

# %%
cat_cols, num_cols = get_feature_types(X_data)
df_results = outer_cv_training_with_results(
    X_data, y_data,
    cat_cols=cat_cols,
    num_cols=num_cols,
    n_trials=30,
    n_splits=5
)
# Out:
# [I 2025-11-17 02:16:04,641] A new study created in memory with name: no-name-fc6fe34b-1f5d-4758-979d-ab9b6128891d
# 🔍 GPU detectada: {'cuda_available': False, 'lightgbm_gpu': False, 'gpu_info': 'Nenhuma GPU detectada (nvidia-smi não disponível)'}
#
# ==============================
#   Fold Externo 1/5
# ==============================
# [I 2025-11-17 02:16:10,918] Trial 1 finished with value: 0.9115050530768682 and parameters: {'model_name': 'lightgbm', 'n_estimators': 15, 'learning_rate': 0.14853294748717483, 'max_depth': 3, 'subsample': 0.6326852414237186, 'colsample_bytree': 0.9171599393826481}. Best is trial 1 with value: 0.9115050530768682.
# [I 2025-11-17 02:16:14,816] Trial 2 finished with value: 0.911001223720796 and parameters: {'model_name': 'lightgbm', 'n_estimators': 8, 'learning_rate': 0.16496644799384175, 'max_depth': 8, 'subsample': 0.7855599662118682, 'colsample_bytree': 0.7853008992807169}. Best is trial 1 with value: 0.9115050530768682.
# [I 2025-11-17 02:16:19,427] Trial 0 finished with value: 0.9031336742704358 and parameters: {'model_name': 'svm', 'C': 1.5503354749844176}. Best is trial 1 with value: 0.9115050530768682.
# [I 2025-11-17 02:16:24,271] Trial 3 finished with value: 0.9133218835597944 and parameters: {'model_name': 'xgboost', 'n_estimators': 12, 'max_depth': 6, 'learning_rate': 0.2809353857015555, 'subsample': 0.500267991636973, 'colsample_bytree': 0.7695123461014377}. Best is trial 3 with value: 0.9133218835597944.
# [I 2025-11-17 02:16:24,965] Trial 4 finished with value: 0.9063140634669055 and parameters: {'model_name': 'lightgbm', 'n_estimators': 10, 'learning_rate': 0.037636198587888664, 'max_depth': 7, 'subsample': 0.5451929699851192, 'colsample_bytree': 0.8773077219975726}. Best is trial 3 with value: 0.9133218835597944.
# [I 2025-11-17 02:16:31,973] Trial 6 finished with value: 0.9180607750040007 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.15646022206069424, 'max_depth': 7, 'subsample': 0.8567003500935702, 'colsample_bytree': 0.5606306299137558}. Best is trial 6 with value: 0.9180607750040007.
# [I 2025-11-17 02:16:32,671] Trial 5 pruned.
# [I 2025-11-17 02:16:35,175] Trial 7 pruned.
# [I 2025-11-17 02:16:36,931] Trial 9 pruned.
# [I 2025-11-17 02:16:38,828] Trial 8 finished with value: 0.9138356753538249 and parameters: {'model_name': 'lightgbm', 'n_estimators': 18, 'learning_rate': 0.14778608902310048, 'max_depth': 6, 'subsample': 0.6014903926619868, 'colsample_bytree': 0.5433539576441162}. Best is trial 6 with value: 0.9180607750040007.
# [I 2025-11-17 02:16:42,696] Trial 10 finished with value: 0.9130044901642466 and parameters: {'model_name': 'lightgbm', 'n_estimators': 10, 'learning_rate': 0.16373252675636626, 'max_depth': 8, 'subsample': 0.6790471082503751, 'colsample_bytree': 0.6027941945930162}. Best is trial 6 with value: 0.9180607750040007.
# [I 2025-11-17 02:16:44,385] Trial 12 pruned.
# [I 2025-11-17 02:16:45,213] Trial 11 pruned.
# [I 2025-11-17 02:16:47,208] Trial 13 pruned.
# [I 2025-11-17 02:16:50,509] Trial 15 pruned.
# [I 2025-11-17 02:16:53,261] Trial 14 finished with value: 0.9147922233613786 and parameters: {'model_name': 'lightgbm', 'n_estimators': 23, 'learning_rate': 0.08339529535395154, 'max_depth': 6, 'subsample': 0.9611625352975625, 'colsample_bytree': 0.5132778161869911}. Best is trial 6 with value: 0.9180607750040007.
# [I 2025-11-17 02:16:55,738] Trial 17 pruned.
# [I 2025-11-17 02:16:57,569] Trial 16 finished with value: 0.9145945545180226 and parameters: {'model_name': 'lightgbm', 'n_estimators': 22, 'learning_rate': 0.21804467906646136, 'max_depth': 7, 'subsample': 0.8964644187610792, 'colsample_bytree': 0.5062309373496044}. Best is trial 6 with value: 0.9180607750040007.
# [I 2025-11-17 02:17:03,880] Trial 18 pruned.
# [I 2025-11-17 02:17:05,657] Trial 19 pruned.
# [I 2025-11-17 02:17:06,851] Trial 20 pruned.
# [I 2025-11-17 02:17:09,035] Trial 21 pruned.
# [I 2025-11-17 02:17:13,423] Trial 22 finished with value: 0.9153527666004173 and parameters: {'model_name': 'lightgbm', 'n_estimators': 22, 'learning_rate': 0.20351446911926827, 'max_depth': 7, 'subsample': 0.8920376514275904, 'colsample_bytree': 0.5048086858647087}. Best is trial 6 with value: 0.9180607750040007.
# [I 2025-11-17 02:17:15,756] Trial 23 finished with value: 0.9144400488006225 and parameters: {'model_name': 'lightgbm', 'n_estimators': 22, 'learning_rate': 0.22940549144715866, 'max_depth': 7, 'subsample': 0.905193195726371, 'colsample_bytree': 0.5011628395947776}. Best is trial 6 with value: 0.9180607750040007.
# [I 2025-11-17 02:17:19,921] Trial 25 pruned.
# [I 2025-11-17 02:17:20,775] Trial 24 finished with value: 0.9155138030669132 and parameters: {'model_name': 'lightgbm', 'n_estimators': 22, 'learning_rate': 0.20744249818974683, 'max_depth': 8, 'subsample': 0.922113814127206, 'colsample_bytree': 0.5833143425234045}. Best is trial 6 with value: 0.9180607750040007.
# [I 2025-11-17 02:17:21,915] Trial 27 pruned.
# [I 2025-11-17 02:17:25,072] Trial 26 finished with value: 0.9162947320004625 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.19115798102821074, 'max_depth': 7, 'subsample': 0.9859896039649363, 'colsample_bytree': 0.570343946028681}. Best is trial 6 with value: 0.9180607750040007.
# [I 2025-11-17 02:17:28,017] Trial 29 pruned.
# [I 2025-11-17 02:17:28,254] Trial 28 finished with value: 0.9146634920118754 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.24255495027357957, 'max_depth': 9, 'subsample': 0.7101196142023114, 'colsample_bytree': 0.5795237905106614}. Best is trial 6 with value: 0.9180607750040007.
# [LightGBM] [Info] Number of positive: 5032, number of negative: 5032
# [LightGBM] [Info] Total Bins 25926
# [LightGBM] [Info] Number of data points in the train set: 10064, number of used features: 204
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-11-17 02:17:31,016] A new study created in memory with name: no-name-8e0dfdda-cbad-4b99-bc98-41b5f574f701
# ==============================
#   Fold Externo 2/5
# ==============================
# [I 2025-11-17 02:17:35,939] Trial 1 finished with value: 0.9066398173497069 and parameters: {'model_name': 'lightgbm', 'n_estimators': 9, 'learning_rate': 0.22098572738066086, 'max_depth': 9, 'subsample': 0.7002476558162621, 'colsample_bytree': 0.8498293314862975}. Best is trial 1 with value: 0.9066398173497069.
# [I 2025-11-17 02:17:43,455] Trial 2 finished with value: 0.9095129751657648 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.023193311812501487, 'max_depth': 7, 'subsample': 0.6875133557248716, 'colsample_bytree': 0.806113829385465}. Best is trial 2 with value: 0.9095129751657648.
# [I 2025-11-17 02:17:48,320] Trial 3 finished with value: 0.9096451318883965 and parameters: {'model_name': 'lightgbm', 'n_estimators': 8, 'learning_rate': 0.29106893848778836, 'max_depth': 5, 'subsample': 0.7361606845986188, 'colsample_bytree': 0.8173230465411191}. Best is trial 3 with value: 0.9096451318883965.
# [I 2025-11-17 02:17:48,600] Trial 0 finished with value: 0.8988095284811616 and parameters: {'model_name': 'svm', 'C': 0.990173425513711}. Best is trial 3 with value: 0.9096451318883965.
# [I 2025-11-17 02:17:53,735] Trial 4 finished with value: 0.8862628404601524 and parameters: {'model_name': 'random_forest', 'n_estimators': 12, 'max_depth': 7, 'min_samples_split': 2, 'min_samples_leaf': 4}. Best is trial 3 with value: 0.9096451318883965.
# [I 2025-11-17 02:17:56,831] Trial 5 pruned.
# [I 2025-11-17 02:17:57,716] Trial 6 pruned.
# [I 2025-11-17 02:17:59,658] Trial 7 pruned.
# [I 2025-11-17 02:18:04,714] Trial 9 pruned.
# [I 2025-11-17 02:18:08,128] Trial 8 pruned.
# [I 2025-11-17 02:18:13,431] Trial 11 finished with value: 0.914044213153415 and parameters: {'model_name': 'lightgbm', 'n_estimators': 16, 'learning_rate': 0.28735177357441655, 'max_depth': 4, 'subsample': 0.9936476410801587, 'colsample_bytree': 0.5097067417010528}. Best is trial 11 with value: 0.914044213153415.
# [I 2025-11-17 02:18:15,460] Trial 10 finished with value: 0.9129427350628331 and parameters: {'model_name': 'xgboost', 'n_estimators': 30, 'max_depth': 4, 'learning_rate': 0.21089131941549863, 'subsample': 0.8314867263182207, 'colsample_bytree': 0.514657860680406}. Best is trial 11 with value: 0.914044213153415.
# [I 2025-11-17 02:18:17,545] Trial 12 finished with value: 0.9118533172161655 and parameters: {'model_name': 'lightgbm', 'n_estimators': 17, 'learning_rate': 0.29894900439009436, 'max_depth': 4, 'subsample': 0.95427905049636, 'colsample_bytree': 0.5228320519328179}. Best is trial 11 with value: 0.914044213153415.
# [I 2025-11-17 02:18:21,038] Trial 13 finished with value: 0.9128857288315823 and parameters: {'model_name': 'xgboost', 'n_estimators': 18, 'max_depth': 4, 'learning_rate': 0.29729621527431976, 'subsample': 0.9790588589544662, 'colsample_bytree': 0.5020909249927684}. Best is trial 11 with value: 0.914044213153415.
# [I 2025-11-17 02:18:25,109] Trial 14 finished with value: 0.91268948664224 and parameters: {'model_name': 'xgboost', 'n_estimators': 20, 'max_depth': 5, 'learning_rate': 0.1750836829241484, 'subsample': 0.9768262580124256, 'colsample_bytree': 0.5180556159148638}. Best is trial 11 with value: 0.914044213153415.
# [I 2025-11-17 02:18:26,482] Trial 16 pruned.
# [I 2025-11-17 02:18:29,025] Trial 15 finished with value: 0.9118994276844022 and parameters: {'model_name': 'xgboost', 'n_estimators': 20, 'max_depth': 5, 'learning_rate': 0.18084685481543777, 'subsample': 0.8670866358308944, 'colsample_bytree': 0.6369823027639867}. Best is trial 11 with value: 0.914044213153415.
# [I 2025-11-17 02:18:31,416] Trial 17 finished with value: 0.9123167024397109 and parameters: {'model_name': 'lightgbm', 'n_estimators': 22, 'learning_rate': 0.13306247930314682, 'max_depth': 5, 'subsample': 0.8611268454730084, 'colsample_bytree': 0.9674284689094291}. Best is trial 11 with value: 0.914044213153415.
# [I 2025-11-17 02:18:32,651] Trial 18 finished with value: 0.9132303770029497 and parameters: {'model_name': 'lightgbm', 'n_estimators': 23, 'learning_rate': 0.11927334898518609, 'max_depth': 4, 'subsample': 0.5431224511492596, 'colsample_bytree': 0.6005847740963716}. Best is trial 11 with value: 0.914044213153415.
# [I 2025-11-17 02:18:33,863] Trial 20 pruned.
# [I 2025-11-17 02:18:35,832] Trial 21 pruned.
# [I 2025-11-17 02:18:38,212] Trial 22 pruned.
# [I 2025-11-17 02:18:38,444] Trial 19 pruned.
# [I 2025-11-17 02:18:44,054] Trial 24 finished with value: 0.9150207665975744 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.10064706429805904, 'max_depth': 4, 'subsample': 0.6050065529467807, 'colsample_bytree': 0.5700670331623492}. Best is trial 24 with value: 0.9150207665975744.
# [I 2025-11-17 02:18:44,121] Trial 23 pruned.
# [I 2025-11-17 02:18:49,791] Trial 25 finished with value: 0.9118626875190246 and parameters: {'model_name': 'lightgbm', 'n_estimators': 23, 'learning_rate': 0.08724209083896453, 'max_depth': 6, 'subsample': 0.5970391767247327, 'colsample_bytree': 0.5934891474458308}. Best is trial 24 with value: 0.9150207665975744.
# [I 2025-11-17 02:18:50,024] Trial 26 finished with value: 0.9122075439692465 and parameters: {'model_name': 'lightgbm', 'n_estimators': 24, 'learning_rate': 0.09514391253988921, 'max_depth': 6, 'subsample': 0.5919059823596143, 'colsample_bytree': 0.584299469089927}. Best is trial 24 with value: 0.9150207665975744.
# [I 2025-11-17 02:18:51,243] Trial 0 finished with value: 0.9194748559912838 and parameters: {'model_name': 'svm', 'C': 1.2299071978590037}. Best is trial 0 with value: 0.9194748559912838.
# [I 2025-11-17 02:18:51,757] Trial 27 pruned.
# [I 2025-11-17 02:18:51,988] Trial 28 pruned.
# [I 2025-11-17 02:18:52,443] Trial 29 pruned.
# [LightGBM] [Info] Number of positive: 5032, number of negative: 5032
# [LightGBM] [Info] Total Bins 25690
# [LightGBM] [Info] Number of data points in the train set: 10064, number of used features: 203
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [I 2025-11-17 02:18:53,480] A new study created in memory with name: no-name-1bf3cf9e-1bf2-4153-9fe5-fd05900c5d84
# ==============================
#   Fold Externo 3/5
# ==============================
# [I 2025-11-17 02:18:55,995] Trial 1 finished with value: 0.9029585333676294 and parameters: {'model_name': 'lightgbm', 'n_estimators': 7, 'learning_rate': 0.058636891640975304, 'max_depth': 9, 'subsample': 0.7449630339098855, 'colsample_bytree': 0.7638222034686619}. Best is trial 1 with value: 0.9029585333676294.
# [I 2025-11-17 02:18:57,799] Trial 0 finished with value: 0.9002759076161188 and parameters: {'model_name': 'random_forest', 'n_estimators': 27, 'max_depth': 8, 'min_samples_split': 4, 'min_samples_leaf': 2}. Best is trial 1 with value: 0.9029585333676294.
# [I 2025-11-17 02:18:59,409] Trial 2 finished with value: 0.9066168091327155 and parameters: {'model_name': 'lightgbm', 'n_estimators': 14, 'learning_rate': 0.16463488362438014, 'max_depth': 8, 'subsample': 0.7604315939587173, 'colsample_bytree': 0.8561513613166152}. Best is trial 2 with value: 0.9066168091327155.
# [I 2025-11-17 02:18:59,973] Trial 3 finished with value: 0.867532327283814 and parameters: {'model_name': 'random_forest', 'n_estimators': 11, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 5}. Best is trial 2 with value: 0.9066168091327155.
# [I 2025-11-17 02:19:04,328] Trial 4 finished with value: 0.8991180669377002 and parameters: {'model_name': 'random_forest', 'n_estimators': 27, 'max_depth': 6, 'min_samples_split': 9, 'min_samples_leaf': 4}. Best is trial 2 with value: 0.9066168091327155.
# [I 2025-11-17 02:19:06,790] Trial 5 pruned.
# [I 2025-11-17 02:19:10,189] Trial 7 pruned.
# [I 2025-11-17 02:19:12,783] Trial 6 pruned.
# [I 2025-11-17 02:19:15,440] Trial 8 finished with value: 0.9071979617328284 and parameters: {'model_name': 'lightgbm', 'n_estimators': 15, 'learning_rate': 0.13999326199169704, 'max_depth': 7, 'subsample': 0.9644741028845081, 'colsample_bytree': 0.9691682859557718}. Best is trial 8 with value: 0.9071979617328284.
# [I 2025-11-17 02:19:18,773] Trial 9 finished with value: 0.9117827642980433 and parameters: {'model_name': 'lightgbm', 'n_estimators': 11, 'learning_rate': 0.2865340770730752, 'max_depth': 5, 'subsample': 0.7432122330343516, 'colsample_bytree': 0.8378604567014337}. Best is trial 9 with value: 0.9117827642980433.
# [I 2025-11-17 02:19:22,618] Trial 10 pruned.
# [I 2025-11-17 02:19:22,777] Trial 11 pruned.
# [I 2025-11-17 02:19:28,653] Trial 13 pruned.
# [I 2025-11-17 02:19:29,898] Trial 12 finished with value: 0.9099737663070538 and parameters: {'model_name': 'lightgbm', 'n_estimators': 17, 'learning_rate': 0.29786316903422605, 'max_depth': 4, 'subsample': 0.9927468379023459, 'colsample_bytree': 0.9965436929777856}. Best is trial 9 with value: 0.9117827642980433.
# [I 2025-11-17 02:19:33,844] Trial 14 finished with value: 0.9079202880984076 and parameters: {'model_name': 'lightgbm', 'n_estimators': 6, 'learning_rate': 0.07394506833493791, 'max_depth': 6, 'subsample': 0.9951421062758097, 'colsample_bytree': 0.5834680206373392}. Best is trial 9 with value: 0.9117827642980433.
# [I 2025-11-17 02:19:34,685] Trial 15 finished with value: 0.9098608510979785 and parameters: {'model_name': 'lightgbm', 'n_estimators': 9, 'learning_rate': 0.2898173180616557, 'max_depth': 4, 'subsample': 0.8486492923226338, 'colsample_bytree': 0.5588434205910818}. Best is trial 9 with value: 0.9117827642980433.
# [I 2025-11-17 02:19:35,954] Trial 1 finished with value: 0.9192838020667528 and parameters: {'model_name': 'svm', 'C': 1.6099374182799868}. Best is trial 0 with value: 0.9194748559912838.
# [I 2025-11-17 02:19:37,557] Trial 16 finished with value: 0.9131397667188578 and parameters: {'model_name': 'lightgbm', 'n_estimators': 20, 'learning_rate': 0.29966197171246167, 'max_depth': 4, 'subsample': 0.857430528962006, 'colsample_bytree': 0.6423802910576049}. Best is trial 16 with value: 0.9131397667188578.
# [I 2025-11-17 02:19:37,717] Trial 17 finished with value: 0.9113280289626938 and parameters: {'model_name': 'lightgbm', 'n_estimators': 20, 'learning_rate': 0.2506380364470056, 'max_depth': 3, 'subsample': 0.6372738184480541, 'colsample_bytree': 0.6661386714769185}. Best is trial 16 with value: 0.9131397667188578.
# [I 2025-11-17 02:19:39,340] Trial 18 finished with value: 0.9120531767769338 and parameters: {'model_name': 'lightgbm', 'n_estimators': 22, 'learning_rate': 0.23077431309327834, 'max_depth': 3, 'subsample': 0.6594017329112319, 'colsample_bytree': 0.6518917094352663}. Best is trial 16 with value: 0.9131397667188578.
# [I 2025-11-17 02:19:41,055] Trial 19 finished with value: 0.9141127178090015 and parameters: {'model_name': 'xgboost', 'n_estimators': 22, 'max_depth': 5, 'learning_rate': 0.22334321014475922, 'subsample': 0.8547837545679458, 'colsample_bytree': 0.6668736329470514}. Best is trial 19 with value: 0.9141127178090015.
# [I 2025-11-17 02:19:41,652] Trial 20 pruned.
# [I 2025-11-17 02:19:45,732] Trial 21 finished with value: 0.9125391675543751 and parameters: {'model_name': 'xgboost', 'n_estimators': 23, 'max_depth': 5, 'learning_rate': 0.2011446632818234, 'subsample': 0.8911785566995394, 'colsample_bytree': 0.66884089871117}. Best is trial 19 with value: 0.9141127178090015.
# [I 2025-11-17 02:19:46,847] Trial 22 finished with value: 0.9118339185110206 and parameters: {'model_name': 'xgboost', 'n_estimators': 30, 'max_depth': 5, 'learning_rate': 0.22443082695671746, 'subsample': 0.6458989805223614, 'colsample_bytree': 0.6607698704933176}. Best is trial 19 with value: 0.9141127178090015.
# [I 2025-11-17 02:19:49,805] Trial 23 finished with value: 0.9160651381069181 and parameters: {'model_name': 'xgboost', 'n_estimators': 30, 'max_depth': 5, 'learning_rate': 0.19036885125180128, 'subsample': 0.9008519140397624, 'colsample_bytree': 0.70588417431983}. Best is trial 23 with value: 0.9160651381069181.
# [I 2025-11-17 02:19:50,338] Trial 24 pruned.
# [I 2025-11-17 02:19:51,358] Trial 26 pruned.
# [I 2025-11-17 02:19:53,294] Trial 25 pruned.
# [I 2025-11-17 02:19:55,798] Trial 27 finished with value: 0.9150885742768863 and parameters: {'model_name': 'xgboost', 'n_estimators': 27, 'max_depth': 6, 'learning_rate': 0.25363030511401086, 'subsample': 0.9202508788540331, 'colsample_bytree': 0.5974749240090649}. Best is trial 23 with value: 0.9160651381069181.
# [I 2025-11-17 02:19:58,580] Trial 28 finished with value: 0.9156577895793631 and parameters: {'model_name': 'xgboost', 'n_estimators': 26, 'max_depth': 6, 'learning_rate': 0.2497299023882278, 'subsample': 0.9293826078593393, 'colsample_bytree': 0.6065350188039924}. Best is trial 23 with value: 0.9160651381069181.
# [I 2025-11-17 02:19:59,980] Trial 29 finished with value: 0.9138575249846008 and parameters: {'model_name': 'xgboost', 'n_estimators': 27, 'max_depth': 6, 'learning_rate': 0.2594802489621277, 'subsample': 0.9261637684234806, 'colsample_bytree': 0.5954814251436831}. Best is trial 23 with value: 0.9160651381069181.
# [I 2025-11-17 02:20:00,993] A new study created in memory with name: no-name-262c9658-bc01-4322-b361-1253ede3e606
# ==============================
#   Fold Externo 4/5
# ==============================
# [I 2025-11-17 02:20:02,335] Trial 1 finished with value: 0.8754271791757814 and parameters: {'model_name': 'random_forest', 'n_estimators': 12, 'max_depth': 4, 'min_samples_split': 5, 'min_samples_leaf': 3}. Best is trial 1 with value: 0.8754271791757814.
# [I 2025-11-17 02:20:06,902] Trial 2 finished with value: 0.9042867271517423 and parameters: {'model_name': 'xgboost', 'n_estimators': 15, 'max_depth': 7, 'learning_rate': 0.2066085065296587, 'subsample': 0.5900714799661588, 'colsample_bytree': 0.936600875957657}. Best is trial 2 with value: 0.9042867271517423.
# [I 2025-11-17 02:20:08,452] Trial 0 finished with value: 0.9056732675900401 and parameters: {'model_name': 'xgboost', 'n_estimators': 22, 'max_depth': 9, 'learning_rate': 0.2394158247731712, 'subsample': 0.7044302531044603, 'colsample_bytree': 0.7684693346052343}. Best is trial 0 with value: 0.9056732675900401.
# [I 2025-11-17 02:20:12,292] Trial 4 finished with value: 0.8829936742908581 and parameters: {'model_name': 'xgboost', 'n_estimators': 6, 'max_depth': 9, 'learning_rate': 0.09774886240630894, 'subsample': 0.7241070630311388, 'colsample_bytree': 0.705502487775215}. Best is trial 0 with value: 0.9056732675900401.
# [I 2025-11-17 02:20:14,791] Trial 3 finished with value: 0.8950878173498579 and parameters: {'model_name': 'svm', 'C': 1.284659235386212}. Best is trial 0 with value: 0.9056732675900401.
# [I 2025-11-17 02:20:15,282] Trial 6 pruned.
# [I 2025-11-17 02:20:19,505] Trial 5 finished with value: 0.8945748369462504 and parameters: {'model_name': 'svm', 'C': 1.698016962056128}. Best is trial 0 with value: 0.9056732675900401.
# [I 2025-11-17 02:20:20,176] Trial 8 pruned.
# [I 2025-11-17 02:20:21,850] Trial 9 pruned.
# [I 2025-11-17 02:20:22,979] Trial 7 finished with value: 0.8942369645047602 and parameters: {'model_name': 'svm', 'C': 2.049089447465691}. Best is trial 0 with value: 0.9056732675900401.
# [I 2025-11-17 02:20:24,144] Trial 11 pruned.
# [I 2025-11-17 02:20:25,529] Trial 10 finished with value: 0.90926302580894 and parameters: {'model_name': 'lightgbm', 'n_estimators': 22, 'learning_rate': 0.1491359689094217, 'max_depth': 8, 'subsample': 0.6871444692761877, 'colsample_bytree': 0.8047477867758133}. Best is trial 10 with value: 0.90926302580894.
# [I 2025-11-17 02:20:27,819] Trial 13 finished with value: 0.9101173880972605 and parameters: {'model_name': 'lightgbm', 'n_estimators': 22, 'learning_rate': 0.17095954116727513, 'max_depth': 8, 'subsample': 0.6052927500803409, 'colsample_bytree': 0.7701081839927026}. Best is trial 13 with value: 0.9101173880972605.
# [I 2025-11-17 02:20:30,365] Trial 14 finished with value: 0.9096673985048981 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.14984098053339265, 'max_depth': 7, 'subsample': 0.5160520145699647, 'colsample_bytree': 0.7822354748481187}. Best is trial 13 with value: 0.9101173880972605.
# [I 2025-11-17 02:20:30,583] Trial 12 finished with value: 0.9057938984133197 and parameters: {'model_name': 'xgboost', 'n_estimators': 21, 'max_depth': 8, 'learning_rate': 0.23402074860142796, 'subsample': 0.505216396356933, 'colsample_bytree': 0.937829531812382}. Best is trial 13 with value: 0.9101173880972605.
# [I 2025-11-17 02:20:32,936] Trial 15 finished with value: 0.9070555129267852 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.13928562084272622, 'max_depth': 7, 'subsample': 0.5168298825397437, 'colsample_bytree': 0.6555955751146108}. Best is trial 13 with value: 0.9101173880972605.
# [I 2025-11-17 02:20:33,119] Trial 16 finished with value: 0.9070599805502201 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.14513995232766327, 'max_depth': 7, 'subsample': 0.5057604151687075, 'colsample_bytree': 0.6497669601769549}. Best is trial 13 with value: 0.9101173880972605.
# [I 2025-11-17 02:20:35,482] Trial 17 finished with value: 0.9090498425981014 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.09624697640850617, 'max_depth': 5, 'subsample': 0.6065004575157309, 'colsample_bytree': 0.8267716220188502}. Best is trial 13 with value: 0.9101173880972605.
# [I 2025-11-17 02:20:35,779] Trial 18 finished with value: 0.9076377835411211 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.0889646399160922, 'max_depth': 5, 'subsample': 0.6183281522218191, 'colsample_bytree': 0.8347181488224713}. Best is trial 13 with value: 0.9101173880972605.
# [I 2025-11-17 02:20:39,011] Trial 20 finished with value: 0.9090203202592978 and parameters: {'model_name': 'lightgbm', 'n_estimators': 18, 'learning_rate': 0.17608496849594427, 'max_depth': 8, 'subsample': 0.8452070157800817, 'colsample_bytree': 0.7152444960776224}. Best is trial 13 with value: 0.9101173880972605.
# [I 2025-11-17 02:20:39,202] Trial 19 finished with value: 0.9074531127317115 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.18757457981907907, 'max_depth': 8, 'subsample': 0.8279555042523219, 'colsample_bytree': 0.8596335109957345}. Best is trial 13 with value: 0.9101173880972605.
# [I 2025-11-17 02:20:41,527] Trial 22 finished with value: 0.9087242293751613 and parameters: {'model_name': 'lightgbm', 'n_estimators': 21, 'learning_rate': 0.13625470293954559, 'max_depth': 8, 'subsample': 0.6558469638261044, 'colsample_bytree': 0.7753674985431693}. Best is trial 13 with value: 0.9101173880972605.
# [I 2025-11-17 02:20:41,766] Trial 21 finished with value: 0.9092881043873962 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.20191238553407234, 'max_depth': 7, 'subsample': 0.8175080681588439, 'colsample_bytree': 0.8772047574330948}. Best is trial 13 with value: 0.9101173880972605.
# [I 2025-11-17 02:20:43,657] Trial 23 finished with value: 0.9102615499983084 and parameters: {'model_name': 'lightgbm', 'n_estimators': 17, 'learning_rate': 0.15515684312042147, 'max_depth': 7, 'subsample': 0.5760076913651354, 'colsample_bytree': 0.7931519417099824}. Best is trial 23 with value: 0.9102615499983084.
# [I 2025-11-17 02:20:44,478] Trial 24 finished with value: 0.9072537237164774 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.21455170095140763, 'max_depth': 7, 'subsample': 0.8116438954844847, 'colsample_bytree': 0.8875358230057249}. Best is trial 23 with value: 0.9102615499983084.
# [I 2025-11-17 02:20:44,972] Trial 25 pruned.
# [I 2025-11-17 02:20:45,839] Trial 26 pruned.
# [I 2025-11-17 02:20:46,552] Trial 28 pruned.
# [I 2025-11-17 02:20:47,073] Trial 27 finished with value: 0.9076260866554374 and parameters: {'model_name': 'lightgbm', 'n_estimators': 19, 'learning_rate': 0.059547288890767214, 'max_depth': 6, 'subsample': 0.5584333906906838, 'colsample_bytree': 0.6627375634770081}. Best is trial 23 with value: 0.9102615499983084.
# [I 2025-11-17 02:20:47,164] Trial 29 pruned.
# [LightGBM] [Info] Number of positive: 5032, number of negative: 5032
# [LightGBM] [Info] Total Bins 25745
# [LightGBM] [Info] Number of data points in the train set: 10064, number of used features: 198
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-11-17 02:20:47,836] A new study created in memory with name: no-name-30131397-e373-4a6d-9dc9-ab79a82f4943
# ==============================
#   Fold Externo 5/5
# ==============================
# [I 2025-11-17 02:20:50,531] Trial 0 finished with value: 0.907545660665907 and parameters: {'model_name': 'lightgbm', 'n_estimators': 12, 'learning_rate': 0.08823981183059258, 'max_depth': 5, 'subsample': 0.6697206909491271, 'colsample_bytree': 0.8297564697416536}. Best is trial 0 with value: 0.907545660665907.
# [I 2025-11-17 02:20:55,403] Trial 1 finished with value: 0.9012197930027854 and parameters: {'model_name': 'svm', 'C': 1.4576541551308717}. Best is trial 0 with value: 0.907545660665907.
# [I 2025-11-17 02:20:55,541] Trial 2 finished with value: 0.9059846453674213 and parameters: {'model_name': 'xgboost', 'n_estimators': 18, 'max_depth': 8, 'learning_rate': 0.07832842214788766, 'subsample': 0.8806327162665766, 'colsample_bytree': 0.5618069437017228}. Best is trial 0 with value: 0.907545660665907.
# [I 2025-11-17 02:21:01,676] Trial 3 finished with value: 0.9017365068253983 and parameters: {'model_name': 'svm', 'C': 1.07612976236494}. Best is trial 0 with value: 0.907545660665907.
# [I 2025-11-17 02:21:01,928] Trial 4 finished with value: 0.901867310907047 and parameters: {'model_name': 'svm', 'C': 1.0046660810339756}. Best is trial 0 with value: 0.907545660665907.
# [I 2025-11-17 02:21:03,203] Trial 6 pruned.
# [I 2025-11-17 02:21:05,301] Trial 5 finished with value: 0.9122546025948074 and parameters: {'model_name': 'lightgbm', 'n_estimators': 24, 'learning_rate': 0.21996633501161056, 'max_depth': 9, 'subsample': 0.8164562398686592, 'colsample_bytree': 0.790315548463673}. Best is trial 5 with value: 0.9122546025948074.
# [I 2025-11-17 02:21:06,240] Trial 7 finished with value: 0.913341815976103 and parameters: {'model_name': 'lightgbm', 'n_estimators': 20, 'learning_rate': 0.24030228486219038, 'max_depth': 5, 'subsample': 0.7183840787482851, 'colsample_bytree': 0.8523185461803668}. Best is trial 7 with value: 0.913341815976103.
# [I 2025-11-17 02:21:07,703] Trial 8 pruned.
# [I 2025-11-17 02:21:08,571] Trial 9 finished with value: 0.9113762872826457 and parameters: {'model_name': 'lightgbm', 'n_estimators': 21, 'learning_rate': 0.07040940177770937, 'max_depth': 6, 'subsample': 0.6953150361985407, 'colsample_bytree': 0.8442818152491194}. Best is trial 7 with value: 0.913341815976103.
# [I 2025-11-17 02:21:11,183] Trial 10 finished with value: 0.9103065897309047 and parameters: {'model_name': 'xgboost', 'n_estimators': 12, 'max_depth': 7, 'learning_rate': 0.262356611646878, 'subsample': 0.5232846897038952, 'colsample_bytree': 0.9009708102333037}. Best is trial 7 with value: 0.913341815976103.
# [I 2025-11-17 02:21:11,418] Trial 11 finished with value: 0.9141313490193151 and parameters: {'model_name': 'xgboost', 'n_estimators': 29, 'max_depth': 3, 'learning_rate': 0.2786748101954365, 'subsample': 0.504979483346888, 'colsample_bytree': 0.9950900600819717}. Best is trial 11 with value: 0.9141313490193151.
# [I 2025-11-17 02:21:12,456] Trial 13 pruned.
# [I 2025-11-17 02:21:12,915] Trial 12 finished with value: 0.9155386807914416 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.23269196066603393, 'max_depth': 3, 'subsample': 0.8656621889942034, 'colsample_bytree': 0.7114196501981296}. Best is trial 12 with value: 0.9155386807914416.
# [I 2025-11-17 02:21:13,131] Trial 14 pruned.
# [I 2025-11-17 02:21:13,500] Trial 15 pruned.
# [I 2025-11-17 02:21:14,143] Trial 16 pruned.
# [I 2025-11-17 02:21:14,597] Trial 17 pruned.
# [I 2025-11-17 02:21:15,513] Trial 18 pruned.
# [I 2025-11-17 02:21:16,277] Trial 19 pruned.
# [I 2025-11-17 02:21:19,640] Trial 20 pruned.
# [I 2025-11-17 02:21:20,259] Trial 22 pruned.
# [I 2025-11-17 02:21:21,066] Trial 21 finished with value: 0.9124542358986966 and parameters: {'model_name': 'xgboost', 'n_estimators': 25, 'max_depth': 6, 'learning_rate': 0.21045282013631122, 'subsample': 0.8990973917786901, 'colsample_bytree': 0.5573239556172244}. Best is trial 12 with value: 0.9155386807914416.
# [I 2025-11-17 02:21:22,009] Trial 23 pruned.
# [I 2025-11-17 02:21:23,626] Trial 24 finished with value: 0.9164493088923796 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.2484358822651243, 'max_depth': 3, 'subsample': 0.7701807356606535, 'colsample_bytree': 0.7606247675742192}. Best is trial 24 with value: 0.9164493088923796.
# [I 2025-11-17 02:21:24,501] Trial 25 finished with value: 0.9151756399291499 and parameters: {'model_name': 'lightgbm', 'n_estimators': 22, 'learning_rate': 0.26385285679820725, 'max_depth': 3, 'subsample': 0.7762744317467553, 'colsample_bytree': 0.7599141593038173}. Best is trial 24 with value: 0.9164493088923796.
# [I 2025-11-17 02:21:24,868] Trial 26 pruned.
# [I 2025-11-17 02:21:25,507] Trial 28 pruned.
# [I 2025-11-17 02:21:25,718] Trial 27 pruned.
# [I 2025-11-17 02:21:26,308] Trial 29 pruned.
# [LightGBM] [Info] Number of positive: 5032, number of negative: 5032
# [LightGBM] [Info] Total Bins 24829
# [LightGBM] [Info] Number of data points in the train set: 10064, number of used features: 197
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %% [markdown]
# #### Conferir checkpoints intermediarios

# %% [markdown]
# Consolida os resultados da validação cruzada externa em um DataFrame,
# salva o resumo em formato Parquet e carrega os logs das trials do Optuna
# para inspeção e análise do processo de otimização.

# %%
df_results=pd.DataFrame(df_results)

# %%
df_results.to_parquet('df_results.parquet')

# %%
df_metrics = pd.read_csv('log_opt/trials_log_v2.csv')
display(df_metrics)
# Out:
#     number     value  params_C  params_colsample_bytree  params_learning_rate  \
# 0        0  0.907546       NaN                 0.829756              0.088240
# 1        1  0.901220  1.457654                      NaN                   NaN
# 2        2  0.905985       NaN                 0.561807              0.078328
# 3        3  0.901737  1.076130                      NaN                   NaN
# 4        4  0.901867  1.004666                      NaN                   NaN
# 5        5  0.912255       NaN                 0.790316              0.219966
# 6        6  0.901878       NaN                      NaN                   NaN
# 7        7  0.913342       NaN                 0.852319              0.240302
# 8        8  0.904478  2.259790                      NaN                   NaN
# 9        9  0.911376       NaN                 0.844282              0.070409
# 10      10  0.910307       NaN                 0.900971              0.262357
# 11      11  0.914131       NaN                 0.995090              0.278675
# 12      12  0.915539       NaN                 0.711420              0.232692
# 13      13  0.905303       NaN                 0.995534              0.298368
# 14      14  0.878963       NaN                      NaN                   NaN
# 15      15  0.882980       NaN                      NaN                   NaN
# 16      16  0.826718       NaN                 0.657920              0.175528
# 17      17  0.826851       NaN                 0.689981              0.171642
# 18      18  0.915757       NaN                 0.697372              0.155336
# 19      19  0.913482       NaN                 0.686567              0.296354
# 20      20  0.915875       NaN                 0.994005              0.290601
# 21      21  0.912454       NaN                 0.557324              0.210453
# 22      22  0.904132       NaN                 0.910439              0.233910
# 23      23  0.913214       NaN                 0.911447              0.225568
# 24      24  0.916449       NaN                 0.760625              0.248436
# 25      25  0.915176       NaN                 0.759914              0.263853
# 26      26  0.914495       NaN                 0.765495              0.260505
# 27      27  0.912133       NaN                 0.744479              0.119799
# 28      28  0.903977       NaN                 0.639115              0.021090
# 29      29  0.913258       NaN                 0.738010              0.189516
#
#     params_max_depth  params_min_samples_leaf  params_min_samples_split  \
# 0                5.0                      NaN                       NaN
# 1                NaN                      NaN                       NaN
# 2                8.0                      NaN                       NaN
# 3                NaN                      NaN                       NaN
# 4                NaN                      NaN                       NaN
# 5                9.0                      NaN                       NaN
# 6                9.0                      4.0                      10.0
# 7                5.0                      NaN                       NaN
# 8                NaN                      NaN                       NaN
# 9                6.0                      NaN                       NaN
# 10               7.0                      NaN                       NaN
# 11               3.0                      NaN                       NaN
# 12               3.0                      NaN                       NaN
# 13               3.0                      NaN                       NaN
# 14               3.0                      1.0                       2.0
# 15               3.0                      1.0                       2.0
# 16               4.0                      NaN                       NaN
# 17               4.0                      NaN                       NaN
# 18               4.0                      NaN                       NaN
# 19               4.0                      NaN                       NaN
# 20               5.0                      NaN                       NaN
# 21               6.0                      NaN                       NaN
# 22               5.0                      NaN                       NaN
# 23               6.0                      NaN                       NaN
# 24               3.0                      NaN                       NaN
# 25               3.0                      NaN                       NaN
# 26               3.0                      NaN                       NaN
# 27               3.0                      NaN                       NaN
# 28               4.0                      NaN                       NaN
# 29               3.0                      NaN                       NaN
#
#    params_model_name  params_n_estimators  params_subsample     state  \
# 0           lightgbm                 12.0          0.669721  COMPLETE
# 1                svm                  NaN               NaN  COMPLETE
# 2            xgboost                 18.0          0.880633  COMPLETE
# 3                svm                  NaN               NaN  COMPLETE
# 4                svm                  NaN               NaN  COMPLETE
# 5           lightgbm                 24.0          0.816456  COMPLETE
# 6      random_forest                 19.0               NaN    PRUNED
# 7           lightgbm                 20.0          0.718384  COMPLETE
# 8                svm                  NaN               NaN    PRUNED
# 9           lightgbm                 21.0          0.695315  COMPLETE
# 10           xgboost                 12.0          0.523285  COMPLETE
# 11           xgboost                 29.0          0.504979  COMPLETE
# 12          lightgbm                 30.0          0.865662  COMPLETE
# 13           xgboost                 29.0          0.529223    PRUNED
# 14     random_forest                 29.0               NaN    PRUNED
# 15     random_forest                 30.0               NaN    PRUNED
# 16           xgboost                  5.0          0.959347    PRUNED
# 17           xgboost                  5.0          0.994497    PRUNED
# 18          lightgbm                 25.0          0.833366    PRUNED
# 19          lightgbm                 25.0          0.609294    PRUNED
# 20           xgboost                 25.0          0.601337    PRUNED
# 21           xgboost                 25.0          0.899097  COMPLETE
# 22          lightgbm                 14.0          0.740416    PRUNED
# 23          lightgbm                 27.0          0.898923    PRUNED
# 24          lightgbm                 28.0          0.770181  COMPLETE
# 25          lightgbm                 22.0          0.776274  COMPLETE
# 26          lightgbm                 28.0          0.803771    PRUNED
# 27          lightgbm                 22.0          0.795409    PRUNED
# 28          lightgbm                 23.0          0.772002    PRUNED
# 29          lightgbm                 22.0          0.853140    PRUNED
#
#                   duration
# 0   0 days 00:00:02.690009
# 1   0 days 00:00:07.561083
# 2   0 days 00:00:04.989495
# 3   0 days 00:00:06.250246
# 4   0 days 00:00:06.373964
# 5   0 days 00:00:03.611867
# 6   0 days 00:00:01.258871
# 7   0 days 00:00:03.018046
# 8   0 days 00:00:02.383348
# 9   0 days 00:00:02.318710
# 10  0 days 00:00:03.465440
# 11  0 days 00:00:02.835824
# 12  0 days 00:00:01.719186
# 13  0 days 00:00:01.025930
# 14  0 days 00:00:00.664584
# 15  0 days 00:00:00.573016
# 16  0 days 00:00:01.000190
# 17  0 days 00:00:01.077369
# 18  0 days 00:00:01.333076
# 19  0 days 00:00:01.669585
# 20  0 days 00:00:04.109502
# 21  0 days 00:00:04.762360
# 22  0 days 00:00:00.609894
# 23  0 days 00:00:01.738391
# 24  0 days 00:00:02.544491
# 25  0 days 00:00:02.455775
# 26  0 days 00:00:01.229872
# 27  0 days 00:00:01.206925
# 28  0 days 00:00:00.629006
# 29  0 days 00:00:00.788711

# %% [markdown]
# Carregando o pkl

# %%
import joblib

modelo = joblib.load("checkpoints_best_models/best_model_fold_1.pkl")

# %%
modelo
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['NU_IDADE_N',
#                                                    'baixa_escolaridade',
#                                                    'raca_vulneravel',
#                                                    'faixa_vulneravel',
#                                                    'vulnerabilidade_social',
#                                                    'mes_sintomas',
#                                                    'periodo_chuvoso']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy...
#                                                    'CLI_PANTUR', 'CLI_VOMITO',
#                                                    'CLI_DIARRE', 'CLI_ICTERI',
#                                                    'CLI_RENAL', 'CLI_RESPIR',
#                                                    'CLI_CARDIA', 'CLI_HEMOPU', ...])])),
#                 ('smote', SMOTE(random_state=42)),
#                 ('model',
#                  LGBMClassifier(colsample_bytree=0.5606306299137558,
#                                 device='cpu', force_col_wise=True,
#                                 is_unbalance=True,
#                                 learning_rate=0.15646022206069424, max_depth=7,
#                                 n_estimators=28, random_state=42,
#                                 subsample=0.8567003500935702))])

# %%
modelo.named_steps["preprocessor"].get_feature_names_out()
# Out:
# array(['num__NU_IDADE_N', 'num__baixa_escolaridade',
#        'num__raca_vulneravel', 'num__faixa_vulneravel',
#        'num__vulnerabilidade_social', 'num__mes_sintomas',
#        'num__periodo_chuvoso', 'cat__CS_SEXO_Feminino',
#        'cat__CS_SEXO_Masculino', 'cat__CS_GESTANT_1º Trimestre',
#        'cat__CS_GESTANT_2º Trimestre', 'cat__CS_GESTANT_3º Trimestre',
#        'cat__CS_GESTANT_Idade gestacional ignorada',
#        'cat__CS_GESTANT_Não', 'cat__CS_GESTANT_Não informado',
#        'cat__CS_GESTANT_Não se aplica', 'cat__CS_RACA_Amarela',
#        'cat__CS_RACA_Branca', 'cat__CS_RACA_Indígena',
#        'cat__CS_RACA_Não informado', 'cat__CS_RACA_Parda',
#        'cat__CS_RACA_Preta', 'cat__CS_ESCOL_N_10',
#        'cat__CS_ESCOL_N_1ª a 4ª série incompleta do EF',
#        'cat__CS_ESCOL_N_4ª série completa do EF',
#        'cat__CS_ESCOL_N_5ª a 8ª série incompleta do EF',
#        'cat__CS_ESCOL_N_Ensino fundamental completo',
#        'cat__CS_ESCOL_N_Ensino médio completo',
#        'cat__CS_ESCOL_N_Ensino médio incompleto',
#        'cat__CS_ESCOL_N_Não informado',
#        'cat__CS_ESCOL_N_Sem escolaridade',
#        'cat__CS_ESCOL_N_Superior completo',
#        'cat__CS_ESCOL_N_Superior incompleto', 'cat__ID_OCUPA_N_000000',
#        'cat__ID_OCUPA_N_010310', 'cat__ID_OCUPA_N_021105',
#        'cat__ID_OCUPA_N_021205', 'cat__ID_OCUPA_N_021210',
#        'cat__ID_OCUPA_N_031110', 'cat__ID_OCUPA_N_031205',
#        'cat__ID_OCUPA_N_100.01', 'cat__ID_OCUPA_N_111220',
#        'cat__ID_OCUPA_N_111250', 'cat__ID_OCUPA_N_111415',
#        'cat__ID_OCUPA_N_121010', 'cat__ID_OCUPA_N_123110',
#        'cat__ID_OCUPA_N_123205', 'cat__ID_OCUPA_N_141115',
#        'cat__ID_OCUPA_N_141205', 'cat__ID_OCUPA_N_1414.1',
#        'cat__ID_OCUPA_N_141405', 'cat__ID_OCUPA_N_141410',
#        'cat__ID_OCUPA_N_141415', 'cat__ID_OCUPA_N_141510',
#        'cat__ID_OCUPA_N_142105', 'cat__ID_OCUPA_N_142305',
#        'cat__ID_OCUPA_N_142320', 'cat__ID_OCUPA_N_142410',
#        'cat__ID_OCUPA_N_142415', 'cat__ID_OCUPA_N_142515',
#        'cat__ID_OCUPA_N_212405', 'cat__ID_OCUPA_N_212415',
#        'cat__ID_OCUPA_N_213205', 'cat__ID_OCUPA_N_213405',
#        'cat__ID_OCUPA_N_214005', 'cat__ID_OCUPA_N_214125',
#        'cat__ID_OCUPA_N_214205', 'cat__ID_OCUPA_N_214305',
#        'cat__ID_OCUPA_N_214405', 'cat__ID_OCUPA_N_214615',
#        'cat__ID_OCUPA_N_214935', 'cat__ID_OCUPA_N_215150',
#        'cat__ID_OCUPA_N_221105', 'cat__ID_OCUPA_N_221205',
#        'cat__ID_OCUPA_N_222105', 'cat__ID_OCUPA_N_223110',
#        'cat__ID_OCUPA_N_223115', 'cat__ID_OCUPA_N_223208',
#        'cat__ID_OCUPA_N_223305', 'cat__ID_OCUPA_N_223310',
#        'cat__ID_OCUPA_N_2234.0', 'cat__ID_OCUPA_N_223405',
#        'cat__ID_OCUPA_N_223415', 'cat__ID_OCUPA_N_223505',
#        'cat__ID_OCUPA_N_223605', 'cat__ID_OCUPA_N_223705',
#        'cat__ID_OCUPA_N_223710', 'cat__ID_OCUPA_N_231110',
#        'cat__ID_OCUPA_N_2312.0', 'cat__ID_OCUPA_N_231205',
#        'cat__ID_OCUPA_N_231210', 'cat__ID_OCUPA_N_2313.1',
#        'cat__ID_OCUPA_N_231310', 'cat__ID_OCUPA_N_231320',
#        'cat__ID_OCUPA_N_232105', 'cat__ID_OCUPA_N_232110',
#        'cat__ID_OCUPA_N_232115', 'cat__ID_OCUPA_N_232120',
#        'cat__ID_OCUPA_N_232125', 'cat__ID_OCUPA_N_233105',
#        'cat__ID_OCUPA_N_234405', 'cat__ID_OCUPA_N_234515',
#        'cat__ID_OCUPA_N_234520', 'cat__ID_OCUPA_N_234810',
#        'cat__ID_OCUPA_N_239415', 'cat__ID_OCUPA_N_2410.0',
#        'cat__ID_OCUPA_N_241005', 'cat__ID_OCUPA_N_251510',
#        'cat__ID_OCUPA_N_251605', 'cat__ID_OCUPA_N_2521.0',
#        'cat__ID_OCUPA_N_252105', 'cat__ID_OCUPA_N_2522.1',
#        'cat__ID_OCUPA_N_252210', 'cat__ID_OCUPA_N_252305',
#        'cat__ID_OCUPA_N_252525', 'cat__ID_OCUPA_N_252545',
#        'cat__ID_OCUPA_N_252605', 'cat__ID_OCUPA_N_2531.1',
#        'cat__ID_OCUPA_N_253105', 'cat__ID_OCUPA_N_253120',
#        'cat__ID_OCUPA_N_254405', 'cat__ID_OCUPA_N_261125',
#        'cat__ID_OCUPA_N_261215', 'cat__ID_OCUPA_N_261410',
#        'cat__ID_OCUPA_N_262105', 'cat__ID_OCUPA_N_262410',
#        'cat__ID_OCUPA_N_263110', 'cat__ID_OCUPA_N_301110',
#        'cat__ID_OCUPA_N_311710', 'cat__ID_OCUPA_N_312320',
#        'cat__ID_OCUPA_N_313120', 'cat__ID_OCUPA_N_313130',
#        'cat__ID_OCUPA_N_313315', 'cat__ID_OCUPA_N_314110',
#        'cat__ID_OCUPA_N_314210', 'cat__ID_OCUPA_N_317210',
#        'cat__ID_OCUPA_N_321105', 'cat__ID_OCUPA_N_321110',
#        'cat__ID_OCUPA_N_3222.0', 'cat__ID_OCUPA_N_322205',
#        'cat__ID_OCUPA_N_322230', 'cat__ID_OCUPA_N_322410',
#        'cat__ID_OCUPA_N_324205', 'cat__ID_OCUPA_N_331105',
#        'cat__ID_OCUPA_N_331205', 'cat__ID_OCUPA_N_333105',
#        'cat__ID_OCUPA_N_333115', 'cat__ID_OCUPA_N_342515',
#        'cat__ID_OCUPA_N_351405', 'cat__ID_OCUPA_N_351605',
#        'cat__ID_OCUPA_N_351810', 'cat__ID_OCUPA_N_352205',
#        'cat__ID_OCUPA_N_352210', 'cat__ID_OCUPA_N_354120',
#        'cat__ID_OCUPA_N_354125', 'cat__ID_OCUPA_N_354135',
#        'cat__ID_OCUPA_N_354145', 'cat__ID_OCUPA_N_354415',
#        'cat__ID_OCUPA_N_354505', 'cat__ID_OCUPA_N_354605',
#        'cat__ID_OCUPA_N_354705', 'cat__ID_OCUPA_N_371105',
#        'cat__ID_OCUPA_N_371410', 'cat__ID_OCUPA_N_372210',
#        'cat__ID_OCUPA_N_373105', 'cat__ID_OCUPA_N_374120',
#        'cat__ID_OCUPA_N_374135', 'cat__ID_OCUPA_N_376215',
#        'cat__ID_OCUPA_N_391105', 'cat__ID_OCUPA_N_391205',
#        'cat__ID_OCUPA_N_391230', 'cat__ID_OCUPA_N_410105',
#        'cat__ID_OCUPA_N_411005', 'cat__ID_OCUPA_N_411010',
#        'cat__ID_OCUPA_N_411030', 'cat__ID_OCUPA_N_411045',
#        'cat__ID_OCUPA_N_411050', 'cat__ID_OCUPA_N_413105',
#        'cat__ID_OCUPA_N_413110', 'cat__ID_OCUPA_N_413115',
#        'cat__ID_OCUPA_N_413205', 'cat__ID_OCUPA_N_413225',
#        'cat__ID_OCUPA_N_413230', 'cat__ID_OCUPA_N_414105',
#        'cat__ID_OCUPA_N_414110', 'cat__ID_OCUPA_N_414210',
#        'cat__ID_OCUPA_N_414215', 'cat__ID_OCUPA_N_415205',
#        'cat__ID_OCUPA_N_4211.2', 'cat__ID_OCUPA_N_421105',
#        'cat__ID_OCUPA_N_421125', 'cat__ID_OCUPA_N_422105',
#        'cat__ID_OCUPA_N_422120', 'cat__ID_OCUPA_N_422125',
#        'cat__ID_OCUPA_N_422205', 'cat__ID_OCUPA_N_422210',
#        'cat__ID_OCUPA_N_423105', 'cat__ID_OCUPA_N_510110',
#        'cat__ID_OCUPA_N_510115', 'cat__ID_OCUPA_N_510125',
#        'cat__ID_OCUPA_N_510310', 'cat__ID_OCUPA_N_511215',
#        'cat__ID_OCUPA_N_5121.0', 'cat__ID_OCUPA_N_5121.1',
#        'cat__ID_OCUPA_N_512105', 'cat__ID_OCUPA_N_512110',
#        'cat__ID_OCUPA_N_512115', 'cat__ID_OCUPA_N_512120',
#        'cat__ID_OCUPA_N_513205', 'cat__ID_OCUPA_N_5134.0',
#        'cat__ID_OCUPA_N_5134.3', 'cat__ID_OCUPA_N_513405',
#        'cat__ID_OCUPA_N_513420', 'cat__ID_OCUPA_N_513425',
#        'cat__ID_OCUPA_N_513435', 'cat__ID_OCUPA_N_513440',
#        'cat__ID_OCUPA_N_513505', 'cat__ID_OCUPA_N_513605',
#        'cat__ID_OCUPA_N_514105', 'cat__ID_OCUPA_N_514120',
#        'cat__ID_OCUPA_N_514205', 'cat__ID_OCUPA_N_514210',
#        'cat__ID_OCUPA_N_514215', 'cat__ID_OCUPA_N_514225',
#        'cat__ID_OCUPA_N_514230', 'cat__ID_OCUPA_N_514310',
#        'cat__ID_OCUPA_N_5151.0', 'cat__ID_OCUPA_N_515105',
#        'cat__ID_OCUPA_N_515110', 'cat__ID_OCUPA_N_515210',
#        'cat__ID_OCUPA_N_515215', 'cat__ID_OCUPA_N_515225',
#        'cat__ID_OCUPA_N_5161.1', 'cat__ID_OCUPA_N_516105',
#        'cat__ID_OCUPA_N_516110', 'cat__ID_OCUPA_N_516120',
#        'cat__ID_OCUPA_N_516135', 'cat__ID_OCUPA_N_516210',
#        'cat__ID_OCUPA_N_516220', 'cat__ID_OCUPA_N_516305',
#        'cat__ID_OCUPA_N_516330', 'cat__ID_OCUPA_N_5171.1',
#        'cat__ID_OCUPA_N_517110', 'cat__ID_OCUPA_N_517210',
#        'cat__ID_OCUPA_N_517215', 'cat__ID_OCUPA_N_517310',
#        'cat__ID_OCUPA_N_517330', 'cat__ID_OCUPA_N_517405',
#        'cat__ID_OCUPA_N_517410', 'cat__ID_OCUPA_N_517420',
#        'cat__ID_OCUPA_N_519110', 'cat__ID_OCUPA_N_519205',
#        'cat__ID_OCUPA_N_519305', 'cat__ID_OCUPA_N_519805',
#        'cat__ID_OCUPA_N_519935', 'cat__ID_OCUPA_N_519940',
#        'cat__ID_OCUPA_N_5211.1', 'cat__ID_OCUPA_N_5211.3',
#        'cat__ID_OCUPA_N_521105', 'cat__ID_OCUPA_N_521110',
#        'cat__ID_OCUPA_N_521115', 'cat__ID_OCUPA_N_521125',
#        'cat__ID_OCUPA_N_521130', 'cat__ID_OCUPA_N_521135',
#        'cat__ID_OCUPA_N_524105', 'cat__ID_OCUPA_N_524205',
#        'cat__ID_OCUPA_N_524305', 'cat__ID_OCUPA_N_611005',
#        'cat__ID_OCUPA_N_612005', 'cat__ID_OCUPA_N_612105',
#        'cat__ID_OCUPA_N_612620', 'cat__ID_OCUPA_N_613405',
#        'cat__ID_OCUPA_N_6210.0', 'cat__ID_OCUPA_N_621005',
#        'cat__ID_OCUPA_N_6220.2', 'cat__ID_OCUPA_N_622005',
#        'cat__ID_OCUPA_N_622010', 'cat__ID_OCUPA_N_622015',
#        'cat__ID_OCUPA_N_622020', 'cat__ID_OCUPA_N_622105',
#        'cat__ID_OCUPA_N_622110', 'cat__ID_OCUPA_N_622115',
#        'cat__ID_OCUPA_N_622120', 'cat__ID_OCUPA_N_622310',
#        'cat__ID_OCUPA_N_622425', 'cat__ID_OCUPA_N_622610',
#        'cat__ID_OCUPA_N_622615', 'cat__ID_OCUPA_N_622620',
#        'cat__ID_OCUPA_N_622715', 'cat__ID_OCUPA_N_622730',
#        'cat__ID_OCUPA_N_623015', 'cat__ID_OCUPA_N_623020',
#        'cat__ID_OCUPA_N_623115', 'cat__ID_OCUPA_N_623215',
#        'cat__ID_OCUPA_N_623305', 'cat__ID_OCUPA_N_631020',
#        'cat__ID_OCUPA_N_631105', 'cat__ID_OCUPA_N_631210',
#        'cat__ID_OCUPA_N_632120', 'cat__ID_OCUPA_N_632125',
#        'cat__ID_OCUPA_N_641005', 'cat__ID_OCUPA_N_641010',
#        'cat__ID_OCUPA_N_641015', 'cat__ID_OCUPA_N_710205',
#        'cat__ID_OCUPA_N_711205', 'cat__ID_OCUPA_N_711230',
#        'cat__ID_OCUPA_N_711405', 'cat__ID_OCUPA_N_715115',
#        'cat__ID_OCUPA_N_715120', 'cat__ID_OCUPA_N_715125',
#        'cat__ID_OCUPA_N_7152.1', 'cat__ID_OCUPA_N_715210',
#        'cat__ID_OCUPA_N_715230', 'cat__ID_OCUPA_N_715305',
#        'cat__ID_OCUPA_N_715315', 'cat__ID_OCUPA_N_715410',
#        'cat__ID_OCUPA_N_715505', 'cat__ID_OCUPA_N_715615',
#        'cat__ID_OCUPA_N_715715', 'cat__ID_OCUPA_N_7161.0',
#        'cat__ID_OCUPA_N_716305', 'cat__ID_OCUPA_N_716405',
#        'cat__ID_OCUPA_N_716525', 'cat__ID_OCUPA_N_716610',
#        'cat__ID_OCUPA_N_717020', 'cat__ID_OCUPA_N_7201.5',
#        'cat__ID_OCUPA_N_720110', 'cat__ID_OCUPA_N_720115',
#        'cat__ID_OCUPA_N_720155', 'cat__ID_OCUPA_N_721105',
#        'cat__ID_OCUPA_N_721415', 'cat__ID_OCUPA_N_722215',
#        'cat__ID_OCUPA_N_722220', 'cat__ID_OCUPA_N_722225',
#        'cat__ID_OCUPA_N_722330', 'cat__ID_OCUPA_N_723220',
#        'cat__ID_OCUPA_N_723310', 'cat__ID_OCUPA_N_723315',
#        'cat__ID_OCUPA_N_723320', 'cat__ID_OCUPA_N_724110',
#        'cat__ID_OCUPA_N_724205', 'cat__ID_OCUPA_N_724315',
#        'cat__ID_OCUPA_N_724405', 'cat__ID_OCUPA_N_724410',
#        'cat__ID_OCUPA_N_724415', 'cat__ID_OCUPA_N_724440',
#        'cat__ID_OCUPA_N_7250.1', 'cat__ID_OCUPA_N_725010',
#        'cat__ID_OCUPA_N_725205', 'cat__ID_OCUPA_N_725225',
#        'cat__ID_OCUPA_N_725705', 'cat__ID_OCUPA_N_731150',
#        'cat__ID_OCUPA_N_731320', 'cat__ID_OCUPA_N_732105',
#        'cat__ID_OCUPA_N_760305', 'cat__ID_OCUPA_N_761327',
#        'cat__ID_OCUPA_N_761330', 'cat__ID_OCUPA_N_761410',
#        'cat__ID_OCUPA_N_761425', 'cat__ID_OCUPA_N_761810',
#        'cat__ID_OCUPA_N_762345', 'cat__ID_OCUPA_N_763010',
#        'cat__ID_OCUPA_N_763015', 'cat__ID_OCUPA_N_763110',
#        'cat__ID_OCUPA_N_763205', 'cat__ID_OCUPA_N_763210',
#        'cat__ID_OCUPA_N_764005', 'cat__ID_OCUPA_N_764105',
#        'cat__ID_OCUPA_N_764205', 'cat__ID_OCUPA_N_764210',
#        'cat__ID_OCUPA_N_764305', 'cat__ID_OCUPA_N_765405',
#        'cat__ID_OCUPA_N_771105', 'cat__ID_OCUPA_N_772105',
#        'cat__ID_OCUPA_N_773120', 'cat__ID_OCUPA_N_773335',
#        'cat__ID_OCUPA_N_774105', 'cat__ID_OCUPA_N_781705',
#        'cat__ID_OCUPA_N_782105', 'cat__ID_OCUPA_N_782220',
#        'cat__ID_OCUPA_N_7823.0', 'cat__ID_OCUPA_N_7823.1',
#        'cat__ID_OCUPA_N_782305', 'cat__ID_OCUPA_N_782310',
#        'cat__ID_OCUPA_N_782315', 'cat__ID_OCUPA_N_7824.1',
#        'cat__ID_OCUPA_N_782405', 'cat__ID_OCUPA_N_782410',
#        'cat__ID_OCUPA_N_7825.0', 'cat__ID_OCUPA_N_7825.1',
#        'cat__ID_OCUPA_N_782505', 'cat__ID_OCUPA_N_782510',
#        'cat__ID_OCUPA_N_782515', 'cat__ID_OCUPA_N_782620',
#        'cat__ID_OCUPA_N_782705', 'cat__ID_OCUPA_N_783110',
#        'cat__ID_OCUPA_N_783210', 'cat__ID_OCUPA_N_783215',
#        'cat__ID_OCUPA_N_783225', 'cat__ID_OCUPA_N_784105',
#        'cat__ID_OCUPA_N_784120', 'cat__ID_OCUPA_N_784205',
#        'cat__ID_OCUPA_N_791115', 'cat__ID_OCUPA_N_823305',
#        'cat__ID_OCUPA_N_823320', 'cat__ID_OCUPA_N_828110',
#        'cat__ID_OCUPA_N_833205', 'cat__ID_OCUPA_N_841115',
#        'cat__ID_OCUPA_N_841408', 'cat__ID_OCUPA_N_841416',
#        'cat__ID_OCUPA_N_841456', 'cat__ID_OCUPA_N_841484',
#        'cat__ID_OCUPA_N_848210', 'cat__ID_OCUPA_N_848305',
#        'cat__ID_OCUPA_N_848310', 'cat__ID_OCUPA_N_8485.1',
#        'cat__ID_OCUPA_N_848505', 'cat__ID_OCUPA_N_848510',
#        'cat__ID_OCUPA_N_848520', 'cat__ID_OCUPA_N_848605',
#        'cat__ID_OCUPA_N_860110', 'cat__ID_OCUPA_N_862120',
#        'cat__ID_OCUPA_N_862150', 'cat__ID_OCUPA_N_911105',
#        'cat__ID_OCUPA_N_911305', 'cat__ID_OCUPA_N_911320',
#        'cat__ID_OCUPA_N_913115', 'cat__ID_OCUPA_N_914105',
#        'cat__ID_OCUPA_N_914405', 'cat__ID_OCUPA_N_914415',
#        'cat__ID_OCUPA_N_914425', 'cat__ID_OCUPA_N_919310',
#        'cat__ID_OCUPA_N_951305', 'cat__ID_OCUPA_N_953115',
#        'cat__ID_OCUPA_N_954120', 'cat__ID_OCUPA_N_991305',
#        'cat__ID_OCUPA_N_991415', 'cat__ID_OCUPA_N_992115',
#        'cat__ID_OCUPA_N_998999', 'cat__ID_OCUPA_N_9999.9',
#        'cat__ID_OCUPA_N_999991', 'cat__ID_OCUPA_N_999992',
#        'cat__ID_OCUPA_N_999993', 'cat__ID_OCUPA_N_999994',
#        'cat__ID_OCUPA_N_999995', 'cat__ID_OCUPA_N_Não informado',
#        'cat__ID_OCUPA_N_XXX', 'cat__CON_AREA_Não informado',
#        'cat__CON_AREA_Periurbana', 'cat__CON_AREA_Rural',
#        'cat__CON_AREA_Urbana', 'cat__CON_AMBIEN_Domicílio',
#        'cat__CON_AMBIEN_Lazer', 'cat__CON_AMBIEN_Não informado',
#        'cat__CON_AMBIEN_Outro', 'cat__CON_AMBIEN_Trabalho',
#        'cat__ANT_CB_LAM_Não', 'cat__ANT_CB_LAM_Não informado',
#        'cat__ANT_CB_LAM_Sim', 'cat__ANT_CB_CRI_Não',
#        'cat__ANT_CB_CRI_Não informado', 'cat__ANT_CB_CRI_Sim',
#        'cat__ANT_CB_SIN_Não', 'cat__ANT_CB_SIN_Não informado',
#        'cat__ANT_CB_SIN_Sim', 'cat__ANT_CB_COR_Não',
#        'cat__ANT_CB_COR_Não informado', 'cat__ANT_CB_COR_Sim',
#        'cat__ANT_CB_ROE_Não', 'cat__ANT_CB_ROE_Não informado',
#        'cat__ANT_CB_ROE_Sim', 'cat__ANT_CB_TER_Não',
#        'cat__ANT_CB_TER_Não informado', 'cat__ANT_CB_TER_Sim',
#        'cat__ANT_CB_LIX_Não', 'cat__ANT_CB_LIX_Não informado',
#        'cat__ANT_CB_LIX_Sim', 'cat__ANT_CB_OUT_Não',
#        'cat__ANT_CB_OUT_Não informado', 'cat__ANT_CB_OUT_Sim',
#        'cat__ANT_ANIMAI_Não', 'cat__ANT_ANIMAI_Não informado',
#        'cat__ANT_ANIMAI_Sim', 'cat__ANT_HUMANO_Não',
#        'cat__ANT_HUMANO_Não informado', 'cat__ANT_HUMANO_Sim',
#        'cat__CLI_FEBRE_Não', 'cat__CLI_FEBRE_Não informado',
#        'cat__CLI_FEBRE_Sim', 'cat__CLI_MIALGI_Não',
#        'cat__CLI_MIALGI_Não informado', 'cat__CLI_MIALGI_Sim',
#        'cat__CLI_CEFALE_Não', 'cat__CLI_CEFALE_Não informado',
#        'cat__CLI_CEFALE_Sim', 'cat__CLI_PROST_Não',
#        'cat__CLI_PROST_Não informado', 'cat__CLI_PROST_Sim',
#        'cat__CLI_CONGES_Não', 'cat__CLI_CONGES_Não informado',
#        'cat__CLI_CONGES_Sim', 'cat__CLI_PANTUR_Não',
#        'cat__CLI_PANTUR_Não informado', 'cat__CLI_PANTUR_Sim',
#        'cat__CLI_VOMITO_Não', 'cat__CLI_VOMITO_Não informado',
#        'cat__CLI_VOMITO_Sim', 'cat__CLI_DIARRE_Não',
#        'cat__CLI_DIARRE_Não informado', 'cat__CLI_DIARRE_Sim',
#        'cat__CLI_ICTERI_Não', 'cat__CLI_ICTERI_Não informado',
#        'cat__CLI_ICTERI_Sim', 'cat__CLI_RENAL_Não',
#        'cat__CLI_RENAL_Não informado', 'cat__CLI_RENAL_Sim',
#        'cat__CLI_RESPIR_Não', 'cat__CLI_RESPIR_Não informado',
#        'cat__CLI_RESPIR_Sim', 'cat__CLI_CARDIA_Não',
#        'cat__CLI_CARDIA_Não informado', 'cat__CLI_CARDIA_Sim',
#        'cat__CLI_HEMOPU_Não', 'cat__CLI_HEMOPU_Não informado',
#        'cat__CLI_HEMOPU_Sim', 'cat__CLI_HEMORR_Não',
#        'cat__CLI_HEMORR_Não informado', 'cat__CLI_HEMORR_Sim',
#        'cat__CLI_MENING_Não', 'cat__CLI_MENING_Não informado',
#        'cat__CLI_MENING_Sim', 'cat__CLI_OUTROS_Não',
#        'cat__CLI_OUTROS_Não informado', 'cat__CLI_OUTROS_Sim',
#        'cat__SG_UF_AC', 'cat__SG_UF_AL', 'cat__SG_UF_AM', 'cat__SG_UF_AP',
#        'cat__SG_UF_BA', 'cat__SG_UF_CE', 'cat__SG_UF_DF', 'cat__SG_UF_ES',
#        'cat__SG_UF_GO', 'cat__SG_UF_MA', 'cat__SG_UF_MG', 'cat__SG_UF_MS',
#        'cat__SG_UF_MT', 'cat__SG_UF_Não informado', 'cat__SG_UF_PA',
#        'cat__SG_UF_PB', 'cat__SG_UF_PE', 'cat__SG_UF_PI', 'cat__SG_UF_PR',
#        'cat__SG_UF_RJ', 'cat__SG_UF_RN', 'cat__SG_UF_RO', 'cat__SG_UF_RR',
#        'cat__SG_UF_RS', 'cat__SG_UF_SC', 'cat__SG_UF_SE', 'cat__SG_UF_SP',
#        'cat__SG_UF_TO', 'cat__nivel_vulnerabilidade_Alta',
#        'cat__nivel_vulnerabilidade_Baixa',
#        'cat__nivel_vulnerabilidade_Moderada', 'cat__estacao_Inverno',
#        'cat__estacao_Outono', 'cat__estacao_Primavera',
#        'cat__estacao_Verão'], dtype=object)

# %%
modelo.predict(X_data.iloc[-10:])
# Out:
# array([1, 1, 1, 1, 1, 0, 1, 0, 0, 1])

# %% [markdown]
# ## Avaliação de desempenho e custo computacional
#
# Nesta seção são avaliados os modelos selecionados ao longo dos folds da validação cruzada externa,
# considerando simultaneamente **qualidade preditiva** e **custo computacional**.
# Essa análise conjunta é fundamental para evitar escolhas baseadas apenas em desempenho,
# desconsiderando viabilidade prática de treinamento e manutenção do modelo.
#
# ### Métricas de desempenho preditivo
#
# O desempenho dos modelos é avaliado por meio de múltiplas métricas,
# permitindo uma análise abrangente do comportamento preditivo:
#
# - **ROC-AUC (OvR, weighted)**: métrica principal de comparação, pois avalia a capacidade de separação entre classes
# em cenários multiclasse e desbalanceados, utilizando probabilidades preditas.
# - **Accuracy**: fornece uma visão global de acerto, mas pode ser influenciada por classes majoritárias.
# - **F1-score (weighted)**: equilibra precisão e recall, sendo mais informativo quando há assimetria entre classes.
# - **Recall (weighted)**: mede a capacidade do modelo em identificar corretamente instâncias relevantes,
# importante em contextos onde falsos negativos possuem maior custo.
# - **Precision (weighted)**: avalia a confiabilidade das predições positivas,
# sendo relevante quando falsos positivos impactam decisões downstream.
#
# A análise por fold permite verificar não apenas o valor médio das métricas,
# mas também sua **estabilidade**, reduzindo o risco de overfitting a uma partição específica dos dados.

# %%
# 2. Basic overview
print("=== Shape of DataFrame ===")
print(df_metrics.shape)

display(df_metrics)
# Out:
# === Shape of DataFrame ===
# (30, 13)
#     number     value  params_C  params_colsample_bytree  params_learning_rate  \
# 0        0  0.907546       NaN                 0.829756              0.088240
# 1        1  0.901220  1.457654                      NaN                   NaN
# 2        2  0.905985       NaN                 0.561807              0.078328
# 3        3  0.901737  1.076130                      NaN                   NaN
# 4        4  0.901867  1.004666                      NaN                   NaN
# 5        5  0.912255       NaN                 0.790316              0.219966
# 6        6  0.901878       NaN                      NaN                   NaN
# 7        7  0.913342       NaN                 0.852319              0.240302
# 8        8  0.904478  2.259790                      NaN                   NaN
# 9        9  0.911376       NaN                 0.844282              0.070409
# 10      10  0.910307       NaN                 0.900971              0.262357
# 11      11  0.914131       NaN                 0.995090              0.278675
# 12      12  0.915539       NaN                 0.711420              0.232692
# 13      13  0.905303       NaN                 0.995534              0.298368
# 14      14  0.878963       NaN                      NaN                   NaN
# 15      15  0.882980       NaN                      NaN                   NaN
# 16      16  0.826718       NaN                 0.657920              0.175528
# 17      17  0.826851       NaN                 0.689981              0.171642
# 18      18  0.915757       NaN                 0.697372              0.155336
# 19      19  0.913482       NaN                 0.686567              0.296354
# 20      20  0.915875       NaN                 0.994005              0.290601
# 21      21  0.912454       NaN                 0.557324              0.210453
# 22      22  0.904132       NaN                 0.910439              0.233910
# 23      23  0.913214       NaN                 0.911447              0.225568
# 24      24  0.916449       NaN                 0.760625              0.248436
# 25      25  0.915176       NaN                 0.759914              0.263853
# 26      26  0.914495       NaN                 0.765495              0.260505
# 27      27  0.912133       NaN                 0.744479              0.119799
# 28      28  0.903977       NaN                 0.639115              0.021090
# 29      29  0.913258       NaN                 0.738010              0.189516
#
#     params_max_depth  params_min_samples_leaf  params_min_samples_split  \
# 0                5.0                      NaN                       NaN
# 1                NaN                      NaN                       NaN
# 2                8.0                      NaN                       NaN
# 3                NaN                      NaN                       NaN
# 4                NaN                      NaN                       NaN
# 5                9.0                      NaN                       NaN
# 6                9.0                      4.0                      10.0
# 7                5.0                      NaN                       NaN
# 8                NaN                      NaN                       NaN
# 9                6.0                      NaN                       NaN
# 10               7.0                      NaN                       NaN
# 11               3.0                      NaN                       NaN
# 12               3.0                      NaN                       NaN
# 13               3.0                      NaN                       NaN
# 14               3.0                      1.0                       2.0
# 15               3.0                      1.0                       2.0
# 16               4.0                      NaN                       NaN
# 17               4.0                      NaN                       NaN
# 18               4.0                      NaN                       NaN
# 19               4.0                      NaN                       NaN
# 20               5.0                      NaN                       NaN
# 21               6.0                      NaN                       NaN
# 22               5.0                      NaN                       NaN
# 23               6.0                      NaN                       NaN
# 24               3.0                      NaN                       NaN
# 25               3.0                      NaN                       NaN
# 26               3.0                      NaN                       NaN
# 27               3.0                      NaN                       NaN
# 28               4.0                      NaN                       NaN
# 29               3.0                      NaN                       NaN
#
#    params_model_name  params_n_estimators  params_subsample     state  \
# 0           lightgbm                 12.0          0.669721  COMPLETE
# 1                svm                  NaN               NaN  COMPLETE
# 2            xgboost                 18.0          0.880633  COMPLETE
# 3                svm                  NaN               NaN  COMPLETE
# 4                svm                  NaN               NaN  COMPLETE
# 5           lightgbm                 24.0          0.816456  COMPLETE
# 6      random_forest                 19.0               NaN    PRUNED
# 7           lightgbm                 20.0          0.718384  COMPLETE
# 8                svm                  NaN               NaN    PRUNED
# 9           lightgbm                 21.0          0.695315  COMPLETE
# 10           xgboost                 12.0          0.523285  COMPLETE
# 11           xgboost                 29.0          0.504979  COMPLETE
# 12          lightgbm                 30.0          0.865662  COMPLETE
# 13           xgboost                 29.0          0.529223    PRUNED
# 14     random_forest                 29.0               NaN    PRUNED
# 15     random_forest                 30.0               NaN    PRUNED
# 16           xgboost                  5.0          0.959347    PRUNED
# 17           xgboost                  5.0          0.994497    PRUNED
# 18          lightgbm                 25.0          0.833366    PRUNED
# 19          lightgbm                 25.0          0.609294    PRUNED
# 20           xgboost                 25.0          0.601337    PRUNED
# 21           xgboost                 25.0          0.899097  COMPLETE
# 22          lightgbm                 14.0          0.740416    PRUNED
# 23          lightgbm                 27.0          0.898923    PRUNED
# 24          lightgbm                 28.0          0.770181  COMPLETE
# 25          lightgbm                 22.0          0.776274  COMPLETE
# 26          lightgbm                 28.0          0.803771    PRUNED
# 27          lightgbm                 22.0          0.795409    PRUNED
# 28          lightgbm                 23.0          0.772002    PRUNED
# 29          lightgbm                 22.0          0.853140    PRUNED
#
#                   duration
# 0   0 days 00:00:02.690009
# 1   0 days 00:00:07.561083
# 2   0 days 00:00:04.989495
# 3   0 days 00:00:06.250246
# 4   0 days 00:00:06.373964
# 5   0 days 00:00:03.611867
# 6   0 days 00:00:01.258871
# 7   0 days 00:00:03.018046
# 8   0 days 00:00:02.383348
# 9   0 days 00:00:02.318710
# 10  0 days 00:00:03.465440
# 11  0 days 00:00:02.835824
# 12  0 days 00:00:01.719186
# 13  0 days 00:00:01.025930
# 14  0 days 00:00:00.664584
# 15  0 days 00:00:00.573016
# 16  0 days 00:00:01.000190
# 17  0 days 00:00:01.077369
# 18  0 days 00:00:01.333076
# 19  0 days 00:00:01.669585
# 20  0 days 00:00:04.109502
# 21  0 days 00:00:04.762360
# 22  0 days 00:00:00.609894
# 23  0 days 00:00:01.738391
# 24  0 days 00:00:02.544491
# 25  0 days 00:00:02.455775
# 26  0 days 00:00:01.229872
# 27  0 days 00:00:01.206925
# 28  0 days 00:00:00.629006
# 29  0 days 00:00:00.788711

# %%
df_metrics
# Out:
#     number     value  params_C  params_colsample_bytree  params_learning_rate  \
# 0        0  0.907546       NaN                 0.829756              0.088240
# 1        1  0.901220  1.457654                      NaN                   NaN
# 2        2  0.905985       NaN                 0.561807              0.078328
# 3        3  0.901737  1.076130                      NaN                   NaN
# 4        4  0.901867  1.004666                      NaN                   NaN
# 5        5  0.912255       NaN                 0.790316              0.219966
# 6        6  0.901878       NaN                      NaN                   NaN
# 7        7  0.913342       NaN                 0.852319              0.240302
# 8        8  0.904478  2.259790                      NaN                   NaN
# 9        9  0.911376       NaN                 0.844282              0.070409
# 10      10  0.910307       NaN                 0.900971              0.262357
# 11      11  0.914131       NaN                 0.995090              0.278675
# 12      12  0.915539       NaN                 0.711420              0.232692
# 13      13  0.905303       NaN                 0.995534              0.298368
# 14      14  0.878963       NaN                      NaN                   NaN
# 15      15  0.882980       NaN                      NaN                   NaN
# 16      16  0.826718       NaN                 0.657920              0.175528
# 17      17  0.826851       NaN                 0.689981              0.171642
# 18      18  0.915757       NaN                 0.697372              0.155336
# 19      19  0.913482       NaN                 0.686567              0.296354
# 20      20  0.915875       NaN                 0.994005              0.290601
# 21      21  0.912454       NaN                 0.557324              0.210453
# 22      22  0.904132       NaN                 0.910439              0.233910
# 23      23  0.913214       NaN                 0.911447              0.225568
# 24      24  0.916449       NaN                 0.760625              0.248436
# 25      25  0.915176       NaN                 0.759914              0.263853
# 26      26  0.914495       NaN                 0.765495              0.260505
# 27      27  0.912133       NaN                 0.744479              0.119799
# 28      28  0.903977       NaN                 0.639115              0.021090
# 29      29  0.913258       NaN                 0.738010              0.189516
#
#     params_max_depth  params_min_samples_leaf  params_min_samples_split  \
# 0                5.0                      NaN                       NaN
# 1                NaN                      NaN                       NaN
# 2                8.0                      NaN                       NaN
# 3                NaN                      NaN                       NaN
# 4                NaN                      NaN                       NaN
# 5                9.0                      NaN                       NaN
# 6                9.0                      4.0                      10.0
# 7                5.0                      NaN                       NaN
# 8                NaN                      NaN                       NaN
# 9                6.0                      NaN                       NaN
# 10               7.0                      NaN                       NaN
# 11               3.0                      NaN                       NaN
# 12               3.0                      NaN                       NaN
# 13               3.0                      NaN                       NaN
# 14               3.0                      1.0                       2.0
# 15               3.0                      1.0                       2.0
# 16               4.0                      NaN                       NaN
# 17               4.0                      NaN                       NaN
# 18               4.0                      NaN                       NaN
# 19               4.0                      NaN                       NaN
# 20               5.0                      NaN                       NaN
# 21               6.0                      NaN                       NaN
# 22               5.0                      NaN                       NaN
# 23               6.0                      NaN                       NaN
# 24               3.0                      NaN                       NaN
# 25               3.0                      NaN                       NaN
# 26               3.0                      NaN                       NaN
# 27               3.0                      NaN                       NaN
# 28               4.0                      NaN                       NaN
# 29               3.0                      NaN                       NaN
#
#    params_model_name  params_n_estimators  params_subsample     state  \
# 0           lightgbm                 12.0          0.669721  COMPLETE
# 1                svm                  NaN               NaN  COMPLETE
# 2            xgboost                 18.0          0.880633  COMPLETE
# 3                svm                  NaN               NaN  COMPLETE
# 4                svm                  NaN               NaN  COMPLETE
# 5           lightgbm                 24.0          0.816456  COMPLETE
# 6      random_forest                 19.0               NaN    PRUNED
# 7           lightgbm                 20.0          0.718384  COMPLETE
# 8                svm                  NaN               NaN    PRUNED
# 9           lightgbm                 21.0          0.695315  COMPLETE
# 10           xgboost                 12.0          0.523285  COMPLETE
# 11           xgboost                 29.0          0.504979  COMPLETE
# 12          lightgbm                 30.0          0.865662  COMPLETE
# 13           xgboost                 29.0          0.529223    PRUNED
# 14     random_forest                 29.0               NaN    PRUNED
# 15     random_forest                 30.0               NaN    PRUNED
# 16           xgboost                  5.0          0.959347    PRUNED
# 17           xgboost                  5.0          0.994497    PRUNED
# 18          lightgbm                 25.0          0.833366    PRUNED
# 19          lightgbm                 25.0          0.609294    PRUNED
# 20           xgboost                 25.0          0.601337    PRUNED
# 21           xgboost                 25.0          0.899097  COMPLETE
# 22          lightgbm                 14.0          0.740416    PRUNED
# 23          lightgbm                 27.0          0.898923    PRUNED
# 24          lightgbm                 28.0          0.770181  COMPLETE
# 25          lightgbm                 22.0          0.776274  COMPLETE
# 26          lightgbm                 28.0          0.803771    PRUNED
# 27          lightgbm                 22.0          0.795409    PRUNED
# 28          lightgbm                 23.0          0.772002    PRUNED
# 29          lightgbm                 22.0          0.853140    PRUNED
#
#                   duration
# 0   0 days 00:00:02.690009
# 1   0 days 00:00:07.561083
# 2   0 days 00:00:04.989495
# 3   0 days 00:00:06.250246
# 4   0 days 00:00:06.373964
# 5   0 days 00:00:03.611867
# 6   0 days 00:00:01.258871
# 7   0 days 00:00:03.018046
# 8   0 days 00:00:02.383348
# 9   0 days 00:00:02.318710
# 10  0 days 00:00:03.465440
# 11  0 days 00:00:02.835824
# 12  0 days 00:00:01.719186
# 13  0 days 00:00:01.025930
# 14  0 days 00:00:00.664584
# 15  0 days 00:00:00.573016
# 16  0 days 00:00:01.000190
# 17  0 days 00:00:01.077369
# 18  0 days 00:00:01.333076
# 19  0 days 00:00:01.669585
# 20  0 days 00:00:04.109502
# 21  0 days 00:00:04.762360
# 22  0 days 00:00:00.609894
# 23  0 days 00:00:01.738391
# 24  0 days 00:00:02.544491
# 25  0 days 00:00:02.455775
# 26  0 days 00:00:01.229872
# 27  0 days 00:00:01.206925
# 28  0 days 00:00:00.629006
# 29  0 days 00:00:00.788711

# %%
# Total de trials por modelo
total_trials = (df_metrics.groupby("params_model_name").size().reset_index(name="total_trials"))

plt.figure(figsize=(8, 6))
sns.barplot(data=total_trials,x="params_model_name",y="total_trials",)
plt.title("Total de tentativas por modelo")
plt.xlabel("Modelo")
plt.ylabel("Tentativas")
plt.tight_layout()
plt.show()

# %%
# Gráfico das tentativas de modelos completas e abortadas
counts_state = df_metrics.groupby(["params_model_name", "state"]).size().reset_index(name="count")

plt.figure(figsize=(8, 6))
sns.barplot(data=counts_state,x="params_model_name",y="count",hue="state",)
plt.title("Resultado das tentativas entre Pruned e Complete")
plt.xlabel("Modelo")
plt.ylabel("Número de tentativas")
plt.tight_layout()
plt.show()

# %%
# Distribuição de performance (value) por modelo
plt.figure(figsize=(8, 6))
sns.boxplot(data=df_metrics, x="params_model_name", y="value")
plt.title("Desempenho por modelo")
plt.xlabel("Modelo")
plt.ylabel("Área por baixo da curva ROC (AUC)")
plt.tight_layout()
plt.show()

# %%
# Duração média de treino por modelo
df_metrics["duration_sec"] = pd.to_timedelta(df_metrics["duration"]).dt.total_seconds()
mean_duration = df_metrics.groupby("params_model_name")["duration_sec"].mean().reset_index()

# Distribuição do tempo de processamento por modelo

plt.figure(figsize=(8, 6))
sns.boxplot(data=df_metrics, x="params_model_name", y="duration_sec")
plt.title("Média do tempo de treinamento por modelo")
plt.xlabel("Modelo")
plt.ylabel("Segundos")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Treinamento do modelo final

# %%
df_hyper =pd.DataFrame(df_results['hyperparameters'].to_list())
df_hyper
# Out:
#   model_name  n_estimators  learning_rate  max_depth  subsample  \
# 0   lightgbm            28       0.156460          7   0.856700
# 1   lightgbm            30       0.100647          4   0.605007
# 2    xgboost            30       0.190369          5   0.900852
# 3   lightgbm            17       0.155157          7   0.576008
# 4   lightgbm            28       0.248436          3   0.770181
#
#    colsample_bytree
# 0          0.560631
# 1          0.570067
# 2          0.705884
# 3          0.793152
# 4          0.760625

# %%
final_params=df_hyper.iloc[:,1:].median().to_dict()
final_params
# Out:
# {'n_estimators': 28.0,
#  'learning_rate': 0.15646022206069424,
#  'max_depth': 5.0,
#  'subsample': 0.7701807356606535,
#  'colsample_bytree': 0.70588417431983}

# %%
final_params = {'n_estimators': 26,
 'learning_rate': 0.226,
 'max_depth': 7,
 'subsample': 0.662,
 'colsample_bytree': 0.6968}

# %%
# Dicionário base para reconstrução
models = {
    'RandomForest': RandomForestClassifier(random_state=42),
    'XGBoost': xgb.XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42),
    'LightGBM': lgb.LGBMClassifier(random_state=42),
    'SVM': CalibratedClassifierCV(LinearSVC( random_state=42))
}

# %%
# Reconstruir modelo
final_model = models['LightGBM']
final_model.set_params(**final_params)

cat_cols, num_cols = get_feature_types(X_data)

final_pipeline = build_pipeline(final_model, cat_cols, num_cols)

# %% [markdown]
# ### Avaliando modelo final

# %% [markdown]
# ## Interpretabilidade: importância de variáveis após pré-processamento (OHE) e mapeamento para colunas originais
#
# Modelos treinados sobre pipelines com `ColumnTransformer` e `OneHotEncoder` operam em um espaço de features
# expandido (múltiplas colunas por variável categórica). Para manter interpretabilidade, esta seção:
# 1) recupera os nomes finais das features no espaço transformado,
# 2) extrai uma medida de importância/coeficiente do modelo treinado,
# 3) mapeia as features transformadas de volta para as variáveis originais,
# 4) consolida a importância no nível da coluna original.
#
# Isso permite reportar resultados em termos das variáveis do dataset original, facilitando comunicação e análise.

# %% [markdown]
# ### Extração de nomes das features pós-`ColumnTransformer`
#
# A função `get_feature_names` reconstrói o vetor de nomes de features gerado após o pré-processamento,
# incluindo:
# - variáveis numéricas (após imputação/escala),
# - variáveis categóricas expandidas via One-Hot Encoding,
# - e, opcionalmente, colunas passadas via `remainder='passthrough'`.
#
# Essa etapa é necessária porque, após o `fit_transform`, a matriz final perde o vínculo direto com o nome
# das colunas originais, e a identificação correta das features é condição para qualquer análise de importância.

# %%
# 1. FUNÇÃO PARA EXTRAIR NOMES DAS FEATURES PÓS-OHE
def get_feature_names(column_transformer):
    """
    Extrai nomes finais das features após ColumnTransformer,
    incluindo OneHotEncoder e transformações numéricas.
    """
    output_features = []

    for name, transformer, features in column_transformer.transformers_:

        # Caso 'remainder=passthrough'
        if name == "remainder":
            output_features.extend(features)
            continue

        # Transformers com get_feature_names_out() (OneHotEncoder, etc)
        if hasattr(transformer, "get_feature_names_out"):
            try:
                names = transformer.get_feature_names_out(features)
            except:
                names = transformer.get_feature_names_out()
            output_features.extend(names)

        # Caso não possua o método
        else:
            output_features.extend(features)

    return output_features

# %% [markdown]
# ### Mapeamento para variáveis originais via fuzzy matching
#
# Após o One-Hot Encoding, uma mesma variável categórica pode gerar dezenas de colunas com nomes derivados.
# Para consolidar resultados no nível da variável original, é aplicado *fuzzy matching* entre o nome da feature
# pós-OHE e a lista de variáveis originais de interesse (`features_explicativas`).
#
# O objetivo do fuzzy matching é lidar com diferenças de sufixos/prefixos criados pelo encoding e manter
# um vínculo prático entre “feature transformada” e “coluna original”. O parâmetro `threshold`
# controla o quão estrita é a correspondência:
# - valores maiores reduzem falsos positivos (match errado),
# - valores menores aumentam cobertura, mas elevam risco de mapeamentos incorretos.
#
# Após o matching, apenas features com correspondência válida são mantidas para agregação.

# %%
def fuzzy_match_original(feature_name, triage_features, threshold=70):
    """
    Realiza fuzzy matching buscando qual variável ORIGINAL
    está mais relacionada com o nome da feature pós-OHE.
    """
    best_match, score, _ = process.extractOne(
        feature_name,
        triage_features,
        scorer=fuzz.partial_ratio
    )
    return best_match if score >= threshold else None

# %% [markdown]
# ## Validação cruzada externa: avaliação e interpretabilidade por fold
#
# Nesta etapa, aplica-se uma `StratifiedKFold` externa para avaliar o desempenho do pipeline e também
# inspecionar a importância de variáveis por fold. A estratificação preserva a proporção das classes,
# reduzindo instabilidade em bases desbalanceadas.
#
# Para cada fold:
# - o pipeline final é treinado no conjunto de treino,
# - a importância das features é extraída do modelo treinado,
# - as importâncias são consolidadas no nível da variável original e visualizadas,
# - e o desempenho é medido no conjunto de teste com métricas e curvas.

# %%
n_splits = 4
outer_cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
results = []
fold = 1
for train_idx, test_idx in outer_cv.split(X_data, y_data):

    print(f"\n==============================")
    print(f"  Fold Externo {fold}/{n_splits}")
    print(f"==============================")

    X_train, X_test = X_data.iloc[train_idx], X_data.iloc[test_idx]
    y_train, y_test = y_data.iloc[train_idx], y_data.iloc[test_idx]

    # Treinando o pipeline final com todo o conjunto de dados
    final_pipeline.fit(X_train,y_train)


    model = final_pipeline.named_steps["model"]   # <-- trocado aqui

    if hasattr(model, "feature_importances_"):
        importances = model.feature_importances_

    elif hasattr(model, "coef_"):
        importances = model.coef_.ravel()

    else:
        raise ValueError("Este modelo não possui atributo de importância.")



    # 3. DF DE IMPORTÂNCIAS COM FEATURES PÓS-PREPROCESSAMENTO


    preproc = final_pipeline.named_steps["preprocessor"]   # <-- trocado aqui
    feature_names = get_feature_names(preproc)

    df_imp = pd.DataFrame({
        "feature": feature_names,
        "importance": importances
    })


    # 5. APLICA FUZZY MATCH EM TODAS AS FEATURES
    df_imp["original_var"] = df_imp["feature"].apply(
        lambda x: fuzzy_match_original(x, triage_features)
    )

    # Remove features que não encontraram correspondência
    df_imp = df_imp[df_imp["original_var"].notna()].copy()

    # 6. AGRUPA IMPORTÂNCIA POR VARIÁVEL ORIGINAL


    df_grouped = (
        df_imp.groupby("original_var")["importance"]
              .sum()
              .sort_values(ascending=False)
              .reset_index()
    )
    df_grouped.rename({'original_var':'feature'},axis=1,inplace=True)

    #Plotando o gráfico
    plt.figure(figsize=(6, 14))
    plt.barh(df_grouped["feature"][::-1],
            df_grouped["importance"][::-1])
    plt.xlabel("Importância")
    plt.title(f"Top- {top_k} importâncias – {type(model).__name__}")
    plt.tight_layout()
    plt.show()



    # Gerar previsões finais
    y_pred = final_pipeline.predict(X_test)
    y_proba = final_pipeline.predict_proba(X_test)[:, 1] if hasattr(final_model, "predict_proba") else None

    # Matriz de confusão
    cm = confusion_matrix(y_test, y_pred)

    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.title("Matriz de Confusão - Dados Completos")
    plt.xlabel("Predito")
    plt.ylabel("Real")
    plt.show()

    # Barplot com métricas
    metrics_dict = {
        "Accuracy": accuracy_score(y_test, y_pred),
        "Precision": precision_score(y_test, y_pred),
        "Recall": recall_score(y_test, y_pred),
        "F1 Score": f1_score(y_test, y_pred),
        "AUC": roc_auc_score(y_test, y_proba) if y_proba is not None else np.nan
    }

    plt.figure(figsize=(8, 5))
    sns.barplot(x=list(metrics_dict.keys()), y=list(metrics_dict.values()), palette="Set2")
    plt.ylim(0, 1.05)
    plt.title("Métricas de Classificação - Dados Completos")
    for i, v in enumerate(metrics_dict.values()):
        plt.text(i, v + 0.02, f"{v:.2f}", ha='center')
    plt.grid(True)
    plt.show()

    # Curva ROC
    if y_proba is not None:
        fpr, tpr, _ = roc_curve(y_test, y_proba)
        roc_auc = auc(fpr, tpr)

        plt.figure(figsize=(6, 5))
        plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.2f}")
        plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
        plt.xlabel("Falso Positivo")
        plt.ylabel("Verdadeiro Positivo")
        plt.title("Curva ROC")
        plt.legend(loc='lower right')
        plt.grid(True)
        plt.show()

    # Curva Precision-Recall
    if y_proba is not None:
        precision, recall, _ = precision_recall_curve(y_test, y_proba)
        auprc_trap = auc(recall, precision)
        plt.figure(figsize=(6, 5))
        plt.plot(recall, precision, label=f"AUPRC = {auprc_trap:.2f}")
        plt.xlabel("Recall")
        plt.ylabel("Precision")
        plt.title("Curva Precision-Recall")
        plt.legend(loc='lower right')
        plt.grid(True)
        plt.show()
# Out:
# ==============================
#   Fold Externo 1/4
# ==============================
# [LightGBM] [Info] Number of positive: 4717, number of negative: 4717
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.024595 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 25285
# [LightGBM] [Info] Number of data points in the train set: 9434, number of used features: 199
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# ==============================
#   Fold Externo 1/4
# ==============================
# [LightGBM] [Info] Number of positive: 4717, number of negative: 4717
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.023575 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 25214
# [LightGBM] [Info] Number of data points in the train set: 9434, number of used features: 197
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# ==============================
#   Fold Externo 1/4
# ==============================
# [LightGBM] [Info] Number of positive: 4718, number of negative: 4718
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.024000 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 25279
# [LightGBM] [Info] Number of data points in the train set: 9436, number of used features: 199
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# ==============================
#   Fold Externo 1/4
# ==============================
# [LightGBM] [Info] Number of positive: 4718, number of negative: 4718
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.015877 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 24859
# [LightGBM] [Info] Number of data points in the train set: 9436, number of used features: 197
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
