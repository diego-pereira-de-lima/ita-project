# %%
# !pip uninstall xgboost -y
# Out:
# Found existing installation: xgboost 3.2.0
# Uninstalling xgboost-3.2.0:
#   Successfully uninstalled xgboost-3.2.0

# %%
# !pip install optuna xgboost==3.1.1 lightgbm fastparquet imbalanced-learn torch rapidfuzz
# Out:
# Collecting optuna
#   Downloading optuna-4.7.0-py3-none-any.whl.metadata (17 kB)
# Collecting xgboost==3.1.1
#   Downloading xgboost-3.1.1-py3-none-manylinux_2_28_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.12/dist-packages (4.6.0)
# Collecting fastparquet
#   Downloading fastparquet-2025.12.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.12/dist-packages (0.14.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.10.0+cpu)
# Collecting rapidfuzz
#   Downloading rapidfuzz-3.14.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from xgboost==3.1.1) (2.0.2)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.12/dist-packages (from xgboost==3.1.1) (2.29.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from xgboost==3.1.1) (1.16.3)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.18.4)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (26.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.47)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: pandas>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from fastparquet) (2.2.2)
# Requirement already satisfied: cramjam>=2.3 in /usr/local/lib/python3.12/dist-packages (from fastparquet) (2.11.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from fastparquet) (2025.3.0)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (1.6.1)
# Requirement already satisfied: sklearn-compat<0.2,>=0.1.5 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (0.1.5)
# Requirement already satisfied: joblib<2,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.24.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->fastparquet) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->fastparquet) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->fastparquet) (2025.3)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.3.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->fastparquet) (1.17.0)
# Downloading xgboost-3.1.1-py3-none-manylinux_2_28_x86_64.whl (115.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 MB 3.1 MB/s eta 0:00:00
# Downloading optuna-4.7.0-py3-none-any.whl (413 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 413.9/413.9 kB 29.1 MB/s eta 0:00:00
# Downloading fastparquet-2025.12.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 79.1 MB/s eta 0:00:00
# Downloading rapidfuzz-3.14.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 103.0 MB/s eta 0:00:00
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Installing collected packages: rapidfuzz, colorlog, xgboost, optuna, fastparquet
# Successfully installed colorlog-6.10.1 fastparquet-2025.12.0 optuna-4.7.0 rapidfuzz-3.14.3 xgboost-3.1.1

# %%
import numpy as np
import pandas as pd
import os, joblib,time
from functools import partial

from sklearn.model_selection import StratifiedKFold, cross_val_score,train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.calibration import CalibratedClassifierCV

import optuna
from optuna.pruners import SuccessiveHalvingPruner
from optuna.exceptions import TrialPruned

#from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.impute import SimpleImputer
from functools import partial


#Feature selection
from __future__ import annotations

from sklearn.model_selection import KFold, StratifiedKFold, cross_val_score
from sklearn.feature_selection import VarianceThreshold, SelectKBest
from sklearn.feature_selection import mutual_info_classif, mutual_info_regression
from sklearn.feature_selection import f_classif, f_regression

from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.multiclass import OneVsRestClassifier, OneVsOneClassifier

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler

from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, confusion_matrix, matthews_corrcoef,
    cohen_kappa_score, balanced_accuracy_score,
    classification_report, brier_score_loss, log_loss,
    confusion_matrix, ConfusionMatrixDisplay,
    precision_recall_curve, RocCurveDisplay,roc_curve,auc
)
from sklearn.calibration import calibration_curve

from optuna.pruners import HyperbandPruner, MedianPruner
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE

import matplotlib.pyplot as plt
import seaborn as sns

import subprocess
import xgboost as xgb
import lightgbm as lgb
import torch

import re
from rapidfuzz import fuzz, process

import os
import re
import glob
import pandas as pd

import shutil
import os
from google.colab import drive


import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Configurando salvamento de checkpoints no Drive
#
# Montando o drive e acessando a conta para poder conseguir salvar os checkpoints ao final do processamento

# %%
drive.mount('/content/drive')
experimento = 'confirmados_descartados_comFeatureSelection_curva_calibracao'
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Carregando base de dados

# %% [markdown]
# Carregamento do conjunto de dados processado a partir de um arquivo no formato Parquet.
# Esse formato colunar é otimizado para leitura eficiente, reduz uso de memória e preserva os tipos de dados,
# sendo adequado para pipelines analíticos e etapas posteriores de modelagem.

# %%
df =pd.read_parquet('df_hepat_processed_v1.parquet',engine='fastparquet')

# %% [markdown]
# ### Selecionar variáveis relevantes para triagem

# %% [markdown]
# Definição das variáveis explicativas e da variável alvo utilizadas no modelo.
# As features incluem características sociodemográficas, condições ambientais, antecedentes clínicos e sintomas,
# além de variáveis derivadas de vulnerabilidade social e sazonalidade, enquanto a variável alvo representa a severidade do caso.

# %%
triage_features = [
    'NU_IDADE_N','CS_SEXO','CS_GESTANT','CS_RACA','CS_ESCOL_N',
    'ID_OCUPA_N','CON_AREA','CON_AMBIEN',
    'ANT_CB_LAM','ANT_CB_CRI','ANT_CB_SIN','ANT_CB_COR','ANT_CB_ROE',
    'ANT_CB_TER','ANT_CB_LIX','ANT_CB_OUT','ANT_ANIMAI','ANT_HUMANO',
    'CLI_FEBRE','CLI_MIALGI','CLI_CEFALE','CLI_PROST','CLI_CONGES',
    'CLI_PANTUR','CLI_VOMITO','CLI_DIARRE','CLI_ICTERI','CLI_RENAL',
    'CLI_RESPIR','CLI_CARDIA','CLI_HEMOPU','CLI_HEMORR','CLI_MENING',
    'CLI_OUTROS','SG_UF', 'baixa_escolaridade','raca_vulneravel','faixa_vulneravel',
    'vulnerabilidade_social', 'nivel_vulnerabilidade','mes_sintomas','estacao', 'periodo_chuvoso'
]



target_col = 'CLASSI_FIN'  # rótulo: confirmado vs descartado

if target_col == 'CLASSI_FIN':
    df = df[df['CLASSI_FIN'].isin(['Confirmado', 'Descartado'])].copy()

    # Criar variável alvo binária
    df['alvo'] = df['CLASSI_FIN'].map({
        'Confirmado': 1,
        'Descartado': 0
    })

# %% [markdown]
# ### Amostragem estratificada dos dados
#
# Nesta etapa é realizada uma amostragem estratificada da base de dados,
# preservando a proporção das classes da variável alvo.
# O procedimento consiste em aplicar uma amostragem aleatória dentro de cada classe,
# extraindo uma fração representativa do conjunto original.
#
# Em seguida, a base amostrada é separada em variáveis explicativas (X)
# e variável resposta (y), que serão utilizadas nas etapas subsequentes de modelagem.
#
# Essa abordagem reduz o volume de dados processados,
# mantendo a representatividade estatística das classes e garantindo reprodutibilidade
# por meio do uso de uma semente aleatória fixa.

# %%
## Amostragem estratificada
amostragem = df.groupby("alvo").sample(frac=0.35, random_state=42).copy()

X_data=amostragem[triage_features]
y_data = amostragem['alvo']

# %%
X_data.shape
# Out:
# (55110, 43)

# %% [markdown]
# ## Pipeline de seleção de variáveis com suporte a tarefas (binária, multiclasse e regressão)
#
# Esta seção implementa um pipeline completo de *feature selection* que funciona para problemas de
# classificação (binária e multiclasse) e regressão. O fluxo combina pré-processamento (numérico e categórico),
# múltiplos métodos de seleção em camadas (filter → embedded → wrapper) e, ao final, reconcilia as variáveis
# selecionadas no espaço transformado com seus nomes originais no dataset.
#
# A motivação é obter um conjunto final de variáveis com bom poder preditivo e maior estabilidade,
# evitando depender de um único critério (ex.: apenas mutual information ou apenas importância de árvore),
# e garantindo rastreabilidade entre “features após encoding” e “colunas originais”.
#
# ### Detecção automática do tipo de tarefa e escolha de validação cruzada
#
# Antes da seleção, o pipeline identifica se o problema é de classificação ou regressão a partir do parâmetro `task`.
# Com isso, define automaticamente o esquema de validação cruzada:
# - **StratifiedKFold** para classificação, preservando a proporção de classes em cada fold;
# - **KFold** para regressão, adequado quando não há estratificação por rótulo.
#
# Além disso, é definido um *scoring* padrão coerente com cada cenário (ex.: AUC-ROC para binário,
# F1-macro para multiclasse, e RMSE negativo para regressão), reduzindo risco de escolhas inconsistentes
# na avaliação do wrapper.

# %%
# -------------------------
# Helpers: task detection
# -------------------------
def _is_classification(task: str) -> bool:
    return task.lower() in ["binary", "multiclass", "classification", "clf"]

def _is_multiclass(task: str) -> bool:
    return task.lower() == "multiclass"

def _make_cv(y, task: str, n_splits: int = 5, random_state: int = 42):
    if _is_classification(task):
        return StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=random_state)
    return KFold(n_splits=n_splits, shuffle=True, random_state=random_state)

def _default_scoring(task: str) -> str:
    t = task.lower()
    if t == "binary":
        return "roc_auc"
    if t == "multiclass":
        return "f1_macro"
    if t in ["regression", "reg"]:
        return "neg_root_mean_squared_error"
    # fallback
    return "f1_macro" if _is_classification(task) else "neg_root_mean_squared_error"

def _selectkbest_score_func(task: str):
    return mutual_info_classif if _is_classification(task) else mutual_info_regression

def _anova_score_func(task: str):
    return f_classif if _is_classification(task) else f_regression

# %% [markdown]
# ### Identificação e pré-processamento de variáveis numéricas e categóricas
#
# Nesta etapa, as colunas são separadas por tipo:
# - categóricas (object/category/bool),
# - numéricas (np.number).
#
# Em seguida, aplica-se um pré-processamento unificado via `ColumnTransformer`:
# - **StandardScaler** para variáveis numéricas (normalização para modelos lineares e métricas);
# - **OneHotEncoder** para variáveis categóricas, com `handle_unknown="ignore"` para robustez.
#
# O resultado é uma matriz de features totalmente numérica, adequada para métodos de seleção e modelos do scikit-learn.

# %%
# ------------------------------------------------
# Preprocess: detect column types (customize here)
# ------------------------------------------------
def get_feature_types(X: pd.DataFrame):
    cat_cols = X.select_dtypes(include=["object", "category", "bool"]).columns.tolist()
    num_cols = X.select_dtypes(include=[np.number]).columns.tolist()
    return cat_cols, num_cols


# -------------------------------------------------------
# Mapping transformed -> original (robust for '_' in names)
# -------------------------------------------------------
def map_transformed_to_original_robust(feature_names_after_preproc, cat_cols):
    cat_cols_sorted = sorted(cat_cols, key=len, reverse=True)  # longest first
    orig = []

    for fn in feature_names_after_preproc:
        if "__" in fn:
            block, rest = fn.split("__", 1)
        else:
            block, rest = "remainder", fn

        if block == "cat":
            matched = None
            for c in cat_cols_sorted:
                if rest == c or rest.startswith(c + "_"):
                    matched = c
                    break
            orig.append(matched if matched is not None else rest.split("_", 1)[0])
        else:
            orig.append(rest)

    return np.array(orig)

# %% [markdown]
# ### Seleção wrapper com validação cruzada (desempenho real por feature)
#
# Como etapa final, aplica-se um *wrapper* que avalia cada variável individualmente usando validação cruzada.
# Ou seja, cada feature é testada em um modelo preditivo simples (Linear/Logistic),
# e é medido o desempenho médio (scoring) ao longo dos folds.
#
# A lógica do wrapper é aproximar o critério de seleção do objetivo final do projeto: desempenho preditivo,
# reduzindo o risco de selecionar variáveis “estatisticamente relevantes” mas com baixo ganho prático no modelo.
#
# O ranking final (`variaveis_finais`) corresponde às `final_wrapper` variáveis com melhor performance no wrapper.

# %%
def _make_wrapper_model(task: str, multiclass_strategy: str = "multinomial", random_state: int = 42):
    """
    multiclass_strategy:
      - "multinomial": LogisticRegression(multi_class="multinomial")
      - "ovr": OneVsRestClassifier(LogisticRegression(...))
      - "ovo": OneVsOneClassifier(LogisticRegression(...))
    """
    t = task.lower()
    m = multiclass_strategy.lower()

    if _is_classification(t):
        base_lr = LogisticRegression(
            max_iter=4000,
            solver="lbfgs",
            n_jobs=None,  # lbfgs ignores n_jobs
        )

        if t == "multiclass":
            if m == "multinomial":
                return LogisticRegression(max_iter=4000, solver="lbfgs", multi_class="multinomial")
            if m == "ovr":
                return OneVsRestClassifier(base_lr)
            if m == "ovo":
                return OneVsOneClassifier(base_lr)
            raise ValueError("multiclass_strategy must be one of: 'multinomial', 'ovr', 'ovo'")

        # binary
        return LogisticRegression(max_iter=4000, solver="lbfgs")

    # regression
    return LinearRegression()

# %% [markdown]
# ### Estratégias para classificação multiclasse: multinomial, OvR e OvO
#
# Para problemas multiclasse, o pipeline permite três estratégias:
# - **multinomial**: regressão logística multiclasse nativa (softmax),
# - **OvR (One-vs-Rest)**: treina um classificador por classe contra o resto,
# - **OvO (One-vs-One)**: treina classificadores para cada par de classes.
#
# A estratégia pode influenciar a avaliação do wrapper (principalmente com F1-macro),
# pois altera como o modelo aprende fronteiras de decisão e lida com classes minoritárias.
#
# ## Pipeline
#
# O pipeline retorna:
# - a matriz processada (`X_processado_df`) e nomes de features após pré-processamento,
# - rankings por método (Mutual Information, ANOVA/F-regression, Random Forest e Wrapper),
# - lista final de variáveis selecionadas no espaço transformado,
# - lista consolidada de variáveis no espaço original (para interpretação),
# - ranking agregado no nível da feature original (melhor score do wrapper entre suas dummies).
#
# Com isso, é possível:
# - justificar tecnicamente a seleção,
# - reproduzir resultados,
# - e comunicar as variáveis relevantes com interpretabilidade.

# %%
def pipeline_selecao_variaveis(
    X: pd.DataFrame,
    y: pd.Series,
    task: str = "binary",              # "binary", "multiclass", "regression"
    var_threshold: float = 0.0,
    k_mi: int = 80,
    k_anova: int = 80,
    top_rf: int = 50,
    final_wrapper: int = 20,
    scoring_wrapper: str | None = None,
    n_splits: int = 5,
    random_state: int = 42,
    multiclass_strategy: str = "multinomial",  # "multinomial", "ovr", "ovo"
):
    # 1) baixa variância
    selector_var = VarianceThreshold(threshold=var_threshold)
    selector_var.fit(X)
    cols_var = X.columns[selector_var.get_support()]
    X1 = X[cols_var]

    # 2) mutual info (rank)
    score_func_mi = _selectkbest_score_func(task)
    if score_func_mi is mutual_info_classif:
        selector_mi = SelectKBest(
            score_func=lambda X_, y_: mutual_info_classif(X_, y_, random_state=random_state),
            k=min(k_mi, X1.shape[1])
        )
    else:
        selector_mi = SelectKBest(score_func=mutual_info_regression, k=min(k_mi, X1.shape[1]))

    selector_mi.fit(X1, y)
    cols_mi = X1.columns[selector_mi.get_support()]
    scores_mi = selector_mi.scores_[selector_mi.get_support()]

    mi_rank = (pd.DataFrame({"variavel": cols_mi, "score_mutual_info": scores_mi})
               .sort_values("score_mutual_info", ascending=False))

    # 3) anova / f-regression (rank)
    score_func_anova = _anova_score_func(task)
    selector_anova = SelectKBest(score_func=score_func_anova, k=min(k_anova, X1.shape[1]))
    selector_anova.fit(X1, y)

    cols_anova = X1.columns[selector_anova.get_support()]
    scores_anova = selector_anova.scores_[selector_anova.get_support()]

    col_score = "score_anova_f" if _is_classification(task) else "score_f_regression"
    anova_rank = (pd.DataFrame({"variavel": cols_anova, col_score: scores_anova})
                  .sort_values(col_score, ascending=False))

    # candidatos (ordem: MI depois ANOVA; sem duplicar)
    candidatos = list(dict.fromkeys(mi_rank["variavel"].tolist() + anova_rank["variavel"].tolist()))
    Xcand = X1[candidatos] if len(candidatos) else X1.copy()

    # 4) RF importance (rank)
    if _is_classification(task):
        rf = RandomForestClassifier(
            n_estimators=400,
            random_state=random_state,
            n_jobs=-1
        )
    else:
        rf = RandomForestRegressor(
            n_estimators=400,
            random_state=random_state,
            n_jobs=-1
        )

    rf.fit(Xcand, y)

    rf_rank = (pd.DataFrame({"variavel": Xcand.columns, "importancia": rf.feature_importances_})
               .sort_values("importancia", ascending=False))

    vars_rf = rf_rank.head(min(top_rf, rf_rank.shape[0]))["variavel"].tolist()

    # 5) wrapper CV (rank) — mede desempenho real por feature (univariado)
    if scoring_wrapper is None:
        scoring_wrapper = _default_scoring(task)

    cv = _make_cv(y, task, n_splits=n_splits, random_state=random_state)
    model = _make_wrapper_model(task, multiclass_strategy=multiclass_strategy, random_state=random_state)

    resultados = []
    for var in vars_rf:
        score = cross_val_score(model, X1[[var]], y, cv=cv, scoring=scoring_wrapper).mean()
        resultados.append((var, score))

    wrap_rank = (pd.DataFrame(resultados, columns=["variavel", scoring_wrapper])
                 .sort_values(scoring_wrapper, ascending=False)
                 .head(min(final_wrapper, len(resultados))))

    return {
        "X_filtrado": X1,
        "ranking_mutual_info": mi_rank,
        "ranking_anova_ou_freg": anova_rank,
        "ranking_rf": rf_rank,
        "ranking_wrapper": wrap_rank,
        "variaveis_finais": wrap_rank["variavel"].tolist(),
        "scoring_wrapper": scoring_wrapper,
    }

# %% [markdown]
# ### Selecionando as variáveis automaticamente
#
# Esta função orquestra um pipeline completo de preparação e seleção de variáveis a partir de um `DataFrame` original,
# suportando tarefas de **classificação (binária/multiclasse)** e **regressão**.
#
# O fluxo é composto por três blocos principais:
#
# 1) **Detecção de tipos de variáveis**
# As colunas de entrada são separadas em **categóricas** e **numéricas** (via `get_feature_types_fn`),
# permitindo aplicar transformações apropriadas a cada tipo.
#
# 2) **Pré-processamento com `ColumnTransformer`**
# - Variáveis numéricas são padronizadas com `StandardScaler`, garantindo escala comparável para métodos e modelos lineares.
# - Variáveis categóricas são transformadas via `OneHotEncoder(handle_unknown="ignore")`, produzindo uma representação numérica robusta.
# Há um tratamento de compatibilidade entre versões do scikit-learn (`sparse_output` vs `sparse`).
#
# O resultado é uma matriz totalmente numérica no “espaço transformado”, acompanhada dos nomes das features geradas (`get_feature_names_out`).
#
# 3) **Seleção de variáveis no espaço transformado + mapeamento para o espaço original**
# A seleção é delegada para `pipeline_selecao_variaveis`, que ranqueia e filtra features usando múltiplos critérios
# (filtros estatísticos, importância por Random Forest e wrapper com validação cruzada).
#
# Como o One-Hot Encoding fragmenta variáveis categóricas em múltiplas colunas, a função reconstrói a rastreabilidade
# mapeando cada feature transformada para sua **coluna original** (`map_transformed_to_original_robust`).
# Além disso, é gerado um ranking agregado por feature original (max do score do wrapper entre suas dummies),
# facilitando interpretação e comunicação dos resultados.
#
# A função retorna tanto artefatos do pré-processamento (preprocessor, matriz transformada) quanto rankings e listas finais
# de variáveis selecionadas no espaço transformado e no espaço original.

# %%
def selecionar_variaveis_auto(
    X_data: pd.DataFrame,
    y_data: pd.Series,
    task: str = "binary",
    multiclass_strategy: str = "multinomial",   # multinomial | ovr | ovo
    scoring_wrapper: str | None = None,
    get_feature_types_fn=get_feature_types,
    var_threshold: float = 0.0,
    k_mi: int = 80,
    k_anova: int = 80,
    top_rf: int = 50,
    final_wrapper: int = 20,
    n_splits: int = 5,
    random_state: int = 42,
    remainder: str = "drop",  # "drop" ou "passthrough"
):
    # 1) tipos
    cat_cols, num_cols = get_feature_types_fn(X_data)

    # 2) preprocessor
    # compatibilidade entre versões sklearn:
    # em versões antigas, OneHotEncoder usa sparse=False; nas novas, sparse_output=False
    try:
        ohe = OneHotEncoder(handle_unknown="ignore", sparse_output=False)
    except TypeError:
        ohe = OneHotEncoder(handle_unknown="ignore", sparse=False)

    preprocessor = ColumnTransformer(
        transformers=[
            ("num", StandardScaler(), num_cols),
            ("cat", ohe, cat_cols),
        ],
        remainder=remainder
    )

    # 3) fit/transform
    X_processed = preprocessor.fit_transform(X_data)
    feature_names = preprocessor.get_feature_names_out()

    X_processed_df = pd.DataFrame(X_processed, columns=feature_names, index=X_data.index)

    # 4) seleção no espaço transformado
    selected = pipeline_selecao_variaveis(
        X_processed_df,
        y_data,
        task=task,
        var_threshold=var_threshold,
        k_mi=k_mi,
        k_anova=k_anova,
        top_rf=top_rf,
        final_wrapper=final_wrapper,
        scoring_wrapper=scoring_wrapper,
        n_splits=n_splits,
        random_state=random_state,
        multiclass_strategy=multiclass_strategy,
    )

    # 5) map back transformed -> original
    transformed_to_original = map_transformed_to_original_robust(feature_names, cat_cols)
    map_dict = dict(zip(feature_names, transformed_to_original))

    vars_transformadas = selected["variaveis_finais"]
    vars_originais = sorted({str(map_dict[v]) for v in vars_transformadas if v in map_dict})

    # agregação opcional: score do wrapper por feature original
    scoring_col = selected["ranking_wrapper"].columns[1]
    df_wrap = selected["ranking_wrapper"].copy()
    df_wrap["feature_original"] = df_wrap["variavel"].map(map_dict)

    ranking_original = (
        df_wrap.groupby("feature_original", dropna=False)[scoring_col]
        .max()
        .sort_values(ascending=False)
        .reset_index()
        .rename(columns={scoring_col: f"{scoring_col}_max"})
    )

    return {
        "preprocessor": preprocessor,
        "X_processado_df": X_processed_df,
        "feature_names_after_preproc": feature_names,
        "resultado_selecao_transformado": selected,
        "variaveis_finais_transformadas": vars_transformadas,
        "variaveis_finais_originais": vars_originais,
        "ranking_wrapper_por_feature_original": ranking_original,
        "cat_cols": cat_cols,
        "num_cols": num_cols,
        "map_transformada_para_original": map_dict,
    }

# %%
var_selected = selecionar_variaveis_auto(
     X_data, y_data,
     task="binary",
     scoring_wrapper="f1",
)


print(f"Variáveis selecionadas({len(var_selected["variaveis_finais_originais"])} variáveis):{var_selected["variaveis_finais_originais"]}")
print(f"Variáveis Originais({len(X_data.columns)} variáveis):{X_data.columns}")
# Out:
# Variáveis selecionadas(13 variáveis):['ANT_CB_LAM', 'CLI_ICTERI', 'CLI_OUTROS', 'CLI_PANTUR', 'CLI_PROST', 'CON_AMBIEN', 'CON_AREA', 'CS_ESCOL_N', 'ID_OCUPA_N', 'NU_IDADE_N', 'nivel_vulnerabilidade', 'periodo_chuvoso', 'vulnerabilidade_social']
# Variáveis Originais(43 variáveis):Index(['NU_IDADE_N', 'CS_SEXO', 'CS_GESTANT', 'CS_RACA', 'CS_ESCOL_N',
#        'ID_OCUPA_N', 'CON_AREA', 'CON_AMBIEN', 'ANT_CB_LAM', 'ANT_CB_CRI',
#        'ANT_CB_SIN', 'ANT_CB_COR', 'ANT_CB_ROE', 'ANT_CB_TER', 'ANT_CB_LIX',
#        'ANT_CB_OUT', 'ANT_ANIMAI', 'ANT_HUMANO', 'CLI_FEBRE', 'CLI_MIALGI',
#        'CLI_CEFALE', 'CLI_PROST', 'CLI_CONGES', 'CLI_PANTUR', 'CLI_VOMITO',
#        'CLI_DIARRE', 'CLI_ICTERI', 'CLI_RENAL', 'CLI_RESPIR', 'CLI_CARDIA',
#        'CLI_HEMOPU', 'CLI_HEMORR', 'CLI_MENING', 'CLI_OUTROS', 'SG_UF',
#        'baixa_escolaridade', 'raca_vulneravel', 'faixa_vulneravel',
#        'vulnerabilidade_social', 'nivel_vulnerabilidade', 'mes_sintomas',
#        'estacao', 'periodo_chuvoso'],
#       dtype='object')

# %%
X_data = X_data[var_selected['variaveis_finais_originais']]
X_data.shape
# Out:
# (55110, 13)

# %% [markdown]
# ## Train framework

# %% [markdown]
# ### Funções de apoio

# %% [markdown]
# Detecta automaticamente a disponibilidade de GPU no ambiente,
# verificando suporte a CUDA, compatibilidade do LightGBM com GPU
# e informações do hardware via `nvidia-smi`.

# %%
def detect_gpu():
    """
    Detecta corretamente suporte a GPU para CUDA, XGBoost e LightGBM.
    Retorna um dicionário completo.
    """

    # 1. Verificar CUDA geral
    try:
        cuda_available = torch.cuda.is_available()
    except:
        cuda_available = False


    # 2. Testar LightGBM GPU

    try:
        # Testa se LightGBM foi compilado com suporte a GPU
        lgb_gpu = lgb.register_logger(lambda x: x)  # dummy
        booster = lgb.LGBMClassifier(device="gpu")
        lgb_gpu = True
    except:
        lgb_gpu = False


    # 3. Detalhes da GPU via nvidia-smi

    try:
        smi_output = subprocess.check_output("nvidia-smi", shell=True).decode()
        gpu_info = smi_output.split("\n")[2].strip()
    except:
        gpu_info = "Nenhuma GPU detectada (nvidia-smi não disponível)"

    return {
        "cuda_available": cuda_available,
        "lightgbm_gpu": lgb_gpu,
        "gpu_info": gpu_info
    }

# %%
def get_model_params_gpu(model_name, gpu_info):
    """
    Retorna hiperparâmetros base apropriados para CPU ou GPU.
    """
    use_gpu = gpu_info["cuda_available"]

    if model_name == "xgboost":
        if use_gpu:
            return {
                "tree_method": "gpu_hist",
                "predictor": "gpu_predictor"
            }
        else:
            return {
                "tree_method": "hist",
                "predictor": "cpu_predictor"
            }

    elif model_name == "lightgbm":
        if use_gpu:
            return {
                "device": "gpu",
                "gpu_platform_id": 0,
                "gpu_device_id": 0
            }
        else:
            return {
                "device": "cpu"
            }

    elif model_name in ["random_forest", "svm"]:
        # sklearn não usa GPU
        return {}

    return {}

# %%
def get_feature_types(df):
    """
    Identifica automaticamente colunas categóricas e numéricas de um dataframe.

    Retorna:
        cat_cols  -> lista de colunas categóricas
        num_cols  -> lista de colunas numéricas
    """

    # CATEGÓRICAS: object, category ou boolean
    cat_cols = df.select_dtypes(include=['object', 'category', 'bool']).columns.tolist()

    # NUMÉRICAS: int, float
    num_cols = df.select_dtypes(include=['int', 'float', 'int64', 'float64']).columns.tolist()

    return cat_cols, num_cols

# %% [markdown]
# ###  1. FUNÇÃO PARA CRIAR O MODELO A PARTIR DO TRIAL (Optuna)

# %% [markdown]
# Esta função encapsula a criação do modelo a ser otimizado por uma *trial* do Optuna,
# permitindo que diferentes famílias de classificadores sejam avaliadas dentro do mesmo processo de busca.
#
# O fluxo é composto por duas decisões principais:
#
# 1) **Seleção do algoritmo**
# A cada iteração, o Optuna escolhe o modelo a ser testado (`svm`, `xgboost`, `lightgbm` ou `random_forest`)
# por meio de uma variável categórica (`model_name`). Isso viabiliza uma busca conjunta que compara
# arquiteturas distintas sob o mesmo protocolo de avaliação.
#
# 2) **Amostragem de hiperparâmetros e configuração dinâmica de GPU**
# Para cada algoritmo, são sugeridos hiperparâmetros relevantes (ex.: profundidade, número de árvores, taxa de aprendizado,
# subsample e colsample), definindo um espaço de busca controlado e reproduzível.
# Em paralelo, a função consulta `get_model_params_gpu(model_name, gpu_info)` para injetar automaticamente
# parâmetros específicos de aceleração (CPU/GPU) quando suportado pelo ambiente, garantindo portabilidade do pipeline.
#
# Além disso, é aplicada uma estratégia de mitigação de desbalanceamento:
# - `class_weight="balanced"` para Random Forest e SVM,
# - `is_unbalance=True` para LightGBM,
# visando reduzir viés em cenários com classes minoritárias.
#
# No caso da SVM, utiliza-se `LinearSVC` com calibração (`CalibratedClassifierCV`),
# permitindo a obtenção de probabilidades calibradas, úteis para métricas baseadas em ranking (ex.: ROC-AUC)
# e para tomada de decisão com limiar de classificação.

# %%
def create_model(trial, gpu_info):
    model_name = trial.suggest_categorical(
        "model_name", ["svm","xgboost", "lightgbm", "random_forest"]
    )

    gpu_params = get_model_params_gpu(model_name, gpu_info)

    # RANDOM FOREST
    if model_name == "random_forest":
        return RandomForestClassifier(
            n_estimators=trial.suggest_int("n_estimators", 5, 30),
            max_depth=trial.suggest_int("max_depth", 3, 9),
            min_samples_split=trial.suggest_int("min_samples_split", 2, 10),
            min_samples_leaf=trial.suggest_int("min_samples_leaf", 1, 5),
            random_state=42,
            class_weight= 'balanced',
            **gpu_params
        )

    # SVM
    elif model_name == "svm":
        svm= LinearSVC(
            C=trial.suggest_float("C", 0.1, 3.0),
            max_iter=5000,
            class_weight= 'balanced'
        )
        return CalibratedClassifierCV(svm, method="sigmoid")

    # XGBOOST
    elif model_name == "xgboost":
        return XGBClassifier(
            n_estimators=trial.suggest_int("n_estimators", 5, 30),
            max_depth=trial.suggest_int("max_depth", 3, 9),
            learning_rate=trial.suggest_float("learning_rate", 0.01, 0.3),
            subsample=trial.suggest_float("subsample", 0.5, 1.0),
            colsample_bytree=trial.suggest_float("colsample_bytree", 0.5, 1.0),
            eval_metric="logloss",
            random_state=42,
            class_weight= 'balanced',
            n_jobs=-1,
            #**gpu_params
        )

    # LIGHTGBM
    elif model_name == "lightgbm":
        return LGBMClassifier(
            n_estimators=trial.suggest_int("n_estimators", 5, 30),
            learning_rate=trial.suggest_float("learning_rate", 0.01, 0.3),
            max_depth=trial.suggest_int("max_depth", 3, 9),
            subsample=trial.suggest_float("subsample", 0.5, 1.0),
            colsample_bytree=trial.suggest_float("colsample_bytree", 0.5, 1.0),
            random_state=42,
            is_unbalance=True,
           force_col_wise=True,
            **gpu_params
        )

# %% [markdown]
# ### 2. FUNÇÃO OBJETIVO DO OPTUNA (COM CROSS-VALIDATION)

# %% [markdown]
# ### Função `build_pipeline`: pré-processamento, balanceamento e modelagem em um fluxo único
#
# Esta função constrói um pipeline completo de treinamento, integrando pré-processamento dos dados,
# tratamento de desbalanceamento e ajuste do modelo em uma única estrutura reprodutível.
#
# O pipeline é organizado em três blocos sequenciais:
#
# 1) **Pré-processamento por tipo de variável**
# - Variáveis numéricas passam por imputação da mediana, reduzindo sensibilidade a outliers,
# seguida de padronização (`StandardScaler`), garantindo escalas compatíveis para modelos sensíveis à magnitude.
# - Variáveis categóricas passam por imputação do valor mais frequente e codificação via `OneHotEncoder`,
# com tratamento explícito de categorias raras (`handle_unknown='infrequent_if_exist'`),
# o que reduz dimensionalidade excessiva e melhora estabilidade do modelo.
#
# 2) **Balanceamento de classes (SMOTE)**
# Após o pré-processamento, aplica-se o SMOTE para gerar amostras sintéticas da classe minoritária
# exclusivamente no conjunto de treino dentro do pipeline,
# evitando vazamento de informação (*data leakage*) e melhorando a capacidade do modelo
# em aprender fronteiras de decisão mais equilibradas.
#
# 3) **Modelo preditivo**
# O estimador final é injetado de forma modular, permitindo que diferentes algoritmos
# (Random Forest, SVM, XGBoost, LightGBM, etc.) sejam testados sob exatamente o mesmo fluxo de dados.
#
# Ao encapsular todas as etapas em um único objeto `Pipeline`,
# a função garante consistência entre treino, validação e inferência,
# além de facilitar integração com validação cruzada e otimização de hiperparâmetros.

# %%
def build_pipeline(model, cat_cols, num_cols):

    # construindo o preprocessor
    num_preprocessor = Pipeline(steps=[
        ("imputer", SimpleImputer(strategy="median")),
        ("scaler", StandardScaler())
    ])

    cat_preprocessor = Pipeline(steps=[
        ("imputer", SimpleImputer(strategy="most_frequent")),
        ("onehot", OneHotEncoder(handle_unknown='infrequent_if_exist'))
    ])

    preprocessor = ColumnTransformer(
        transformers=[
            ("num", num_preprocessor, num_cols),
            ("cat", cat_preprocessor, cat_cols)
        ]
    )

    # construindo pipe
    pipe = Pipeline([
        ("preprocessor", preprocessor),
        ("smote", SMOTE(random_state=42)),
        ("model", model)
    ])

    return pipe

# %% [markdown]
# ### Função `objective`: avaliação do modelo por validação cruzada e otimização com Optuna (com pruning)
#
# Esta função define a métrica objetivo utilizada pelo Optuna durante a busca de hiperparâmetros.
# Para cada `trial`, ela instancia um modelo candidato (via `create_model`) e o encapsula em um pipeline completo
# de pré-processamento + balanceamento (via `build_pipeline`), garantindo que todas as transformações
# sejam aplicadas corretamente dentro de cada fold e evitando *data leakage*.
#
# A avaliação é realizada com **validação cruzada estratificada** (`StratifiedKFold`),
# preservando a proporção de classes em treino e validação. Em cada fold:
# - o pipeline é treinado no subconjunto de treino (`fit`),
# - e a performance é medida no subconjunto de validação por **ROC-AUC** calculado a partir de probabilidades (`predict_proba`).
#
# Para suportar cenários multiclasse, o AUC é calculado com `multi_class='ovr'`
# e agregação `average='weighted'`, o que pondera o desempenho pelo suporte de cada classe
# e reduz distorções em bases desbalanceadas.
#
# Além disso, a função utiliza mecanismos de *early stopping* do Optuna:
# - `trial.report` comunica a métrica parcial por fold,
# - `trial.should_prune()` permite interromper tentativas com desempenho fraco,
# economizando tempo computacional e acelerando a convergência do processo de otimização.
#
# Ao final, a função retorna a média do AUC entre os folds, que é o valor maximizado pelo Optuna.

# %%
def objective(trial, X_train, y_train, cat_cols, num_cols,feature_names, gpu_info):

    model = create_model(trial, gpu_info)

    pipe = build_pipeline(model ,cat_cols, num_cols)


    cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

    scores = []
    for step, (train_idx, val_idx) in enumerate(cv.split(X_train, y_train)):

        X_tr, X_val = X_train.iloc[train_idx], X_train.iloc[val_idx]
        y_tr, y_val = y_train.iloc[train_idx], y_train.iloc[val_idx]


        pipe.fit(X_tr, y_tr)
        fold_auc = roc_auc_score(y_val, pipe.predict_proba(X_val)[:, 1])
        scores.append(fold_auc)

        #  reporta o valor parcial ao Optuna
        trial.report(fold_auc, step=step)

        #  aborta a tentativa dado a avaliação do pruner
        if trial.should_prune():
            raise TrialPruned()


    return np.mean(scores)

# %% [markdown]
# Salva o histórico das trials do Optuna (métrica, parâmetros, estado e duração)
# em arquivo CSV para análise e rastreabilidade do processo de otimização.

# %%
# salva os logs das tentativas com métricas, tempo de treinamento, e parametros utilizados pelos modelos
def dump_trials(study, trial, out_path):
    df_metrics = study.trials_dataframe(
        attrs=("number", "value", "params", "state", "duration")
    )
    df_metrics.to_csv(out_path, index=False)

# %% [markdown]
# ### 3. VALIDAÇÃO EXTERNA (OUTER CV) + OPTUNA INTERNO

# %% [markdown]
# ### Função `outer_cv_training_with_results`: nested CV com Optuna, checkpoint e métricas por fold
#
# Esta função executa um processo completo de treinamento e avaliação com **validação cruzada externa**
# (*outer cross-validation*), integrando **otimização de hiperparâmetros com Optuna** dentro de cada fold
# e registrando resultados detalhados (modelo escolhido, métricas, tempo e artefatos salvos).
#
# O fluxo segue a lógica de *nested cross-validation*:
#
# 1) **Diagnóstico do ambiente (GPU)**
# Antes do treinamento, a função identifica a disponibilidade de GPU (`detect_gpu`), permitindo que a criação dos modelos
# ative parâmetros específicos de aceleração quando suportado.
#
# 2) **Validação cruzada externa (generalização)**
# É aplicada uma `StratifiedKFold` externa com `n_splits`, garantindo que a proporção das classes seja preservada em cada divisão.
# Em cada fold externo, o conjunto é particionado em `X_train/y_train` (para otimização e treino) e `X_test/y_test` (avaliação final).
#
# 3) **Otimização interna com Optuna (seleção de modelo + hiperparâmetros)**
# Para cada fold externo, um `study` é criado com objetivo de maximizar a métrica definida na função `objective`.
# A função `objective` é “fixada” via `partial`, injetando os dados do fold e metadados do pipeline (colunas numéricas e categóricas,
# GPU, etc.), de forma que cada trial avalie modelos e hiperparâmetros sob o mesmo protocolo.
#
# O estudo é executado com:
# - `n_trials` tentativas,
# - controle de tempo (`timeout`),
# - paralelismo (`n_jobs=-1`),
# - callback de logging (`dump_trials`) para persistir histórico das trials.
#
# 4) **Treinamento final do melhor modelo no fold e checkpoint**
# Após a otimização, a melhor configuração é recuperada (`study.best_params`) e o melhor modelo é reconstruído (`create_model`),
# sendo então encapsulado em um pipeline (`build_pipeline`) com pré-processamento e SMOTE.
# O pipeline é treinado no conjunto de treino do fold com medição de tempo, e o artefato final é salvo em disco (`joblib.dump`)
# como checkpoint (`best_model_fold_k.pkl`), garantindo reprodutibilidade e possibilidade de reuso posterior.
#
# 5) **Avaliação no conjunto de teste do fold (métricas completas)**
# O modelo treinado é avaliado no `X_test/y_test` do fold externo usando:
# - **ROC-AUC multiclasse** com estratégia OvR e média ponderada (`average='weighted'`),
# - além de `accuracy`, `f1`, `recall` e `precision` (também ponderadas), adequadas para cenários desbalanceados.
#
# Ao final, a função retorna uma lista de dicionários com os resultados de cada fold,
# incluindo o modelo vencedor, hiperparâmetros, métricas, tempo de treino e caminho do checkpoint.
# Isso permite comparar estabilidade do desempenho entre folds e estimar capacidade real de generalização.

# %%
def outer_cv_training_with_results(
    X, y, cat_cols, num_cols,
    n_trials=30, n_splits=5,
    log_dir="log_opt",
    model_ckpt_dir="checkpoints_best_models",
    pruner_mode='halving'
):
    gpu_info = detect_gpu()
    print("\n🔍 GPU detectada:", gpu_info)


    outer_cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
    results = []
    feature_names = X.columns

    for fold, (train_idx, test_idx) in enumerate(outer_cv.split(X, y), start=1):

        print(f"\n==============================")
        print(f"  Fold Externo {fold}/{n_splits}")
        print(f"==============================")

        X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]
        if pruner_mode.lower() == "hyperband":
            pruner = HyperbandPruner(
                min_resource=1,
                max_resource=20,
                reduction_factor=10
            )
        elif pruner_mode.lower() == "median":
            pruner = MedianPruner(
                n_warmup_steps=10
            )
        elif pruner_mode.lower() == "halving":
            pruner = SuccessiveHalvingPruner(
                min_resource=1, reduction_factor=3, min_early_stopping_rate=1
            )

        study = optuna.create_study(direction="maximize", pruner=pruner)

        objective_fixed = partial(
            objective,
            X_train=X_train,
            y_train=y_train,
            cat_cols=cat_cols,
            num_cols=num_cols,
            feature_names=feature_names,
            gpu_info=gpu_info
        )

        # log por fold (arquivo diferente)
        log_path = os.path.join(log_dir, f"trials_log_fold_{fold}.csv")
        dump_trials_cb = partial(dump_trials, out_path=log_path)

        study.optimize(
            objective_fixed,
            n_trials=n_trials,
            callbacks=[dump_trials_cb],
            timeout=1800,
            n_jobs=-1,
        )

        best_params = study.best_params
        best_model_name = best_params.get("model_name", "unknown")
        best_model = create_model(study.best_trial, gpu_info)

        pipe = build_pipeline(best_model, cat_cols, num_cols)

        start_time = time.time()
        pipe.fit(X_train, y_train)
        train_time = time.time() - start_time

        # checkpoint do melhor modelo do fold
        checkpoint_path = os.path.join(model_ckpt_dir, f"best_model_fold_{fold}.pkl")
        joblib.dump(pipe, checkpoint_path)

        # predição
        y_pred = pipe.predict(X_test)
        y_pred_prob = pipe.predict_proba(X_test)[:, 1]

        # métricas
        auc = roc_auc_score(y_test, y_pred_prob)
        acc = accuracy_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)
        rec = recall_score(y_test, y_pred)
        prec = precision_score(y_test, y_pred)

        results.append({
            "fold": fold,
            "best_model": best_model_name,
            "auc": auc,
            "accuracy": acc,
            "f1": f1,
            "recall": rec,
            "precision": prec,
            "hyperparameters": best_params,
            "checkpoint_path": checkpoint_path,
            "train_time_seconds": train_time,
            "trials_log_path": log_path,
        })

    return results

# %% [markdown]
# # Execute Framework

# %% [markdown]
# Cria os diretórios de checkpoints de modelos e logs de otimização,
# caso não existam, garantindo persistência e organização dos artefatos do experimento.

# %%
import os, joblib
checkpoint_dir = "checkpoints_best_models"

if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)

checkpoint_dir = "log_opt"
if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)


# ================================================

# %% [markdown]
# ### Execução do treinamento com validação cruzada externa e otimização de hiperparâmetros
#
# Nesta etapa, o conjunto de dados é preparado para o processo completo de treinamento e avaliação.
# Inicialmente, as colunas são classificadas em **categóricas** e **numéricas** por meio da função
# `get_feature_types`, garantindo que o pré-processamento subsequente seja aplicado de forma adequada
# a cada tipo de variável.
#
# Em seguida, é executado o procedimento de **validação cruzada externa** (*outer cross-validation*),
# no qual, para cada fold, ocorre uma otimização interna de hiperparâmetros via Optuna.
# Esse desenho experimental permite avaliar o desempenho dos modelos de forma mais realista,
# uma vez que o conjunto de teste de cada fold permanece completamente isolado do processo de tuning.
#
# Os parâmetros utilizados (`n_trials=30` e `n_splits=5`) definem, respectivamente,
# o orçamento de busca de hiperparâmetros em cada fold e o número de partições externas,
# balanceando custo computacional e robustez estatística.
#
# O resultado final (`df_results`) contém métricas, hiperparâmetros selecionados,
# tempos de treinamento e caminhos dos checkpoints para cada fold,
# servindo como base para análises comparativas e seleção do modelo final.

# %%
cat_cols, num_cols = get_feature_types(X_data)
df_results = outer_cv_training_with_results(
    X_data, y_data,
    cat_cols=cat_cols,
    num_cols=num_cols,
    n_trials=50,
    n_splits=5
)
# Out:
# 🔍 GPU detectada: {'cuda_available': False, 'lightgbm_gpu': False, 'gpu_info': 'Nenhuma GPU detectada (nvidia-smi não disponível)'}
# [I 2026-03-09 00:19:31,792] A new study created in memory with name: no-name-e3e07184-4bac-4df7-95d5-c9557983d3c7
# ==============================
#   Fold Externo 1/5
# ==============================
# [I 2026-03-09 00:19:46,502] Trial 1 finished with value: 0.9020220238466717 and parameters: {'model_name': 'xgboost', 'n_estimators': 7, 'max_depth': 6, 'learning_rate': 0.18535605773143185, 'subsample': 0.7984989230288234, 'colsample_bytree': 0.7073052256846193}. Best is trial 1 with value: 0.9020220238466717.
# [I 2026-03-09 00:19:46,929] Trial 0 finished with value: 0.9098799037678743 and parameters: {'model_name': 'lightgbm', 'n_estimators': 23, 'learning_rate': 0.09524834730878337, 'max_depth': 7, 'subsample': 0.813903218799491, 'colsample_bytree': 0.5497652704552}. Best is trial 0 with value: 0.9098799037678743.
# [I 2026-03-09 00:20:01,586] Trial 3 finished with value: 0.9011766286465526 and parameters: {'model_name': 'random_forest', 'n_estimators': 19, 'max_depth': 7, 'min_samples_split': 7, 'min_samples_leaf': 3}. Best is trial 0 with value: 0.9098799037678743.
# [I 2026-03-09 00:20:05,367] Trial 2 finished with value: 0.9079207428536549 and parameters: {'model_name': 'xgboost', 'n_estimators': 25, 'max_depth': 8, 'learning_rate': 0.08516840727585229, 'subsample': 0.9883432795225828, 'colsample_bytree': 0.5205693046035808}. Best is trial 0 with value: 0.9098799037678743.
# [I 2026-03-09 00:20:16,325] Trial 4 finished with value: 0.8990744391499715 and parameters: {'model_name': 'random_forest', 'n_estimators': 27, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 5}. Best is trial 0 with value: 0.9098799037678743.
# [I 2026-03-09 00:20:20,068] Trial 5 finished with value: 0.9091362697433878 and parameters: {'model_name': 'xgboost', 'n_estimators': 19, 'max_depth': 6, 'learning_rate': 0.2513048598900353, 'subsample': 0.8709731886190557, 'colsample_bytree': 0.5547016276049672}. Best is trial 0 with value: 0.9098799037678743.
# [I 2026-03-09 00:20:34,809] Trial 7 finished with value: 0.9077791896684339 and parameters: {'model_name': 'xgboost', 'n_estimators': 21, 'max_depth': 5, 'learning_rate': 0.16564097039338674, 'subsample': 0.7509946740534643, 'colsample_bytree': 0.6316101819765094}. Best is trial 0 with value: 0.9098799037678743.
# [I 2026-03-09 00:20:40,844] Trial 6 finished with value: 0.903636820242586 and parameters: {'model_name': 'svm', 'C': 0.3541901408646879}. Best is trial 0 with value: 0.9098799037678743.
# [I 2026-03-09 00:20:48,648] Trial 8 finished with value: 0.8913118656948225 and parameters: {'model_name': 'xgboost', 'n_estimators': 10, 'max_depth': 5, 'learning_rate': 0.05234235065465126, 'subsample': 0.8670516830746775, 'colsample_bytree': 0.5087623505830375}. Best is trial 0 with value: 0.9098799037678743.
# [I 2026-03-09 00:20:54,500] Trial 9 finished with value: 0.9074552596482266 and parameters: {'model_name': 'lightgbm', 'n_estimators': 16, 'learning_rate': 0.03844169237553806, 'max_depth': 6, 'subsample': 0.5954225735176368, 'colsample_bytree': 0.5912495802820414}. Best is trial 0 with value: 0.9098799037678743.
# [I 2026-03-09 00:21:09,019] Trial 11 finished with value: 0.9104888234877319 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.10463850927858571, 'max_depth': 9, 'subsample': 0.5899818491858959, 'colsample_bytree': 0.8888725912198825}. Best is trial 11 with value: 0.9104888234877319.
# [I 2026-03-09 00:21:13,308] Trial 10 finished with value: 0.9033080931292892 and parameters: {'model_name': 'svm', 'C': 0.4891678478509287}. Best is trial 11 with value: 0.9104888234877319.
# [I 2026-03-09 00:21:24,030] Trial 12 finished with value: 0.9105986117465527 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.10503013411353607, 'max_depth': 9, 'subsample': 0.5392840342273052, 'colsample_bytree': 0.9195532502316963}. Best is trial 12 with value: 0.9105986117465527.
# [I 2026-03-09 00:21:27,345] Trial 13 finished with value: 0.9103192170903972 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.09637023320216659, 'max_depth': 9, 'subsample': 0.5475760565235815, 'colsample_bytree': 0.9268395118794711}. Best is trial 12 with value: 0.9105986117465527.
# [I 2026-03-09 00:21:45,023] Trial 14 finished with value: 0.9106003690637622 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.1181233389833723, 'max_depth': 9, 'subsample': 0.5198275018971955, 'colsample_bytree': 0.9513247965577801}. Best is trial 14 with value: 0.9106003690637622.
# [I 2026-03-09 00:21:48,357] Trial 15 finished with value: 0.9106629778757487 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.14180107547752424, 'max_depth': 9, 'subsample': 0.6384852739760442, 'colsample_bytree': 0.9275198407291303}. Best is trial 15 with value: 0.9106629778757487.
# [I 2026-03-09 00:21:58,902] Trial 16 finished with value: 0.909281148903219 and parameters: {'model_name': 'lightgbm', 'n_estimators': 15, 'learning_rate': 0.1472233710910818, 'max_depth': 8, 'subsample': 0.5020527170286825, 'colsample_bytree': 0.9990642146918404}. Best is trial 15 with value: 0.9106629778757487.
# [I 2026-03-09 00:22:00,765] Trial 17 finished with value: 0.9098234060121104 and parameters: {'model_name': 'lightgbm', 'n_estimators': 15, 'learning_rate': 0.20366082202633612, 'max_depth': 8, 'subsample': 0.6613562967408451, 'colsample_bytree': 0.9975281624077545}. Best is trial 15 with value: 0.9106629778757487.
# [I 2026-03-09 00:22:13,200] Trial 18 finished with value: 0.910368720985689 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.21049137592570472, 'max_depth': 8, 'subsample': 0.663365852107179, 'colsample_bytree': 0.7860500467123374}. Best is trial 15 with value: 0.9106629778757487.
# [I 2026-03-09 00:22:14,874] Trial 19 finished with value: 0.9091222357662395 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.2880627725203747, 'max_depth': 7, 'subsample': 0.6814495059084972, 'colsample_bytree': 0.842967345490232}. Best is trial 15 with value: 0.9106629778757487.
# [I 2026-03-09 00:22:26,178] Trial 20 finished with value: 0.8973436111079408 and parameters: {'model_name': 'random_forest', 'n_estimators': 27, 'max_depth': 3, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 15 with value: 0.9106629778757487.
# [I 2026-03-09 00:22:41,147] Trial 22 finished with value: 0.9107558455600593 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.1395787245159349, 'max_depth': 9, 'subsample': 0.5031861791666687, 'colsample_bytree': 0.9260712915319801}. Best is trial 22 with value: 0.9107558455600593.
# [I 2026-03-09 00:22:49,433] Trial 21 finished with value: 0.9020271636001996 and parameters: {'model_name': 'svm', 'C': 2.923027024891909}. Best is trial 22 with value: 0.9107558455600593.
# [I 2026-03-09 00:22:55,774] Trial 23 finished with value: 0.9104110133506748 and parameters: {'model_name': 'lightgbm', 'n_estimators': 23, 'learning_rate': 0.1410173575408905, 'max_depth': 9, 'subsample': 0.5025620426613588, 'colsample_bytree': 0.8414515993939929}. Best is trial 22 with value: 0.9107558455600593.
# [I 2026-03-09 00:23:03,584] Trial 24 finished with value: 0.9103086399076398 and parameters: {'model_name': 'lightgbm', 'n_estimators': 23, 'learning_rate': 0.1478142553822749, 'max_depth': 9, 'subsample': 0.6070196449700038, 'colsample_bytree': 0.8518706714757113}. Best is trial 22 with value: 0.9107558455600593.
# [I 2026-03-09 00:23:09,808] Trial 25 finished with value: 0.9104643719570115 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.13134856809935508, 'max_depth': 9, 'subsample': 0.6195648487146886, 'colsample_bytree': 0.9499771880499007}. Best is trial 22 with value: 0.9107558455600593.
# [I 2026-03-09 00:23:17,934] Trial 26 finished with value: 0.9107572224377863 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.12562070608239803, 'max_depth': 8, 'subsample': 0.5630584259330115, 'colsample_bytree': 0.9399307141856974}. Best is trial 26 with value: 0.9107572224377863.
# [I 2026-03-09 00:23:23,652] Trial 27 finished with value: 0.9105414902775691 and parameters: {'model_name': 'lightgbm', 'n_estimators': 29, 'learning_rate': 0.17169527037821328, 'max_depth': 8, 'subsample': 0.5482066183874166, 'colsample_bytree': 0.7535067369649286}. Best is trial 26 with value: 0.9107572224377863.
# [I 2026-03-09 00:23:32,204] Trial 28 finished with value: 0.9092816702029834 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.0682012992738617, 'max_depth': 8, 'subsample': 0.7051580706488272, 'colsample_bytree': 0.7651718229493701}. Best is trial 26 with value: 0.9107572224377863.
# [I 2026-03-09 00:23:45,040] Trial 30 finished with value: 0.892344320464966 and parameters: {'model_name': 'random_forest', 'n_estimators': 12, 'max_depth': 7, 'min_samples_split': 2, 'min_samples_leaf': 5}. Best is trial 26 with value: 0.9107572224377863.
# [I 2026-03-09 00:23:59,414] Trial 29 finished with value: 0.9021210302984622 and parameters: {'model_name': 'svm', 'C': 2.425297272559502}. Best is trial 26 with value: 0.9107572224377863.
# [I 2026-03-09 00:24:13,375] Trial 32 finished with value: 0.910348092738397 and parameters: {'model_name': 'lightgbm', 'n_estimators': 25, 'learning_rate': 0.12336044150874419, 'max_depth': 9, 'subsample': 0.553444156581131, 'colsample_bytree': 0.9607707123482657}. Best is trial 26 with value: 0.9107572224377863.
# [I 2026-03-09 00:24:18,877] Trial 31 finished with value: 0.9021301200222483 and parameters: {'model_name': 'svm', 'C': 2.389715719015407}. Best is trial 26 with value: 0.9107572224377863.
# [I 2026-03-09 00:24:27,421] Trial 33 finished with value: 0.9105006696029871 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.1214568563623747, 'max_depth': 9, 'subsample': 0.5075017571068213, 'colsample_bytree': 0.8932098147238768}. Best is trial 26 with value: 0.9107572224377863.
# [I 2026-03-09 00:24:33,529] Trial 34 finished with value: 0.9107291807097996 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.12324750843030993, 'max_depth': 9, 'subsample': 0.5012608617071391, 'colsample_bytree': 0.8901285390221757}. Best is trial 26 with value: 0.9107572224377863.
# [I 2026-03-09 00:24:41,116] Trial 35 finished with value: 0.9053825368044995 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.01146444786218001, 'max_depth': 8, 'subsample': 0.5762958816531701, 'colsample_bytree': 0.9598072379475935}. Best is trial 26 with value: 0.9107572224377863.
# [I 2026-03-09 00:24:47,728] Trial 36 finished with value: 0.9104146941060535 and parameters: {'model_name': 'lightgbm', 'n_estimators': 24, 'learning_rate': 0.1787740978716179, 'max_depth': 8, 'subsample': 0.5737627794105187, 'colsample_bytree': 0.8808039384783212}. Best is trial 26 with value: 0.9107572224377863.
# [I 2026-03-09 00:24:55,002] Trial 37 finished with value: 0.9106273425363054 and parameters: {'model_name': 'lightgbm', 'n_estimators': 24, 'learning_rate': 0.18944453456794946, 'max_depth': 8, 'subsample': 0.6233406020618247, 'colsample_bytree': 0.8808619645934551}. Best is trial 26 with value: 0.9107572224377863.
# [I 2026-03-09 00:25:01,743] Trial 38 finished with value: 0.9025236462401945 and parameters: {'model_name': 'random_forest', 'n_estimators': 28, 'max_depth': 7, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 26 with value: 0.9107572224377863.
# [I 2026-03-09 00:25:09,001] Trial 39 finished with value: 0.9025236462401945 and parameters: {'model_name': 'random_forest', 'n_estimators': 28, 'max_depth': 7, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 26 with value: 0.9107572224377863.
# [I 2026-03-09 00:25:16,469] Trial 40 finished with value: 0.9017617880712029 and parameters: {'model_name': 'xgboost', 'n_estimators': 6, 'max_depth': 9, 'learning_rate': 0.15461298931210563, 'subsample': 0.6345125339919386, 'colsample_bytree': 0.7928619794059586}. Best is trial 26 with value: 0.9107572224377863.
# [I 2026-03-09 00:25:27,675] Trial 41 finished with value: 0.9053184575041046 and parameters: {'model_name': 'xgboost', 'n_estimators': 21, 'max_depth': 9, 'learning_rate': 0.07517997700131825, 'subsample': 0.6295680071483593, 'colsample_bytree': 0.8129401410893512}. Best is trial 26 with value: 0.9107572224377863.
# [I 2026-03-09 00:25:29,501] Trial 42 finished with value: 0.9103047225575279 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.20505579616693195, 'max_depth': 8, 'subsample': 0.644411646317879, 'colsample_bytree': 0.9147473616681612}. Best is trial 26 with value: 0.9107572224377863.
# [I 2026-03-09 00:25:42,019] Trial 43 finished with value: 0.9105226928119902 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.19502125313402538, 'max_depth': 8, 'subsample': 0.7146535646703425, 'colsample_bytree': 0.9187393057400706}. Best is trial 26 with value: 0.9107572224377863.
# [I 2026-03-09 00:25:43,101] Trial 44 finished with value: 0.910361741542022 and parameters: {'model_name': 'lightgbm', 'n_estimators': 25, 'learning_rate': 0.22556290378722096, 'max_depth': 8, 'subsample': 0.5333009760749696, 'colsample_bytree': 0.8650019994027122}. Best is trial 26 with value: 0.9107572224377863.
# [I 2026-03-09 00:25:55,986] Trial 45 finished with value: 0.9107470087938102 and parameters: {'model_name': 'lightgbm', 'n_estimators': 24, 'learning_rate': 0.1625278854478735, 'max_depth': 8, 'subsample': 0.5375399455540896, 'colsample_bytree': 0.8796373510559503}. Best is trial 26 with value: 0.9107572224377863.
# [I 2026-03-09 00:25:56,876] Trial 46 finished with value: 0.910798318514373 and parameters: {'model_name': 'lightgbm', 'n_estimators': 21, 'learning_rate': 0.16639427756743294, 'max_depth': 9, 'subsample': 0.5691530833047652, 'colsample_bytree': 0.7018463368170325}. Best is trial 46 with value: 0.910798318514373.
# [I 2026-03-09 00:26:10,232] Trial 47 finished with value: 0.9105111199137667 and parameters: {'model_name': 'lightgbm', 'n_estimators': 29, 'learning_rate': 0.160739907449349, 'max_depth': 5, 'subsample': 0.5654026513585811, 'colsample_bytree': 0.6773292486947358}. Best is trial 46 with value: 0.910798318514373.
# [I 2026-03-09 00:26:10,852] Trial 48 finished with value: 0.9105067895020055 and parameters: {'model_name': 'lightgbm', 'n_estimators': 21, 'learning_rate': 0.16362449232194523, 'max_depth': 7, 'subsample': 0.5642639708706535, 'colsample_bytree': 0.705529011636246}. Best is trial 46 with value: 0.910798318514373.
# [I 2026-03-09 00:26:20,385] Trial 49 finished with value: 0.9085547013269912 and parameters: {'model_name': 'xgboost', 'n_estimators': 21, 'max_depth': 7, 'learning_rate': 0.17028776112543195, 'subsample': 0.528710905830952, 'colsample_bytree': 0.6932262018765651}. Best is trial 46 with value: 0.910798318514373.
# [LightGBM] [Info] Number of positive: 35224, number of negative: 35224
# [LightGBM] [Info] Total Bins 15660
# [LightGBM] [Info] Number of data points in the train set: 70448, number of used features: 225
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2026-03-09 00:26:25,301] A new study created in memory with name: no-name-fa40a98b-210e-4c31-85ff-bcac81b13344
# ==============================
#   Fold Externo 2/5
# ==============================
# [I 2026-03-09 00:26:39,102] Trial 1 finished with value: 0.9058065704258588 and parameters: {'model_name': 'lightgbm', 'n_estimators': 12, 'learning_rate': 0.22615432790293788, 'max_depth': 4, 'subsample': 0.8030874153432855, 'colsample_bytree': 0.5350308792738931}. Best is trial 1 with value: 0.9058065704258588.
# [I 2026-03-09 00:26:41,618] Trial 0 finished with value: 0.9073180872671588 and parameters: {'model_name': 'xgboost', 'n_estimators': 16, 'max_depth': 8, 'learning_rate': 0.1888365666278468, 'subsample': 0.8222653556517313, 'colsample_bytree': 0.7418396981191193}. Best is trial 0 with value: 0.9073180872671588.
# [I 2026-03-09 00:26:54,047] Trial 2 finished with value: 0.9080889257834667 and parameters: {'model_name': 'lightgbm', 'n_estimators': 16, 'learning_rate': 0.20686248133358626, 'max_depth': 6, 'subsample': 0.666211453579215, 'colsample_bytree': 0.8574721338847382}. Best is trial 2 with value: 0.9080889257834667.
# [I 2026-03-09 00:26:58,042] Trial 3 finished with value: 0.9067420136486932 and parameters: {'model_name': 'xgboost', 'n_estimators': 16, 'max_depth': 7, 'learning_rate': 0.23669941440011838, 'subsample': 0.7293817409266221, 'colsample_bytree': 0.9896322254034944}. Best is trial 2 with value: 0.9080889257834667.
# [I 2026-03-09 00:27:08,052] Trial 4 finished with value: 0.9038985648053178 and parameters: {'model_name': 'lightgbm', 'n_estimators': 14, 'learning_rate': 0.13846528218391307, 'max_depth': 3, 'subsample': 0.9343091629287275, 'colsample_bytree': 0.6488544087297843}. Best is trial 2 with value: 0.9080889257834667.
# [I 2026-03-09 00:27:20,539] Trial 6 finished with value: 0.9085161615529606 and parameters: {'model_name': 'lightgbm', 'n_estimators': 12, 'learning_rate': 0.27782139657731003, 'max_depth': 7, 'subsample': 0.8103479915095959, 'colsample_bytree': 0.679953119394568}. Best is trial 6 with value: 0.9085161615529606.
# [I 2026-03-09 00:27:25,956] Trial 5 finished with value: 0.902071216604769 and parameters: {'model_name': 'svm', 'C': 0.6434797211943449}. Best is trial 6 with value: 0.9085161615529606.
# [I 2026-03-09 00:27:32,736] Trial 7 finished with value: 0.9078457936635735 and parameters: {'model_name': 'lightgbm', 'n_estimators': 14, 'learning_rate': 0.2505890437863234, 'max_depth': 8, 'subsample': 0.9076210170918276, 'colsample_bytree': 0.6468312611935423}. Best is trial 6 with value: 0.9085161615529606.
# [I 2026-03-09 00:27:39,322] Trial 8 finished with value: 0.9080192110898331 and parameters: {'model_name': 'lightgbm', 'n_estimators': 11, 'learning_rate': 0.22230514624560485, 'max_depth': 9, 'subsample': 0.9383498186976209, 'colsample_bytree': 0.848687947387514}. Best is trial 6 with value: 0.9085161615529606.
# [I 2026-03-09 00:28:08,068] Trial 9 finished with value: 0.9011366813119132 and parameters: {'model_name': 'svm', 'C': 1.9421514620459297}. Best is trial 6 with value: 0.9085161615529606.
# [I 2026-03-09 00:28:13,668] Trial 10 finished with value: 0.9011952721532245 and parameters: {'model_name': 'svm', 'C': 1.7780023591817646}. Best is trial 6 with value: 0.9085161615529606.
# [I 2026-03-09 00:28:20,424] Trial 11 finished with value: 0.8962881127671727 and parameters: {'model_name': 'random_forest', 'n_estimators': 26, 'max_depth': 5, 'min_samples_split': 9, 'min_samples_leaf': 2}. Best is trial 6 with value: 0.9085161615529606.
# [I 2026-03-09 00:28:27,460] Trial 12 finished with value: 0.9075171511417994 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.29962371729626985, 'max_depth': 5, 'subsample': 0.5639322041719793, 'colsample_bytree': 0.871496646460336}. Best is trial 6 with value: 0.9085161615529606.
# [I 2026-03-09 00:28:33,149] Trial 13 finished with value: 0.9050019072254667 and parameters: {'model_name': 'lightgbm', 'n_estimators': 5, 'learning_rate': 0.05805779798705589, 'max_depth': 6, 'subsample': 0.5700333497499062, 'colsample_bytree': 0.8599668269267474}. Best is trial 6 with value: 0.9085161615529606.
# [I 2026-03-09 00:28:37,735] Trial 14 finished with value: 0.8794621820428494 and parameters: {'model_name': 'random_forest', 'n_estimators': 6, 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 5}. Best is trial 6 with value: 0.9085161615529606.
# [I 2026-03-09 00:28:44,914] Trial 15 finished with value: 0.8794621820428494 and parameters: {'model_name': 'random_forest', 'n_estimators': 6, 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 5}. Best is trial 6 with value: 0.9085161615529606.
# [I 2026-03-09 00:28:51,884] Trial 16 finished with value: 0.908331656059772 and parameters: {'model_name': 'lightgbm', 'n_estimators': 22, 'learning_rate': 0.13554480670184677, 'max_depth': 7, 'subsample': 0.6929966504557046, 'colsample_bytree': 0.7414293540969006}. Best is trial 6 with value: 0.9085161615529606.
# [I 2026-03-09 00:28:58,545] Trial 17 finished with value: 0.9086345367709621 and parameters: {'model_name': 'lightgbm', 'n_estimators': 22, 'learning_rate': 0.29416191797614033, 'max_depth': 7, 'subsample': 0.6820734755969534, 'colsample_bytree': 0.7438076590466657}. Best is trial 17 with value: 0.9086345367709621.
# [I 2026-03-09 00:29:05,569] Trial 18 finished with value: 0.9080977034046165 and parameters: {'model_name': 'lightgbm', 'n_estimators': 21, 'learning_rate': 0.11505953721251333, 'max_depth': 8, 'subsample': 0.680701376011399, 'colsample_bytree': 0.7100697159942495}. Best is trial 17 with value: 0.9086345367709621.
# [I 2026-03-09 00:29:15,105] Trial 19 finished with value: 0.9068753242465752 and parameters: {'model_name': 'xgboost', 'n_estimators': 22, 'max_depth': 9, 'learning_rate': 0.28354859971732255, 'subsample': 0.8199149807499341, 'colsample_bytree': 0.6395435524056035}. Best is trial 17 with value: 0.9086345367709621.
# [I 2026-03-09 00:29:21,747] Trial 20 finished with value: 0.9073105264390952 and parameters: {'model_name': 'xgboost', 'n_estimators': 21, 'max_depth': 9, 'learning_rate': 0.28374976281293385, 'subsample': 0.8291917316013234, 'colsample_bytree': 0.5506445544299843}. Best is trial 17 with value: 0.9086345367709621.
# [I 2026-03-09 00:29:28,754] Trial 21 finished with value: 0.9081952773253882 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.2700606216728947, 'max_depth': 7, 'subsample': 0.6043942662079269, 'colsample_bytree': 0.515068239610442}. Best is trial 17 with value: 0.9086345367709621.
# [I 2026-03-09 00:29:36,085] Trial 22 finished with value: 0.9082131679736879 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.08267505737559804, 'max_depth': 7, 'subsample': 0.63626439957584, 'colsample_bytree': 0.7887827079883114}. Best is trial 17 with value: 0.9086345367709621.
# [I 2026-03-09 00:29:41,871] Trial 23 finished with value: 0.9078577356811272 and parameters: {'model_name': 'lightgbm', 'n_estimators': 24, 'learning_rate': 0.09041977407673443, 'max_depth': 7, 'subsample': 0.7286420967696015, 'colsample_bytree': 0.7792750175431443}. Best is trial 17 with value: 0.9086345367709621.
# [I 2026-03-09 00:29:50,027] Trial 24 finished with value: 0.9084924994311141 and parameters: {'model_name': 'lightgbm', 'n_estimators': 24, 'learning_rate': 0.17375628309026664, 'max_depth': 7, 'subsample': 0.7314698571109568, 'colsample_bytree': 0.7002943929039601}. Best is trial 17 with value: 0.9086345367709621.
# [I 2026-03-09 00:29:55,446] Trial 25 finished with value: 0.908226088319724 and parameters: {'model_name': 'lightgbm', 'n_estimators': 20, 'learning_rate': 0.1735899438971446, 'max_depth': 8, 'subsample': 0.7519060196342059, 'colsample_bytree': 0.6964764609454033}. Best is trial 17 with value: 0.9086345367709621.
# [I 2026-03-09 00:30:03,537] Trial 26 finished with value: 0.9085812237330689 and parameters: {'model_name': 'lightgbm', 'n_estimators': 19, 'learning_rate': 0.1805165761385559, 'max_depth': 8, 'subsample': 0.5044184990537952, 'colsample_bytree': 0.6863925456164093}. Best is trial 17 with value: 0.9086345367709621.
# [I 2026-03-09 00:30:08,555] Trial 27 finished with value: 0.9058782736998664 and parameters: {'model_name': 'lightgbm', 'n_estimators': 9, 'learning_rate': 0.17884849651299844, 'max_depth': 5, 'subsample': 0.5038110000768681, 'colsample_bytree': 0.6213218688730078}. Best is trial 17 with value: 0.9086345367709621.
# [I 2026-03-09 00:30:15,256] Trial 28 finished with value: 0.8932087843829813 and parameters: {'model_name': 'random_forest', 'n_estimators': 9, 'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 17 with value: 0.9086345367709621.
# [I 2026-03-09 00:30:46,426] Trial 29 finished with value: 0.9009433775006567 and parameters: {'model_name': 'svm', 'C': 2.8075243509063412}. Best is trial 17 with value: 0.9086345367709621.
# [I 2026-03-09 00:30:53,408] Trial 30 finished with value: 0.9009210775806574 and parameters: {'model_name': 'svm', 'C': 2.9585703084806108}. Best is trial 17 with value: 0.9086345367709621.
# [I 2026-03-09 00:31:00,954] Trial 31 finished with value: 0.9071619789268567 and parameters: {'model_name': 'xgboost', 'n_estimators': 19, 'max_depth': 8, 'learning_rate': 0.2542785252501587, 'subsample': 0.5116109800007688, 'colsample_bytree': 0.5804619135164827}. Best is trial 17 with value: 0.9086345367709621.
# [I 2026-03-09 00:31:07,180] Trial 32 finished with value: 0.9087388746077688 and parameters: {'model_name': 'lightgbm', 'n_estimators': 19, 'learning_rate': 0.2590980604577539, 'max_depth': 7, 'subsample': 0.773613960694523, 'colsample_bytree': 0.6930976640610395}. Best is trial 32 with value: 0.9087388746077688.
# [I 2026-03-09 00:31:14,772] Trial 33 finished with value: 0.9067662436359291 and parameters: {'model_name': 'lightgbm', 'n_estimators': 25, 'learning_rate': 0.026229967024163053, 'max_depth': 7, 'subsample': 0.7850235634153806, 'colsample_bytree': 0.6928236240382032}. Best is trial 32 with value: 0.9087388746077688.
# [I 2026-03-09 00:31:20,356] Trial 34 finished with value: 0.9086628620028466 and parameters: {'model_name': 'lightgbm', 'n_estimators': 18, 'learning_rate': 0.259994663590834, 'max_depth': 7, 'subsample': 0.8686816638990786, 'colsample_bytree': 0.6841575003824042}. Best is trial 32 with value: 0.9087388746077688.
# [I 2026-03-09 00:31:28,042] Trial 35 finished with value: 0.908643683283643 and parameters: {'model_name': 'lightgbm', 'n_estimators': 18, 'learning_rate': 0.2593985494820406, 'max_depth': 6, 'subsample': 0.8783394507873178, 'colsample_bytree': 0.7969729018091258}. Best is trial 32 with value: 0.9087388746077688.
# [I 2026-03-09 00:31:32,997] Trial 36 finished with value: 0.9081854235774429 and parameters: {'model_name': 'lightgbm', 'n_estimators': 17, 'learning_rate': 0.2993921170003875, 'max_depth': 8, 'subsample': 0.886803547350988, 'colsample_bytree': 0.7937425165338176}. Best is trial 32 with value: 0.9087388746077688.
# [I 2026-03-09 00:31:41,553] Trial 37 finished with value: 0.9087911050290277 and parameters: {'model_name': 'lightgbm', 'n_estimators': 17, 'learning_rate': 0.25242571362473554, 'max_depth': 6, 'subsample': 0.8810700490564883, 'colsample_bytree': 0.8065604838840057}. Best is trial 37 with value: 0.9087911050290277.
# [I 2026-03-09 00:31:53,414] Trial 38 finished with value: 0.9085635318873928 and parameters: {'model_name': 'lightgbm', 'n_estimators': 18, 'learning_rate': 0.25833275296655445, 'max_depth': 6, 'subsample': 0.9949346280722041, 'colsample_bytree': 0.7610459948747309}. Best is trial 37 with value: 0.9087911050290277.
# [I 2026-03-09 00:32:03,545] Trial 39 finished with value: 0.9083646313011857 and parameters: {'model_name': 'lightgbm', 'n_estimators': 18, 'learning_rate': 0.26118689791288663, 'max_depth': 6, 'subsample': 0.8612331923526825, 'colsample_bytree': 0.8291397286780754}. Best is trial 37 with value: 0.9087911050290277.
# [I 2026-03-09 00:32:09,107] Trial 40 finished with value: 0.9050980551352087 and parameters: {'model_name': 'xgboost', 'n_estimators': 15, 'max_depth': 5, 'learning_rate': 0.2040199149829045, 'subsample': 0.861376689993008, 'colsample_bytree': 0.8147382206447098}. Best is trial 37 with value: 0.9087911050290277.
# [I 2026-03-09 00:32:17,244] Trial 41 finished with value: 0.9040607254228652 and parameters: {'model_name': 'xgboost', 'n_estimators': 15, 'max_depth': 4, 'learning_rate': 0.20355618718251176, 'subsample': 0.8614769680712722, 'colsample_bytree': 0.8922496367509027}. Best is trial 37 with value: 0.9087911050290277.
# [I 2026-03-09 00:32:22,282] Trial 42 finished with value: 0.908785207685193 and parameters: {'model_name': 'lightgbm', 'n_estimators': 17, 'learning_rate': 0.2404202623594302, 'max_depth': 6, 'subsample': 0.8562644112070235, 'colsample_bytree': 0.906579082894174}. Best is trial 37 with value: 0.9087911050290277.
# [I 2026-03-09 00:32:30,978] Trial 43 finished with value: 0.9086021935756122 and parameters: {'model_name': 'lightgbm', 'n_estimators': 17, 'learning_rate': 0.23228034745618512, 'max_depth': 6, 'subsample': 0.9746791146042314, 'colsample_bytree': 0.7349585802295677}. Best is trial 37 with value: 0.9087911050290277.
# [I 2026-03-09 00:32:35,945] Trial 44 finished with value: 0.9083116406592896 and parameters: {'model_name': 'lightgbm', 'n_estimators': 17, 'learning_rate': 0.23034651073399598, 'max_depth': 6, 'subsample': 0.7746217784800831, 'colsample_bytree': 0.9171561716489304}. Best is trial 37 with value: 0.9087911050290277.
# [I 2026-03-09 00:32:43,628] Trial 45 finished with value: 0.9083908744979182 and parameters: {'model_name': 'lightgbm', 'n_estimators': 16, 'learning_rate': 0.2400953822353978, 'max_depth': 6, 'subsample': 0.7740928771536469, 'colsample_bytree': 0.9358033762613404}. Best is trial 37 with value: 0.9087911050290277.
# [I 2026-03-09 00:32:49,230] Trial 46 finished with value: 0.9083434853637519 and parameters: {'model_name': 'lightgbm', 'n_estimators': 13, 'learning_rate': 0.24171575745688825, 'max_depth': 5, 'subsample': 0.9049010222746987, 'colsample_bytree': 0.9472649694780049}. Best is trial 37 with value: 0.9087911050290277.
# [I 2026-03-09 00:32:55,797] Trial 47 finished with value: 0.9073756518900504 and parameters: {'model_name': 'lightgbm', 'n_estimators': 13, 'learning_rate': 0.2173270402902038, 'max_depth': 5, 'subsample': 0.9024123915638971, 'colsample_bytree': 0.8233460929581545}. Best is trial 37 with value: 0.9087911050290277.
# [I 2026-03-09 00:33:02,667] Trial 48 finished with value: 0.9088916643572178 and parameters: {'model_name': 'lightgbm', 'n_estimators': 19, 'learning_rate': 0.2721040298358011, 'max_depth': 4, 'subsample': 0.8351249073082154, 'colsample_bytree': 0.981649217727502}. Best is trial 48 with value: 0.9088916643572178.
# [I 2026-03-09 00:33:05,977] Trial 49 finished with value: 0.8925655991629728 and parameters: {'model_name': 'random_forest', 'n_estimators': 19, 'max_depth': 4, 'min_samples_split': 6, 'min_samples_leaf': 3}. Best is trial 48 with value: 0.9088916643572178.
# [LightGBM] [Info] Number of positive: 35224, number of negative: 35224
# [LightGBM] [Info] Total Bins 15587
# [LightGBM] [Info] Number of data points in the train set: 70448, number of used features: 225
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [I 2026-03-09 00:33:10,941] A new study created in memory with name: no-name-27d1a710-fae4-4dab-92b1-dccaa67e6a30
# ==============================
#   Fold Externo 3/5
# ==============================
# [I 2026-03-09 00:33:23,314] Trial 0 finished with value: 0.8998102048810072 and parameters: {'model_name': 'xgboost', 'n_estimators': 6, 'max_depth': 5, 'learning_rate': 0.2751070954063535, 'subsample': 0.6662696050959731, 'colsample_bytree': 0.5734231523194713}. Best is trial 0 with value: 0.8998102048810072.
# [I 2026-03-09 00:33:25,839] Trial 1 finished with value: 0.9067562490141373 and parameters: {'model_name': 'xgboost', 'n_estimators': 19, 'max_depth': 7, 'learning_rate': 0.1132357874757715, 'subsample': 0.5487121722357982, 'colsample_bytree': 0.6261287928375077}. Best is trial 1 with value: 0.9067562490141373.
# [I 2026-03-09 00:33:40,046] Trial 3 finished with value: 0.9081319228612887 and parameters: {'model_name': 'lightgbm', 'n_estimators': 29, 'learning_rate': 0.03641803592979598, 'max_depth': 9, 'subsample': 0.536718121742137, 'colsample_bytree': 0.7770718091199417}. Best is trial 3 with value: 0.9081319228612887.
# [I 2026-03-09 00:33:40,363] Trial 2 finished with value: 0.904366384128889 and parameters: {'model_name': 'xgboost', 'n_estimators': 20, 'max_depth': 9, 'learning_rate': 0.061847527026205315, 'subsample': 0.7061368775077466, 'colsample_bytree': 0.7193184250477442}. Best is trial 3 with value: 0.9081319228612887.
# [I 2026-03-09 00:33:54,665] Trial 4 finished with value: 0.9075897182330485 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.032031610343962, 'max_depth': 6, 'subsample': 0.5698904508943247, 'colsample_bytree': 0.6771622093983152}. Best is trial 3 with value: 0.9081319228612887.
# [I 2026-03-09 00:34:04,757] Trial 5 finished with value: 0.9040238221039808 and parameters: {'model_name': 'svm', 'C': 0.22932076191753364}. Best is trial 3 with value: 0.9081319228612887.
# [I 2026-03-09 00:34:08,249] Trial 6 finished with value: 0.9004283517197683 and parameters: {'model_name': 'xgboost', 'n_estimators': 12, 'max_depth': 6, 'learning_rate': 0.09463373078836528, 'subsample': 0.7498385227421875, 'colsample_bytree': 0.5791670430752367}. Best is trial 3 with value: 0.9081319228612887.
# [I 2026-03-09 00:34:15,318] Trial 7 finished with value: 0.8957539512120608 and parameters: {'model_name': 'random_forest', 'n_estimators': 16, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 3}. Best is trial 3 with value: 0.9081319228612887.
# [I 2026-03-09 00:34:21,616] Trial 8 finished with value: 0.8967639128285105 and parameters: {'model_name': 'xgboost', 'n_estimators': 9, 'max_depth': 6, 'learning_rate': 0.0792787499593918, 'subsample': 0.9720736026092144, 'colsample_bytree': 0.5417609013242113}. Best is trial 3 with value: 0.9081319228612887.
# [I 2026-03-09 00:34:28,358] Trial 9 finished with value: 0.9010733107488945 and parameters: {'model_name': 'random_forest', 'n_estimators': 17, 'max_depth': 9, 'min_samples_split': 10, 'min_samples_leaf': 5}. Best is trial 3 with value: 0.9081319228612887.
# [I 2026-03-09 00:34:33,993] Trial 10 finished with value: 0.9070555771061165 and parameters: {'model_name': 'lightgbm', 'n_estimators': 12, 'learning_rate': 0.08313282500554645, 'max_depth': 7, 'subsample': 0.5055640390460261, 'colsample_bytree': 0.9591029088928815}. Best is trial 3 with value: 0.9081319228612887.
# [I 2026-03-09 00:34:42,641] Trial 11 finished with value: 0.9089401283810803 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.1993495073085804, 'max_depth': 8, 'subsample': 0.9181274734700967, 'colsample_bytree': 0.9068382486322955}. Best is trial 11 with value: 0.9089401283810803.
# [I 2026-03-09 00:34:46,165] Trial 12 finished with value: 0.8987466144905619 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.01062308094437693, 'max_depth': 3, 'subsample': 0.5996338067304778, 'colsample_bytree': 0.8252980837383108}. Best is trial 11 with value: 0.9089401283810803.
# [I 2026-03-09 00:34:56,718] Trial 13 finished with value: 0.9090120690203344 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.22495221182329214, 'max_depth': 8, 'subsample': 0.9186169967923795, 'colsample_bytree': 0.8683180817989998}. Best is trial 13 with value: 0.9090120690203344.
# [I 2026-03-09 00:34:59,988] Trial 14 finished with value: 0.9092756193722389 and parameters: {'model_name': 'lightgbm', 'n_estimators': 25, 'learning_rate': 0.21020532390852925, 'max_depth': 8, 'subsample': 0.8968917913743397, 'colsample_bytree': 0.851045033319374}. Best is trial 14 with value: 0.9092756193722389.
# [I 2026-03-09 00:35:11,061] Trial 15 finished with value: 0.9088354161896101 and parameters: {'model_name': 'lightgbm', 'n_estimators': 25, 'learning_rate': 0.22263635691440195, 'max_depth': 8, 'subsample': 0.9059467867283698, 'colsample_bytree': 0.8919830616430618}. Best is trial 14 with value: 0.9092756193722389.
# [I 2026-03-09 00:35:36,148] Trial 16 finished with value: 0.9018873852081429 and parameters: {'model_name': 'svm', 'C': 2.737533390362291}. Best is trial 14 with value: 0.9092756193722389.
# [I 2026-03-09 00:35:46,908] Trial 17 finished with value: 0.9018788623709083 and parameters: {'model_name': 'svm', 'C': 2.7721350709766366}. Best is trial 14 with value: 0.9092756193722389.
# [I 2026-03-09 00:35:49,476] Trial 18 finished with value: 0.9094795033932691 and parameters: {'model_name': 'lightgbm', 'n_estimators': 24, 'learning_rate': 0.17412210527211316, 'max_depth': 8, 'subsample': 0.8482294379217756, 'colsample_bytree': 0.8134612297613818}. Best is trial 18 with value: 0.9094795033932691.
# [I 2026-03-09 00:36:01,028] Trial 19 finished with value: 0.9094757436598631 and parameters: {'model_name': 'lightgbm', 'n_estimators': 24, 'learning_rate': 0.17351080873677557, 'max_depth': 8, 'subsample': 0.8475400572373444, 'colsample_bytree': 0.831861132817073}. Best is trial 18 with value: 0.9094795033932691.
# [I 2026-03-09 00:36:03,390] Trial 20 finished with value: 0.9094450942724001 and parameters: {'model_name': 'lightgbm', 'n_estimators': 24, 'learning_rate': 0.15008975976803182, 'max_depth': 7, 'subsample': 0.8319844583167316, 'colsample_bytree': 0.9938448387017914}. Best is trial 18 with value: 0.9094795033932691.
# [I 2026-03-09 00:36:14,721] Trial 21 finished with value: 0.8967538071700089 and parameters: {'model_name': 'random_forest', 'n_estimators': 23, 'max_depth': 7, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 18 with value: 0.9094795033932691.
# [I 2026-03-09 00:36:17,237] Trial 22 finished with value: 0.9093684117811257 and parameters: {'model_name': 'lightgbm', 'n_estimators': 23, 'learning_rate': 0.15020565070355335, 'max_depth': 7, 'subsample': 0.816988892703878, 'colsample_bytree': 0.9497947140780226}. Best is trial 18 with value: 0.9094795033932691.
# [I 2026-03-09 00:36:28,831] Trial 23 finished with value: 0.9093492877160566 and parameters: {'model_name': 'lightgbm', 'n_estimators': 24, 'learning_rate': 0.14403020857929488, 'max_depth': 7, 'subsample': 0.8175907636850005, 'colsample_bytree': 0.999205707381713}. Best is trial 18 with value: 0.9094795033932691.
# [I 2026-03-09 00:36:31,274] Trial 24 finished with value: 0.9093345171248853 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.15748439549135715, 'max_depth': 8, 'subsample': 0.8208711769499134, 'colsample_bytree': 0.9969532841209471}. Best is trial 18 with value: 0.9094795033932691.
# [I 2026-03-09 00:36:42,070] Trial 25 finished with value: 0.9092832350048407 and parameters: {'model_name': 'lightgbm', 'n_estimators': 21, 'learning_rate': 0.17892139465877158, 'max_depth': 8, 'subsample': 0.8225453347673274, 'colsample_bytree': 0.770078115663517}. Best is trial 18 with value: 0.9094795033932691.
# [I 2026-03-09 00:36:44,740] Trial 26 finished with value: 0.9088148534786349 and parameters: {'model_name': 'lightgbm', 'n_estimators': 21, 'learning_rate': 0.17906649404627584, 'max_depth': 5, 'subsample': 0.8526645640543163, 'colsample_bytree': 0.7854283525768039}. Best is trial 18 with value: 0.9094795033932691.
# [I 2026-03-09 00:36:54,662] Trial 27 finished with value: 0.9088264330542417 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.12234918521288524, 'max_depth': 5, 'subsample': 0.8585998477657745, 'colsample_bytree': 0.8117874141913114}. Best is trial 18 with value: 0.9094795033932691.
# [I 2026-03-09 00:36:58,699] Trial 28 finished with value: 0.909470230853939 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.12870291100165965, 'max_depth': 9, 'subsample': 0.7808426294154698, 'colsample_bytree': 0.7005848591916464}. Best is trial 18 with value: 0.9094795033932691.
# [I 2026-03-09 00:37:13,618] Trial 30 finished with value: 0.9036375397758842 and parameters: {'model_name': 'random_forest', 'n_estimators': 27, 'max_depth': 9, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 18 with value: 0.9094795033932691.
# [I 2026-03-09 00:37:23,126] Trial 29 finished with value: 0.902786221499977 and parameters: {'model_name': 'svm', 'C': 0.7803577888647611}. Best is trial 18 with value: 0.9094795033932691.
# [I 2026-03-09 00:37:37,293] Trial 32 finished with value: 0.9091670848094647 and parameters: {'model_name': 'lightgbm', 'n_estimators': 22, 'learning_rate': 0.12325663135867253, 'max_depth': 9, 'subsample': 0.7458618737366224, 'colsample_bytree': 0.7115806086496472}. Best is trial 18 with value: 0.9094795033932691.
# [I 2026-03-09 00:37:40,040] Trial 31 finished with value: 0.9027536392666122 and parameters: {'model_name': 'svm', 'C': 0.8077013397105691}. Best is trial 18 with value: 0.9094795033932691.
# [I 2026-03-09 00:37:51,454] Trial 33 finished with value: 0.9094847477176037 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.17961260912189075, 'max_depth': 8, 'subsample': 0.7785523725286605, 'colsample_bytree': 0.646288852426182}. Best is trial 33 with value: 0.9094847477176037.
# [I 2026-03-09 00:37:54,201] Trial 34 finished with value: 0.9095781688215138 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.17133930395744593, 'max_depth': 8, 'subsample': 0.8038784683471047, 'colsample_bytree': 0.6958890851704563}. Best is trial 34 with value: 0.9095781688215138.
# [I 2026-03-09 00:38:08,690] Trial 35 finished with value: 0.909059346956667 and parameters: {'model_name': 'xgboost', 'n_estimators': 28, 'max_depth': 9, 'learning_rate': 0.25430408772612145, 'subsample': 0.7700385339647264, 'colsample_bytree': 0.6578060860051236}. Best is trial 34 with value: 0.9095781688215138.
# [I 2026-03-09 00:38:10,574] Trial 36 finished with value: 0.9082322178006397 and parameters: {'model_name': 'xgboost', 'n_estimators': 28, 'max_depth': 8, 'learning_rate': 0.24361348196438715, 'subsample': 0.674331524707341, 'colsample_bytree': 0.6254776576289964}. Best is trial 34 with value: 0.9095781688215138.
# [I 2026-03-09 00:38:22,960] Trial 37 finished with value: 0.9091640005945226 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.18296784750774608, 'max_depth': 8, 'subsample': 0.688074101711082, 'colsample_bytree': 0.6352367002486458}. Best is trial 34 with value: 0.9095781688215138.
# [I 2026-03-09 00:38:23,780] Trial 38 finished with value: 0.9089927901917291 and parameters: {'model_name': 'lightgbm', 'n_estimators': 19, 'learning_rate': 0.1809470820864674, 'max_depth': 8, 'subsample': 0.967188943364045, 'colsample_bytree': 0.7417394685475545}. Best is trial 34 with value: 0.9095781688215138.
# [I 2026-03-09 00:38:36,292] Trial 39 finished with value: 0.9090436033939536 and parameters: {'model_name': 'lightgbm', 'n_estimators': 19, 'learning_rate': 0.1676571384924996, 'max_depth': 7, 'subsample': 0.8815128499362871, 'colsample_bytree': 0.8274729622851795}. Best is trial 34 with value: 0.9095781688215138.
# [I 2026-03-09 00:38:36,713] Trial 40 finished with value: 0.9071187300413515 and parameters: {'model_name': 'lightgbm', 'n_estimators': 5, 'learning_rate': 0.28735935120946043, 'max_depth': 7, 'subsample': 0.6294987119037321, 'colsample_bytree': 0.5880898554206286}. Best is trial 34 with value: 0.9095781688215138.
# [I 2026-03-09 00:38:49,573] Trial 41 finished with value: 0.8983484291109339 and parameters: {'model_name': 'random_forest', 'n_estimators': 25, 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 5}. Best is trial 34 with value: 0.9095781688215138.
# [I 2026-03-09 00:38:50,955] Trial 42 finished with value: 0.909371626590442 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.19885200003999637, 'max_depth': 9, 'subsample': 0.7815232718721421, 'colsample_bytree': 0.6986797911286418}. Best is trial 34 with value: 0.9095781688215138.
# [I 2026-03-09 00:39:02,655] Trial 43 finished with value: 0.909853545468906 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.20134721418273382, 'max_depth': 9, 'subsample': 0.7772708339042348, 'colsample_bytree': 0.7256038276141418}. Best is trial 43 with value: 0.909853545468906.
# [I 2026-03-09 00:39:05,068] Trial 44 finished with value: 0.9096502606610105 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.13387169162892337, 'max_depth': 9, 'subsample': 0.7326915086289348, 'colsample_bytree': 0.7443303169684854}. Best is trial 43 with value: 0.909853545468906.
# [I 2026-03-09 00:39:16,178] Trial 45 finished with value: 0.9094130878396841 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.20408419614930298, 'max_depth': 9, 'subsample': 0.7072696409543591, 'colsample_bytree': 0.7454403711474975}. Best is trial 43 with value: 0.909853545468906.
# [I 2026-03-09 00:39:23,282] Trial 46 finished with value: 0.9085104060672693 and parameters: {'model_name': 'xgboost', 'n_estimators': 29, 'max_depth': 9, 'learning_rate': 0.19688802699729585, 'subsample': 0.7406285905229778, 'colsample_bytree': 0.7378002928740548}. Best is trial 43 with value: 0.909853545468906.
# [I 2026-03-09 00:39:35,705] Trial 47 finished with value: 0.9089873803947128 and parameters: {'model_name': 'xgboost', 'n_estimators': 29, 'max_depth': 9, 'learning_rate': 0.1398924117612437, 'subsample': 0.7154011665371545, 'colsample_bytree': 0.6675018729232263}. Best is trial 43 with value: 0.909853545468906.
# [I 2026-03-09 00:39:36,701] Trial 48 finished with value: 0.9090158741011461 and parameters: {'model_name': 'lightgbm', 'n_estimators': 15, 'learning_rate': 0.14255582674925932, 'max_depth': 9, 'subsample': 0.7020311918914486, 'colsample_bytree': 0.6696576648420487}. Best is trial 43 with value: 0.909853545468906.
# [I 2026-03-09 00:39:42,975] Trial 49 finished with value: 0.908187207875163 and parameters: {'model_name': 'lightgbm', 'n_estimators': 14, 'learning_rate': 0.10751222736090786, 'max_depth': 9, 'subsample': 0.7861333187805227, 'colsample_bytree': 0.7946615301092887}. Best is trial 43 with value: 0.909853545468906.
# [LightGBM] [Info] Number of positive: 35224, number of negative: 35224
# [LightGBM] [Info] Total Bins 15442
# [LightGBM] [Info] Number of data points in the train set: 70448, number of used features: 226
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2026-03-09 00:39:48,499] A new study created in memory with name: no-name-80fc68ae-4b20-429e-9ad9-47fa2ad81f2c
# ==============================
#   Fold Externo 4/5
# ==============================
# [I 2026-03-09 00:40:00,661] Trial 0 finished with value: 0.898505488556097 and parameters: {'model_name': 'random_forest', 'n_estimators': 18, 'max_depth': 6, 'min_samples_split': 7, 'min_samples_leaf': 5}. Best is trial 0 with value: 0.898505488556097.
# ...
# [I 2026-03-09 00:46:18,968] Trial 48 finished with value: 0.8993975405600004 and parameters: {'model_name': 'random_forest', 'n_estimators': 20, 'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 36 with value: 0.9098833078904156.
# [I 2026-03-09 00:46:25,264] Trial 49 finished with value: 0.8973821375336007 and parameters: {'model_name': 'random_forest', 'n_estimators': 19, 'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 36 with value: 0.9098833078904156.
# [LightGBM] [Info] Number of positive: 35224, number of negative: 35224
# [LightGBM] [Info] Total Bins 15448
# [LightGBM] [Info] Number of data points in the train set: 70448, number of used features: 218
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2026-03-09 00:46:30,466] A new study created in memory with name: no-name-bd227bf4-fd7e-42f6-9e0c-8d5bd3ef7751
# ==============================
#   Fold Externo 5/5
# ==============================
# [I 2026-03-09 00:46:43,349] Trial 0 finished with value: 0.8968941363435637 and parameters: {'model_name': 'random_forest', 'n_estimators': 13, 'max_depth': 8, 'min_samples_split': 7, 'min_samples_leaf': 4}. Best is trial 0 with value: 0.8968941363435637.
# [I 2026-03-09 00:46:44,748] Trial 1 finished with value: 0.908819780174062 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.26088114090713505, 'max_depth': 9, 'subsample': 0.8066963359105164, 'colsample_bytree': 0.5777519365524093}. Best is trial 1 with value: 0.908819780174062.
# [I 2026-03-09 00:46:57,195] Trial 2 finished with value: 0.9098479999827226 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.18756678218326053, 'max_depth': 7, 'subsample': 0.6031513196723868, 'colsample_bytree': 0.6934939547300472}. Best is trial 2 with value: 0.9098479999827226.
# [I 2026-03-09 00:47:10,358] Trial 4 finished with value: 0.9091839906130458 and parameters: {'model_name': 'lightgbm', 'n_estimators': 22, 'learning_rate': 0.2959694459019194, 'max_depth': 6, 'subsample': 0.5080189601923987, 'colsample_bytree': 0.9571304720700418}. Best is trial 2 with value: 0.9098479999827226.
# [I 2026-03-09 00:47:18,711] Trial 3 finished with value: 0.9014731946697969 and parameters: {'model_name': 'svm', 'C': 2.069047230832947}. Best is trial 2 with value: 0.9098479999827226.
# [I 2026-03-09 00:47:23,762] Trial 5 finished with value: 0.8966210699575826 and parameters: {'model_name': 'xgboost', 'n_estimators': 17, 'max_depth': 4, 'learning_rate': 0.03430230739734041, 'subsample': 0.7562245867411128, 'colsample_bytree': 0.7317027480752687}. Best is trial 2 with value: 0.9098479999827226.
# [I 2026-03-09 00:47:34,044] Trial 6 finished with value: 0.905293442182491 and parameters: {'model_name': 'random_forest', 'n_estimators': 29, 'max_depth': 9, 'min_samples_split': 9, 'min_samples_leaf': 1}. Best is trial 2 with value: 0.9098479999827226.
# [I 2026-03-09 00:47:49,981] Trial 7 finished with value: 0.9025140441028846 and parameters: {'model_name': 'svm', 'C': 0.5414666938985871}. Best is trial 2 with value: 0.9098479999827226.
# [I 2026-03-09 00:48:03,768] Trial 8 finished with value: 0.9021623229585015 and parameters: {'model_name': 'svm', 'C': 0.7850324201096824}. Best is trial 2 with value: 0.9098479999827226.
# [I 2026-03-09 00:48:05,961] Trial 9 finished with value: 0.9038212000209898 and parameters: {'model_name': 'xgboost', 'n_estimators': 17, 'max_depth': 6, 'learning_rate': 0.11973939791852223, 'subsample': 0.8588730343171329, 'colsample_bytree': 0.6198101387149284}. Best is trial 2 with value: 0.9098479999827226.
# [I 2026-03-09 00:48:18,086] Trial 10 finished with value: 0.9022721813116762 and parameters: {'model_name': 'random_forest', 'n_estimators': 19, 'max_depth': 9, 'min_samples_split': 4, 'min_samples_leaf': 2}. Best is trial 2 with value: 0.9098479999827226.
# [I 2026-03-09 00:48:18,840] Trial 11 finished with value: 0.9070078889281451 and parameters: {'model_name': 'lightgbm', 'n_estimators': 8, 'learning_rate': 0.19438861491496678, 'max_depth': 6, 'subsample': 0.5779183027379741, 'colsample_bytree': 0.8725968346847025}. Best is trial 2 with value: 0.9098479999827226.
# [I 2026-03-09 00:48:31,551] Trial 12 finished with value: 0.9100078521512461 and parameters: {'model_name': 'lightgbm', 'n_estimators': 24, 'learning_rate': 0.2638960532649586, 'max_depth': 6, 'subsample': 0.5050950855515286, 'colsample_bytree': 0.9850720842674725}. Best is trial 12 with value: 0.9100078521512461.
# [I 2026-03-09 00:48:32,835] Trial 13 finished with value: 0.9095937671169981 and parameters: {'model_name': 'lightgbm', 'n_estimators': 24, 'learning_rate': 0.29046296762032997, 'max_depth': 7, 'subsample': 0.520604510480541, 'colsample_bytree': 0.9895399193404589}. Best is trial 12 with value: 0.9100078521512461.
# [I 2026-03-09 00:48:43,805] Trial 14 finished with value: 0.9092369074943152 and parameters: {'model_name': 'lightgbm', 'n_estimators': 25, 'learning_rate': 0.19873279493766788, 'max_depth': 4, 'subsample': 0.6261447508724, 'colsample_bytree': 0.7799995799256749}. Best is trial 12 with value: 0.9100078521512461.
# [I 2026-03-09 00:48:45,586] Trial 15 finished with value: 0.9091933136949623 and parameters: {'model_name': 'lightgbm', 'n_estimators': 25, 'learning_rate': 0.18656374513634533, 'max_depth': 4, 'subsample': 0.6425798210240437, 'colsample_bytree': 0.7490125408257277}. Best is trial 12 with value: 0.9100078521512461.
# [I 2026-03-09 00:48:57,565] Trial 16 finished with value: 0.9094235858236632 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.21381859621467572, 'max_depth': 5, 'subsample': 0.6490585222930576, 'colsample_bytree': 0.7056423503552702}. Best is trial 12 with value: 0.9100078521512461.
# [I 2026-03-09 00:48:58,761] Trial 17 finished with value: 0.9095604335148987 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.12350907881876254, 'max_depth': 7, 'subsample': 0.9757342947651955, 'colsample_bytree': 0.6736562400090712}. Best is trial 12 with value: 0.9100078521512461.
# [I 2026-03-09 00:49:11,789] Trial 18 finished with value: 0.9097255424968141 and parameters: {'model_name': 'lightgbm', 'n_estimators': 21, 'learning_rate': 0.11821508406300033, 'max_depth': 7, 'subsample': 0.9532408086943049, 'colsample_bytree': 0.5111131248268957}. Best is trial 12 with value: 0.9100078521512461.
# [I 2026-03-09 00:49:15,184] Trial 19 finished with value: 0.9086112676066538 and parameters: {'model_name': 'xgboost', 'n_estimators': 20, 'max_depth': 7, 'learning_rate': 0.24741736849485768, 'subsample': 0.5757485444898623, 'colsample_bytree': 0.8628619498021397}. Best is trial 12 with value: 0.9100078521512461.
# [I 2026-03-09 00:49:25,270] Trial 20 finished with value: 0.9043354512941062 and parameters: {'model_name': 'xgboost', 'n_estimators': 12, 'max_depth': 3, 'learning_rate': 0.24484184444743462, 'subsample': 0.6955109611834536, 'colsample_bytree': 0.8621195099615198}. Best is trial 12 with value: 0.9100078521512461.
# [I 2026-03-09 00:49:27,671] Trial 21 finished with value: 0.8924724914018629 and parameters: {'model_name': 'lightgbm', 'n_estimators': 6, 'learning_rate': 0.05061303640209462, 'max_depth': 3, 'subsample': 0.6924871086323184, 'colsample_bytree': 0.8353837047384199}. Best is trial 12 with value: 0.9100078521512461.
# [I 2026-03-09 00:49:39,372] Trial 22 finished with value: 0.9091611453713305 and parameters: {'model_name': 'lightgbm', 'n_estimators': 22, 'learning_rate': 0.07704132017540097, 'max_depth': 8, 'subsample': 0.9971269376228122, 'colsample_bytree': 0.5017346412615612}. Best is trial 12 with value: 0.9100078521512461.
# [I 2026-03-09 00:49:41,203] Trial 23 finished with value: 0.9097519245032165 and parameters: {'model_name': 'lightgbm', 'n_estimators': 22, 'learning_rate': 0.1351343845553372, 'max_depth': 8, 'subsample': 0.9777939412585944, 'colsample_bytree': 0.5130083219606824}. Best is trial 12 with value: 0.9100078521512461.
# [I 2026-03-09 00:50:01,005] Trial 24 finished with value: 0.9099607329110128 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.1409016941151995, 'max_depth': 7, 'subsample': 0.9049076576692722, 'colsample_bytree': 0.5259886229967665}. Best is trial 12 with value: 0.9100078521512461.
# [I 2026-03-09 00:50:02,255] Trial 25 finished with value: 0.909708999036661 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.1597159517697459, 'max_depth': 8, 'subsample': 0.8651646440603841, 'colsample_bytree': 0.6077784520263877}. Best is trial 12 with value: 0.9100078521512461.
# [I 2026-03-09 00:50:15,245] Trial 26 finished with value: 0.9093525584713348 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.14881494286319982, 'max_depth': 5, 'subsample': 0.8739723903710649, 'colsample_bytree': 0.6305939968542851}. Best is trial 12 with value: 0.9100078521512461.
# [I 2026-03-09 00:50:16,467] Trial 27 finished with value: 0.9095549738681017 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.16903401272684862, 'max_depth': 5, 'subsample': 0.5616811595421217, 'colsample_bytree': 0.6614751597273336}. Best is trial 12 with value: 0.9100078521512461.
# [I 2026-03-09 00:50:28,819] Trial 28 finished with value: 0.9019017993713873 and parameters: {'model_name': 'random_forest', 'n_estimators': 30, 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 5}. Best is trial 12 with value: 0.9100078521512461.
# [I 2026-03-09 00:50:30,652] Trial 29 finished with value: 0.9031532801129482 and parameters: {'model_name': 'random_forest', 'n_estimators': 30, 'max_depth': 7, 'min_samples_split': 2, 'min_samples_leaf': 5}. Best is trial 12 with value: 0.9100078521512461.
# [I 2026-03-09 00:51:04,354] Trial 30 finished with value: 0.9013012625221336 and parameters: {'model_name': 'svm', 'C': 2.943288855205255}. Best is trial 12 with value: 0.9100078521512461.
# [I 2026-03-09 00:51:06,764] Trial 31 finished with value: 0.901294767305704 and parameters: {'model_name': 'svm', 'C': 2.9966656092931423}. Best is trial 12 with value: 0.9100078521512461.
# [I 2026-03-09 00:51:18,226] Trial 32 finished with value: 0.9094306750694093 and parameters: {'model_name': 'lightgbm', 'n_estimators': 23, 'learning_rate': 0.0933754230920129, 'max_depth': 8, 'subsample': 0.9246683718803967, 'colsample_bytree': 0.5532636796429486}. Best is trial 12 with value: 0.9100078521512461.
# [I 2026-03-09 00:51:20,700] Trial 33 finished with value: 0.9091007031709638 and parameters: {'model_name': 'lightgbm', 'n_estimators': 23, 'learning_rate': 0.08654890464255993, 'max_depth': 8, 'subsample': 0.9370353400984058, 'colsample_bytree': 0.5646593393497213}. Best is trial 12 with value: 0.9100078521512461.
# [I 2026-03-09 00:51:32,673] Trial 34 finished with value: 0.9095242680564238 and parameters: {'model_name': 'lightgbm', 'n_estimators': 24, 'learning_rate': 0.13623303374353637, 'max_depth': 8, 'subsample': 0.9183115120062626, 'colsample_bytree': 0.5374324218499408}. Best is trial 12 with value: 0.9100078521512461.
# [I 2026-03-09 00:51:35,281] Trial 35 finished with value: 0.9093899785492545 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.2208841873806341, 'max_depth': 7, 'subsample': 0.9129247922321507, 'colsample_bytree': 0.9232288197395986}. Best is trial 12 with value: 0.9100078521512461.
# [I 2026-03-09 00:51:46,525] Trial 36 finished with value: 0.9094993538555896 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.21916568823007093, 'max_depth': 7, 'subsample': 0.8141556803629244, 'colsample_bytree': 0.7980708216153714}. Best is trial 12 with value: 0.9100078521512461.
# [I 2026-03-09 00:51:48,404] Trial 37 finished with value: 0.9080835308494398 and parameters: {'model_name': 'lightgbm', 'n_estimators': 14, 'learning_rate': 0.16065837961122473, 'max_depth': 6, 'subsample': 0.7668279924225601, 'colsample_bytree': 0.7946719384305219}. Best is trial 12 with value: 0.9100078521512461.
# [I 2026-03-09 00:51:58,933] Trial 38 finished with value: 0.9094247179296273 and parameters: {'model_name': 'lightgbm', 'n_estimators': 19, 'learning_rate': 0.17938178864470072, 'max_depth': 6, 'subsample': 0.5555337461525247, 'colsample_bytree': 0.5932054618357031}. Best is trial 12 with value: 0.9100078521512461.
# [I 2026-03-09 00:52:01,757] Trial 39 finished with value: 0.9090540839617388 and parameters: {'model_name': 'lightgbm', 'n_estimators': 20, 'learning_rate': 0.17850492234540358, 'max_depth': 6, 'subsample': 0.5471365134455892, 'colsample_bytree': 0.5998233377582042}. Best is trial 12 with value: 0.9100078521512461.
# [I 2026-03-09 00:52:15,166] Trial 40 finished with value: 0.9077274148193352 and parameters: {'model_name': 'xgboost', 'n_estimators': 21, 'max_depth': 9, 'learning_rate': 0.10047986399112467, 'subsample': 0.6013108649221809, 'colsample_bytree': 0.5271684377906318}. Best is trial 12 with value: 0.9100078521512461.
# [I 2026-03-09 00:52:18,890] Trial 41 finished with value: 0.9083444200331607 and parameters: {'model_name': 'xgboost', 'n_estimators': 22, 'max_depth': 9, 'learning_rate': 0.2646555072077603, 'subsample': 0.8079404306676995, 'colsample_bytree': 0.6685396361115208}. Best is trial 12 with value: 0.9100078521512461.
# [I 2026-03-09 00:52:29,022] Trial 42 finished with value: 0.9097474456940357 and parameters: {'model_name': 'lightgbm', 'n_estimators': 22, 'learning_rate': 0.11337467116141056, 'max_depth': 7, 'subsample': 0.9568582371114711, 'colsample_bytree': 0.5009855382946542}. Best is trial 12 with value: 0.9100078521512461.
# [I 2026-03-09 00:52:30,894] Trial 43 finished with value: 0.9092026184085787 and parameters: {'model_name': 'lightgbm', 'n_estimators': 16, 'learning_rate': 0.11418194961030688, 'max_depth': 7, 'subsample': 0.9599391708430371, 'colsample_bytree': 0.5034585260075003}. Best is trial 12 with value: 0.9100078521512461.
# [I 2026-03-09 00:52:42,647] Trial 44 finished with value: 0.9095603434846744 and parameters: {'model_name': 'lightgbm', 'n_estimators': 16, 'learning_rate': 0.13738878052439196, 'max_depth': 7, 'subsample': 0.963016995472069, 'colsample_bytree': 0.5556690309363806}. Best is trial 12 with value: 0.9100078521512461.
# [I 2026-03-09 00:52:44,089] Trial 45 finished with value: 0.9035844886966745 and parameters: {'model_name': 'random_forest', 'n_estimators': 24, 'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 3}. Best is trial 12 with value: 0.9100078521512461.
# [I 2026-03-09 00:52:56,371] Trial 46 finished with value: 0.9035844886966745 and parameters: {'model_name': 'random_forest', 'n_estimators': 24, 'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 3}. Best is trial 12 with value: 0.9100078521512461.
# [I 2026-03-09 00:53:16,927] Trial 47 finished with value: 0.9016333272193321 and parameters: {'model_name': 'svm', 'C': 1.5863976764300627}. Best is trial 12 with value: 0.9100078521512461.
# [I 2026-03-09 00:53:28,841] Trial 48 finished with value: 0.9016177618545907 and parameters: {'model_name': 'svm', 'C': 1.6251746242993172}. Best is trial 12 with value: 0.9100078521512461.
# [I 2026-03-09 00:53:30,409] Trial 49 finished with value: 0.9097122973971373 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.14484746875391993, 'max_depth': 6, 'subsample': 0.5153935491765058, 'colsample_bytree': 0.5668364965220246}. Best is trial 12 with value: 0.9100078521512461.
# [LightGBM] [Info] Number of positive: 35224, number of negative: 35224
# [LightGBM] [Info] Total Bins 15479
# [LightGBM] [Info] Number of data points in the train set: 70448, number of used features: 219
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000

# %% [markdown]
# #### Conferir checkpoints intermediarios

# %% [markdown]
# Consolida os resultados da validação cruzada externa em um DataFrame,
# salva o resumo em formato Parquet e carrega os logs das trials do Optuna
# para inspeção e análise do processo de otimização.

# %%
df_results=pd.DataFrame(df_results)
display(df_results)
# Out:
#    fold best_model       auc  accuracy        f1    recall  precision  \
# 0     1   lightgbm  0.906159  0.916258  0.778922  0.733755   0.830015
# 1     2   lightgbm  0.913128  0.915714  0.779701  0.741877   0.821589
# 2     3   lightgbm  0.909327  0.913446  0.773612  0.735560   0.815816
# 3     4   lightgbm  0.909399  0.912811  0.768378  0.719314   0.824625
# 4     5   lightgbm  0.909900  0.915260  0.779092  0.743231   0.818588
#
#                                      hyperparameters  \
# 0  {'model_name': 'lightgbm', 'n_estimators': 21,...
# 1  {'model_name': 'lightgbm', 'n_estimators': 19,...
# 2  {'model_name': 'lightgbm', 'n_estimators': 28,...
# 3  {'model_name': 'lightgbm', 'n_estimators': 26,...
# 4  {'model_name': 'lightgbm', 'n_estimators': 24,...
#
#                                  checkpoint_path  train_time_seconds  \
# 0  checkpoints_best_models/best_model_fold_1.pkl            4.758514
# 1  checkpoints_best_models/best_model_fold_2.pkl            4.811630
# 2  checkpoints_best_models/best_model_fold_3.pkl            5.262824
# 3  checkpoints_best_models/best_model_fold_4.pkl            5.027210
# 4  checkpoints_best_models/best_model_fold_5.pkl            5.563833
#
#                  trials_log_path
# 0  log_opt/trials_log_fold_1.csv
# 1  log_opt/trials_log_fold_2.csv
# 2  log_opt/trials_log_fold_3.csv
# 3  log_opt/trials_log_fold_4.csv
# 4  log_opt/trials_log_fold_5.csv

# %%
df_results.to_parquet('df_results.parquet')

# %% [markdown]
# Carregando o pkl

# %%
import joblib

modelo = joblib.load("checkpoints_best_models/best_model_fold_1.pkl")

# %%
modelo
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['NU_IDADE_N',
#                                                    'periodo_chuvoso',
#                                                    'vulnerabilidade_social']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='infrequent_if_...
#                                                    'CLI_OUTROS', 'CLI_PANTUR',
#                                                    'CLI_PROST', 'CON_AMBIEN',
#                                                    'CON_AREA', 'CS_ESCOL_N',
#                                                    'ID_OCUPA_N',
#                                                    'nivel_vulnerabilidade'])])),
#                 ('smote', SMOTE(random_state=42)),
#                 ('model',
#                  LGBMClassifier(colsample_bytree=0.7018463368170325,
#                                 device='cpu', force_col_wise=True,
#                                 is_unbalance=True,
#                                 learning_rate=0.16639427756743294, max_depth=9,
#                                 n_estimators=21, random_state=42,
#                                 subsample=0.5691530833047652))])

# %%
modelo.named_steps["preprocessor"].get_feature_names_out()
# Out:
# array(['num__NU_IDADE_N', 'num__periodo_chuvoso',
#        'num__vulnerabilidade_social', ...,
#        'cat__nivel_vulnerabilidade_Alta',
#        'cat__nivel_vulnerabilidade_Baixa',
#        'cat__nivel_vulnerabilidade_Moderada'], dtype=object)

# %%
modelo.predict(X_data.iloc[-10:])
# Out:
# array([1, 1, 0, 0, 1, 1, 1, 0, 1, 1])

# %% [markdown]
# ## Avaliação de desempenho e custo computacional
#
# Nesta seção são avaliados os modelos selecionados ao longo dos folds da validação cruzada externa,
# considerando simultaneamente **qualidade preditiva** e **custo computacional**.
# Essa análise conjunta é fundamental para evitar escolhas baseadas apenas em desempenho,
# desconsiderando viabilidade prática de treinamento e manutenção do modelo.
#
# ### Métricas de desempenho preditivo
#
# O desempenho dos modelos é avaliado por meio de múltiplas métricas,
# permitindo uma análise abrangente do comportamento preditivo:
#
# - **ROC-AUC (OvR, weighted)**: métrica principal de comparação, pois avalia a capacidade de separação entre classes
# em cenários multiclasse e desbalanceados, utilizando probabilidades preditas.
# - **Accuracy**: fornece uma visão global de acerto, mas pode ser influenciada por classes majoritárias.
# - **F1-score (weighted)**: equilibra precisão e recall, sendo mais informativo quando há assimetria entre classes.
# - **Recall (weighted)**: mede a capacidade do modelo em identificar corretamente instâncias relevantes,
# importante em contextos onde falsos negativos possuem maior custo.
# - **Precision (weighted)**: avalia a confiabilidade das predições positivas,
# sendo relevante quando falsos positivos impactam decisões downstream.
#
# A análise por fold permite verificar não apenas o valor médio das métricas,
# mas também sua **estabilidade**, reduzindo o risco de overfitting a uma partição específica dos dados.

# %%
def read_and_consolidate_optuna_logs(
    log_dir: str = "log_opt",
    pattern: str = "trials_log_fold_*.csv",
    fold_col_name: str = "outer_fold",
    keep_only_complete: bool = True,
) -> pd.DataFrame:
    """
    Lê todos os arquivos de log do Optuna (1 por fold) e consolida em um único DataFrame.

    Espera arquivos no formato: trials_log_fold_{k}.csv (gerados por dump_trials).

    Parâmetros
    ----------
    log_dir : str
        Diretório onde os logs estão salvos.
    pattern : str
        Padrão dos arquivos dentro do log_dir.
    fold_col_name : str
        Nome da coluna que será criada para identificar o fold externo.
    keep_only_complete : bool
        Se True, mantém apenas trials com state == 'COMPLETE' (quando existir essa coluna).

    Retorna
    -------
    pd.DataFrame
        DataFrame consolidado com colunas originais + coluna de fold.
    """
    path_pattern = os.path.join(log_dir, pattern)
    files = sorted(glob.glob(path_pattern))

    if not files:
        raise FileNotFoundError(f"Nenhum arquivo encontrado em: {path_pattern}")

    dfs = []
    for fp in files:
        df = pd.read_csv(fp)

        # Extrai fold do nome do arquivo (ex.: trials_log_fold_3.csv -> 3)
        m = re.search(r"fold_(\d+)", os.path.basename(fp))
        fold = int(m.group(1)) if m else None

        df[fold_col_name] = fold
        df["source_file"] = os.path.basename(fp)

        # Normaliza duration se estiver como string do tipo "0 days 00:00:12.345"
        if "duration" in df.columns:
            try:
                df["duration"] = pd.to_timedelta(df["duration"])
                df["duration_seconds"] = df["duration"].dt.total_seconds()
            except Exception:
                pass

        dfs.append(df)

    df_all = pd.concat(dfs, ignore_index=True)

    # Ordenação útil (se existir)
    sort_cols = [c for c in [fold_col_name, "number"] if c in df_all.columns]
    if sort_cols:
        df_all = df_all.sort_values(sort_cols).reset_index(drop=True)

    return df_all


df_metrics = read_and_consolidate_optuna_logs(log_dir="log_opt", keep_only_complete=True)

# 2. Basic overview
print("=== Shape of DataFrame ===")
print(df_metrics.shape)

display(df_metrics)
# Out:
# === Shape of DataFrame ===
# (250, 16)
#      number     value  params_C  params_colsample_bytree  \
# 0         0  0.909880       NaN                 0.549765
# 1         1  0.902022       NaN                 0.707305
# 2         2  0.907921       NaN                 0.520569
# 3         3  0.901177       NaN                      NaN
# 4         4  0.899074       NaN                      NaN
# ..      ...       ...       ...                      ...
# 245      45  0.903584       NaN                      NaN
# 246      46  0.903584       NaN                      NaN
# 247      47  0.901633  1.586398                      NaN
# 248      48  0.901618  1.625175                      NaN
# 249      49  0.909712       NaN                 0.566836
#
#      params_learning_rate  params_max_depth  params_min_samples_leaf  \
# 0                0.095248               7.0                      NaN
# 1                0.185356               6.0                      NaN
# 2                0.085168               8.0                      NaN
# 3                     NaN               7.0                      3.0
# 4                     NaN               4.0                      5.0
# ..                    ...               ...                      ...
# 245                   NaN               8.0                      3.0
# 246                   NaN               8.0                      3.0
# 247                   NaN               NaN                      NaN
# 248                   NaN               NaN                      NaN
# 249              0.144847               6.0                      NaN
#
#      params_min_samples_split params_model_name  params_n_estimators  \
# 0                         NaN          lightgbm                 23.0
# 1                         NaN           xgboost                  7.0
# 2                         NaN           xgboost                 25.0
# 3                         7.0     random_forest                 19.0
# 4                         2.0     random_forest                 27.0
# ..                        ...               ...                  ...
# 245                      10.0     random_forest                 24.0
# 246                      10.0     random_forest                 24.0
# 247                       NaN               svm                  NaN
# 248                       NaN               svm                  NaN
# 249                       NaN          lightgbm                 27.0
#
#      params_subsample     state               duration  outer_fold  \
# 0            0.813903  COMPLETE 0 days 00:00:15.132334           1
# 1            0.798499  COMPLETE 0 days 00:00:14.700765           1
# 2            0.988343  COMPLETE 0 days 00:00:18.835411           1
# 3                 NaN  COMPLETE 0 days 00:00:14.645472           1
# 4                 NaN  COMPLETE 0 days 00:00:14.729774           1
# ..                ...       ...                    ...         ...
# 245               NaN  COMPLETE 0 days 00:00:13.167370           5
# 246               NaN  COMPLETE 0 days 00:00:13.710553           5
# 247               NaN  COMPLETE 0 days 00:00:32.825957           5
# 248               NaN  COMPLETE 0 days 00:00:32.453970           5
# 249          0.515394  COMPLETE 0 days 00:00:13.469361           5
#
#                source_file  duration_seconds
# 0    trials_log_fold_1.csv         15.132334
# 1    trials_log_fold_1.csv         14.700765
# 2    trials_log_fold_1.csv         18.835411
# 3    trials_log_fold_1.csv         14.645472
# 4    trials_log_fold_1.csv         14.729774
# ..                     ...               ...
# 245  trials_log_fold_5.csv         13.167370
# 246  trials_log_fold_5.csv         13.710553
# 247  trials_log_fold_5.csv         32.825957
# 248  trials_log_fold_5.csv         32.453970
# 249  trials_log_fold_5.csv         13.469361
#
# [250 rows x 16 columns]

# %%
# Total de trials por modelo
total_trials = (df_metrics.groupby("params_model_name").size().reset_index(name="total_trials"))

plt.figure(figsize=(8, 6))
sns.barplot(data=total_trials,x="params_model_name",y="total_trials",)
plt.title("Total de tentativas por modelo")
plt.xlabel("Modelo")
plt.ylabel("Tentativas")
plt.tight_layout()
plt.show()

# %%
# Gráfico das tentativas de modelos completas e abortadas
counts_state = df_metrics.groupby(["params_model_name", "state"]).size().reset_index(name="count")

plt.figure(figsize=(8, 6))
sns.barplot(data=counts_state,x="params_model_name",y="count",hue="state",)
plt.title("Resultado das tentativas entre Pruned e Complete")
plt.xlabel("Modelo")
plt.ylabel("Número de tentativas")
plt.tight_layout()
plt.show()

# %%
# Distribuição de performance (value) por modelo
plt.figure(figsize=(8, 6))
sns.boxplot(data=df_metrics, x="params_model_name", y="value")
plt.title("Desempenho por modelo")
plt.xlabel("Modelo")
plt.ylabel("Área por baixo da curva ROC (AUC)")
plt.tight_layout()
plt.show()

# %%
# Duração média de treino por modelo
df_metrics["duration_sec"] = pd.to_timedelta(df_metrics["duration"]).dt.total_seconds()
mean_duration = df_metrics.groupby("params_model_name")["duration_sec"].mean().reset_index()

# Distribuição do tempo de processamento por modelo

plt.figure(figsize=(8, 6))
sns.boxplot(data=df_metrics, x="params_model_name", y="duration_sec")
plt.title("Média do tempo de treinamento por modelo")
plt.xlabel("Modelo")
plt.ylabel("Segundos")
plt.tight_layout()
plt.show()

# %%
tabela_resumo = (
    df_metrics
    .groupby("params_model_name")["value"]
    .agg(
        media="mean",
        desvio_padrao="std",
        mediana="median",
        minimo="min",
        maximo="max",
        n="count"
    )
    .reset_index()
    .sort_values("media", ascending=False)
)

# Opcional: arredondar para facilitar leitura
tabela_resumo = tabela_resumo.round(4)

tabela_resumo
# Out:
#   params_model_name   media  desvio_padrao  mediana  minimo  maximo    n
# 0          lightgbm  0.9088         0.0020   0.9092  0.8925  0.9108  156
# 3           xgboost  0.9052         0.0041   0.9069  0.8913  0.9091   35
# 2               svm  0.9023         0.0010   0.9021  0.9009  0.9046   28
# 1     random_forest  0.8951         0.0160   0.8985  0.8159  0.9053   31

# %%
tabela_resumo = (
    df_metrics
    .groupby("params_model_name")["duration_seconds"]
    .agg(
        media="mean",
        desvio_padrao="std",
        mediana="median",
        minimo="min",
        maximo="max",
        n="count"
    )
    .reset_index()
    .sort_values("media", ascending=False)
)

# Opcional: arredondar para facilitar leitura
tabela_resumo = tabela_resumo.round(4)

tabela_resumo
# Out:
#   params_model_name    media  desvio_padrao  mediana   minimo   maximo    n
# 2               svm  31.6693         5.1457  33.6620  21.4001  38.2181   28
# 3           xgboost  15.4452         1.9891  15.9657  10.1391  19.4867   35
# 0          lightgbm  13.9569         1.6777  13.8355   7.2198  21.9784  156
# 1     random_forest  12.9218         1.4828  13.0922   9.2032  15.3245   31

# %% [markdown]
# ## Treinamento do modelo final

# %%
df_hyper =pd.DataFrame(df_results['hyperparameters'].to_list())
df_hyper
# Out:
#   model_name  n_estimators  learning_rate  max_depth  subsample  \
# 0   lightgbm            21       0.166394          9   0.569153
# 1   lightgbm            19       0.272104          4   0.835125
# 2   lightgbm            28       0.201347          9   0.777271
# 3   lightgbm            26       0.129603          8   0.685983
# 4   lightgbm            24       0.263896          6   0.505095
#
#    colsample_bytree
# 0          0.701846
# 1          0.981649
# 2          0.725604
# 3          0.567968
# 4          0.985072

# %%
final_params=df_hyper.iloc[:,1:].median().to_dict()
final_params
# Out:
# {'n_estimators': 24.0,
#  'learning_rate': 0.20134721418273382,
#  'max_depth': 8.0,
#  'subsample': 0.6859830939927777,
#  'colsample_bytree': 0.7256038276141418}

# %%
def cast_params(params: dict) -> dict:
    p = dict(params)  # cópia

    # chaves que devem ser int no LightGBM
    int_keys = {
        "n_estimators", "num_iterations",
        "max_depth", "num_leaves",
        "min_child_samples", "min_data_in_leaf",
        "max_bin",
        "bagging_freq",
    }

    for k in list(p.keys()):
        if k in int_keys and p[k] is not None and not (isinstance(p[k], bool)):
            p[k] = int(round(float(p[k])))

    # max_depth: LightGBM aceita -1 como "sem limite"
    if "max_depth" in p and p["max_depth"] is not None:
        p["max_depth"] = int(p["max_depth"])

    return p

final_params = cast_params(final_params)
final_params
# Out:
# {'n_estimators': 24,
#  'learning_rate': 0.20134721418273382,
#  'max_depth': 8,
#  'subsample': 0.6859830939927777,
#  'colsample_bytree': 0.7256038276141418}

# %%
# Dicionário base para reconstrução
models = {
    'RandomForest': RandomForestClassifier(random_state=42),
    'XGBoost': xgb.XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42),
    'LightGBM': lgb.LGBMClassifier(random_state=42),
    'SVM': CalibratedClassifierCV(LinearSVC( random_state=42))
}

# %%
# Reconstruir modelo
final_model = models['LightGBM']
final_model.set_params(**final_params)

cat_cols, num_cols = get_feature_types(X_data)

final_pipeline = build_pipeline(final_model, cat_cols, num_cols)

# %% [markdown]
# ### Avaliando modelo final

# %% [markdown]
# ## Interpretabilidade: importância de variáveis após pré-processamento (OHE) e mapeamento para colunas originais
#
# Modelos treinados sobre pipelines com `ColumnTransformer` e `OneHotEncoder` operam em um espaço de features
# expandido (múltiplas colunas por variável categórica). Para manter interpretabilidade, esta seção:
# 1) recupera os nomes finais das features no espaço transformado,
# 2) extrai uma medida de importância/coeficiente do modelo treinado,
# 3) mapeia as features transformadas de volta para as variáveis originais,
# 4) consolida a importância no nível da coluna original.
#
# Isso permite reportar resultados em termos das variáveis do dataset original, facilitando comunicação e análise.

# %% [markdown]
# ### Extração de nomes das features pós-`ColumnTransformer`
#
# A função `get_feature_names` reconstrói o vetor de nomes de features gerado após o pré-processamento,
# incluindo:
# - variáveis numéricas (após imputação/escala),
# - variáveis categóricas expandidas via One-Hot Encoding,
# - e, opcionalmente, colunas passadas via `remainder='passthrough'`.
#
# Essa etapa é necessária porque, após o `fit_transform`, a matriz final perde o vínculo direto com o nome
# das colunas originais, e a identificação correta das features é condição para qualquer análise de importância.

# %%
# 1. FUNÇÃO PARA EXTRAIR NOMES DAS FEATURES PÓS-OHE
def get_feature_names(column_transformer):
    """
    Extrai nomes finais das features após ColumnTransformer,
    incluindo OneHotEncoder e transformações numéricas.
    """
    output_features = []

    for name, transformer, features in column_transformer.transformers_:

        # Caso 'remainder=passthrough'
        if name == "remainder":
            output_features.extend(features)
            continue

        # Transformers com get_feature_names_out() (OneHotEncoder, etc)
        if hasattr(transformer, "get_feature_names_out"):
            try:
                names = transformer.get_feature_names_out(features)
            except:
                names = transformer.get_feature_names_out()
            output_features.extend(names)

        # Caso não possua o método
        else:
            output_features.extend(features)

    return output_features

# %% [markdown]
# ### Mapeamento para variáveis originais via fuzzy matching
#
# Após o One-Hot Encoding, uma mesma variável categórica pode gerar dezenas de colunas com nomes derivados.
# Para consolidar resultados no nível da variável original, é aplicado *fuzzy matching* entre o nome da feature
# pós-OHE e a lista de variáveis originais de interesse (`features_explicativas`).
#
# O objetivo do fuzzy matching é lidar com diferenças de sufixos/prefixos criados pelo encoding e manter
# um vínculo prático entre “feature transformada” e “coluna original”. O parâmetro `threshold`
# controla o quão estrita é a correspondência:
# - valores maiores reduzem falsos positivos (match errado),
# - valores menores aumentam cobertura, mas elevam risco de mapeamentos incorretos.
#
# Após o matching, apenas features com correspondência válida são mantidas para agregação.

# %%
def fuzzy_match_original(feature_name, triage_features, threshold=70):
    """
    Realiza fuzzy matching buscando qual variável ORIGINAL
    está mais relacionada com o nome da feature pós-OHE.
    """
    best_match, score, _ = process.extractOne(
        feature_name,
        triage_features,
        scorer=fuzz.partial_ratio
    )
    return best_match if score >= threshold else None

# %% [markdown]
# ## Validação cruzada externa: avaliação e interpretabilidade por fold
#
# Nesta etapa, aplica-se uma `StratifiedKFold` externa para avaliar o desempenho do pipeline e também
# inspecionar a importância de variáveis por fold. A estratificação preserva a proporção das classes,
# reduzindo instabilidade em bases desbalanceadas.
#
# Para cada fold:
# - o pipeline final é treinado no conjunto de treino,
# - a importância das features é extraída do modelo treinado,
# - as importâncias são consolidadas no nível da variável original e visualizadas,
# - e o desempenho é medido no conjunto de teste com métricas e curvas.

# %%
# =========================
# Parâmetros
# =========================
n_splits = 4
top_k = 20        # top features por fold (para tabelas)
top_overall = 30  # top features gerais (para tabela final)

outer_cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

# =========================
# Coletores (tabelas)
# =========================
fold_metrics = []          # 1 linha por fold com métricas + conf matrix flatten
fold_top_features = []     # top_k features por fold (já agrupadas em original_var)
all_features_long = []     # todas features (agrupadas) por fold -> resumo geral

fold = 1
for train_idx, test_idx in outer_cv.split(X_data, y_data):

    print(f"\n==============================")
    print(f"  Fold Externo {fold}/{n_splits}")
    print(f"==============================")

    X_train, X_test = X_data.iloc[train_idx], X_data.iloc[test_idx]
    y_train, y_test = y_data.iloc[train_idx], y_data.iloc[test_idx]

    # =========================
    # 1) Fit do pipeline no fold
    # =========================
    final_pipeline.fit(X_train, y_train)

    # =========================
    # 2) Importâncias
    # =========================
    model = final_pipeline.named_steps["model"]

    if hasattr(model, "feature_importances_"):
        importances = model.feature_importances_
    elif hasattr(model, "coef_"):
        coef = model.coef_
        # binary: (n_features,) ou (1, n_features)
        # multiclass: (n_classes, n_features) -> agregamos por média do abs
        importances = coef.ravel() if coef.ndim == 1 else np.mean(np.abs(coef), axis=0)
    else:
        raise ValueError("Este modelo não possui atributo de importância (feature_importances_ ou coef_).")

    # =========================
    # 3) Nomes pós-preprocessamento
    # =========================
    preproc = final_pipeline.named_steps["preprocessor"]
    feature_names = get_feature_names(preproc)

    if len(feature_names) != len(importances):
        raise ValueError(
            f"Mismatch: {len(feature_names)} nomes de features vs {len(importances)} importâncias. "
            "Cheque get_feature_names() / preprocessor."
        )

    df_imp = pd.DataFrame({"feature": feature_names, "importance": importances})

    # =========================
    # 4) Fuzzy match para variáveis originais e agregação
    # =========================
    df_imp["original_var"] = df_imp["feature"].apply(lambda x: fuzzy_match_original(x, triage_features))
    df_imp = df_imp[df_imp["original_var"].notna()].copy()

    df_grouped = (
        df_imp.groupby("original_var", as_index=False)["importance"]
              .sum()
              .sort_values("importance", ascending=False)
              .rename(columns={"original_var": "feature"})
              .reset_index(drop=True)
    )

    # =========================
    # 4.1) Plot: Feature importance (por fold)
    # =========================
    plt.figure(figsize=(6, 14))
    plt.barh(df_grouped["feature"][::-1], df_grouped["importance"][::-1])
    plt.xlabel("Importância (agregada por variável original)")
    plt.title(f"Feature importance – {type(model).__name__} – Fold {fold}")
    plt.tight_layout()
    plt.show()

    # guarda top features do fold (top_k)
    df_top = df_grouped.head(top_k).copy()
    df_top["fold"] = fold
    df_top["rank_in_fold"] = np.arange(1, len(df_top) + 1)
    fold_top_features.append(df_top)

    # guarda TODAS as features agregadas do fold (para resumo geral)
    df_grouped_long = df_grouped.copy()
    df_grouped_long["fold"] = fold
    all_features_long.append(df_grouped_long)

    # =========================
    # 5) Predições / probabilidades
    # =========================
    y_pred = final_pipeline.predict(X_test)

    y_proba = None
    if hasattr(final_pipeline, "predict_proba"):
        try:
            y_proba = final_pipeline.predict_proba(X_test)[:, 1]
        except Exception:
            y_proba = None

    # =========================
    # 6) Matriz de confusão (plot)
    # =========================
    cm = confusion_matrix(y_test, y_pred)

    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.title(f"Matriz de Confusão – Fold {fold}")
    plt.xlabel("Predito")
    plt.ylabel("Real")
    plt.tight_layout()
    plt.show()

    # =========================
    # 7) Métricas (plot + tabela)
    # =========================
    metrics_dict_plot = {
        "Accuracy": accuracy_score(y_test, y_pred),
        "Precision": precision_score(y_test, y_pred, zero_division=0),
        "Recall": recall_score(y_test, y_pred, zero_division=0),
        "F1 Score": f1_score(y_test, y_pred, zero_division=0),
        "AUC": roc_auc_score(y_test, y_proba) if y_proba is not None else np.nan
    }

    plt.figure(figsize=(8, 5))
    sns.barplot(x=list(metrics_dict_plot.keys()), y=list(metrics_dict_plot.values()), palette="Set2")
    plt.ylim(0, 1.05)
    plt.title(f"Métricas de Classificação – Fold {fold}")
    for i, v in enumerate(metrics_dict_plot.values()):
        if np.isfinite(v):
            plt.text(i, v + 0.02, f"{v:.2f}", ha='center')
        else:
            plt.text(i, 0.02, "NA", ha='center')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    # salva métricas estruturadas (para df_metrics)
    fold_metrics.append({
        "fold": fold,
        "n_train": len(train_idx),
        "n_test": len(test_idx),
        "accuracy": metrics_dict_plot["Accuracy"],
        "precision": metrics_dict_plot["Precision"],
        "recall": metrics_dict_plot["Recall"],
        "f1": metrics_dict_plot["F1 Score"],
        "auc": metrics_dict_plot["AUC"],
        "tn": cm[0, 0], "fp": cm[0, 1], "fn": cm[1, 0], "tp": cm[1, 1],
        "model_name": type(model).__name__,
    })

    # =========================
    # 8) Curva ROC (plot)
    # =========================
    if y_proba is not None:
        fpr, tpr, _ = roc_curve(y_test, y_proba)
        roc_auc = auc(fpr, tpr)

        plt.figure(figsize=(6, 5))
        plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.2f}")
        plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
        plt.xlabel("Falso Positivo")
        plt.ylabel("Verdadeiro Positivo")
        plt.title(f"Curva ROC – Fold {fold}")
        plt.legend(loc='lower right')
        plt.grid(True)
        plt.tight_layout()
        plt.show()

    # =========================
    # 9) Curva Precision-Recall (plot)
    # =========================
    if y_proba is not None:
        precision, recall, _ = precision_recall_curve(y_test, y_proba)
        auprc_trap = auc(recall, precision)

        plt.figure(figsize=(6, 5))
        plt.plot(recall, precision, label=f"AUPRC = {auprc_trap:.2f}")
        plt.xlabel("Recall")
        plt.ylabel("Precision")
        plt.title(f"Curva Precision-Recall – Fold {fold}")
        plt.legend(loc='lower right')
        plt.grid(True)
        plt.tight_layout()
        plt.show()


    # =========================
    # 10) Curva Calibração (plot)
    # =========================
    if y_proba is not None:
        prob_true, prob_pred = calibration_curve(y_test, y_proba, n_bins=10, strategy='uniform')

        plt.figure(figsize=(6,6))
        plt.plot(prob_pred, prob_true, marker='o', linewidth=2, label='Modelo calibrado')
        plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Calibração perfeita')
        plt.title("Curva de Calibração (Isotonic Regression)")
        plt.xlabel("Probabilidade prevista (modelo)")
        plt.ylabel("Frequência real observada")
        plt.legend()
        plt.grid(True, linestyle='--', alpha=0.6)
        plt.show()


    # =========================
    # 11) Análise de FP/FN X Thresholds
    # =========================

    if y_proba is not None:
        thresholds = np.linspace(0, 1, 101)
        fp_list, fn_list = [], []

        for t in thresholds:
            y_pred = (y_proba >= t).astype(int)
            tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
            fp_list.append(fp)
            fn_list.append(fn)

        df_threshold = pd.DataFrame({
            'threshold': thresholds,
            'false_positives': fp_list,
            'false_negatives': fn_list
        })

        plt.figure(figsize=(8,5))
        plt.plot(df_threshold['threshold'], df_threshold['false_positives'], label='Falsos Positivos (FP)', color='tab:red')
        plt.plot(df_threshold['threshold'], df_threshold['false_negatives'], label='Falsos Negativos (FN)', color='tab:blue')
        plt.xlabel('Threshold (Probabilidade de Corte)')
        plt.ylabel('Quantidade de Casos')
        plt.title('Variação de FP e FN conforme o Threshold de Decisão')
        plt.legend()
        plt.grid(True, linestyle='--', alpha=0.6)
        plt.show()


    fold += 1


# =========================
#  DF: métricas por fold
# =========================
df_metrics = pd.DataFrame(fold_metrics).sort_values("fold").reset_index(drop=True)

# resumo (média e desvio padrão) das métricas
metric_cols = ["accuracy", "precision", "recall", "f1", "auc"]
df_metrics_summary = (
    df_metrics[metric_cols]
    .agg(["mean", "std"])
    .T
    .rename(columns={"mean": "mean", "std": "std"})
    .reset_index()
    .rename(columns={"index": "metric"})
)

# =========================
# DF: top features por fold
# =========================
df_top_by_fold = pd.concat(fold_top_features, ignore_index=True)

# =========================
# DF: resumo geral das features (média/std + rank)
# =========================
df_all_features_long = pd.concat(all_features_long, ignore_index=True)

df_feature_summary = (
    df_all_features_long
    .groupby("feature", as_index=False)
    .agg(
        mean_importance=("importance", "mean"),
        std_importance=("importance", "std"),
        folds_present=("fold", "nunique"),
    )
)

# ranking médio por fold (quanto menor, mais importante)
df_ranks = (
    df_all_features_long
    .assign(rank_in_fold=lambda d: d.groupby("fold")["importance"].rank(ascending=False, method="average"))
)

df_rank_summary = (
    df_ranks.groupby("feature", as_index=False)
            .agg(mean_rank=("rank_in_fold", "mean"), std_rank=("rank_in_fold", "std"))
)

df_feature_summary = (
    df_feature_summary.merge(df_rank_summary, on="feature", how="left")
                      .sort_values(["mean_importance", "folds_present"], ascending=[False, False])
                      .reset_index(drop=True)
)

df_top_features_overall = df_feature_summary.head(top_overall).copy()

# =========================
# OUTPUT final (tabelas)
# =========================
print("\n\n==============================")
print("MÉTRICAS POR FOLD")
print("==============================")
display(df_metrics)

print("\n\n==============================")
print("RESUMO GERAL DAS MÉTRICAS (média e desvio padrão)")
print("==============================")
display(df_metrics_summary)

print("\n\n==============================")
print(f"TOP {top_k} FEATURES POR FOLD (agregadas em variável original)")
print("==============================")
display(df_top_by_fold.sort_values(["fold", "rank_in_fold"]))

print("\n\n==============================")
print(f"TOP {top_overall} FEATURES GERAIS (média/std das importâncias + estabilidade via rank)")
print("==============================")
display(df_top_features_overall)

# Se quiser salvar:
# df_metrics.to_csv("cv_metrics_by_fold.csv", index=False)
# df_metrics_summary.to_csv("cv_metrics_summary.csv", index=False)
# df_top_by_fold.to_csv("cv_top_features_by_fold.csv", index=False)
# df_feature_summary.to_csv("cv_feature_importance_summary.csv", index=False)
# Out:
# ==============================
#   Fold Externo 1/4
# ==============================
# [LightGBM] [Info] Number of positive: 33022, number of negative: 33022
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.198270 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 15322
# [LightGBM] [Info] Number of data points in the train set: 66044, number of used features: 222
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# ==============================
#   Fold Externo 2/4
# ==============================
# [LightGBM] [Info] Number of positive: 33022, number of negative: 33022
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.204248 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 15222
# [LightGBM] [Info] Number of data points in the train set: 66044, number of used features: 210
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# ==============================
#   Fold Externo 3/4
# ==============================
# [LightGBM] [Info] Number of positive: 33023, number of negative: 33023
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.418882 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 15253
# [LightGBM] [Info] Number of data points in the train set: 66046, number of used features: 217
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# ==============================
#   Fold Externo 4/4
# ==============================
# [LightGBM] [Info] Number of positive: 33023, number of negative: 33023
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.087481 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 15199
# [LightGBM] [Info] Number of data points in the train set: 66046, number of used features: 215
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# ==============================
# MÉTRICAS POR FOLD
# ==============================
#    fold  n_train  n_test  accuracy  precision    recall        f1       auc  \
# 0     1    41332   13778  0.914647   0.827714  0.726715  0.773933  0.904792
# 1     2    41332   13778  0.915880   0.820278  0.744765  0.780700  0.915610
# 2     3    41333   13777  0.913261   0.815631  0.734657  0.773029  0.910371
# 3     4    41333   13777  0.911374   0.809182  0.731769  0.768531  0.908903
#
#       tn   fp   fn    tp      model_name
# 0  10589  419  757  2013  LGBMClassifier
# 1  10556  452  707  2063  LGBMClassifier
# 2  10547  460  735  2035  LGBMClassifier
# 3  10529  478  743  2027  LGBMClassifier
# ==============================
# RESUMO GERAL DAS MÉTRICAS (média e desvio padrão)
# ==============================
#       metric      mean       std
# 0   accuracy  0.913791  0.001934
# 1  precision  0.818201  0.007805
# 2     recall  0.734477  0.007604
# 3         f1  0.774048  0.005025
# 4        auc  0.909919  0.004469
# ==============================
# TOP 20 FEATURES POR FOLD (agregadas em variável original)
# ==============================
#                    feature  importance  fold  rank_in_fold
# 0               ID_OCUPA_N         185     1             1
# 1               CS_ESCOL_N         104     1             2
# 2               NU_IDADE_N          71     1             3
# 3               ANT_CB_LAM          68     1             4
# 4               CON_AMBIEN          58     1             5
# 5               CLI_ICTERI          53     1             6
# 6               CLI_PANTUR          51     1             7
# 7                 CON_AREA          48     1             8
# 8               CLI_OUTROS          29     1             9
# 9                CLI_PROST          26     1            10
# 10   nivel_vulnerabilidade          11     1            11
# 11         periodo_chuvoso           9     1            12
# 12  vulnerabilidade_social           7     1            13
# 13              ID_OCUPA_N         189     2             1
# 14              CS_ESCOL_N          99     2             2
# 15              ANT_CB_LAM          68     2             3
# 16              CLI_ICTERI          67     2             4
# 17              CON_AMBIEN          62     2             5
# 18              CLI_PANTUR          54     2             6
# 19              NU_IDADE_N          54     2             7
# 20                CON_AREA          48     2             8
# 21              CLI_OUTROS          35     2             9
# 22               CLI_PROST          24     2            10
# 23  vulnerabilidade_social           9     2            11
# 24   nivel_vulnerabilidade           6     2            12
# 25         periodo_chuvoso           5     2            13
# 26              ID_OCUPA_N         192     3             1
# 27              CS_ESCOL_N         120     3             2
# 28              CLI_ICTERI          68     3             3
# 29              ANT_CB_LAM          67     3             4
# 30              NU_IDADE_N          61     3             5
# 31              CON_AMBIEN          51     3             6
# 32                CON_AREA          48     3             7
# 33              CLI_PANTUR          40     3             8
# 34              CLI_OUTROS          30     3             9
# 35               CLI_PROST          18     3            10
# 36  vulnerabilidade_social          12     3            11
# 37         periodo_chuvoso          10     3            12
# 38   nivel_vulnerabilidade           3     3            13
# 39              ID_OCUPA_N         185     4             1
# 40              CS_ESCOL_N          92     4             2
# 41              NU_IDADE_N          79     4             3
# 42              CLI_ICTERI          67     4             4
# 43              ANT_CB_LAM          63     4             5
# 44              CLI_PANTUR          63     4             6
# 45              CON_AMBIEN          61     4             7
# 46                CON_AREA          40     4             8
# 47               CLI_PROST          24     4             9
# 48              CLI_OUTROS          18     4            10
# 49  vulnerabilidade_social          13     4            11
# 50   nivel_vulnerabilidade           9     4            12
# 51         periodo_chuvoso           6     4            13
# ==============================
# TOP 30 FEATURES GERAIS (média/std das importâncias + estabilidade via rank)
# ==============================
#                    feature  mean_importance  std_importance  folds_present  \
# 0               ID_OCUPA_N           187.75        3.403430              4
# 1               CS_ESCOL_N           103.75       11.898879              4
# 2               ANT_CB_LAM            66.50        2.380476              4
# 3               NU_IDADE_N            66.25       10.996211              4
# 4               CLI_ICTERI            63.75        7.182154              4
# 5               CON_AMBIEN            58.00        4.966555              4
# 6               CLI_PANTUR            52.00        9.486833              4
# 7                 CON_AREA            46.00        4.000000              4
# 8               CLI_OUTROS            28.00        7.164728              4
# 9                CLI_PROST            23.00        3.464102              4
# 10  vulnerabilidade_social            10.25        2.753785              4
# 11         periodo_chuvoso             7.50        2.380476              4
# 12   nivel_vulnerabilidade             7.25        3.500000              4
#
#     mean_rank  std_rank
# 0       1.000  0.000000
# 1       2.000  0.000000
# 2       4.125  1.030776
# 3       4.375  1.701715
# 4       4.250  1.258306
# 5       5.750  0.957427
# 6       6.750  1.040833
# 7       7.750  0.500000
# 8       9.250  0.500000
# 9       9.750  0.500000
# 10     11.500  1.000000
# 11     12.500  0.577350
# 12     12.000  0.816497

# %% [markdown]
# ### Salvando checkpoints do colab no drive

# %% [markdown]
# Salvar metricas

# %%
src = "/content/checkpoints_best_models"
dst = f"/content/drive/MyDrive/ITA/TCC/Resultados/{experimento}/checkpoints_best_models"

os.makedirs(os.path.dirname(dst), exist_ok=True)
shutil.copytree(src, dst, dirs_exist_ok=True)

# %% [markdown]
# Salvar modelos

# %%
src = "/content/log_opt"
dst = f"/content/drive/MyDrive/ITA/TCC/Resultados/{experimento}/log_opt"

os.makedirs(os.path.dirname(dst), exist_ok=True)
shutil.copytree(src, dst, dirs_exist_ok=True)
