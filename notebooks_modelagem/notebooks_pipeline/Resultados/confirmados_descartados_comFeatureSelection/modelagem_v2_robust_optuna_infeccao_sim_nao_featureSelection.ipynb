# %%
# !pip uninstall xgboost -y
# Out:
# Found existing installation: xgboost 3.1.1
# Uninstalling xgboost-3.1.1:
#   Successfully uninstalled xgboost-3.1.1

# %%
# !pip install optuna xgboost==3.1.1 lightgbm fastparquet imbalanced-learn torch rapidfuzz
# Out:
# Requirement already satisfied: optuna in /usr/local/lib/python3.12/dist-packages (4.7.0)
# Collecting xgboost==3.1.1
#   Using cached xgboost-3.1.1-py3-none-manylinux_2_28_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.12/dist-packages (4.6.0)
# Requirement already satisfied: fastparquet in /usr/local/lib/python3.12/dist-packages (2025.12.0)
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.12/dist-packages (0.14.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.9.0+cpu)
# Requirement already satisfied: rapidfuzz in /usr/local/lib/python3.12/dist-packages (3.14.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from xgboost==3.1.1) (2.0.2)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.12/dist-packages (from xgboost==3.1.1) (2.29.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from xgboost==3.1.1) (1.16.3)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.18.3)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.12/dist-packages (from optuna) (6.10.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (26.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.46)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.2)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: pandas>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from fastparquet) (2.2.2)
# Requirement already satisfied: cramjam>=2.3 in /usr/local/lib/python3.12/dist-packages (from fastparquet) (2.11.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from fastparquet) (2025.3.0)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (1.6.1)
# Requirement already satisfied: sklearn-compat<0.2,>=0.1.5 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (0.1.5)
# Requirement already satisfied: joblib<2,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->fastparquet) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->fastparquet) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->fastparquet) (2025.3)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->fastparquet) (1.17.0)
# Using cached xgboost-3.1.1-py3-none-manylinux_2_28_x86_64.whl (115.9 MB)
# Installing collected packages: xgboost
# Successfully installed xgboost-3.1.1

# %%
import numpy as np
import pandas as pd
import os, joblib,time
from functools import partial

from sklearn.model_selection import StratifiedKFold, cross_val_score,train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.calibration import CalibratedClassifierCV

import optuna
from optuna.pruners import SuccessiveHalvingPruner
from optuna.exceptions import TrialPruned

#from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.impute import SimpleImputer
from functools import partial


#Feature selection
from __future__ import annotations

from sklearn.model_selection import KFold, StratifiedKFold, cross_val_score
from sklearn.feature_selection import VarianceThreshold, SelectKBest
from sklearn.feature_selection import mutual_info_classif, mutual_info_regression
from sklearn.feature_selection import f_classif, f_regression

from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.multiclass import OneVsRestClassifier, OneVsOneClassifier

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler

from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, confusion_matrix, matthews_corrcoef,
    cohen_kappa_score, balanced_accuracy_score,
    classification_report, brier_score_loss, log_loss,
    confusion_matrix, ConfusionMatrixDisplay,
    precision_recall_curve, RocCurveDisplay,roc_curve,auc
)
from optuna.pruners import HyperbandPruner, MedianPruner
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE

import matplotlib.pyplot as plt
import seaborn as sns

import subprocess
import xgboost as xgb
import lightgbm as lgb
import torch

import re
from rapidfuzz import fuzz, process

import os
import re
import glob
import pandas as pd

import shutil
import os
from google.colab import drive


import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Configurando salvamento de checkpoints no Drive
#
# Montando o drive e acessando a conta para poder conseguir salvar os checkpoints ao final do processamento

# %%
drive.mount('/content/drive')
experimento = 'confirmados_descartados_comFeatureSelection'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Carregando base de dados

# %% [markdown]
# Carregamento do conjunto de dados processado a partir de um arquivo no formato Parquet.
# Esse formato colunar é otimizado para leitura eficiente, reduz uso de memória e preserva os tipos de dados,
# sendo adequado para pipelines analíticos e etapas posteriores de modelagem.

# %%
df =pd.read_parquet('df_hepat_processed_v1.parquet',engine='fastparquet')

# %% [markdown]
# ### Selecionar variáveis relevantes para triagem

# %% [markdown]
# Definição das variáveis explicativas e da variável alvo utilizadas no modelo.
# As features incluem características sociodemográficas, condições ambientais, antecedentes clínicos e sintomas,
# além de variáveis derivadas de vulnerabilidade social e sazonalidade, enquanto a variável alvo representa a severidade do caso.

# %%
triage_features = [
    'NU_IDADE_N','CS_SEXO','CS_GESTANT','CS_RACA','CS_ESCOL_N',
    'ID_OCUPA_N','CON_AREA','CON_AMBIEN',
    'ANT_CB_LAM','ANT_CB_CRI','ANT_CB_SIN','ANT_CB_COR','ANT_CB_ROE',
    'ANT_CB_TER','ANT_CB_LIX','ANT_CB_OUT','ANT_ANIMAI','ANT_HUMANO',
    'CLI_FEBRE','CLI_MIALGI','CLI_CEFALE','CLI_PROST','CLI_CONGES',
    'CLI_PANTUR','CLI_VOMITO','CLI_DIARRE','CLI_ICTERI','CLI_RENAL',
    'CLI_RESPIR','CLI_CARDIA','CLI_HEMOPU','CLI_HEMORR','CLI_MENING',
    'CLI_OUTROS','SG_UF', 'baixa_escolaridade','raca_vulneravel','faixa_vulneravel',
    'vulnerabilidade_social', 'nivel_vulnerabilidade','mes_sintomas','estacao', 'periodo_chuvoso'
]



target_col = 'CLASSI_FIN'  # rótulo: confirmado vs descartado

if target_col == 'CLASSI_FIN':
    df = df[df['CLASSI_FIN'].isin(['Confirmado', 'Descartado'])].copy()

    # Criar variável alvo binária
    df['alvo'] = df['CLASSI_FIN'].map({
        'Confirmado': 1,
        'Descartado': 0
    })

# %% [markdown]
# ### Amostragem estratificada dos dados
#
# Nesta etapa é realizada uma amostragem estratificada da base de dados,
# preservando a proporção das classes da variável alvo.
# O procedimento consiste em aplicar uma amostragem aleatória dentro de cada classe,
# extraindo uma fração representativa do conjunto original.
#
# Em seguida, a base amostrada é separada em variáveis explicativas (X)
# e variável resposta (y), que serão utilizadas nas etapas subsequentes de modelagem.
#
# Essa abordagem reduz o volume de dados processados,
# mantendo a representatividade estatística das classes e garantindo reprodutibilidade
# por meio do uso de uma semente aleatória fixa.

# %%
## Amostragem estratificada
amostragem = df.groupby("alvo").sample(frac=0.35, random_state=42).copy()

X_data=amostragem[triage_features]
y_data = amostragem['alvo']

# %%
X_data.shape
# Out:
# (55110, 43)

# %% [markdown]
# ## Pipeline de seleção de variáveis com suporte a tarefas (binária, multiclasse e regressão)
#
# Esta seção implementa um pipeline completo de *feature selection* que funciona para problemas de
# classificação (binária e multiclasse) e regressão. O fluxo combina pré-processamento (numérico e categórico),
# múltiplos métodos de seleção em camadas (filter → embedded → wrapper) e, ao final, reconcilia as variáveis
# selecionadas no espaço transformado com seus nomes originais no dataset.
#
# A motivação é obter um conjunto final de variáveis com bom poder preditivo e maior estabilidade,
# evitando depender de um único critério (ex.: apenas mutual information ou apenas importância de árvore),
# e garantindo rastreabilidade entre “features após encoding” e “colunas originais”.
#
# ### Detecção automática do tipo de tarefa e escolha de validação cruzada
#
# Antes da seleção, o pipeline identifica se o problema é de classificação ou regressão a partir do parâmetro `task`.
# Com isso, define automaticamente o esquema de validação cruzada:
# - **StratifiedKFold** para classificação, preservando a proporção de classes em cada fold;
# - **KFold** para regressão, adequado quando não há estratificação por rótulo.
#
# Além disso, é definido um *scoring* padrão coerente com cada cenário (ex.: AUC-ROC para binário,
# F1-macro para multiclasse, e RMSE negativo para regressão), reduzindo risco de escolhas inconsistentes
# na avaliação do wrapper.

# %%
# -------------------------
# Helpers: task detection
# -------------------------
def _is_classification(task: str) -> bool:
    return task.lower() in ["binary", "multiclass", "classification", "clf"]

def _is_multiclass(task: str) -> bool:
    return task.lower() == "multiclass"

def _make_cv(y, task: str, n_splits: int = 5, random_state: int = 42):
    if _is_classification(task):
        return StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=random_state)
    return KFold(n_splits=n_splits, shuffle=True, random_state=random_state)

def _default_scoring(task: str) -> str:
    t = task.lower()
    if t == "binary":
        return "roc_auc"
    if t == "multiclass":
        return "f1_macro"
    if t in ["regression", "reg"]:
        return "neg_root_mean_squared_error"
    # fallback
    return "f1_macro" if _is_classification(task) else "neg_root_mean_squared_error"

def _selectkbest_score_func(task: str):
    return mutual_info_classif if _is_classification(task) else mutual_info_regression

def _anova_score_func(task: str):
    return f_classif if _is_classification(task) else f_regression

# %% [markdown]
# ### Identificação e pré-processamento de variáveis numéricas e categóricas
#
# Nesta etapa, as colunas são separadas por tipo:
# - categóricas (object/category/bool),
# - numéricas (np.number).
#
# Em seguida, aplica-se um pré-processamento unificado via `ColumnTransformer`:
# - **StandardScaler** para variáveis numéricas (normalização para modelos lineares e métricas);
# - **OneHotEncoder** para variáveis categóricas, com `handle_unknown="ignore"` para robustez.
#
# O resultado é uma matriz de features totalmente numérica, adequada para métodos de seleção e modelos do scikit-learn.

# %%
# ------------------------------------------------
# Preprocess: detect column types (customize here)
# ------------------------------------------------
def get_feature_types(X: pd.DataFrame):
    cat_cols = X.select_dtypes(include=["object", "category", "bool"]).columns.tolist()
    num_cols = X.select_dtypes(include=[np.number]).columns.tolist()
    return cat_cols, num_cols


# -------------------------------------------------------
# Mapping transformed -> original (robust for '_' in names)
# -------------------------------------------------------
def map_transformed_to_original_robust(feature_names_after_preproc, cat_cols):
    cat_cols_sorted = sorted(cat_cols, key=len, reverse=True)  # longest first
    orig = []

    for fn in feature_names_after_preproc:
        if "__" in fn:
            block, rest = fn.split("__", 1)
        else:
            block, rest = "remainder", fn

        if block == "cat":
            matched = None
            for c in cat_cols_sorted:
                if rest == c or rest.startswith(c + "_"):
                    matched = c
                    break
            orig.append(matched if matched is not None else rest.split("_", 1)[0])
        else:
            orig.append(rest)

    return np.array(orig)

# %% [markdown]
# ### Seleção wrapper com validação cruzada (desempenho real por feature)
#
# Como etapa final, aplica-se um *wrapper* que avalia cada variável individualmente usando validação cruzada.
# Ou seja, cada feature é testada em um modelo preditivo simples (Linear/Logistic),
# e é medido o desempenho médio (scoring) ao longo dos folds.
#
# A lógica do wrapper é aproximar o critério de seleção do objetivo final do projeto: desempenho preditivo,
# reduzindo o risco de selecionar variáveis “estatisticamente relevantes” mas com baixo ganho prático no modelo.
#
# O ranking final (`variaveis_finais`) corresponde às `final_wrapper` variáveis com melhor performance no wrapper.

# %%
def _make_wrapper_model(task: str, multiclass_strategy: str = "multinomial", random_state: int = 42):
    """
    multiclass_strategy:
      - "multinomial": LogisticRegression(multi_class="multinomial")
      - "ovr": OneVsRestClassifier(LogisticRegression(...))
      - "ovo": OneVsOneClassifier(LogisticRegression(...))
    """
    t = task.lower()
    m = multiclass_strategy.lower()

    if _is_classification(t):
        base_lr = LogisticRegression(
            max_iter=4000,
            solver="lbfgs",
            n_jobs=None,  # lbfgs ignores n_jobs
        )

        if t == "multiclass":
            if m == "multinomial":
                return LogisticRegression(max_iter=4000, solver="lbfgs", multi_class="multinomial")
            if m == "ovr":
                return OneVsRestClassifier(base_lr)
            if m == "ovo":
                return OneVsOneClassifier(base_lr)
            raise ValueError("multiclass_strategy must be one of: 'multinomial', 'ovr', 'ovo'")

        # binary
        return LogisticRegression(max_iter=4000, solver="lbfgs")

    # regression
    return LinearRegression()

# %% [markdown]
# ### Estratégias para classificação multiclasse: multinomial, OvR e OvO
#
# Para problemas multiclasse, o pipeline permite três estratégias:
# - **multinomial**: regressão logística multiclasse nativa (softmax),
# - **OvR (One-vs-Rest)**: treina um classificador por classe contra o resto,
# - **OvO (One-vs-One)**: treina classificadores para cada par de classes.
#
# A estratégia pode influenciar a avaliação do wrapper (principalmente com F1-macro),
# pois altera como o modelo aprende fronteiras de decisão e lida com classes minoritárias.
#
# ## Pipeline
#
# O pipeline retorna:
# - a matriz processada (`X_processado_df`) e nomes de features após pré-processamento,
# - rankings por método (Mutual Information, ANOVA/F-regression, Random Forest e Wrapper),
# - lista final de variáveis selecionadas no espaço transformado,
# - lista consolidada de variáveis no espaço original (para interpretação),
# - ranking agregado no nível da feature original (melhor score do wrapper entre suas dummies).
#
# Com isso, é possível:
# - justificar tecnicamente a seleção,
# - reproduzir resultados,
# - e comunicar as variáveis relevantes com interpretabilidade.

# %%
def pipeline_selecao_variaveis(
    X: pd.DataFrame,
    y: pd.Series,
    task: str = "binary",              # "binary", "multiclass", "regression"
    var_threshold: float = 0.0,
    k_mi: int = 80,
    k_anova: int = 80,
    top_rf: int = 50,
    final_wrapper: int = 20,
    scoring_wrapper: str | None = None,
    n_splits: int = 5,
    random_state: int = 42,
    multiclass_strategy: str = "multinomial",  # "multinomial", "ovr", "ovo"
):
    # 1) baixa variância
    selector_var = VarianceThreshold(threshold=var_threshold)
    selector_var.fit(X)
    cols_var = X.columns[selector_var.get_support()]
    X1 = X[cols_var]

    # 2) mutual info (rank)
    score_func_mi = _selectkbest_score_func(task)
    if score_func_mi is mutual_info_classif:
        selector_mi = SelectKBest(
            score_func=lambda X_, y_: mutual_info_classif(X_, y_, random_state=random_state),
            k=min(k_mi, X1.shape[1])
        )
    else:
        selector_mi = SelectKBest(score_func=mutual_info_regression, k=min(k_mi, X1.shape[1]))

    selector_mi.fit(X1, y)
    cols_mi = X1.columns[selector_mi.get_support()]
    scores_mi = selector_mi.scores_[selector_mi.get_support()]

    mi_rank = (pd.DataFrame({"variavel": cols_mi, "score_mutual_info": scores_mi})
               .sort_values("score_mutual_info", ascending=False))

    # 3) anova / f-regression (rank)
    score_func_anova = _anova_score_func(task)
    selector_anova = SelectKBest(score_func=score_func_anova, k=min(k_anova, X1.shape[1]))
    selector_anova.fit(X1, y)

    cols_anova = X1.columns[selector_anova.get_support()]
    scores_anova = selector_anova.scores_[selector_anova.get_support()]

    col_score = "score_anova_f" if _is_classification(task) else "score_f_regression"
    anova_rank = (pd.DataFrame({"variavel": cols_anova, col_score: scores_anova})
                  .sort_values(col_score, ascending=False))

    # candidatos (ordem: MI depois ANOVA; sem duplicar)
    candidatos = list(dict.fromkeys(mi_rank["variavel"].tolist() + anova_rank["variavel"].tolist()))
    Xcand = X1[candidatos] if len(candidatos) else X1.copy()

    # 4) RF importance (rank)
    if _is_classification(task):
        rf = RandomForestClassifier(
            n_estimators=400,
            random_state=random_state,
            n_jobs=-1
        )
    else:
        rf = RandomForestRegressor(
            n_estimators=400,
            random_state=random_state,
            n_jobs=-1
        )

    rf.fit(Xcand, y)

    rf_rank = (pd.DataFrame({"variavel": Xcand.columns, "importancia": rf.feature_importances_})
               .sort_values("importancia", ascending=False))

    vars_rf = rf_rank.head(min(top_rf, rf_rank.shape[0]))["variavel"].tolist()

    # 5) wrapper CV (rank) — mede desempenho real por feature (univariado)
    if scoring_wrapper is None:
        scoring_wrapper = _default_scoring(task)

    cv = _make_cv(y, task, n_splits=n_splits, random_state=random_state)
    model = _make_wrapper_model(task, multiclass_strategy=multiclass_strategy, random_state=random_state)

    resultados = []
    for var in vars_rf:
        score = cross_val_score(model, X1[[var]], y, cv=cv, scoring=scoring_wrapper).mean()
        resultados.append((var, score))

    wrap_rank = (pd.DataFrame(resultados, columns=["variavel", scoring_wrapper])
                 .sort_values(scoring_wrapper, ascending=False)
                 .head(min(final_wrapper, len(resultados))))

    return {
        "X_filtrado": X1,
        "ranking_mutual_info": mi_rank,
        "ranking_anova_ou_freg": anova_rank,
        "ranking_rf": rf_rank,
        "ranking_wrapper": wrap_rank,
        "variaveis_finais": wrap_rank["variavel"].tolist(),
        "scoring_wrapper": scoring_wrapper,
    }

# %% [markdown]
# ### Selecionando as variáveis automaticamente
#
# Esta função orquestra um pipeline completo de preparação e seleção de variáveis a partir de um `DataFrame` original,
# suportando tarefas de **classificação (binária/multiclasse)** e **regressão**.
#
# O fluxo é composto por três blocos principais:
#
# 1) **Detecção de tipos de variáveis**
# As colunas de entrada são separadas em **categóricas** e **numéricas** (via `get_feature_types_fn`),
# permitindo aplicar transformações apropriadas a cada tipo.
#
# 2) **Pré-processamento com `ColumnTransformer`**
# - Variáveis numéricas são padronizadas com `StandardScaler`, garantindo escala comparável para métodos e modelos lineares.
# - Variáveis categóricas são transformadas via `OneHotEncoder(handle_unknown="ignore")`, produzindo uma representação numérica robusta.
# Há um tratamento de compatibilidade entre versões do scikit-learn (`sparse_output` vs `sparse`).
#
# O resultado é uma matriz totalmente numérica no “espaço transformado”, acompanhada dos nomes das features geradas (`get_feature_names_out`).
#
# 3) **Seleção de variáveis no espaço transformado + mapeamento para o espaço original**
# A seleção é delegada para `pipeline_selecao_variaveis`, que ranqueia e filtra features usando múltiplos critérios
# (filtros estatísticos, importância por Random Forest e wrapper com validação cruzada).
#
# Como o One-Hot Encoding fragmenta variáveis categóricas em múltiplas colunas, a função reconstrói a rastreabilidade
# mapeando cada feature transformada para sua **coluna original** (`map_transformed_to_original_robust`).
# Além disso, é gerado um ranking agregado por feature original (max do score do wrapper entre suas dummies),
# facilitando interpretação e comunicação dos resultados.
#
# A função retorna tanto artefatos do pré-processamento (preprocessor, matriz transformada) quanto rankings e listas finais
# de variáveis selecionadas no espaço transformado e no espaço original.

# %%
def selecionar_variaveis_auto(
    X_data: pd.DataFrame,
    y_data: pd.Series,
    task: str = "binary",
    multiclass_strategy: str = "multinomial",   # multinomial | ovr | ovo
    scoring_wrapper: str | None = None,
    get_feature_types_fn=get_feature_types,
    var_threshold: float = 0.0,
    k_mi: int = 80,
    k_anova: int = 80,
    top_rf: int = 50,
    final_wrapper: int = 20,
    n_splits: int = 5,
    random_state: int = 42,
    remainder: str = "drop",  # "drop" ou "passthrough"
):
    # 1) tipos
    cat_cols, num_cols = get_feature_types_fn(X_data)

    # 2) preprocessor
    # compatibilidade entre versões sklearn:
    # em versões antigas, OneHotEncoder usa sparse=False; nas novas, sparse_output=False
    try:
        ohe = OneHotEncoder(handle_unknown="ignore", sparse_output=False)
    except TypeError:
        ohe = OneHotEncoder(handle_unknown="ignore", sparse=False)

    preprocessor = ColumnTransformer(
        transformers=[
            ("num", StandardScaler(), num_cols),
            ("cat", ohe, cat_cols),
        ],
        remainder=remainder
    )

    # 3) fit/transform
    X_processed = preprocessor.fit_transform(X_data)
    feature_names = preprocessor.get_feature_names_out()

    X_processed_df = pd.DataFrame(X_processed, columns=feature_names, index=X_data.index)

    # 4) seleção no espaço transformado
    selected = pipeline_selecao_variaveis(
        X_processed_df,
        y_data,
        task=task,
        var_threshold=var_threshold,
        k_mi=k_mi,
        k_anova=k_anova,
        top_rf=top_rf,
        final_wrapper=final_wrapper,
        scoring_wrapper=scoring_wrapper,
        n_splits=n_splits,
        random_state=random_state,
        multiclass_strategy=multiclass_strategy,
    )

    # 5) map back transformed -> original
    transformed_to_original = map_transformed_to_original_robust(feature_names, cat_cols)
    map_dict = dict(zip(feature_names, transformed_to_original))

    vars_transformadas = selected["variaveis_finais"]
    vars_originais = sorted({str(map_dict[v]) for v in vars_transformadas if v in map_dict})

    # agregação opcional: score do wrapper por feature original
    scoring_col = selected["ranking_wrapper"].columns[1]
    df_wrap = selected["ranking_wrapper"].copy()
    df_wrap["feature_original"] = df_wrap["variavel"].map(map_dict)

    ranking_original = (
        df_wrap.groupby("feature_original", dropna=False)[scoring_col]
        .max()
        .sort_values(ascending=False)
        .reset_index()
        .rename(columns={scoring_col: f"{scoring_col}_max"})
    )

    return {
        "preprocessor": preprocessor,
        "X_processado_df": X_processed_df,
        "feature_names_after_preproc": feature_names,
        "resultado_selecao_transformado": selected,
        "variaveis_finais_transformadas": vars_transformadas,
        "variaveis_finais_originais": vars_originais,
        "ranking_wrapper_por_feature_original": ranking_original,
        "cat_cols": cat_cols,
        "num_cols": num_cols,
        "map_transformada_para_original": map_dict,
    }

# %%
var_selected = selecionar_variaveis_auto(
     X_data, y_data,
     task="binary",
     scoring_wrapper="f1",
)


print(f"Variáveis selecionadas({len(var_selected["variaveis_finais_originais"])} variáveis):{var_selected["variaveis_finais_originais"]}")
print(f"Variáveis Originais({len(X_data.columns)} variáveis):{X_data.columns}")
# Out:
# Variáveis selecionadas(13 variáveis):['ANT_CB_LAM', 'CLI_ICTERI', 'CLI_OUTROS', 'CLI_PANTUR', 'CLI_PROST', 'CON_AMBIEN', 'CON_AREA', 'CS_ESCOL_N', 'ID_OCUPA_N', 'NU_IDADE_N', 'nivel_vulnerabilidade', 'periodo_chuvoso', 'vulnerabilidade_social']
# Variáveis Originais(43 variáveis):Index(['NU_IDADE_N', 'CS_SEXO', 'CS_GESTANT', 'CS_RACA', 'CS_ESCOL_N',
#        'ID_OCUPA_N', 'CON_AREA', 'CON_AMBIEN', 'ANT_CB_LAM', 'ANT_CB_CRI',
#        'ANT_CB_SIN', 'ANT_CB_COR', 'ANT_CB_ROE', 'ANT_CB_TER', 'ANT_CB_LIX',
#        'ANT_CB_OUT', 'ANT_ANIMAI', 'ANT_HUMANO', 'CLI_FEBRE', 'CLI_MIALGI',
#        'CLI_CEFALE', 'CLI_PROST', 'CLI_CONGES', 'CLI_PANTUR', 'CLI_VOMITO',
#        'CLI_DIARRE', 'CLI_ICTERI', 'CLI_RENAL', 'CLI_RESPIR', 'CLI_CARDIA',
#        'CLI_HEMOPU', 'CLI_HEMORR', 'CLI_MENING', 'CLI_OUTROS', 'SG_UF',
#        'baixa_escolaridade', 'raca_vulneravel', 'faixa_vulneravel',
#        'vulnerabilidade_social', 'nivel_vulnerabilidade', 'mes_sintomas',
#        'estacao', 'periodo_chuvoso'],
#       dtype='object')

# %%
X_data = X_data[var_selected['variaveis_finais_originais']]
X_data.shape
# Out:
# (55110, 13)

# %% [markdown]
# ## Train framework

# %% [markdown]
# ### Funções de apoio

# %% [markdown]
# Detecta automaticamente a disponibilidade de GPU no ambiente,
# verificando suporte a CUDA, compatibilidade do LightGBM com GPU
# e informações do hardware via `nvidia-smi`.

# %%
def detect_gpu():
    """
    Detecta corretamente suporte a GPU para CUDA, XGBoost e LightGBM.
    Retorna um dicionário completo.
    """

    # 1. Verificar CUDA geral
    try:
        cuda_available = torch.cuda.is_available()
    except:
        cuda_available = False


    # 2. Testar LightGBM GPU

    try:
        # Testa se LightGBM foi compilado com suporte a GPU
        lgb_gpu = lgb.register_logger(lambda x: x)  # dummy
        booster = lgb.LGBMClassifier(device="gpu")
        lgb_gpu = True
    except:
        lgb_gpu = False


    # 3. Detalhes da GPU via nvidia-smi

    try:
        smi_output = subprocess.check_output("nvidia-smi", shell=True).decode()
        gpu_info = smi_output.split("\n")[2].strip()
    except:
        gpu_info = "Nenhuma GPU detectada (nvidia-smi não disponível)"

    return {
        "cuda_available": cuda_available,
        "lightgbm_gpu": lgb_gpu,
        "gpu_info": gpu_info
    }

# %%
def get_model_params_gpu(model_name, gpu_info):
    """
    Retorna hiperparâmetros base apropriados para CPU ou GPU.
    """
    use_gpu = gpu_info["cuda_available"]

    if model_name == "xgboost":
        if use_gpu:
            return {
                "tree_method": "gpu_hist",
                "predictor": "gpu_predictor"
            }
        else:
            return {
                "tree_method": "hist",
                "predictor": "cpu_predictor"
            }

    elif model_name == "lightgbm":
        if use_gpu:
            return {
                "device": "gpu",
                "gpu_platform_id": 0,
                "gpu_device_id": 0
            }
        else:
            return {
                "device": "cpu"
            }

    elif model_name in ["random_forest", "svm"]:
        # sklearn não usa GPU
        return {}

    return {}

# %%
def get_feature_types(df):
    """
    Identifica automaticamente colunas categóricas e numéricas de um dataframe.

    Retorna:
        cat_cols  -> lista de colunas categóricas
        num_cols  -> lista de colunas numéricas
    """

    # CATEGÓRICAS: object, category ou boolean
    cat_cols = df.select_dtypes(include=['object', 'category', 'bool']).columns.tolist()

    # NUMÉRICAS: int, float
    num_cols = df.select_dtypes(include=['int', 'float', 'int64', 'float64']).columns.tolist()

    return cat_cols, num_cols

# %% [markdown]
# ###  1. FUNÇÃO PARA CRIAR O MODELO A PARTIR DO TRIAL (Optuna)

# %% [markdown]
# Esta função encapsula a criação do modelo a ser otimizado por uma *trial* do Optuna,
# permitindo que diferentes famílias de classificadores sejam avaliadas dentro do mesmo processo de busca.
#
# O fluxo é composto por duas decisões principais:
#
# 1) **Seleção do algoritmo**
# A cada iteração, o Optuna escolhe o modelo a ser testado (`svm`, `xgboost`, `lightgbm` ou `random_forest`)
# por meio de uma variável categórica (`model_name`). Isso viabiliza uma busca conjunta que compara
# arquiteturas distintas sob o mesmo protocolo de avaliação.
#
# 2) **Amostragem de hiperparâmetros e configuração dinâmica de GPU**
# Para cada algoritmo, são sugeridos hiperparâmetros relevantes (ex.: profundidade, número de árvores, taxa de aprendizado,
# subsample e colsample), definindo um espaço de busca controlado e reproduzível.
# Em paralelo, a função consulta `get_model_params_gpu(model_name, gpu_info)` para injetar automaticamente
# parâmetros específicos de aceleração (CPU/GPU) quando suportado pelo ambiente, garantindo portabilidade do pipeline.
#
# Além disso, é aplicada uma estratégia de mitigação de desbalanceamento:
# - `class_weight="balanced"` para Random Forest e SVM,
# - `is_unbalance=True` para LightGBM,
# visando reduzir viés em cenários com classes minoritárias.
#
# No caso da SVM, utiliza-se `LinearSVC` com calibração (`CalibratedClassifierCV`),
# permitindo a obtenção de probabilidades calibradas, úteis para métricas baseadas em ranking (ex.: ROC-AUC)
# e para tomada de decisão com limiar de classificação.

# %%
def create_model(trial, gpu_info):
    model_name = trial.suggest_categorical(
        "model_name", ["svm","xgboost", "lightgbm", "random_forest"]
    )

    gpu_params = get_model_params_gpu(model_name, gpu_info)

    # RANDOM FOREST
    if model_name == "random_forest":
        return RandomForestClassifier(
            n_estimators=trial.suggest_int("n_estimators", 5, 30),
            max_depth=trial.suggest_int("max_depth", 3, 9),
            min_samples_split=trial.suggest_int("min_samples_split", 2, 10),
            min_samples_leaf=trial.suggest_int("min_samples_leaf", 1, 5),
            random_state=42,
            class_weight= 'balanced',
            **gpu_params
        )

    # SVM
    elif model_name == "svm":
        svm= LinearSVC(
            C=trial.suggest_float("C", 0.1, 3.0),
            max_iter=5000,
            class_weight= 'balanced'
        )
        return CalibratedClassifierCV(svm, method="sigmoid")

    # XGBOOST
    elif model_name == "xgboost":
        return XGBClassifier(
            n_estimators=trial.suggest_int("n_estimators", 5, 30),
            max_depth=trial.suggest_int("max_depth", 3, 9),
            learning_rate=trial.suggest_float("learning_rate", 0.01, 0.3),
            subsample=trial.suggest_float("subsample", 0.5, 1.0),
            colsample_bytree=trial.suggest_float("colsample_bytree", 0.5, 1.0),
            eval_metric="logloss",
            random_state=42,
            class_weight= 'balanced',
            n_jobs=-1,
            #**gpu_params
        )

    # LIGHTGBM
    elif model_name == "lightgbm":
        return LGBMClassifier(
            n_estimators=trial.suggest_int("n_estimators", 5, 30),
            learning_rate=trial.suggest_float("learning_rate", 0.01, 0.3),
            max_depth=trial.suggest_int("max_depth", 3, 9),
            subsample=trial.suggest_float("subsample", 0.5, 1.0),
            colsample_bytree=trial.suggest_float("colsample_bytree", 0.5, 1.0),
            random_state=42,
            is_unbalance=True,
           force_col_wise=True,
            **gpu_params
        )

# %% [markdown]
# ### 2. FUNÇÃO OBJETIVO DO OPTUNA (COM CROSS-VALIDATION)

# %% [markdown]
# ### Função `build_pipeline`: pré-processamento, balanceamento e modelagem em um fluxo único
#
# Esta função constrói um pipeline completo de treinamento, integrando pré-processamento dos dados,
# tratamento de desbalanceamento e ajuste do modelo em uma única estrutura reprodutível.
#
# O pipeline é organizado em três blocos sequenciais:
#
# 1) **Pré-processamento por tipo de variável**
# - Variáveis numéricas passam por imputação da mediana, reduzindo sensibilidade a outliers,
# seguida de padronização (`StandardScaler`), garantindo escalas compatíveis para modelos sensíveis à magnitude.
# - Variáveis categóricas passam por imputação do valor mais frequente e codificação via `OneHotEncoder`,
# com tratamento explícito de categorias raras (`handle_unknown='infrequent_if_exist'`),
# o que reduz dimensionalidade excessiva e melhora estabilidade do modelo.
#
# 2) **Balanceamento de classes (SMOTE)**
# Após o pré-processamento, aplica-se o SMOTE para gerar amostras sintéticas da classe minoritária
# exclusivamente no conjunto de treino dentro do pipeline,
# evitando vazamento de informação (*data leakage*) e melhorando a capacidade do modelo
# em aprender fronteiras de decisão mais equilibradas.
#
# 3) **Modelo preditivo**
# O estimador final é injetado de forma modular, permitindo que diferentes algoritmos
# (Random Forest, SVM, XGBoost, LightGBM, etc.) sejam testados sob exatamente o mesmo fluxo de dados.
#
# Ao encapsular todas as etapas em um único objeto `Pipeline`,
# a função garante consistência entre treino, validação e inferência,
# além de facilitar integração com validação cruzada e otimização de hiperparâmetros.

# %%
def build_pipeline(model, cat_cols, num_cols):

    # construindo o preprocessor
    num_preprocessor = Pipeline(steps=[
        ("imputer", SimpleImputer(strategy="median")),
        ("scaler", StandardScaler())
    ])

    cat_preprocessor = Pipeline(steps=[
        ("imputer", SimpleImputer(strategy="most_frequent")),
        ("onehot", OneHotEncoder(handle_unknown='infrequent_if_exist'))
    ])

    preprocessor = ColumnTransformer(
        transformers=[
            ("num", num_preprocessor, num_cols),
            ("cat", cat_preprocessor, cat_cols)
        ]
    )

    # construindo pipe
    pipe = Pipeline([
        ("preprocessor", preprocessor),
        ("smote", SMOTE(random_state=42)),
        ("model", model)
    ])

    return pipe

# %% [markdown]
# ### Função `objective`: avaliação do modelo por validação cruzada e otimização com Optuna (com pruning)
#
# Esta função define a métrica objetivo utilizada pelo Optuna durante a busca de hiperparâmetros.
# Para cada `trial`, ela instancia um modelo candidato (via `create_model`) e o encapsula em um pipeline completo
# de pré-processamento + balanceamento (via `build_pipeline`), garantindo que todas as transformações
# sejam aplicadas corretamente dentro de cada fold e evitando *data leakage*.
#
# A avaliação é realizada com **validação cruzada estratificada** (`StratifiedKFold`),
# preservando a proporção de classes em treino e validação. Em cada fold:
# - o pipeline é treinado no subconjunto de treino (`fit`),
# - e a performance é medida no subconjunto de validação por **ROC-AUC** calculado a partir de probabilidades (`predict_proba`).
#
# Para suportar cenários multiclasse, o AUC é calculado com `multi_class='ovr'`
# e agregação `average='weighted'`, o que pondera o desempenho pelo suporte de cada classe
# e reduz distorções em bases desbalanceadas.
#
# Além disso, a função utiliza mecanismos de *early stopping* do Optuna:
# - `trial.report` comunica a métrica parcial por fold,
# - `trial.should_prune()` permite interromper tentativas com desempenho fraco,
# economizando tempo computacional e acelerando a convergência do processo de otimização.
#
# Ao final, a função retorna a média do AUC entre os folds, que é o valor maximizado pelo Optuna.

# %%
def objective(trial, X_train, y_train, cat_cols, num_cols,feature_names, gpu_info):

    model = create_model(trial, gpu_info)

    pipe = build_pipeline(model ,cat_cols, num_cols)


    cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

    scores = []
    for step, (train_idx, val_idx) in enumerate(cv.split(X_train, y_train)):

        X_tr, X_val = X_train.iloc[train_idx], X_train.iloc[val_idx]
        y_tr, y_val = y_train.iloc[train_idx], y_train.iloc[val_idx]


        pipe.fit(X_tr, y_tr)
        fold_auc = roc_auc_score(y_val, pipe.predict_proba(X_val)[:, 1])
        scores.append(fold_auc)

        #  reporta o valor parcial ao Optuna
        trial.report(fold_auc, step=step)

        #  aborta a tentativa dado a avaliação do pruner
        if trial.should_prune():
            raise TrialPruned()


    return np.mean(scores)

# %% [markdown]
# Salva o histórico das trials do Optuna (métrica, parâmetros, estado e duração)
# em arquivo CSV para análise e rastreabilidade do processo de otimização.

# %%
# salva os logs das tentativas com métricas, tempo de treinamento, e parametros utilizados pelos modelos
def dump_trials(study, trial, out_path):
    df_metrics = study.trials_dataframe(
        attrs=("number", "value", "params", "state", "duration")
    )
    df_metrics.to_csv(out_path, index=False)

# %% [markdown]
# ### 3. VALIDAÇÃO EXTERNA (OUTER CV) + OPTUNA INTERNO

# %% [markdown]
# ### Função `outer_cv_training_with_results`: nested CV com Optuna, checkpoint e métricas por fold
#
# Esta função executa um processo completo de treinamento e avaliação com **validação cruzada externa**
# (*outer cross-validation*), integrando **otimização de hiperparâmetros com Optuna** dentro de cada fold
# e registrando resultados detalhados (modelo escolhido, métricas, tempo e artefatos salvos).
#
# O fluxo segue a lógica de *nested cross-validation*:
#
# 1) **Diagnóstico do ambiente (GPU)**
# Antes do treinamento, a função identifica a disponibilidade de GPU (`detect_gpu`), permitindo que a criação dos modelos
# ative parâmetros específicos de aceleração quando suportado.
#
# 2) **Validação cruzada externa (generalização)**
# É aplicada uma `StratifiedKFold` externa com `n_splits`, garantindo que a proporção das classes seja preservada em cada divisão.
# Em cada fold externo, o conjunto é particionado em `X_train/y_train` (para otimização e treino) e `X_test/y_test` (avaliação final).
#
# 3) **Otimização interna com Optuna (seleção de modelo + hiperparâmetros)**
# Para cada fold externo, um `study` é criado com objetivo de maximizar a métrica definida na função `objective`.
# A função `objective` é “fixada” via `partial`, injetando os dados do fold e metadados do pipeline (colunas numéricas e categóricas,
# GPU, etc.), de forma que cada trial avalie modelos e hiperparâmetros sob o mesmo protocolo.
#
# O estudo é executado com:
# - `n_trials` tentativas,
# - controle de tempo (`timeout`),
# - paralelismo (`n_jobs=-1`),
# - callback de logging (`dump_trials`) para persistir histórico das trials.
#
# 4) **Treinamento final do melhor modelo no fold e checkpoint**
# Após a otimização, a melhor configuração é recuperada (`study.best_params`) e o melhor modelo é reconstruído (`create_model`),
# sendo então encapsulado em um pipeline (`build_pipeline`) com pré-processamento e SMOTE.
# O pipeline é treinado no conjunto de treino do fold com medição de tempo, e o artefato final é salvo em disco (`joblib.dump`)
# como checkpoint (`best_model_fold_k.pkl`), garantindo reprodutibilidade e possibilidade de reuso posterior.
#
# 5) **Avaliação no conjunto de teste do fold (métricas completas)**
# O modelo treinado é avaliado no `X_test/y_test` do fold externo usando:
# - **ROC-AUC multiclasse** com estratégia OvR e média ponderada (`average='weighted'`),
# - além de `accuracy`, `f1`, `recall` e `precision` (também ponderadas), adequadas para cenários desbalanceados.
#
# Ao final, a função retorna uma lista de dicionários com os resultados de cada fold,
# incluindo o modelo vencedor, hiperparâmetros, métricas, tempo de treino e caminho do checkpoint.
# Isso permite comparar estabilidade do desempenho entre folds e estimar capacidade real de generalização.

# %%
def outer_cv_training_with_results(
    X, y, cat_cols, num_cols,
    n_trials=30, n_splits=5,
    log_dir="log_opt",
    model_ckpt_dir="checkpoints_best_models",
    pruner_mode='halving'
):
    gpu_info = detect_gpu()
    print("\n🔍 GPU detectada:", gpu_info)


    outer_cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
    results = []
    feature_names = X.columns

    for fold, (train_idx, test_idx) in enumerate(outer_cv.split(X, y), start=1):

        print(f"\n==============================")
        print(f"  Fold Externo {fold}/{n_splits}")
        print(f"==============================")

        X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]
        if pruner_mode.lower() == "hyperband":
            pruner = HyperbandPruner(
                min_resource=1,
                max_resource=20,
                reduction_factor=10
            )
        elif pruner_mode.lower() == "median":
            pruner = MedianPruner(
                n_warmup_steps=10
            )
        elif pruner_mode.lower() == "halving":
            pruner = SuccessiveHalvingPruner(
                min_resource=1, reduction_factor=3, min_early_stopping_rate=1
            )

        study = optuna.create_study(direction="maximize", pruner=pruner)

        objective_fixed = partial(
            objective,
            X_train=X_train,
            y_train=y_train,
            cat_cols=cat_cols,
            num_cols=num_cols,
            feature_names=feature_names,
            gpu_info=gpu_info
        )

        # log por fold (arquivo diferente)
        log_path = os.path.join(log_dir, f"trials_log_fold_{fold}.csv")
        dump_trials_cb = partial(dump_trials, out_path=log_path)

        study.optimize(
            objective_fixed,
            n_trials=n_trials,
            callbacks=[dump_trials_cb],
            timeout=1800,
            n_jobs=-1,
        )

        best_params = study.best_params
        best_model_name = best_params.get("model_name", "unknown")
        best_model = create_model(study.best_trial, gpu_info)

        pipe = build_pipeline(best_model, cat_cols, num_cols)

        start_time = time.time()
        pipe.fit(X_train, y_train)
        train_time = time.time() - start_time

        # checkpoint do melhor modelo do fold
        checkpoint_path = os.path.join(model_ckpt_dir, f"best_model_fold_{fold}.pkl")
        joblib.dump(pipe, checkpoint_path)

        # predição
        y_pred = pipe.predict(X_test)
        y_pred_prob = pipe.predict_proba(X_test)[:, 1]

        # métricas
        auc = roc_auc_score(y_test, y_pred_prob)
        acc = accuracy_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)
        rec = recall_score(y_test, y_pred)
        prec = precision_score(y_test, y_pred)

        results.append({
            "fold": fold,
            "best_model": best_model_name,
            "auc": auc,
            "accuracy": acc,
            "f1": f1,
            "recall": rec,
            "precision": prec,
            "hyperparameters": best_params,
            "checkpoint_path": checkpoint_path,
            "train_time_seconds": train_time,
            "trials_log_path": log_path,
        })

    return results

# %% [markdown]
# # Execute Framework

# %% [markdown]
# Cria os diretórios de checkpoints de modelos e logs de otimização,
# caso não existam, garantindo persistência e organização dos artefatos do experimento.

# %%
import os, joblib
checkpoint_dir = "checkpoints_best_models"

if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)

checkpoint_dir = "log_opt"
if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)


# ================================================

# %% [markdown]
# ### Execução do treinamento com validação cruzada externa e otimização de hiperparâmetros
#
# Nesta etapa, o conjunto de dados é preparado para o processo completo de treinamento e avaliação.
# Inicialmente, as colunas são classificadas em **categóricas** e **numéricas** por meio da função
# `get_feature_types`, garantindo que o pré-processamento subsequente seja aplicado de forma adequada
# a cada tipo de variável.
#
# Em seguida, é executado o procedimento de **validação cruzada externa** (*outer cross-validation*),
# no qual, para cada fold, ocorre uma otimização interna de hiperparâmetros via Optuna.
# Esse desenho experimental permite avaliar o desempenho dos modelos de forma mais realista,
# uma vez que o conjunto de teste de cada fold permanece completamente isolado do processo de tuning.
#
# Os parâmetros utilizados (`n_trials=30` e `n_splits=5`) definem, respectivamente,
# o orçamento de busca de hiperparâmetros em cada fold e o número de partições externas,
# balanceando custo computacional e robustez estatística.
#
# O resultado final (`df_results`) contém métricas, hiperparâmetros selecionados,
# tempos de treinamento e caminhos dos checkpoints para cada fold,
# servindo como base para análises comparativas e seleção do modelo final.

# %%
cat_cols, num_cols = get_feature_types(X_data)
df_results = outer_cv_training_with_results(
    X_data, y_data,
    cat_cols=cat_cols,
    num_cols=num_cols,
    n_trials=50,
    n_splits=5
)
# Out:
# 🔍 GPU detectada: {'cuda_available': False, 'lightgbm_gpu': False, 'gpu_info': 'Nenhuma GPU detectada (nvidia-smi não disponível)'}
#
# ==============================
#   Fold Externo 1/5
# ==============================
# [I 2026-02-09 23:30:22,826] A new study created in memory with name: no-name-f91d7001-41d6-4f86-ae74-2a2ad89874d9
# [I 2026-02-09 23:30:35,831] Trial 1 finished with value: 0.9050944553654795 and parameters: {'model_name': 'lightgbm', 'n_estimators': 21, 'learning_rate': 0.11757752695697711, 'max_depth': 3, 'subsample': 0.8708387756191605, 'colsample_bytree': 0.9678075313272447}. Best is trial 1 with value: 0.9050944553654795.
# [I 2026-02-09 23:30:37,250] Trial 0 finished with value: 0.909715782075323 and parameters: {'model_name': 'lightgbm', 'n_estimators': 21, 'learning_rate': 0.10957552146353261, 'max_depth': 7, 'subsample': 0.561284412295517, 'colsample_bytree': 0.8118407929254006}. Best is trial 0 with value: 0.909715782075323.
# [I 2026-02-09 23:30:50,607] Trial 2 finished with value: 0.9090231965187434 and parameters: {'model_name': 'xgboost', 'n_estimators': 22, 'max_depth': 6, 'learning_rate': 0.2772840968398591, 'subsample': 0.5820512225014624, 'colsample_bytree': 0.8461705930952055}. Best is trial 0 with value: 0.909715782075323.
# [I 2026-02-09 23:30:51,039] Trial 3 finished with value: 0.9045771901544036 and parameters: {'model_name': 'xgboost', 'n_estimators': 12, 'max_depth': 5, 'learning_rate': 0.2491240178737378, 'subsample': 0.9313646695055404, 'colsample_bytree': 0.7790386997778724}. Best is trial 0 with value: 0.909715782075323.
# [I 2026-02-09 23:31:25,669] Trial 5 finished with value: 0.9025783160289106 and parameters: {'model_name': 'svm', 'C': 1.1676885568445676}. Best is trial 0 with value: 0.909715782075323.
# [I 2026-02-09 23:31:31,104] Trial 4 finished with value: 0.9022413404402467 and parameters: {'model_name': 'svm', 'C': 1.955698551411743}. Best is trial 0 with value: 0.909715782075323.
# [I 2026-02-09 23:31:39,048] Trial 6 finished with value: 0.904283397216581 and parameters: {'model_name': 'xgboost', 'n_estimators': 8, 'max_depth': 7, 'learning_rate': 0.2444310001157883, 'subsample': 0.8793288436735109, 'colsample_bytree': 0.716729017960396}. Best is trial 0 with value: 0.909715782075323.
# [I 2026-02-09 23:31:43,641] Trial 7 finished with value: 0.892344320464966 and parameters: {'model_name': 'random_forest', 'n_estimators': 12, 'max_depth': 7, 'min_samples_split': 5, 'min_samples_leaf': 5}. Best is trial 0 with value: 0.909715782075323.
# [I 2026-02-09 23:31:50,786] Trial 8 finished with value: 0.9001149897778399 and parameters: {'model_name': 'random_forest', 'n_estimators': 13, 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 5}. Best is trial 0 with value: 0.909715782075323.
# [I 2026-02-09 23:31:57,861] Trial 9 finished with value: 0.9038186504828875 and parameters: {'model_name': 'random_forest', 'n_estimators': 27, 'max_depth': 8, 'min_samples_split': 9, 'min_samples_leaf': 4}. Best is trial 0 with value: 0.909715782075323.
# [I 2026-02-09 23:32:02,552] Trial 10 finished with value: 0.9068811530039236 and parameters: {'model_name': 'lightgbm', 'n_estimators': 10, 'learning_rate': 0.11372020449093104, 'max_depth': 9, 'subsample': 0.8111915849192584, 'colsample_bytree': 0.931743362472226}. Best is trial 0 with value: 0.909715782075323.
# [I 2026-02-09 23:32:11,813] Trial 11 finished with value: 0.9086798271551205 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.018100386134068863, 'max_depth': 9, 'subsample': 0.510458269631061, 'colsample_bytree': 0.5928532873696297}. Best is trial 0 with value: 0.909715782075323.
# [I 2026-02-09 23:32:16,639] Trial 12 finished with value: 0.9011613786171733 and parameters: {'model_name': 'xgboost', 'n_estimators': 22, 'max_depth': 5, 'learning_rate': 0.026895726868359282, 'subsample': 0.5402225581378621, 'colsample_bytree': 0.8191527003082495}. Best is trial 0 with value: 0.909715782075323.
# [I 2026-02-09 23:32:25,908] Trial 13 finished with value: 0.9074158242780581 and parameters: {'model_name': 'xgboost', 'n_estimators': 20, 'max_depth': 5, 'learning_rate': 0.17808451004344694, 'subsample': 0.5722562604347199, 'colsample_bytree': 0.827975956121321}. Best is trial 0 with value: 0.909715782075323.
# [I 2026-02-09 23:32:31,746] Trial 14 finished with value: 0.9079438641379438 and parameters: {'model_name': 'xgboost', 'n_estimators': 19, 'max_depth': 6, 'learning_rate': 0.1865632949860609, 'subsample': 0.6521917767861077, 'colsample_bytree': 0.8415454019610178}. Best is trial 0 with value: 0.909715782075323.
# [I 2026-02-09 23:32:38,903] Trial 15 finished with value: 0.9095792376082326 and parameters: {'model_name': 'lightgbm', 'n_estimators': 16, 'learning_rate': 0.17464342479469797, 'max_depth': 6, 'subsample': 0.6749552126639244, 'colsample_bytree': 0.6789545899686604}. Best is trial 0 with value: 0.909715782075323.
# [I 2026-02-09 23:32:45,661] Trial 16 finished with value: 0.9094925464909975 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.2777916274676987, 'max_depth': 6, 'subsample': 0.6765643095377738, 'colsample_bytree': 0.6791380160402318}. Best is trial 0 with value: 0.909715782075323.
# [I 2026-02-09 23:32:50,788] Trial 17 finished with value: 0.9045175626545078 and parameters: {'model_name': 'lightgbm', 'n_estimators': 16, 'learning_rate': 0.09369621722761343, 'max_depth': 3, 'subsample': 0.6988040008892609, 'colsample_bytree': 0.6667218051166386}. Best is trial 0 with value: 0.909715782075323.
# [I 2026-02-09 23:32:58,574] Trial 18 finished with value: 0.9046794316851478 and parameters: {'model_name': 'lightgbm', 'n_estimators': 16, 'learning_rate': 0.09019246739558394, 'max_depth': 3, 'subsample': 0.7107312862020365, 'colsample_bytree': 0.5393066496714891}. Best is trial 0 with value: 0.909715782075323.
# [I 2026-02-09 23:33:03,242] Trial 19 finished with value: 0.9076005396416177 and parameters: {'model_name': 'lightgbm', 'n_estimators': 16, 'learning_rate': 0.15251940251386584, 'max_depth': 4, 'subsample': 0.7485817014456937, 'colsample_bytree': 0.5126883528912778}. Best is trial 0 with value: 0.909715782075323.
# [I 2026-02-09 23:33:12,321] Trial 20 finished with value: 0.9106778181805004 and parameters: {'model_name': 'lightgbm', 'n_estimators': 25, 'learning_rate': 0.15468786775967472, 'max_depth': 7, 'subsample': 0.6186044950855171, 'colsample_bytree': 0.6019395904823486}. Best is trial 20 with value: 0.9106778181805004.
# [I 2026-02-09 23:33:15,804] Trial 21 finished with value: 0.9072593909473939 and parameters: {'model_name': 'lightgbm', 'n_estimators': 6, 'learning_rate': 0.2088917682606679, 'max_depth': 7, 'subsample': 0.6166756406731984, 'colsample_bytree': 0.6103343364713605}. Best is trial 20 with value: 0.9106778181805004.
# [I 2026-02-09 23:33:26,738] Trial 22 finished with value: 0.9102884517486559 and parameters: {'model_name': 'lightgbm', 'n_estimators': 25, 'learning_rate': 0.15843750058896314, 'max_depth': 7, 'subsample': 0.6232404259827448, 'colsample_bytree': 0.6192399502975459}. Best is trial 20 with value: 0.9106778181805004.
# [I 2026-02-09 23:33:29,746] Trial 23 finished with value: 0.9103479090500711 and parameters: {'model_name': 'lightgbm', 'n_estimators': 25, 'learning_rate': 0.1463511597313639, 'max_depth': 8, 'subsample': 0.6189688355000371, 'colsample_bytree': 0.6423363817858517}. Best is trial 20 with value: 0.9106778181805004.
# [I 2026-02-09 23:33:40,959] Trial 24 finished with value: 0.910860096497188 and parameters: {'model_name': 'lightgbm', 'n_estimators': 25, 'learning_rate': 0.13959387224784825, 'max_depth': 8, 'subsample': 0.6159536393908984, 'colsample_bytree': 0.5936091736192096}. Best is trial 24 with value: 0.910860096497188.
# [I 2026-02-09 23:33:54,705] Trial 25 finished with value: 0.904567019194365 and parameters: {'model_name': 'svm', 'C': 0.14718246761110532}. Best is trial 24 with value: 0.910860096497188.
# [I 2026-02-09 23:34:04,277] Trial 26 finished with value: 0.9045017485520798 and parameters: {'model_name': 'svm', 'C': 0.15675635452015224}. Best is trial 24 with value: 0.910860096497188.
# [I 2026-02-09 23:34:07,840] Trial 27 finished with value: 0.9097878778983177 and parameters: {'model_name': 'lightgbm', 'n_estimators': 25, 'learning_rate': 0.05851146488302908, 'max_depth': 8, 'subsample': 0.7634788777944247, 'colsample_bytree': 0.5460660497090479}. Best is trial 24 with value: 0.910860096497188.
# [I 2026-02-09 23:34:18,325] Trial 28 finished with value: 0.9106141142888294 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.1398475738778713, 'max_depth': 8, 'subsample': 0.7678668668020902, 'colsample_bytree': 0.5712904885807527}. Best is trial 24 with value: 0.910860096497188.
# [I 2026-02-09 23:34:21,257] Trial 29 finished with value: 0.9108178604741156 and parameters: {'model_name': 'lightgbm', 'n_estimators': 29, 'learning_rate': 0.14228875476354025, 'max_depth': 8, 'subsample': 0.6191538501424654, 'colsample_bytree': 0.5916300278060798}. Best is trial 24 with value: 0.910860096497188.
# [I 2026-02-09 23:34:38,541] Trial 30 finished with value: 0.9101727764534212 and parameters: {'model_name': 'lightgbm', 'n_estimators': 29, 'learning_rate': 0.21687199290180625, 'max_depth': 9, 'subsample': 0.791783740706242, 'colsample_bytree': 0.5668607726933387}. Best is trial 24 with value: 0.910860096497188.
# [I 2026-02-09 23:34:43,021] Trial 31 finished with value: 0.9102893121129915 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.21070184407071801, 'max_depth': 9, 'subsample': 0.6062371313103894, 'colsample_bytree': 0.5024467708872553}. Best is trial 24 with value: 0.910860096497188.
# [I 2026-02-09 23:34:52,973] Trial 32 finished with value: 0.9105544851600641 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.14260643922345748, 'max_depth': 8, 'subsample': 0.7297765332123881, 'colsample_bytree': 0.5764773503096353}. Best is trial 24 with value: 0.910860096497188.
# [I 2026-02-09 23:34:56,719] Trial 33 finished with value: 0.9107376083553005 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.13359948407825925, 'max_depth': 8, 'subsample': 0.5120454997164869, 'colsample_bytree': 0.5822385639863564}. Best is trial 24 with value: 0.910860096497188.
# [I 2026-02-09 23:35:07,012] Trial 34 finished with value: 0.9105417107963817 and parameters: {'model_name': 'lightgbm', 'n_estimators': 24, 'learning_rate': 0.12657875270675129, 'max_depth': 8, 'subsample': 0.6584676323497022, 'colsample_bytree': 0.7221220582063479}. Best is trial 24 with value: 0.910860096497188.
# [I 2026-02-09 23:35:09,869] Trial 35 finished with value: 0.909868116051951 and parameters: {'model_name': 'lightgbm', 'n_estimators': 23, 'learning_rate': 0.12567734998257035, 'max_depth': 7, 'subsample': 0.5179354304757348, 'colsample_bytree': 0.7167882841977133}. Best is trial 24 with value: 0.910860096497188.
# [I 2026-02-09 23:35:21,099] Trial 36 finished with value: 0.9097053666925272 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.07592342805406312, 'max_depth': 7, 'subsample': 0.5242281821211305, 'colsample_bytree': 0.6397515441761616}. Best is trial 24 with value: 0.910860096497188.
# [I 2026-02-09 23:35:23,604] Trial 37 finished with value: 0.9037251745339656 and parameters: {'model_name': 'random_forest', 'n_estimators': 28, 'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 24 with value: 0.910860096497188.
# [I 2026-02-09 23:35:36,127] Trial 38 finished with value: 0.9044225078254015 and parameters: {'model_name': 'random_forest', 'n_estimators': 28, 'max_depth': 9, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 24 with value: 0.910860096497188.
# [I 2026-02-09 23:36:09,944] Trial 39 finished with value: 0.9020375214651452 and parameters: {'model_name': 'svm', 'C': 2.895165000426986}. Best is trial 24 with value: 0.910860096497188.
# [I 2026-02-09 23:36:23,949] Trial 41 finished with value: 0.9106929041383602 and parameters: {'model_name': 'lightgbm', 'n_estimators': 23, 'learning_rate': 0.1652246658681978, 'max_depth': 8, 'subsample': 0.5710127594706566, 'colsample_bytree': 0.5420665892754022}. Best is trial 24 with value: 0.910860096497188.
# [I 2026-02-09 23:36:24,056] Trial 40 finished with value: 0.9020230992961572 and parameters: {'model_name': 'svm', 'C': 2.9846513296929063}. Best is trial 24 with value: 0.910860096497188.
# [I 2026-02-09 23:36:37,423] Trial 42 finished with value: 0.9106634734856099 and parameters: {'model_name': 'lightgbm', 'n_estimators': 23, 'learning_rate': 0.16648781722415135, 'max_depth': 8, 'subsample': 0.5648709665039294, 'colsample_bytree': 0.5382143587665252}. Best is trial 24 with value: 0.910860096497188.
# [I 2026-02-09 23:36:38,209] Trial 43 finished with value: 0.910653309072026 and parameters: {'model_name': 'lightgbm', 'n_estimators': 22, 'learning_rate': 0.172303470556526, 'max_depth': 8, 'subsample': 0.5565683349666813, 'colsample_bytree': 0.5415551556467063}. Best is trial 24 with value: 0.910860096497188.
# [I 2026-02-09 23:36:51,468] Trial 44 finished with value: 0.9106393273510246 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.19005034495323356, 'max_depth': 8, 'subsample': 0.5514165589360912, 'colsample_bytree': 0.6038607084853701}. Best is trial 24 with value: 0.910860096497188.
# [I 2026-02-09 23:36:52,464] Trial 45 finished with value: 0.9104942010476792 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.19253986997885258, 'max_depth': 7, 'subsample': 0.5851647262066183, 'colsample_bytree': 0.608316069816888}. Best is trial 24 with value: 0.910860096497188.
# [I 2026-02-09 23:37:05,505] Trial 46 finished with value: 0.9100583559663517 and parameters: {'model_name': 'lightgbm', 'n_estimators': 24, 'learning_rate': 0.10276371670576458, 'max_depth': 7, 'subsample': 0.5877133467402038, 'colsample_bytree': 0.6420986044625747}. Best is trial 24 with value: 0.910860096497188.
# [I 2026-02-09 23:37:09,283] Trial 47 finished with value: 0.9068783021186264 and parameters: {'model_name': 'xgboost', 'n_estimators': 20, 'max_depth': 9, 'learning_rate': 0.10409987884352778, 'subsample': 0.5930964799602277, 'colsample_bytree': 0.6506732580271264}. Best is trial 24 with value: 0.910860096497188.
# [I 2026-02-09 23:37:21,994] Trial 48 finished with value: 0.9087246109443686 and parameters: {'model_name': 'xgboost', 'n_estimators': 20, 'max_depth': 9, 'learning_rate': 0.1323635822244902, 'subsample': 0.5010577823084027, 'colsample_bytree': 0.5760104003387267}. Best is trial 24 with value: 0.910860096497188.
# [I 2026-02-09 23:37:23,171] Trial 49 finished with value: 0.9059826434297641 and parameters: {'model_name': 'random_forest', 'n_estimators': 30, 'max_depth': 8, 'min_samples_split': 6, 'min_samples_leaf': 3}. Best is trial 24 with value: 0.910860096497188.
# [LightGBM] [Info] Number of positive: 35224, number of negative: 35224
# [LightGBM] [Info] Total Bins 15660
# [LightGBM] [Info] Number of data points in the train set: 70448, number of used features: 225
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2026-02-09 23:37:28,297] A new study created in memory with name: no-name-038c99a5-2d43-4a0d-b15c-b433575c5adf
# ==============================
#   Fold Externo 2/5
# ==============================
# [I 2026-02-09 23:37:42,055] Trial 0 finished with value: 0.9031625388940508 and parameters: {'model_name': 'random_forest', 'n_estimators': 22, 'max_depth': 9, 'min_samples_split': 3, 'min_samples_leaf': 5}. Best is trial 0 with value: 0.9031625388940508.
# [I 2026-02-09 23:38:02,491] Trial 2 finished with value: 0.8906480797229127 and parameters: {'model_name': 'xgboost', 'n_estimators': 7, 'max_depth': 3, 'learning_rate': 0.15764303547887032, 'subsample': 0.572265920686545, 'colsample_bytree': 0.523032157830772}. Best is trial 0 with value: 0.9031625388940508.
# [I 2026-02-09 23:38:39,740] Trial 1 finished with value: 0.90094932411117 and parameters: {'model_name': 'svm', 'C': 2.7656372195819903}. Best is trial 0 with value: 0.9031625388940508.
# [I 2026-02-09 23:38:49,536] Trial 3 finished with value: 0.9023871572320322 and parameters: {'model_name': 'svm', 'C': 0.4746936341429876}. Best is trial 0 with value: 0.9031625388940508.
# [I 2026-02-09 23:38:52,698] Trial 4 finished with value: 0.8905683648291784 and parameters: {'model_name': 'random_forest', 'n_estimators': 10, 'max_depth': 7, 'min_samples_split': 9, 'min_samples_leaf': 2}. Best is trial 0 with value: 0.9031625388940508.
# [I 2026-02-09 23:39:00,570] Trial 5 finished with value: 0.87262339254785 and parameters: {'model_name': 'random_forest', 'n_estimators': 18, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 2}. Best is trial 0 with value: 0.9031625388940508.
# [I 2026-02-09 23:39:04,218] Trial 6 finished with value: 0.8897632329263013 and parameters: {'model_name': 'xgboost', 'n_estimators': 15, 'max_depth': 3, 'learning_rate': 0.054888569112060234, 'subsample': 0.5504948601272628, 'colsample_bytree': 0.5473064866731447}. Best is trial 0 with value: 0.9031625388940508.
# [I 2026-02-09 23:39:13,719] Trial 7 finished with value: 0.8941184418892713 and parameters: {'model_name': 'random_forest', 'n_estimators': 24, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 4}. Best is trial 0 with value: 0.9031625388940508.
# [I 2026-02-09 23:39:20,591] Trial 8 finished with value: 0.9036403052362806 and parameters: {'model_name': 'xgboost', 'n_estimators': 21, 'max_depth': 7, 'learning_rate': 0.070292144215254, 'subsample': 0.6018541350048252, 'colsample_bytree': 0.8433609154692749}. Best is trial 8 with value: 0.9036403052362806.
# [I 2026-02-09 23:39:27,552] Trial 9 finished with value: 0.9074248751934793 and parameters: {'model_name': 'lightgbm', 'n_estimators': 16, 'learning_rate': 0.0963892771896592, 'max_depth': 9, 'subsample': 0.7145697895010434, 'colsample_bytree': 0.5633659534782569}. Best is trial 9 with value: 0.9074248751934793.
# [I 2026-02-09 23:39:32,857] Trial 10 finished with value: 0.9077346954365627 and parameters: {'model_name': 'lightgbm', 'n_estimators': 11, 'learning_rate': 0.2038173692978358, 'max_depth': 7, 'subsample': 0.642887266486025, 'colsample_bytree': 0.8141177104206082}. Best is trial 10 with value: 0.9077346954365627.
# [I 2026-02-09 23:39:41,600] Trial 11 finished with value: 0.9079921958268601 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.25255030241301696, 'max_depth': 9, 'subsample': 0.9069936053045502, 'colsample_bytree': 0.6951781495583771}. Best is trial 11 with value: 0.9079921958268601.
# [I 2026-02-09 23:39:45,784] Trial 12 finished with value: 0.9081867211987781 and parameters: {'model_name': 'lightgbm', 'n_estimators': 13, 'learning_rate': 0.282085411354688, 'max_depth': 9, 'subsample': 0.8313899637714303, 'colsample_bytree': 0.7353121082932289}. Best is trial 12 with value: 0.9081867211987781.
# [I 2026-02-09 23:39:55,297] Trial 13 finished with value: 0.9082533464872009 and parameters: {'model_name': 'lightgbm', 'n_estimators': 29, 'learning_rate': 0.28052468762052574, 'max_depth': 7, 'subsample': 0.9655098823065622, 'colsample_bytree': 0.7464366289526838}. Best is trial 13 with value: 0.9082533464872009.
# [I 2026-02-09 23:39:59,959] Trial 14 finished with value: 0.9069473916148834 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.29517727426429907, 'max_depth': 9, 'subsample': 0.9199449016270138, 'colsample_bytree': 0.7047899630418131}. Best is trial 13 with value: 0.9082533464872009.
# [I 2026-02-09 23:40:10,612] Trial 15 finished with value: 0.9081344465756228 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.299712914490753, 'max_depth': 5, 'subsample': 0.9723830406248016, 'colsample_bytree': 0.9812460719803227}. Best is trial 13 with value: 0.9082533464872009.
# [I 2026-02-09 23:40:13,943] Trial 16 finished with value: 0.9043124578426424 and parameters: {'model_name': 'lightgbm', 'n_estimators': 5, 'learning_rate': 0.29267671561272984, 'max_depth': 5, 'subsample': 0.9967588310283216, 'colsample_bytree': 0.7395391335250047}. Best is trial 13 with value: 0.9082533464872009.
# [I 2026-02-09 23:40:25,259] Trial 17 finished with value: 0.9084035718732935 and parameters: {'model_name': 'lightgbm', 'n_estimators': 13, 'learning_rate': 0.22512905535022676, 'max_depth': 8, 'subsample': 0.8226803515167774, 'colsample_bytree': 0.766431731280423}. Best is trial 17 with value: 0.9084035718732935.
# [I 2026-02-09 23:40:28,664] Trial 18 finished with value: 0.9083382969056384 and parameters: {'model_name': 'lightgbm', 'n_estimators': 13, 'learning_rate': 0.22319892990822104, 'max_depth': 8, 'subsample': 0.804043052677503, 'colsample_bytree': 0.6386942577225883}. Best is trial 17 with value: 0.9084035718732935.
# [I 2026-02-09 23:40:39,809] Trial 19 finished with value: 0.9084535529248231 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.2177367098746579, 'max_depth': 8, 'subsample': 0.795642821550339, 'colsample_bytree': 0.8489283762771698}. Best is trial 19 with value: 0.9084535529248231.
# [I 2026-02-09 23:41:15,861] Trial 20 finished with value: 0.9009197891873972 and parameters: {'model_name': 'svm', 'C': 2.9354832783666787}. Best is trial 19 with value: 0.9084535529248231.
# [I 2026-02-09 23:41:22,131] Trial 21 finished with value: 0.9011083853388963 and parameters: {'model_name': 'svm', 'C': 2.036258720796012}. Best is trial 19 with value: 0.9084535529248231.
# [I 2026-02-09 23:41:29,847] Trial 22 finished with value: 0.9090636511446822 and parameters: {'model_name': 'lightgbm', 'n_estimators': 19, 'learning_rate': 0.21353506351219442, 'max_depth': 8, 'subsample': 0.8008516464190732, 'colsample_bytree': 0.8454528341823284}. Best is trial 22 with value: 0.9090636511446822.
# [I 2026-02-09 23:41:35,137] Trial 23 finished with value: 0.9088337839252988 and parameters: {'model_name': 'lightgbm', 'n_estimators': 18, 'learning_rate': 0.2133342483795863, 'max_depth': 8, 'subsample': 0.7925431389270764, 'colsample_bytree': 0.8562626261114974}. Best is trial 22 with value: 0.9090636511446822.
# [I 2026-02-09 23:41:44,138] Trial 24 finished with value: 0.9086567947904625 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.18360684250749928, 'max_depth': 8, 'subsample': 0.754644346416273, 'colsample_bytree': 0.8750992262012025}. Best is trial 22 with value: 0.9090636511446822.
# [I 2026-02-09 23:41:48,978] Trial 25 finished with value: 0.908909163280364 and parameters: {'model_name': 'lightgbm', 'n_estimators': 25, 'learning_rate': 0.1724795723986849, 'max_depth': 8, 'subsample': 0.733118279969001, 'colsample_bytree': 0.9020419592794434}. Best is trial 22 with value: 0.9090636511446822.
# [I 2026-02-09 23:41:57,562] Trial 26 finished with value: 0.9086326132898819 and parameters: {'model_name': 'lightgbm', 'n_estimators': 19, 'learning_rate': 0.16554893769114096, 'max_depth': 6, 'subsample': 0.7147701869244573, 'colsample_bytree': 0.923230262843622}. Best is trial 22 with value: 0.9090636511446822.
# [I 2026-02-09 23:42:02,420] Trial 27 finished with value: 0.9080997006644415 and parameters: {'model_name': 'lightgbm', 'n_estimators': 19, 'learning_rate': 0.12802204151918073, 'max_depth': 6, 'subsample': 0.700714081875538, 'colsample_bytree': 0.9265093984296682}. Best is trial 22 with value: 0.9090636511446822.
# [I 2026-02-09 23:42:11,406] Trial 28 finished with value: 0.9083789644649395 and parameters: {'model_name': 'lightgbm', 'n_estimators': 21, 'learning_rate': 0.1263656411224272, 'max_depth': 6, 'subsample': 0.6783681667311425, 'colsample_bytree': 0.9211729434753579}. Best is trial 22 with value: 0.9090636511446822.
# [I 2026-02-09 23:42:20,463] Trial 29 finished with value: 0.9071939896866109 and parameters: {'model_name': 'xgboost', 'n_estimators': 22, 'max_depth': 8, 'learning_rate': 0.18598817275455076, 'subsample': 0.8797177749926105, 'colsample_bytree': 0.908537314819771}. Best is trial 22 with value: 0.9090636511446822.
# [I 2026-02-09 23:42:29,806] Trial 30 finished with value: 0.9073543234406788 and parameters: {'model_name': 'xgboost', 'n_estimators': 25, 'max_depth': 8, 'learning_rate': 0.18576189726219325, 'subsample': 0.8804847495745546, 'colsample_bytree': 0.9836529415542377}. Best is trial 22 with value: 0.9090636511446822.
# [I 2026-02-09 23:42:34,782] Trial 31 finished with value: 0.8986221896968 and parameters: {'model_name': 'random_forest', 'n_estimators': 24, 'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 22 with value: 0.9090636511446822.
# [I 2026-02-09 23:42:43,742] Trial 32 finished with value: 0.9084099591645941 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.24502637260991825, 'max_depth': 8, 'subsample': 0.7550749648778352, 'colsample_bytree': 0.8705312865388524}. Best is trial 22 with value: 0.9090636511446822.
# [I 2026-02-09 23:42:49,020] Trial 33 finished with value: 0.9077625374648047 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.24808041406757592, 'max_depth': 8, 'subsample': 0.7513301151150854, 'colsample_bytree': 0.8626510177518553}. Best is trial 22 with value: 0.9090636511446822.
# [I 2026-02-09 23:42:57,779] Trial 34 finished with value: 0.9063019120220656 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.019555949012123097, 'max_depth': 8, 'subsample': 0.7654359195040461, 'colsample_bytree': 0.8037741067192589}. Best is trial 22 with value: 0.9090636511446822.
# [I 2026-02-09 23:43:03,025] Trial 35 finished with value: 0.9089510095514611 and parameters: {'model_name': 'lightgbm', 'n_estimators': 23, 'learning_rate': 0.17535078011729802, 'max_depth': 9, 'subsample': 0.7763498112295893, 'colsample_bytree': 0.7938131268707436}. Best is trial 22 with value: 0.9090636511446822.
# [I 2026-02-09 23:43:24,874] Trial 36 finished with value: 0.9029741115880526 and parameters: {'model_name': 'svm', 'C': 0.27568687368492695}. Best is trial 22 with value: 0.9090636511446822.
# [I 2026-02-09 23:43:32,913] Trial 37 finished with value: 0.9026387516302746 and parameters: {'model_name': 'svm', 'C': 0.37674286735525375}. Best is trial 22 with value: 0.9090636511446822.
# [I 2026-02-09 23:43:38,949] Trial 38 finished with value: 0.903696753710534 and parameters: {'model_name': 'random_forest', 'n_estimators': 23, 'max_depth': 9, 'min_samples_split': 7, 'min_samples_leaf': 5}. Best is trial 22 with value: 0.9090636511446822.
# [I 2026-02-09 23:43:46,762] Trial 39 finished with value: 0.9031625388940508 and parameters: {'model_name': 'random_forest', 'n_estimators': 22, 'max_depth': 9, 'min_samples_split': 7, 'min_samples_leaf': 5}. Best is trial 22 with value: 0.9090636511446822.
# [I 2026-02-09 23:43:51,863] Trial 40 finished with value: 0.9083494293405506 and parameters: {'model_name': 'lightgbm', 'n_estimators': 20, 'learning_rate': 0.13630684109917, 'max_depth': 9, 'subsample': 0.8450620608673287, 'colsample_bytree': 0.7978105644895036}. Best is trial 22 with value: 0.9090636511446822.
# [I 2026-02-09 23:44:00,182] Trial 41 finished with value: 0.908037098800453 and parameters: {'model_name': 'lightgbm', 'n_estimators': 20, 'learning_rate': 0.13626727088089738, 'max_depth': 9, 'subsample': 0.8339889881680372, 'colsample_bytree': 0.8047531625103375}. Best is trial 22 with value: 0.9090636511446822.
# [I 2026-02-09 23:44:05,689] Trial 42 finished with value: 0.9085928827824548 and parameters: {'model_name': 'lightgbm', 'n_estimators': 24, 'learning_rate': 0.18249756699968406, 'max_depth': 8, 'subsample': 0.7776247225668053, 'colsample_bytree': 0.886679116996365}. Best is trial 22 with value: 0.9090636511446822.
# [I 2026-02-09 23:44:13,359] Trial 43 finished with value: 0.9086646603366842 and parameters: {'model_name': 'lightgbm', 'n_estimators': 18, 'learning_rate': 0.18314747174665366, 'max_depth': 8, 'subsample': 0.7698569559667364, 'colsample_bytree': 0.8846091496058379}. Best is trial 22 with value: 0.9090636511446822.
# [I 2026-02-09 23:44:19,160] Trial 44 finished with value: 0.9084799987075565 and parameters: {'model_name': 'lightgbm', 'n_estimators': 17, 'learning_rate': 0.2035920062235922, 'max_depth': 7, 'subsample': 0.7348332027116595, 'colsample_bytree': 0.9565034430587284}. Best is trial 22 with value: 0.9090636511446822.
# [I 2026-02-09 23:44:26,916] Trial 45 finished with value: 0.9082680963440876 and parameters: {'model_name': 'lightgbm', 'n_estimators': 17, 'learning_rate': 0.16127798972757007, 'max_depth': 7, 'subsample': 0.7242300887630311, 'colsample_bytree': 0.8374669966410484}. Best is trial 22 with value: 0.9090636511446822.
# [I 2026-02-09 23:44:35,406] Trial 46 finished with value: 0.9064247909173001 and parameters: {'model_name': 'xgboost', 'n_estimators': 17, 'max_depth': 7, 'learning_rate': 0.1577715800036715, 'subsample': 0.6511821643652074, 'colsample_bytree': 0.8233830516440888}. Best is trial 22 with value: 0.9090636511446822.
# [I 2026-02-09 23:44:47,444] Trial 47 finished with value: 0.9059201232955904 and parameters: {'model_name': 'xgboost', 'n_estimators': 16, 'max_depth': 7, 'learning_rate': 0.15767613310391526, 'subsample': 0.6821068670634771, 'colsample_bytree': 0.8952316582003998}. Best is trial 22 with value: 0.9090636511446822.
# [I 2026-02-09 23:44:53,899] Trial 48 finished with value: 0.908457563323609 and parameters: {'model_name': 'lightgbm', 'n_estimators': 15, 'learning_rate': 0.20216055786696824, 'max_depth': 9, 'subsample': 0.5028568631892465, 'colsample_bytree': 0.8962903042179476}. Best is trial 22 with value: 0.9090636511446822.
# [I 2026-02-09 23:44:58,036] Trial 49 finished with value: 0.9086833535581059 and parameters: {'model_name': 'lightgbm', 'n_estimators': 19, 'learning_rate': 0.1960792124655749, 'max_depth': 9, 'subsample': 0.5150726822797663, 'colsample_bytree': 0.7694511597854671}. Best is trial 22 with value: 0.9090636511446822.
# [LightGBM] [Info] Number of positive: 35224, number of negative: 35224
# [LightGBM] [Info] Total Bins 15587
# [LightGBM] [Info] Number of data points in the train set: 70448, number of used features: 225
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2026-02-09 23:45:04,045] A new study created in memory with name: no-name-67cdfdc9-d8b1-49de-ad78-0d95d84795cb
# ==============================
#   Fold Externo 3/5
# ==============================
# [I 2026-02-09 23:45:17,639] Trial 0 finished with value: 0.9047729396584829 and parameters: {'model_name': 'xgboost', 'n_estimators': 6, 'max_depth': 8, 'learning_rate': 0.2506419775767486, 'subsample': 0.715088527323569, 'colsample_bytree': 0.7148734570442585}. Best is trial 0 with value: 0.9047729396584829.
# [I 2026-02-09 23:45:31,459] Trial 2 finished with value: 0.9019808231715519 and parameters: {'model_name': 'random_forest', 'n_estimators': 18, 'max_depth': 9, 'min_samples_split': 10, 'min_samples_leaf': 3}. Best is trial 0 with value: 0.9047729396584829.
# [I 2026-02-09 23:45:34,999] Trial 1 finished with value: 0.9032845323061194 and parameters: {'model_name': 'svm', 'C': 0.4707530853918088}. Best is trial 0 with value: 0.9047729396584829.
# [I 2026-02-09 23:45:43,954] Trial 3 finished with value: 0.8912604174429247 and parameters: {'model_name': 'random_forest', 'n_estimators': 21, 'max_depth': 5, 'min_samples_split': 5, 'min_samples_leaf': 3}. Best is trial 0 with value: 0.9047729396584829.
# [I 2026-02-09 23:45:56,702] Trial 5 finished with value: 0.9087296896823833 and parameters: {'model_name': 'lightgbm', 'n_estimators': 18, 'learning_rate': 0.24915091014289373, 'max_depth': 9, 'subsample': 0.7619497392287444, 'colsample_bytree': 0.9548109500455793}. Best is trial 5 with value: 0.9087296896823833.
# [I 2026-02-09 23:46:11,751] Trial 6 finished with value: 0.9072485268634881 and parameters: {'model_name': 'xgboost', 'n_estimators': 21, 'max_depth': 5, 'learning_rate': 0.18130234997457267, 'subsample': 0.7986999171639786, 'colsample_bytree': 0.7103240240804367}. Best is trial 5 with value: 0.9087296896823833.
# [I 2026-02-09 23:46:19,769] Trial 4 finished with value: 0.9018396891271688 and parameters: {'model_name': 'svm', 'C': 2.999459072873406}. Best is trial 5 with value: 0.9087296896823833.
# [I 2026-02-09 23:46:23,199] Trial 7 finished with value: 0.8882241771778777 and parameters: {'model_name': 'random_forest', 'n_estimators': 7, 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 5}. Best is trial 5 with value: 0.9087296896823833.
# [I 2026-02-09 23:46:36,984] Trial 9 finished with value: 0.9086021364024335 and parameters: {'model_name': 'lightgbm', 'n_estimators': 29, 'learning_rate': 0.26577540930874927, 'max_depth': 4, 'subsample': 0.7448713740545279, 'colsample_bytree': 0.5802334334463511}. Best is trial 5 with value: 0.9087296896823833.
# [I 2026-02-09 23:46:50,948] Trial 8 finished with value: 0.9031376872324522 and parameters: {'model_name': 'svm', 'C': 0.5450540168939941}. Best is trial 5 with value: 0.9087296896823833.
# [I 2026-02-09 23:47:03,726] Trial 11 finished with value: 0.905897527300064 and parameters: {'model_name': 'lightgbm', 'n_estimators': 13, 'learning_rate': 0.023625903978487267, 'max_depth': 7, 'subsample': 0.982663738437987, 'colsample_bytree': 0.9333668859420714}. Best is trial 5 with value: 0.9087296896823833.
# [I 2026-02-09 23:47:04,963] Trial 10 finished with value: 0.9036023685689272 and parameters: {'model_name': 'svm', 'C': 0.346268859730307}. Best is trial 5 with value: 0.9087296896823833.
# [I 2026-02-09 23:47:17,139] Trial 12 finished with value: 0.9090144657421227 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.2957322032410927, 'max_depth': 3, 'subsample': 0.5578860346475235, 'colsample_bytree': 0.5008447751172775}. Best is trial 12 with value: 0.9090144657421227.
# [I 2026-02-09 23:47:18,504] Trial 13 finished with value: 0.9088307926453206 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.2987946278856326, 'max_depth': 3, 'subsample': 0.5327294078855185, 'colsample_bytree': 0.5220314927085127}. Best is trial 12 with value: 0.9090144657421227.
# [I 2026-02-09 23:47:29,668] Trial 14 finished with value: 0.9093310316586055 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.27984354392026956, 'max_depth': 3, 'subsample': 0.5206555627113738, 'colsample_bytree': 0.9799979536949365}. Best is trial 14 with value: 0.9093310316586055.
# [I 2026-02-09 23:47:31,792] Trial 15 finished with value: 0.909239705679496 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.2980528265436101, 'max_depth': 3, 'subsample': 0.5025508315351112, 'colsample_bytree': 0.5023011530392897}. Best is trial 14 with value: 0.9093310316586055.
# [I 2026-02-09 23:47:41,575] Trial 16 finished with value: 0.90854971139367 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.17080149384793464, 'max_depth': 3, 'subsample': 0.5170013106793662, 'colsample_bytree': 0.8366670715680963}. Best is trial 14 with value: 0.9093310316586055.
# [I 2026-02-09 23:47:44,704] Trial 17 finished with value: 0.9089807379236724 and parameters: {'model_name': 'lightgbm', 'n_estimators': 25, 'learning_rate': 0.17544490873486884, 'max_depth': 4, 'subsample': 0.5017806762953679, 'colsample_bytree': 0.8535326459045242}. Best is trial 14 with value: 0.9093310316586055.
# [I 2026-02-09 23:47:54,755] Trial 18 finished with value: 0.9073986487624547 and parameters: {'model_name': 'lightgbm', 'n_estimators': 24, 'learning_rate': 0.08054530060518492, 'max_depth': 5, 'subsample': 0.6297540148088323, 'colsample_bytree': 0.8271616207600587}. Best is trial 14 with value: 0.9093310316586055.
# [I 2026-02-09 23:47:57,422] Trial 19 finished with value: 0.9076572800502363 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.09208398254822128, 'max_depth': 5, 'subsample': 0.6369277297960075, 'colsample_bytree': 0.6367756735328173}. Best is trial 14 with value: 0.9093310316586055.
# [I 2026-02-09 23:48:07,487] Trial 20 finished with value: 0.9040100519747049 and parameters: {'model_name': 'xgboost', 'n_estimators': 13, 'max_depth': 4, 'learning_rate': 0.2158152715860892, 'subsample': 0.6388931728846234, 'colsample_bytree': 0.6413906581839082}. Best is trial 14 with value: 0.9093310316586055.
# [I 2026-02-09 23:48:10,154] Trial 21 finished with value: 0.9054124009461422 and parameters: {'model_name': 'xgboost', 'n_estimators': 13, 'max_depth': 4, 'learning_rate': 0.22026271456826796, 'subsample': 0.638620274027774, 'colsample_bytree': 0.9925709881793982}. Best is trial 14 with value: 0.9093310316586055.
# [I 2026-02-09 23:48:20,869] Trial 22 finished with value: 0.9092605705634377 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.2958032566505039, 'max_depth': 3, 'subsample': 0.5782083183874062, 'colsample_bytree': 0.5057432545295169}. Best is trial 14 with value: 0.9093310316586055.
# [I 2026-02-09 23:48:23,694] Trial 23 finished with value: 0.9086449887709698 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.29997329855631694, 'max_depth': 3, 'subsample': 0.5676843381087917, 'colsample_bytree': 0.5028613141234061}. Best is trial 14 with value: 0.9093310316586055.
# [I 2026-02-09 23:48:34,230] Trial 24 finished with value: 0.9093924892746706 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.2979297603787231, 'max_depth': 3, 'subsample': 0.569268186634526, 'colsample_bytree': 0.5818423226742189}. Best is trial 24 with value: 0.9093924892746706.
# [I 2026-02-09 23:48:37,033] Trial 25 finished with value: 0.9086895690636174 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.2660928707637761, 'max_depth': 3, 'subsample': 0.6075944970673184, 'colsample_bytree': 0.5644287711725904}. Best is trial 24 with value: 0.9093924892746706.
# [I 2026-02-09 23:48:47,810] Trial 26 finished with value: 0.9092577076280822 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.2629443067051111, 'max_depth': 6, 'subsample': 0.5818684201905222, 'colsample_bytree': 0.5906687390185226}. Best is trial 24 with value: 0.9093924892746706.
# [I 2026-02-09 23:48:50,521] Trial 27 finished with value: 0.9097797153889036 and parameters: {'model_name': 'lightgbm', 'n_estimators': 23, 'learning_rate': 0.2208366794636018, 'max_depth': 6, 'subsample': 0.6913485448662269, 'colsample_bytree': 0.6255171735371508}. Best is trial 27 with value: 0.9097797153889036.
# [I 2026-02-09 23:49:00,307] Trial 28 finished with value: 0.9089882436488156 and parameters: {'model_name': 'lightgbm', 'n_estimators': 22, 'learning_rate': 0.21390631365103838, 'max_depth': 4, 'subsample': 0.67853889220556, 'colsample_bytree': 0.780471321771838}. Best is trial 27 with value: 0.9097797153889036.
# [I 2026-02-09 23:49:03,173] Trial 29 finished with value: 0.8959270335803492 and parameters: {'model_name': 'random_forest', 'n_estimators': 23, 'max_depth': 6, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 27 with value: 0.9097797153889036.
# [I 2026-02-09 23:49:12,687] Trial 30 finished with value: 0.8960869652078637 and parameters: {'model_name': 'random_forest', 'n_estimators': 24, 'max_depth': 6, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 27 with value: 0.9097797153889036.
# [I 2026-02-09 23:49:18,234] Trial 31 finished with value: 0.9087484421051096 and parameters: {'model_name': 'xgboost', 'n_estimators': 28, 'max_depth': 7, 'learning_rate': 0.2282332531354427, 'subsample': 0.8286277149503882, 'colsample_bytree': 0.6562145725367879}. Best is trial 27 with value: 0.9097797153889036.
# [I 2026-02-09 23:49:26,894] Trial 32 finished with value: 0.9092799129879025 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.23184750744573907, 'max_depth': 7, 'subsample': 0.8491990514558176, 'colsample_bytree': 0.6384220918839907}. Best is trial 27 with value: 0.9097797153889036.
# [I 2026-02-09 23:49:30,947] Trial 33 finished with value: 0.9086480939973919 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.2779809470421762, 'max_depth': 4, 'subsample': 0.5776315356244568, 'colsample_bytree': 0.553175002141439}. Best is trial 27 with value: 0.9097797153889036.
# [I 2026-02-09 23:49:40,882] Trial 34 finished with value: 0.9093401922660943 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.23653206137227722, 'max_depth': 7, 'subsample': 0.8687104340335299, 'colsample_bytree': 0.6838269175865854}. Best is trial 27 with value: 0.9097797153889036.
# [I 2026-02-09 23:49:43,422] Trial 35 finished with value: 0.9093393245886774 and parameters: {'model_name': 'lightgbm', 'n_estimators': 20, 'learning_rate': 0.2374303847126194, 'max_depth': 7, 'subsample': 0.8607873254430575, 'colsample_bytree': 0.6753488790600898}. Best is trial 27 with value: 0.9097797153889036.
# [I 2026-02-09 23:50:25,317] Trial 36 finished with value: 0.9020122845199948 and parameters: {'model_name': 'svm', 'C': 2.181203466810122}. Best is trial 27 with value: 0.9097797153889036.
# [I 2026-02-09 23:50:25,834] Trial 37 finished with value: 0.901965241969464 and parameters: {'model_name': 'svm', 'C': 2.3627907880707113}. Best is trial 27 with value: 0.9097797153889036.
# [I 2026-02-09 23:50:39,105] Trial 38 finished with value: 0.908808339080303 and parameters: {'model_name': 'lightgbm', 'n_estimators': 16, 'learning_rate': 0.1324518860520949, 'max_depth': 8, 'subsample': 0.8989974331020023, 'colsample_bytree': 0.6836758122623297}. Best is trial 27 with value: 0.9097797153889036.
# [I 2026-02-09 23:50:39,723] Trial 39 finished with value: 0.908780274355396 and parameters: {'model_name': 'lightgbm', 'n_estimators': 16, 'learning_rate': 0.19038666240853547, 'max_depth': 8, 'subsample': 0.8961941183983916, 'colsample_bytree': 0.6971960903417556}. Best is trial 27 with value: 0.9097797153889036.
# [I 2026-02-09 23:50:53,991] Trial 40 finished with value: 0.9022746363479555 and parameters: {'model_name': 'random_forest', 'n_estimators': 19, 'max_depth': 8, 'min_samples_split': 6, 'min_samples_leaf': 5}. Best is trial 27 with value: 0.9097797153889036.
# [I 2026-02-09 23:50:54,712] Trial 41 finished with value: 0.8988119475940165 and parameters: {'model_name': 'random_forest', 'n_estimators': 20, 'max_depth': 7, 'min_samples_split': 6, 'min_samples_leaf': 5}. Best is trial 27 with value: 0.9097797153889036.
# [I 2026-02-09 23:51:07,371] Trial 42 finished with value: 0.9083965974294211 and parameters: {'model_name': 'lightgbm', 'n_estimators': 21, 'learning_rate': 0.2461389830782888, 'max_depth': 7, 'subsample': 0.9028773288180527, 'colsample_bytree': 0.6115861457167524}. Best is trial 27 with value: 0.9097797153889036.
# [I 2026-02-09 23:51:08,632] Trial 43 finished with value: 0.9093123892175722 and parameters: {'model_name': 'lightgbm', 'n_estimators': 22, 'learning_rate': 0.24144345035998413, 'max_depth': 7, 'subsample': 0.911857473476045, 'colsample_bytree': 0.7602075476257737}. Best is trial 27 with value: 0.9097797153889036.
# [I 2026-02-09 23:51:21,270] Trial 44 finished with value: 0.9095406011520648 and parameters: {'model_name': 'lightgbm', 'n_estimators': 25, 'learning_rate': 0.2027436020218372, 'max_depth': 9, 'subsample': 0.9567293849629144, 'colsample_bytree': 0.7653925047352034}. Best is trial 27 with value: 0.9097797153889036.
# [I 2026-02-09 23:51:22,524] Trial 45 finished with value: 0.9093631432240334 and parameters: {'model_name': 'lightgbm', 'n_estimators': 25, 'learning_rate': 0.20241373110614486, 'max_depth': 9, 'subsample': 0.7077339426177092, 'colsample_bytree': 0.7363864516527868}. Best is trial 27 with value: 0.9097797153889036.
# [I 2026-02-09 23:51:34,750] Trial 46 finished with value: 0.9095157853113287 and parameters: {'model_name': 'lightgbm', 'n_estimators': 25, 'learning_rate': 0.2067487106253207, 'max_depth': 9, 'subsample': 0.9619284939412599, 'colsample_bytree': 0.7511048502391333}. Best is trial 27 with value: 0.9097797153889036.
# [I 2026-02-09 23:51:36,053] Trial 47 finished with value: 0.9097021056160481 and parameters: {'model_name': 'lightgbm', 'n_estimators': 25, 'learning_rate': 0.19863747162893217, 'max_depth': 9, 'subsample': 0.6896159801339151, 'colsample_bytree': 0.7403986882627495}. Best is trial 27 with value: 0.9097797153889036.
# [I 2026-02-09 23:51:48,240] Trial 49 finished with value: 0.8983526007785597 and parameters: {'model_name': 'xgboost', 'n_estimators': 5, 'max_depth': 9, 'learning_rate': 0.14772958020893387, 'subsample': 0.997477533727357, 'colsample_bytree': 0.7910491143628726}. Best is trial 27 with value: 0.9097797153889036.
# [I 2026-02-09 23:51:51,703] Trial 48 finished with value: 0.907775595892731 and parameters: {'model_name': 'xgboost', 'n_estimators': 25, 'max_depth': 9, 'learning_rate': 0.20140579062193517, 'subsample': 0.9892459968142622, 'colsample_bytree': 0.7416751048666835}. Best is trial 27 with value: 0.9097797153889036.
# [LightGBM] [Info] Number of positive: 35224, number of negative: 35224
# [LightGBM] [Info] Total Bins 15442
# [LightGBM] [Info] Number of data points in the train set: 70448, number of used features: 226
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2026-02-09 23:51:56,510] A new study created in memory with name: no-name-73421347-4fc5-462c-997f-ad023f2cadd4
# ==============================
#   Fold Externo 4/5
# ==============================
# [I 2026-02-09 23:52:09,542] Trial 0 finished with value: 0.8977140013778134 and parameters: {'model_name': 'random_forest', 'n_estimators': 30, 'max_depth': 4, 'min_samples_split': 5, 'min_samples_leaf': 3}. Best is trial 0 with value: 0.8977140013778134.
# [I 2026-02-09 23:52:23,156] Trial 2 finished with value: 0.9003882098003929 and parameters: {'model_name': 'random_forest', 'n_estimators': 20, 'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 2 with value: 0.9003882098003929.
# [I 2026-02-09 23:52:32,942] Trial 1 finished with value: 0.9026772145352083 and parameters: {'model_name': 'svm', 'C': 1.3978830459969083}. Best is trial 1 with value: 0.9026772145352083.
# [I 2026-02-09 23:52:42,950] Trial 3 finished with value: 0.9069509252423614 and parameters: {'model_name': 'xgboost', 'n_estimators': 20, 'max_depth': 8, 'learning_rate': 0.10621200640623486, 'subsample': 0.9813236629003621, 'colsample_bytree': 0.6397507980168233}. Best is trial 3 with value: 0.9069509252423614.
# [I 2026-02-09 23:52:55,299] Trial 5 finished with value: 0.8901168307242395 and parameters: {'model_name': 'random_forest', 'n_estimators': 23, 'max_depth': 3, 'min_samples_split': 5, 'min_samples_leaf': 4}. Best is trial 3 with value: 0.9069509252423614.
# [I 2026-02-09 23:53:06,998] Trial 6 finished with value: 0.8349680290567575 and parameters: {'model_name': 'random_forest', 'n_estimators': 9, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 3}. Best is trial 3 with value: 0.9069509252423614.
# [I 2026-02-09 23:53:15,117] Trial 4 finished with value: 0.9023605279993215 and parameters: {'model_name': 'svm', 'C': 2.513861629880439}. Best is trial 3 with value: 0.9069509252423614.
# [I 2026-02-09 23:53:44,304] Trial 8 finished with value: 0.9036119225190004 and parameters: {'model_name': 'svm', 'C': 0.45496658474620133}. Best is trial 3 with value: 0.9069509252423614.
# [I 2026-02-09 23:53:53,543] Trial 7 finished with value: 0.9023118990486937 and parameters: {'model_name': 'svm', 'C': 2.7923862418143184}. Best is trial 3 with value: 0.9069509252423614.
# [I 2026-02-09 23:53:58,459] Trial 9 finished with value: 0.9084138684970625 and parameters: {'model_name': 'lightgbm', 'n_estimators': 19, 'learning_rate': 0.10202287550101406, 'max_depth': 7, 'subsample': 0.7224225879637827, 'colsample_bytree': 0.7442599886689609}. Best is trial 9 with value: 0.9084138684970625.
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [I 2026-02-09 23:59:23,519] A new study created in memory with name: no-name-6f58a23a-0508-4cfb-b34f-85f896de63d8
# ==============================
#   Fold Externo 5/5
# ==============================
# [I 2026-02-09 23:59:37,664] Trial 1 finished with value: 0.9091606977040091 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.29762912886928455, 'max_depth': 6, 'subsample': 0.8488898712016959, 'colsample_bytree': 0.619587644357616}. Best is trial 1 with value: 0.9091606977040091.
# [I 2026-02-09 23:59:40,523] Trial 0 finished with value: 0.9077457136301889 and parameters: {'model_name': 'xgboost', 'n_estimators': 16, 'max_depth': 8, 'learning_rate': 0.2597737391439428, 'subsample': 0.5323275070460112, 'colsample_bytree': 0.715459201105583}. Best is trial 1 with value: 0.9091606977040091.
# [I 2026-02-09 23:59:54,271] Trial 2 finished with value: 0.9079971033105968 and parameters: {'model_name': 'xgboost', 'n_estimators': 18, 'max_depth': 9, 'learning_rate': 0.20478326371603925, 'subsample': 0.9198070220922637, 'colsample_bytree': 0.6427195289809329}. Best is trial 1 with value: 0.9091606977040091.
# [I 2026-02-09 23:59:54,883] Trial 3 finished with value: 0.9031739726635571 and parameters: {'model_name': 'random_forest', 'n_estimators': 24, 'max_depth': 8, 'min_samples_split': 7, 'min_samples_leaf': 2}. Best is trial 1 with value: 0.9091606977040091.
# [I 2026-02-10 00:00:09,578] Trial 4 finished with value: 0.8997802741736888 and parameters: {'model_name': 'random_forest', 'n_estimators': 29, 'max_depth': 5, 'min_samples_split': 8, 'min_samples_leaf': 2}. Best is trial 1 with value: 0.9091606977040091.
# [I 2026-02-10 00:00:09,924] Trial 5 finished with value: 0.9048112820420524 and parameters: {'model_name': 'lightgbm', 'n_estimators': 5, 'learning_rate': 0.19939225172585576, 'max_depth': 5, 'subsample': 0.7266695122086007, 'colsample_bytree': 0.6820983454980267}. Best is trial 1 with value: 0.9091606977040091.
# [I 2026-02-10 00:00:23,664] Trial 7 finished with value: 0.8940390248677993 and parameters: {'model_name': 'random_forest', 'n_estimators': 20, 'max_depth': 6, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 1 with value: 0.9091606977040091.
# [I 2026-02-10 00:00:24,449] Trial 6 finished with value: 0.9051602978491692 and parameters: {'model_name': 'xgboost', 'n_estimators': 23, 'max_depth': 5, 'learning_rate': 0.11021366576669446, 'subsample': 0.5849756312755167, 'colsample_bytree': 0.5358635854126488}. Best is trial 1 with value: 0.9091606977040091.
# [I 2026-02-10 00:00:37,720] Trial 8 finished with value: 0.9040203752957483 and parameters: {'model_name': 'random_forest', 'n_estimators': 30, 'max_depth': 7, 'min_samples_split': 6, 'min_samples_leaf': 2}. Best is trial 1 with value: 0.9091606977040091.
# [I 2026-02-10 00:00:38,224] Trial 9 finished with value: 0.9088247592229856 and parameters: {'model_name': 'lightgbm', 'n_estimators': 20, 'learning_rate': 0.08746255845916179, 'max_depth': 9, 'subsample': 0.8038775547057334, 'colsample_bytree': 0.513718680255927}. Best is trial 1 with value: 0.9091606977040091.
# [I 2026-02-10 00:00:54,266] Trial 10 finished with value: 0.9072451619630323 and parameters: {'model_name': 'xgboost', 'n_estimators': 28, 'max_depth': 7, 'learning_rate': 0.10761386727507184, 'subsample': 0.6584063825579511, 'colsample_bytree': 0.5378023031067645}. Best is trial 1 with value: 0.9091606977040091.
# [I 2026-02-10 00:01:07,254] Trial 12 finished with value: 0.9024067543833109 and parameters: {'model_name': 'lightgbm', 'n_estimators': 13, 'learning_rate': 0.049638715389823396, 'max_depth': 4, 'subsample': 0.8609365559306266, 'colsample_bytree': 0.9694789257303683}. Best is trial 1 with value: 0.9091606977040091.
# [I 2026-02-10 00:01:17,874] Trial 11 finished with value: 0.9016397744584704 and parameters: {'model_name': 'svm', 'C': 1.5729719047071649}. Best is trial 1 with value: 0.9091606977040091.
# [I 2026-02-10 00:01:30,445] Trial 14 finished with value: 0.899822189630612 and parameters: {'model_name': 'lightgbm', 'n_estimators': 9, 'learning_rate': 0.014064852538368394, 'max_depth': 3, 'subsample': 0.8113485039543604, 'colsample_bytree': 0.5012357887903472}. Best is trial 1 with value: 0.9091606977040091.
# [I 2026-02-10 00:01:38,302] Trial 13 finished with value: 0.9025949844405646 and parameters: {'model_name': 'svm', 'C': 0.5003198513694278}. Best is trial 1 with value: 0.9091606977040091.
# [I 2026-02-10 00:01:44,254] Trial 15 finished with value: 0.9085038678546851 and parameters: {'model_name': 'lightgbm', 'n_estimators': 24, 'learning_rate': 0.29987918062030183, 'max_depth': 9, 'subsample': 0.9789437202769757, 'colsample_bytree': 0.8449336337771853}. Best is trial 1 with value: 0.9091606977040091.
# [I 2026-02-10 00:01:52,388] Trial 16 finished with value: 0.9085133519383305 and parameters: {'model_name': 'lightgbm', 'n_estimators': 25, 'learning_rate': 0.2980436977576817, 'max_depth': 9, 'subsample': 0.9957673422625438, 'colsample_bytree': 0.8529981602597582}. Best is trial 1 with value: 0.9091606977040091.
# [I 2026-02-10 00:01:57,729] Trial 17 finished with value: 0.9095444336378407 and parameters: {'model_name': 'lightgbm', 'n_estimators': 21, 'learning_rate': 0.13692838516017886, 'max_depth': 7, 'subsample': 0.7945703863620621, 'colsample_bytree': 0.6119415922568162}. Best is trial 17 with value: 0.9095444336378407.
# [I 2026-02-10 00:02:05,233] Trial 18 finished with value: 0.9083315143665222 and parameters: {'model_name': 'lightgbm', 'n_estimators': 20, 'learning_rate': 0.11597347885334451, 'max_depth': 6, 'subsample': 0.7701410040292281, 'colsample_bytree': 0.6113983649083307}. Best is trial 17 with value: 0.9095444336378407.
# [I 2026-02-10 00:02:12,219] Trial 19 finished with value: 0.9096263761142965 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.1693207088636832, 'max_depth': 6, 'subsample': 0.7225324327284111, 'colsample_bytree': 0.5761408270900918}. Best is trial 19 with value: 0.9096263761142965.
# [I 2026-02-10 00:02:18,280] Trial 20 finished with value: 0.9097433071384792 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.17666521377014988, 'max_depth': 7, 'subsample': 0.6995658441305312, 'colsample_bytree': 0.78223459100407}. Best is trial 20 with value: 0.9097433071384792.
# [I 2026-02-10 00:02:32,499] Trial 22 finished with value: 0.9096362314380609 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.16418613990055791, 'max_depth': 7, 'subsample': 0.6893018481207237, 'colsample_bytree': 0.7732857771894032}. Best is trial 20 with value: 0.9097433071384792.
# [I 2026-02-10 00:02:46,209] Trial 23 finished with value: 0.9100510250981421 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.19591106633374214, 'max_depth': 7, 'subsample': 0.6979446301758107, 'colsample_bytree': 0.7936552075066573}. Best is trial 23 with value: 0.9100510250981421.
# [I 2026-02-10 00:02:55,307] Trial 21 finished with value: 0.9013039819821979 and parameters: {'model_name': 'svm', 'C': 2.9305805430993166}. Best is trial 23 with value: 0.9100510250981421.
# [I 2026-02-10 00:03:08,559] Trial 25 finished with value: 0.9098438641352514 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.18414385610140577, 'max_depth': 8, 'subsample': 0.6564871810975073, 'colsample_bytree': 0.7951491796604089}. Best is trial 23 with value: 0.9100510250981421.
# [I 2026-02-10 00:03:22,536] Trial 26 finished with value: 0.9095373754573733 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.21693577868374428, 'max_depth': 8, 'subsample': 0.6286673709395288, 'colsample_bytree': 0.804573217351417}. Best is trial 23 with value: 0.9100510250981421.
# [I 2026-02-10 00:03:29,232] Trial 24 finished with value: 0.9013128213819358 and parameters: {'model_name': 'svm', 'C': 2.8758471176627647}. Best is trial 23 with value: 0.9100510250981421.
# [I 2026-02-10 00:03:35,039] Trial 27 finished with value: 0.9094631052947405 and parameters: {'model_name': 'lightgbm', 'n_estimators': 22, 'learning_rate': 0.24144700499229627, 'max_depth': 8, 'subsample': 0.6084834158469726, 'colsample_bytree': 0.876542751729013}. Best is trial 23 with value: 0.9100510250981421.
# [I 2026-02-10 00:03:43,126] Trial 28 finished with value: 0.9095423314886885 and parameters: {'model_name': 'lightgbm', 'n_estimators': 22, 'learning_rate': 0.2437393518966462, 'max_depth': 8, 'subsample': 0.6040828310607752, 'colsample_bytree': 0.9161583675559527}. Best is trial 23 with value: 0.9100510250981421.
# [I 2026-02-10 00:03:49,162] Trial 29 finished with value: 0.9096292158078093 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.19124025989290075, 'max_depth': 7, 'subsample': 0.6732205296339243, 'colsample_bytree': 0.9146887528414034}. Best is trial 23 with value: 0.9100510250981421.
# [I 2026-02-10 00:03:58,134] Trial 30 finished with value: 0.9063321208161529 and parameters: {'model_name': 'xgboost', 'n_estimators': 16, 'max_depth': 7, 'learning_rate': 0.18430698497384704, 'subsample': 0.6927775568886962, 'colsample_bytree': 0.7529058290521997}. Best is trial 23 with value: 0.9100510250981421.
# [I 2026-02-10 00:04:04,575] Trial 31 finished with value: 0.906230625492135 and parameters: {'model_name': 'xgboost', 'n_estimators': 17, 'max_depth': 7, 'learning_rate': 0.14721665262330103, 'subsample': 0.5428502233388159, 'colsample_bytree': 0.752021970625902}. Best is trial 23 with value: 0.9100510250981421.
# [I 2026-02-10 00:04:11,875] Trial 32 finished with value: 0.9094851549625363 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.15674879493615101, 'max_depth': 7, 'subsample': 0.7081749584223356, 'colsample_bytree': 0.7790089405158553}. Best is trial 23 with value: 0.9100510250981421.
# [I 2026-02-10 00:04:18,511] Trial 33 finished with value: 0.9090524645808772 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.16275604369347554, 'max_depth': 8, 'subsample': 0.6969636060644545, 'colsample_bytree': 0.8024488729745899}. Best is trial 23 with value: 0.9100510250981421.
# [I 2026-02-10 00:04:25,818] Trial 34 finished with value: 0.9093830186854337 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.2222920016035459, 'max_depth': 8, 'subsample': 0.6525528929755525, 'colsample_bytree': 0.8097956515154188}. Best is trial 23 with value: 0.9100510250981421.
# [I 2026-02-10 00:04:32,559] Trial 35 finished with value: 0.9093308151162659 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.21893728490529346, 'max_depth': 8, 'subsample': 0.6439913042599688, 'colsample_bytree': 0.697342453745842}. Best is trial 23 with value: 0.9100510250981421.
# [I 2026-02-10 00:04:39,381] Trial 36 finished with value: 0.909577503142541 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.1790185331745359, 'max_depth': 8, 'subsample': 0.7374385690474544, 'colsample_bytree': 0.705049137005584}. Best is trial 23 with value: 0.9100510250981421.
# [I 2026-02-10 00:04:46,919] Trial 37 finished with value: 0.9094882723165396 and parameters: {'model_name': 'lightgbm', 'n_estimators': 24, 'learning_rate': 0.17574283573025334, 'max_depth': 6, 'subsample': 0.753722811854126, 'colsample_bytree': 0.7207785629027148}. Best is trial 23 with value: 0.9100510250981421.
# [I 2026-02-10 00:04:51,205] Trial 38 finished with value: 0.8853361183281118 and parameters: {'model_name': 'random_forest', 'n_estimators': 13, 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 5}. Best is trial 23 with value: 0.9100510250981421.
# [I 2026-02-10 00:05:03,406] Trial 39 finished with value: 0.8951501106864659 and parameters: {'model_name': 'random_forest', 'n_estimators': 12, 'max_depth': 7, 'min_samples_split': 2, 'min_samples_leaf': 5}. Best is trial 23 with value: 0.9100510250981421.
# [I 2026-02-10 00:05:11,645] Trial 40 finished with value: 0.90267002458029 and parameters: {'model_name': 'random_forest', 'n_estimators': 24, 'max_depth': 7, 'min_samples_split': 2, 'min_samples_leaf': 5}. Best is trial 23 with value: 0.9100510250981421.
# [I 2026-02-10 00:05:19,672] Trial 41 finished with value: 0.9096435648603873 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.12998677060437216, 'max_depth': 7, 'subsample': 0.5488707915464217, 'colsample_bytree': 0.7705168682883307}. Best is trial 23 with value: 0.9100510250981421.
# [I 2026-02-10 00:05:25,325] Trial 42 finished with value: 0.9100789126778349 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.1915914953209147, 'max_depth': 7, 'subsample': 0.6767923281288073, 'colsample_bytree': 0.9289485300952475}. Best is trial 42 with value: 0.9100789126778349.
# [I 2026-02-10 00:05:33,790] Trial 43 finished with value: 0.9094420957845392 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.13346085297420499, 'max_depth': 7, 'subsample': 0.5204057525035709, 'colsample_bytree': 0.7666199989751133}. Best is trial 42 with value: 0.9100789126778349.
# [I 2026-02-10 00:05:39,136] Trial 44 finished with value: 0.9090745923782134 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.1335852049102525, 'max_depth': 5, 'subsample': 0.524893311304746, 'colsample_bytree': 0.8408922340897754}. Best is trial 42 with value: 0.9100789126778349.
# [I 2026-02-10 00:05:47,744] Trial 45 finished with value: 0.9093091041884765 and parameters: {'model_name': 'lightgbm', 'n_estimators': 29, 'learning_rate': 0.26417121497632967, 'max_depth': 5, 'subsample': 0.5716905617133415, 'colsample_bytree': 0.9807306934570804}. Best is trial 42 with value: 0.9100789126778349.
# [I 2026-02-10 00:05:53,445] Trial 46 finished with value: 0.9095498271309626 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.19940665070925417, 'max_depth': 8, 'subsample': 0.5830008473885318, 'colsample_bytree': 0.9930764869850774}. Best is trial 42 with value: 0.9100789126778349.
# [I 2026-02-10 00:06:04,351] Trial 47 finished with value: 0.9087799568534143 and parameters: {'model_name': 'xgboost', 'n_estimators': 28, 'max_depth': 8, 'learning_rate': 0.1953117304131043, 'subsample': 0.560731738752572, 'colsample_bytree': 0.6617697380930981}. Best is trial 42 with value: 0.9100789126778349.
# [I 2026-02-10 00:06:09,589] Trial 48 finished with value: 0.9078154216522094 and parameters: {'model_name': 'xgboost', 'n_estimators': 27, 'max_depth': 6, 'learning_rate': 0.20932863956140702, 'subsample': 0.6290251096277961, 'colsample_bytree': 0.7223531210529099}. Best is trial 42 with value: 0.9100789126778349.
# [I 2026-02-10 00:06:20,663] Trial 49 finished with value: 0.9040664588438432 and parameters: {'model_name': 'svm', 'C': 0.13952863498087598}. Best is trial 42 with value: 0.9100789126778349.
# [LightGBM] [Info] Number of positive: 35224, number of negative: 35224
# [LightGBM] [Info] Total Bins 15479
# [LightGBM] [Info] Number of data points in the train set: 70448, number of used features: 219
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000

# %% [markdown]
# #### Conferir checkpoints intermediarios

# %% [markdown]
# Consolida os resultados da validação cruzada externa em um DataFrame,
# salva o resumo em formato Parquet e carrega os logs das trials do Optuna
# para inspeção e análise do processo de otimização.

# %%
df_results=pd.DataFrame(df_results)
display(df_results)
# Out:
#    fold best_model       auc  accuracy        f1    recall  precision  \
# 0     1   lightgbm  0.906007  0.915351  0.778753  0.740975   0.820590
# 1     2   lightgbm  0.914279  0.915533  0.779017  0.740523   0.821733
# 2     3   lightgbm  0.910006  0.913083  0.773308  0.737365   0.812935
# 3     4   lightgbm  0.909573  0.912992  0.767965  0.716155   0.827856
# 4     5   lightgbm  0.910493  0.915623  0.779202  0.740523   0.822144
#
#                                      hyperparameters  \
# 0  {'model_name': 'lightgbm', 'n_estimators': 25,...
# 1  {'model_name': 'lightgbm', 'n_estimators': 19,...
# 2  {'model_name': 'lightgbm', 'n_estimators': 23,...
# 3  {'model_name': 'lightgbm', 'n_estimators': 26,...
# 4  {'model_name': 'lightgbm', 'n_estimators': 27,...
#
#                                  checkpoint_path  train_time_seconds  \
# 0  checkpoints_best_models/best_model_fold_1.pkl            4.948162
# 1  checkpoints_best_models/best_model_fold_2.pkl            5.828392
# 2  checkpoints_best_models/best_model_fold_3.pkl            4.638143
# 3  checkpoints_best_models/best_model_fold_4.pkl            4.718088
# 4  checkpoints_best_models/best_model_fold_5.pkl            5.432179
#
#                  trials_log_path
# 0  log_opt/trials_log_fold_1.csv
# 1  log_opt/trials_log_fold_2.csv
# 2  log_opt/trials_log_fold_3.csv
# 3  log_opt/trials_log_fold_4.csv
# 4  log_opt/trials_log_fold_5.csv

# %%
df_results.to_parquet('df_results.parquet')

# %% [markdown]
# Carregando o pkl

# %%
import joblib

modelo = joblib.load("checkpoints_best_models/best_model_fold_1.pkl")

# %%
modelo
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['NU_IDADE_N',
#                                                    'periodo_chuvoso',
#                                                    'vulnerabilidade_social']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='infrequent_if_...
#                                                    'CLI_OUTROS', 'CLI_PANTUR',
#                                                    'CLI_PROST', 'CON_AMBIEN',
#                                                    'CON_AREA', 'CS_ESCOL_N',
#                                                    'ID_OCUPA_N',
#                                                    'nivel_vulnerabilidade'])])),
#                 ('smote', SMOTE(random_state=42)),
#                 ('model',
#                  LGBMClassifier(colsample_bytree=0.5936091736192096,
#                                 device='cpu', force_col_wise=True,
#                                 is_unbalance=True,
#                                 learning_rate=0.13959387224784825, max_depth=8,
#                                 n_estimators=25, random_state=42,
#                                 subsample=0.6159536393908984))])

# %%
modelo.named_steps["preprocessor"].get_feature_names_out()
# Out:
# array(['num__NU_IDADE_N', 'num__periodo_chuvoso',
#        'num__vulnerabilidade_social', ...,
#        'cat__nivel_vulnerabilidade_Alta',
#        'cat__nivel_vulnerabilidade_Baixa',
#        'cat__nivel_vulnerabilidade_Moderada'], dtype=object)

# %%
modelo.predict(X_data.iloc[-10:])
# Out:
# array([1, 1, 0, 0, 1, 1, 1, 0, 1, 1])

# %% [markdown]
# ## Avaliação de desempenho e custo computacional
#
# Nesta seção são avaliados os modelos selecionados ao longo dos folds da validação cruzada externa,
# considerando simultaneamente **qualidade preditiva** e **custo computacional**.
# Essa análise conjunta é fundamental para evitar escolhas baseadas apenas em desempenho,
# desconsiderando viabilidade prática de treinamento e manutenção do modelo.
#
# ### Métricas de desempenho preditivo
#
# O desempenho dos modelos é avaliado por meio de múltiplas métricas,
# permitindo uma análise abrangente do comportamento preditivo:
#
# - **ROC-AUC (OvR, weighted)**: métrica principal de comparação, pois avalia a capacidade de separação entre classes
# em cenários multiclasse e desbalanceados, utilizando probabilidades preditas.
# - **Accuracy**: fornece uma visão global de acerto, mas pode ser influenciada por classes majoritárias.
# - **F1-score (weighted)**: equilibra precisão e recall, sendo mais informativo quando há assimetria entre classes.
# - **Recall (weighted)**: mede a capacidade do modelo em identificar corretamente instâncias relevantes,
# importante em contextos onde falsos negativos possuem maior custo.
# - **Precision (weighted)**: avalia a confiabilidade das predições positivas,
# sendo relevante quando falsos positivos impactam decisões downstream.
#
# A análise por fold permite verificar não apenas o valor médio das métricas,
# mas também sua **estabilidade**, reduzindo o risco de overfitting a uma partição específica dos dados.

# %%
def read_and_consolidate_optuna_logs(
    log_dir: str = "log_opt",
    pattern: str = "trials_log_fold_*.csv",
    fold_col_name: str = "outer_fold",
    keep_only_complete: bool = True,
) -> pd.DataFrame:
    """
    Lê todos os arquivos de log do Optuna (1 por fold) e consolida em um único DataFrame.

    Espera arquivos no formato: trials_log_fold_{k}.csv (gerados por dump_trials).

    Parâmetros
    ----------
    log_dir : str
        Diretório onde os logs estão salvos.
    pattern : str
        Padrão dos arquivos dentro do log_dir.
    fold_col_name : str
        Nome da coluna que será criada para identificar o fold externo.
    keep_only_complete : bool
        Se True, mantém apenas trials com state == 'COMPLETE' (quando existir essa coluna).

    Retorna
    -------
    pd.DataFrame
        DataFrame consolidado com colunas originais + coluna de fold.
    """
    path_pattern = os.path.join(log_dir, pattern)
    files = sorted(glob.glob(path_pattern))

    if not files:
        raise FileNotFoundError(f"Nenhum arquivo encontrado em: {path_pattern}")

    dfs = []
    for fp in files:
        df = pd.read_csv(fp)

        # Extrai fold do nome do arquivo (ex.: trials_log_fold_3.csv -> 3)
        m = re.search(r"fold_(\d+)", os.path.basename(fp))
        fold = int(m.group(1)) if m else None

        df[fold_col_name] = fold
        df["source_file"] = os.path.basename(fp)

        # Normaliza duration se estiver como string do tipo "0 days 00:00:12.345"
        if "duration" in df.columns:
            try:
                df["duration"] = pd.to_timedelta(df["duration"])
                df["duration_seconds"] = df["duration"].dt.total_seconds()
            except Exception:
                pass

        dfs.append(df)

    df_all = pd.concat(dfs, ignore_index=True)

    # Ordenação útil (se existir)
    sort_cols = [c for c in [fold_col_name, "number"] if c in df_all.columns]
    if sort_cols:
        df_all = df_all.sort_values(sort_cols).reset_index(drop=True)

    return df_all


df_metrics = read_and_consolidate_optuna_logs(log_dir="log_opt", keep_only_complete=True)

# 2. Basic overview
print("=== Shape of DataFrame ===")
print(df_metrics.shape)

display(df_metrics)
# Out:
# === Shape of DataFrame ===
# (250, 16)
#      number     value  params_C  params_colsample_bytree  \
# 0         0  0.909716       NaN                 0.811841
# 1         1  0.905094       NaN                 0.967808
# 2         2  0.909023       NaN                 0.846171
# 3         3  0.904577       NaN                 0.779039
# 4         4  0.902241  1.955699                      NaN
# ..      ...       ...       ...                      ...
# 245      45  0.909309       NaN                 0.980731
# 246      46  0.909550       NaN                 0.993076
# 247      47  0.908780       NaN                 0.661770
# 248      48  0.907815       NaN                 0.722353
# 249      49  0.904066  0.139529                      NaN
#
#      params_learning_rate  params_max_depth  params_min_samples_leaf  \
# 0                0.109576               7.0                      NaN
# 1                0.117578               3.0                      NaN
# 2                0.277284               6.0                      NaN
# 3                0.249124               5.0                      NaN
# 4                     NaN               NaN                      NaN
# ..                    ...               ...                      ...
# 245              0.264171               5.0                      NaN
# 246              0.199407               8.0                      NaN
# 247              0.195312               8.0                      NaN
# 248              0.209329               6.0                      NaN
# 249                   NaN               NaN                      NaN
#
#      params_min_samples_split params_model_name  params_n_estimators  \
# 0                         NaN          lightgbm                 21.0
# 1                         NaN          lightgbm                 21.0
# 2                         NaN           xgboost                 22.0
# 3                         NaN           xgboost                 12.0
# 4                         NaN               svm                  NaN
# ..                        ...               ...                  ...
# 245                       NaN          lightgbm                 29.0
# 246                       NaN          lightgbm                 28.0
# 247                       NaN           xgboost                 28.0
# 248                       NaN           xgboost                 27.0
# 249                       NaN               svm                  NaN
#
#      params_subsample     state               duration  outer_fold  \
# 0            0.561284  COMPLETE 0 days 00:00:14.417553           1
# 1            0.870839  COMPLETE 0 days 00:00:12.996966           1
# 2            0.582051  COMPLETE 0 days 00:00:14.747542           1
# 3            0.931365  COMPLETE 0 days 00:00:13.770112           1
# 4                 NaN  COMPLETE 0 days 00:00:40.474005           1
# ..                ...       ...                    ...         ...
# 245          0.571691  COMPLETE 0 days 00:00:13.933088           5
# 246          0.583001  COMPLETE 0 days 00:00:14.289700           5
# 247          0.560732  COMPLETE 0 days 00:00:16.591900           5
# 248          0.629025  COMPLETE 0 days 00:00:16.126587           5
# 249               NaN  COMPLETE 0 days 00:00:16.295018           5
#
#                source_file  duration_seconds
# 0    trials_log_fold_1.csv         14.417553
# 1    trials_log_fold_1.csv         12.996966
# 2    trials_log_fold_1.csv         14.747542
# 3    trials_log_fold_1.csv         13.770112
# 4    trials_log_fold_1.csv         40.474005
# ..                     ...               ...
# 245  trials_log_fold_5.csv         13.933088
# 246  trials_log_fold_5.csv         14.289700
# 247  trials_log_fold_5.csv         16.591900
# 248  trials_log_fold_5.csv         16.126587
# 249  trials_log_fold_5.csv         16.295018
#
# [250 rows x 16 columns]

# %%
# Total de trials por modelo
total_trials = (df_metrics.groupby("params_model_name").size().reset_index(name="total_trials"))

plt.figure(figsize=(8, 6))
sns.barplot(data=total_trials,x="params_model_name",y="total_trials",)
plt.title("Total de tentativas por modelo")
plt.xlabel("Modelo")
plt.ylabel("Tentativas")
plt.tight_layout()
plt.show()

# %%
# Gráfico das tentativas de modelos completas e abortadas
counts_state = df_metrics.groupby(["params_model_name", "state"]).size().reset_index(name="count")

plt.figure(figsize=(8, 6))
sns.barplot(data=counts_state,x="params_model_name",y="count",hue="state",)
plt.title("Resultado das tentativas entre Pruned e Complete")
plt.xlabel("Modelo")
plt.ylabel("Número de tentativas")
plt.tight_layout()
plt.show()

# %%
# Distribuição de performance (value) por modelo
plt.figure(figsize=(8, 6))
sns.boxplot(data=df_metrics, x="params_model_name", y="value")
plt.title("Desempenho por modelo")
plt.xlabel("Modelo")
plt.ylabel("Área por baixo da curva ROC (AUC)")
plt.tight_layout()
plt.show()

# %%
# Duração média de treino por modelo
df_metrics["duration_sec"] = pd.to_timedelta(df_metrics["duration"]).dt.total_seconds()
mean_duration = df_metrics.groupby("params_model_name")["duration_sec"].mean().reset_index()

# Distribuição do tempo de processamento por modelo

plt.figure(figsize=(8, 6))
sns.boxplot(data=df_metrics, x="params_model_name", y="duration_sec")
plt.title("Média do tempo de treinamento por modelo")
plt.xlabel("Modelo")
plt.ylabel("Segundos")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Treinamento do modelo final

# %%
df_hyper =pd.DataFrame(df_results['hyperparameters'].to_list())
df_hyper
# Out:
#   model_name  n_estimators  learning_rate  max_depth  subsample  \
# 0   lightgbm            25       0.139594          8   0.615954
# 1   lightgbm            19       0.213535          8   0.800852
# 2   lightgbm            23       0.220837          6   0.691349
# 3   lightgbm            26       0.206667          5   0.503097
# 4   lightgbm            27       0.191591          7   0.676792
#
#    colsample_bytree
# 0          0.593609
# 1          0.845453
# 2          0.625517
# 3          0.519312
# 4          0.928949

# %%
final_params=df_hyper.iloc[:,1:].median().to_dict()
final_params
# Out:
# {'n_estimators': 25.0,
#  'learning_rate': 0.2066673338942078,
#  'max_depth': 7.0,
#  'subsample': 0.6767923281288073,
#  'colsample_bytree': 0.6255171735371508}

# %%
def cast_params(params: dict) -> dict:
    p = dict(params)  # cópia

    # chaves que devem ser int no LightGBM
    int_keys = {
        "n_estimators", "num_iterations",
        "max_depth", "num_leaves",
        "min_child_samples", "min_data_in_leaf",
        "max_bin",
        "bagging_freq",
    }

    for k in list(p.keys()):
        if k in int_keys and p[k] is not None and not (isinstance(p[k], bool)):
            p[k] = int(round(float(p[k])))

    # max_depth: LightGBM aceita -1 como "sem limite"
    if "max_depth" in p and p["max_depth"] is not None:
        p["max_depth"] = int(p["max_depth"])

    return p

final_params = cast_params(final_params)
final_params
# Out:
# {'n_estimators': 25,
#  'learning_rate': 0.2066673338942078,
#  'max_depth': 7,
#  'subsample': 0.6767923281288073,
#  'colsample_bytree': 0.6255171735371508}

# %%
# Dicionário base para reconstrução
models = {
    'RandomForest': RandomForestClassifier(random_state=42),
    'XGBoost': xgb.XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42),
    'LightGBM': lgb.LGBMClassifier(random_state=42),
    'SVM': CalibratedClassifierCV(LinearSVC( random_state=42))
}

# %%
# Reconstruir modelo
final_model = models['LightGBM']
final_model.set_params(**final_params)

cat_cols, num_cols = get_feature_types(X_data)

final_pipeline = build_pipeline(final_model, cat_cols, num_cols)

# %% [markdown]
# ### Avaliando modelo final

# %% [markdown]
# ## Interpretabilidade: importância de variáveis após pré-processamento (OHE) e mapeamento para colunas originais
#
# Modelos treinados sobre pipelines com `ColumnTransformer` e `OneHotEncoder` operam em um espaço de features
# expandido (múltiplas colunas por variável categórica). Para manter interpretabilidade, esta seção:
# 1) recupera os nomes finais das features no espaço transformado,
# 2) extrai uma medida de importância/coeficiente do modelo treinado,
# 3) mapeia as features transformadas de volta para as variáveis originais,
# 4) consolida a importância no nível da coluna original.
#
# Isso permite reportar resultados em termos das variáveis do dataset original, facilitando comunicação e análise.

# %% [markdown]
# ### Extração de nomes das features pós-`ColumnTransformer`
#
# A função `get_feature_names` reconstrói o vetor de nomes de features gerado após o pré-processamento,
# incluindo:
# - variáveis numéricas (após imputação/escala),
# - variáveis categóricas expandidas via One-Hot Encoding,
# - e, opcionalmente, colunas passadas via `remainder='passthrough'`.
#
# Essa etapa é necessária porque, após o `fit_transform`, a matriz final perde o vínculo direto com o nome
# das colunas originais, e a identificação correta das features é condição para qualquer análise de importância.

# %%
# 1. FUNÇÃO PARA EXTRAIR NOMES DAS FEATURES PÓS-OHE
def get_feature_names(column_transformer):
    """
    Extrai nomes finais das features após ColumnTransformer,
    incluindo OneHotEncoder e transformações numéricas.
    """
    output_features = []

    for name, transformer, features in column_transformer.transformers_:

        # Caso 'remainder=passthrough'
        if name == "remainder":
            output_features.extend(features)
            continue

        # Transformers com get_feature_names_out() (OneHotEncoder, etc)
        if hasattr(transformer, "get_feature_names_out"):
            try:
                names = transformer.get_feature_names_out(features)
            except:
                names = transformer.get_feature_names_out()
            output_features.extend(names)

        # Caso não possua o método
        else:
            output_features.extend(features)

    return output_features

# %% [markdown]
# ### Mapeamento para variáveis originais via fuzzy matching
#
# Após o One-Hot Encoding, uma mesma variável categórica pode gerar dezenas de colunas com nomes derivados.
# Para consolidar resultados no nível da variável original, é aplicado *fuzzy matching* entre o nome da feature
# pós-OHE e a lista de variáveis originais de interesse (`features_explicativas`).
#
# O objetivo do fuzzy matching é lidar com diferenças de sufixos/prefixos criados pelo encoding e manter
# um vínculo prático entre “feature transformada” e “coluna original”. O parâmetro `threshold`
# controla o quão estrita é a correspondência:
# - valores maiores reduzem falsos positivos (match errado),
# - valores menores aumentam cobertura, mas elevam risco de mapeamentos incorretos.
#
# Após o matching, apenas features com correspondência válida são mantidas para agregação.

# %%
def fuzzy_match_original(feature_name, triage_features, threshold=70):
    """
    Realiza fuzzy matching buscando qual variável ORIGINAL
    está mais relacionada com o nome da feature pós-OHE.
    """
    best_match, score, _ = process.extractOne(
        feature_name,
        triage_features,
        scorer=fuzz.partial_ratio
    )
    return best_match if score >= threshold else None

# %% [markdown]
# ## Validação cruzada externa: avaliação e interpretabilidade por fold
#
# Nesta etapa, aplica-se uma `StratifiedKFold` externa para avaliar o desempenho do pipeline e também
# inspecionar a importância de variáveis por fold. A estratificação preserva a proporção das classes,
# reduzindo instabilidade em bases desbalanceadas.
#
# Para cada fold:
# - o pipeline final é treinado no conjunto de treino,
# - a importância das features é extraída do modelo treinado,
# - as importâncias são consolidadas no nível da variável original e visualizadas,
# - e o desempenho é medido no conjunto de teste com métricas e curvas.

# %%
# =========================
# Parâmetros
# =========================
n_splits = 4
top_k = 20        # top features por fold (para tabelas)
top_overall = 30  # top features gerais (para tabela final)

outer_cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

# =========================
# Coletores (tabelas)
# =========================
fold_metrics = []          # 1 linha por fold com métricas + conf matrix flatten
fold_top_features = []     # top_k features por fold (já agrupadas em original_var)
all_features_long = []     # todas features (agrupadas) por fold -> resumo geral

fold = 1
for train_idx, test_idx in outer_cv.split(X_data, y_data):

    print(f"\n==============================")
    print(f"  Fold Externo {fold}/{n_splits}")
    print(f"==============================")

    X_train, X_test = X_data.iloc[train_idx], X_data.iloc[test_idx]
    y_train, y_test = y_data.iloc[train_idx], y_data.iloc[test_idx]

    # =========================
    # 1) Fit do pipeline no fold
    # =========================
    final_pipeline.fit(X_train, y_train)

    # =========================
    # 2) Importâncias
    # =========================
    model = final_pipeline.named_steps["model"]

    if hasattr(model, "feature_importances_"):
        importances = model.feature_importances_
    elif hasattr(model, "coef_"):
        coef = model.coef_
        # binary: (n_features,) ou (1, n_features)
        # multiclass: (n_classes, n_features) -> agregamos por média do abs
        importances = coef.ravel() if coef.ndim == 1 else np.mean(np.abs(coef), axis=0)
    else:
        raise ValueError("Este modelo não possui atributo de importância (feature_importances_ ou coef_).")

    # =========================
    # 3) Nomes pós-preprocessamento
    # =========================
    preproc = final_pipeline.named_steps["preprocessor"]
    feature_names = get_feature_names(preproc)

    if len(feature_names) != len(importances):
        raise ValueError(
            f"Mismatch: {len(feature_names)} nomes de features vs {len(importances)} importâncias. "
            "Cheque get_feature_names() / preprocessor."
        )

    df_imp = pd.DataFrame({"feature": feature_names, "importance": importances})

    # =========================
    # 4) Fuzzy match para variáveis originais e agregação
    # =========================
    df_imp["original_var"] = df_imp["feature"].apply(lambda x: fuzzy_match_original(x, triage_features))
    df_imp = df_imp[df_imp["original_var"].notna()].copy()

    df_grouped = (
        df_imp.groupby("original_var", as_index=False)["importance"]
              .sum()
              .sort_values("importance", ascending=False)
              .rename(columns={"original_var": "feature"})
              .reset_index(drop=True)
    )

    # =========================
    # 4.1) Plot: Feature importance (por fold)
    # =========================
    plt.figure(figsize=(6, 14))
    plt.barh(df_grouped["feature"][::-1], df_grouped["importance"][::-1])
    plt.xlabel("Importância (agregada por variável original)")
    plt.title(f"Feature importance – {type(model).__name__} – Fold {fold}")
    plt.tight_layout()
    plt.show()

    # guarda top features do fold (top_k)
    df_top = df_grouped.head(top_k).copy()
    df_top["fold"] = fold
    df_top["rank_in_fold"] = np.arange(1, len(df_top) + 1)
    fold_top_features.append(df_top)

    # guarda TODAS as features agregadas do fold (para resumo geral)
    df_grouped_long = df_grouped.copy()
    df_grouped_long["fold"] = fold
    all_features_long.append(df_grouped_long)

    # =========================
    # 5) Predições / probabilidades
    # =========================
    y_pred = final_pipeline.predict(X_test)

    y_proba = None
    if hasattr(final_pipeline, "predict_proba"):
        try:
            y_proba = final_pipeline.predict_proba(X_test)[:, 1]
        except Exception:
            y_proba = None

    # =========================
    # 6) Matriz de confusão (plot)
    # =========================
    cm = confusion_matrix(y_test, y_pred)

    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.title(f"Matriz de Confusão – Fold {fold}")
    plt.xlabel("Predito")
    plt.ylabel("Real")
    plt.tight_layout()
    plt.show()

    # =========================
    # 7) Métricas (plot + tabela)
    # =========================
    metrics_dict_plot = {
        "Accuracy": accuracy_score(y_test, y_pred),
        "Precision": precision_score(y_test, y_pred, zero_division=0),
        "Recall": recall_score(y_test, y_pred, zero_division=0),
        "F1 Score": f1_score(y_test, y_pred, zero_division=0),
        "AUC": roc_auc_score(y_test, y_proba) if y_proba is not None else np.nan
    }

    plt.figure(figsize=(8, 5))
    sns.barplot(x=list(metrics_dict_plot.keys()), y=list(metrics_dict_plot.values()), palette="Set2")
    plt.ylim(0, 1.05)
    plt.title(f"Métricas de Classificação – Fold {fold}")
    for i, v in enumerate(metrics_dict_plot.values()):
        if np.isfinite(v):
            plt.text(i, v + 0.02, f"{v:.2f}", ha='center')
        else:
            plt.text(i, 0.02, "NA", ha='center')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    # salva métricas estruturadas (para df_metrics)
    fold_metrics.append({
        "fold": fold,
        "n_train": len(train_idx),
        "n_test": len(test_idx),
        "accuracy": metrics_dict_plot["Accuracy"],
        "precision": metrics_dict_plot["Precision"],
        "recall": metrics_dict_plot["Recall"],
        "f1": metrics_dict_plot["F1 Score"],
        "auc": metrics_dict_plot["AUC"],
        "tn": cm[0, 0], "fp": cm[0, 1], "fn": cm[1, 0], "tp": cm[1, 1],
        "model_name": type(model).__name__,
    })

    # =========================
    # 8) Curva ROC (plot)
    # =========================
    if y_proba is not None:
        fpr, tpr, _ = roc_curve(y_test, y_proba)
        roc_auc = auc(fpr, tpr)

        plt.figure(figsize=(6, 5))
        plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.2f}")
        plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
        plt.xlabel("Falso Positivo")
        plt.ylabel("Verdadeiro Positivo")
        plt.title(f"Curva ROC – Fold {fold}")
        plt.legend(loc='lower right')
        plt.grid(True)
        plt.tight_layout()
        plt.show()

    # =========================
    # 9) Curva Precision-Recall (plot)
    # =========================
    if y_proba is not None:
        precision, recall, _ = precision_recall_curve(y_test, y_proba)
        auprc_trap = auc(recall, precision)

        plt.figure(figsize=(6, 5))
        plt.plot(recall, precision, label=f"AUPRC = {auprc_trap:.2f}")
        plt.xlabel("Recall")
        plt.ylabel("Precision")
        plt.title(f"Curva Precision-Recall – Fold {fold}")
        plt.legend(loc='lower right')
        plt.grid(True)
        plt.tight_layout()
        plt.show()

    fold += 1


# =========================
# 10) DF: métricas por fold
# =========================
df_metrics = pd.DataFrame(fold_metrics).sort_values("fold").reset_index(drop=True)

# resumo (média e desvio padrão) das métricas
metric_cols = ["accuracy", "precision", "recall", "f1", "auc"]
df_metrics_summary = (
    df_metrics[metric_cols]
    .agg(["mean", "std"])
    .T
    .rename(columns={"mean": "mean", "std": "std"})
    .reset_index()
    .rename(columns={"index": "metric"})
)

# =========================
# 11) DF: top features por fold
# =========================
df_top_by_fold = pd.concat(fold_top_features, ignore_index=True)

# =========================
# 12) DF: resumo geral das features (média/std + rank)
# =========================
df_all_features_long = pd.concat(all_features_long, ignore_index=True)

df_feature_summary = (
    df_all_features_long
    .groupby("feature", as_index=False)
    .agg(
        mean_importance=("importance", "mean"),
        std_importance=("importance", "std"),
        folds_present=("fold", "nunique"),
    )
)

# ranking médio por fold (quanto menor, mais importante)
df_ranks = (
    df_all_features_long
    .assign(rank_in_fold=lambda d: d.groupby("fold")["importance"].rank(ascending=False, method="average"))
)

df_rank_summary = (
    df_ranks.groupby("feature", as_index=False)
            .agg(mean_rank=("rank_in_fold", "mean"), std_rank=("rank_in_fold", "std"))
)

df_feature_summary = (
    df_feature_summary.merge(df_rank_summary, on="feature", how="left")
                      .sort_values(["mean_importance", "folds_present"], ascending=[False, False])
                      .reset_index(drop=True)
)

df_top_features_overall = df_feature_summary.head(top_overall).copy()

# =========================
# 13) OUTPUT final (tabelas)
# =========================
print("\n\n==============================")
print("MÉTRICAS POR FOLD")
print("==============================")
display(df_metrics)

print("\n\n==============================")
print("RESUMO GERAL DAS MÉTRICAS (média e desvio padrão)")
print("==============================")
display(df_metrics_summary)

print("\n\n==============================")
print(f"TOP {top_k} FEATURES POR FOLD (agregadas em variável original)")
print("==============================")
display(df_top_by_fold.sort_values(["fold", "rank_in_fold"]))

print("\n\n==============================")
print(f"TOP {top_overall} FEATURES GERAIS (média/std das importâncias + estabilidade via rank)")
print("==============================")
display(df_top_features_overall)

# Se quiser salvar:
# df_metrics.to_csv("cv_metrics_by_fold.csv", index=False)
# df_metrics_summary.to_csv("cv_metrics_summary.csv", index=False)
# df_top_by_fold.to_csv("cv_top_features_by_fold.csv", index=False)
# df_feature_summary.to_csv("cv_feature_importance_summary.csv", index=False)
# Out:
# ==============================
#   Fold Externo 1/4
# ==============================
# [LightGBM] [Info] Number of positive: 33022, number of negative: 33022
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.086830 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 15322
# [LightGBM] [Info] Number of data points in the train set: 66044, number of used features: 222
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# ==============================
#   Fold Externo 2/4
# ==============================
# [LightGBM] [Info] Number of positive: 33022, number of negative: 33022
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.084581 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 15222
# [LightGBM] [Info] Number of data points in the train set: 66044, number of used features: 210
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# ==============================
#   Fold Externo 3/4
# ==============================
# [LightGBM] [Info] Number of positive: 33023, number of negative: 33023
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.086683 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 15253
# [LightGBM] [Info] Number of data points in the train set: 66046, number of used features: 217
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# ==============================
#   Fold Externo 4/4
# ==============================
# [LightGBM] [Info] Number of positive: 33023, number of negative: 33023
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.092576 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 15199
# [LightGBM] [Info] Number of data points in the train set: 66046, number of used features: 215
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# ==============================
# MÉTRICAS POR FOLD
# ==============================
#    fold  n_train  n_test  accuracy  precision    recall        f1       auc  \
# 0     1    41332   13778  0.914574   0.827105  0.727076  0.773871  0.905401
# 1     2    41332   13778  0.917840   0.832656  0.740072  0.783639  0.915296
# 2     3    41333   13777  0.913334   0.815958  0.734657  0.773176  0.911372
# 3     4    41333   13777  0.913842   0.820575  0.731408  0.773430  0.909329
#
#       tn   fp   fn    tp      model_name
# 0  10587  421  756  2014  LGBMClassifier
# 1  10596  412  720  2050  LGBMClassifier
# 2  10548  459  735  2035  LGBMClassifier
# 3  10564  443  744  2026  LGBMClassifier
# ==============================
# RESUMO GERAL DAS MÉTRICAS (média e desvio padrão)
# ==============================
#       metric      mean       std
# 0   accuracy  0.914897  0.002027
# 1  precision  0.824074  0.007325
# 2     recall  0.733303  0.005478
# 3         f1  0.776029  0.005081
# 4        auc  0.910349  0.004125
# ==============================
# TOP 20 FEATURES POR FOLD (agregadas em variável original)
# ==============================
#                    feature  importance  fold  rank_in_fold
# 0               ID_OCUPA_N         189     1             1
# 1               CS_ESCOL_N         107     1             2
# 2               NU_IDADE_N          79     1             3
# 3               CON_AMBIEN          76     1             4
# 4               ANT_CB_LAM          62     1             5
# 5                 CON_AREA          52     1             6
# 6               CLI_ICTERI          50     1             7
# 7               CLI_PANTUR          48     1             8
# 8               CLI_OUTROS          33     1             9
# 9                CLI_PROST          23     1            10
# 10  vulnerabilidade_social          14     1            11
# 11   nivel_vulnerabilidade          13     1            12
# 12         periodo_chuvoso           4     1            13
# 13              ID_OCUPA_N         194     2             1
# 14              CS_ESCOL_N         108     2             2
# 15              CLI_ICTERI          69     2             3
# 16              ANT_CB_LAM          68     2             4
# 17              CLI_PANTUR          59     2             5
# 18              CON_AMBIEN          57     2             6
# 19              NU_IDADE_N          56     2             7
# 20                CON_AREA          52     2             8
# 21              CLI_OUTROS          31     2             9
# 22               CLI_PROST          30     2            10
# 23   nivel_vulnerabilidade          10     2            11
# 24  vulnerabilidade_social           9     2            12
# 25         periodo_chuvoso           7     2            13
# 26              ID_OCUPA_N         174     3             1
# 27              CS_ESCOL_N         117     3             2
# 28              CLI_ICTERI          74     3             3
# 29              ANT_CB_LAM          71     3             4
# 30              NU_IDADE_N          66     3             5
# 31              CON_AMBIEN          63     3             6
# 32                CON_AREA          55     3             7
# 33              CLI_PANTUR          38     3             8
# 34              CLI_OUTROS          34     3             9
# 35               CLI_PROST          25     3            10
# 36  vulnerabilidade_social          18     3            11
# 37         periodo_chuvoso           8     3            12
# 38   nivel_vulnerabilidade           7     3            13
# 39              ID_OCUPA_N         190     4             1
# 40              CS_ESCOL_N          93     4             2
# 41              NU_IDADE_N          77     4             3
# 42              CON_AMBIEN          71     4             4
# 43              CLI_ICTERI          69     4             5
# 44              ANT_CB_LAM          67     4             6
# 45                CON_AREA          47     4             7
# 46              CLI_PANTUR          46     4             8
# 47              CLI_OUTROS          32     4             9
# 48               CLI_PROST          27     4            10
# 49  vulnerabilidade_social          17     4            11
# 50   nivel_vulnerabilidade           8     4            12
# 51         periodo_chuvoso           6     4            13
# ==============================
# TOP 30 FEATURES GERAIS (média/std das importâncias + estabilidade via rank)
# ==============================
#                    feature  mean_importance  std_importance  folds_present  \
# 0               ID_OCUPA_N           186.75        8.770215              4
# 1               CS_ESCOL_N           106.25        9.912114              4
# 2               NU_IDADE_N            69.50       10.661457              4
# 3               ANT_CB_LAM            67.00        3.741657              4
# 4               CON_AMBIEN            66.75        8.421203              4
# 5               CLI_ICTERI            65.50       10.598742              4
# 6                 CON_AREA            51.50        3.316625              4
# 7               CLI_PANTUR            47.75        8.655441              4
# 8               CLI_OUTROS            32.50        1.290994              4
# 9                CLI_PROST            26.25        2.986079              4
# 10  vulnerabilidade_social            14.50        4.041452              4
# 11   nivel_vulnerabilidade             9.50        2.645751              4
# 12         periodo_chuvoso             6.25        1.707825              4
#
#     mean_rank  std_rank
# 0        1.00  0.000000
# 1        2.00  0.000000
# 2        4.50  1.914854
# 3        4.75  0.957427
# 4        5.00  1.154701
# 5        4.50  1.914854
# 6        7.00  0.816497
# 7        7.25  1.500000
# 8        9.00  0.000000
# 9       10.00  0.000000
# 10      11.25  0.500000
# 11      12.00  0.816497
# 12      12.75  0.500000

# %% [markdown]
# ### Salvando checkpoints do colab no drive

# %% [markdown]
# Salvar metricas

# %%
src = "/content/checkpoints_best_models"
dst = f"/content/drive/MyDrive/ITA/TCC/Resultados/{experimento}/checkpoints_best_models"

os.makedirs(os.path.dirname(dst), exist_ok=True)
shutil.copytree(src, dst, dirs_exist_ok=True)
# Out:
# '/content/drive/MyDrive/ITA/TCC/Resultados/confirmados_descartados_comFeatureSelection/checkpoints_best_models'

# %% [markdown]
# Salvar modelos

# %%
src = "/content/log_opt"
dst = f"/content/drive/MyDrive/ITA/TCC/Resultados/{experimento}/log_opt"

os.makedirs(os.path.dirname(dst), exist_ok=True)
shutil.copytree(src, dst, dirs_exist_ok=True)
# Out:
# '/content/drive/MyDrive/ITA/TCC/Resultados/confirmados_descartados_comFeatureSelection/log_opt'
