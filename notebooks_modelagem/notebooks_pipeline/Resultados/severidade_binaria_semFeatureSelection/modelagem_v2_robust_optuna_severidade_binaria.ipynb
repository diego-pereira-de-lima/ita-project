# %%
# !pip uninstall xgboost -y
# Out:
# Found existing installation: xgboost 3.1.1
# Uninstalling xgboost-3.1.1:
#   Successfully uninstalled xgboost-3.1.1

# %%
# !pip install optuna xgboost==3.1.1 lightgbm fastparquet imbalanced-learn torch rapidfuzz
# Out:
# Requirement already satisfied: optuna in /usr/local/lib/python3.12/dist-packages (4.8.0)
# Collecting xgboost==3.1.1
#   Using cached xgboost-3.1.1-py3-none-manylinux_2_28_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.12/dist-packages (4.6.0)
# Requirement already satisfied: fastparquet in /usr/local/lib/python3.12/dist-packages (2026.3.0)
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.12/dist-packages (0.14.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.10.0+cpu)
# Requirement already satisfied: rapidfuzz in /usr/local/lib/python3.12/dist-packages (3.14.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from xgboost==3.1.1) (2.0.2)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.12/dist-packages (from xgboost==3.1.1) (2.29.7)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from xgboost==3.1.1) (1.16.3)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.18.4)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.12/dist-packages (from optuna) (6.10.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (26.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.48)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: pandas>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from fastparquet) (2.2.2)
# Requirement already satisfied: cramjam>=2.3 in /usr/local/lib/python3.12/dist-packages (from fastparquet) (2.11.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from fastparquet) (2025.3.0)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (1.6.1)
# Requirement already satisfied: sklearn-compat<0.2,>=0.1.5 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (0.1.5)
# Requirement already satisfied: joblib<2,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->fastparquet) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->fastparquet) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->fastparquet) (2025.3)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.3.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->fastparquet) (1.17.0)
# Using cached xgboost-3.1.1-py3-none-manylinux_2_28_x86_64.whl (115.9 MB)
# Installing collected packages: xgboost
# Successfully installed xgboost-3.1.1

# %%
import numpy as np
import pandas as pd
import os, joblib,time
from functools import partial

from sklearn.model_selection import StratifiedKFold, cross_val_score,train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.calibration import CalibratedClassifierCV

import optuna
from optuna.pruners import SuccessiveHalvingPruner
from optuna.exceptions import TrialPruned

#from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.impute import SimpleImputer
from functools import partial

from __future__ import annotations

from sklearn.model_selection import KFold, StratifiedKFold, cross_val_score
from sklearn.feature_selection import VarianceThreshold, SelectKBest
from sklearn.feature_selection import mutual_info_classif, mutual_info_regression
from sklearn.feature_selection import f_classif, f_regression

from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.multiclass import OneVsRestClassifier, OneVsOneClassifier

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler

from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, confusion_matrix, matthews_corrcoef,
    cohen_kappa_score, balanced_accuracy_score,
    classification_report, brier_score_loss, log_loss,
    confusion_matrix, ConfusionMatrixDisplay,
    precision_recall_curve, RocCurveDisplay,roc_curve,auc
)

from sklearn.calibration import calibration_curve


from imblearn.pipeline import Pipeline
from imblearn.over_sampling import RandomOverSampler, SMOTE
from imblearn.under_sampling import RandomUnderSampler

import matplotlib.pyplot as plt
import seaborn as sns

import subprocess
import xgboost as xgb
import lightgbm as lgb
#import torch

import re
from rapidfuzz import fuzz, process

import os
import re
import glob
import pandas as pd

import shutil
import os
from google.colab import drive


import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Configurando salvamento de checkpoints no Drive
#
# Montando o drive e acessando a conta para poder conseguir salvar os checkpoints ao final do processamento

# %%
drive.mount('/content/drive')
experimento = 'severidade_binaria_semFeatureSelection'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Carregando base de dados

# %% [markdown]
# Carregamento do conjunto de dados processado a partir de um arquivo no formato Parquet.
# Esse formato colunar é otimizado para leitura eficiente, reduz uso de memória e preserva os tipos de dados,
# sendo adequado para pipelines analíticos e etapas posteriores de modelagem.

# %%
df =pd.read_parquet('df_hepat_processed_v1.parquet',engine='fastparquet')

# %% [markdown]
# ### Selecionar variáveis relevantes para triagem

# %% [markdown]
# Definição das variáveis explicativas e da variável alvo utilizadas no modelo.
# As features incluem características sociodemográficas, condições ambientais, antecedentes clínicos e sintomas,
# além de variáveis derivadas de vulnerabilidade social e sazonalidade, enquanto a variável alvo representa a severidade do caso.

# %%
features_explicativas = [
    'NU_IDADE_N','CS_SEXO','CS_GESTANT','CS_RACA','CS_ESCOL_N',
    'ID_OCUPA_N','CON_AREA','CON_AMBIEN',
    'ANT_CB_LAM','ANT_CB_CRI','ANT_CB_SIN','ANT_CB_COR','ANT_CB_ROE',
    'ANT_CB_TER','ANT_CB_LIX','ANT_CB_OUT','ANT_ANIMAI','ANT_HUMANO',
    'CLI_FEBRE','CLI_MIALGI','CLI_CEFALE','CLI_PROST','CLI_CONGES',
    'CLI_PANTUR','CLI_VOMITO','CLI_DIARRE','CLI_OUTROS','SG_UF', 'baixa_escolaridade','raca_vulneravel','faixa_vulneravel',
    'vulnerabilidade_social', 'nivel_vulnerabilidade','mes_sintomas','estacao', 'periodo_chuvoso'
]

target = 'SEVERIDADE'

# %% [markdown]
# #### Classificação da Severidade da Leptospirose
#
# * Classifica a severidade clínica dos casos de leptospirose com base em critérios médicos descritos na literatura, distinguindo entre formas leve, moderada e grave.
# * Cria variáveis auxiliares para identificar comprometimento de órgãos graves (respiratório, cardíaco e sistema nervoso central) e presença de hemorragias.
# * Define critérios de gravidade a partir da combinação de sinais clínicos como hemorragia pulmonar, disfunção renal associada, icterícia e envolvimento de múltiplos órgãos.
# * Identifica casos moderados a partir de manifestações como icterícia isolada, comprometimento renal leve e hemorragias cutâneas.
# * Converte a classificação categórica de severidade em rótulos numéricos (0 = Leve, 1 = Moderado, 2 = Grave), tornando a variável adequada para uso em modelos de machine learning.
# * Remove colunas clínicas e variáveis auxiliares utilizadas exclusivamente na lógica de classificação, garantindo um DataFrame final mais limpo e focado na modelagem.

# %%
import numpy as np
import pandas as pd

def classificar_severidade_leptospirose_binaria(
    df: pd.DataFrame,
    positive_value: str = "Sim",
    negative_value: str = "Não",
    drop_aux: bool = True,
    out_col: str = "SEVERIDADE",
):
    """
    Classifica leptospirose em 2 classes:
      - Grave (1): sinais compatíveis com formas graves (p.ex., hemorragia pulmonar/insuf. respiratória,
                  Weil (icterícia + renal), meningite/meningoencefalite, miocardite/arritmias/colapso circulatório,
                  sangramento relevante com disfunção orgânica)
      - Leve  (0): demais casos

    Convenção:
      - Entradas esperadas nas colunas clínicas: "Sim"/"Não" (ajustável por parâmetros)
      - Saída: out_col = 1 (Grave) ou 0 (Leve)

    Referências clínicas (alto nível):
      - Formas graves incluem: Weil (icterícia + insuf. renal + hemorragia/miocardite), meningite/encefalite,
        e hemorragia pulmonar com insuficiência respiratória. :contentReference[oaicite:1]{index=1}
    """

    df = df.copy()

    # --------- util: padronizar Sim/Não e tratar ausência de colunas ----------
    expected_cols = [
        "CLI_RESPIR",  # comprometimento respiratório importante / insuficiência respiratória / ARDS
        "CLI_HEMOPU",  # hemorragia pulmonar
        "CLI_HEMORR",  # hemorragia (cutânea/outros sangramentos)
        "CLI_CARDIA",  # miocardite/arritmias/comprometimento cardíaco
        "CLI_MENING",  # meningite/meningoencefalite
        "CLI_ICTERI",  # icterícia
        "CLI_RENAL",   # disfunção renal / IRA
        # se você tiver choque/hipotensão/DIC em outras colunas, dá para incorporar também
    ]

    for c in expected_cols:
        if c not in df.columns:
            df[c] = negative_value

    # normaliza strings (caso venha "sim", "SIM", etc.)
    def _norm(v):
        if pd.isna(v):
            return negative_value
        s = str(v).strip()
        if s.lower() == str(positive_value).lower():
            return positive_value
        if s.lower() == str(negative_value).lower():
            return negative_value
        # se vier 1/0 como string, tenta mapear
        if s in ("1", "True", "true"):
            return positive_value
        if s in ("0", "False", "false"):
            return negative_value
        return s

    for c in expected_cols:
        df[c] = df[c].map(_norm)

    # --------- flags auxiliares ----------
    orgao_critico = (
        (df["CLI_RESPIR"] == positive_value) |
        (df["CLI_CARDIA"] == positive_value) |
        (df["CLI_MENING"] == positive_value)
    )

    sangramento_relevante = (
        (df["CLI_HEMOPU"] == positive_value) |   # hemorragia pulmonar é particularmente associada a gravidade
        (df["CLI_HEMORR"] == positive_value)
    )

    weil_sindrome = (
        (df["CLI_ICTERI"] == positive_value) &
        (df["CLI_RENAL"] == positive_value)
    )
    # Weil (icterícia + renal, frequentemente com sangramento/comprometimento sistêmico) é forma clássica grave :contentReference[oaicite:2]{index=2}

    # --------- critérios de GRAVIDADE (binário) ----------
    criterio_grave = (
        # 1) Hemorragia pulmonar / síndrome hemorrágica pulmonar severa / insuf. respiratória :contentReference[oaicite:3]{index=3}
        (df["CLI_HEMOPU"] == positive_value) |
        (df["CLI_RESPIR"] == positive_value) |

        # 2) SNC (meningite/encefalite) :contentReference[oaicite:4]{index=4}
        (df["CLI_MENING"] == positive_value) |

        # 3) Cardíaco (miocardite/arritmias/colapso) :contentReference[oaicite:5]{index=5}
        (df["CLI_CARDIA"] == positive_value) |

        # 4) Síndrome de Weil (icterícia + renal) :contentReference[oaicite:6]{index=6}
        weil_sindrome |

        # 5) Sangramento + disfunção de órgão crítico (captura “hemorragia + órgão” como marcador de gravidade)
        (sangramento_relevante & orgao_critico) |

        # 6) Renal + órgão crítico (coocorrência sugere maior gravidade clínica)
        ((df["CLI_RENAL"] == positive_value) & orgao_critico)
    )

    df[out_col] = np.where(criterio_grave, 1, 0)

    # opcional: manter rastreabilidade do porquê (útil em artigo / auditoria)
    df["FLAG_ORGAO_CRITICO"] = orgao_critico.astype(int)
    df["FLAG_SANGRAMENTO"] = sangramento_relevante.astype(int)
    df["FLAG_WEIL"] = weil_sindrome.astype(int)

    if drop_aux:
        df.drop(
            ["FLAG_ORGAO_CRITICO", "FLAG_SANGRAMENTO", "FLAG_WEIL"],
            axis=1,
            inplace=True,
            errors="ignore"
        )

    return df

# %%
df_feat_select=classificar_severidade_leptospirose_binaria(df)

# %% [markdown]
# ### Filtrar casos positivos
# Pelo fato da análise ser devido a severidade dos casos positivos iremos filtrar apenas estes para não incluir ruido amostral na base de treinamento

# %%
df_feat_select=df_feat_select[df_feat_select['CLASSI_FIN']=='Confirmado']

# %% [markdown]
# ### Amostragem estratificada dos dados
#
# Nesta etapa é realizada uma amostragem estratificada da base de dados,
# preservando a proporção das classes da variável alvo.
# O procedimento consiste em aplicar uma amostragem aleatória dentro de cada classe,
# extraindo uma fração representativa do conjunto original.
#
# Em seguida, a base amostrada é separada em variáveis explicativas (X)
# e variável resposta (y), que serão utilizadas nas etapas subsequentes de modelagem.
#
# Essa abordagem reduz o volume de dados processados,
# mantendo a representatividade estatística das classes e garantindo reprodutibilidade
# por meio do uso de uma semente aleatória fixa.

# %%
## Amostragem estratificada
amostragem = df_feat_select.groupby(target).sample(frac=1, random_state=42).copy()

X_data=amostragem[features_explicativas]
y_data = amostragem[target]

# %%
y_data.unique()
# Out:
# array([0, 1])

# %%
X_data.shape
# Out:
# (31658, 36)

# %% [markdown]
# ## Pipeline de seleção de variáveis com suporte a tarefas (binária, multiclasse e regressão)
#
# Esta seção implementa um pipeline completo de *feature selection* que funciona para problemas de
# classificação (binária e multiclasse) e regressão. O fluxo combina pré-processamento (numérico e categórico),
# múltiplos métodos de seleção em camadas (filter → embedded → wrapper) e, ao final, reconcilia as variáveis
# selecionadas no espaço transformado com seus nomes originais no dataset.
#
# A motivação é obter um conjunto final de variáveis com bom poder preditivo e maior estabilidade,
# evitando depender de um único critério (ex.: apenas mutual information ou apenas importância de árvore),
# e garantindo rastreabilidade entre “features após encoding” e “colunas originais”.
#
# ### Detecção automática do tipo de tarefa e escolha de validação cruzada
#
# Antes da seleção, o pipeline identifica se o problema é de classificação ou regressão a partir do parâmetro `task`.
# Com isso, define automaticamente o esquema de validação cruzada:
# - **StratifiedKFold** para classificação, preservando a proporção de classes em cada fold;
# - **KFold** para regressão, adequado quando não há estratificação por rótulo.
#
# Além disso, é definido um *scoring* padrão coerente com cada cenário (ex.: AUC-ROC para binário,
# F1-macro para multiclasse, e RMSE negativo para regressão), reduzindo risco de escolhas inconsistentes
# na avaliação do wrapper.

# %%
# -------------------------
# Helpers: task detection
# -------------------------
def _is_classification(task: str) -> bool:
    return task.lower() in ["binary", "multiclass", "classification", "clf"]

def _is_multiclass(task: str) -> bool:
    return task.lower() == "multiclass"

def _make_cv(y, task: str, n_splits: int = 5, random_state: int = 42):
    if _is_classification(task):
        return StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=random_state)
    return KFold(n_splits=n_splits, shuffle=True, random_state=random_state)

def _default_scoring(task: str) -> str:
    t = task.lower()
    if t == "binary":
        return "roc_auc"
    if t == "multiclass":
        return "f1_macro"
    if t in ["regression", "reg"]:
        return "neg_root_mean_squared_error"
    # fallback
    return "f1_macro" if _is_classification(task) else "neg_root_mean_squared_error"

def _selectkbest_score_func(task: str):
    return mutual_info_classif if _is_classification(task) else mutual_info_regression

def _anova_score_func(task: str):
    return f_classif if _is_classification(task) else f_regression

# %% [markdown]
# ### Identificação e pré-processamento de variáveis numéricas e categóricas
#
# Nesta etapa, as colunas são separadas por tipo:
# - categóricas (object/category/bool),
# - numéricas (np.number).
#
# Em seguida, aplica-se um pré-processamento unificado via `ColumnTransformer`:
# - **StandardScaler** para variáveis numéricas (normalização para modelos lineares e métricas);
# - **OneHotEncoder** para variáveis categóricas, com `handle_unknown="ignore"` para robustez.
#
# O resultado é uma matriz de features totalmente numérica, adequada para métodos de seleção e modelos do scikit-learn.

# %%
# ------------------------------------------------
# Preprocess: detect column types (customize here)
# ------------------------------------------------
def get_feature_types(X: pd.DataFrame):
    cat_cols = X.select_dtypes(include=["object", "category", "bool"]).columns.tolist()
    num_cols = X.select_dtypes(include=[np.number]).columns.tolist()
    return cat_cols, num_cols


# -------------------------------------------------------
# Mapping transformed -> original (robust for '_' in names)
# -------------------------------------------------------
def map_transformed_to_original_robust(feature_names_after_preproc, cat_cols):
    cat_cols_sorted = sorted(cat_cols, key=len, reverse=True)  # longest first
    orig = []

    for fn in feature_names_after_preproc:
        if "__" in fn:
            block, rest = fn.split("__", 1)
        else:
            block, rest = "remainder", fn

        if block == "cat":
            matched = None
            for c in cat_cols_sorted:
                if rest == c or rest.startswith(c + "_"):
                    matched = c
                    break
            orig.append(matched if matched is not None else rest.split("_", 1)[0])
        else:
            orig.append(rest)

    return np.array(orig)

# %% [markdown]
# ### Seleção wrapper com validação cruzada (desempenho real por feature)
#
# Como etapa final, aplica-se um *wrapper* que avalia cada variável individualmente usando validação cruzada.
# Ou seja, cada feature é testada em um modelo preditivo simples (Linear/Logistic),
# e é medido o desempenho médio (scoring) ao longo dos folds.
#
# A lógica do wrapper é aproximar o critério de seleção do objetivo final do projeto: desempenho preditivo,
# reduzindo o risco de selecionar variáveis “estatisticamente relevantes” mas com baixo ganho prático no modelo.
#
# O ranking final (`variaveis_finais`) corresponde às `final_wrapper` variáveis com melhor performance no wrapper.

# %%
def _make_wrapper_model(task: str, multiclass_strategy: str = "multinomial", random_state: int = 42):
    """
    multiclass_strategy:
      - "multinomial": LogisticRegression(multi_class="multinomial")
      - "ovr": OneVsRestClassifier(LogisticRegression(...))
      - "ovo": OneVsOneClassifier(LogisticRegression(...))
    """
    t = task.lower()
    m = multiclass_strategy.lower()

    if _is_classification(t):
        base_lr = LogisticRegression(
            max_iter=4000,
            solver="lbfgs",
            n_jobs=None,  # lbfgs ignores n_jobs
        )

        if t == "multiclass":
            if m == "multinomial":
                return LogisticRegression(max_iter=4000, solver="lbfgs", multi_class="multinomial")
            if m == "ovr":
                return OneVsRestClassifier(base_lr)
            if m == "ovo":
                return OneVsOneClassifier(base_lr)
            raise ValueError("multiclass_strategy must be one of: 'multinomial', 'ovr', 'ovo'")

        # binary
        return LogisticRegression(max_iter=4000, solver="lbfgs")

    # regression
    return LinearRegression()

# %% [markdown]
# ### Estratégias para classificação multiclasse: multinomial, OvR e OvO
#
# Para problemas multiclasse, o pipeline permite três estratégias:
# - **multinomial**: regressão logística multiclasse nativa (softmax),
# - **OvR (One-vs-Rest)**: treina um classificador por classe contra o resto,
# - **OvO (One-vs-One)**: treina classificadores para cada par de classes.
#
# A estratégia pode influenciar a avaliação do wrapper (principalmente com F1-macro),
# pois altera como o modelo aprende fronteiras de decisão e lida com classes minoritárias.
#
# ## Pipeline
#
# O pipeline retorna:
# - a matriz processada (`X_processado_df`) e nomes de features após pré-processamento,
# - rankings por método (Mutual Information, ANOVA/F-regression, Random Forest e Wrapper),
# - lista final de variáveis selecionadas no espaço transformado,
# - lista consolidada de variáveis no espaço original (para interpretação),
# - ranking agregado no nível da feature original (melhor score do wrapper entre suas dummies).
#
# Com isso, é possível:
# - justificar tecnicamente a seleção,
# - reproduzir resultados,
# - e comunicar as variáveis relevantes com interpretabilidade.

# %%
def pipeline_selecao_variaveis(
    X: pd.DataFrame,
    y: pd.Series,
    task: str = "binary",              # "binary", "multiclass", "regression"
    var_threshold: float = 0.0,
    k_mi: int = 80,
    k_anova: int = 80,
    top_rf: int = 50,
    final_wrapper: int = 20,
    scoring_wrapper: str | None = None,
    n_splits: int = 5,
    random_state: int = 42,
    multiclass_strategy: str = "multinomial",  # "multinomial", "ovr", "ovo"
):
    # 1) baixa variância
    selector_var = VarianceThreshold(threshold=var_threshold)
    selector_var.fit(X)
    cols_var = X.columns[selector_var.get_support()]
    X1 = X[cols_var]

    # 2) mutual info (rank)
    score_func_mi = _selectkbest_score_func(task)
    if score_func_mi is mutual_info_classif:
        selector_mi = SelectKBest(
            score_func=lambda X_, y_: mutual_info_classif(X_, y_, random_state=random_state),
            k=min(k_mi, X1.shape[1])
        )
    else:
        selector_mi = SelectKBest(score_func=mutual_info_regression, k=min(k_mi, X1.shape[1]))

    selector_mi.fit(X1, y)
    cols_mi = X1.columns[selector_mi.get_support()]
    scores_mi = selector_mi.scores_[selector_mi.get_support()]

    mi_rank = (pd.DataFrame({"variavel": cols_mi, "score_mutual_info": scores_mi})
               .sort_values("score_mutual_info", ascending=False))

    # 3) anova / f-regression (rank)
    score_func_anova = _anova_score_func(task)
    selector_anova = SelectKBest(score_func=score_func_anova, k=min(k_anova, X1.shape[1]))
    selector_anova.fit(X1, y)

    cols_anova = X1.columns[selector_anova.get_support()]
    scores_anova = selector_anova.scores_[selector_anova.get_support()]

    col_score = "score_anova_f" if _is_classification(task) else "score_f_regression"
    anova_rank = (pd.DataFrame({"variavel": cols_anova, col_score: scores_anova})
                  .sort_values(col_score, ascending=False))

    # candidatos (ordem: MI depois ANOVA; sem duplicar)
    candidatos = list(dict.fromkeys(mi_rank["variavel"].tolist() + anova_rank["variavel"].tolist()))
    Xcand = X1[candidatos] if len(candidatos) else X1.copy()

    # 4) RF importance (rank)
    if _is_classification(task):
        rf = RandomForestClassifier(
            n_estimators=400,
            random_state=random_state,
            n_jobs=-1
        )
    else:
        rf = RandomForestRegressor(
            n_estimators=400,
            random_state=random_state,
            n_jobs=-1
        )

    rf.fit(Xcand, y)

    rf_rank = (pd.DataFrame({"variavel": Xcand.columns, "importancia": rf.feature_importances_})
               .sort_values("importancia", ascending=False))

    vars_rf = rf_rank.head(min(top_rf, rf_rank.shape[0]))["variavel"].tolist()

    # 5) wrapper CV (rank) — mede desempenho real por feature (univariado)
    if scoring_wrapper is None:
        scoring_wrapper = _default_scoring(task)

    cv = _make_cv(y, task, n_splits=n_splits, random_state=random_state)
    model = _make_wrapper_model(task, multiclass_strategy=multiclass_strategy, random_state=random_state)

    resultados = []
    for var in vars_rf:
        score = cross_val_score(model, X1[[var]], y, cv=cv, scoring=scoring_wrapper).mean()
        resultados.append((var, score))

    wrap_rank = (pd.DataFrame(resultados, columns=["variavel", scoring_wrapper])
                 .sort_values(scoring_wrapper, ascending=False)
                 .head(min(final_wrapper, len(resultados))))

    return {
        "X_filtrado": X1,
        "ranking_mutual_info": mi_rank,
        "ranking_anova_ou_freg": anova_rank,
        "ranking_rf": rf_rank,
        "ranking_wrapper": wrap_rank,
        "variaveis_finais": wrap_rank["variavel"].tolist(),
        "scoring_wrapper": scoring_wrapper,
    }

# %% [markdown]
# ### Selecionando as variáveis automaticamente
#
# Esta função orquestra um pipeline completo de preparação e seleção de variáveis a partir de um `DataFrame` original,
# suportando tarefas de **classificação (binária/multiclasse)** e **regressão**.
#
# O fluxo é composto por três blocos principais:
#
# 1) **Detecção de tipos de variáveis**
# As colunas de entrada são separadas em **categóricas** e **numéricas** (via `get_feature_types_fn`),
# permitindo aplicar transformações apropriadas a cada tipo.
#
# 2) **Pré-processamento com `ColumnTransformer`**
# - Variáveis numéricas são padronizadas com `StandardScaler`, garantindo escala comparável para métodos e modelos lineares.
# - Variáveis categóricas são transformadas via `OneHotEncoder(handle_unknown="ignore")`, produzindo uma representação numérica robusta.
# Há um tratamento de compatibilidade entre versões do scikit-learn (`sparse_output` vs `sparse`).
#
# O resultado é uma matriz totalmente numérica no “espaço transformado”, acompanhada dos nomes das features geradas (`get_feature_names_out`).
#
# 3) **Seleção de variáveis no espaço transformado + mapeamento para o espaço original**
# A seleção é delegada para `pipeline_selecao_variaveis`, que ranqueia e filtra features usando múltiplos critérios
# (filtros estatísticos, importância por Random Forest e wrapper com validação cruzada).
#
# Como o One-Hot Encoding fragmenta variáveis categóricas em múltiplas colunas, a função reconstrói a rastreabilidade
# mapeando cada feature transformada para sua **coluna original** (`map_transformed_to_original_robust`).
# Além disso, é gerado um ranking agregado por feature original (max do score do wrapper entre suas dummies),
# facilitando interpretação e comunicação dos resultados.
#
# A função retorna tanto artefatos do pré-processamento (preprocessor, matriz transformada) quanto rankings e listas finais
# de variáveis selecionadas no espaço transformado e no espaço original.

# %%
def selecionar_variaveis_auto(
    X_data: pd.DataFrame,
    y_data: pd.Series,
    task: str = "binary",
    multiclass_strategy: str = "multinomial",   # multinomial | ovr | ovo
    scoring_wrapper: str | None = None,
    get_feature_types_fn=get_feature_types,
    var_threshold: float = 0.0,
    k_mi: int = 80,
    k_anova: int = 80,
    top_rf: int = 50,
    final_wrapper: int = 20,
    n_splits: int = 5,
    random_state: int = 42,
    remainder: str = "drop",  # "drop" ou "passthrough"
):
    # 1) tipos
    cat_cols, num_cols = get_feature_types_fn(X_data)

    # 2) preprocessor
    # compatibilidade entre versões sklearn:
    # em versões antigas, OneHotEncoder usa sparse=False; nas novas, sparse_output=False
    try:
        ohe = OneHotEncoder(handle_unknown="ignore", sparse_output=False)
    except TypeError:
        ohe = OneHotEncoder(handle_unknown="ignore", sparse=False)

    preprocessor = ColumnTransformer(
        transformers=[
            ("num", StandardScaler(), num_cols),
            ("cat", ohe, cat_cols),
        ],
        remainder=remainder
    )

    # 3) fit/transform
    X_processed = preprocessor.fit_transform(X_data)
    feature_names = preprocessor.get_feature_names_out()

    X_processed_df = pd.DataFrame(X_processed, columns=feature_names, index=X_data.index)

    # 4) seleção no espaço transformado
    selected = pipeline_selecao_variaveis(
        X_processed_df,
        y_data,
        task=task,
        var_threshold=var_threshold,
        k_mi=k_mi,
        k_anova=k_anova,
        top_rf=top_rf,
        final_wrapper=final_wrapper,
        scoring_wrapper=scoring_wrapper,
        n_splits=n_splits,
        random_state=random_state,
        multiclass_strategy=multiclass_strategy,
    )

    # 5) map back transformed -> original
    transformed_to_original = map_transformed_to_original_robust(feature_names, cat_cols)
    map_dict = dict(zip(feature_names, transformed_to_original))

    vars_transformadas = selected["variaveis_finais"]
    vars_originais = sorted({str(map_dict[v]) for v in vars_transformadas if v in map_dict})

    # agregação opcional: score do wrapper por feature original
    scoring_col = selected["ranking_wrapper"].columns[1]
    df_wrap = selected["ranking_wrapper"].copy()
    df_wrap["feature_original"] = df_wrap["variavel"].map(map_dict)

    ranking_original = (
        df_wrap.groupby("feature_original", dropna=False)[scoring_col]
        .max()
        .sort_values(ascending=False)
        .reset_index()
        .rename(columns={scoring_col: f"{scoring_col}_max"})
    )

    return {
        "preprocessor": preprocessor,
        "X_processado_df": X_processed_df,
        "feature_names_after_preproc": feature_names,
        "resultado_selecao_transformado": selected,
        "variaveis_finais_transformadas": vars_transformadas,
        "variaveis_finais_originais": vars_originais,
        "ranking_wrapper_por_feature_original": ranking_original,
        "cat_cols": cat_cols,
        "num_cols": num_cols,
        "map_transformada_para_original": map_dict,
    }

# %%
var_selected = selecionar_variaveis_auto(
     X_data, y_data,
     task="binary",
     scoring_wrapper="f1",
)

print(f"Variáveis selecionadas({len(var_selected["variaveis_finais_originais"])} variáveis):{var_selected["variaveis_finais_originais"]}")
print(f"Variáveis Originais({len(X_data.columns)} variáveis):{X_data.columns}")
# Out:
# Variáveis selecionadas(16 variáveis):['ANT_CB_CRI', 'ANT_CB_LAM', 'ANT_CB_SIN', 'CLI_CEFALE', 'CLI_CONGES', 'CLI_OUTROS', 'CLI_PANTUR', 'CLI_PROST', 'CON_AMBIEN', 'CON_AREA', 'CS_ESCOL_N', 'ID_OCUPA_N', 'NU_IDADE_N', 'SG_UF', 'nivel_vulnerabilidade', 'vulnerabilidade_social']
# Variáveis Originais(36 variáveis):Index(['NU_IDADE_N', 'CS_SEXO', 'CS_GESTANT', 'CS_RACA', 'CS_ESCOL_N',
#        'ID_OCUPA_N', 'CON_AREA', 'CON_AMBIEN', 'ANT_CB_LAM', 'ANT_CB_CRI',
#        'ANT_CB_SIN', 'ANT_CB_COR', 'ANT_CB_ROE', 'ANT_CB_TER', 'ANT_CB_LIX',
#        'ANT_CB_OUT', 'ANT_ANIMAI', 'ANT_HUMANO', 'CLI_FEBRE', 'CLI_MIALGI',
#        'CLI_CEFALE', 'CLI_PROST', 'CLI_CONGES', 'CLI_PANTUR', 'CLI_VOMITO',
#        'CLI_DIARRE', 'CLI_OUTROS', 'SG_UF', 'baixa_escolaridade',
#        'raca_vulneravel', 'faixa_vulneravel', 'vulnerabilidade_social',
#        'nivel_vulnerabilidade', 'mes_sintomas', 'estacao', 'periodo_chuvoso'],
#       dtype='object')

# %%
#X_data = X_data[var_selected['variaveis_finais_originais']]
X_data.shape
# Out:
# (31658, 36)

# %% [markdown]
# ## Train framework

# %% [markdown]
# ### Funções de apoio

# %% [markdown]
# Detecta automaticamente a disponibilidade de GPU no ambiente,
# verificando suporte a CUDA, compatibilidade do LightGBM com GPU
# e informações do hardware via `nvidia-smi`.

# %%
def detect_gpu():
    """
    Detecta corretamente suporte a GPU para CUDA, XGBoost e LightGBM.
    Retorna um dicionário completo.
    """

    # 1. Verificar CUDA geral
    try:
        cuda_available = torch.cuda.is_available()
    except:
        cuda_available = False


    # 2. Testar LightGBM GPU

    try:
        # Testa se LightGBM foi compilado com suporte a GPU
        lgb_gpu = lgb.register_logger(lambda x: x)  # dummy
        booster = lgb.LGBMClassifier(device="gpu")
        lgb_gpu = True
    except:
        lgb_gpu = False


    # 3. Detalhes da GPU via nvidia-smi

    try:
        smi_output = subprocess.check_output("nvidia-smi", shell=True).decode()
        gpu_info = smi_output.split("\n")[2].strip()
    except:
        gpu_info = "Nenhuma GPU detectada (nvidia-smi não disponível)"

    return {
        "cuda_available": cuda_available,
        "lightgbm_gpu": lgb_gpu,
        "gpu_info": gpu_info
    }

# %%
def get_model_params_gpu(model_name, gpu_info):
    """
    Retorna hiperparâmetros base apropriados para CPU ou GPU.
    """
    use_gpu = gpu_info["cuda_available"]

    if model_name == "xgboost":
        if use_gpu:
            return {
                "tree_method": "gpu_hist",
                "predictor": "gpu_predictor"
            }
        else:
            return {
                "tree_method": "hist",
                "predictor": "cpu_predictor"
            }

    elif model_name == "lightgbm":
        if use_gpu:
            return {
                "device": "gpu",
                "gpu_platform_id": 0,
                "gpu_device_id": 0
            }
        else:
            return {
                "device": "cpu"
            }

    elif model_name in ["random_forest", "svm"]:
        # sklearn não usa GPU
        return {}

    return {}

# %%
def get_feature_types(df):
    """
    Identifica automaticamente colunas categóricas e numéricas de um dataframe.

    Retorna:
        cat_cols  -> lista de colunas categóricas
        num_cols  -> lista de colunas numéricas
    """

    # CATEGÓRICAS: object, category ou boolean
    cat_cols = df.select_dtypes(include=['object', 'category', 'bool']).columns.tolist()

    # NUMÉRICAS: int, float
    num_cols = df.select_dtypes(include=['int', 'float', 'int64', 'float64']).columns.tolist()

    return cat_cols, num_cols

# %% [markdown]
# ###  1. FUNÇÃO PARA CRIAR O MODELO A PARTIR DO TRIAL (Optuna)

# %% [markdown]
# Esta função encapsula a criação do modelo a ser otimizado por uma *trial* do Optuna,
# permitindo que diferentes famílias de classificadores sejam avaliadas dentro do mesmo processo de busca.
#
# O fluxo é composto por duas decisões principais:
#
# 1) **Seleção do algoritmo**
# A cada iteração, o Optuna escolhe o modelo a ser testado (`svm`, `xgboost`, `lightgbm` ou `random_forest`)
# por meio de uma variável categórica (`model_name`). Isso viabiliza uma busca conjunta que compara
# arquiteturas distintas sob o mesmo protocolo de avaliação.
#
# 2) **Amostragem de hiperparâmetros e configuração dinâmica de GPU**
# Para cada algoritmo, são sugeridos hiperparâmetros relevantes (ex.: profundidade, número de árvores, taxa de aprendizado,
# subsample e colsample), definindo um espaço de busca controlado e reproduzível.
# Em paralelo, a função consulta `get_model_params_gpu(model_name, gpu_info)` para injetar automaticamente
# parâmetros específicos de aceleração (CPU/GPU) quando suportado pelo ambiente, garantindo portabilidade do pipeline.
#
# Além disso, é aplicada uma estratégia de mitigação de desbalanceamento:
# - `class_weight="balanced"` para Random Forest e SVM,
# - `is_unbalance=True` para LightGBM,
# visando reduzir viés em cenários com classes minoritárias.
#
# No caso da SVM, utiliza-se `LinearSVC` com calibração (`CalibratedClassifierCV`),
# permitindo a obtenção de probabilidades calibradas, úteis para métricas baseadas em ranking (ex.: ROC-AUC)
# e para tomada de decisão com limiar de classificação.

# %%
def create_model(trial, gpu_info,pos_count,neg_count):
    model_name = trial.suggest_categorical(
        "model_name", ["svm","xgboost", "lightgbm", "random_forest"]
    )

    gpu_params = get_model_params_gpu(model_name, gpu_info)

    # RANDOM FOREST
    if model_name == "random_forest":
        return RandomForestClassifier(
            n_estimators=trial.suggest_int("n_estimators", 5, 30),
            max_depth=trial.suggest_int("max_depth", 3, 9),
            min_samples_split=trial.suggest_int("min_samples_split", 2, 10),
            min_samples_leaf=trial.suggest_int("min_samples_leaf", 1, 5),
            random_state=42,
            class_weight= 'balanced',
            **gpu_params
        )

    # SVM
    elif model_name == "svm":
        svm= LinearSVC(
            C=trial.suggest_float("C", 0.1, 3.0),
            max_iter=5000,
            class_weight= 'balanced'
        )
        return CalibratedClassifierCV(svm, method="sigmoid")

    # XGBOOST
    elif model_name == "xgboost":
        if pos_count == 0: # Avoid division by zero if no positive samples
            scale_pos_weight_val = 1 # Or handle as an error if positive samples are mandatory
        else:
            scale_pos_weight_val = neg_count / pos_count

        return  XGBClassifier(
            n_estimators=trial.suggest_int("n_estimators", 5, 30),
            max_depth=trial.suggest_int("max_depth", 3, 9),
            learning_rate=trial.suggest_float("learning_rate", 0.01, 0.3),
            subsample=trial.suggest_float("subsample", 0.5, 1.0),
            colsample_bytree=trial.suggest_float("colsample_bytree", 0.5, 1.0),
            eval_metric="logloss",
            random_state=42,
            n_jobs=-1,
            scale_pos_weight=scale_pos_weight_val
        )

    # LIGHTGBM
    elif model_name == "lightgbm":
        return LGBMClassifier(
            n_estimators=trial.suggest_int("n_estimators", 5, 30),
            learning_rate=trial.suggest_float("learning_rate", 0.01, 0.3),
            max_depth=trial.suggest_int("max_depth", 3, 9),
            subsample=trial.suggest_float("subsample", 0.5, 1.0),
            colsample_bytree=trial.suggest_float("colsample_bytree", 0.5, 1.0),
            random_state=42,
            is_unbalance=True,
           force_col_wise=True,
            **gpu_params
        )

# %% [markdown]
# ### 2. FUNÇÃO OBJETIVO DO OPTUNA (COM CROSS-VALIDATION)

# %% [markdown]
# ### Função `build_pipeline`: pré-processamento, balanceamento e modelagem em um fluxo único
#
# Esta função constrói um pipeline completo de treinamento, integrando pré-processamento dos dados,
# tratamento de desbalanceamento e ajuste do modelo em uma única estrutura reprodutível.
#
# O pipeline é organizado em três blocos sequenciais:
#
# 1) **Pré-processamento por tipo de variável**
# - Variáveis numéricas passam por imputação da mediana, reduzindo sensibilidade a outliers,
# seguida de padronização (`StandardScaler`), garantindo escalas compatíveis para modelos sensíveis à magnitude.
# - Variáveis categóricas passam por imputação do valor mais frequente e codificação via `OneHotEncoder`,
# com tratamento explícito de categorias raras (`handle_unknown='infrequent_if_exist'`),
# o que reduz dimensionalidade excessiva e melhora estabilidade do modelo.
#
# 2) **Balanceamento de classes (SMOTE)**
# Após o pré-processamento, aplica-se o SMOTE para gerar amostras sintéticas da classe minoritária
# exclusivamente no conjunto de treino dentro do pipeline,
# evitando vazamento de informação (*data leakage*) e melhorando a capacidade do modelo
# em aprender fronteiras de decisão mais equilibradas.
#
# 3) **Modelo preditivo**
# O estimador final é injetado de forma modular, permitindo que diferentes algoritmos
# (Random Forest, SVM, XGBoost, LightGBM, etc.) sejam testados sob exatamente o mesmo fluxo de dados.
#
# Ao encapsular todas as etapas em um único objeto `Pipeline`,
# a função garante consistência entre treino, validação e inferência,
# além de facilitar integração com validação cruzada e otimização de hiperparâmetros.

# %%
def build_pipeline(model, cat_cols, num_cols, sampler):

    # construindo o preprocessor
    num_preprocessor = Pipeline(steps=[
        ("imputer", SimpleImputer(strategy="median")),
        ("scaler", StandardScaler())
    ])

    cat_preprocessor = Pipeline(steps=[
        ("imputer", SimpleImputer(strategy="most_frequent")),
        ("onehot", OneHotEncoder(handle_unknown='infrequent_if_exist'))
    ])

    preprocessor = ColumnTransformer(
        transformers=[
            ("num", num_preprocessor, num_cols),
            ("cat", cat_preprocessor, cat_cols)
        ]
    )


    # ===== pipeline final =====
    pipe = Pipeline([
        ("preprocessor", preprocessor),
        ("sampler", sampler),
        ("model", model)
    ])

    return pipe

# %% [markdown]
# ### Função `make_sampler`: Estratégia de Reamostragem de Classes (`make_sampler`)
#
# Em problemas de classificação com **desbalanceamento de classes**, como é comum em tarefas de vigilância epidemiológica e detecção de eventos raros (por exemplo, casos graves de leptospirose), modelos supervisionados tendem a **favorecer a classe majoritária**, resultando em métricas infladas e baixo poder discriminativo para a classe de interesse. Para mitigar esse problema, foi adotada uma etapa explícita de **reamostragem dos dados de treino** integrada ao pipeline de modelagem.
#
# A função `make_sampler(trial)` é responsável por **selecionar e parametrizar automaticamente** a estratégia de balanceamento de classes durante o processo de otimização de hiperparâmetros com Optuna. Em cada `trial`, o algoritmo escolhe entre três abordagens clássicas:
#
# * **Oversampling aleatório (`RandomOverSampler`)**: aumenta a representatividade da classe minoritária por meio de replicação de amostras existentes, controlando a proporção final entre classes via o hiperparâmetro `over_ratio`.
# * **Undersampling aleatório (`RandomUnderSampler`)**: reduz o número de amostras da classe majoritária, também controlado por `under_ratio`, o que pode acelerar o treinamento, mas com potencial perda de informação.
# * **SMOTE (`Synthetic Minority Over-sampling Technique`)**: gera **amostras sintéticas** da classe minoritária a partir de seus vizinhos mais próximos no espaço de features, sendo controlado pela proporção `smote_ratio` e pelo número de vizinhos `k_neighbors`.
#
# Ao tratar a escolha do método de reamostragem e seus hiperparâmetros como **variáveis de otimização**, o estudo permite que o próprio processo de busca identifique a combinação mais adequada entre **qualidade preditiva** e **estabilidade do modelo**, evitando decisões arbitrárias sobre o balanceamento dos dados. Essa abordagem é particularmente relevante em cenários clínicos e epidemiológicos, onde o custo de erros na classe minoritária (por exemplo, não identificar um caso grave) é substancialmente maior do que na classe majoritária.
#
# Na prática, o `make_sampler` retorna um objeto de reamostragem compatível com o `imblearn.pipeline.Pipeline`, garantindo que o balanceamento seja aplicado **apenas nos conjuntos de treino dentro da validação cruzada**, prevenindo vazamento de informação (data leakage) e assegurando uma avaliação mais realista do desempenho dos modelos.

# %%
def make_sampler(trial):
    sampling_mode = trial.suggest_categorical("sampling_mode", ["over", "under", "smote"])

    if sampling_mode == "over":
        return RandomOverSampler(
            sampling_strategy='auto', # Alterado para 'auto' para maior robustez
            random_state=42
        )

    elif sampling_mode == "under":
        return RandomUnderSampler(
            sampling_strategy='auto', # Alterado para 'auto' para maior robustez
            random_state=42
        )

    elif sampling_mode == "smote":
        return SMOTE(
            sampling_strategy='minority', # Alterado para 'minority' para maior robustez
            k_neighbors=trial.suggest_int("smote_k", 3, 10), # Adicionado sugestão para k_neighbors
            random_state=42
        )
    # Default return for safety, though categorical should cover all cases
    return RandomOverSampler(random_state=42) # fallback

# %% [markdown]
# ### Função `objective`: avaliação do modelo por validação cruzada e otimização com Optuna (com pruning)
#
# Esta função define a métrica objetivo utilizada pelo Optuna durante a busca de hiperparâmetros.
# Para cada `trial`, ela instancia um modelo candidato (via `create_model`) e o encapsula em um pipeline completo
# de pré-processamento + balanceamento (via `build_pipeline`), garantindo que todas as transformações
# sejam aplicadas corretamente dentro de cada fold e evitando *data leakage*.
#
# A avaliação é realizada com **validação cruzada estratificada** (`StratifiedKFold`),
# preservando a proporção de classes em treino e validação. Em cada fold:
# - o pipeline é treinado no subconjunto de treino (`fit`),
# - e a performance é medida no subconjunto de validação por **ROC-AUC** calculado a partir de probabilidades (`predict_proba`).
#
# Para suportar cenários multiclasse, o AUC é calculado com `multi_class='ovr'`
# e agregação `average='weighted'`, o que pondera o desempenho pelo suporte de cada classe
# e reduz distorções em bases desbalanceadas.
#
# Além disso, a função utiliza mecanismos de *early stopping* do Optuna:
# - `trial.report` comunica a métrica parcial por fold,
# - `trial.should_prune()` permite interromper tentativas com desempenho fraco,
# economizando tempo computacional e acelerando a convergência do processo de otimização.
#
# Ao final, a função retorna a média do AUC entre os folds, que é o valor maximizado pelo Optuna.

# %%
def objective(trial, X_train, y_train, cat_cols, num_cols,feature_names, gpu_info):
    neg_count = (y_train == 0).sum()
    pos_count = (y_train == 1).sum()
    model = create_model(trial, gpu_info,pos_count,neg_count)

    sampler = make_sampler(trial)

    pipe = build_pipeline(model, cat_cols, num_cols, sampler)


    cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

    scores = []
    for step, (train_idx, val_idx) in enumerate(cv.split(X_train, y_train)):

        X_tr, X_val = X_train.iloc[train_idx], X_train.iloc[val_idx]
        y_tr, y_val = y_train.iloc[train_idx], y_train.iloc[val_idx]


        pipe.fit(X_tr, y_tr)
        fold_auc = roc_auc_score(y_val, pipe.predict_proba(X_val)[:, 1])
        scores.append(fold_auc)

        #  reporta o valor parcial ao Optuna
        trial.report(fold_auc, step=step)

        #  aborta a tentativa dado a avaliação do pruner
        if trial.should_prune():
            raise TrialPruned()


    return np.mean(scores)

# %% [markdown]
# Salva o histórico das trials do Optuna (métrica, parâmetros, estado e duração)
# em arquivo CSV para análise e rastreabilidade do processo de otimização.

# %%
# salva os logs das tentativas com métricas, tempo de treinamento, e parametros utilizados pelos modelos
def dump_trials(study, trial, out_path):
    df_metrics = study.trials_dataframe(
        attrs=("number", "value", "params", "state", "duration")
    )
    df_metrics.to_csv(out_path, index=False)

# %% [markdown]
# ### 3. VALIDAÇÃO EXTERNA (OUTER CV) + OPTUNA INTERNO

# %% [markdown]
# ### Função `outer_cv_training_with_results`: nested CV com Optuna, checkpoint e métricas por fold
#
# Esta função executa um processo completo de treinamento e avaliação com **validação cruzada externa**
# (*outer cross-validation*), integrando **otimização de hiperparâmetros com Optuna** dentro de cada fold
# e registrando resultados detalhados (modelo escolhido, métricas, tempo e artefatos salvos).
#
# O fluxo segue a lógica de *nested cross-validation*:
#
# 1) **Diagnóstico do ambiente (GPU)**
# Antes do treinamento, a função identifica a disponibilidade de GPU (`detect_gpu`), permitindo que a criação dos modelos
# ative parâmetros específicos de aceleração quando suportado.
#
# 2) **Validação cruzada externa (generalização)**
# É aplicada uma `StratifiedKFold` externa com `n_splits`, garantindo que a proporção das classes seja preservada em cada divisão.
# Em cada fold externo, o conjunto é particionado em `X_train/y_train` (para otimização e treino) e `X_test/y_test` (avaliação final).
#
# 3) **Otimização interna com Optuna (seleção de modelo + hiperparâmetros)**
# Para cada fold externo, um `study` é criado com objetivo de maximizar a métrica definida na função `objective`.
# A função `objective` é “fixada” via `partial`, injetando os dados do fold e metadados do pipeline (colunas numéricas e categóricas,
# GPU, etc.), de forma que cada trial avalie modelos e hiperparâmetros sob o mesmo protocolo.
#
# O estudo é executado com:
# - `n_trials` tentativas,
# - controle de tempo (`timeout`),
# - paralelismo (`n_jobs=-1`),
# - callback de logging (`dump_trials`) para persistir histórico das trials.
#
# 4) **Treinamento final do melhor modelo no fold e checkpoint**
# Após a otimização, a melhor configuração é recuperada (`study.best_params`) e o melhor modelo é reconstruído (`create_model`),
# sendo então encapsulado em um pipeline (`build_pipeline`) com pré-processamento e SMOTE.
# O pipeline é treinado no conjunto de treino do fold com medição de tempo, e o artefato final é salvo em disco (`joblib.dump`)
# como checkpoint (`best_model_fold_k.pkl`), garantindo reprodutibilidade e possibilidade de reuso posterior.
#
# 5) **Avaliação no conjunto de teste do fold (métricas completas)**
# O modelo treinado é avaliado no `X_test/y_test` do fold externo usando:
# - **ROC-AUC multiclasse** com estratégia OvR e média ponderada (`average='weighted'`),
# - além de `accuracy`, `f1`, `recall` e `precision` (também ponderadas), adequadas para cenários desbalanceados.
#
# Ao final, a função retorna uma lista de dicionários com os resultados de cada fold,
# incluindo o modelo vencedor, hiperparâmetros, métricas, tempo de treino e caminho do checkpoint.
# Isso permite comparar estabilidade do desempenho entre folds e estimar capacidade real de generalização.

# %%
def outer_cv_training_with_results(
    X, y, cat_cols, num_cols,
    n_trials=30, n_splits=5,
    log_dir="log_opt",
    model_ckpt_dir="checkpoints_best_models",
    pruner_mode='halving'
):
    gpu_info = detect_gpu()
    print("\n🔍 GPU detectada:", gpu_info)


    outer_cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
    results = []
    feature_names = X.columns

    for fold, (train_idx, test_idx) in enumerate(outer_cv.split(X, y), start=1):

        print(f"\n==============================")
        print(f"  Fold Externo {fold}/{n_splits}")
        print(f"==============================")

        X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]
        if pruner_mode.lower() == "hyperband":
            pruner = HyperbandPruner(
                min_resource=1,
                max_resource=20,
                reduction_factor=10
            )
        elif pruner_mode.lower() == "median":
            pruner = MedianPruner(
                n_warmup_steps=10
            )
        elif pruner_mode.lower() == "halving":
            pruner = SuccessiveHalvingPruner(
                min_resource=1, reduction_factor=3, min_early_stopping_rate=1
            )

        study = optuna.create_study(direction="maximize", pruner=pruner)

        objective_fixed = partial(
            objective,
            X_train=X_train,
            y_train=y_train,
            cat_cols=cat_cols,
            num_cols=num_cols,
            feature_names=feature_names,
            gpu_info=gpu_info
        )

        # log por fold (arquivo diferente)
        log_path = os.path.join(log_dir, f"trials_log_fold_{fold}.csv")
        dump_trials_cb = partial(dump_trials, out_path=log_path)

        study.optimize(
            objective_fixed,
            n_trials=n_trials,
            callbacks=[dump_trials_cb],
            timeout=1800,
            n_jobs=-1,
        )

        best_params = study.best_params
        best_model_name = best_params.get("model_name", "unknown")
        neg_count = (y_test == 0).sum()
        pos_count = (y_test == 1).sum()
        best_model = create_model(study.best_trial, gpu_info,pos_count,neg_count)

        # Reconstruct the best sampler using study.best_trial
        best_sampler = make_sampler(study.best_trial)

        pipe = build_pipeline(best_model, cat_cols, num_cols, best_sampler)

        start_time = time.time()
        pipe.fit(X_train, y_train)
        train_time = time.time() - start_time

        # checkpoint do melhor modelo do fold
        checkpoint_path = os.path.join(model_ckpt_dir, f"best_model_fold_{fold}.pkl")
        joblib.dump(pipe, checkpoint_path)

        # predição
        y_pred = pipe.predict(X_test)
        y_pred_prob = pipe.predict_proba(X_test)[:, 1]

        # métricas
        auc = roc_auc_score(y_test, y_pred_prob)
        acc = accuracy_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)
        rec = recall_score(y_test, y_pred)
        prec = precision_score(y_test, y_pred)

        results.append({
            "fold": fold,
            "best_model": best_model_name,
            "auc": auc,
            "accuracy": acc,
            "f1": f1,
            "recall": rec,
            "precision": prec,
            "hyperparameters": best_params,
            "checkpoint_path": checkpoint_path,
            "train_time_seconds": train_time,
            "trials_log_path": log_path,
        })

    return results

# %% [markdown]
# # Execute Framework

# %% [markdown]
# Cria os diretórios de checkpoints de modelos e logs de otimização,
# caso não existam, garantindo persistência e organização dos artefatos do experimento.

# %%
import os, joblib
checkpoint_dir = "checkpoints_best_models"

if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)

checkpoint_dir = "log_opt"
if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)


# ================================================

# %% [markdown]
# ### Execução do treinamento com validação cruzada externa e otimização de hiperparâmetros
#
# Nesta etapa, o conjunto de dados é preparado para o processo completo de treinamento e avaliação.
# Inicialmente, as colunas são classificadas em **categóricas** e **numéricas** por meio da função
# `get_feature_types`, garantindo que o pré-processamento subsequente seja aplicado de forma adequada
# a cada tipo de variável.
#
# Em seguida, é executado o procedimento de **validação cruzada externa** (*outer cross-validation*),
# no qual, para cada fold, ocorre uma otimização interna de hiperparâmetros via Optuna.
# Esse desenho experimental permite avaliar o desempenho dos modelos de forma mais realista,
# uma vez que o conjunto de teste de cada fold permanece completamente isolado do processo de tuning.
#
# Os parâmetros utilizados (`n_trials=30` e `n_splits=5`) definem, respectivamente,
# o orçamento de busca de hiperparâmetros em cada fold e o número de partições externas,
# balanceando custo computacional e robustez estatística.
#
# O resultado final (`df_results`) contém métricas, hiperparâmetros selecionados,
# tempos de treinamento e caminhos dos checkpoints para cada fold,
# servindo como base para análises comparativas e seleção do modelo final.

# %%
cat_cols, num_cols = get_feature_types(X_data)
df_results = outer_cv_training_with_results(
    X_data, y_data,
    cat_cols=cat_cols,
    num_cols=num_cols,
    n_trials=50,
    n_splits=5
)
# Out:
# [I 2026-03-22 12:15:28,675] A new study created in memory with name: no-name-098d4be3-8108-49ef-897f-e58f9427d820
# 🔍 GPU detectada: {'cuda_available': False, 'lightgbm_gpu': False, 'gpu_info': 'Nenhuma GPU detectada (nvidia-smi não disponível)'}
#
# ==============================
#   Fold Externo 1/5
# ==============================
# [I 2026-03-22 12:15:31,557] Trial 1 finished with value: 0.6915161968511699 and parameters: {'model_name': 'xgboost', 'n_estimators': 7, 'max_depth': 7, 'learning_rate': 0.1081059379202866, 'subsample': 0.7083458133910692, 'colsample_bytree': 0.6138263839483045, 'sampling_mode': 'under'}. Best is trial 1 with value: 0.6915161968511699.
# [I 2026-03-22 12:15:50,708] Trial 2 finished with value: 0.6941068291793977 and parameters: {'model_name': 'svm', 'C': 1.5313194338306444, 'sampling_mode': 'under'}. Best is trial 2 with value: 0.6941068291793977.
# [I 2026-03-22 12:15:55,511] Trial 3 finished with value: 0.7060302210664652 and parameters: {'model_name': 'lightgbm', 'n_estimators': 22, 'learning_rate': 0.1669942425328946, 'max_depth': 5, 'subsample': 0.5920861216355326, 'colsample_bytree': 0.7698843400925166, 'sampling_mode': 'under'}. Best is trial 3 with value: 0.7060302210664652.
# [I 2026-03-22 12:15:59,293] Trial 4 finished with value: 0.6885454955574587 and parameters: {'model_name': 'lightgbm', 'n_estimators': 18, 'learning_rate': 0.1076208807713064, 'max_depth': 3, 'subsample': 0.7763226011686037, 'colsample_bytree': 0.9814331803802627, 'sampling_mode': 'under'}. Best is trial 3 with value: 0.7060302210664652.
# [I 2026-03-22 12:16:31,952] Trial 5 finished with value: 0.6212473784688568 and parameters: {'model_name': 'xgboost', 'n_estimators': 6, 'max_depth': 3, 'learning_rate': 0.18848547665407978, 'subsample': 0.939312663572204, 'colsample_bytree': 0.630787982139579, 'sampling_mode': 'smote', 'smote_k': 5}. Best is trial 3 with value: 0.7060302210664652.
# [I 2026-03-22 12:16:33,777] Trial 0 finished with value: 0.6948897866241607 and parameters: {'model_name': 'svm', 'C': 0.5985575077985641, 'sampling_mode': 'smote', 'smote_k': 8}. Best is trial 3 with value: 0.7060302210664652.
# [I 2026-03-22 12:16:36,193] Trial 6 finished with value: 0.6925105958812701 and parameters: {'model_name': 'random_forest', 'n_estimators': 24, 'max_depth': 7, 'min_samples_split': 9, 'min_samples_leaf': 4, 'sampling_mode': 'under'}. Best is trial 3 with value: 0.7060302210664652.
# [I 2026-03-22 12:16:38,631] Trial 8 finished with value: 0.6590519945823577 and parameters: {'model_name': 'random_forest', 'n_estimators': 5, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 1, 'sampling_mode': 'over'}. Best is trial 3 with value: 0.7060302210664652.
# [I 2026-03-22 12:16:45,152] Trial 9 finished with value: 0.7028104012145772 and parameters: {'model_name': 'xgboost', 'n_estimators': 28, 'max_depth': 6, 'learning_rate': 0.25886456742784186, 'subsample': 0.8141200101118202, 'colsample_bytree': 0.5148524336326714, 'sampling_mode': 'over'}. Best is trial 3 with value: 0.7060302210664652.
# [I 2026-03-22 12:17:01,519] Trial 7 finished with value: 0.6964081785643487 and parameters: {'model_name': 'svm', 'C': 0.40313525514285475, 'sampling_mode': 'over'}. Best is trial 3 with value: 0.7060302210664652.
# [I 2026-03-22 12:17:05,506] Trial 11 finished with value: 0.7054577060532589 and parameters: {'model_name': 'lightgbm', 'n_estimators': 17, 'learning_rate': 0.20949936340353847, 'max_depth': 9, 'subsample': 0.518131861028184, 'colsample_bytree': 0.8566922592929213, 'sampling_mode': 'under'}. Best is trial 3 with value: 0.7060302210664652.
# [I 2026-03-22 12:17:08,510] Trial 12 finished with value: 0.7071769988777677 and parameters: {'model_name': 'lightgbm', 'n_estimators': 17, 'learning_rate': 0.20787608190952434, 'max_depth': 9, 'subsample': 0.5115773758108493, 'colsample_bytree': 0.8548741673570628, 'sampling_mode': 'under'}. Best is trial 12 with value: 0.7071769988777677.
# [I 2026-03-22 12:17:11,437] Trial 13 finished with value: 0.7064825697280689 and parameters: {'model_name': 'lightgbm', 'n_estimators': 17, 'learning_rate': 0.17867958467246647, 'max_depth': 9, 'subsample': 0.5032244768111106, 'colsample_bytree': 0.8014265734316026, 'sampling_mode': 'under'}. Best is trial 12 with value: 0.7071769988777677.
# [I 2026-03-22 12:17:14,244] Trial 14 finished with value: 0.6844087996722931 and parameters: {'model_name': 'lightgbm', 'n_estimators': 13, 'learning_rate': 0.017395474785485476, 'max_depth': 9, 'subsample': 0.5018540469287001, 'colsample_bytree': 0.8572847664713165, 'sampling_mode': 'under'}. Best is trial 12 with value: 0.7071769988777677.
# [I 2026-03-22 12:17:18,142] Trial 15 finished with value: 0.7036743667495307 and parameters: {'model_name': 'lightgbm', 'n_estimators': 14, 'learning_rate': 0.29630467102285063, 'max_depth': 8, 'subsample': 0.6313532081777984, 'colsample_bytree': 0.8475964948053247, 'sampling_mode': 'under'}. Best is trial 12 with value: 0.7071769988777677.
# [I 2026-03-22 12:17:23,500] Trial 10 finished with value: 0.6931217360109008 and parameters: {'model_name': 'svm', 'C': 2.1450714738083265, 'sampling_mode': 'over'}. Best is trial 12 with value: 0.7071769988777677.
# [I 2026-03-22 12:17:49,247] Trial 16 finished with value: 0.7038145403942319 and parameters: {'model_name': 'lightgbm', 'n_estimators': 13, 'learning_rate': 0.22286651450816566, 'max_depth': 9, 'subsample': 0.6121649056140074, 'colsample_bytree': 0.985460812321197, 'sampling_mode': 'smote', 'smote_k': 3}. Best is trial 12 with value: 0.7071769988777677.
# [I 2026-03-22 12:17:54,615] Trial 17 finished with value: 0.7034414352863947 and parameters: {'model_name': 'lightgbm', 'n_estimators': 12, 'learning_rate': 0.23118317187124546, 'max_depth': 9, 'subsample': 0.6092253322751069, 'colsample_bytree': 0.9807950762021088, 'sampling_mode': 'smote', 'smote_k': 3}. Best is trial 12 with value: 0.7071769988777677.
# [I 2026-03-22 12:17:54,670] Trial 18 finished with value: 0.7055751948554274 and parameters: {'model_name': 'lightgbm', 'n_estimators': 20, 'learning_rate': 0.12919233854793838, 'max_depth': 8, 'subsample': 0.5207400630942102, 'colsample_bytree': 0.7474104852413125, 'sampling_mode': 'under'}. Best is trial 12 with value: 0.7071769988777677.
# [I 2026-03-22 12:17:57,320] Trial 19 finished with value: 0.7046060042508122 and parameters: {'model_name': 'lightgbm', 'n_estimators': 20, 'learning_rate': 0.13091668912553805, 'max_depth': 8, 'subsample': 0.5015193283150705, 'colsample_bytree': 0.7689965061846646, 'sampling_mode': 'under'}. Best is trial 12 with value: 0.7071769988777677.
# [I 2026-03-22 12:17:59,813] Trial 20 finished with value: 0.6955487990233754 and parameters: {'model_name': 'random_forest', 'n_estimators': 27, 'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 5, 'sampling_mode': 'under'}. Best is trial 12 with value: 0.7071769988777677.
# [I 2026-03-22 12:18:01,484] Trial 21 finished with value: 0.690738299162953 and parameters: {'model_name': 'random_forest', 'n_estimators': 25, 'max_depth': 7, 'min_samples_split': 2, 'min_samples_leaf': 5, 'sampling_mode': 'under'}. Best is trial 12 with value: 0.7071769988777677.
# [I 2026-03-22 12:18:02,480] Trial 22 finished with value: 0.7060020400259424 and parameters: {'model_name': 'lightgbm', 'n_estimators': 22, 'learning_rate': 0.17009995248121254, 'max_depth': 5, 'subsample': 0.5860818039453892, 'colsample_bytree': 0.787121676036612, 'sampling_mode': 'under'}. Best is trial 12 with value: 0.7071769988777677.
# [I 2026-03-22 12:18:04,440] Trial 23 finished with value: 0.7065993709203883 and parameters: {'model_name': 'lightgbm', 'n_estimators': 22, 'learning_rate': 0.16775570802972184, 'max_depth': 5, 'subsample': 0.5877613532148199, 'colsample_bytree': 0.7679630466717552, 'sampling_mode': 'under'}. Best is trial 12 with value: 0.7071769988777677.
# [I 2026-03-22 12:18:05,655] Trial 24 finished with value: 0.7023304905321565 and parameters: {'model_name': 'lightgbm', 'n_estimators': 16, 'learning_rate': 0.1698107585337638, 'max_depth': 5, 'subsample': 0.5688683293505082, 'colsample_bytree': 0.7239245390643558, 'sampling_mode': 'under'}. Best is trial 12 with value: 0.7071769988777677.
# [I 2026-03-22 12:18:09,676] Trial 25 finished with value: 0.6854453366730587 and parameters: {'model_name': 'lightgbm', 'n_estimators': 16, 'learning_rate': 0.058371464314543334, 'max_depth': 4, 'subsample': 0.6879307092016621, 'colsample_bytree': 0.6923180069524056, 'sampling_mode': 'under'}. Best is trial 12 with value: 0.7071769988777677.
# [I 2026-03-22 12:18:10,385] Trial 26 finished with value: 0.6777488948146574 and parameters: {'model_name': 'lightgbm', 'n_estimators': 9, 'learning_rate': 0.0768412356987404, 'max_depth': 4, 'subsample': 0.6912824588405617, 'colsample_bytree': 0.9103921082322547, 'sampling_mode': 'under'}. Best is trial 12 with value: 0.7071769988777677.
# [I 2026-03-22 12:18:12,634] Trial 27 finished with value: 0.7011573358405513 and parameters: {'model_name': 'lightgbm', 'n_estimators': 11, 'learning_rate': 0.20140485426296253, 'max_depth': 6, 'subsample': 0.5482084843895111, 'colsample_bytree': 0.900814360064612, 'sampling_mode': 'under'}. Best is trial 12 with value: 0.7071769988777677.
# [I 2026-03-22 12:18:13,441] Trial 28 finished with value: 0.7055771002453457 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.19899254975447525, 'max_depth': 6, 'subsample': 0.5476218998236609, 'colsample_bytree': 0.9072194422787074, 'sampling_mode': 'under'}. Best is trial 12 with value: 0.7071769988777677.
# [I 2026-03-22 12:18:16,139] Trial 29 finished with value: 0.7034847470267843 and parameters: {'model_name': 'xgboost', 'n_estimators': 19, 'max_depth': 4, 'learning_rate': 0.24993963658110296, 'subsample': 0.6496682617720919, 'colsample_bytree': 0.8115394909305019, 'sampling_mode': 'over'}. Best is trial 12 with value: 0.7071769988777677.
# [I 2026-03-22 12:18:45,814] Trial 30 finished with value: 0.6965377583588351 and parameters: {'model_name': 'xgboost', 'n_estimators': 19, 'max_depth': 4, 'learning_rate': 0.2738805031242225, 'subsample': 0.8519772696270812, 'colsample_bytree': 0.8179111592808763, 'sampling_mode': 'smote', 'smote_k': 10}. Best is trial 12 with value: 0.7071769988777677.
# [I 2026-03-22 12:18:48,742] Trial 32 finished with value: 0.7048622909649014 and parameters: {'model_name': 'lightgbm', 'n_estimators': 22, 'learning_rate': 0.1491337068914026, 'max_depth': 5, 'subsample': 0.5694051643523435, 'colsample_bytree': 0.690076714729676, 'sampling_mode': 'under'}. Best is trial 12 with value: 0.7071769988777677.
# [I 2026-03-22 12:18:51,838] Trial 33 finished with value: 0.7058194133284817 and parameters: {'model_name': 'lightgbm', 'n_estimators': 22, 'learning_rate': 0.16096102496540549, 'max_depth': 5, 'subsample': 0.6572545121649707, 'colsample_bytree': 0.7377924797209698, 'sampling_mode': 'under'}. Best is trial 12 with value: 0.7071769988777677.
# [I 2026-03-22 12:19:14,601] Trial 34 finished with value: 0.6933102871063651 and parameters: {'model_name': 'svm', 'C': 2.893170715705762, 'sampling_mode': 'under'}. Best is trial 12 with value: 0.7071769988777677.
# [I 2026-03-22 12:19:18,696] Trial 35 finished with value: 0.7072718451829605 and parameters: {'model_name': 'lightgbm', 'n_estimators': 24, 'learning_rate': 0.18882872491826733, 'max_depth': 7, 'subsample': 0.548600024977915, 'colsample_bytree': 0.7977037476059634, 'sampling_mode': 'under'}. Best is trial 35 with value: 0.7072718451829605.
# [I 2026-03-22 12:19:21,675] Trial 36 finished with value: 0.7093741023552763 and parameters: {'model_name': 'lightgbm', 'n_estimators': 25, 'learning_rate': 0.18873196736979367, 'max_depth': 7, 'subsample': 0.5509061473364516, 'colsample_bytree': 0.8112454789154606, 'sampling_mode': 'under'}. Best is trial 36 with value: 0.7093741023552763.
# [I 2026-03-22 12:19:47,217] Trial 31 finished with value: 0.6921701227411269 and parameters: {'model_name': 'svm', 'C': 2.971658880300571, 'sampling_mode': 'smote', 'smote_k': 10}. Best is trial 36 with value: 0.7093741023552763.
# [I 2026-03-22 12:19:52,277] Trial 38 finished with value: 0.7067222631961366 and parameters: {'model_name': 'lightgbm', 'n_estimators': 25, 'learning_rate': 0.23273000860643966, 'max_depth': 7, 'subsample': 0.5509300521363594, 'colsample_bytree': 0.8376298470198555, 'sampling_mode': 'under'}. Best is trial 36 with value: 0.7093741023552763.
# [I 2026-03-22 12:19:55,274] Trial 39 finished with value: 0.7058109402068108 and parameters: {'model_name': 'lightgbm', 'n_estimators': 25, 'learning_rate': 0.23152145765509843, 'max_depth': 7, 'subsample': 0.5482948454940159, 'colsample_bytree': 0.8813342233118417, 'sampling_mode': 'under'}. Best is trial 36 with value: 0.7093741023552763.
# [I 2026-03-22 12:19:59,625] Trial 40 finished with value: 0.6909426663437888 and parameters: {'model_name': 'random_forest', 'n_estimators': 27, 'max_depth': 7, 'min_samples_split': 6, 'min_samples_leaf': 1, 'sampling_mode': 'under'}. Best is trial 36 with value: 0.7093741023552763.
# [I 2026-03-22 12:20:00,071] Trial 37 finished with value: 0.7075859507154392 and parameters: {'model_name': 'lightgbm', 'n_estimators': 25, 'learning_rate': 0.2205597513382548, 'max_depth': 7, 'subsample': 0.5588785341901439, 'colsample_bytree': 0.8438389347968144, 'sampling_mode': 'smote', 'smote_k': 7}. Best is trial 36 with value: 0.7093741023552763.
# [I 2026-03-22 12:20:03,878] Trial 41 finished with value: 0.7033051980194225 and parameters: {'model_name': 'xgboost', 'n_estimators': 24, 'max_depth': 6, 'learning_rate': 0.21486504525907646, 'subsample': 0.9892310490664182, 'colsample_bytree': 0.9461334201563473, 'sampling_mode': 'over'}. Best is trial 36 with value: 0.7093741023552763.
# [I 2026-03-22 12:20:32,816] Trial 42 finished with value: 0.7071923643148509 and parameters: {'model_name': 'lightgbm', 'n_estimators': 24, 'learning_rate': 0.2207249054962729, 'max_depth': 7, 'subsample': 0.5435404508785673, 'colsample_bytree': 0.830822513653672, 'sampling_mode': 'smote', 'smote_k': 6}. Best is trial 36 with value: 0.7093741023552763.
# [I 2026-03-22 12:20:35,747] Trial 43 finished with value: 0.70676024539804 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.2490644845912847, 'max_depth': 7, 'subsample': 0.5462050712317901, 'colsample_bytree': 0.8252687171215397, 'sampling_mode': 'smote', 'smote_k': 7}. Best is trial 36 with value: 0.7093741023552763.
# [I 2026-03-22 12:21:06,222] Trial 44 finished with value: 0.7083678325457038 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.1945398050913343, 'max_depth': 8, 'subsample': 0.5396613888581544, 'colsample_bytree': 0.8231284179954264, 'sampling_mode': 'smote', 'smote_k': 6}. Best is trial 36 with value: 0.7093741023552763.
# [I 2026-03-22 12:21:08,212] Trial 45 finished with value: 0.707961781903501 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.19137043933393033, 'max_depth': 8, 'subsample': 0.7262127594335414, 'colsample_bytree': 0.8820956416402493, 'sampling_mode': 'smote', 'smote_k': 5}. Best is trial 36 with value: 0.7093741023552763.
# [I 2026-03-22 12:21:39,646] Trial 46 finished with value: 0.709876855299037 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.18958759630089442, 'max_depth': 8, 'subsample': 0.7337586825891832, 'colsample_bytree': 0.7919463813575026, 'sampling_mode': 'smote', 'smote_k': 6}. Best is trial 46 with value: 0.709876855299037.
# [I 2026-03-22 12:22:19,337] Trial 47 finished with value: 0.6934612808922055 and parameters: {'model_name': 'svm', 'C': 1.3172431322742588, 'sampling_mode': 'smote', 'smote_k': 5}. Best is trial 46 with value: 0.709876855299037.
# [I 2026-03-22 12:22:47,322] Trial 48 finished with value: 0.6935408269139266 and parameters: {'model_name': 'svm', 'C': 1.255010007988998, 'sampling_mode': 'smote', 'smote_k': 5}. Best is trial 46 with value: 0.709876855299037.
# [I 2026-03-22 12:22:49,369] Trial 49 finished with value: 0.7085885800948701 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.1436379544273107, 'max_depth': 8, 'subsample': 0.757162900390521, 'colsample_bytree': 0.8824955778775875, 'sampling_mode': 'smote', 'smote_k': 6}. Best is trial 46 with value: 0.709876855299037.
# [LightGBM] [Info] Number of positive: 15568, number of negative: 15568
# [LightGBM] [Info] Total Bins 24522
# [LightGBM] [Info] Number of data points in the train set: 31136, number of used features: 230
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2026-03-22 12:23:02,156] A new study created in memory with name: no-name-dd459db2-49a6-4752-a5b8-ee2f3ada0e60
# ==============================
#   Fold Externo 2/5
# ==============================
# [I 2026-03-22 12:23:05,073] Trial 1 finished with value: 0.6744247197528134 and parameters: {'model_name': 'xgboost', 'n_estimators': 6, 'max_depth': 3, 'learning_rate': 0.18064343999350707, 'subsample': 0.5294369766719946, 'colsample_bytree': 0.7965797309453881, 'sampling_mode': 'over'}. Best is trial 1 with value: 0.6744247197528134.
# [I 2026-03-22 12:23:35,608] Trial 0 finished with value: 0.6910204433149573 and parameters: {'model_name': 'random_forest', 'n_estimators': 17, 'max_depth': 7, 'min_samples_split': 6, 'min_samples_leaf': 2, 'sampling_mode': 'smote', 'smote_k': 5}. Best is trial 0 with value: 0.6910204433149573.
# [I 2026-03-22 12:23:38,218] Trial 2 finished with value: 0.6683779168471965 and parameters: {'model_name': 'xgboost', 'n_estimators': 12, 'max_depth': 7, 'learning_rate': 0.04259790025408229, 'subsample': 0.6381521777652313, 'colsample_bytree': 0.8405661215851289, 'sampling_mode': 'smote', 'smote_k': 4}. Best is trial 0 with value: 0.6910204433149573.
# [I 2026-03-22 12:23:43,707] Trial 3 finished with value: 0.6986949573620791 and parameters: {'model_name': 'random_forest', 'n_estimators': 22, 'max_depth': 9, 'min_samples_split': 3, 'min_samples_leaf': 5, 'sampling_mode': 'over'}. Best is trial 3 with value: 0.6986949573620791.
# [I 2026-03-22 12:23:45,631] Trial 4 finished with value: 0.6989591029713887 and parameters: {'model_name': 'random_forest', 'n_estimators': 24, 'max_depth': 9, 'min_samples_split': 8, 'min_samples_leaf': 4, 'sampling_mode': 'under'}. Best is trial 4 with value: 0.6989591029713887.
# [I 2026-03-22 12:23:46,833] Trial 5 finished with value: 0.7039243898759548 and parameters: {'model_name': 'xgboost', 'n_estimators': 22, 'max_depth': 5, 'learning_rate': 0.10863973742442898, 'subsample': 0.9976863209940392, 'colsample_bytree': 0.8865022700247485, 'sampling_mode': 'under'}. Best is trial 5 with value: 0.7039243898759548.
# [I 2026-03-22 12:23:48,645] Trial 6 finished with value: 0.6758331538253809 and parameters: {'model_name': 'random_forest', 'n_estimators': 23, 'max_depth': 3, 'min_samples_split': 10, 'min_samples_leaf': 2, 'sampling_mode': 'under'}. Best is trial 5 with value: 0.7039243898759548.
# [I 2026-03-22 12:23:49,677] Trial 7 finished with value: 0.6999247334272262 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.08723579762283108, 'max_depth': 4, 'subsample': 0.952431687673674, 'colsample_bytree': 0.7399240264495803, 'sampling_mode': 'under'}. Best is trial 5 with value: 0.7039243898759548.
# [I 2026-03-22 12:23:52,665] Trial 9 finished with value: 0.6826696757053439 and parameters: {'model_name': 'random_forest', 'n_estimators': 12, 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 3, 'sampling_mode': 'over'}. Best is trial 5 with value: 0.7039243898759548.
# [I 2026-03-22 12:23:56,336] Trial 10 finished with value: 0.6964501167190482 and parameters: {'model_name': 'lightgbm', 'n_estimators': 12, 'learning_rate': 0.14165195409254305, 'max_depth': 4, 'subsample': 0.9993571811524573, 'colsample_bytree': 0.7360204180418761, 'sampling_mode': 'over'}. Best is trial 5 with value: 0.7039243898759548.
# [I 2026-03-22 12:24:18,748] Trial 11 finished with value: 0.6963319013633592 and parameters: {'model_name': 'svm', 'C': 1.8595188996694088, 'sampling_mode': 'under'}. Best is trial 5 with value: 0.7039243898759548.
# [I 2026-03-22 12:24:20,314] Trial 8 finished with value: 0.6880593970591976 and parameters: {'model_name': 'random_forest', 'n_estimators': 13, 'max_depth': 7, 'min_samples_split': 6, 'min_samples_leaf': 2, 'sampling_mode': 'smote', 'smote_k': 7}. Best is trial 5 with value: 0.7039243898759548.
# [I 2026-03-22 12:24:21,799] Trial 12 finished with value: 0.7030049997142925 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.07203622762239237, 'max_depth': 5, 'subsample': 0.9952668747788807, 'colsample_bytree': 0.9989225288848853, 'sampling_mode': 'under'}. Best is trial 5 with value: 0.7039243898759548.
# [I 2026-03-22 12:24:23,467] Trial 13 finished with value: 0.7034330205742675 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.06863905806221123, 'max_depth': 5, 'subsample': 0.9976911166281986, 'colsample_bytree': 0.9754171067587107, 'sampling_mode': 'under'}. Best is trial 5 with value: 0.7039243898759548.
# [I 2026-03-22 12:24:24,908] Trial 14 finished with value: 0.7075651358859852 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.2689931116918643, 'max_depth': 5, 'subsample': 0.8423852058802941, 'colsample_bytree': 0.994667181575342, 'sampling_mode': 'under'}. Best is trial 14 with value: 0.7075651358859852.
# [I 2026-03-22 12:24:26,442] Trial 15 finished with value: 0.706470137946544 and parameters: {'model_name': 'xgboost', 'n_estimators': 26, 'max_depth': 5, 'learning_rate': 0.2579393978680917, 'subsample': 0.80573279008232, 'colsample_bytree': 0.9815279387075757, 'sampling_mode': 'under'}. Best is trial 14 with value: 0.7075651358859852.
# [I 2026-03-22 12:24:27,918] Trial 16 finished with value: 0.705393763858195 and parameters: {'model_name': 'xgboost', 'n_estimators': 26, 'max_depth': 5, 'learning_rate': 0.28945732370522637, 'subsample': 0.8202145055360993, 'colsample_bytree': 0.9049412936648003, 'sampling_mode': 'under'}. Best is trial 14 with value: 0.7075651358859852.
# [I 2026-03-22 12:24:40,655] Trial 18 finished with value: 0.7039417863848166 and parameters: {'model_name': 'svm', 'C': 0.11100624633996681, 'sampling_mode': 'under'}. Best is trial 14 with value: 0.7075651358859852.
# [I 2026-03-22 12:24:42,219] Trial 17 finished with value: 0.7008602243108887 and parameters: {'model_name': 'svm', 'C': 0.3032382861212819, 'sampling_mode': 'under'}. Best is trial 14 with value: 0.7075651358859852.
# [I 2026-03-22 12:24:43,615] Trial 19 finished with value: 0.7051777825556919 and parameters: {'model_name': 'lightgbm', 'n_estimators': 19, 'learning_rate': 0.2865597622361637, 'max_depth': 6, 'subsample': 0.8096381409864369, 'colsample_bytree': 0.5673887613998903, 'sampling_mode': 'under'}. Best is trial 14 with value: 0.7075651358859852.
# [I 2026-03-22 12:25:14,977] Trial 20 finished with value: 0.7075515573230605 and parameters: {'model_name': 'lightgbm', 'n_estimators': 18, 'learning_rate': 0.2770626792664201, 'max_depth': 6, 'subsample': 0.8063925646161983, 'colsample_bytree': 0.5768518187259991, 'sampling_mode': 'smote', 'smote_k': 10}. Best is trial 14 with value: 0.7075651358859852.
# [I 2026-03-22 12:25:16,116] Trial 21 finished with value: 0.7029912030054984 and parameters: {'model_name': 'xgboost', 'n_estimators': 27, 'max_depth': 4, 'learning_rate': 0.2285146008028679, 'subsample': 0.8647302543699708, 'colsample_bytree': 0.618255061349924, 'sampling_mode': 'smote', 'smote_k': 10}. Best is trial 14 with value: 0.7075651358859852.
# [I 2026-03-22 12:25:47,968] Trial 23 finished with value: 0.707974547646991 and parameters: {'model_name': 'lightgbm', 'n_estimators': 18, 'learning_rate': 0.23646858171204221, 'max_depth': 6, 'subsample': 0.6990921600274079, 'colsample_bytree': 0.647358331575721, 'sampling_mode': 'smote', 'smote_k': 10}. Best is trial 23 with value: 0.707974547646991.
# [I 2026-03-22 12:25:48,040] Trial 22 finished with value: 0.7093739971509918 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.23557184980129914, 'max_depth': 6, 'subsample': 0.8512610928617383, 'colsample_bytree': 0.5290782467379196, 'sampling_mode': 'smote', 'smote_k': 10}. Best is trial 22 with value: 0.7093739971509918.
# [I 2026-03-22 12:26:19,054] Trial 25 finished with value: 0.6925379418756309 and parameters: {'model_name': 'lightgbm', 'n_estimators': 6, 'learning_rate': 0.21692659974208114, 'max_depth': 8, 'subsample': 0.7092014714450825, 'colsample_bytree': 0.6437953450150595, 'sampling_mode': 'smote', 'smote_k': 9}. Best is trial 22 with value: 0.7093739971509918.
# [I 2026-03-22 12:26:19,994] Trial 24 finished with value: 0.708263811831419 and parameters: {'model_name': 'lightgbm', 'n_estimators': 17, 'learning_rate': 0.21747542669155281, 'max_depth': 8, 'subsample': 0.7162873774757545, 'colsample_bytree': 0.6625595766684524, 'sampling_mode': 'smote', 'smote_k': 10}. Best is trial 22 with value: 0.7093739971509918.
# [I 2026-03-22 12:26:57,004] Trial 26 finished with value: 0.7085405395165614 and parameters: {'model_name': 'lightgbm', 'n_estimators': 16, 'learning_rate': 0.22210707281933115, 'max_depth': 7, 'subsample': 0.698839769443774, 'colsample_bytree': 0.5044765335590926, 'sampling_mode': 'smote', 'smote_k': 8}. Best is trial 22 with value: 0.7093739971509918.
# [I 2026-03-22 12:26:57,866] Trial 27 finished with value: 0.7077385685849382 and parameters: {'model_name': 'lightgbm', 'n_estimators': 16, 'learning_rate': 0.2037396238958662, 'max_depth': 8, 'subsample': 0.6972512846779646, 'colsample_bytree': 0.500868290380398, 'sampling_mode': 'smote', 'smote_k': 8}. Best is trial 22 with value: 0.7093739971509918.
# [I 2026-03-22 12:27:29,200] Trial 28 finished with value: 0.7071836854517871 and parameters: {'model_name': 'lightgbm', 'n_estimators': 15, 'learning_rate': 0.19131708225517202, 'max_depth': 8, 'subsample': 0.62342874488432, 'colsample_bytree': 0.5325911324506759, 'sampling_mode': 'smote', 'smote_k': 8}. Best is trial 22 with value: 0.7093739971509918.
# [I 2026-03-22 12:27:30,298] Trial 29 finished with value: 0.7061486807129765 and parameters: {'model_name': 'lightgbm', 'n_estimators': 15, 'learning_rate': 0.1812840731220119, 'max_depth': 8, 'subsample': 0.6359660235418141, 'colsample_bytree': 0.5065706568284098, 'sampling_mode': 'smote', 'smote_k': 8}. Best is trial 22 with value: 0.7093739971509918.
# [I 2026-03-22 12:28:00,730] Trial 30 finished with value: 0.6999718848205964 and parameters: {'model_name': 'lightgbm', 'n_estimators': 9, 'learning_rate': 0.17377063008275806, 'max_depth': 7, 'subsample': 0.6218495686008249, 'colsample_bytree': 0.6839490117090401, 'sampling_mode': 'smote', 'smote_k': 8}. Best is trial 22 with value: 0.7093739971509918.
# [I 2026-03-22 12:28:01,390] Trial 31 finished with value: 0.6953152462356216 and parameters: {'model_name': 'lightgbm', 'n_estimators': 9, 'learning_rate': 0.14328775858515733, 'max_depth': 7, 'subsample': 0.7514093640763594, 'colsample_bytree': 0.6725501394040417, 'sampling_mode': 'smote', 'smote_k': 9}. Best is trial 22 with value: 0.7093739971509918.
# [I 2026-03-22 12:28:33,252] Trial 32 finished with value: 0.7095051271941298 and parameters: {'model_name': 'lightgbm', 'n_estimators': 20, 'learning_rate': 0.23330234230275196, 'max_depth': 6, 'subsample': 0.7601380925448676, 'colsample_bytree': 0.6799113314110501, 'sampling_mode': 'smote', 'smote_k': 10}. Best is trial 32 with value: 0.7095051271941298.
# [I 2026-03-22 12:28:34,078] Trial 33 finished with value: 0.7085171476012251 and parameters: {'model_name': 'lightgbm', 'n_estimators': 20, 'learning_rate': 0.24589408441351318, 'max_depth': 6, 'subsample': 0.7313701176501561, 'colsample_bytree': 0.5882720307028333, 'sampling_mode': 'smote', 'smote_k': 10}. Best is trial 32 with value: 0.7095051271941298.
# [I 2026-03-22 12:29:06,693] Trial 34 finished with value: 0.7104061120279132 and parameters: {'model_name': 'lightgbm', 'n_estimators': 19, 'learning_rate': 0.24680711983558654, 'max_depth': 7, 'subsample': 0.7534820178158338, 'colsample_bytree': 0.5785030452477914, 'sampling_mode': 'smote', 'smote_k': 10}. Best is trial 34 with value: 0.7104061120279132.
# [I 2026-03-22 12:29:07,300] Trial 35 finished with value: 0.7086423348020204 and parameters: {'model_name': 'lightgbm', 'n_estimators': 20, 'learning_rate': 0.2483880084453351, 'max_depth': 6, 'subsample': 0.7578895375416607, 'colsample_bytree': 0.5816109891812623, 'sampling_mode': 'smote', 'smote_k': 9}. Best is trial 34 with value: 0.7104061120279132.
# [I 2026-03-22 12:29:39,369] Trial 36 finished with value: 0.710294016004792 and parameters: {'model_name': 'lightgbm', 'n_estimators': 20, 'learning_rate': 0.25761809099318655, 'max_depth': 7, 'subsample': 0.8832096978704038, 'colsample_bytree': 0.5559785163083896, 'sampling_mode': 'smote', 'smote_k': 9}. Best is trial 34 with value: 0.7104061120279132.
# [I 2026-03-22 12:30:25,291] Trial 38 finished with value: 0.6944808813285346 and parameters: {'model_name': 'svm', 'C': 2.793108571538268, 'sampling_mode': 'over'}. Best is trial 34 with value: 0.7104061120279132.
# [I 2026-03-22 12:30:40,158] Trial 37 finished with value: 0.693989012279118 and parameters: {'model_name': 'svm', 'C': 2.9906948350366793, 'sampling_mode': 'smote', 'smote_k': 9}. Best is trial 34 with value: 0.7104061120279132.
# [I 2026-03-22 12:30:57,730] Trial 39 finished with value: 0.710748609756763 and parameters: {'model_name': 'lightgbm', 'n_estimators': 21, 'learning_rate': 0.2553079601025434, 'max_depth': 7, 'subsample': 0.899367326724511, 'colsample_bytree': 0.5519092678898937, 'sampling_mode': 'smote', 'smote_k': 9}. Best is trial 39 with value: 0.710748609756763.
# [I 2026-03-22 12:31:11,868] Trial 40 finished with value: 0.7082586218479349 and parameters: {'model_name': 'lightgbm', 'n_estimators': 21, 'learning_rate': 0.2557740130321108, 'max_depth': 7, 'subsample': 0.8872412531187058, 'colsample_bytree': 0.5469136715892738, 'sampling_mode': 'smote', 'smote_k': 10}. Best is trial 39 with value: 0.710748609756763.
# [I 2026-03-22 12:31:29,386] Trial 41 finished with value: 0.6898494332089348 and parameters: {'model_name': 'random_forest', 'n_estimators': 21, 'max_depth': 7, 'min_samples_split': 4, 'min_samples_leaf': 1, 'sampling_mode': 'smote', 'smote_k': 6}. Best is trial 39 with value: 0.710748609756763.
# [I 2026-03-22 12:31:43,958] Trial 42 finished with value: 0.710198318203226 and parameters: {'model_name': 'lightgbm', 'n_estimators': 24, 'learning_rate': 0.26985541187043466, 'max_depth': 7, 'subsample': 0.9102540625581274, 'colsample_bytree': 0.6137967553192298, 'sampling_mode': 'smote', 'smote_k': 9}. Best is trial 39 with value: 0.710748609756763.
# [I 2026-03-22 12:32:02,068] Trial 43 finished with value: 0.7088350204385447 and parameters: {'model_name': 'lightgbm', 'n_estimators': 24, 'learning_rate': 0.2670045251467468, 'max_depth': 7, 'subsample': 0.9185449025079077, 'colsample_bytree': 0.5436738185654215, 'sampling_mode': 'smote', 'smote_k': 9}. Best is trial 39 with value: 0.710748609756763.
# [I 2026-03-22 12:32:07,356] Trial 45 finished with value: 0.7058135150869612 and parameters: {'model_name': 'lightgbm', 'n_estimators': 23, 'learning_rate': 0.2971916093223153, 'max_depth': 7, 'subsample': 0.9122248261120897, 'colsample_bytree': 0.7044109737771763, 'sampling_mode': 'over'}. Best is trial 39 with value: 0.710748609756763.
# [I 2026-03-22 12:32:16,612] Trial 44 finished with value: 0.7090319223836233 and parameters: {'model_name': 'lightgbm', 'n_estimators': 24, 'learning_rate': 0.27075962649732, 'max_depth': 7, 'subsample': 0.9126154410721949, 'colsample_bytree': 0.6129613528557464, 'sampling_mode': 'smote', 'smote_k': 9}. Best is trial 39 with value: 0.710748609756763.
# [I 2026-03-22 12:32:41,407] Trial 46 finished with value: 0.6966459309873817 and parameters: {'model_name': 'random_forest', 'n_estimators': 24, 'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 5, 'sampling_mode': 'smote', 'smote_k': 9}. Best is trial 39 with value: 0.710748609756763.
# [I 2026-03-22 12:32:50,497] Trial 47 finished with value: 0.6926659683405484 and parameters: {'model_name': 'random_forest', 'n_estimators': 22, 'max_depth': 9, 'min_samples_split': 10, 'min_samples_leaf': 5, 'sampling_mode': 'smote', 'smote_k': 7}. Best is trial 39 with value: 0.710748609756763.
# [I 2026-03-22 12:32:54,626] Trial 49 finished with value: 0.7052458508600705 and parameters: {'model_name': 'xgboost', 'n_estimators': 20, 'max_depth': 7, 'learning_rate': 0.20468610192081765, 'subsample': 0.9489350711903182, 'colsample_bytree': 0.6077265621163648, 'sampling_mode': 'over'}. Best is trial 39 with value: 0.710748609756763.
# [I 2026-03-22 12:33:04,021] Trial 48 finished with value: 0.7110675498904072 and parameters: {'model_name': 'lightgbm', 'n_estimators': 22, 'learning_rate': 0.20144816410375194, 'max_depth': 7, 'subsample': 0.9432669864153782, 'colsample_bytree': 0.6133772884122449, 'sampling_mode': 'smote', 'smote_k': 7}. Best is trial 48 with value: 0.7110675498904072.
# [LightGBM] [Info] Number of positive: 15568, number of negative: 15568
# [LightGBM] [Info] Total Bins 24672
# [LightGBM] [Info] Number of data points in the train set: 31136, number of used features: 231
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2026-03-22 12:33:15,920] A new study created in memory with name: no-name-f02c655f-e134-4e13-ab7c-5cb7a9bc745f
# ==============================
#   Fold Externo 3/5
# ==============================
# [I 2026-03-22 12:33:18,713] Trial 1 finished with value: 0.6632386817869532 and parameters: {'model_name': 'random_forest', 'n_estimators': 16, 'max_depth': 3, 'min_samples_split': 8, 'min_samples_leaf': 1, 'sampling_mode': 'under'}. Best is trial 1 with value: 0.6632386817869532.
# [I 2026-03-22 12:33:20,263] Trial 0 finished with value: 0.6949395942961892 and parameters: {'model_name': 'xgboost', 'n_estimators': 13, 'max_depth': 8, 'learning_rate': 0.245271937541592, 'subsample': 0.5693219783069896, 'colsample_bytree': 0.6464637933242943, 'sampling_mode': 'over'}. Best is trial 0 with value: 0.6949395942961892.
# [I 2026-03-22 12:33:21,803] Trial 2 finished with value: 0.6838428295194836 and parameters: {'model_name': 'random_forest', 'n_estimators': 16, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 4, 'sampling_mode': 'under'}. Best is trial 0 with value: 0.6949395942961892.
# [I 2026-03-22 12:33:23,190] Trial 3 finished with value: 0.6677842714542184 and parameters: {'model_name': 'random_forest', 'n_estimators': 24, 'max_depth': 3, 'min_samples_split': 6, 'min_samples_leaf': 4, 'sampling_mode': 'under'}. Best is trial 0 with value: 0.6949395942961892.
# [I 2026-03-22 12:33:54,905] Trial 4 finished with value: 0.689655893230138 and parameters: {'model_name': 'lightgbm', 'n_estimators': 19, 'learning_rate': 0.07513574493474753, 'max_depth': 5, 'subsample': 0.8933807825682067, 'colsample_bytree': 0.5912924983708168, 'sampling_mode': 'smote', 'smote_k': 7}. Best is trial 0 with value: 0.6949395942961892.
# [I 2026-03-22 12:33:56,240] Trial 5 finished with value: 0.682802867366847 and parameters: {'model_name': 'random_forest', 'n_estimators': 30, 'max_depth': 5, 'min_samples_split': 7, 'min_samples_leaf': 5, 'sampling_mode': 'smote', 'smote_k': 7}. Best is trial 0 with value: 0.6949395942961892.
# [I 2026-03-22 12:33:58,359] Trial 6 finished with value: 0.6866716453256086 and parameters: {'model_name': 'random_forest', 'n_estimators': 24, 'max_depth': 5, 'min_samples_split': 9, 'min_samples_leaf': 5, 'sampling_mode': 'under'}. Best is trial 0 with value: 0.6949395942961892.
# [I 2026-03-22 12:33:59,380] Trial 7 finished with value: 0.7022783522459836 and parameters: {'model_name': 'lightgbm', 'n_estimators': 14, 'learning_rate': 0.11427599541625295, 'max_depth': 7, 'subsample': 0.6148463747797597, 'colsample_bytree': 0.5382708134067202, 'sampling_mode': 'over'}. Best is trial 7 with value: 0.7022783522459836.
# [I 2026-03-22 12:34:04,204] Trial 8 finished with value: 0.6737661527277453 and parameters: {'model_name': 'random_forest', 'n_estimators': 20, 'max_depth': 4, 'min_samples_split': 10, 'min_samples_leaf': 3, 'sampling_mode': 'under'}. Best is trial 7 with value: 0.7022783522459836.
# [I 2026-03-22 12:34:07,831] Trial 9 finished with value: 0.7045836976697162 and parameters: {'model_name': 'xgboost', 'n_estimators': 27, 'max_depth': 9, 'learning_rate': 0.07741089752048982, 'subsample': 0.594037515979518, 'colsample_bytree': 0.8241766280510847, 'sampling_mode': 'under'}. Best is trial 9 with value: 0.7045836976697162.
# [I 2026-03-22 12:34:08,692] Trial 10 finished with value: 0.689356498177848 and parameters: {'model_name': 'random_forest', 'n_estimators': 17, 'max_depth': 7, 'min_samples_split': 5, 'min_samples_leaf': 4, 'sampling_mode': 'over'}. Best is trial 9 with value: 0.7045836976697162.
# [I 2026-03-22 12:34:11,258] Trial 11 finished with value: 0.6865364907673218 and parameters: {'model_name': 'xgboost', 'n_estimators': 6, 'max_depth': 9, 'learning_rate': 0.031518774912741375, 'subsample': 0.7304244987171113, 'colsample_bytree': 0.9064672081541452, 'sampling_mode': 'over'}. Best is trial 9 with value: 0.7045836976697162.
# [I 2026-03-22 12:34:11,840] Trial 12 finished with value: 0.6891498707818101 and parameters: {'model_name': 'xgboost', 'n_estimators': 6, 'max_depth': 9, 'learning_rate': 0.08228979595306297, 'subsample': 0.5870975490692651, 'colsample_bytree': 0.9195265588772741, 'sampling_mode': 'over'}. Best is trial 9 with value: 0.7045836976697162.
# [I 2026-03-22 12:34:46,511] Trial 13 finished with value: 0.7002261176487053 and parameters: {'model_name': 'svm', 'C': 0.7763872066622134, 'sampling_mode': 'over'}. Best is trial 9 with value: 0.7045836976697162.
# [I 2026-03-22 12:34:56,110] Trial 14 finished with value: 0.6988824166959405 and parameters: {'model_name': 'svm', 'C': 1.8957450426678322, 'sampling_mode': 'over'}. Best is trial 9 with value: 0.7045836976697162.
# [I 2026-03-22 12:35:18,262] Trial 15 finished with value: 0.6973196456106514 and parameters: {'model_name': 'lightgbm', 'n_estimators': 10, 'learning_rate': 0.15828349511307555, 'max_depth': 7, 'subsample': 0.6674487674592287, 'colsample_bytree': 0.772808208061322, 'sampling_mode': 'smote', 'smote_k': 3}. Best is trial 9 with value: 0.7045836976697162.
# [I 2026-03-22 12:35:21,436] Trial 17 finished with value: 0.7111741243946783 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.1443974761620789, 'max_depth': 7, 'subsample': 0.5060708983171334, 'colsample_bytree': 0.76230144973056, 'sampling_mode': 'under'}. Best is trial 17 with value: 0.7111741243946783.
# [I 2026-03-22 12:35:27,247] Trial 16 finished with value: 0.6980000680412087 and parameters: {'model_name': 'lightgbm', 'n_estimators': 10, 'learning_rate': 0.15323847273207614, 'max_depth': 7, 'subsample': 0.6727207408130923, 'colsample_bytree': 0.7971737169704096, 'sampling_mode': 'smote', 'smote_k': 3}. Best is trial 17 with value: 0.7111741243946783.
# [I 2026-03-22 12:35:27,527] Trial 18 finished with value: 0.6981907933082168 and parameters: {'model_name': 'xgboost', 'n_estimators': 29, 'max_depth': 8, 'learning_rate': 0.18440012977037568, 'subsample': 0.5122709178829827, 'colsample_bytree': 0.7778488878543286, 'sampling_mode': 'under'}. Best is trial 17 with value: 0.7111741243946783.
# [I 2026-03-22 12:35:30,535] Trial 20 finished with value: 0.7097053080791077 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.21786007635332835, 'max_depth': 8, 'subsample': 0.8738421129212192, 'colsample_bytree': 0.6744992091119283, 'sampling_mode': 'under'}. Best is trial 17 with value: 0.7111741243946783.
# [I 2026-03-22 12:35:31,757] Trial 19 finished with value: 0.6937409534273051 and parameters: {'model_name': 'xgboost', 'n_estimators': 30, 'max_depth': 8, 'learning_rate': 0.21911069372980652, 'subsample': 0.5004118310172949, 'colsample_bytree': 0.7042466585278533, 'sampling_mode': 'under'}. Best is trial 17 with value: 0.7111741243946783.
# [I 2026-03-22 12:35:33,388] Trial 21 finished with value: 0.7085967844589103 and parameters: {'model_name': 'lightgbm', 'n_estimators': 25, 'learning_rate': 0.2999771523637962, 'max_depth': 6, 'subsample': 0.877382560602616, 'colsample_bytree': 0.6799144958032837, 'sampling_mode': 'under'}. Best is trial 17 with value: 0.7111741243946783.
# [I 2026-03-22 12:35:34,890] Trial 22 finished with value: 0.7060153112425427 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.28316355586667824, 'max_depth': 9, 'subsample': 0.8866735951216411, 'colsample_bytree': 0.8567443871918883, 'sampling_mode': 'under'}. Best is trial 17 with value: 0.7111741243946783.
# [I 2026-03-22 12:35:36,345] Trial 23 finished with value: 0.708392104709536 and parameters: {'model_name': 'lightgbm', 'n_estimators': 25, 'learning_rate': 0.26718069843416037, 'max_depth': 6, 'subsample': 0.8963994295238971, 'colsample_bytree': 0.6836560823008359, 'sampling_mode': 'under'}. Best is trial 17 with value: 0.7111741243946783.
# [I 2026-03-22 12:35:37,755] Trial 24 finished with value: 0.7055744317896652 and parameters: {'model_name': 'lightgbm', 'n_estimators': 22, 'learning_rate': 0.290259089183412, 'max_depth': 6, 'subsample': 0.9882139532837048, 'colsample_bytree': 0.690213844514774, 'sampling_mode': 'under'}. Best is trial 17 with value: 0.7111741243946783.
# [I 2026-03-22 12:35:40,277] Trial 25 finished with value: 0.7084553533858248 and parameters: {'model_name': 'lightgbm', 'n_estimators': 22, 'learning_rate': 0.29702698032584296, 'max_depth': 6, 'subsample': 0.9799945357293656, 'colsample_bytree': 0.6219674521206981, 'sampling_mode': 'under'}. Best is trial 17 with value: 0.7111741243946783.
# [I 2026-03-22 12:35:43,058] Trial 26 finished with value: 0.7110376121150533 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.21471934632701067, 'max_depth': 6, 'subsample': 0.8162994641070813, 'colsample_bytree': 0.6268413623367195, 'sampling_mode': 'under'}. Best is trial 17 with value: 0.7111741243946783.
# [I 2026-03-22 12:35:44,867] Trial 27 finished with value: 0.7094125982589018 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.21497497184259665, 'max_depth': 8, 'subsample': 0.8085776999458999, 'colsample_bytree': 0.7273224649000076, 'sampling_mode': 'under'}. Best is trial 17 with value: 0.7111741243946783.
# [I 2026-03-22 12:35:46,456] Trial 28 finished with value: 0.7089645753450258 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.2068425955530179, 'max_depth': 8, 'subsample': 0.7966141521618996, 'colsample_bytree': 0.5073186729185155, 'sampling_mode': 'under'}. Best is trial 17 with value: 0.7111741243946783.
# [I 2026-03-22 12:36:06,478] Trial 29 finished with value: 0.6979971523483667 and parameters: {'model_name': 'svm', 'C': 2.998705106356959, 'sampling_mode': 'under'}. Best is trial 17 with value: 0.7111741243946783.
# [I 2026-03-22 12:36:08,315] Trial 30 finished with value: 0.6980122597432582 and parameters: {'model_name': 'svm', 'C': 2.9504909335613343, 'sampling_mode': 'under'}. Best is trial 17 with value: 0.7111741243946783.
# [I 2026-03-22 12:36:11,676] Trial 32 finished with value: 0.7118292909053233 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.21329190597598127, 'max_depth': 7, 'subsample': 0.7981027378133547, 'colsample_bytree': 0.7331256269521618, 'sampling_mode': 'under'}. Best is trial 32 with value: 0.7118292909053233.
# [I 2026-03-22 12:36:16,843] Trial 33 finished with value: 0.7110283487305247 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.1749799291684748, 'max_depth': 7, 'subsample': 0.826105931916577, 'colsample_bytree': 0.5911015724044629, 'sampling_mode': 'under'}. Best is trial 32 with value: 0.7118292909053233.
# [I 2026-03-22 12:36:20,174] Trial 34 finished with value: 0.7110205442122859 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.1620022202846937, 'max_depth': 7, 'subsample': 0.804748725489557, 'colsample_bytree': 0.5926135143532473, 'sampling_mode': 'under'}. Best is trial 32 with value: 0.7118292909053233.
# [I 2026-03-22 12:36:23,300] Trial 35 finished with value: 0.7113141029014689 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.13058893581203593, 'max_depth': 7, 'subsample': 0.7561780851671029, 'colsample_bytree': 0.563560636970523, 'sampling_mode': 'under'}. Best is trial 32 with value: 0.7118292909053233.
# [I 2026-03-22 12:36:26,331] Trial 36 finished with value: 0.7086986284932372 and parameters: {'model_name': 'lightgbm', 'n_estimators': 23, 'learning_rate': 0.13335720351006417, 'max_depth': 6, 'subsample': 0.740744333647991, 'colsample_bytree': 0.5517709999032232, 'sampling_mode': 'under'}. Best is trial 32 with value: 0.7118292909053233.
# [I 2026-03-22 12:36:38,760] Trial 31 finished with value: 0.7075448921804003 and parameters: {'model_name': 'lightgbm', 'n_estimators': 22, 'learning_rate': 0.15903204326751819, 'max_depth': 7, 'subsample': 0.8265427149325935, 'colsample_bytree': 0.6133628457364739, 'sampling_mode': 'smote', 'smote_k': 10}. Best is trial 32 with value: 0.7118292909053233.
# [I 2026-03-22 12:36:41,842] Trial 38 finished with value: 0.7086768701910717 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.11961504802186804, 'max_depth': 6, 'subsample': 0.7653868756502872, 'colsample_bytree': 0.988611798615589, 'sampling_mode': 'under'}. Best is trial 32 with value: 0.7118292909053233.
# [I 2026-03-22 12:36:45,179] Trial 39 finished with value: 0.7101241145214288 and parameters: {'model_name': 'lightgbm', 'n_estimators': 29, 'learning_rate': 0.24972833262112643, 'max_depth': 7, 'subsample': 0.7104214806634691, 'colsample_bytree': 0.7244857396977213, 'sampling_mode': 'under'}. Best is trial 32 with value: 0.7118292909053233.
# [I 2026-03-22 12:36:58,781] Trial 37 finished with value: 0.7070541409345635 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.11430870796828888, 'max_depth': 6, 'subsample': 0.701548912219048, 'colsample_bytree': 0.9871353883271414, 'sampling_mode': 'smote', 'smote_k': 9}. Best is trial 32 with value: 0.7118292909053233.
# [I 2026-03-22 12:37:01,754] Trial 41 finished with value: 0.7059743351630271 and parameters: {'model_name': 'lightgbm', 'n_estimators': 20, 'learning_rate': 0.1992579359059689, 'max_depth': 4, 'subsample': 0.7714362635217064, 'colsample_bytree': 0.7417540386483861, 'sampling_mode': 'under'}. Best is trial 32 with value: 0.7118292909053233.
# [I 2026-03-22 12:37:06,833] Trial 42 finished with value: 0.7112781947325487 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.18128822214185913, 'max_depth': 7, 'subsample': 0.842987734130376, 'colsample_bytree': 0.569068678428196, 'sampling_mode': 'under'}. Best is trial 32 with value: 0.7118292909053233.
# [I 2026-03-22 12:37:10,304] Trial 43 finished with value: 0.7089297397676484 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.23435651722050602, 'max_depth': 7, 'subsample': 0.856504784186913, 'colsample_bytree': 0.6422293113224788, 'sampling_mode': 'under'}. Best is trial 32 with value: 0.7118292909053233.
# [I 2026-03-22 12:37:15,178] Trial 44 finished with value: 0.6955411104343785 and parameters: {'model_name': 'random_forest', 'n_estimators': 26, 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'sampling_mode': 'under'}. Best is trial 32 with value: 0.7118292909053233.
# ...
# [I 2026-03-22 12:43:23,352] Trial 1 finished with value: 0.7018106955487408 and parameters: {'model_name': 'svm', 'C': 1.731277188210179, 'sampling_mode': 'over'}. Best is trial 2 with value: 0.7110568170740131.
# [I 2026-03-22 12:43:27,469] Trial 4 finished with value: 0.6878938371001051 and parameters: {'model_name': 'xgboost', 'n_estimators': 10, 'max_depth': 4, 'learning_rate': 0.08385744247013789, 'subsample': 0.8529452482329847, 'colsample_bytree': 0.8379359030184315, 'sampling_mode': 'under'}. Best is trial 2 with value: 0.7110568170740131.
# [I 2026-03-22 12:43:34,570] Trial 5 finished with value: 0.7047164908334951 and parameters: {'model_name': 'xgboost', 'n_estimators': 25, 'max_depth': 8, 'learning_rate': 0.21423864250558378, 'subsample': 0.880486345683194, 'colsample_bytree': 0.8032480326675819, 'sampling_mode': 'under'}. Best is trial 2 with value: 0.7110568170740131.
# [I 2026-03-22 12:43:37,226] Trial 6 finished with value: 0.7080406344028041 and parameters: {'model_name': 'lightgbm', 'n_estimators': 15, 'learning_rate': 0.2704008286232095, 'max_depth': 4, 'subsample': 0.547086733070706, 'colsample_bytree': 0.7451882017984128, 'sampling_mode': 'under'}. Best is trial 2 with value: 0.7110568170740131.
# [I 2026-03-22 12:43:41,161] Trial 7 finished with value: 0.7033146245719261 and parameters: {'model_name': 'xgboost', 'n_estimators': 20, 'max_depth': 6, 'learning_rate': 0.02505295223852617, 'subsample': 0.9481717129696193, 'colsample_bytree': 0.5031476767124028, 'sampling_mode': 'over'}. Best is trial 2 with value: 0.7110568170740131.
# [I 2026-03-22 12:44:22,855] Trial 3 finished with value: 0.700324715937413 and parameters: {'model_name': 'svm', 'C': 2.780707707893435, 'sampling_mode': 'smote', 'smote_k': 4}. Best is trial 2 with value: 0.7110568170740131.
# [I 2026-03-22 12:44:45,112] Trial 8 finished with value: 0.7009358397350046 and parameters: {'model_name': 'svm', 'C': 0.6338181691812785, 'sampling_mode': 'smote', 'smote_k': 9}. Best is trial 2 with value: 0.7110568170740131.
# [I 2026-03-22 12:45:00,321] Trial 9 finished with value: 0.7019905241183384 and parameters: {'model_name': 'svm', 'C': 1.495839252991694, 'sampling_mode': 'over'}. Best is trial 2 with value: 0.7110568170740131.
# [I 2026-03-22 12:45:03,624] Trial 11 finished with value: 0.7131823114100658 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.14246596527550331, 'max_depth': 9, 'subsample': 0.664041561551488, 'colsample_bytree': 0.9842371581740206, 'sampling_mode': 'under'}. Best is trial 11 with value: 0.7131823114100658.
# [I 2026-03-22 12:45:07,164] Trial 12 finished with value: 0.7131840972719905 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.14441413422222427, 'max_depth': 9, 'subsample': 0.6275261157534048, 'colsample_bytree': 0.9978887986385435, 'sampling_mode': 'under'}. Best is trial 12 with value: 0.7131840972719905.
# [I 2026-03-22 12:45:12,848] Trial 13 finished with value: 0.7135381327175429 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.17105990254843034, 'max_depth': 9, 'subsample': 0.646888043406738, 'colsample_bytree': 0.9984274158108221, 'sampling_mode': 'under'}. Best is trial 13 with value: 0.7135381327175429.
# [I 2026-03-22 12:45:15,997] Trial 14 finished with value: 0.7112092674809755 and parameters: {'model_name': 'lightgbm', 'n_estimators': 21, 'learning_rate': 0.19777774200597423, 'max_depth': 9, 'subsample': 0.6434385533228185, 'colsample_bytree': 0.9856985925904057, 'sampling_mode': 'under'}. Best is trial 13 with value: 0.7135381327175429.
# [I 2026-03-22 12:45:19,270] Trial 15 finished with value: 0.7141001430406732 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.1866482542174523, 'max_depth': 7, 'subsample': 0.6825371847230172, 'colsample_bytree': 0.883154656417201, 'sampling_mode': 'under'}. Best is trial 15 with value: 0.7141001430406732.
# [I 2026-03-22 12:45:21,882] Trial 16 finished with value: 0.6687427891353547 and parameters: {'model_name': 'random_forest', 'n_estimators': 5, 'max_depth': 7, 'min_samples_split': 2, 'min_samples_leaf': 1, 'sampling_mode': 'under'}. Best is trial 15 with value: 0.7141001430406732.
# [I 2026-03-22 12:45:44,758] Trial 10 finished with value: 0.702455003565408 and parameters: {'model_name': 'svm', 'C': 0.46987330064291843, 'sampling_mode': 'smote', 'smote_k': 8}. Best is trial 15 with value: 0.7141001430406732.
# [I 2026-03-22 12:45:48,108] Trial 18 finished with value: 0.7114211938041688 and parameters: {'model_name': 'lightgbm', 'n_estimators': 22, 'learning_rate': 0.2158266867816274, 'max_depth': 6, 'subsample': 0.7381695749882375, 'colsample_bytree': 0.88243995174251, 'sampling_mode': 'under'}. Best is trial 15 with value: 0.7141001430406732.
# [I 2026-03-22 12:45:50,902] Trial 19 finished with value: 0.7100979549976264 and parameters: {'model_name': 'lightgbm', 'n_estimators': 16, 'learning_rate': 0.2634419077981075, 'max_depth': 7, 'subsample': 0.5079874047367563, 'colsample_bytree': 0.696254256692844, 'sampling_mode': 'under'}. Best is trial 15 with value: 0.7141001430406732.
# [I 2026-03-22 12:45:54,106] Trial 17 finished with value: 0.7139593274542554 and parameters: {'model_name': 'lightgbm', 'n_estimators': 23, 'learning_rate': 0.21275615472764697, 'max_depth': 6, 'subsample': 0.7387156985138689, 'colsample_bytree': 0.8743829167812573, 'sampling_mode': 'smote', 'smote_k': 10}. Best is trial 15 with value: 0.7141001430406732.
# [I 2026-03-22 12:46:24,134] Trial 20 finished with value: 0.7129451785386994 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.18497999112410202, 'max_depth': 6, 'subsample': 0.7407734155057717, 'colsample_bytree': 0.8867379756652322, 'sampling_mode': 'smote', 'smote_k': 4}. Best is trial 15 with value: 0.7141001430406732.
# [I 2026-03-22 12:46:25,265] Trial 21 finished with value: 0.6837061920382116 and parameters: {'model_name': 'random_forest', 'n_estimators': 24, 'max_depth': 5, 'min_samples_split': 10, 'min_samples_leaf': 3, 'sampling_mode': 'smote', 'smote_k': 10}. Best is trial 15 with value: 0.7141001430406732.
# [I 2026-03-22 12:46:56,781] Trial 22 finished with value: 0.7127644127053058 and parameters: {'model_name': 'lightgbm', 'n_estimators': 24, 'learning_rate': 0.17352116553671082, 'max_depth': 5, 'subsample': 0.6957929058153536, 'colsample_bytree': 0.896008108791366, 'sampling_mode': 'smote', 'smote_k': 10}. Best is trial 15 with value: 0.7141001430406732.
# [I 2026-03-22 12:46:57,621] Trial 23 finished with value: 0.7148784347986354 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.23503882115566183, 'max_depth': 7, 'subsample': 0.7023568614111229, 'colsample_bytree': 0.8981680491311078, 'sampling_mode': 'smote', 'smote_k': 7}. Best is trial 23 with value: 0.7148784347986354.
# [I 2026-03-22 12:47:29,379] Trial 24 finished with value: 0.714133664210593 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.23415591030775385, 'max_depth': 7, 'subsample': 0.5916344394265431, 'colsample_bytree': 0.654208157868605, 'sampling_mode': 'smote', 'smote_k': 7}. Best is trial 23 with value: 0.7148784347986354.
# [I 2026-03-22 12:47:29,882] Trial 25 finished with value: 0.7130950004288676 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.23987065899777948, 'max_depth': 7, 'subsample': 0.8076709478597128, 'colsample_bytree': 0.7866024391033227, 'sampling_mode': 'smote', 'smote_k': 6}. Best is trial 23 with value: 0.7148784347986354.
# [I 2026-03-22 12:48:02,167] Trial 26 finished with value: 0.7125573118901732 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.2982781339243856, 'max_depth': 7, 'subsample': 0.5829030410809188, 'colsample_bytree': 0.6224629282612155, 'sampling_mode': 'smote', 'smote_k': 6}. Best is trial 23 with value: 0.7148784347986354.
# [I 2026-03-22 12:48:02,981] Trial 27 finished with value: 0.7135972535658811 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.2428538771763631, 'max_depth': 8, 'subsample': 0.5824669910070394, 'colsample_bytree': 0.6249738231926943, 'sampling_mode': 'smote', 'smote_k': 7}. Best is trial 23 with value: 0.7148784347986354.
# [I 2026-03-22 12:48:34,307] Trial 28 finished with value: 0.7130166760515317 and parameters: {'model_name': 'lightgbm', 'n_estimators': 19, 'learning_rate': 0.25182589515393117, 'max_depth': 8, 'subsample': 0.5816273879239003, 'colsample_bytree': 0.6669110566928074, 'sampling_mode': 'smote', 'smote_k': 7}. Best is trial 23 with value: 0.7148784347986354.
# [I 2026-03-22 12:48:36,780] Trial 29 finished with value: 0.6985229973623234 and parameters: {'model_name': 'random_forest', 'n_estimators': 28, 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'sampling_mode': 'smote', 'smote_k': 7}. Best is trial 23 with value: 0.7148784347986354.
# [I 2026-03-22 12:48:39,179] Trial 30 finished with value: 0.7000941558923593 and parameters: {'model_name': 'random_forest', 'n_estimators': 28, 'max_depth': 7, 'min_samples_split': 2, 'min_samples_leaf': 5, 'sampling_mode': 'over'}. Best is trial 23 with value: 0.7148784347986354.
# [I 2026-03-22 12:48:39,613] Trial 31 finished with value: 0.701617918157984 and parameters: {'model_name': 'xgboost', 'n_estimators': 14, 'max_depth': 7, 'learning_rate': 0.2993474324068916, 'subsample': 0.6960987413917491, 'colsample_bytree': 0.549378701700792, 'sampling_mode': 'over'}. Best is trial 23 with value: 0.7148784347986354.
# [I 2026-03-22 12:49:11,467] Trial 33 finished with value: 0.7125550794942788 and parameters: {'model_name': 'lightgbm', 'n_estimators': 23, 'learning_rate': 0.21976251948863093, 'max_depth': 5, 'subsample': 0.7690491015610643, 'colsample_bytree': 0.838532116658761, 'sampling_mode': 'smote', 'smote_k': 5}. Best is trial 23 with value: 0.7148784347986354.
# [I 2026-03-22 12:49:11,870] Trial 32 finished with value: 0.7119036634060031 and parameters: {'model_name': 'lightgbm', 'n_estimators': 23, 'learning_rate': 0.2173514575795447, 'max_depth': 6, 'subsample': 0.7162928479166106, 'colsample_bytree': 0.91850553756426, 'sampling_mode': 'smote', 'smote_k': 5}. Best is trial 23 with value: 0.7148784347986354.
# [I 2026-03-22 12:49:44,172] Trial 34 finished with value: 0.7150019764786517 and parameters: {'model_name': 'lightgbm', 'n_estimators': 25, 'learning_rate': 0.2052960474412192, 'max_depth': 6, 'subsample': 0.7073988037779166, 'colsample_bytree': 0.9297237451280853, 'sampling_mode': 'smote', 'smote_k': 8}. Best is trial 34 with value: 0.7150019764786517.
# [I 2026-03-22 12:49:44,480] Trial 35 finished with value: 0.7135730035038773 and parameters: {'model_name': 'lightgbm', 'n_estimators': 25, 'learning_rate': 0.19605797142799178, 'max_depth': 6, 'subsample': 0.6800068669523773, 'colsample_bytree': 0.9299206540941167, 'sampling_mode': 'smote', 'smote_k': 8}. Best is trial 34 with value: 0.7150019764786517.
# [I 2026-03-22 12:50:23,856] Trial 36 finished with value: 0.7150518151315849 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.19378643347086386, 'max_depth': 6, 'subsample': 0.6741009913623653, 'colsample_bytree': 0.920180592687201, 'sampling_mode': 'smote', 'smote_k': 8}. Best is trial 36 with value: 0.7150518151315849.
# [I 2026-03-22 12:50:24,553] Trial 37 finished with value: 0.7151575998175216 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.15639907580838897, 'max_depth': 7, 'subsample': 0.7718898178852842, 'colsample_bytree': 0.9384216737423283, 'sampling_mode': 'smote', 'smote_k': 8}. Best is trial 37 with value: 0.7151575998175216.
# [I 2026-03-22 12:50:58,149] Trial 38 finished with value: 0.7114329260074149 and parameters: {'model_name': 'xgboost', 'n_estimators': 28, 'max_depth': 5, 'learning_rate': 0.23368550716620232, 'subsample': 0.6113366430570258, 'colsample_bytree': 0.9429615942189823, 'sampling_mode': 'smote', 'smote_k': 8}. Best is trial 37 with value: 0.7151575998175216.
# [I 2026-03-22 12:50:58,619] Trial 39 finished with value: 0.7006209387080319 and parameters: {'model_name': 'xgboost', 'n_estimators': 26, 'max_depth': 5, 'learning_rate': 0.12019055980378494, 'subsample': 0.786470307163025, 'colsample_bytree': 0.9459687095126272, 'sampling_mode': 'smote', 'smote_k': 8}. Best is trial 37 with value: 0.7151575998175216.
# [I 2026-03-22 12:52:23,850] Trial 41 finished with value: 0.6987329343050078 and parameters: {'model_name': 'svm', 'C': 2.984752647574587, 'sampling_mode': 'smote', 'smote_k': 9}. Best is trial 37 with value: 0.7151575998175216.
# [I 2026-03-22 12:52:23,898] Trial 40 finished with value: 0.698744189750033 and parameters: {'model_name': 'svm', 'C': 2.9309874424145033, 'sampling_mode': 'smote', 'smote_k': 9}. Best is trial 37 with value: 0.7151575998175216.
# [I 2026-03-22 12:52:56,650] Trial 42 finished with value: 0.7131253193748298 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.16379169039470973, 'max_depth': 7, 'subsample': 0.781654949983054, 'colsample_bytree': 0.8333264075352417, 'sampling_mode': 'smote', 'smote_k': 7}. Best is trial 37 with value: 0.7151575998175216.
# [I 2026-03-22 12:52:57,142] Trial 43 finished with value: 0.71554831926098 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.16578829479908888, 'max_depth': 7, 'subsample': 0.717450010775454, 'colsample_bytree': 0.8360228251715973, 'sampling_mode': 'smote', 'smote_k': 7}. Best is trial 43 with value: 0.71554831926098.
# [I 2026-03-22 12:53:29,882] Trial 44 finished with value: 0.7118241656668 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.1209611629364148, 'max_depth': 6, 'subsample': 0.7170174585166833, 'colsample_bytree': 0.9556568742861477, 'sampling_mode': 'smote', 'smote_k': 8}. Best is trial 43 with value: 0.71554831926098.
# [I 2026-03-22 12:53:29,953] Trial 45 finished with value: 0.7126541247581027 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.140059779147306, 'max_depth': 6, 'subsample': 0.7175944650145734, 'colsample_bytree': 0.9466881752459371, 'sampling_mode': 'smote', 'smote_k': 8}. Best is trial 43 with value: 0.71554831926098.
# [I 2026-03-22 12:53:32,807] Trial 47 finished with value: 0.7001923342336394 and parameters: {'model_name': 'lightgbm', 'n_estimators': 12, 'learning_rate': 0.15469907703184968, 'max_depth': 4, 'subsample': 0.8403031031257933, 'colsample_bytree': 0.8576120829839575, 'sampling_mode': 'over'}. Best is trial 43 with value: 0.71554831926098.
# [I 2026-03-22 12:53:34,146] Trial 46 finished with value: 0.7143176226149041 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.1527911990703907, 'max_depth': 8, 'subsample': 0.8396971364762631, 'colsample_bytree': 0.911578189569377, 'sampling_mode': 'over'}. Best is trial 43 with value: 0.71554831926098.
# [I 2026-03-22 12:54:05,138] Trial 49 finished with value: 0.6839195692186935 and parameters: {'model_name': 'lightgbm', 'n_estimators': 19, 'learning_rate': 0.0886143730971808, 'max_depth': 3, 'subsample': 0.763932678976463, 'colsample_bytree': 0.7847642883454113, 'sampling_mode': 'smote', 'smote_k': 6}. Best is trial 43 with value: 0.71554831926098.
# [I 2026-03-22 12:54:05,655] Trial 48 finished with value: 0.7145573757121797 and parameters: {'model_name': 'lightgbm', 'n_estimators': 25, 'learning_rate': 0.19600832261884166, 'max_depth': 8, 'subsample': 0.7630131796216701, 'colsample_bytree': 0.9091653341397126, 'sampling_mode': 'smote', 'smote_k': 6}. Best is trial 43 with value: 0.71554831926098.
# [LightGBM] [Info] Number of positive: 15568, number of negative: 15568
# [LightGBM] [Info] Total Bins 24689
# [LightGBM] [Info] Number of data points in the train set: 31136, number of used features: 226
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000

# %% [markdown]
# #### Conferir checkpoints intermediarios

# %% [markdown]
# Consolida os resultados da validação cruzada externa em um DataFrame,
# salva o resumo em formato Parquet e carrega os logs das trials do Optuna
# para inspeção e análise do processo de otimização.

# %%
df_results=pd.DataFrame(df_results)
display(df_results)
# Out:
#    fold best_model       auc  accuracy        f1    recall  precision  \
# 0     1   lightgbm  0.722188  0.680985  0.513956  0.437705   0.622378
# 1     2   lightgbm  0.714969  0.678617  0.541150  0.491803   0.601504
# 2     3   lightgbm  0.712307  0.645768  0.605036  0.704098   0.530411
# 3     4   lightgbm  0.683100  0.625494  0.571635  0.648626   0.510982
# 4     5   lightgbm  0.683957  0.666877  0.493637  0.421484   0.595597
#
#                                      hyperparameters  \
# 0  {'model_name': 'lightgbm', 'n_estimators': 28,...
# 1  {'model_name': 'lightgbm', 'n_estimators': 22,...
# 2  {'model_name': 'lightgbm', 'n_estimators': 28,...
# 3  {'model_name': 'lightgbm', 'n_estimators': 30,...
# 4  {'model_name': 'lightgbm', 'n_estimators': 26,...
#
#                                  checkpoint_path  train_time_seconds  \
# 0  checkpoints_best_models/best_model_fold_1.pkl           12.567255
# 1  checkpoints_best_models/best_model_fold_2.pkl           11.686354
# 2  checkpoints_best_models/best_model_fold_3.pkl            0.949952
# 3  checkpoints_best_models/best_model_fold_4.pkl            0.610070
# 4  checkpoints_best_models/best_model_fold_5.pkl           11.928236
#
#                  trials_log_path
# 0  log_opt/trials_log_fold_1.csv
# 1  log_opt/trials_log_fold_2.csv
# 2  log_opt/trials_log_fold_3.csv
# 3  log_opt/trials_log_fold_4.csv
# 4  log_opt/trials_log_fold_5.csv

# %%
df_results.to_parquet('df_results.parquet')

# %% [markdown]
# Carregando o pkl

# %%
import joblib

modelo = joblib.load("checkpoints_best_models/best_model_fold_1.pkl")

# %%
modelo
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['NU_IDADE_N',
#                                                    'baixa_escolaridade',
#                                                    'raca_vulneravel',
#                                                    'faixa_vulneravel',
#                                                    'vulnerabilidade_social',
#                                                    'mes_sintomas',
#                                                    'periodo_chuvoso']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy...
#                                                    'CLI_DIARRE', 'CLI_OUTROS',
#                                                    'SG_UF',
#                                                    'nivel_vulnerabilidade',
#                                                    'estacao'])])),
#                 ('sampler',
#                  SMOTE(k_neighbors=6, random_state=42,
#                        sampling_strategy='minority')),
#                 ('model',
#                  LGBMClassifier(colsample_bytree=0.7919463813575026,
#                                 device='cpu', force_col_wise=True,
#                                 is_unbalance=True,
#                                 learning_rate=0.18958759630089442, max_depth=8,
#                                 n_estimators=28, random_state=42,
#                                 subsample=0.7337586825891832))])

# %%
modelo.named_steps["preprocessor"].get_feature_names_out()
# Out:
# array(['num__NU_IDADE_N', 'num__baixa_escolaridade',
#        'num__raca_vulneravel', 'num__faixa_vulneravel',
#        'num__vulnerabilidade_social', 'num__mes_sintomas',
#        'num__periodo_chuvoso', 'cat__CS_SEXO_Feminino',
#        'cat__CS_SEXO_Masculino', 'cat__CS_SEXO_Não informado',
#        'cat__CS_GESTANT_1º Trimestre', 'cat__CS_GESTANT_2º Trimestre',
#        'cat__CS_GESTANT_3º Trimestre',
#        'cat__CS_GESTANT_Idade gestacional ignorada',
#        'cat__CS_GESTANT_Não', 'cat__CS_GESTANT_Não informado',
#        'cat__CS_GESTANT_Não se aplica', 'cat__CS_RACA_Amarela',
#        'cat__CS_RACA_Branca', 'cat__CS_RACA_Indígena',
#        'cat__CS_RACA_Não informado', 'cat__CS_RACA_Parda',
#        'cat__CS_RACA_Preta', 'cat__CS_ESCOL_N_10',
#        'cat__CS_ESCOL_N_1ª a 4ª série incompleta do EF',
#        'cat__CS_ESCOL_N_4ª série completa do EF',
#        'cat__CS_ESCOL_N_5ª a 8ª série incompleta do EF',
#        'cat__CS_ESCOL_N_Ensino fundamental completo',
#        'cat__CS_ESCOL_N_Ensino médio completo',
#        'cat__CS_ESCOL_N_Ensino médio incompleto',
#        'cat__CS_ESCOL_N_Não informado',
#        'cat__CS_ESCOL_N_Sem escolaridade',
#        'cat__CS_ESCOL_N_Superior completo',
#        'cat__CS_ESCOL_N_Superior incompleto', 'cat__ID_OCUPA_N_000000',
#        'cat__ID_OCUPA_N_010205', 'cat__ID_OCUPA_N_010210',
#        'cat__ID_OCUPA_N_010310', 'cat__ID_OCUPA_N_010315',
#        'cat__ID_OCUPA_N_020110', 'cat__ID_OCUPA_N_020205',
#        'cat__ID_OCUPA_N_021110', 'cat__ID_OCUPA_N_021205',
#        'cat__ID_OCUPA_N_021210', 'cat__ID_OCUPA_N_031205',
#        'cat__ID_OCUPA_N_031210', 'cat__ID_OCUPA_N_100.01',
#        'cat__ID_OCUPA_N_111120', 'cat__ID_OCUPA_N_111220',
#        'cat__ID_OCUPA_N_111250', 'cat__ID_OCUPA_N_111255',
#        'cat__ID_OCUPA_N_111405', 'cat__ID_OCUPA_N_111415',
#        'cat__ID_OCUPA_N_111510', 'cat__ID_OCUPA_N_122610',
#        'cat__ID_OCUPA_N_123105', 'cat__ID_OCUPA_N_123305',
#        'cat__ID_OCUPA_N_123310', 'cat__ID_OCUPA_N_131310',
#        'cat__ID_OCUPA_N_131320', 'cat__ID_OCUPA_N_141105',
#        'cat__ID_OCUPA_N_141205', 'cat__ID_OCUPA_N_141305',
#        'cat__ID_OCUPA_N_1414.0', 'cat__ID_OCUPA_N_1414.1',
#        'cat__ID_OCUPA_N_141405', 'cat__ID_OCUPA_N_141410',
#        'cat__ID_OCUPA_N_141415', 'cat__ID_OCUPA_N_141505',
#        'cat__ID_OCUPA_N_141510', 'cat__ID_OCUPA_N_1416.1',
#        'cat__ID_OCUPA_N_141615', 'cat__ID_OCUPA_N_141705',
#        'cat__ID_OCUPA_N_141710', 'cat__ID_OCUPA_N_142105',
#        'cat__ID_OCUPA_N_142115', 'cat__ID_OCUPA_N_142305',
#        'cat__ID_OCUPA_N_142320', 'cat__ID_OCUPA_N_142405',
#        'cat__ID_OCUPA_N_142415', 'cat__ID_OCUPA_N_142705',
#        'cat__ID_OCUPA_N_203510', 'cat__ID_OCUPA_N_211205',
#        'cat__ID_OCUPA_N_212.10', 'cat__ID_OCUPA_N_212205',
#        'cat__ID_OCUPA_N_212315', 'cat__ID_OCUPA_N_212410',
#        'cat__ID_OCUPA_N_212415', 'cat__ID_OCUPA_N_213205',
#        'cat__ID_OCUPA_N_213315', 'cat__ID_OCUPA_N_213405',
#        'cat__ID_OCUPA_N_213440', 'cat__ID_OCUPA_N_214005',
#        'cat__ID_OCUPA_N_214010', 'cat__ID_OCUPA_N_214105',
#        'cat__ID_OCUPA_N_214110', 'cat__ID_OCUPA_N_214120',
#        'cat__ID_OCUPA_N_214125', 'cat__ID_OCUPA_N_214205',
#        'cat__ID_OCUPA_N_214215', 'cat__ID_OCUPA_N_214235',
#        'cat__ID_OCUPA_N_214405', 'cat__ID_OCUPA_N_214420',
#        'cat__ID_OCUPA_N_214610', 'cat__ID_OCUPA_N_214615',
#        'cat__ID_OCUPA_N_221105', 'cat__ID_OCUPA_N_221205',
#        'cat__ID_OCUPA_N_222105', 'cat__ID_OCUPA_N_222110',
#        'cat__ID_OCUPA_N_222120', 'cat__ID_OCUPA_N_223106',
#        'cat__ID_OCUPA_N_223110', 'cat__ID_OCUPA_N_223112',
#        'cat__ID_OCUPA_N_223115', 'cat__ID_OCUPA_N_223122',
#        'cat__ID_OCUPA_N_223147', 'cat__ID_OCUPA_N_223149',
#        'cat__ID_OCUPA_N_223151', 'cat__ID_OCUPA_N_223208',
#        'cat__ID_OCUPA_N_2233.1', 'cat__ID_OCUPA_N_223305',
#        'cat__ID_OCUPA_N_223310', 'cat__ID_OCUPA_N_223405',
#        'cat__ID_OCUPA_N_223410', 'cat__ID_OCUPA_N_223415',
#        'cat__ID_OCUPA_N_2235.0', 'cat__ID_OCUPA_N_223505',
#        'cat__ID_OCUPA_N_2236.0', 'cat__ID_OCUPA_N_223605',
#        'cat__ID_OCUPA_N_223610', 'cat__ID_OCUPA_N_223620',
#        'cat__ID_OCUPA_N_223710', 'cat__ID_OCUPA_N_224120',
#        'cat__ID_OCUPA_N_2312.0', 'cat__ID_OCUPA_N_231205',
#        'cat__ID_OCUPA_N_231210', 'cat__ID_OCUPA_N_2313.1',
#        'cat__ID_OCUPA_N_231305', 'cat__ID_OCUPA_N_231310',
#        'cat__ID_OCUPA_N_231315', 'cat__ID_OCUPA_N_231320',
#        'cat__ID_OCUPA_N_231335', 'cat__ID_OCUPA_N_231340',
#        'cat__ID_OCUPA_N_232105', 'cat__ID_OCUPA_N_232110',
#        'cat__ID_OCUPA_N_232115', 'cat__ID_OCUPA_N_232120',
#        'cat__ID_OCUPA_N_232125', 'cat__ID_OCUPA_N_233105',
#        'cat__ID_OCUPA_N_233130', 'cat__ID_OCUPA_N_234305',
#        'cat__ID_OCUPA_N_234320', 'cat__ID_OCUPA_N_234415',
#        'cat__ID_OCUPA_N_234505', 'cat__ID_OCUPA_N_234624',
#        'cat__ID_OCUPA_N_2348.1', 'cat__ID_OCUPA_N_234810',
#        'cat__ID_OCUPA_N_239405', 'cat__ID_OCUPA_N_239410',
#        'cat__ID_OCUPA_N_239415', 'cat__ID_OCUPA_N_239425',
#        'cat__ID_OCUPA_N_241005', 'cat__ID_OCUPA_N_241225',
#        'cat__ID_OCUPA_N_241340', 'cat__ID_OCUPA_N_242235',
#        'cat__ID_OCUPA_N_251205', 'cat__ID_OCUPA_N_251510',
#        'cat__ID_OCUPA_N_251550', 'cat__ID_OCUPA_N_251605',
#        'cat__ID_OCUPA_N_2521.0', 'cat__ID_OCUPA_N_252105',
#        'cat__ID_OCUPA_N_2522.1', 'cat__ID_OCUPA_N_252205',
#        'cat__ID_OCUPA_N_252210', 'cat__ID_OCUPA_N_2523.0',
#        'cat__ID_OCUPA_N_252305', 'cat__ID_OCUPA_N_252515',
#        'cat__ID_OCUPA_N_252525', 'cat__ID_OCUPA_N_252545',
#        'cat__ID_OCUPA_N_253105', 'cat__ID_OCUPA_N_253115',
#        'cat__ID_OCUPA_N_253125', 'cat__ID_OCUPA_N_253205',
#        'cat__ID_OCUPA_N_253305', 'cat__ID_OCUPA_N_254310',
#        'cat__ID_OCUPA_N_254405', 'cat__ID_OCUPA_N_261125',
#        'cat__ID_OCUPA_N_261140', 'cat__ID_OCUPA_N_261205',
#        'cat__ID_OCUPA_N_261505', 'cat__ID_OCUPA_N_2617.0',
#        'cat__ID_OCUPA_N_2617.1', 'cat__ID_OCUPA_N_261730',
#        'cat__ID_OCUPA_N_261805', 'cat__ID_OCUPA_N_262105',
#        'cat__ID_OCUPA_N_262410', 'cat__ID_OCUPA_N_262705',
#        'cat__ID_OCUPA_N_262710', 'cat__ID_OCUPA_N_263110',
#        'cat__ID_OCUPA_N_271110', 'cat__ID_OCUPA_N_300305',
#        'cat__ID_OCUPA_N_301105', 'cat__ID_OCUPA_N_301110',
#        'cat__ID_OCUPA_N_311515', 'cat__ID_OCUPA_N_312.05',
#        'cat__ID_OCUPA_N_312105', 'cat__ID_OCUPA_N_312210',
#        'cat__ID_OCUPA_N_312305', 'cat__ID_OCUPA_N_312320',
#        'cat__ID_OCUPA_N_313105', 'cat__ID_OCUPA_N_313110',
#        'cat__ID_OCUPA_N_313120', 'cat__ID_OCUPA_N_313125',
#        'cat__ID_OCUPA_N_313130', 'cat__ID_OCUPA_N_313205',
#        'cat__ID_OCUPA_N_313215', 'cat__ID_OCUPA_N_313220',
#        'cat__ID_OCUPA_N_313305', 'cat__ID_OCUPA_N_313310',
#        'cat__ID_OCUPA_N_313315', 'cat__ID_OCUPA_N_313410',
#        'cat__ID_OCUPA_N_314105', 'cat__ID_OCUPA_N_314110',
#        'cat__ID_OCUPA_N_314115', 'cat__ID_OCUPA_N_314120',
#        'cat__ID_OCUPA_N_314405', 'cat__ID_OCUPA_N_314410',
#        'cat__ID_OCUPA_N_317105', 'cat__ID_OCUPA_N_317210',
#        'cat__ID_OCUPA_N_318015', 'cat__ID_OCUPA_N_3183.0',
#        'cat__ID_OCUPA_N_318405', 'cat__ID_OCUPA_N_318610',
#        'cat__ID_OCUPA_N_321105', 'cat__ID_OCUPA_N_321110',
#        'cat__ID_OCUPA_N_3222.3', 'cat__ID_OCUPA_N_322205',
#        'cat__ID_OCUPA_N_322225', 'cat__ID_OCUPA_N_322230',
#        'cat__ID_OCUPA_N_322430', 'cat__ID_OCUPA_N_3224F2',
#        'cat__ID_OCUPA_N_324115', 'cat__ID_OCUPA_N_324120',
#        'cat__ID_OCUPA_N_325110', 'cat__ID_OCUPA_N_331105',
#        'cat__ID_OCUPA_N_331110', 'cat__ID_OCUPA_N_331205',
#        'cat__ID_OCUPA_N_332205', 'cat__ID_OCUPA_N_333105',
#        'cat__ID_OCUPA_N_333110', 'cat__ID_OCUPA_N_333115',
#        'cat__ID_OCUPA_N_334110', 'cat__ID_OCUPA_N_334115',
#        'cat__ID_OCUPA_N_341120', 'cat__ID_OCUPA_N_341230',
#        'cat__ID_OCUPA_N_341310', 'cat__ID_OCUPA_N_342120',
#        'cat__ID_OCUPA_N_342205', 'cat__ID_OCUPA_N_342210',
#        'cat__ID_OCUPA_N_342315', 'cat__ID_OCUPA_N_342510',
#        'cat__ID_OCUPA_N_351115', 'cat__ID_OCUPA_N_351305',
#        'cat__ID_OCUPA_N_351605', 'cat__ID_OCUPA_N_3517.4',
#        'cat__ID_OCUPA_N_351740', 'cat__ID_OCUPA_N_352210',
#        'cat__ID_OCUPA_N_352310', 'cat__ID_OCUPA_N_352405',
#        'cat__ID_OCUPA_N_353230', 'cat__ID_OCUPA_N_3541.4',
#        'cat__ID_OCUPA_N_354120', 'cat__ID_OCUPA_N_354145',
#        'cat__ID_OCUPA_N_354415', 'cat__ID_OCUPA_N_354505',
#        'cat__ID_OCUPA_N_354605', 'cat__ID_OCUPA_N_3547.0',
#        'cat__ID_OCUPA_N_354705', 'cat__ID_OCUPA_N_371410',
#        'cat__ID_OCUPA_N_372210', 'cat__ID_OCUPA_N_373105',
#        'cat__ID_OCUPA_N_375115', 'cat__ID_OCUPA_N_375120',
#        'cat__ID_OCUPA_N_376110', 'cat__ID_OCUPA_N_376215',
#        'cat__ID_OCUPA_N_376225', 'cat__ID_OCUPA_N_376235',
#        'cat__ID_OCUPA_N_376305', 'cat__ID_OCUPA_N_377105',
#        'cat__ID_OCUPA_N_391110', 'cat__ID_OCUPA_N_391120',
#        'cat__ID_OCUPA_N_391125', 'cat__ID_OCUPA_N_391205',
#        'cat__ID_OCUPA_N_410105', 'cat__ID_OCUPA_N_410205',
#        'cat__ID_OCUPA_N_4110.0', 'cat__ID_OCUPA_N_4110.1',
#        'cat__ID_OCUPA_N_4110.3', 'cat__ID_OCUPA_N_411005',
#        'cat__ID_OCUPA_N_411010', 'cat__ID_OCUPA_N_411020',
#        'cat__ID_OCUPA_N_411030', 'cat__ID_OCUPA_N_411040',
#        'cat__ID_OCUPA_N_411045', 'cat__ID_OCUPA_N_412110',
#        'cat__ID_OCUPA_N_412205', 'cat__ID_OCUPA_N_413110',
#        'cat__ID_OCUPA_N_413205', 'cat__ID_OCUPA_N_413210',
#        'cat__ID_OCUPA_N_413220', 'cat__ID_OCUPA_N_414105',
#        'cat__ID_OCUPA_N_414110', 'cat__ID_OCUPA_N_414205',
#        'cat__ID_OCUPA_N_414210', 'cat__ID_OCUPA_N_414215',
#        'cat__ID_OCUPA_N_415205', 'cat__ID_OCUPA_N_420135',
#        'cat__ID_OCUPA_N_4211.2', 'cat__ID_OCUPA_N_421105',
#        'cat__ID_OCUPA_N_421125', 'cat__ID_OCUPA_N_422105',
#        'cat__ID_OCUPA_N_422110', 'cat__ID_OCUPA_N_422120',
#        'cat__ID_OCUPA_N_422125', 'cat__ID_OCUPA_N_422205',
#        'cat__ID_OCUPA_N_422210', 'cat__ID_OCUPA_N_422305',
#        'cat__ID_OCUPA_N_422310', 'cat__ID_OCUPA_N_423105',
#        'cat__ID_OCUPA_N_510120', 'cat__ID_OCUPA_N_510125',
#        'cat__ID_OCUPA_N_510130', 'cat__ID_OCUPA_N_511215',
#        'cat__ID_OCUPA_N_511405', 'cat__ID_OCUPA_N_5121.0',
#        'cat__ID_OCUPA_N_512105', 'cat__ID_OCUPA_N_512110',
#        'cat__ID_OCUPA_N_512115', 'cat__ID_OCUPA_N_512120',
#        'cat__ID_OCUPA_N_513115', 'cat__ID_OCUPA_N_5132.0',
#        'cat__ID_OCUPA_N_513205', 'cat__ID_OCUPA_N_513210',
#        'cat__ID_OCUPA_N_513215', 'cat__ID_OCUPA_N_5133.1',
#        'cat__ID_OCUPA_N_513315', 'cat__ID_OCUPA_N_513405',
#        'cat__ID_OCUPA_N_513420', 'cat__ID_OCUPA_N_513425',
#        'cat__ID_OCUPA_N_513435', 'cat__ID_OCUPA_N_513505',
#        'cat__ID_OCUPA_N_513605', 'cat__ID_OCUPA_N_513610',
#        'cat__ID_OCUPA_N_513615', 'cat__ID_OCUPA_N_514105',
#        'cat__ID_OCUPA_N_514120', 'cat__ID_OCUPA_N_5142.1',
#        'cat__ID_OCUPA_N_514205', 'cat__ID_OCUPA_N_514210',
#        'cat__ID_OCUPA_N_514215', 'cat__ID_OCUPA_N_514225',
#        'cat__ID_OCUPA_N_514230', 'cat__ID_OCUPA_N_514310',
#        'cat__ID_OCUPA_N_514330', 'cat__ID_OCUPA_N_515105',
#        'cat__ID_OCUPA_N_5152.1', 'cat__ID_OCUPA_N_5152.2',
#        'cat__ID_OCUPA_N_515210', 'cat__ID_OCUPA_N_515215',
#        'cat__ID_OCUPA_N_515225', 'cat__ID_OCUPA_N_515305',
#        'cat__ID_OCUPA_N_515320', 'cat__ID_OCUPA_N_5161.1',
#        'cat__ID_OCUPA_N_516105', 'cat__ID_OCUPA_N_516110',
#        'cat__ID_OCUPA_N_516115', 'cat__ID_OCUPA_N_516120',
#        'cat__ID_OCUPA_N_516125', 'cat__ID_OCUPA_N_516205',
#        'cat__ID_OCUPA_N_516210', 'cat__ID_OCUPA_N_516220',
#        'cat__ID_OCUPA_N_516305', 'cat__ID_OCUPA_N_516320',
#        'cat__ID_OCUPA_N_516330', 'cat__ID_OCUPA_N_516335',
#        'cat__ID_OCUPA_N_516345', 'cat__ID_OCUPA_N_516405',
#        'cat__ID_OCUPA_N_516505', 'cat__ID_OCUPA_N_516610',
#        'cat__ID_OCUPA_N_517105', 'cat__ID_OCUPA_N_517110',
#        'cat__ID_OCUPA_N_517115', 'cat__ID_OCUPA_N_517210',
#        'cat__ID_OCUPA_N_517215', 'cat__ID_OCUPA_N_517220',
#        'cat__ID_OCUPA_N_5173.1', 'cat__ID_OCUPA_N_517310',
#        'cat__ID_OCUPA_N_517315', 'cat__ID_OCUPA_N_517330',
#        'cat__ID_OCUPA_N_517405', 'cat__ID_OCUPA_N_517410',
#        'cat__ID_OCUPA_N_517415', 'cat__ID_OCUPA_N_517420',
#        'cat__ID_OCUPA_N_5191.1', 'cat__ID_OCUPA_N_519110',
#        'cat__ID_OCUPA_N_5192.0', 'cat__ID_OCUPA_N_519205',
#        'cat__ID_OCUPA_N_519210', 'cat__ID_OCUPA_N_519315',
#        'cat__ID_OCUPA_N_519905', 'cat__ID_OCUPA_N_519910',
#        'cat__ID_OCUPA_N_519915', 'cat__ID_OCUPA_N_519925',
#        'cat__ID_OCUPA_N_519935', 'cat__ID_OCUPA_N_519940',
#        'cat__ID_OCUPA_N_520110', 'cat__ID_OCUPA_N_5211.1',
#        'cat__ID_OCUPA_N_521105', 'cat__ID_OCUPA_N_521110',
#        'cat__ID_OCUPA_N_521115', 'cat__ID_OCUPA_N_521125',
#        'cat__ID_OCUPA_N_521130', 'cat__ID_OCUPA_N_521135',
#        'cat__ID_OCUPA_N_523105', 'cat__ID_OCUPA_N_523110',
#        'cat__ID_OCUPA_N_523115', 'cat__ID_OCUPA_N_524105',
#        'cat__ID_OCUPA_N_524205', 'cat__ID_OCUPA_N_524210',
#        'cat__ID_OCUPA_N_524215', 'cat__ID_OCUPA_N_524305',
#        'cat__ID_OCUPA_N_6110.0', 'cat__ID_OCUPA_N_611005',
#        'cat__ID_OCUPA_N_612005', 'cat__ID_OCUPA_N_612105',
#        'cat__ID_OCUPA_N_612125', 'cat__ID_OCUPA_N_612315',
#        'cat__ID_OCUPA_N_612410', 'cat__ID_OCUPA_N_612420',
#        'cat__ID_OCUPA_N_612505', 'cat__ID_OCUPA_N_612510',
#        'cat__ID_OCUPA_N_612605', 'cat__ID_OCUPA_N_612620',
#        'cat__ID_OCUPA_N_612740', 'cat__ID_OCUPA_N_613005',
#        'cat__ID_OCUPA_N_613010', 'cat__ID_OCUPA_N_6131.1',
#        'cat__ID_OCUPA_N_613110', 'cat__ID_OCUPA_N_613115',
#        'cat__ID_OCUPA_N_613130', 'cat__ID_OCUPA_N_613215',
#        'cat__ID_OCUPA_N_613305', 'cat__ID_OCUPA_N_613405',
#        'cat__ID_OCUPA_N_613410', 'cat__ID_OCUPA_N_613420',
#        'cat__ID_OCUPA_N_620110', 'cat__ID_OCUPA_N_6210.0',
#        'cat__ID_OCUPA_N_621005', 'cat__ID_OCUPA_N_6220.0',
#        'cat__ID_OCUPA_N_6220.2', 'cat__ID_OCUPA_N_622005',
#        'cat__ID_OCUPA_N_622010', 'cat__ID_OCUPA_N_622015',
#        'cat__ID_OCUPA_N_622020', 'cat__ID_OCUPA_N_622105',
#        'cat__ID_OCUPA_N_622110', 'cat__ID_OCUPA_N_622115',
#        'cat__ID_OCUPA_N_622120', 'cat__ID_OCUPA_N_622310',
#        'cat__ID_OCUPA_N_622315', 'cat__ID_OCUPA_N_622320',
#        'cat__ID_OCUPA_N_622405', 'cat__ID_OCUPA_N_622425',
#        'cat__ID_OCUPA_N_622505', 'cat__ID_OCUPA_N_622515',
#        'cat__ID_OCUPA_N_6226.1', 'cat__ID_OCUPA_N_622610',
#        'cat__ID_OCUPA_N_622615', 'cat__ID_OCUPA_N_622620',
#        'cat__ID_OCUPA_N_622730', 'cat__ID_OCUPA_N_623005',
#        'cat__ID_OCUPA_N_623015', 'cat__ID_OCUPA_N_623020',
#        'cat__ID_OCUPA_N_623110', 'cat__ID_OCUPA_N_623115',
#        'cat__ID_OCUPA_N_623125', 'cat__ID_OCUPA_N_623215',
#        'cat__ID_OCUPA_N_623305', 'cat__ID_OCUPA_N_623310',
#        'cat__ID_OCUPA_N_630110', 'cat__ID_OCUPA_N_631005',
#        'cat__ID_OCUPA_N_631010', 'cat__ID_OCUPA_N_631020',
#        'cat__ID_OCUPA_N_631105', 'cat__ID_OCUPA_N_631205',
#        'cat__ID_OCUPA_N_631210', 'cat__ID_OCUPA_N_631325',
#        'cat__ID_OCUPA_N_632015', 'cat__ID_OCUPA_N_632120',
#        'cat__ID_OCUPA_N_632125', 'cat__ID_OCUPA_N_632205',
#        'cat__ID_OCUPA_N_632215', 'cat__ID_OCUPA_N_632330',
#        'cat__ID_OCUPA_N_632405', 'cat__ID_OCUPA_N_632420',
#        'cat__ID_OCUPA_N_632505', 'cat__ID_OCUPA_N_632525',
#        'cat__ID_OCUPA_N_641005', 'cat__ID_OCUPA_N_641010',
#        'cat__ID_OCUPA_N_641015', 'cat__ID_OCUPA_N_643005',
#        'cat__ID_OCUPA_N_643025', 'cat__ID_OCUPA_N_710205',
#        'cat__ID_OCUPA_N_711205', 'cat__ID_OCUPA_N_711215',
#        'cat__ID_OCUPA_N_711225', 'cat__ID_OCUPA_N_711320',
#        'cat__ID_OCUPA_N_711325', 'cat__ID_OCUPA_N_711405',
#        'cat__ID_OCUPA_N_712115', 'cat__ID_OCUPA_N_712205',
#        'cat__ID_OCUPA_N_712220', 'cat__ID_OCUPA_N_712225',
#        'cat__ID_OCUPA_N_712230', 'cat__ID_OCUPA_N_7151.4',
#        'cat__ID_OCUPA_N_715105', 'cat__ID_OCUPA_N_715115',
#        'cat__ID_OCUPA_N_715120', 'cat__ID_OCUPA_N_715125',
#        'cat__ID_OCUPA_N_715135', 'cat__ID_OCUPA_N_715140',
#        'cat__ID_OCUPA_N_7152.1', 'cat__ID_OCUPA_N_715205',
#        'cat__ID_OCUPA_N_715210', 'cat__ID_OCUPA_N_715225',
#        'cat__ID_OCUPA_N_715230', 'cat__ID_OCUPA_N_715305',
#        'cat__ID_OCUPA_N_715315', 'cat__ID_OCUPA_N_715405',
#        'cat__ID_OCUPA_N_715410', 'cat__ID_OCUPA_N_715505',
#        'cat__ID_OCUPA_N_715510', 'cat__ID_OCUPA_N_715520',
#        'cat__ID_OCUPA_N_715525', 'cat__ID_OCUPA_N_715540',
#        'cat__ID_OCUPA_N_715545', 'cat__ID_OCUPA_N_715615',
#        'cat__ID_OCUPA_N_715715', 'cat__ID_OCUPA_N_715730',
#        'cat__ID_OCUPA_N_716305', 'cat__ID_OCUPA_N_716310',
#        'cat__ID_OCUPA_N_716405', 'cat__ID_OCUPA_N_716525',
#        'cat__ID_OCUPA_N_716610', 'cat__ID_OCUPA_N_7170.2',
#        'cat__ID_OCUPA_N_717005', 'cat__ID_OCUPA_N_717015',
#        'cat__ID_OCUPA_N_717020', 'cat__ID_OCUPA_N_720135',
#        'cat__ID_OCUPA_N_720155', 'cat__ID_OCUPA_N_721105',
#        'cat__ID_OCUPA_N_721110', 'cat__ID_OCUPA_N_721210',
#        'cat__ID_OCUPA_N_721215', 'cat__ID_OCUPA_N_721225',
#        'cat__ID_OCUPA_N_721310', 'cat__ID_OCUPA_N_721325',
#        'cat__ID_OCUPA_N_721415', 'cat__ID_OCUPA_N_721425',
#        'cat__ID_OCUPA_N_721430', 'cat__ID_OCUPA_N_722105',
#        'cat__ID_OCUPA_N_722205', 'cat__ID_OCUPA_N_722215',
#        'cat__ID_OCUPA_N_722225', 'cat__ID_OCUPA_N_722330',
#        'cat__ID_OCUPA_N_723105', 'cat__ID_OCUPA_N_723220',
#        'cat__ID_OCUPA_N_723225', 'cat__ID_OCUPA_N_7233.1',
#        'cat__ID_OCUPA_N_7233.2', 'cat__ID_OCUPA_N_723310',
#        'cat__ID_OCUPA_N_723315', 'cat__ID_OCUPA_N_723320',
#        'cat__ID_OCUPA_N_723330', 'cat__ID_OCUPA_N_724110',
#        'cat__ID_OCUPA_N_724115', 'cat__ID_OCUPA_N_724205',
#        'cat__ID_OCUPA_N_724220', 'cat__ID_OCUPA_N_7243.1',
#        'cat__ID_OCUPA_N_724315', 'cat__ID_OCUPA_N_724325',
#        'cat__ID_OCUPA_N_7244.4', 'cat__ID_OCUPA_N_724405',
#        'cat__ID_OCUPA_N_724410', 'cat__ID_OCUPA_N_724415',
#        'cat__ID_OCUPA_N_724435', 'cat__ID_OCUPA_N_724440',
#        'cat__ID_OCUPA_N_724505', 'cat__ID_OCUPA_N_724510',
#        'cat__ID_OCUPA_N_7250.1', 'cat__ID_OCUPA_N_725005',
#        'cat__ID_OCUPA_N_725010', 'cat__ID_OCUPA_N_725015',
#        'cat__ID_OCUPA_N_725205', 'cat__ID_OCUPA_N_725310',
#        'cat__ID_OCUPA_N_725505', 'cat__ID_OCUPA_N_725705',
#        'cat__ID_OCUPA_N_7311.3', 'cat__ID_OCUPA_N_731125',
#        'cat__ID_OCUPA_N_731135', 'cat__ID_OCUPA_N_731150',
#        'cat__ID_OCUPA_N_731155', 'cat__ID_OCUPA_N_731180',
#        'cat__ID_OCUPA_N_731320', 'cat__ID_OCUPA_N_732105',
#        'cat__ID_OCUPA_N_740105', 'cat__ID_OCUPA_N_751010',
#        'cat__ID_OCUPA_N_751015', 'cat__ID_OCUPA_N_752105',
#        'cat__ID_OCUPA_N_752305', 'cat__ID_OCUPA_N_752430',
#        'cat__ID_OCUPA_N_760105', 'cat__ID_OCUPA_N_761215',
#        'cat__ID_OCUPA_N_761309', 'cat__ID_OCUPA_N_761321',
#        'cat__ID_OCUPA_N_761327', 'cat__ID_OCUPA_N_761345',
#        'cat__ID_OCUPA_N_762005', 'cat__ID_OCUPA_N_762110',
#        'cat__ID_OCUPA_N_762205', 'cat__ID_OCUPA_N_762315',
#        'cat__ID_OCUPA_N_762345', 'cat__ID_OCUPA_N_7630.1',
#        'cat__ID_OCUPA_N_763010', 'cat__ID_OCUPA_N_763015',
#        'cat__ID_OCUPA_N_763105', 'cat__ID_OCUPA_N_763110',
#        'cat__ID_OCUPA_N_763125', 'cat__ID_OCUPA_N_763205',
#        'cat__ID_OCUPA_N_763210', 'cat__ID_OCUPA_N_763215',
#        'cat__ID_OCUPA_N_763320', 'cat__ID_OCUPA_N_764005',
#        'cat__ID_OCUPA_N_764205', 'cat__ID_OCUPA_N_764305',
#        'cat__ID_OCUPA_N_765110', 'cat__ID_OCUPA_N_7652.3',
#        'cat__ID_OCUPA_N_765235', 'cat__ID_OCUPA_N_765315',
#        'cat__ID_OCUPA_N_765405', 'cat__ID_OCUPA_N_766205',
#        'cat__ID_OCUPA_N_768110', 'cat__ID_OCUPA_N_768315',
#        'cat__ID_OCUPA_N_768320', 'cat__ID_OCUPA_N_768625',
#        'cat__ID_OCUPA_N_771105', 'cat__ID_OCUPA_N_771110',
#        'cat__ID_OCUPA_N_771115', 'cat__ID_OCUPA_N_772105',
#        'cat__ID_OCUPA_N_773105', 'cat__ID_OCUPA_N_773120',
#        'cat__ID_OCUPA_N_773130', 'cat__ID_OCUPA_N_773325',
#        'cat__ID_OCUPA_N_773505', 'cat__ID_OCUPA_N_773510',
#        'cat__ID_OCUPA_N_774105', 'cat__ID_OCUPA_N_775105',
#        'cat__ID_OCUPA_N_776430', 'cat__ID_OCUPA_N_777105',
#        'cat__ID_OCUPA_N_781705', 'cat__ID_OCUPA_N_782105',
#        'cat__ID_OCUPA_N_782110', 'cat__ID_OCUPA_N_782125',
#        'cat__ID_OCUPA_N_782220', 'cat__ID_OCUPA_N_7823.0',
#        'cat__ID_OCUPA_N_7823.1', 'cat__ID_OCUPA_N_782305',
#        'cat__ID_OCUPA_N_782310', 'cat__ID_OCUPA_N_782315',
#        'cat__ID_OCUPA_N_7824.1', 'cat__ID_OCUPA_N_782405',
#        'cat__ID_OCUPA_N_782410', 'cat__ID_OCUPA_N_782415',
#        'cat__ID_OCUPA_N_7825.0', 'cat__ID_OCUPA_N_7825.1',
#        'cat__ID_OCUPA_N_782505', 'cat__ID_OCUPA_N_782510',
#        'cat__ID_OCUPA_N_782515', 'cat__ID_OCUPA_N_782610',
#        'cat__ID_OCUPA_N_782620', 'cat__ID_OCUPA_N_782625',
#        'cat__ID_OCUPA_N_782705', 'cat__ID_OCUPA_N_782710',
#        'cat__ID_OCUPA_N_782805', 'cat__ID_OCUPA_N_782815',
#        'cat__ID_OCUPA_N_782820', 'cat__ID_OCUPA_N_783110',
#        'cat__ID_OCUPA_N_7832.1', 'cat__ID_OCUPA_N_7832.2',
#        'cat__ID_OCUPA_N_783205', 'cat__ID_OCUPA_N_783210',
#        'cat__ID_OCUPA_N_783215', 'cat__ID_OCUPA_N_783220',
#        'cat__ID_OCUPA_N_783225', 'cat__ID_OCUPA_N_784105',
#        'cat__ID_OCUPA_N_784110', 'cat__ID_OCUPA_N_784205',
#        'cat__ID_OCUPA_N_791105', 'cat__ID_OCUPA_N_791115',
#        'cat__ID_OCUPA_N_791130', 'cat__ID_OCUPA_N_791140',
#        'cat__ID_OCUPA_N_811110', 'cat__ID_OCUPA_N_811115',
#        'cat__ID_OCUPA_N_813125', 'cat__ID_OCUPA_N_821105',
#        'cat__ID_OCUPA_N_821305', 'cat__ID_OCUPA_N_821405',
#        'cat__ID_OCUPA_N_821410', 'cat__ID_OCUPA_N_821415',
#        'cat__ID_OCUPA_N_821430', 'cat__ID_OCUPA_N_821435',
#        'cat__ID_OCUPA_N_821445', 'cat__ID_OCUPA_N_822110',
#        'cat__ID_OCUPA_N_822120', 'cat__ID_OCUPA_N_823130',
#        'cat__ID_OCUPA_N_823315', 'cat__ID_OCUPA_N_823320',
#        'cat__ID_OCUPA_N_828110', 'cat__ID_OCUPA_N_832115',
#        'cat__ID_OCUPA_N_840110', 'cat__ID_OCUPA_N_841115',
#        'cat__ID_OCUPA_N_841310', 'cat__ID_OCUPA_N_841408',
#        'cat__ID_OCUPA_N_841416', 'cat__ID_OCUPA_N_841456',
#        'cat__ID_OCUPA_N_841460', 'cat__ID_OCUPA_N_841505',
#        'cat__ID_OCUPA_N_841705', 'cat__ID_OCUPA_N_841710',
#        'cat__ID_OCUPA_N_842110', 'cat__ID_OCUPA_N_848210',
#        'cat__ID_OCUPA_N_8483.0', 'cat__ID_OCUPA_N_848305',
#        'cat__ID_OCUPA_N_848310', 'cat__ID_OCUPA_N_848405',
#        'cat__ID_OCUPA_N_848425', 'cat__ID_OCUPA_N_8485.1',
#        'cat__ID_OCUPA_N_848505', 'cat__ID_OCUPA_N_848510',
#        'cat__ID_OCUPA_N_848515', 'cat__ID_OCUPA_N_848520',
#        'cat__ID_OCUPA_N_848605', 'cat__ID_OCUPA_N_860105',
#        'cat__ID_OCUPA_N_860110', 'cat__ID_OCUPA_N_862110',
#        'cat__ID_OCUPA_N_862120', 'cat__ID_OCUPA_N_862140',
#        'cat__ID_OCUPA_N_862150', 'cat__ID_OCUPA_N_862205',
#        'cat__ID_OCUPA_N_862305', 'cat__ID_OCUPA_N_862310',
#        'cat__ID_OCUPA_N_862515', 'cat__ID_OCUPA_N_910105',
#        'cat__ID_OCUPA_N_911115', 'cat__ID_OCUPA_N_911120',
#        'cat__ID_OCUPA_N_911205', 'cat__ID_OCUPA_N_911305',
#        'cat__ID_OCUPA_N_911320', 'cat__ID_OCUPA_N_9131.1',
#        'cat__ID_OCUPA_N_913110', 'cat__ID_OCUPA_N_913115',
#        'cat__ID_OCUPA_N_914105', 'cat__ID_OCUPA_N_914205',
#        'cat__ID_OCUPA_N_914305', 'cat__ID_OCUPA_N_9144.0',
#        'cat__ID_OCUPA_N_9144.2', 'cat__ID_OCUPA_N_914405',
#        'cat__ID_OCUPA_N_914410', 'cat__ID_OCUPA_N_914415',
#        'cat__ID_OCUPA_N_914420', 'cat__ID_OCUPA_N_914425',
#        'cat__ID_OCUPA_N_915115', 'cat__ID_OCUPA_N_915305',
#        'cat__ID_OCUPA_N_919110', 'cat__ID_OCUPA_N_919310',
#        'cat__ID_OCUPA_N_919315', 'cat__ID_OCUPA_N_950205',
#        'cat__ID_OCUPA_N_951105', 'cat__ID_OCUPA_N_951305',
#        'cat__ID_OCUPA_N_953115', 'cat__ID_OCUPA_N_954105',
#        'cat__ID_OCUPA_N_954120', 'cat__ID_OCUPA_N_991105',
#        'cat__ID_OCUPA_N_991110', 'cat__ID_OCUPA_N_991115',
#        'cat__ID_OCUPA_N_991205', 'cat__ID_OCUPA_N_991305',
#        'cat__ID_OCUPA_N_991310', 'cat__ID_OCUPA_N_991315',
#        'cat__ID_OCUPA_N_991405', 'cat__ID_OCUPA_N_991415',
#        'cat__ID_OCUPA_N_992115', 'cat__ID_OCUPA_N_992205',
#        'cat__ID_OCUPA_N_992210', 'cat__ID_OCUPA_N_992220',
#        'cat__ID_OCUPA_N_992225', 'cat__ID_OCUPA_N_998999',
#        'cat__ID_OCUPA_N_9999.9', 'cat__ID_OCUPA_N_999991',
#        'cat__ID_OCUPA_N_999992', 'cat__ID_OCUPA_N_999993',
#        'cat__ID_OCUPA_N_999994', 'cat__ID_OCUPA_N_999995',
#        'cat__ID_OCUPA_N_Não informado', 'cat__ID_OCUPA_N_XXX',
#        'cat__CON_AREA_Não informado', 'cat__CON_AREA_Periurbana',
#        'cat__CON_AREA_Rural', 'cat__CON_AREA_Urbana',
#        'cat__CON_AMBIEN_Domicílio', 'cat__CON_AMBIEN_Lazer',
#        'cat__CON_AMBIEN_Não informado', 'cat__CON_AMBIEN_Outro',
#        'cat__CON_AMBIEN_Trabalho', 'cat__ANT_CB_LAM_Não',
#        'cat__ANT_CB_LAM_Não informado', 'cat__ANT_CB_LAM_Sim',
#        'cat__ANT_CB_CRI_Não', 'cat__ANT_CB_CRI_Não informado',
#        'cat__ANT_CB_CRI_Sim', 'cat__ANT_CB_SIN_Não',
#        'cat__ANT_CB_SIN_Não informado', 'cat__ANT_CB_SIN_Sim',
#        'cat__ANT_CB_COR_Não', 'cat__ANT_CB_COR_Não informado',
#        'cat__ANT_CB_COR_Sim', 'cat__ANT_CB_ROE_Não',
#        'cat__ANT_CB_ROE_Não informado', 'cat__ANT_CB_ROE_Sim',
#        'cat__ANT_CB_TER_Não', 'cat__ANT_CB_TER_Não informado',
#        'cat__ANT_CB_TER_Sim', 'cat__ANT_CB_LIX_Não',
#        'cat__ANT_CB_LIX_Não informado', 'cat__ANT_CB_LIX_Sim',
#        'cat__ANT_CB_OUT_Não', 'cat__ANT_CB_OUT_Não informado',
#        'cat__ANT_CB_OUT_Sim', 'cat__ANT_ANIMAI_Não',
#        'cat__ANT_ANIMAI_Não informado', 'cat__ANT_ANIMAI_Sim',
#        'cat__ANT_HUMANO_Não', 'cat__ANT_HUMANO_Não informado',
#        'cat__ANT_HUMANO_Sim', 'cat__CLI_FEBRE_Não',
#        'cat__CLI_FEBRE_Não informado', 'cat__CLI_FEBRE_Sim',
#        'cat__CLI_MIALGI_Não', 'cat__CLI_MIALGI_Não informado',
#        'cat__CLI_MIALGI_Sim', 'cat__CLI_CEFALE_Não',
#        'cat__CLI_CEFALE_Não informado', 'cat__CLI_CEFALE_Sim',
#        'cat__CLI_PROST_Não', 'cat__CLI_PROST_Não informado',
#        'cat__CLI_PROST_Sim', 'cat__CLI_CONGES_Não',
#        'cat__CLI_CONGES_Não informado', 'cat__CLI_CONGES_Sim',
#        'cat__CLI_PANTUR_Não', 'cat__CLI_PANTUR_Não informado',
#        'cat__CLI_PANTUR_Sim', 'cat__CLI_VOMITO_Não',
#        'cat__CLI_VOMITO_Não informado', 'cat__CLI_VOMITO_Sim',
#        'cat__CLI_DIARRE_Não', 'cat__CLI_DIARRE_Não informado',
#        'cat__CLI_DIARRE_Sim', 'cat__CLI_OUTROS_Não',
#        'cat__CLI_OUTROS_Não informado', 'cat__CLI_OUTROS_Sim',
#        'cat__SG_UF_AC', 'cat__SG_UF_AL', 'cat__SG_UF_AM', 'cat__SG_UF_AP',
#        'cat__SG_UF_BA', 'cat__SG_UF_CE', 'cat__SG_UF_DF', 'cat__SG_UF_ES',
#        'cat__SG_UF_GO', 'cat__SG_UF_MA', 'cat__SG_UF_MG', 'cat__SG_UF_MS',
#        'cat__SG_UF_MT', 'cat__SG_UF_Não informado', 'cat__SG_UF_PA',
#        'cat__SG_UF_PB', 'cat__SG_UF_PE', 'cat__SG_UF_PI', 'cat__SG_UF_PR',
#        'cat__SG_UF_RJ', 'cat__SG_UF_RN', 'cat__SG_UF_RO', 'cat__SG_UF_RR',
#        'cat__SG_UF_RS', 'cat__SG_UF_SC', 'cat__SG_UF_SE', 'cat__SG_UF_SP',
#        'cat__SG_UF_TO', 'cat__nivel_vulnerabilidade_Alta',
#        'cat__nivel_vulnerabilidade_Baixa',
#        'cat__nivel_vulnerabilidade_Moderada', 'cat__estacao_Inverno',
#        'cat__estacao_Outono', 'cat__estacao_Primavera',
#        'cat__estacao_Verão'], dtype=object)

# %%
modelo.predict(X_data.iloc[-10:])
# Out:
# array([0, 1, 1, 1, 0, 0, 0, 0, 1, 0])

# %% [markdown]
# ## Avaliação de desempenho e custo computacional
#
# Nesta seção são avaliados os modelos selecionados ao longo dos folds da validação cruzada externa,
# considerando simultaneamente **qualidade preditiva** e **custo computacional**.
# Essa análise conjunta é fundamental para evitar escolhas baseadas apenas em desempenho,
# desconsiderando viabilidade prática de treinamento e manutenção do modelo.
#
# ### Métricas de desempenho preditivo
#
# O desempenho dos modelos é avaliado por meio de múltiplas métricas,
# permitindo uma análise abrangente do comportamento preditivo:
#
# - **ROC-AUC (OvR, weighted)**: métrica principal de comparação, pois avalia a capacidade de separação entre classes
# em cenários multiclasse e desbalanceados, utilizando probabilidades preditas.
# - **Accuracy**: fornece uma visão global de acerto, mas pode ser influenciada por classes majoritárias.
# - **F1-score (weighted)**: equilibra precisão e recall, sendo mais informativo quando há assimetria entre classes.
# - **Recall (weighted)**: mede a capacidade do modelo em identificar corretamente instâncias relevantes,
# importante em contextos onde falsos negativos possuem maior custo.
# - **Precision (weighted)**: avalia a confiabilidade das predições positivas,
# sendo relevante quando falsos positivos impactam decisões downstream.
#
# A análise por fold permite verificar não apenas o valor médio das métricas,
# mas também sua **estabilidade**, reduzindo o risco de overfitting a uma partição específica dos dados.

# %%
def read_and_consolidate_optuna_logs(
    log_dir: str = "log_opt",
    pattern: str = "trials_log_fold_*.csv",
    fold_col_name: str = "outer_fold",
    keep_only_complete: bool = True,
) -> pd.DataFrame:
    """
    Lê todos os arquivos de log do Optuna (1 por fold) e consolida em um único DataFrame.

    Espera arquivos no formato: trials_log_fold_{k}.csv (gerados por dump_trials).

    Parâmetros
    ----------
    log_dir : str
        Diretório onde os logs estão salvos.
    pattern : str
        Padrão dos arquivos dentro do log_dir.
    fold_col_name : str
        Nome da coluna que será criada para identificar o fold externo.
    keep_only_complete : bool
        Se True, mantém apenas trials com state == 'COMPLETE' (quando existir essa coluna).

    Retorna
    -------
    pd.DataFrame
        DataFrame consolidado com colunas originais + coluna de fold.
    """
    path_pattern = os.path.join(log_dir, pattern)
    files = sorted(glob.glob(path_pattern))

    if not files:
        raise FileNotFoundError(f"Nenhum arquivo encontrado em: {path_pattern}")

    dfs = []
    for fp in files:
        df = pd.read_csv(fp)

        # Extrai fold do nome do arquivo (ex.: trials_log_fold_3.csv -> 3)
        m = re.search(r"fold_(\d+)", os.path.basename(fp))
        fold = int(m.group(1)) if m else None

        df[fold_col_name] = fold
        df["source_file"] = os.path.basename(fp)

        # Normaliza duration se estiver como string do tipo "0 days 00:00:12.345"
        if "duration" in df.columns:
            try:
                df["duration"] = pd.to_timedelta(df["duration"])
                df["duration_seconds"] = df["duration"].dt.total_seconds()
            except Exception:
                pass

        dfs.append(df)

    df_all = pd.concat(dfs, ignore_index=True)

    # Ordenação útil (se existir)
    sort_cols = [c for c in [fold_col_name, "number"] if c in df_all.columns]
    if sort_cols:
        df_all = df_all.sort_values(sort_cols).reset_index(drop=True)

    return df_all


df_metrics = read_and_consolidate_optuna_logs(log_dir="log_opt", keep_only_complete=True)

# 2. Basic overview
print("=== Shape of DataFrame ===")
print(df_metrics.shape)

display(df_metrics)
# Out:
# === Shape of DataFrame ===
# (250, 18)
#      number     value  params_C  params_colsample_bytree  \
# 0         0  0.694890  0.598558                      NaN
# 1         1  0.691516       NaN                 0.613826
# 2         2  0.694107  1.531319                      NaN
# 3         3  0.706030       NaN                 0.769884
# 4         4  0.688545       NaN                 0.981433
# ..      ...       ...       ...                      ...
# 245      45  0.712654       NaN                 0.946688
# 246      46  0.714318       NaN                 0.911578
# 247      47  0.700192       NaN                 0.857612
# 248      48  0.714557       NaN                 0.909165
# 249      49  0.683920       NaN                 0.784764
#
#      params_learning_rate  params_max_depth  params_min_samples_leaf  \
# 0                     NaN               NaN                      NaN
# 1                0.108106               7.0                      NaN
# 2                     NaN               NaN                      NaN
# 3                0.166994               5.0                      NaN
# 4                0.107621               3.0                      NaN
# ..                    ...               ...                      ...
# 245              0.140060               6.0                      NaN
# 246              0.152791               8.0                      NaN
# 247              0.154699               4.0                      NaN
# 248              0.196008               8.0                      NaN
# 249              0.088614               3.0                      NaN
#
#      params_min_samples_split params_model_name  params_n_estimators  \
# 0                         NaN               svm                  NaN
# 1                         NaN           xgboost                  7.0
# 2                         NaN               svm                  NaN
# 3                         NaN          lightgbm                 22.0
# 4                         NaN          lightgbm                 18.0
# ..                        ...               ...                  ...
# 245                       NaN          lightgbm                 26.0
# 246                       NaN          lightgbm                 26.0
# 247                       NaN          lightgbm                 12.0
# 248                       NaN          lightgbm                 25.0
# 249                       NaN          lightgbm                 19.0
#
#     params_sampling_mode  params_smote_k  params_subsample     state  \
# 0                  smote             8.0               NaN  COMPLETE
# 1                  under             NaN          0.708346  COMPLETE
# 2                  under             NaN               NaN  COMPLETE
# 3                  under             NaN          0.592086  COMPLETE
# 4                  under             NaN          0.776323  COMPLETE
# ..                   ...             ...               ...       ...
# 245                smote             8.0          0.717594  COMPLETE
# 246                 over             NaN          0.839697  COMPLETE
# 247                 over             NaN          0.840303  COMPLETE
# 248                smote             6.0          0.763013  COMPLETE
# 249                smote             6.0          0.763933  COMPLETE
#
#                   duration  outer_fold            source_file  \
# 0   0 days 00:01:05.096570           1  trials_log_fold_1.csv
# 1   0 days 00:00:02.874840           1  trials_log_fold_1.csv
# 2   0 days 00:00:19.136376           1  trials_log_fold_1.csv
# 3   0 days 00:00:04.791645           1  trials_log_fold_1.csv
# 4   0 days 00:00:03.760325           1  trials_log_fold_1.csv
# ..                     ...         ...                    ...
# 245 0 days 00:00:32.792008           5  trials_log_fold_5.csv
# 246 0 days 00:00:04.246833           5  trials_log_fold_5.csv
# 247 0 days 00:00:02.838498           5  trials_log_fold_5.csv
# 248 0 days 00:00:32.833245           5  trials_log_fold_5.csv
# 249 0 days 00:00:30.968048           5  trials_log_fold_5.csv
#
#      duration_seconds
# 0           65.096570
# 1            2.874840
# 2           19.136376
# 3            4.791645
# 4            3.760325
# ..                ...
# 245         32.792008
# 246          4.246833
# 247          2.838498
# 248         32.833245
# 249         30.968048
#
# [250 rows x 18 columns]

# %%
# Total de trials por modelo
total_trials = (df_metrics.groupby("params_model_name").size().reset_index(name="total_trials"))

plt.figure(figsize=(8, 6))
sns.barplot(data=total_trials,x="params_model_name",y="total_trials",)
plt.title("Total de tentativas por modelo")
plt.xlabel("Modelo")
plt.ylabel("Tentativas")
plt.tight_layout()
plt.show()

# %%
# Gráfico das tentativas de modelos completas e abortadas
counts_state = df_metrics.groupby(["params_model_name", "state"]).size().reset_index(name="count")

plt.figure(figsize=(8, 6))
sns.barplot(data=counts_state,x="params_model_name",y="count",hue="state",)
plt.title("Resultado das tentativas entre Pruned e Complete")
plt.xlabel("Modelo")
plt.ylabel("Número de tentativas")
plt.tight_layout()
plt.show()

# %%
# Distribuição de performance (value) por modelo
plt.figure(figsize=(8, 6))
sns.boxplot(data=df_metrics, x="params_model_name", y="value")
plt.title("Desempenho por modelo")
plt.xlabel("Modelo")
plt.ylabel("Área por baixo da curva ROC (AUC)")
plt.tight_layout()
plt.show()

# %%
# Duração média de treino por modelo
df_metrics["duration_sec"] = pd.to_timedelta(df_metrics["duration"]).dt.total_seconds()
mean_duration = df_metrics.groupby("params_model_name")["duration_sec"].mean().reset_index()

# Distribuição do tempo de processamento por modelo

plt.figure(figsize=(8, 6))
sns.boxplot(data=df_metrics, x="params_model_name", y="duration_sec")
plt.title("Média do tempo de treinamento por modelo")
plt.xlabel("Modelo")
plt.ylabel("Segundos")
plt.tight_layout()
plt.show()

# %%
tabela_resumo = (
    df_metrics
    .groupby("params_model_name")["value"]
    .agg(
        media="mean",
        desvio_padrao="std",
        mediana="median",
        minimo="min",
        maximo="max",
        n="count"
    )
    .reset_index()
    .sort_values("media", ascending=False)
)

# Opcional: arredondar para facilitar leitura
tabela_resumo = tabela_resumo.round(4)

tabela_resumo
# Out:
#   params_model_name   media  desvio_padrao  mediana  minimo  maximo    n
# 0          lightgbm  0.7083         0.0074   0.7095  0.6706  0.7177  152
# 2               svm  0.6990         0.0044   0.6989  0.6922  0.7087   31
# 3           xgboost  0.6945         0.0192   0.7017  0.6212  0.7126   32
# 1     random_forest  0.6865         0.0119   0.6907  0.6591  0.7016   35

# %%
tabela_resumo = (
    df_metrics
    .groupby("params_model_name")["duration_seconds"]
    .agg(
        media="mean",
        desvio_padrao="std",
        mediana="median",
        minimo="min",
        maximo="max",
        n="count"
    )
    .reset_index()
    .sort_values("media", ascending=False)
)

# Opcional: arredondar para facilitar leitura
tabela_resumo = tabela_resumo.round(4)

tabela_resumo
# Out:
#   params_model_name    media  desvio_padrao  mediana   minimo   maximo    n
# 2               svm  45.5082        26.1817  38.3298  12.7244  92.8423   31
# 0          lightgbm  15.1341        14.3007   4.7480   2.4453  40.0437  152
# 1     random_forest  12.6449        13.1450   5.1196   2.4288  37.0176   35
# 3           xgboost  12.4102        13.5567   4.2859   2.6945  35.8750   32

# %% [markdown]
# ## Treinamento do modelo final

# %%
df_hyper =pd.DataFrame(df_results['hyperparameters'].to_list())
df_hyper
# Out:
#   model_name  n_estimators  learning_rate  max_depth  subsample  \
# 0   lightgbm            28       0.189588          8   0.733759
# 1   lightgbm            22       0.201448          7   0.943267
# 2   lightgbm            28       0.213292          7   0.798103
# 3   lightgbm            30       0.190227          7   0.845491
# 4   lightgbm            26       0.165788          7   0.717450
#
#    colsample_bytree sampling_mode  smote_k
# 0          0.791946         smote      6.0
# 1          0.613377         smote      7.0
# 2          0.733126         under      NaN
# 3          0.814078         under      NaN
# 4          0.836023         smote      7.0

# %%
final_params=df_hyper.drop(['sampling_mode'],axis=1).iloc[:,1:].median().to_dict()
sampler_mode=df_hyper.sampling_mode.mode()[0]

# %%
def cast_params(params: dict) -> dict:
    p = dict(params)  # cópia

    # chaves que devem ser int no LightGBM
    int_keys = {
        "n_estimators", "num_iterations",
        "max_depth", "num_leaves",
        "min_child_samples", "min_data_in_leaf",
        "max_bin",
        "bagging_freq",
    }

    for k in list(p.keys()):
        if k in int_keys and p[k] is not None and not (isinstance(p[k], bool)):
            p[k] = int(round(float(p[k])))

    # max_depth: LightGBM aceita -1 como "sem limite"
    if "max_depth" in p and p["max_depth"] is not None:
        p["max_depth"] = int(p["max_depth"])

    return p

final_params = cast_params(final_params)
final_params
# Out:
# {'n_estimators': 28,
#  'learning_rate': 0.1902270088775915,
#  'max_depth': 7,
#  'subsample': 0.7981027378133547,
#  'colsample_bytree': 0.7919463813575026,
#  'smote_k': 7.0}

# %%
# Dicionário base para reconstrução
models = {
    'RandomForest': RandomForestClassifier(random_state=42),
    'XGBoost': xgb.XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42),
    'LightGBM': lgb.LGBMClassifier(random_state=42),
    'SVM': CalibratedClassifierCV(LinearSVC( random_state=42))
}

# %%
def sampler_from_params(best_params,mode):

    if mode == "over":
        return RandomOverSampler(
            sampling_strategy='auto',
            random_state=42
        )

    if mode == "under":
        return RandomUnderSampler(
            sampling_strategy='auto',
            random_state=42
        )

    # smote
    return SMOTE(
        k_neighbors=int(best_params["smote_k"]),
        random_state=42
    )

# Reconstruir modelo
final_model = models['LightGBM']
final_model.set_params(**final_params)

cat_cols, num_cols = get_feature_types(X_data)
best_sampler = sampler_from_params(final_params,'')

final_pipeline = build_pipeline(final_model, cat_cols, num_cols, best_sampler)

# %% [markdown]
# ### Avaliando modelo final

# %% [markdown]
# ## Interpretabilidade: importância de variáveis após pré-processamento (OHE) e mapeamento para colunas originais
#
# Modelos treinados sobre pipelines com `ColumnTransformer` e `OneHotEncoder` operam em um espaço de features
# expandido (múltiplas colunas por variável categórica). Para manter interpretabilidade, esta seção:
# 1) recupera os nomes finais das features no espaço transformado,
# 2) extrai uma medida de importância/coeficiente do modelo treinado,
# 3) mapeia as features transformadas de volta para as variáveis originais,
# 4) consolida a importância no nível da coluna original.
#
# Isso permite reportar resultados em termos das variáveis do dataset original, facilitando comunicação e análise.

# %% [markdown]
# ### Extração de nomes das features pós-`ColumnTransformer`
#
# A função `get_feature_names` reconstrói o vetor de nomes de features gerado após o pré-processamento,
# incluindo:
# - variáveis numéricas (após imputação/escala),
# - variáveis categóricas expandidas via One-Hot Encoding,
# - e, opcionalmente, colunas passadas via `remainder='passthrough'`.
#
# Essa etapa é necessária porque, após o `fit_transform`, a matriz final perde o vínculo direto com o nome
# das colunas originais, e a identificação correta das features é condição para qualquer análise de importância.

# %%
# 1. FUNÇÃO PARA EXTRAIR NOMES DAS FEATURES PÓS-OHE
def get_feature_names(column_transformer):
    """
    Extrai nomes finais das features após ColumnTransformer,
    incluindo OneHotEncoder e transformações numéricas.
    """
    output_features = []

    for name, transformer, features in column_transformer.transformers_:

        # Caso 'remainder=passthrough'
        if name == "remainder":
            output_features.extend(features)
            continue

        # Transformers com get_feature_names_out() (OneHotEncoder, etc)
        if hasattr(transformer, "get_feature_names_out"):
            try:
                names = transformer.get_feature_names_out(features)
            except:
                names = transformer.get_feature_names_out()
            output_features.extend(names)

        # Caso não possua o método
        else:
            output_features.extend(features)

    return output_features

# %% [markdown]
# ### Mapeamento para variáveis originais via fuzzy matching
#
# Após o One-Hot Encoding, uma mesma variável categórica pode gerar dezenas de colunas com nomes derivados.
# Para consolidar resultados no nível da variável original, é aplicado *fuzzy matching* entre o nome da feature
# pós-OHE e a lista de variáveis originais de interesse (`features_explicativas`).
#
# O objetivo do fuzzy matching é lidar com diferenças de sufixos/prefixos criados pelo encoding e manter
# um vínculo prático entre “feature transformada” e “coluna original”. O parâmetro `threshold`
# controla o quão estrita é a correspondência:
# - valores maiores reduzem falsos positivos (match errado),
# - valores menores aumentam cobertura, mas elevam risco de mapeamentos incorretos.
#
# Após o matching, apenas features com correspondência válida são mantidas para agregação.

# %%
def fuzzy_match_original(feature_name, features_explicativas, threshold=70):
    """
    Realiza fuzzy matching buscando qual variável ORIGINAL
    está mais relacionada com o nome da feature pós-OHE.
    """
    best_match, score, _ = process.extractOne(
        feature_name,
        features_explicativas,
        scorer=fuzz.partial_ratio
    )
    return best_match if score >= threshold else None

# %% [markdown]
# ## Validação cruzada externa: avaliação e interpretabilidade por fold
#
# Nesta etapa, aplica-se uma `StratifiedKFold` externa para avaliar o desempenho do pipeline e também
# inspecionar a importância de variáveis por fold. A estratificação preserva a proporção das classes,
# reduzindo instabilidade em bases desbalanceadas.
#
# Para cada fold:
# - o pipeline final é treinado no conjunto de treino,
# - a importância das features é extraída do modelo treinado,
# - as importâncias são consolidadas no nível da variável original e visualizadas,
# - e o desempenho é medido no conjunto de teste com métricas e curvas.

# %%
# =========================
# Parâmetros
# =========================
n_splits = 4
top_k = 20        # top features por fold (para tabelas)
top_overall = 30  # top features gerais (para tabela final)

outer_cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

# =========================
# Coletores (tabelas)
# =========================
fold_metrics = []          # 1 linha por fold com métricas + conf matrix flatten
fold_top_features = []     # top_k features por fold (já agrupadas em original_var)
all_features_long = []     # todas features (agrupadas) por fold -> resumo geral

fold = 1
for train_idx, test_idx in outer_cv.split(X_data, y_data):

    print(f"\n==============================")
    print(f"  Fold Externo {fold}/{n_splits}")
    print(f"==============================")

    X_train, X_test = X_data.iloc[train_idx], X_data.iloc[test_idx]
    y_train, y_test = y_data.iloc[train_idx], y_data.iloc[test_idx]

    # =========================
    # 1) Fit do pipeline no fold
    # =========================
    final_pipeline.fit(X_train, y_train)

    # =========================
    # 2) Importâncias
    # =========================
    model = final_pipeline.named_steps["model"]

    if hasattr(model, "feature_importances_"):
        importances = model.feature_importances_
    elif hasattr(model, "coef_"):
        coef = model.coef_
        # binary: (n_features,) ou (1, n_features)
        # multiclass: (n_classes, n_features) -> agregamos por média do abs
        importances = coef.ravel() if coef.ndim == 1 else np.mean(np.abs(coef), axis=0)
    else:
        raise ValueError("Este modelo não possui atributo de importância (feature_importances_ ou coef_).")

    # =========================
    # 3) Nomes pós-preprocessamento
    # =========================
    preproc = final_pipeline.named_steps["preprocessor"]
    feature_names = get_feature_names(preproc)

    if len(feature_names) != len(importances):
        raise ValueError(
            f"Mismatch: {len(feature_names)} nomes de features vs {len(importances)} importâncias. "
            "Cheque get_feature_names() / preprocessor."
        )

    df_imp = pd.DataFrame({"feature": feature_names, "importance": importances})

    # =========================
    # 4) Fuzzy match para variáveis originais e agregação
    # =========================
    df_imp["original_var"] = df_imp["feature"].apply(lambda x: fuzzy_match_original(x, features_explicativas))
    df_imp = df_imp[df_imp["original_var"].notna()].copy()

    df_grouped = (
        df_imp.groupby("original_var", as_index=False)["importance"]
              .sum()
              .sort_values("importance", ascending=False)
              .rename(columns={"original_var": "feature"})
              .reset_index(drop=True)
    )

    # =========================
    # 4.1) Plot: Feature importance (por fold)
    # =========================
    plt.figure(figsize=(6, 14))
    plt.barh(df_grouped["feature"][::-1], df_grouped["importance"][::-1])
    plt.xlabel("Importância (agregada por variável original)")
    plt.title(f"Feature importance – {type(model).__name__} – Fold {fold}")
    plt.tight_layout()
    plt.show()

    # guarda top features do fold (top_k)
    df_top = df_grouped.head(top_k).copy()
    df_top["fold"] = fold
    df_top["rank_in_fold"] = np.arange(1, len(df_top) + 1)
    fold_top_features.append(df_top)

    # guarda TODAS as features agregadas do fold (para resumo geral)
    df_grouped_long = df_grouped.copy()
    df_grouped_long["fold"] = fold
    all_features_long.append(df_grouped_long)

    # =========================
    # 5) Predições / probabilidades
    # =========================
    y_pred = final_pipeline.predict(X_test)

    y_proba = None
    if hasattr(final_pipeline, "predict_proba"):
        try:
            y_proba = final_pipeline.predict_proba(X_test)[:, 1]
        except Exception:
            y_proba = None

    # =========================
    # 6) Matriz de confusão (plot)
    # =========================
    cm = confusion_matrix(y_test, y_pred)

    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.title(f"Matriz de Confusão – Fold {fold}")
    plt.xlabel("Predito")
    plt.ylabel("Real")
    plt.tight_layout()
    plt.show()

    # =========================
    # 7) Métricas (plot + tabela)
    # =========================
    metrics_dict_plot = {
        "Accuracy": accuracy_score(y_test, y_pred),
        "Precision": precision_score(y_test, y_pred, zero_division=0),
        "Recall": recall_score(y_test, y_pred, zero_division=0),
        "F1 Score": f1_score(y_test, y_pred, zero_division=0),
        "AUC": roc_auc_score(y_test, y_proba) if y_proba is not None else np.nan
    }

    plt.figure(figsize=(8, 5))
    sns.barplot(x=list(metrics_dict_plot.keys()), y=list(metrics_dict_plot.values()), palette="Set2")
    plt.ylim(0, 1.05)
    plt.title(f"Métricas de Classificação – Fold {fold}")
    for i, v in enumerate(metrics_dict_plot.values()):
        if np.isfinite(v):
            plt.text(i, v + 0.02, f"{v:.2f}", ha='center')
        else:
            plt.text(i, 0.02, "NA", ha='center')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    # salva métricas estruturadas (para df_metrics)
    fold_metrics.append({
        "fold": fold,
        "n_train": len(train_idx),
        "n_test": len(test_idx),
        "accuracy": metrics_dict_plot["Accuracy"],
        "precision": metrics_dict_plot["Precision"],
        "recall": metrics_dict_plot["Recall"],
        "f1": metrics_dict_plot["F1 Score"],
        "auc": metrics_dict_plot["AUC"],
        "tn": cm[0, 0], "fp": cm[0, 1], "fn": cm[1, 0], "tp": cm[1, 1],
        "model_name": type(model).__name__,
    })

    # =========================
    # 8) Curva ROC (plot)
    # =========================
    if y_proba is not None:
        fpr, tpr, _ = roc_curve(y_test, y_proba)
        roc_auc = auc(fpr, tpr)

        plt.figure(figsize=(6, 5))
        plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.2f}")
        plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
        plt.xlabel("Falso Positivo")
        plt.ylabel("Verdadeiro Positivo")
        plt.title(f"Curva ROC – Fold {fold}")
        plt.legend(loc='lower right')
        plt.grid(True)
        plt.tight_layout()
        plt.show()

    # =========================
    # 9) Curva Precision-Recall (plot)
    # =========================
    if y_proba is not None:
        precision, recall, _ = precision_recall_curve(y_test, y_proba)
        auprc_trap = auc(recall, precision)

        plt.figure(figsize=(6, 5))
        plt.plot(recall, precision, label=f"AUPRC = {auprc_trap:.2f}")
        plt.xlabel("Recall")
        plt.ylabel("Precision")
        plt.title(f"Curva Precision-Recall – Fold {fold}")
        plt.legend(loc='lower right')
        plt.grid(True)
        plt.tight_layout()
        plt.show()

    # =========================
    # 10) Curva Calibração (plot)
    # =========================
    if y_proba is not None:

        prob_true, prob_pred = calibration_curve(y_test, y_proba, n_bins=10, strategy='uniform')

        plt.figure(figsize=(6,6))
        plt.plot(prob_pred, prob_true, marker='o', linewidth=2, label='Modelo calibrado')
        plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Calibração perfeita')
        plt.title("Curva de Calibração (Isotonic Regression)")
        plt.xlabel("Probabilidade prevista (modelo)")
        plt.ylabel("Frequência real observada")
        plt.legend()
        plt.grid(True, linestyle='--', alpha=0.6)
        plt.show()


    # =========================
    # 11) Análise de FP/FN X Thresholds
    # =========================

    if y_proba is not None:
        thresholds = np.linspace(0, 1, 101)
        fp_list, fn_list = [], []

        for t in thresholds:
            y_pred = (y_proba >= t).astype(int)
            tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
            fp_list.append(fp)
            fn_list.append(fn)

        df_threshold = pd.DataFrame({
            'threshold': thresholds,
            'false_positives': fp_list,
            'false_negatives': fn_list
        })

        plt.figure(figsize=(8,5))
        plt.plot(df_threshold['threshold'], df_threshold['false_positives'], label='Falsos Positivos (FP)', color='tab:red')
        plt.plot(df_threshold['threshold'], df_threshold['false_negatives'], label='Falsos Negativos (FN)', color='tab:blue')
        plt.xlabel('Threshold (Probabilidade de Corte)')
        plt.ylabel('Quantidade de Casos')
        plt.title('Variação de FP e FN conforme o Threshold de Decisão')
        plt.legend()
        plt.grid(True, linestyle='--', alpha=0.6)
        plt.show()


    fold += 1


# =========================
#  DF: métricas por fold
# =========================
df_metrics = pd.DataFrame(fold_metrics).sort_values("fold").reset_index(drop=True)

# resumo (média e desvio padrão) das métricas
metric_cols = ["accuracy", "precision", "recall", "f1", "auc"]
df_metrics_summary = (
    df_metrics[metric_cols]
    .agg(["mean", "std"])
    .T
    .rename(columns={"mean": "mean", "std": "std"})
    .reset_index()
    .rename(columns={"index": "metric"})
)

# =========================
#  DF: top features por fold
# =========================
df_top_by_fold = pd.concat(fold_top_features, ignore_index=True)

# =========================
#  DF: resumo geral das features (média/std + rank)
# =========================
df_all_features_long = pd.concat(all_features_long, ignore_index=True)

df_feature_summary = (
    df_all_features_long
    .groupby("feature", as_index=False)
    .agg(
        mean_importance=("importance", "mean"),
        std_importance=("importance", "std"),
        folds_present=("fold", "nunique"),
    )
)

# ranking médio por fold (quanto menor, mais importante)
df_ranks = (
    df_all_features_long
    .assign(rank_in_fold=lambda d: d.groupby("fold")["importance"].rank(ascending=False, method="average"))
)

df_rank_summary = (
    df_ranks.groupby("feature", as_index=False)
            .agg(mean_rank=("rank_in_fold", "mean"), std_rank=("rank_in_fold", "std"))
)

df_feature_summary = (
    df_feature_summary.merge(df_rank_summary, on="feature", how="left")
                      .sort_values(["mean_importance", "folds_present"], ascending=[False, False])
                      .reset_index(drop=True)
)

df_top_features_overall = df_feature_summary.head(top_overall).copy()

# =========================
#  OUTPUT final (tabelas)
# =========================
print("\n\n==============================")
print("MÉTRICAS POR FOLD")
print("==============================")
display(df_metrics)

print("\n\n==============================")
print("RESUMO GERAL DAS MÉTRICAS (média e desvio padrão)")
print("==============================")
display(df_metrics_summary)

print("\n\n==============================")
print(f"TOP {top_k} FEATURES POR FOLD (agregadas em variável original)")
print("==============================")
display(df_top_by_fold.sort_values(["fold", "rank_in_fold"]))

print("\n\n==============================")
print(f"TOP {top_overall} FEATURES GERAIS (média/std das importâncias + estabilidade via rank)")
print("==============================")
display(df_top_features_overall)

# Se quiser salvar:
# df_metrics.to_csv("cv_metrics_by_fold.csv", index=False)
# df_metrics_summary.to_csv("cv_metrics_summary.csv", index=False)
# df_top_by_fold.to_csv("cv_top_features_by_fold.csv", index=False)
# df_feature_summary.to_csv("cv_feature_importance_summary.csv", index=False)
# Out:
# ==============================
#   Fold Externo 1/4
# ==============================
# [LightGBM] [Warning] Unknown parameter: smote_k
# [LightGBM] [Warning] Unknown parameter: smote_k
# [LightGBM] [Info] Number of positive: 14595, number of negative: 14595
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.060263 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 24130
# [LightGBM] [Info] Number of data points in the train set: 29190, number of used features: 222
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Unknown parameter: smote_k
# [LightGBM] [Warning] Unknown parameter: smote_k
# ==============================
#   Fold Externo 2/4
# ==============================
# [LightGBM] [Warning] Unknown parameter: smote_k
# [LightGBM] [Warning] Unknown parameter: smote_k
# [LightGBM] [Info] Number of positive: 14595, number of negative: 14595
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.088514 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 23976
# [LightGBM] [Info] Number of data points in the train set: 29190, number of used features: 226
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] Unknown parameter: smote_k
# [LightGBM] [Warning] Unknown parameter: smote_k
# ==============================
#   Fold Externo 3/4
# ==============================
# [LightGBM] [Warning] Unknown parameter: smote_k
# [LightGBM] [Warning] Unknown parameter: smote_k
# [LightGBM] [Info] Number of positive: 14595, number of negative: 14595
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.068932 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 24383
# [LightGBM] [Info] Number of data points in the train set: 29190, number of used features: 225
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] Unknown parameter: smote_k
# [LightGBM] [Warning] Unknown parameter: smote_k
# ==============================
#   Fold Externo 4/4
# ==============================
# [LightGBM] [Warning] Unknown parameter: smote_k
# [LightGBM] [Warning] Unknown parameter: smote_k
# [LightGBM] [Info] Number of positive: 14595, number of negative: 14595
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.087363 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 24535
# [LightGBM] [Info] Number of data points in the train set: 29190, number of used features: 225
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] Unknown parameter: smote_k
# [LightGBM] [Warning] Unknown parameter: smote_k
# ==============================
# MÉTRICAS POR FOLD
# ==============================
#    fold  n_train  n_test  accuracy  precision    recall        f1       auc  \
# 0     1    23743    7915  0.678080   0.618508  0.429508  0.506966  0.722672
# 1     2    23743    7915  0.682754   0.604175  0.512459  0.554550  0.720100
# 2     3    23744    7914  0.665909   0.582150  0.470646  0.520493  0.696215
# 3     4    23744    7914  0.662370   0.590494  0.403411  0.479345  0.684203
#
#      tn    fp    fn    tp      model_name
# 0  4057   808  1740  1310  LGBMClassifier
# 1  3841  1024  1487  1563  LGBMClassifier
# 2  3835  1030  1614  1435  LGBMClassifier
# 3  4012   853  1819  1230  LGBMClassifier
# ==============================
# RESUMO GERAL DAS MÉTRICAS (média e desvio padrão)
# ==============================
#       metric      mean       std
# 0   accuracy  0.672278  0.009698
# 1  precision  0.598832  0.015953
# 2     recall  0.454006  0.047797
# 3         f1  0.515339  0.031250
# 4        auc  0.705798  0.018685
# ==============================
# TOP 20 FEATURES POR FOLD (agregadas em variável original)
# ==============================
#          feature  importance  fold  rank_in_fold
# 0          SG_UF         151     1             1
# 1     NU_IDADE_N          76     1             2
# 2     ID_OCUPA_N          42     1             3
# 3     CLI_OUTROS          42     1             4
# 4     CLI_CONGES          39     1             5
# ..           ...         ...   ...           ...
# 75    ANT_CB_LAM          21     4            16
# 76       CS_RACA          20     4            17
# 77    CLI_PANTUR          19     4            18
# 78    ANT_CB_CRI          17     4            19
# 79  mes_sintomas          16     4            20
#
# [80 rows x 4 columns]
# ==============================
# TOP 30 FEATURES GERAIS (média/std das importâncias + estabilidade via rank)
# ==============================
#             feature  mean_importance  std_importance  folds_present  \
# 0             SG_UF           142.25        7.135592              4
# 1        NU_IDADE_N            80.25        4.031129              4
# 2        CLI_CONGES            43.75        5.737305              4
# 3        CLI_OUTROS            40.75        4.573474              4
# 4        ID_OCUPA_N            38.75        7.365460              4
# 5        CLI_CEFALE            35.00        4.320494              4
# 6        CS_ESCOL_N            34.75        3.500000              4
# 7        CLI_VOMITO            31.50        2.645751              4
# 8         CLI_PROST            29.50        3.109126              4
# 9        CLI_DIARRE            27.50        2.886751              4
# 10       ANT_CB_ROE            26.00        1.414214              4
# 11       ANT_CB_SIN            24.00        2.000000              4
# 12       ANT_CB_LIX            23.75        2.500000              4
# 13       CLI_PANTUR            23.25        2.986079              4
# 14         CON_AREA            23.25        8.015610              4
# 15          CS_RACA            22.25        3.862210              4
# 16       CON_AMBIEN            21.00        5.656854              4
# 17     mes_sintomas            17.75        5.678908              4
# 18       CLI_MIALGI            15.00        0.816497              4
# 19          CS_SEXO            14.00        5.477226              4
# 20       ANT_CB_CRI            13.25        2.872281              4
# 21          estacao            13.25        5.057997              4
# 22       ANT_CB_LAM            13.00        6.782330              4
# 23        CLI_FEBRE            11.50        1.290994              4
# 24       CS_GESTANT            11.00        3.915780              4
# 25       ANT_HUMANO            10.50        3.109126              4
# 26       ANT_CB_TER             9.75        2.061553              4
# 27       ANT_CB_OUT             8.75        2.500000              4
# 28       ANT_ANIMAI             7.25        3.201562              4
# 29  raca_vulneravel             6.75        3.304038              4
#
#     mean_rank  std_rank
# 0       1.000  0.000000
# 1       2.000  0.000000
# 2       3.750  0.957427
# 3       4.625  1.796988
# 4       5.375  2.056494
# 5       6.625  1.887459
# 6       6.000  1.080123
# 7       7.625  1.796988
# 8       9.750  1.190238
# 9      11.250  3.175426
# 10     12.000  1.779513
# 11     14.000  1.471960
# 12     14.750  1.190238
# 13     14.375  2.495830
# 14     13.750  6.344289
# 15     14.250  3.201562
# 16     15.125  3.567796
# 17     18.375  4.007805
# 18     20.250  0.957427
# 19     21.500  3.851407
# 20     21.750  2.598076
# 21     22.375  4.404070
# 22     23.625  7.696049
# 23     23.375  2.136001
# 24     23.875  4.130678
# 25     25.625  2.868652
# 26     25.875  2.212653
# 27     26.625  1.887459
# 28     29.000  3.763863
# 29     29.250  3.403430

# %% [markdown]
# ### Selecionando o melhor threshold e construindo as métricas

# %%
def select_best_threshold_fp_fn_balance(y_true, y_proba, thresholds=None):
    if thresholds is None:
        thresholds = np.linspace(0, 1, 101)

    rows = []

    for t in thresholds:
        y_pred_t = (y_proba >= t).astype(int)
        tn, fp, fn, tp = confusion_matrix(y_true, y_pred_t, labels=[0, 1]).ravel()

        rows.append({
            "threshold": t,
            "tn": tn,
            "fp": fp,
            "fn": fn,
            "tp": tp,
            "diff_fp_fn": abs(fp - fn)
        })

    df_threshold = pd.DataFrame(rows)

    # thresholds com menor diferença entre FP e FN
    best_candidates = df_threshold[
        df_threshold["diff_fp_fn"] == df_threshold["diff_fp_fn"].min()
    ].copy()

    candidate_rows = []

    for _, row in best_candidates.iterrows():
        t = row["threshold"]
        y_pred_t = (y_proba >= t).astype(int)

        candidate_rows.append({
            "threshold": t,
            "accuracy": accuracy_score(y_true, y_pred_t),
            "precision": precision_score(y_true, y_pred_t, zero_division=0),
            "recall": recall_score(y_true, y_pred_t, zero_division=0),
            "f1": f1_score(y_true, y_pred_t, zero_division=0)
        })

    df_candidates = pd.DataFrame(candidate_rows).sort_values(
        by=["recall", "f1"],
        ascending=False
    ).reset_index(drop=True)

    best_threshold = df_candidates.loc[0, "threshold"]

    return best_threshold, df_threshold, df_candidates


# =========================
# Parâmetros
# =========================
n_splits = 4
top_k = 20        # top features por fold (para tabelas)
top_overall = 30  # top features gerais (para tabela final)

outer_cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

# =========================
# Coletores (tabelas)
# =========================
fold_metrics = []          # 1 linha por fold com métricas + conf matrix flatten
fold_top_features = []     # top_k features por fold (já agrupadas em original_var)
all_features_long = []     # todas features (agrupadas) por fold -> resumo geral

fold = 1
for train_idx, test_idx in outer_cv.split(X_data, y_data):

    print(f"\n==============================")
    print(f"  Fold Externo {fold}/{n_splits}")
    print(f"==============================")

    X_train, X_test = X_data.iloc[train_idx], X_data.iloc[test_idx]
    y_train, y_test = y_data.iloc[train_idx], y_data.iloc[test_idx]

    # =========================
    # 1) Fit do pipeline no fold
    # =========================
    final_pipeline.fit(X_train, y_train)

    # =========================
    # 2) Importâncias
    # =========================
    model = final_pipeline.named_steps["model"]

    if hasattr(model, "feature_importances_"):
        importances = model.feature_importances_
    elif hasattr(model, "coef_"):
        coef = model.coef_
        # binary: (n_features,) ou (1, n_features)
        # multiclass: (n_classes, n_features) -> agregamos por média do abs
        importances = coef.ravel() if coef.ndim == 1 else np.mean(np.abs(coef), axis=0)
    else:
        raise ValueError(
            "Este modelo não possui atributo de importância "
            "(feature_importances_ ou coef_)."
        )

    # =========================
    # 3) Nomes pós-preprocessamento
    # =========================
    preproc = final_pipeline.named_steps["preprocessor"]
    feature_names = get_feature_names(preproc)

    if len(feature_names) != len(importances):
        raise ValueError(
            f"Mismatch: {len(feature_names)} nomes de features vs "
            f"{len(importances)} importâncias. "
            "validacao get_feature_names() / preprocessor."
        )

    df_imp = pd.DataFrame({
        "feature": feature_names,
        "importance": importances
    })

    # =========================
    # 4) Fuzzy match para variáveis originais e agregação
    # =========================
    df_imp["original_var"] = df_imp["feature"].apply(
        lambda x: fuzzy_match_original(x, features_explicativas)
    )
    df_imp = df_imp[df_imp["original_var"].notna()].copy()

    df_grouped = (
        df_imp.groupby("original_var", as_index=False)["importance"]
              .sum()
              .sort_values("importance", ascending=False)
              .rename(columns={"original_var": "feature"})
              .reset_index(drop=True)
    )

    # =========================
    # 4.1) Plot: Feature importance (por fold)
    # =========================
    plt.figure(figsize=(6, 14))
    plt.barh(df_grouped["feature"][::-1], df_grouped["importance"][::-1])
    plt.xlabel("Importância (agregada por variável original)")
    plt.title(f"Feature importance – {type(model).__name__} – Fold {fold}")
    plt.tight_layout()
    plt.show()

    # guarda top features do fold (top_k)
    df_top = df_grouped.head(top_k).copy()
    df_top["fold"] = fold
    df_top["rank_in_fold"] = np.arange(1, len(df_top) + 1)
    fold_top_features.append(df_top)

    # guarda TODAS as features agregadas do fold (para resumo geral)
    df_grouped_long = df_grouped.copy()
    df_grouped_long["fold"] = fold
    all_features_long.append(df_grouped_long)

    # =========================
    # 5) Predições / probabilidades
    # =========================
    y_pred_default = final_pipeline.predict(X_test)

    y_proba = None
    if hasattr(final_pipeline, "predict_proba"):
        try:
            y_proba = final_pipeline.predict_proba(X_test)[:, 1]
        except Exception:
            y_proba = None

    # =========================
    # 6) Escolha do threshold ótimo
    # =========================
    best_threshold = 0.5
    df_threshold = None
    df_candidates = None

    if y_proba is not None:
        best_threshold, df_threshold, df_candidates = select_best_threshold_fp_fn_balance(
            y_true=y_test,
            y_proba=y_proba,
            thresholds=np.linspace(0, 1, 101)
        )

        print(f"Threshold ótimo (FP ≈ FN, desempate por recall/F1): {best_threshold:.2f}")

        # Predição final pós-threshold
        y_pred_final = (y_proba >= best_threshold).astype(int)
    else:
        # fallback quando não há probabilidade
        y_pred_final = y_pred_default

    # =========================
    # 7) Matriz de confusão (plot) - pós-threshold
    # =========================
    cm = confusion_matrix(y_test, y_pred_final, labels=[0, 1])

    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.title(f"Matriz de Confusão – Fold {fold} (threshold={best_threshold:.2f})")
    plt.xlabel("Predito")
    plt.ylabel("Real")
    plt.tight_layout()
    plt.show()

    # =========================
    # 8) Métricas (plot + tabela) - pós-threshold
    # =========================
    metrics_dict_plot = {
        "Accuracy": accuracy_score(y_test, y_pred_final),
        "Precision": precision_score(y_test, y_pred_final, zero_division=0),
        "Recall": recall_score(y_test, y_pred_final, zero_division=0),
        "F1 Score": f1_score(y_test, y_pred_final, zero_division=0),
        "AUC": roc_auc_score(y_test, y_proba) if y_proba is not None else np.nan
    }

    plt.figure(figsize=(8, 5))
    sns.barplot(
        x=list(metrics_dict_plot.keys()),
        y=list(metrics_dict_plot.values()),
        palette="Set2"
    )
    plt.ylim(0, 1.05)
    plt.title(f"Métricas de Classificação – Fold {fold} (pós-threshold)")
    for i, v in enumerate(metrics_dict_plot.values()):
        if np.isfinite(v):
            plt.text(i, v + 0.02, f"{v:.2f}", ha='center')
        else:
            plt.text(i, 0.02, "NA", ha='center')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    # salva métricas estruturadas
    fold_metrics.append({
        "fold": fold,
        "n_train": len(train_idx),
        "n_test": len(test_idx),
        "threshold": best_threshold,
        "accuracy": metrics_dict_plot["Accuracy"],
        "precision": metrics_dict_plot["Precision"],
        "recall": metrics_dict_plot["Recall"],
        "f1": metrics_dict_plot["F1 Score"],
        "auc": metrics_dict_plot["AUC"],
        "tn": cm[0, 0],
        "fp": cm[0, 1],
        "fn": cm[1, 0],
        "tp": cm[1, 1],
        "model_name": type(model).__name__,
    })

    # =========================
    # 9) Curva ROC (plot)
    # =========================
    if y_proba is not None:
        fpr, tpr, _ = roc_curve(y_test, y_proba)
        roc_auc = auc(fpr, tpr)

        plt.figure(figsize=(6, 5))
        plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.2f}")
        plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
        plt.xlabel("Falso Positivo")
        plt.ylabel("Verdadeiro Positivo")
        plt.title(f"Curva ROC – Fold {fold}")
        plt.legend(loc='lower right')
        plt.grid(True)
        plt.tight_layout()
        plt.show()

    # =========================
    # 10) Curva Precision-Recall (plot)
    # =========================
    if y_proba is not None:
        precision_curve, recall_curve, _ = precision_recall_curve(y_test, y_proba)
        auprc_trap = auc(recall_curve, precision_curve)

        plt.figure(figsize=(6, 5))
        plt.plot(recall_curve, precision_curve, label=f"AUPRC = {auprc_trap:.2f}")
        plt.xlabel("Recall")
        plt.ylabel("Precision")
        plt.title(f"Curva Precision-Recall – Fold {fold}")
        plt.legend(loc='lower right')
        plt.grid(True)
        plt.tight_layout()
        plt.show()

    # =========================
    # 11) Curva Calibração (plot)
    # =========================
    if y_proba is not None:
        prob_true, prob_pred = calibration_curve(
            y_test, y_proba, n_bins=10, strategy='uniform'
        )

        plt.figure(figsize=(6, 6))
        plt.plot(prob_pred, prob_true, marker='o', linewidth=2, label='Modelo calibrado')
        plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Calibração perfeita')
        plt.title(f"Curva de Calibração – Fold {fold}")
        plt.xlabel("Probabilidade prevista (modelo)")
        plt.ylabel("Frequência real observada")
        plt.legend()
        plt.grid(True, linestyle='--', alpha=0.6)
        plt.tight_layout()
        plt.show()

    # =========================
    # 12) Análise de FP/FN X Thresholds
    # =========================
    if y_proba is not None:
        plt.figure(figsize=(8, 5))
        plt.plot(
            df_threshold['threshold'],
            df_threshold['fp'],
            label='Falsos Positivos (FP)',
            color='tab:red'
        )
        plt.plot(
            df_threshold['threshold'],
            df_threshold['fn'],
            label='Falsos Negativos (FN)',
            color='tab:blue'
        )
        plt.axvline(
            best_threshold,
            linestyle='--',
            color='black',
            label=f'Threshold ótimo = {best_threshold:.2f}'
        )
        plt.xlabel('Threshold (Probabilidade de Corte)')
        plt.ylabel('Quantidade de Casos')
        plt.title(f'Variação de FP e FN conforme o Threshold – Fold {fold}')
        plt.legend()
        plt.grid(True, linestyle='--', alpha=0.6)
        plt.tight_layout()
        plt.show()

        print("\nCandidatos a threshold ótimo:")
        display(df_candidates)

    fold += 1


# =========================
# DF: métricas por fold
# =========================
df_metrics = pd.DataFrame(fold_metrics).sort_values("fold").reset_index(drop=True)

# resumo (média e desvio padrão) das métricas
metric_cols = ["accuracy", "precision", "recall", "f1", "auc"]
df_metrics_summary = (
    df_metrics[metric_cols]
    .agg(["mean", "std"])
    .T
    .reset_index()
    .rename(columns={"index": "metric"})
)

# resumo do threshold
df_threshold_summary = (
    df_metrics[["threshold"]]
    .agg(["mean", "std"])
    .T
    .reset_index()
    .rename(columns={"index": "metric"})
)

# =========================
# DF: top features por fold
# =========================
df_top_by_fold = pd.concat(fold_top_features, ignore_index=True)

# =========================
# DF: resumo geral das features (média/std + rank)
# =========================
df_all_features_long = pd.concat(all_features_long, ignore_index=True)

df_feature_summary = (
    df_all_features_long
    .groupby("feature", as_index=False)
    .agg(
        mean_importance=("importance", "mean"),
        std_importance=("importance", "std"),
        folds_present=("fold", "nunique"),
    )
)

# ranking médio por fold (quanto menor, mais importante)
df_ranks = (
    df_all_features_long
    .assign(rank_in_fold=lambda d: d.groupby("fold")["importance"].rank(
        ascending=False,
        method="average"
    ))
)

df_rank_summary = (
    df_ranks.groupby("feature", as_index=False)
            .agg(mean_rank=("rank_in_fold", "mean"),
                 std_rank=("rank_in_fold", "std"))
)

df_feature_summary = (
    df_feature_summary.merge(df_rank_summary, on="feature", how="left")
                      .sort_values(
                          ["mean_importance", "folds_present"],
                          ascending=[False, False]
                      )
                      .reset_index(drop=True)
)

df_top_features_overall = df_feature_summary.head(top_overall).copy()

# =========================
# OUTPUT final (tabelas)
# =========================
print("\n\n==============================")
print("MÉTRICAS POR FOLD")
print("==============================")
display(df_metrics)

print("\n\n==============================")
print("RESUMO GERAL DAS MÉTRICAS (média e desvio padrão)")
print("==============================")
display(df_metrics_summary)

print("\n\n==============================")
print("RESUMO DO THRESHOLD ÓTIMO")
print("==============================")
display(df_threshold_summary)

print("\n\n==============================")
print(f"TOP {top_k} FEATURES POR FOLD (agregadas em variável original)")
print("==============================")
display(df_top_by_fold.sort_values(["fold", "rank_in_fold"]))

print("\n\n==============================")
print(f"TOP {top_overall} FEATURES GERAIS (média/std das importâncias + estabilidade via rank)")
print("==============================")
display(df_top_features_overall)
# Out:
# ==============================
#   Fold Externo 1/4
# ==============================
# [LightGBM] [Warning] Unknown parameter: smote_k
# [LightGBM] [Warning] Unknown parameter: smote_k
# [LightGBM] [Info] Number of positive: 14595, number of negative: 14595
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.060977 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 24130
# [LightGBM] [Info] Number of data points in the train set: 29190, number of used features: 222
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Unknown parameter: smote_k
# [LightGBM] [Warning] Unknown parameter: smote_k
# Threshold ótimo (FP ≈ FN, desempate por recall/F1): 0.43
# Candidatos a threshold ótimo:
#    threshold  accuracy  precision    recall        f1
# 0       0.43  0.673658   0.576482  0.577049  0.576766
# ==============================
#   Fold Externo 2/4
# ==============================
# [LightGBM] [Warning] Unknown parameter: smote_k
# [LightGBM] [Warning] Unknown parameter: smote_k
# [LightGBM] [Info] Number of positive: 14595, number of negative: 14595
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.064919 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 23976
# [LightGBM] [Info] Number of data points in the train set: 29190, number of used features: 226
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] Unknown parameter: smote_k
# [LightGBM] [Warning] Unknown parameter: smote_k
# Threshold ótimo (FP ≈ FN, desempate por recall/F1): 0.47
# Candidatos a threshold ótimo:
#    threshold  accuracy  precision    recall       f1
# 0       0.47  0.671636   0.573238  0.578689  0.57595
# ==============================
#   Fold Externo 3/4
# ==============================
# [LightGBM] [Warning] Unknown parameter: smote_k
# [LightGBM] [Warning] Unknown parameter: smote_k
# [LightGBM] [Info] Number of positive: 14595, number of negative: 14595
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.121502 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 24383
# [LightGBM] [Info] Number of data points in the train set: 29190, number of used features: 225
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] Unknown parameter: smote_k
# [LightGBM] [Warning] Unknown parameter: smote_k
# Threshold ótimo (FP ≈ FN, desempate por recall/F1): 0.46
# Candidatos a threshold ótimo:
#    threshold  accuracy  precision    recall        f1
# 0       0.46  0.653652       0.55  0.555592  0.552782
# ==============================
#   Fold Externo 4/4
# ==============================
# [LightGBM] [Warning] Unknown parameter: smote_k
# [LightGBM] [Warning] Unknown parameter: smote_k
# [LightGBM] [Info] Number of positive: 14595, number of negative: 14595
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.072953 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 24535
# [LightGBM] [Info] Number of data points in the train set: 29190, number of used features: 225
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] Unknown parameter: smote_k
# [LightGBM] [Warning] Unknown parameter: smote_k
# Threshold ótimo (FP ≈ FN, desempate por recall/F1): 0.43
# Candidatos a threshold ótimo:
#    threshold  accuracy  precision    recall        f1
# 0       0.43  0.647839   0.541907  0.555592  0.548664
# ==============================
# MÉTRICAS POR FOLD
# ==============================
#    fold  n_train  n_test  threshold  accuracy  precision    recall        f1  \
# 0     1    23743    7915       0.43  0.673658   0.576482  0.577049  0.576766
# 1     2    23743    7915       0.47  0.671636   0.573238  0.578689  0.575950
# 2     3    23744    7914       0.46  0.653652   0.550000  0.555592  0.552782
# 3     4    23744    7914       0.43  0.647839   0.541907  0.555592  0.548664
#
#         auc    tn    fp    fn    tp      model_name
# 0  0.722672  3572  1293  1290  1760  LGBMClassifier
# 1  0.720100  3551  1314  1285  1765  LGBMClassifier
# 2  0.696215  3479  1386  1355  1694  LGBMClassifier
# 3  0.684203  3433  1432  1355  1694  LGBMClassifier
# ==============================
# RESUMO GERAL DAS MÉTRICAS (média e desvio padrão)
# ==============================
#       metric      mean       std
# 0   accuracy  0.661696  0.012892
# 1  precision  0.560407  0.017065
# 2     recall  0.566730  0.012879
# 3         f1  0.563540  0.014899
# 4        auc  0.705798  0.018685
# ==============================
# RESUMO DO THRESHOLD ÓTIMO
# ==============================
#       metric    mean       std
# 0  threshold  0.4475  0.020616
# ==============================
# TOP 20 FEATURES POR FOLD (agregadas em variável original)
# ==============================
#          feature  importance  fold  rank_in_fold
# 0          SG_UF         151     1             1
# 1     NU_IDADE_N          76     1             2
# 2     ID_OCUPA_N          42     1             3
# 3     CLI_OUTROS          42     1             4
# 4     CLI_CONGES          39     1             5
# ..           ...         ...   ...           ...
# 75    ANT_CB_LAM          21     4            16
# 76       CS_RACA          20     4            17
# 77    CLI_PANTUR          19     4            18
# 78    ANT_CB_CRI          17     4            19
# 79  mes_sintomas          16     4            20
#
# [80 rows x 4 columns]
# ==============================
# TOP 30 FEATURES GERAIS (média/std das importâncias + estabilidade via rank)
# ==============================
#             feature  mean_importance  std_importance  folds_present  \
# 0             SG_UF           142.25        7.135592              4
# 1        NU_IDADE_N            80.25        4.031129              4
# 2        CLI_CONGES            43.75        5.737305              4
# 3        CLI_OUTROS            40.75        4.573474              4
# 4        ID_OCUPA_N            38.75        7.365460              4
# 5        CLI_CEFALE            35.00        4.320494              4
# 6        CS_ESCOL_N            34.75        3.500000              4
# 7        CLI_VOMITO            31.50        2.645751              4
# 8         CLI_PROST            29.50        3.109126              4
# 9        CLI_DIARRE            27.50        2.886751              4
# 10       ANT_CB_ROE            26.00        1.414214              4
# 11       ANT_CB_SIN            24.00        2.000000              4
# 12       ANT_CB_LIX            23.75        2.500000              4
# 13       CLI_PANTUR            23.25        2.986079              4
# 14         CON_AREA            23.25        8.015610              4
# 15          CS_RACA            22.25        3.862210              4
# 16       CON_AMBIEN            21.00        5.656854              4
# 17     mes_sintomas            17.75        5.678908              4
# 18       CLI_MIALGI            15.00        0.816497              4
# 19          CS_SEXO            14.00        5.477226              4
# 20       ANT_CB_CRI            13.25        2.872281              4
# 21          estacao            13.25        5.057997              4
# 22       ANT_CB_LAM            13.00        6.782330              4
# 23        CLI_FEBRE            11.50        1.290994              4
# 24       CS_GESTANT            11.00        3.915780              4
# 25       ANT_HUMANO            10.50        3.109126              4
# 26       ANT_CB_TER             9.75        2.061553              4
# 27       ANT_CB_OUT             8.75        2.500000              4
# 28       ANT_ANIMAI             7.25        3.201562              4
# 29  raca_vulneravel             6.75        3.304038              4
#
#     mean_rank  std_rank
# 0       1.000  0.000000
# 1       2.000  0.000000
# 2       3.750  0.957427
# 3       4.625  1.796988
# 4       5.375  2.056494
# 5       6.625  1.887459
# 6       6.000  1.080123
# 7       7.625  1.796988
# 8       9.750  1.190238
# 9      11.250  3.175426
# 10     12.000  1.779513
# 11     14.000  1.471960
# 12     14.750  1.190238
# 13     14.375  2.495830
# 14     13.750  6.344289
# 15     14.250  3.201562
# 16     15.125  3.567796
# 17     18.375  4.007805
# 18     20.250  0.957427
# 19     21.500  3.851407
# 20     21.750  2.598076
# 21     22.375  4.404070
# 22     23.625  7.696049
# 23     23.375  2.136001
# 24     23.875  4.130678
# 25     25.625  2.868652
# 26     25.875  2.212653
# 27     26.625  1.887459
# 28     29.000  3.763863
# 29     29.250  3.403430

# %% [markdown]
# ### Salvando checkpoints do colab no drive

# %% [markdown]
# Salvar metricas

# %%
src = "/content/checkpoints_best_models"
dst = f"/content/drive/MyDrive/ITA/TCC/Resultados/{experimento}/checkpoints_best_models"

os.makedirs(os.path.dirname(dst), exist_ok=True)
shutil.copytree(src, dst, dirs_exist_ok=True)
# Out:
# '/content/drive/MyDrive/ITA/TCC/Resultados/severidade_binaria_semFeatureSelection/checkpoints_best_models'

# %% [markdown]
# Salvar modelos

# %%
src = "/content/log_opt"
dst = f"/content/drive/MyDrive/ITA/TCC/Resultados/{experimento}/log_opt"

os.makedirs(os.path.dirname(dst), exist_ok=True)
shutil.copytree(src, dst, dirs_exist_ok=True)
# Out:
# '/content/drive/MyDrive/ITA/TCC/Resultados/severidade_binaria_semFeatureSelection/log_opt'
