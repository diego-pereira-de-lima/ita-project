# %%
# !pip uninstall xgboost -y
# Out:
# Found existing installation: xgboost 3.1.1
# Uninstalling xgboost-3.1.1:
#   Successfully uninstalled xgboost-3.1.1

# %%
# !pip install optuna xgboost==3.1.1 lightgbm fastparquet imbalanced-learn torch rapidfuzz
# Out:
# Requirement already satisfied: optuna in /usr/local/lib/python3.12/dist-packages (4.7.0)
# Collecting xgboost==3.1.1
#   Using cached xgboost-3.1.1-py3-none-manylinux_2_28_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.12/dist-packages (4.6.0)
# Requirement already satisfied: fastparquet in /usr/local/lib/python3.12/dist-packages (2025.12.0)
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.12/dist-packages (0.14.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.9.0+cpu)
# Requirement already satisfied: rapidfuzz in /usr/local/lib/python3.12/dist-packages (3.14.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from xgboost==3.1.1) (2.0.2)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.12/dist-packages (from xgboost==3.1.1) (2.29.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from xgboost==3.1.1) (1.16.3)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.18.3)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.12/dist-packages (from optuna) (6.10.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (26.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.46)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.2)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: pandas>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from fastparquet) (2.2.2)
# Requirement already satisfied: cramjam>=2.3 in /usr/local/lib/python3.12/dist-packages (from fastparquet) (2.11.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from fastparquet) (2025.3.0)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (1.6.1)
# Requirement already satisfied: sklearn-compat<0.2,>=0.1.5 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (0.1.5)
# Requirement already satisfied: joblib<2,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->fastparquet) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->fastparquet) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->fastparquet) (2025.3)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->fastparquet) (1.17.0)
# Using cached xgboost-3.1.1-py3-none-manylinux_2_28_x86_64.whl (115.9 MB)
# Installing collected packages: xgboost
# Successfully installed xgboost-3.1.1

# %%
import numpy as np
import pandas as pd
import os, joblib,time
from functools import partial

from sklearn.model_selection import StratifiedKFold, cross_val_score,train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.calibration import CalibratedClassifierCV

import optuna
from optuna.pruners import SuccessiveHalvingPruner
from optuna.exceptions import TrialPruned

#from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.impute import SimpleImputer
from functools import partial


from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, confusion_matrix, matthews_corrcoef,
    cohen_kappa_score, balanced_accuracy_score,
    classification_report, brier_score_loss, log_loss,
    confusion_matrix, ConfusionMatrixDisplay,
    precision_recall_curve, RocCurveDisplay,roc_curve,auc
)

from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE

import matplotlib.pyplot as plt
import seaborn as sns

import subprocess
import xgboost as xgb
import lightgbm as lgb
import torch

import re
from rapidfuzz import fuzz, process

import os
import re
import glob
import pandas as pd

import shutil
import os
from google.colab import drive


import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Configurando salvamento de checkpoints no Drive
#
# Montando o drive e acessando a conta para poder conseguir salvar os checkpoints ao final do processamento

# %%
drive.mount('/content/drive')
experimento = 'severidade_semFeatureSelection'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Carregando base de dados

# %% [markdown]
# Carregamento do conjunto de dados processado a partir de um arquivo no formato Parquet.
# Esse formato colunar é otimizado para leitura eficiente, reduz uso de memória e preserva os tipos de dados,
# sendo adequado para pipelines analíticos e etapas posteriores de modelagem.

# %%
df =pd.read_parquet('df_hepat_processed_v1.parquet',engine='fastparquet')

# %% [markdown]
# ### Selecionar variáveis relevantes para triagem

# %% [markdown]
# Definição das variáveis explicativas e da variável alvo utilizadas no modelo.
# As features incluem características sociodemográficas, condições ambientais, antecedentes clínicos e sintomas,
# além de variáveis derivadas de vulnerabilidade social e sazonalidade, enquanto a variável alvo representa a severidade do caso.

# %%
features_explicativas = [
    'NU_IDADE_N','CS_SEXO','CS_GESTANT','CS_RACA','CS_ESCOL_N',
    'ID_OCUPA_N','CON_AREA','CON_AMBIEN',
    'ANT_CB_LAM','ANT_CB_CRI','ANT_CB_SIN','ANT_CB_COR','ANT_CB_ROE',
    'ANT_CB_TER','ANT_CB_LIX','ANT_CB_OUT','ANT_ANIMAI','ANT_HUMANO',
    'CLI_FEBRE','CLI_MIALGI','CLI_CEFALE','CLI_PROST','CLI_CONGES',
    'CLI_PANTUR','CLI_VOMITO','CLI_DIARRE','CLI_OUTROS','SG_UF', 'baixa_escolaridade','raca_vulneravel','faixa_vulneravel',
    'vulnerabilidade_social', 'nivel_vulnerabilidade','mes_sintomas','estacao', 'periodo_chuvoso'
]

target = 'SEVERIDADE'

# %% [markdown]
# ### Construção variavel alvo **Forma Clinica**

# %% [markdown]
# #### Classificação da Severidade da Leptospirose
#
# * Classifica a severidade clínica dos casos de leptospirose com base em critérios médicos descritos na literatura, distinguindo entre formas leve, moderada e grave.
# * Cria variáveis auxiliares para identificar comprometimento de órgãos graves (respiratório, cardíaco e sistema nervoso central) e presença de hemorragias.
# * Define critérios de gravidade a partir da combinação de sinais clínicos como hemorragia pulmonar, disfunção renal associada, icterícia e envolvimento de múltiplos órgãos.
# * Identifica casos moderados a partir de manifestações como icterícia isolada, comprometimento renal leve e hemorragias cutâneas.
# * Converte a classificação categórica de severidade em rótulos numéricos (0 = Leve, 1 = Moderado, 2 = Grave), tornando a variável adequada para uso em modelos de machine learning.
# * Remove colunas clínicas e variáveis auxiliares utilizadas exclusivamente na lógica de classificação, garantindo um DataFrame final mais limpo e focado na modelagem.

# %%
def classificar_severidade_leptospirose(df):
    """
    Classificação de severidade da leptospirose
    Alinhada à definição clínica do artigo (leve, moderada, grave)
    Valores esperados: "Sim" / "Não"
    """

    # Flags auxiliares
    df["orgao_grave"] = (
        (df["CLI_RESPIR"] == "Sim") |
        (df["CLI_CARDIA"] == "Sim") |
        (df["CLI_MENING"] == "Sim")
    )

    df["hemorragia"] = (
        (df["CLI_HEMORR"] == "Sim") |
        (df["CLI_HEMOPU"] == "Sim")
    )

    # Critérios de gravidade
    criterio_grave = (
        (df["CLI_HEMOPU"] == "Sim") |                           # hemorragia pulmonar
        (df["CLI_RESPIR"] == "Sim") |                           # respiratório grave
        (df["CLI_CARDIA"] == "Sim") |                           # miocardite
        (df["CLI_MENING"] == "Sim") |                           # SNC
        ((df["CLI_RENAL"] == "Sim") & df["orgao_grave"]) |      # renal + outro órgão
        (df["hemorragia"] & df["orgao_grave"]) |                # hemorragia + órgão
        ((df["CLI_ICTERI"] == "Sim") & (df["CLI_RENAL"] == "Sim"))  # síndrome de Weil
    )

    # Critérios moderados
    criterio_moderado = (
        (df["CLI_ICTERI"] == "Sim") |     # icterícia sem gravidade
        (df["CLI_RENAL"] == "Sim") |      # renal leve / reversível
        (df["CLI_HEMORR"] == "Sim")       # hemorragia cutânea
    )

    # Classificação final
    df["SEVERIDADE"] = np.select(
        [criterio_grave, criterio_moderado],
        ["Grave", "Moderado"],
        default="Leve"
    )


    severidade_map = {
        "Leve": 0,
        "Moderado": 1,
        "Grave": 2
    }

    df["SEVERIDADE"] = df["SEVERIDADE"].map(severidade_map)
    # Remover colunas auxiliares
    df.drop(
        [
            "CLI_RESPIR", "CLI_HEMORR", "CLI_HEMOPU",
            "CLI_CARDIA", "CLI_MENING", "CLI_ICTERI",
            "CLI_RENAL", "hemorragia", "orgao_grave"
        ],
        axis=1,
        inplace=True
    )



    return df

# %%
df_feat_select=classificar_severidade_leptospirose(df)

# %% [markdown]
# ### Filtrar casos positivos
# Pelo fato da análise ser devido a severidade dos casos positivos iremos filtrar apenas estes para não incluir ruido amostral na base de treinamento

# %%
df_feat_select=df_feat_select[df_feat_select['CLASSI_FIN']=='Confirmado']

# %% [markdown]
# ### Amostragem estratificada dos dados
#
# Nesta etapa é realizada uma amostragem estratificada da base de dados,
# preservando a proporção das classes da variável alvo.
# O procedimento consiste em aplicar uma amostragem aleatória dentro de cada classe,
# extraindo uma fração representativa do conjunto original.
#
# Em seguida, a base amostrada é separada em variáveis explicativas (X)
# e variável resposta (y), que serão utilizadas nas etapas subsequentes de modelagem.
#
# Essa abordagem reduz o volume de dados processados,
# mantendo a representatividade estatística das classes e garantindo reprodutibilidade
# por meio do uso de uma semente aleatória fixa.

# %%
## Amostragem estratificada
amostragem = df_feat_select.groupby(target).sample(frac=1, random_state=42).copy()

# %%
X_data=amostragem[features_explicativas]
y_data = amostragem[target]

# %%
X_data.shape
# Out:
# (31658, 36)

# %% [markdown]
# ## Train framework

# %% [markdown]
# ### Funções de apoio

# %% [markdown]
# Detecta automaticamente a disponibilidade de GPU no ambiente,
# verificando suporte a CUDA, compatibilidade do LightGBM com GPU
# e informações do hardware via `nvidia-smi`.

# %%
def detect_gpu():
    """
    Detecta corretamente suporte a GPU para CUDA, XGBoost e LightGBM.
    Retorna um dicionário completo.
    """

    # 1. Verificar CUDA geral
    try:
        cuda_available = torch.cuda.is_available()
    except:
        cuda_available = False


    # 2. Testar LightGBM GPU

    try:
        # Testa se LightGBM foi compilado com suporte a GPU
        lgb_gpu = lgb.register_logger(lambda x: x)  # dummy
        booster = lgb.LGBMClassifier(device="gpu")
        lgb_gpu = True
    except:
        lgb_gpu = False


    # 3. Detalhes da GPU via nvidia-smi

    try:
        smi_output = subprocess.check_output("nvidia-smi", shell=True).decode()
        gpu_info = smi_output.split("\n")[2].strip()
    except:
        gpu_info = "Nenhuma GPU detectada (nvidia-smi não disponível)"

    return {
        "cuda_available": cuda_available,
        "lightgbm_gpu": lgb_gpu,
        "gpu_info": gpu_info
    }

# %%
def get_model_params_gpu(model_name, gpu_info):
    """
    Retorna hiperparâmetros base apropriados para CPU ou GPU.
    """
    use_gpu = gpu_info["cuda_available"]

    if model_name == "xgboost":
        if use_gpu:
            return {
                "tree_method": "gpu_hist",
                "predictor": "gpu_predictor"
            }
        else:
            return {
                "tree_method": "hist",
                "predictor": "cpu_predictor"
            }

    elif model_name == "lightgbm":
        if use_gpu:
            return {
                "device": "gpu",
                "gpu_platform_id": 0,
                "gpu_device_id": 0
            }
        else:
            return {
                "device": "cpu"
            }

    elif model_name in ["random_forest", "svm"]:
        # sklearn não usa GPU
        return {}

    return {}

# %%
def get_feature_types(df):
    """
    Identifica automaticamente colunas categóricas e numéricas de um dataframe.

    Retorna:
        cat_cols  -> lista de colunas categóricas
        num_cols  -> lista de colunas numéricas
    """

    # CATEGÓRICAS: object, category ou boolean
    cat_cols = df.select_dtypes(include=['object', 'category', 'bool']).columns.tolist()

    # NUMÉRICAS: int, float
    num_cols = df.select_dtypes(include=['int', 'float', 'int64', 'float64']).columns.tolist()

    return cat_cols, num_cols

# %% [markdown]
# ###  1. FUNÇÃO PARA CRIAR O MODELO A PARTIR DO TRIAL (Optuna)

# %% [markdown]
# Esta função encapsula a criação do modelo a ser otimizado por uma *trial* do Optuna,
# permitindo que diferentes famílias de classificadores sejam avaliadas dentro do mesmo processo de busca.
#
# O fluxo é composto por duas decisões principais:
#
# 1) **Seleção do algoritmo**
# A cada iteração, o Optuna escolhe o modelo a ser testado (`svm`, `xgboost`, `lightgbm` ou `random_forest`)
# por meio de uma variável categórica (`model_name`). Isso viabiliza uma busca conjunta que compara
# arquiteturas distintas sob o mesmo protocolo de avaliação.
#
# 2) **Amostragem de hiperparâmetros e configuração dinâmica de GPU**
# Para cada algoritmo, são sugeridos hiperparâmetros relevantes (ex.: profundidade, número de árvores, taxa de aprendizado,
# subsample e colsample), definindo um espaço de busca controlado e reproduzível.
# Em paralelo, a função consulta `get_model_params_gpu(model_name, gpu_info)` para injetar automaticamente
# parâmetros específicos de aceleração (CPU/GPU) quando suportado pelo ambiente, garantindo portabilidade do pipeline.
#
# Além disso, é aplicada uma estratégia de mitigação de desbalanceamento:
# - `class_weight="balanced"` para Random Forest e SVM,
# - `is_unbalance=True` para LightGBM,
# visando reduzir viés em cenários com classes minoritárias.
#
# No caso da SVM, utiliza-se `LinearSVC` com calibração (`CalibratedClassifierCV`),
# permitindo a obtenção de probabilidades calibradas, úteis para métricas baseadas em ranking (ex.: ROC-AUC)
# e para tomada de decisão com limiar de classificação.

# %%
def create_model(trial, gpu_info):
    model_name = trial.suggest_categorical(
        "model_name", ["svm","xgboost", "lightgbm", "random_forest"]
    )

    gpu_params = get_model_params_gpu(model_name, gpu_info)

    # RANDOM FOREST
    if model_name == "random_forest":
        return RandomForestClassifier(
            n_estimators=trial.suggest_int("n_estimators", 5, 30),
            max_depth=trial.suggest_int("max_depth", 3, 9),
            min_samples_split=trial.suggest_int("min_samples_split", 2, 10),
            min_samples_leaf=trial.suggest_int("min_samples_leaf", 1, 5),
            random_state=42,
            class_weight= 'balanced',
            **gpu_params
        )

    # SVM
    elif model_name == "svm":
        svm= LinearSVC(
            C=trial.suggest_float("C", 0.1, 3.0),
            max_iter=5000,
            class_weight= 'balanced'
        )
        return CalibratedClassifierCV(svm, method="sigmoid")

    # XGBOOST
    elif model_name == "xgboost":
        return XGBClassifier(
            n_estimators=trial.suggest_int("n_estimators", 5, 30),
            max_depth=trial.suggest_int("max_depth", 3, 9),
            learning_rate=trial.suggest_float("learning_rate", 0.01, 0.3),
            subsample=trial.suggest_float("subsample", 0.5, 1.0),
            colsample_bytree=trial.suggest_float("colsample_bytree", 0.5, 1.0),
            eval_metric="logloss",
            random_state=42,
            class_weight= 'balanced',
            n_jobs=-1,
            #**gpu_params
        )

    # LIGHTGBM
    elif model_name == "lightgbm":
        return LGBMClassifier(
            n_estimators=trial.suggest_int("n_estimators", 5, 30),
            learning_rate=trial.suggest_float("learning_rate", 0.01, 0.3),
            max_depth=trial.suggest_int("max_depth", 3, 9),
            subsample=trial.suggest_float("subsample", 0.5, 1.0),
            colsample_bytree=trial.suggest_float("colsample_bytree", 0.5, 1.0),
            random_state=42,
            is_unbalance=True,
           force_col_wise=True,
            **gpu_params
        )

# %% [markdown]
# ### 2. FUNÇÃO OBJETIVO DO OPTUNA (COM CROSS-VALIDATION)

# %% [markdown]
# ### Função `build_pipeline`: pré-processamento, balanceamento e modelagem em um fluxo único
#
# Esta função constrói um pipeline completo de treinamento, integrando pré-processamento dos dados,
# tratamento de desbalanceamento e ajuste do modelo em uma única estrutura reprodutível.
#
# O pipeline é organizado em três blocos sequenciais:
#
# 1) **Pré-processamento por tipo de variável**
# - Variáveis numéricas passam por imputação da mediana, reduzindo sensibilidade a outliers,
# seguida de padronização (`StandardScaler`), garantindo escalas compatíveis para modelos sensíveis à magnitude.
# - Variáveis categóricas passam por imputação do valor mais frequente e codificação via `OneHotEncoder`,
# com tratamento explícito de categorias raras (`handle_unknown='infrequent_if_exist'`),
# o que reduz dimensionalidade excessiva e melhora estabilidade do modelo.
#
# 2) **Balanceamento de classes (SMOTE)**
# Após o pré-processamento, aplica-se o SMOTE para gerar amostras sintéticas da classe minoritária
# exclusivamente no conjunto de treino dentro do pipeline,
# evitando vazamento de informação (*data leakage*) e melhorando a capacidade do modelo
# em aprender fronteiras de decisão mais equilibradas.
#
# 3) **Modelo preditivo**
# O estimador final é injetado de forma modular, permitindo que diferentes algoritmos
# (Random Forest, SVM, XGBoost, LightGBM, etc.) sejam testados sob exatamente o mesmo fluxo de dados.
#
# Ao encapsular todas as etapas em um único objeto `Pipeline`,
# a função garante consistência entre treino, validação e inferência,
# além de facilitar integração com validação cruzada e otimização de hiperparâmetros.

# %%
def build_pipeline(model, cat_cols, num_cols):

    # construindo o preprocessor
    num_preprocessor = Pipeline(steps=[
        ("imputer", SimpleImputer(strategy="median")),
        ("scaler", StandardScaler())
    ])

    cat_preprocessor = Pipeline(steps=[
        ("imputer", SimpleImputer(strategy="most_frequent")),
        ("onehot", OneHotEncoder(handle_unknown='infrequent_if_exist'))
    ])

    preprocessor = ColumnTransformer(
        transformers=[
            ("num", num_preprocessor, num_cols),
            ("cat", cat_preprocessor, cat_cols)
        ]
    )

    # construindo pipe
    pipe = Pipeline([
        ("preprocessor", preprocessor),
        ("smote", SMOTE(random_state=42)),
        ("model", model)
    ])

    return pipe

# %% [markdown]
# ### Função `objective`: avaliação do modelo por validação cruzada e otimização com Optuna (com pruning)
#
# Esta função define a métrica objetivo utilizada pelo Optuna durante a busca de hiperparâmetros.
# Para cada `trial`, ela instancia um modelo candidato (via `create_model`) e o encapsula em um pipeline completo
# de pré-processamento + balanceamento (via `build_pipeline`), garantindo que todas as transformações
# sejam aplicadas corretamente dentro de cada fold e evitando *data leakage*.
#
# A avaliação é realizada com **validação cruzada estratificada** (`StratifiedKFold`),
# preservando a proporção de classes em treino e validação. Em cada fold:
# - o pipeline é treinado no subconjunto de treino (`fit`),
# - e a performance é medida no subconjunto de validação por **ROC-AUC** calculado a partir de probabilidades (`predict_proba`).
#
# Para suportar cenários multiclasse, o AUC é calculado com `multi_class='ovr'`
# e agregação `average='weighted'`, o que pondera o desempenho pelo suporte de cada classe
# e reduz distorções em bases desbalanceadas.
#
# Além disso, a função utiliza mecanismos de *early stopping* do Optuna:
# - `trial.report` comunica a métrica parcial por fold,
# - `trial.should_prune()` permite interromper tentativas com desempenho fraco,
# economizando tempo computacional e acelerando a convergência do processo de otimização.
#
# Ao final, a função retorna a média do AUC entre os folds, que é o valor maximizado pelo Optuna.

# %%
def objective(trial, X_train, y_train, cat_cols, num_cols,feature_names, gpu_info):

    model = create_model(trial, gpu_info)

    pipe = build_pipeline(model ,cat_cols, num_cols)


    cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

    scores = []
    for step, (train_idx, val_idx) in enumerate(cv.split(X_train, y_train)):

        X_tr, X_val = X_train.iloc[train_idx], X_train.iloc[val_idx]
        y_tr, y_val = y_train.iloc[train_idx], y_train.iloc[val_idx]


        pipe.fit(X_tr, y_tr)
        # Modified roc_auc_score to handle multi-class classification
        fold_auc = roc_auc_score(y_val, pipe.predict_proba(X_val), multi_class='ovr', average='weighted')
        scores.append(fold_auc)

        #  reporta o valor parcial ao Optuna
        trial.report(fold_auc, step=step)

        #  aborta a tentativa dado a avaliação do pruner
        if trial.should_prune():
            raise TrialPruned()


    return np.mean(scores)

# %% [markdown]
# Salva o histórico das trials do Optuna (métrica, parâmetros, estado e duração)
# em arquivo CSV para análise e rastreabilidade do processo de otimização.

# %%
# salva os logs das tentativas com métricas, tempo de treinamento, e parametros utilizados pelos modelos
def dump_trials(study, trial, out_path):
    df_metrics = study.trials_dataframe(
        attrs=("number", "value", "params", "state", "duration")
    )
    df_metrics.to_csv(out_path, index=False)

# %% [markdown]
# ### 3. VALIDAÇÃO EXTERNA (OUTER CV) + OPTUNA INTERNO

# %% [markdown]
# ### Função `outer_cv_training_with_results`: nested CV com Optuna, checkpoint e métricas por fold
#
# Esta função executa um processo completo de treinamento e avaliação com **validação cruzada externa**
# (*outer cross-validation*), integrando **otimização de hiperparâmetros com Optuna** dentro de cada fold
# e registrando resultados detalhados (modelo escolhido, métricas, tempo e artefatos salvos).
#
# O fluxo segue a lógica de *nested cross-validation*:
#
# 1) **Diagnóstico do ambiente (GPU)**
# Antes do treinamento, a função identifica a disponibilidade de GPU (`detect_gpu`), permitindo que a criação dos modelos
# ative parâmetros específicos de aceleração quando suportado.
#
# 2) **Validação cruzada externa (generalização)**
# É aplicada uma `StratifiedKFold` externa com `n_splits`, garantindo que a proporção das classes seja preservada em cada divisão.
# Em cada fold externo, o conjunto é particionado em `X_train/y_train` (para otimização e treino) e `X_test/y_test` (avaliação final).
#
# 3) **Otimização interna com Optuna (seleção de modelo + hiperparâmetros)**
# Para cada fold externo, um `study` é criado com objetivo de maximizar a métrica definida na função `objective`.
# A função `objective` é “fixada” via `partial`, injetando os dados do fold e metadados do pipeline (colunas numéricas e categóricas,
# GPU, etc.), de forma que cada trial avalie modelos e hiperparâmetros sob o mesmo protocolo.
#
# O estudo é executado com:
# - `n_trials` tentativas,
# - controle de tempo (`timeout`),
# - paralelismo (`n_jobs=-1`),
# - callback de logging (`dump_trials`) para persistir histórico das trials.
#
# 4) **Treinamento final do melhor modelo no fold e checkpoint**
# Após a otimização, a melhor configuração é recuperada (`study.best_params`) e o melhor modelo é reconstruído (`create_model`),
# sendo então encapsulado em um pipeline (`build_pipeline`) com pré-processamento e SMOTE.
# O pipeline é treinado no conjunto de treino do fold com medição de tempo, e o artefato final é salvo em disco (`joblib.dump`)
# como checkpoint (`best_model_fold_k.pkl`), garantindo reprodutibilidade e possibilidade de reuso posterior.
#
# 5) **Avaliação no conjunto de teste do fold (métricas completas)**
# O modelo treinado é avaliado no `X_test/y_test` do fold externo usando:
# - **ROC-AUC multiclasse** com estratégia OvR e média ponderada (`average='weighted'`),
# - além de `accuracy`, `f1`, `recall` e `precision` (também ponderadas), adequadas para cenários desbalanceados.
#
# Ao final, a função retorna uma lista de dicionários com os resultados de cada fold,
# incluindo o modelo vencedor, hiperparâmetros, métricas, tempo de treino e caminho do checkpoint.
# Isso permite comparar estabilidade do desempenho entre folds e estimar capacidade real de generalização.

# %%
def outer_cv_training_with_results(
    X, y, cat_cols, num_cols,
    n_trials=30, n_splits=5,
    log_dir="log_opt",
    model_ckpt_dir="checkpoints_best_models"
):
    gpu_info = detect_gpu()
    print("\n🔍 GPU detectada:", gpu_info)


    outer_cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
    results = []
    feature_names = X.columns

    for fold, (train_idx, test_idx) in enumerate(outer_cv.split(X, y), start=1):

        print(f"\n==============================")
        print(f"  Fold Externo {fold}/{n_splits}")
        print(f"==============================")

        X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

        pruner = SuccessiveHalvingPruner(
            min_resource=1, reduction_factor=3, min_early_stopping_rate=1
        )

        study = optuna.create_study(direction="maximize", pruner=pruner)

        objective_fixed = partial(
            objective,
            X_train=X_train,
            y_train=y_train,
            cat_cols=cat_cols,
            num_cols=num_cols,
            feature_names=feature_names,
            gpu_info=gpu_info
        )

        # log por fold (arquivo diferente)
        log_path = os.path.join(log_dir, f"trials_log_fold_{fold}.csv")
        dump_trials_cb = partial(dump_trials, out_path=log_path)

        study.optimize(
            objective_fixed,
            n_trials=n_trials,
            callbacks=[dump_trials_cb],
            timeout=1800,
            n_jobs=-1,
        )

        best_params = study.best_params
        best_model_name = best_params.get("model_name", "unknown")
        best_model = create_model(study.best_trial, gpu_info)

        pipe = build_pipeline(best_model, cat_cols, num_cols)

        start_time = time.time()
        pipe.fit(X_train, y_train)
        train_time = time.time() - start_time

        # checkpoint do melhor modelo do fold
        checkpoint_path = os.path.join(model_ckpt_dir, f"best_model_fold_{fold}.pkl")
        joblib.dump(pipe, checkpoint_path)

        # predição
        y_pred = pipe.predict(X_test)
        # For multi-class AUC, pass the full probability matrix and specify multi_class and average
        y_pred_prob = pipe.predict_proba(X_test)

        # métricas
        auc = roc_auc_score(y_test, y_pred_prob, multi_class='ovr', average='weighted')
        acc = accuracy_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred, average='weighted')
        rec = recall_score(y_test, y_pred, average='weighted')
        prec = precision_score(y_test, y_pred, average='weighted')

        # salvar dados do fold
        results.append({
            "fold": fold,
            "best_model": best_model_name,
            "auc": auc,
            "accuracy": acc,
            "f1": f1,
            "recall": rec,
            "precision": prec,
            "hyperparameters": best_params,
            "checkpoint_path": checkpoint_path,
            "train_time_seconds": train_time,
        })

        fold += 1

    return results

# %% [markdown]
# # Execute Framework

# %% [markdown]
# Cria os diretórios de checkpoints de modelos e logs de otimização,
# caso não existam, garantindo persistência e organização dos artefatos do experimento.

# %%
import os, joblib
checkpoint_dir = "checkpoints_best_models"

if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)

checkpoint_dir = "log_opt"
if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)


# ================================================

# %% [markdown]
# ### Execução do treinamento com validação cruzada externa e otimização de hiperparâmetros
#
# Nesta etapa, o conjunto de dados é preparado para o processo completo de treinamento e avaliação.
# Inicialmente, as colunas são classificadas em **categóricas** e **numéricas** por meio da função
# `get_feature_types`, garantindo que o pré-processamento subsequente seja aplicado de forma adequada
# a cada tipo de variável.
#
# Em seguida, é executado o procedimento de **validação cruzada externa** (*outer cross-validation*),
# no qual, para cada fold, ocorre uma otimização interna de hiperparâmetros via Optuna.
# Esse desenho experimental permite avaliar o desempenho dos modelos de forma mais realista,
# uma vez que o conjunto de teste de cada fold permanece completamente isolado do processo de tuning.
#
# Os parâmetros utilizados (`n_trials=30` e `n_splits=5`) definem, respectivamente,
# o orçamento de busca de hiperparâmetros em cada fold e o número de partições externas,
# balanceando custo computacional e robustez estatística.
#
# O resultado final (`df_results`) contém métricas, hiperparâmetros selecionados,
# tempos de treinamento e caminhos dos checkpoints para cada fold,
# servindo como base para análises comparativas e seleção do modelo final.

# %%
cat_cols, num_cols = get_feature_types(X_data)
df_results = outer_cv_training_with_results(
    X_data, y_data,
    cat_cols=cat_cols,
    num_cols=num_cols,
    n_trials=50,
    n_splits=5
)
# Out:
# [I 2026-02-08 21:43:24,481] A new study created in memory with name: no-name-5f50f459-fac0-4f3c-ae83-d96fbf65b896
# 🔍 GPU detectada: {'cuda_available': False, 'lightgbm_gpu': False, 'gpu_info': 'Nenhuma GPU detectada (nvidia-smi não disponível)'}
#
# ==============================
#   Fold Externo 1/5
# ==============================
# [I 2026-02-08 21:44:02,382] Trial 1 finished with value: 0.6852632529420887 and parameters: {'model_name': 'random_forest', 'n_estimators': 20, 'max_depth': 9, 'min_samples_split': 5, 'min_samples_leaf': 2}. Best is trial 1 with value: 0.6852632529420887.
# [I 2026-02-08 21:44:03,464] Trial 0 finished with value: 0.7086304631278858 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.2997440426941218, 'max_depth': 6, 'subsample': 0.7139331938814663, 'colsample_bytree': 0.5239453785188298}. Best is trial 0 with value: 0.7086304631278858.
# [I 2026-02-08 21:44:27,430] Trial 3 finished with value: 0.6855482225847948 and parameters: {'model_name': 'random_forest', 'n_estimators': 29, 'max_depth': 8, 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.7086304631278858.
# [I 2026-02-08 21:44:49,031] Trial 4 finished with value: 0.6645587429169885 and parameters: {'model_name': 'random_forest', 'n_estimators': 10, 'max_depth': 5, 'min_samples_split': 8, 'min_samples_leaf': 5}. Best is trial 0 with value: 0.7086304631278858.
# [I 2026-02-08 21:45:19,639] Trial 5 finished with value: 0.6949175762285451 and parameters: {'model_name': 'xgboost', 'n_estimators': 17, 'max_depth': 5, 'learning_rate': 0.1391853795410878, 'subsample': 0.922303494938358, 'colsample_bytree': 0.7068555510179317}. Best is trial 0 with value: 0.7086304631278858.
# [I 2026-02-08 21:45:41,358] Trial 2 finished with value: 0.6941381486179267 and parameters: {'model_name': 'svm', 'C': 1.0778466865285556}. Best is trial 0 with value: 0.7086304631278858.
# [I 2026-02-08 21:45:51,374] Trial 6 finished with value: 0.700403279890177 and parameters: {'model_name': 'xgboost', 'n_estimators': 14, 'max_depth': 7, 'learning_rate': 0.1512753949094452, 'subsample': 0.6642022558395394, 'colsample_bytree': 0.5645933964725256}. Best is trial 0 with value: 0.7086304631278858.
# [I 2026-02-08 21:46:08,042] Trial 7 finished with value: 0.6557251760170413 and parameters: {'model_name': 'random_forest', 'n_estimators': 6, 'max_depth': 6, 'min_samples_split': 9, 'min_samples_leaf': 2}. Best is trial 0 with value: 0
and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.21384890351694807, 'max_depth': 7, 'subsample': 0.5909012810153974, 'colsample_bytree': 0.8132646538752556}. Best is trial 21 with value: 0.7094274769714182.
# [I 2026-02-08 21:51:03,769] Trial 23 finished with value: 0.7083938054637565 and parameters: {'model_name': 'lightgbm', 'n_estimators': 21, 'learning_rate': 0.217683435070433, 'max_depth': 7, 'subsample': 0.5853397551873415, 'colsample_bytree': 0.8257672511812607}. Best is trial 21 with value: 0.7094274769714182.
# [I 2026-02-08 21:51:28,535] Trial 24 finished with value: 0.7079543217147344 and parameters: {'model_name': 'lightgbm', 'n_estimators': 21, 'learning_rate': 0.19273582308864834, 'max_depth': 7, 'subsample': 0.6149632020510536, 'colsample_bytree': 0.9966543478324917}. Best is trial 21 with value: 0.7094274769714182.
# [I 2026-02-08 21:51:29,595] Trial 25 finished with value: 0.7089355727923842 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.18498169133699965, 'max_depth': 8, 'subsample': 0.6005784561326223, 'colsample_bytree': 0.9883509854214108}. Best is trial 21 with value: 0.7094274769714182.
# [I 2026-02-08 21:51:53,874] Trial 26 finished with value: 0.7102089907793311 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.1833113478357459, 'max_depth': 8, 'subsample': 0.5832272250894193, 'colsample_bytree': 0.7838732917353263}. Best is trial 26 with value: 0.7102089907793311.
# [I 2026-02-08 21:51:54,385] Trial 27 finished with value: 0.7108068742508338 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.2501756168254183, 'max_depth': 8, 'subsample': 0.5656301880165443, 'colsample_bytree': 0.781120843127629}. Best is trial 27 with value: 0.7108068742508338.
# [I 2026-02-08 21:52:20,668] Trial 28 finished with value: 0.7092406071355897 and parameters: {'model_name': 'lightgbm', 'n_estimators': 22, 'learning_rate': 0.25174979260618124, 'max_depth': 8, 'subsample': 0.5564764710027896, 'colsample_bytree': 0.7627736844373141}. Best is trial 27 with value: 0.7108068742508338.
# [I 2026-02-08 21:52:37,478] Trial 29 finished with value: 0.7051563604840766 and parameters: {'model_name': 'xgboost', 'n_estimators': 23, 'max_depth': 8, 'learning_rate': 0.2512799553702347, 'subsample': 0.5454088252952074, 'colsample_bytree': 0.7666135488536895}. Best is trial 27 with value: 0.7108068742508338.
# [I 2026-02-08 21:53:02,488] Trial 30 finished with value: 0.7062283048440169 and parameters: {'model_name': 'xgboost', 'n_estimators': 23, 'max_depth': 8, 'learning_rate': 0.2570018201338796, 'subsample': 0.747964249762314, 'colsample_bytree': 0.9062880390576754}. Best is trial 27 with value: 0.7108068742508338.
# [I 2026-02-08 21:53:28,680] Trial 32 finished with value: 0.7104733877578345 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.1871237596332916, 'max_depth': 9, 'subsample': 0.6454294971090202, 'colsample_bytree': 0.8565597549682576}. Best is trial 27 with value: 0.7108068742508338.
# [I 2026-02-08 21:53:34,400] Trial 31 finished with value: 0.6987315218763 and parameters: {'model_name': 'svm', 'C': 0.1370989445002091}. Best is trial 27 with value: 0.7108068742508338.
# [I 2026-02-08 21:53:53,749] Trial 33 finished with value: 0.7110157646347152 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.17768268066313536, 'max_depth': 9, 'subsample': 0.6307243188569395, 'colsample_bytree': 0.889726450524801}. Best is trial 33 with value: 0.7110157646347152.
# [I 2026-02-08 21:54:00,351] Trial 34 finished with value: 0.7103269267219279 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0
# [I 2026-02-08 21:58:35,393] Trial 47 finished with value: 0.7085042916118863 and parameters: {'model_name': 'xgboost', 'n_estimators': 28, 'max_depth': 8, 'learning_rate': 0.20104166164602622, 'subsample': 0.6848451708152129, 'colsample_bytree': 0.9526572656981418}. Best is trial 33 with value: 0.7110157646347152.
# [I 2026-02-08 21:58:45,704] Trial 49 finished with value: 0.6897565258436346 and parameters: {'model_name': 'lightgbm', 'n_estimators': 8, 'learning_rate': 0.08428456989199554, 'max_depth': 9, 'subsample': 0.55101243893213, 'colsample_bytree': 0.8487866172208861}. Best is trial 33 with value: 0.7110157646347152.
# [LightGBM] [Info] Total Bins 21425
# [LightGBM] [Info] Number of data points in the train set: 29274, number of used features: 223
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [I 2026-02-08 21:58:56,190] A new study created in memory with name: no-name-34cd406b-561b-478a-9381-4a92cef6cecc
# ==============================
#   Fold Externo 2/5
# ==============================
# [I 2026-02-08 21:59:21,804] Trial 0 finished with value: 0.6993743765631283 and parameters: {'model_name': 'xgboost', 'n_estimators': 21, 'max_depth': 3, 'learning_rate': 0.27758919417045524, 'subsample': 0.9927507222330925, 'colsample_bytree': 0.6600194177115927}. Best is trial 0 with value: 0.6993743765631283.
# [I 2026-02-08 21:59:22,233] Trial 1 finished with value: 0.7093712424840781 and parameters: {'model_name': 'lightgbm', 'n_estimators': 25, 'learning_rate': 0.2811466046210773, 'max_depth': 9, 'subsample': 0.7671717276647886, 'colsample_bytree': 0.7900085381205055}. Best is trial 1 with value: 0.7093712424840781.
# [I 2026-02-08 21:59:52,234] Trial 3 finished with value: 0.6996882917500287 and parameters: {'model_name': 'xgboost', 'n_estimators': 19, 'max_depth': 7, 'learning_rate': 0.05949862118430788, 'subsample': 0.960018558250048, 'colsample_bytree': 0.5206798095933967}. Best is trial 1 with value: 0.7093712424840781.
# [I 2026-02-08 22:00:15,492] Trial 4 finished with value: 0.700127052076931 and parameters: {'model_name': 'lightgbm', 'n_estimators': 12, 'learning_rate': 0.18349934868804688, 'max_depth': 5, 'subsample': 0.5623321634453197, 'colsample_bytree': 0.9019672996489789}. Best is trial 1 with value: 0.7093712424840781.
# [I 2026-02-08 22:00:31,713] Trial 2 finished with value: 0.6952967867225422 and parameters: {'model_name': 'svm', 'C': 0.27683149117349937}. Best is trial 1 with value: 0.7093712424840781.
# [I 2026-02-08 22:00:38,054] Trial 5 finished with value: 0.6705169746523788 and parameters: {'model_name': 'random_forest', 'n_estimators': 20, 'max_depth': 4, 'min_samples_split': 9, 'min_samples_leaf': 2}. Best is trial 1 with value: 0.7093712424840781.
# [I 2026-02-08 22:00:54,949] Trial 6 finished with value: 0.6818136888445742 and parameters: {'model_name': 'random_forest', 'n_estimators': 21, 'max_depth': 7, 'min_samples_split': 4, 'min_samples_leaf': 4}. Best is trial 1 with value: 0.7093712424840781.
# [I 2026-02-08 22:01:52,932] Trial 7 finished with value: 0.6956656371395528 and parameters: {'model_name': 'svm', 'C': 0.2397411578777039}. Best is trial 1 with value: 0.7093712424840781.
# [I 2026-02-08 22:02:13,835] Trial 9 finished with value: 0.63488472708458 and parameters: {'model_name': 'random_forest', 'n_estimators': 6, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 2}. Best is trial 1 with value: 0
# [I 2026-02-08 22:13:52,148] Trial 49 finished with value: 0.7031702953028223 and parameters: {'model_name': 'lightgbm', 'n_estimators': 20, 'learning_rate': 0.26424042856376767, 'max_depth': 3, 'subsample': 0.9888560705851807, 'colsample_bytree': 0.6211271422569888}. Best is trial 16 with value: 0.7108187388113266.
# [LightGBM] [Info] Total Bins 21432
# [LightGBM] [Info] Number of data points in the train set: 29274, number of used features: 223
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# ==============================
#   Fold Externo 3/5
# ==============================
# [I 2026-02-08 22:14:00,941] A new study created in memory with name: no-name-82f763ff-558e-4117-a35e-c0802d343b0b
# [I 2026-02-08 22:14:23,802] Trial 1 finished with value: 0.6622494445063493 and parameters: {'model_name': 'random_forest', 'n_estimators': 8, 'max_depth': 6, 'min_samples_split': 6, 'min_samples_leaf': 5}. Best is trial 1 with value: 0.6622494445063493.
# [I 2026-02-08 22:14:24,430] Trial 0 finished with value: 0.6713077536779949 and parameters: {'model_name': 'random_forest', 'n_estimators': 9, 'max_depth': 9, 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.6713077536779949.
# [I 2026-02-08 22:14:46,858] Trial 2 finished with value: 0.6863143812394045 and parameters: {'model_name': 'random_forest', 'n_estimators': 27, 'max_depth': 7, 'min_samples_split': 6, 'min_samples_leaf': 2}. Best is trial 2 with value: 0.6863143812394045.
# [I 2026-02-08 22:14:48,162] Trial 3 finished with value: 0.6843709510551271 and parameters: {'model_name': 'random_forest', 'n_estimators': 22, 'max_depth': 9, 'min_samples_split': 9, 'min_samples_leaf': 5}. Best is trial 2 with value: 0.6863143812394045.
# [I 2026-02-08 22:17:02,806] Trial 4 finished with value: 0.69293592827607 and parameters: {'model_name': 'svm', 'C': 2.0611051751049017}. Best is trial 4 with value: 0.69293592827607.
# [I 2026-02-08 22:17:07,173] Trial 5 finished with value: 0.6927024470730058 and parameters: {'model_name': 'svm', 'C': 2.801859016224358}. Best is trial 4 with value: 0.69293592827607.
# [I 2026-02-08 22:17:33,401] Trial 7 finished with value: 0.6813964561544702 and parameters: {'model_name': 'random_forest', 'n_estimators': 29, 'max_depth': 6, 'min_samples_split': 8, 'min_samples_leaf': 1}. Best is trial 4 with value: 0.69293592827607.
# [I 2026-02-08 22:17:54,097] Trial 6 finished with value: 0.6920747904788261 and parameters: {'model_name': 'xgboost', 'n_estimators': 27, 'max_depth': 7, 'learning_rate': 0.0247010778682207, 'subsample': 0.5146757827034665, 'colsample_bytree': 0.9605822953758584}. Best is trial 4 with value: 0.69293592827607.
# [I 2026-02-08 22:19:45,758] Trial 9 finished with value: 0.6937163816963389 and parameters: {'model_name': 'svm', 'C': 1.0239088880389131}. Best is trial 9 with value: 0.6937163816963389.
# [I 2026-02-08 22:19:55,936] Trial 8 finished with value: 0.6926651069983398 and parameters: {'model_name': 'svm', 'C': 2.945366319314394}. Best is trial 9 with value: 0.6937163816963389.
# [I 2026-02-08 22:20:20,185] Trial 10 finished with value: 0.6923031159001404 and parameters: {'model_name': 'xgboost', 'n_estimators': 8, 'max_depth': 8, 'learning_rate': 0.0922510611204827, 'subsample': 0.6567623642480375, 'colsample_bytree': 0.7226373863467728}. Best is trial 9 with value: 0.6937163816963389.
# [I 2026-02-08 22:20:21,708] Trial 11 finished with value: 0.69863526812252 and parameters: {'model_name': 'lightgbm', 'n_estimators': 15, 'learning_rate': 0.279291580166908, 'max_depth': 3, 'subsample': 0.9664377931840119, 'colsample_bytree': 0.5276065569364701}. Best is trial 11 with value: 0.69863526812252.
# [I 2026-02-08 22:26:33,968] Trial 34 finished with value: 0.7036540872195437 and parameters: {'model_name': 'xgboost', 'n_estimators': 30, 'max_depth': 8, 'learning_rate': 0.2523817346115943, 'subsample': 0.5878764962352078, 'colsample_bytree': 0.9924664329407793}. Best is trial 27 with value: 0.708165717469028.
# [I 2026-02-08 22:26:52,013] Trial 35 finished with value: 0.7055545921647397 and parameters: {'model_name': 'xgboost', 'n_estimators': 30, 'max_depth': 8, 'learning_rate': 0.259988258304823, 'subsample': 0.5780933491190081, 'colsample_bytree': 0.7641830702879105}. Best is trial 27 with value: 0.708165717469028.
# [I 2026-02-08 22:26:59,953] Trial 36 finished with value: 0.6871704531763498 and parameters: {'model_name': 'xgboost', 'n_estimators': 5, 'max_depth': 8, 'learning_rate': 0.26223473286884125, 'subsample': 0.6970138808597759, 'colsample_bytree': 0.7764366440444171}. Best is trial 27 with value: 0.708165717469028.
# [I 2026-02-08 22:27:28,650] Trial 37 finished with value: 0.7072130021414486 and parameters: {'model_name': 'xgboost', 'n_estimators': 28, 'max_depth': 7, 'learning_rate': 0.21748499936463767, 'subsample': 0.6964639224612852, 'colsample_bytree': 0.7696690324894531}. Best is trial 27 with value: 0.708165717469028.
# [I 2026-02-08 22:27:37,516] Trial 38 finished with value: 0.7069577459998445 and parameters: {'model_name': 'xgboost', 'n_estimators': 28, 'max_depth': 7, 'learning_rate': 0.22342868118009587, 'subsample': 0.7041312607946373, 'colsample_bytree': 0.9039433264826151}. Best is trial 27 with value: 0.708165717469028.
# [I 2026-02-08 22:28:00,147] Trial 39 finished with value: 0.7067334135881228 and parameters: {'model_name': 'xgboost', 'n_estimators': 27, 'max_depth': 6, 'learning_rate': 0.2180889397555924, 'subsample': 0.7043251129293618, 'colsample_bytree': 0.884576888418481}. Best is trial 27 with value: 0.708165717469028.
# [I 2026-02-08 22:28:08,889] Trial 40 finished with value: 0.7060030806424361 and parameters: {'model_name': 'xgboost', 'n_estimators': 26, 'max_depth': 6, 'learning_rate': 0.22301492148439334, 'subsample': 0.5480392604346742, 'colsample_bytree': 0.8713027269141232}. Best is trial 27 with value: 0.708165717469028.
# [I 2026-02-08 22:28:22,789] Trial 41 finished with value: 0.6813655257252919 and parameters: {'model_name': 'random_forest', 'n_estimators': 26, 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 3}. Best is trial 27 with value: 0.708165717469028.
# [I 2026-02-08 22:28:50,875] Trial 42 finished with value: 0.6905783147455887 and parameters: {'model_name': 'xgboost', 'n_estimators': 29, 'max_depth': 7, 'learning_rate': 0.023162336343735823, 'subsample': 0.6962412567009302, 'colsample_bytree': 0.9696575177756139}. Best is trial 27 with value: 0.708165717469028.
# [I 2026-02-08 22:29:03,264] Trial 43 finished with value: 0.693633481792399 and parameters: {'model_name': 'xgboost', 'n_estimators': 28, 'max_depth': 7, 'learning_rate': 0.034324121203555935, 'subsample': 0.699900573678546, 'colsample_bytree': 0.9510971953946933}. Best is trial 27 with value: 0.708165717469028.
# [I 2026-02-08 22:29:28,869] Trial 44 finished with value: 0.7054070157519153 and parameters: {'model_name': 'xgboost', 'n_estimators': 28, 'max_depth': 7, 'learning_rate': 0.2341621164255693, 'subsample': 0.612277115359859, 'colsample_bytree': 0.9288292416028873}. Best is trial 27 with value: 0.708165717469028.
# [I 2026-02-08 22:29:53,938] Trial 45 finished with value: 0.7031824284950754 and parameters: {'model_name': 'xgboost', 'n_estimators': 28, 'max_depth': 9, 'learning_rate': 0.23269747435734855, 'subsample': 0.6113622099460804, 'colsample_bytree': 0.9081241896343739}. Best is trial 27 with value: 0.708165717469028.
# [I 2026-02-08 22:30:12,930] Trial 46 finished with value: 0.7033499757120678 and parameters: {'model_name': 'xgboost', 'n_estimators': 30, 'max_depth': 8, 'learning_rate': 0.2714371896892178, 'subsample': 0.5297494590654639, 'colsample_bytree': 0.8718054132080748}. Best is trial 27 with value: 0.708165717469028.
# [I 2026-02-08 22:30:35,299] Trial 48 finished with value: 0.6845529431682849 and parameters: {'model_name': 'random_forest', 'n_estimators': 27, 'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 4}. Best is trial 27 with value: 0.708165717469028.
# [I 2026-02-08 22:30:39,056] Trial 47 finished with value: 0.7028344972990186 and parameters: {'model_name': 'xgboost', 'n_estimators': 30, 'max_depth': 8, 'learning_rate': 0.26724003985872463, 'subsample': 0.52327037663673, 'colsample_bytree': 0.8579112173452733}. Best is trial 27 with value: 0.708165717469028.
# [I 2026-02-08 22:31:00,111] Trial 49 finished with value: 0.7062054431646604 and parameters: {'model_name': 'xgboost', 'n_estimators': 25, 'max_depth': 8, 'learning_rate': 0.20431990392813038, 'subsample': 0.6758825375022106, 'colsample_bytree': 0.8530711650078808}. Best is trial 27 with value: 0.708165717469028.
# [I 2026-02-08 22:31:11,275] A new study created in memory with name: no-name-9b33d3db-1dfd-4162-ba57-fcd6a6a08253
# ==============================
#   Fold Externo 4/5
# ==============================
# [I 2026-02-08 22:31:34,662] Trial 0 finished with value: 0.6875660727219005 and parameters: {'model_name': 'random_forest', 'n_estimators': 23, 'max_depth': 8, 'min_samples_split': 6, 'min_samples_leaf': 4}. Best is trial 0 with value: 0.6875660727219005.
# [I 2026-02-08 22:31:50,337] Trial 1 finished with value: 0.7097086241268736 and parameters: {'model_name': 'xgboost', 'n_estimators': 30, 'max_depth': 7, 'learning_rate': 0.09591437801912236, 'subsample': 0.944523813747314, 'colsample_bytree': 0.70982990308188}. Best is trial 1 with value: 0.7097086241268736.
# [I 2026-02-08 22:32:07,989] Trial 2 finished with value: 0.7118232214104004 and parameters: {'model_name': 'xgboost', 'n_estimators': 17, 'max_depth': 8, 'learning_rate': 0.25919504969235946, 'subsample': 0.9344701214226495, 'colsample_bytree': 0.6026578917311081}. Best is trial 2 with value: 0.7118232214104004.
# [I 2026-02-08 22:32:15,779] Trial 3 finished with value: 0.7121211119066714 and parameters: {'model_name': 'lightgbm', 'n_estimators': 19, 'learning_rate': 0.24113635446706053, 'max_depth': 9, 'subsample': 0.6095277064411423, 'colsample_bytree': 0.9064188150058535}. Best is trial 3 with value: 0.7121211119066714.
# [I 2026-02-08 22:32:37,000] Trial 4 finished with value: 0.6870705810828904 and parameters: {'model_name': 'xgboost', 'n_estimators': 7, 'max_depth': 4, 'learning_rate': 0.2167536422661012, 'subsample': 0.72161574501395, 'colsample_bytree': 0.591320122156573}. Best is trial 3 with value: 0.7121211119066714.
# [I 2026-02-08 22:32:45,172] Trial 5 finished with value: 0.6763552201965769 and parameters: {'model_name': 'random_forest', 'n_estimators': 30, 'max_depth': 4, 'min_samples_split': 9, 'min_samples_leaf':
and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.15364547886914745, 'max_depth': 3, 'subsample': 0.6975604548167277, 'colsample_bytree': 0.9785398316463407}. Best is trial 7 with value: 0.7096863529756372.
# [I 2026-02-08 22:50:35,523] Trial 12 finished with value: 0.7089558109979163 and parameters: {'model_name': 'xgboost', 'n_estimators': 25, 'max_depth': 9, 'learning_rate': 0.2799074329195092, 'subsample': 0.8531548700704439, 'colsample_bytree': 0.5166476935260277}. Best is trial 7 with value: 0.7096863529756372.
# [I 2026-02-08 22:50:49,979] Trial 9 finished with value: 0.6952855721658521 and parameters: {'model_name': 'svm', 'C': 2.6582742413526823}. Best is trial 7 with value: 0.7096863529756372.
# [I 2026-02-08 22:51:14,115] Trial 13 finished with value: 0.709149009807239 and parameters: {'model_name': 'xgboost', 'n_estimators': 22, 'max_depth': 8, 'learning_rate': 0.1612588239827918, 'subsample': 0.8472235614805351, 'colsample_bytree': 0.6463447779628353}. Best is trial 7 with value: 0.7096863529756372.
# [I 2026-02-08 22:51:35,999] Trial 14 finished with value: 0.7094634931803893 and parameters: {'model_name': 'xgboost', 'n_estimators': 22, 'max_depth': 9, 'learning_rate': 0.16745638578525038, 'subsample': 0.8583544706593489, 'colsample_bytree': 0.650271247766191}. Best is trial 7 with value: 0.7096863529756372.
# [I 2026-02-08 22:51:50,646] Trial 15 finished with value: 0.7080861244850071 and parameters: {'model_name': 'xgboost', 'n_estimators': 20, 'max_depth': 8, 'learning_rate': 0.1522534824230444, 'subsample': 0.715198529429197, 'colsample_bytree': 0.665048587915925}. Best is trial 7 with value: 0.7096863529756372.
# [I 2026-02-08 22:51:59,521] Trial 16 finished with value: 0.7078101440242941 and parameters: {'model_name': 'lightgbm', 'n_estimators': 21, 'learning_rate': 0.1492810773661907, 'max_depth': 5, 'subsample': 0.9884056731684008, 'colsample_bytree': 0.6726476605700275}. Best is trial 7 with value: 0.7096863529756372.
# [I 2026-02-08 22:52:15,232] Trial 17 finished with value: 0.7113394514686232 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.2103474801114612, 'max_depth': 5, 'subsample': 0.9793416329325833, 'colsample_bytree': 0.8707056532857338}. Best is trial 17 with value: 0.7113394514686232.
# [I 2026-02-08 22:52:22,625] Trial 18 finished with value: 0.684635360637858 and parameters: {'model_name': 'random_forest', 'n_estimators': 29, 'max_depth': 6, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 17 with value: 0.7113394514686232.
# [I 2026-02-08 22:52:38,909] Trial 19 finished with value: 0.7113885463361739 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.22792304571662977, 'max_depth': 5, 'subsample': 0.6298909613065026, 'colsample_bytree': 0.8790912184980059}. Best is trial 19 with value: 0.7113885463361739.
# [I 2026-02-08 22:52:47,239] Trial 20 finished with value: 0.7113514039447718 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.21771371001897402, 'max_depth': 5, 'subsample': 0.6551472885867096, 'colsample_bytree': 0.8794898524966033}. Best is trial 19 with value: 0.7113885463361739.
# [I 2026-02-08 22:53:03,314] Trial 21 finished with value: 0.7097118797237414 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.22795801045648412, 'max_depth': 4, 'subsample': 0.500842013684066, 'colsample_bytree': 0.8434954066491236}. Best is trial 19 with value: 0.7113885463361739.
# [I 2026-02-08 22:53:12,268] Trial 22 finished with value: 0.7099619322279102 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0
and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.19074035843032153, 'max_depth': 6, 'subsample': 0.5704729576765084, 'colsample_bytree': 0.8231727892205614}. Best is trial 37 with value: 0.7120036371230528.
# [LightGBM] [Info] Total Bins 22011
# [LightGBM] [Info] Number of data points in the train set: 29277, number of used features: 222
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %% [markdown]
# #### Conferir checkpoints intermediarios

# %% [markdown]
# Consolida os resultados da validação cruzada externa em um DataFrame,
# salva o resumo em formato Parquet e carrega os logs das trials do Optuna
# para inspeção e análise do processo de otimização.

# %%
df_results=pd.DataFrame(df_results)
display(df_results)
# Out:
#    fold best_model       auc  accuracy        f1    recall  precision  \
# 0     1   lightgbm  0.708764  0.551958  0.505749  0.551958   0.516304
# 1     2   lightgbm  0.710111  0.550853  0.513884  0.550853   0.520223
# 2     3    xgboost  0.712616  0.542641  0.482311  0.542641   0.506682
# 3     4   lightgbm  0.690795  0.526457  0.504342  0.526457   0.507367
# 4     5   lightgbm  0.689032  0.529774  0.494305  0.529774   0.507492
#
#                                      hyperparameters  \
# 0  {'model_name': 'lightgbm', 'n_estimators': 27,...
# 1  {'model_name': 'lightgbm', 'n_estimators': 25,...
# 2  {'model_name': 'xgboost', 'n_estimators': 30, ...
# 3  {'model_name': 'lightgbm', 'n_estimators': 30,...
# 4  {'model_name': 'lightgbm', 'n_estimators': 27,...
#
#                                  checkpoint_path  train_time_seconds
# 0  checkpoints_best_models/best_model_fold_1.pkl           10.286502
# 1  checkpoints_best_models/best_model_fold_2.pkl            8.582524
# 2  checkpoints_best_models/best_model_fold_3.pkl           10.973317
# 3  checkpoints_best_models/best_model_fold_4.pkl            9.307247
# 4  checkpoints_best_models/best_model_fold_5.pkl            9.127014

# %%
df_results.to_parquet('df_results.parquet')

# %% [markdown]
# Carregando o pkl

# %%
import joblib

modelo = joblib.load("checkpoints_best_models/best_model_fold_1.pkl")

# %%
modelo
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['NU_IDADE_N',
#                                                    'baixa_escolaridade',
#                                                    'raca_vulneravel',
#                                                    'faixa_vulneravel',
#                                                    'vulnerabilidade_social',
#                                                    'mes_sintomas',
#                                                    'periodo_chuvoso']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy...
#                                                    'CLI_PANTUR', 'CLI_VOMITO',
#                                                    'CLI_DIARRE', 'CLI_OUTROS',
#                                                    'SG_UF',
#                                                    'nivel_vulnerabilidade',
#                                                    'estacao'])])),
#                 ('smote', SMOTE(random_state=42)),
#                 ('model',
#                  LGBMClassifier(colsample_bytree=0.889726450524801,
#                                 device='cpu', force_col_wise=True,
#                                 is_unbalance=True,
#                                 learning_rate=0.17768268066313536, max_depth=9,
#                                 n_estimators=27, random_state=42,
#                                 subsample=0.6307243188569395))])

# %%
modelo.named_steps["preprocessor"].get_feature_names_out()
# Out:
# array(['num__NU_IDADE_N', 'num__baixa_escolaridade',
#        'num__raca_vulneravel', 'num__faixa_vulneravel',
#        'num__vulnerabilidade_social', 'num__mes_sintomas',
#        'num__periodo_chuvoso', 'cat__CS_SEXO_Feminino',
#        'cat__CS_SEXO_Masculino', 'cat__CS_SEXO_Não informado',
#        'cat__CS_GESTANT_1º Trimestre', 'cat__CS_GESTANT_2º Trimestre',
#        'cat__CS_GESTANT_3º Trimestre',
#        'cat__CS_GESTANT_Idade gestacional ignorada',
#        'cat__CS_GESTANT_Não', 'cat__CS_GESTANT_Não informado',
#        'cat__CS_GESTANT_Não se aplica', 'cat__CS_RACA_Amarela',
#        'cat__CS_RACA_Branca', 'cat__CS_RACA_Indígena',
#        'cat__CS_RACA_Não informado', 'cat__CS_RACA_Parda',
#        'cat__CS_RACA_Preta', 'cat__CS_ESCOL_N_10',
#        'cat__CS_ESCOL_N_1ª a 4ª série incompleta do EF',
#        'cat__CS_ESCOL_N_4ª série completa do EF',
#        'cat__CS_ESCOL_N_5ª a 8ª série incompleta do EF',
#        'cat__CS_ESCOL_N_Ensino fundamental completo',
#        'cat__CS_ESCOL_N_Ensino médio completo',
#        'cat__CS_ESCOL_N_Ensino médio incompleto',
#        'cat__CS_ESCOL_N_Não informado',
#        'cat__CS_ESCOL_N_Sem escolaridade',
#        'cat__CS_ESCOL_N_Superior completo',
#        'cat__CS_ESCOL_N_Superior incompleto', 'cat__ID_OCUPA_N_000000',
#        'cat__ID_OCUPA_N_010205', 'cat__ID_OCUPA_N_010210',
#        'cat__ID_OCUPA_N_010310', 'cat__ID_OCUPA_N_010315',
#        'cat__ID_OCUPA_N_020110', 'cat__ID_OCUPA_N_020205',
#        'cat__ID_OCUPA_N_021110', 'cat__ID_OCUPA_N_021205',
#        'cat__ID_OCUPA_N_021210', 'cat__ID_OCUPA_N_031205',
#        'cat__ID_OCUPA_N_031210', 'cat__ID_OCUPA_N_100.01',
#        'cat__ID_OCUPA_N_111120', 'cat__ID_OCUPA_N_111220',
#        'cat__ID_OCUPA_N_111250', 'cat__ID_OCUPA_N_111255',
#        'cat__ID_OCUPA_N_111405', 'cat__ID_OCUPA_N_111415',
#        'cat__ID_OCUPA_N_111510', 'cat__ID_OCUPA_N_122610',
#        'cat__ID_OCUPA_N_123105', 'cat__ID_OCUPA_N_123305',
#        'cat__ID_OCUPA_N_123310', 'cat__ID_OCUPA_N_131310',
#        'cat__ID_OCUPA_N_131320', 'cat__ID_OCUPA_N_141105',
#        'cat__ID_OCUPA_N_141205', 'cat__ID_OCUPA_N_141305',
#        'cat__ID_OCUPA_N_1414.0', 'cat__ID_OCUPA_N_1414.1',
#        'cat__ID_OCUPA_N_141405', 'cat__ID_OCUPA_N_141410',
#        'cat__ID_OCUPA_N_141415', 'cat__ID_OCUPA_N_141505',
#        'cat__ID_OCUPA_N_141510', 'cat__ID_OCUPA_N_1416.1',
#        'cat__ID_OCUPA_N_141705', 'cat__ID_OCUPA_N_141710',
#        'cat__ID_OCUPA_N_142105', 'cat__ID_OCUPA_N_142115',
#        'cat__ID_OCUPA_N_142305', 'cat__ID_OCUPA_N_142320',
#        'cat__ID_OCUPA_N_142405', 'cat__ID_OCUPA_N_142415',
#        'cat__ID_OCUPA_N_142705', 'cat__ID_OCUPA_N_203510',
#        'cat__ID_OCUPA_N_211205', 'cat__ID_OCUPA_N_212.10',
#        'cat__ID_OCUPA_N_212205', 'cat__ID_OCUPA_N_212315',
#        'cat__ID_OCUPA_N_212410', 'cat__ID_OCUPA_N_212415',
#        'cat__ID_OCUPA_N_213205', 'cat__ID_OCUPA_N_213315',
#        'cat__ID_OCUPA_N_213405', 'cat__ID_OCUPA_N_213440',
#        'cat__ID_OCUPA_N_214005', 'cat__ID_OCUPA_N_214010',
#        'cat__ID_OCUPA_N_214105', 'cat__ID_OCUPA_N_214110',
#        'cat__ID_OCUPA_N_214120', 'cat__ID_OCUPA_N_214125',
#        'cat__ID_OCUPA_N_214205', 'cat__ID_OCUPA_N_214215',
#        'cat__ID_OCUPA_N_214235', 'cat__ID_OCUPA_N_214405',
#        'cat__ID_OCUPA_N_214420', 'cat__ID_OCUPA_N_214610',
#        'cat__ID_OCUPA_N_214615', 'cat__ID_OCUPA_N_221105',
#        'cat__ID_OCUPA_N_221205', 'cat__ID_OCUPA_N_222105',
#        'cat__ID_OCUPA_N_222110', 'cat__ID_OCUPA_N_222120',
#        'cat__ID_OCUPA_N_223106', 'cat__ID_OCUPA_N_223110',
#        'cat__ID_OCUPA_N_223112', 'cat__ID_OCUPA_N_223115',
#        'cat__ID_OCUPA_N_223122', 'cat__ID_OCUPA_N_223147',
#        'cat__ID_OCUPA_N_223149', 'cat__ID_OCUPA_N_223151',
#        'cat__ID_OCUPA_N_223208', 'cat__ID_OCUPA_N_2233.1',
#        'cat__ID_OCUPA_N_223305', 'cat__ID_OCUPA_N_223310',
#        'cat__ID_OCUPA_N_223405', 'cat__ID_OCUPA_N_223410',
#        'cat__ID_OCUPA_N_223415', 'cat__ID_OCUPA_N_2235.0',
#        'cat__ID_OCUPA_N_223505', 'cat__ID_OCUPA_N_2236.0',
#        'cat__ID_OCUPA_N_223605', 'cat__ID_OCUPA_N_223610',
#        'cat__ID_OCUPA_N_223620', 'cat__ID_OCUPA_N_223710',
#        'cat__ID_OCUPA_N_224120', 'cat__ID_OCUPA_N_2312.0',
#        'cat__ID_OCUPA_N_231205', 'cat__ID_OCUPA_N_231210',
#        'cat__ID_OCUPA_N_2313.1', 'cat__ID_OCUPA_N_231305',
#        'cat__ID_OCUPA_N_231310', 'cat__ID_OCUPA_N_231315',
#        'cat__ID_OCUPA_N_231320', 'cat__ID_OCUPA_N_231335',
#        'cat__ID_OCUPA_N_231340', 'cat__ID_OCUPA_N_232105',
#        'cat__ID_OCUPA_N_232110', 'cat__ID_OCUPA_N_232115',
#        'cat__ID_OCUPA_N_232120', 'cat__ID_OCUPA_N_232125',
#        'cat__ID_OCUPA_N_233105', 'cat__ID_OCUPA_N_233130',
#        'cat__ID_OCUPA_N_234305', 'cat__ID_OCUPA_N_234320',
#        'cat__ID_OCUPA_N_234415', 'cat__ID_OCUPA_N_234505',
#        'cat__ID_OCUPA_N_234624', 'cat__ID_OCUPA_N_2348.1',
#        'cat__ID_OCUPA_N_234810', 'cat__ID_OCUPA_N_239405',
#        'cat__ID_OCUPA_N_239410', 'cat__ID_OCUPA_N_239415',
#        'cat__ID_OCUPA_N_239425', 'cat__ID_OCUPA_N_241005',
#        'cat__ID_OCUPA_N_241225', 'cat__ID_OCUPA_N_241340',
#        'cat__ID_OCUPA_N_242235', 'cat__ID_OCUPA_N_251205',
#        'cat__ID_OCUPA_N_251510', 'cat__ID_OCUPA_N_251550',
#        'cat__ID_OCUPA_N_251605', 'cat__ID_OCUPA_N_2521.0',
#        'cat__ID_OCUPA_N_252105', 'cat__ID_OCUPA_N_2522.1',
#        'cat__ID_OCUPA_N_252205', 'cat__ID_OCUPA_N_252210',
#        'cat__ID_OCUPA_N_2523.0', 'cat__ID_OCUPA_N_252305',
#        'cat__ID_OCUPA_N_252515', 'cat__ID_OCUPA_N_252525',
#        'cat__ID_OCUPA_N_252545', 'cat__ID_OCUPA_N_253105',
#        'cat__ID_OCUPA_N_253115', 'cat__ID_OCUPA_N_253125',
#        'cat__ID_OCUPA_N_253205', 'cat__ID_OCUPA_N_253305',
#        'cat__ID_OCUPA_N_254310', 'cat__ID_OCUPA_N_254405',
#        'cat__ID_OCUPA_N_261125', 'cat__ID_OCUPA_N_261140',
#        'cat__ID_OCUPA_N_261205', 'cat__ID_OCUPA_N_261505',
#        'cat__ID_OCUPA_N_2617.0', 'cat__ID_OCUPA_N_2617.1',
#        'cat__ID_OCUPA_N_261730', 'cat__ID_OCUPA_N_261805',
#        'cat__ID_OCUPA_N_262105', 'cat__ID_OCUPA_N_262410',
#        'cat__ID_OCUPA_N_262705', 'cat__ID_OCUPA_N_262710',
#        'cat__ID_OCUPA_N_263110', 'cat__ID_OCUPA_N_271110',
#        'cat__ID_OCUPA_N_300305', 'cat__ID_OCUPA_N_301105',
#        'cat__ID_OCUPA_N_301110', 'cat__ID_OCUPA_N_311515',
#        'cat__ID_OCUPA_N_312.05', 'cat__ID_OCUPA_N_312105',
#        'cat__ID_OCUPA_N_312210', 'cat__ID_OCUPA_N_312305',
#        'cat__ID_OCUPA_N_312320', 'cat__ID_OCUPA_N_313105',
#        'cat__ID_OCUPA_N_313110', 'cat__ID_OCUPA_N_313120',
#        'cat__ID_OCUPA_N_313125', 'cat__ID_OCUPA_N_313130',
#        'cat__ID_OCUPA_N_313205', 'cat__ID_OCUPA_N_313215',
#        'cat__ID_OCUPA_N_313220', 'cat__ID_OCUPA_N_313305',
#        'cat__ID_OCUPA_N_313310', 'cat__ID_OCUPA_N_313315',
#        'cat__ID_OCUPA_N_313410', 'cat__ID_OCUPA_N_314105',
#        'cat__ID_OCUPA_N_314110', 'cat__ID_OCUPA_N_314115',
#        'cat__ID_OCUPA_N_314120', 'cat__ID_OCUPA_N_314405',
#        'cat__ID_OCUPA_N_314410', 'cat__ID_OCUPA_N_317105',
#        'cat__ID_OCUPA_N_317210', 'cat__ID_OCUPA_N_318015',
#        'cat__ID_OCUPA_N_3183.0', 'cat__ID_OCUPA_N_318405',
#        'cat__ID_OCUPA_N_318610', 'cat__ID_OCUPA_N_321105',
#        'cat__ID_OCUPA_N_321110', 'cat__ID_OCUPA_N_3222.3',
#        'cat__ID_OCUPA_N_322205', 'cat__ID_OCUPA_N_322225',
#        'cat__ID_OCUPA_N_322230', 'cat__ID_OCUPA_N_322430',
#        'cat__ID_OCUPA_N_3224F2', 'cat__ID_OCUPA_N_324115',
#        'cat__ID_OCUPA_N_324120', 'cat__ID_OCUPA_N_325110',
#        'cat__ID_OCUPA_N_331105', 'cat__ID_OCUPA_N_331110',
#        'cat__ID_OCUPA_N_331205', 'cat__ID_OCUPA_N_332205',
#        'cat__ID_OCUPA_N_333105', 'cat__ID_OCUPA_N_333110',
#        'cat__ID_OCUPA_N_333115', 'cat__ID_OCUPA_N_334110',
#        'cat__ID_OCUPA_N_334115', 'cat__ID_OCUPA_N_341120',
#        'cat__ID_OCUPA_N_341230', 'cat__ID_OCUPA_N_341310',
#        'cat__ID_OCUPA_N_342120', 'cat__ID_OCUPA_N_342205',
#        'cat__ID_OCUPA_N_342210', 'cat__ID_OCUPA_N_342315',
#        'cat__ID_OCUPA_N_342510', 'cat__ID_OCUPA_N_351115',
#        'cat__ID_OCUPA_N_351305', 'cat__ID_OCUPA_N_351605',
#        'cat__ID_OCUPA_N_3517.4', 'cat__ID_OCUPA_N_351740',
#        'cat__ID_OCUPA_N_352210', 'cat__ID_OCUPA_N_352310',
#        'cat__ID_OCUPA_N_352405', 'cat__ID_OCUPA_N_353230',
#        'cat__ID_OCUPA_N_3541.4', 'cat__ID_OCUPA_N_354120',
#        'cat__ID_OCUPA_N_354145', 'cat__ID_OCUPA_N_354415',
#        'cat__ID_OCUPA_N_354505', 'cat__ID_OCUPA_N_354605',
#        'cat__ID_OCUPA_N_3547.0', 'cat__ID_OCUPA_N_354705',
#        'cat__ID_OCUPA_N_371410', 'cat__ID_OCUPA_N_372210',
#        'cat__ID_OCUPA_N_373105', 'cat__ID_OCUPA_N_375115',
#        'cat__ID_OCUPA_N_375120', 'cat__ID_OCUPA_N_376110',
#        'cat__ID_OCUPA_N_376215', 'cat__ID_OCUPA_N_376225',
#        'cat__ID_OCUPA_N_376235', 'cat__ID_OCUPA_N_376305',
#        'cat__ID_OCUPA_N_377105', 'cat__ID_OCUPA_N_391110',
#        'cat__ID_OCUPA_N_391120', 'cat__ID_OCUPA_N_391125',
#        'cat__ID_OCUPA_N_391205', 'cat__ID_OCUPA_N_410105',
#        'cat__ID_OCUPA_N_410205', 'cat__ID_OCUPA_N_4110.0',
#        'cat__ID_OCUPA_N_4110.1', 'cat__ID_OCUPA_N_4110.3',
#        'cat__ID_OCUPA_N_411005', 'cat__ID_OCUPA_N_411010',
#        'cat__ID_OCUPA_N_411020', 'cat__ID_OCUPA_N_411030',
#        'cat__ID_OCUPA_N_411040', 'cat__ID_OCUPA_N_411045',
#        'cat__ID_OCUPA_N_412110', 'cat__ID_OCUPA_N_412205',
#        'cat__ID_OCUPA_N_413110', 'cat__ID_OCUPA_N_413205',
#        'cat__ID_OCUPA_N_413210', 'cat__ID_OCUPA_N_413220',
#        'cat__ID_OCUPA_N_414105', 'cat__ID_OCUPA_N_414110',
#        'cat__ID_OCUPA_N_414205', 'cat__ID_OCUPA_N_414210',
#        'cat__ID_OCUPA_N_414215', 'cat__ID_OCUPA_N_415205',
#        'cat__ID_OCUPA_N_420135', 'cat__ID_OCUPA_N_4211.2',
#        'cat__ID_OCUPA_N_421105', 'cat__ID_OCUPA_N_421125',
#        'cat__ID_OCUPA_N_422105', 'cat__ID_OCUPA_N_422110',
#        'cat__ID_OCUPA_N_422120', 'cat__ID_OCUPA_N_422125',
#        'cat__ID_OCUPA_N_422205', 'cat__ID_OCUPA_N_422210',
#        'cat__ID_OCUPA_N_422305', 'cat__ID_OCUPA_N_422310',
#        'cat__ID_OCUPA_N_423105', 'cat__ID_OCUPA_N_510120',
#        'cat__ID_OCUPA_N_510125', 'cat__ID_OCUPA_N_510130',
#        'cat__ID_OCUPA_N_511215', 'cat__ID_OCUPA_N_511405',
#        'cat__ID_OCUPA_N_5121.0', 'cat__ID_OCUPA_N_512105',
#        'cat__ID_OCUPA_N_512110', 'cat__ID_OCUPA_N_512115',
#        'cat__ID_OCUPA_N_512120', 'cat__ID_OCUPA_N_513115',
#        'cat__ID_OCUPA_N_5132.0', 'cat__ID_OCUPA_N_513205',
#        'cat__ID_OCUPA_N_513210', 'cat__ID_OCUPA_N_513215',
#        'cat__ID_OCUPA_N_5133.1', 'cat__ID_OCUPA_N_513315',
#        'cat__ID_OCUPA_N_513405', 'cat__ID_OCUPA_N_513420',
#        'cat__ID_OCUPA_N_513425', 'cat__ID_OCUPA_N_513435',
#        'cat__ID_OCUPA_N_513505', 'cat__ID_OCUPA_N_513605',
#        'cat__ID_OCUPA_N_513610', 'cat__ID_OCUPA_N_513615',
#        'cat__ID_OCUPA_N_514105', 'cat__ID_OCUPA_N_514120',
#        'cat__ID_OCUPA_N_5142.1', 'cat__ID_OCUPA_N_514205',
#        'cat__ID_OCUPA_N_514210', 'cat__ID_OCUPA_N_514215',
#        'cat__ID_OCUPA_N_514225', 'cat__ID_OCUPA_N_514230',
#        'cat__ID_OCUPA_N_514310', 'cat__ID_OCUPA_N_514330',
#        'cat__ID_OCUPA_N_515105', 'cat__ID_OCUPA_N_5152.1',
#        'cat__ID_OCUPA_N_5152.2', 'cat__ID_OCUPA_N_515210',
#        'cat__ID_OCUPA_N_515215', 'cat__ID_OCUPA_N_515225',
#        'cat__ID_OCUPA_N_515305', 'cat__ID_OCUPA_N_515320',
#        'cat__ID_OCUPA_N_5161.1', 'cat__ID_OCUPA_N_516105',
#        'cat__ID_OCUPA_N_516110', 'cat__ID_OCUPA_N_516115',
#        'cat__ID_OCUPA_N_516120', 'cat__ID_OCUPA_N_516125',
#        'cat__ID_OCUPA_N_516205', 'cat__ID_OCUPA_N_516210',
#        'cat__ID_OCUPA_N_516220', 'cat__ID_OCUPA_N_516305',
#        'cat__ID_OCUPA_N_516320', 'cat__ID_OCUPA_N_516330',
#        'cat__ID_OCUPA_N_516335', 'cat__ID_OCUPA_N_516345',
#        'cat__ID_OCUPA_N_516405', 'cat__ID_OCUPA_N_516505',
#        'cat__ID_OCUPA_N_516610', 'cat__ID_OCUPA_N_517105',
#        'cat__ID_OCUPA_N_517110', 'cat__ID_OCUPA_N_517115',
#        'cat__ID_OCUPA_N_517210', 'cat__ID_OCUPA_N_517215',
#        'cat__ID_OCUPA_N_517220', 'cat__ID_OCUPA_N_5173.1',
#        'cat__ID_OCUPA_N_517310', 'cat__ID_OCUPA_N_517315',
#        'cat__ID_OCUPA_N_517330', 'cat__ID_OCUPA_N_517405',
#        'cat__ID_OCUPA_N_517410', 'cat__ID_OCUPA_N_517415',
#        'cat__ID_OCUPA_N_517420', 'cat__ID_OCUPA_N_5191.1',
#        'cat__ID_OCUPA_N_519110', 'cat__ID_OCUPA_N_5192.0',
#        'cat__ID_OCUPA_N_519205', 'cat__ID_OCUPA_N_519210',
#        'cat__ID_OCUPA_N_519315', 'cat__ID_OCUPA_N_519905',
#        'cat__ID_OCUPA_N_519910', 'cat__ID_OCUPA_N_519915',
#        'cat__ID_OCUPA_N_519925', 'cat__ID_OCUPA_N_519935',
#        'cat__ID_OCUPA_N_519940', 'cat__ID_OCUPA_N_520110',
#        'cat__ID_OCUPA_N_5211.1', 'cat__ID_OCUPA_N_521105',
#        'cat__ID_OCUPA_N_521110', 'cat__ID_OCUPA_N_521115',
#        'cat__ID_OCUPA_N_521125', 'cat__ID_OCUPA_N_521130',
#        'cat__ID_OCUPA_N_521135', 'cat__ID_OCUPA_N_523105',
#        'cat__ID_OCUPA_N_523110', 'cat__ID_OCUPA_N_523115',
#        'cat__ID_OCUPA_N_524105', 'cat__ID_OCUPA_N_524205',
#        'cat__ID_OCUPA_N_524210', 'cat__ID_OCUPA_N_524215',
#        'cat__ID_OCUPA_N_524305', 'cat__ID_OCUPA_N_6110.0',
#        'cat__ID_OCUPA_N_611005', 'cat__ID_OCUPA_N_612005',
#        'cat__ID_OCUPA_N_612105', 'cat__ID_OCUPA_N_612125',
#        'cat__ID_OCUPA_N_612315', 'cat__ID_OCUPA_N_612410',
#        'cat__ID_OCUPA_N_612420', 'cat__ID_OCUPA_N_612505',
#        'cat__ID_OCUPA_N_612510', 'cat__ID_OCUPA_N_612605',
#        'cat__ID_OCUPA_N_612620', 'cat__ID_OCUPA_N_612740',
#        'cat__ID_OCUPA_N_613005', 'cat__ID_OCUPA_N_613010',
#        'cat__ID_OCUPA_N_6131.1', 'cat__ID_OCUPA_N_613110',
#        'cat__ID_OCUPA_N_613115', 'cat__ID_OCUPA_N_613130',
#        'cat__ID_OCUPA_N_613215', 'cat__ID_OCUPA_N_613305',
#        'cat__ID_OCUPA_N_613405', 'cat__ID_OCUPA_N_613410',
#        'cat__ID_OCUPA_N_613420', 'cat__ID_OCUPA_N_620110',
#        'cat__ID_OCUPA_N_6210.0', 'cat__ID_OCUPA_N_621005',
#        'cat__ID_OCUPA_N_6220.0', 'cat__ID_OCUPA_N_6220.2',
#        'cat__ID_OCUPA_N_622005', 'cat__ID_OCUPA_N_622010',
#        'cat__ID_OCUPA_N_622015', 'cat__ID_OCUPA_N_622020',
#        'cat__ID_OCUPA_N_622105', 'cat__ID_OCUPA_N_622110',
#        'cat__ID_OCUPA_N_622115', 'cat__ID_OCUPA_N_622120',
#        'cat__ID_OCUPA_N_622310', 'cat__ID_OCUPA_N_622315',
#        'cat__ID_OCUPA_N_622320', 'cat__ID_OCUPA_N_622405',
#        'cat__ID_OCUPA_N_622425', 'cat__ID_OCUPA_N_622505',
#        'cat__ID_OCUPA_N_622515', 'cat__ID_OCUPA_N_6226.1',
#        'cat__ID_OCUPA_N_622610', 'cat__ID_OCUPA_N_622615',
#        'cat__ID_OCUPA_N_622620', 'cat__ID_OCUPA_N_623005',
#        'cat__ID_OCUPA_N_623015', 'cat__ID_OCUPA_N_623020',
#        'cat__ID_OCUPA_N_623105', 'cat__ID_OCUPA_N_623110',
#        'cat__ID_OCUPA_N_623115', 'cat__ID_OCUPA_N_623125',
#        'cat__ID_OCUPA_N_623215', 'cat__ID_OCUPA_N_623305',
#        'cat__ID_OCUPA_N_623310', 'cat__ID_OCUPA_N_630110',
#        'cat__ID_OCUPA_N_631005', 'cat__ID_OCUPA_N_631010',
#        'cat__ID_OCUPA_N_631020', 'cat__ID_OCUPA_N_631105',
#        'cat__ID_OCUPA_N_631205', 'cat__ID_OCUPA_N_631210',
#        'cat__ID_OCUPA_N_631325', 'cat__ID_OCUPA_N_632015',
#        'cat__ID_OCUPA_N_632120', 'cat__ID_OCUPA_N_632125',
#        'cat__ID_OCUPA_N_632205', 'cat__ID_OCUPA_N_632215',
#        'cat__ID_OCUPA_N_632330', 'cat__ID_OCUPA_N_632405',
#        'cat__ID_OCUPA_N_632420', 'cat__ID_OCUPA_N_632505',
#        'cat__ID_OCUPA_N_632525', 'cat__ID_OCUPA_N_641005',
#        'cat__ID_OCUPA_N_641010', 'cat__ID_OCUPA_N_641015',
#        'cat__ID_OCUPA_N_643005', 'cat__ID_OCUPA_N_643025',
#        'cat__ID_OCUPA_N_710205', 'cat__ID_OCUPA_N_711205',
#        'cat__ID_OCUPA_N_711215', 'cat__ID_OCUPA_N_711225',
#        'cat__ID_OCUPA_N_711320', 'cat__ID_OCUPA_N_711325',
#        'cat__ID_OCUPA_N_711405', 'cat__ID_OCUPA_N_712115',
#        'cat__ID_OCUPA_N_712205', 'cat__ID_OCUPA_N_712220',
#        'cat__ID_OCUPA_N_712225', 'cat__ID_OCUPA_N_712230',
#        'cat__ID_OCUPA_N_7151.4', 'cat__ID_OCUPA_N_715105',
#        'cat__ID_OCUPA_N_715115', 'cat__ID_OCUPA_N_715120',
#        'cat__ID_OCUPA_N_715125', 'cat__ID_OCUPA_N_715135',
#        'cat__ID_OCUPA_N_715140', 'cat__ID_OCUPA_N_7152.1',
#        'cat__ID_OCUPA_N_715205', 'cat__ID_OCUPA_N_715210',
#        'cat__ID_OCUPA_N_715225', 'cat__ID_OCUPA_N_715230',
#        'cat__ID_OCUPA_N_715305', 'cat__ID_OCUPA_N_715315',
#        'cat__ID_OCUPA_N_715405', 'cat__ID_OCUPA_N_715410',
#        'cat__ID_OCUPA_N_715505', 'cat__ID_OCUPA_N_715510',
#        'cat__ID_OCUPA_N_715520', 'cat__ID_OCUPA_N_715525',
#        'cat__ID_OCUPA_N_715540', 'cat__ID_OCUPA_N_715545',
#        'cat__ID_OCUPA_N_715615', 'cat__ID_OCUPA_N_715715',
#        'cat__ID_OCUPA_N_715730', 'cat__ID_OCUPA_N_716305',
#        'cat__ID_OCUPA_N_716310', 'cat__ID_OCUPA_N_716405',
#        'cat__ID_OCUPA_N_716525', 'cat__ID_OCUPA_N_716610',
#        'cat__ID_OCUPA_N_7170.2', 'cat__ID_OCUPA_N_717005',
#        'cat__ID_OCUPA_N_717015', 'cat__ID_OCUPA_N_717020',
#        'cat__ID_OCUPA_N_720135', 'cat__ID_OCUPA_N_720155',
#        'cat__ID_OCUPA_N_721105', 'cat__ID_OCUPA_N_721110',
#        'cat__ID_OCUPA_N_721210', 'cat__ID_OCUPA_N_721215',
#        'cat__ID_OCUPA_N_721225', 'cat__ID_OCUPA_N_721310',
#        'cat__ID_OCUPA_N_721325', 'cat__ID_OCUPA_N_721415',
#        'cat__ID_OCUPA_N_721425', 'cat__ID_OCUPA_N_721430',
#        'cat__ID_OCUPA_N_722105', 'cat__ID_OCUPA_N_722205',
#        'cat__ID_OCUPA_N_722215', 'cat__ID_OCUPA_N_722225',
#        'cat__ID_OCUPA_N_722330', 'cat__ID_OCUPA_N_723105',
#        'cat__ID_OCUPA_N_723220', 'cat__ID_OCUPA_N_723225',
#        'cat__ID_OCUPA_N_7233.1', 'cat__ID_OCUPA_N_7233.2',
#        'cat__ID_OCUPA_N_723310', 'cat__ID_OCUPA_N_723315',
#        'cat__ID_OCUPA_N_723320', 'cat__ID_OCUPA_N_723330',
#        'cat__ID_OCUPA_N_724110', 'cat__ID_OCUPA_N_724115',
#        'cat__ID_OCUPA_N_724205', 'cat__ID_OCUPA_N_724220',
#        'cat__ID_OCUPA_N_7243.1', 'cat__ID_OCUPA_N_724315',
#        'cat__ID_OCUPA_N_724325', 'cat__ID_OCUPA_N_7244.4',
#        'cat__ID_OCUPA_N_724405', 'cat__ID_OCUPA_N_724410',
#        'cat__ID_OCUPA_N_724415', 'cat__ID_OCUPA_N_724435',
#        'cat__ID_OCUPA_N_724440', 'cat__ID_OCUPA_N_724505',
#        'cat__ID_OCUPA_N_724510', 'cat__ID_OCUPA_N_7250.1',
#        'cat__ID_OCUPA_N_725005', 'cat__ID_OCUPA_N_725010',
#        'cat__ID_OCUPA_N_725015', 'cat__ID_OCUPA_N_725205',
#        'cat__ID_OCUPA_N_725310', 'cat__ID_OCUPA_N_725505',
#        'cat__ID_OCUPA_N_725705', 'cat__ID_OCUPA_N_7311.3',
#        'cat__ID_OCUPA_N_731125', 'cat__ID_OCUPA_N_731135',
#        'cat__ID_OCUPA_N_731150', 'cat__ID_OCUPA_N_731155',
#        'cat__ID_OCUPA_N_731180', 'cat__ID_OCUPA_N_731320',
#        'cat__ID_OCUPA_N_732105', 'cat__ID_OCUPA_N_740105',
#        'cat__ID_OCUPA_N_751010', 'cat__ID_OCUPA_N_751015',
#        'cat__ID_OCUPA_N_752105', 'cat__ID_OCUPA_N_752305',
#        'cat__ID_OCUPA_N_752430', 'cat__ID_OCUPA_N_760105',
#        'cat__ID_OCUPA_N_761215', 'cat__ID_OCUPA_N_761309',
#        'cat__ID_OCUPA_N_761321', 'cat__ID_OCUPA_N_761327',
#        'cat__ID_OCUPA_N_761345', 'cat__ID_OCUPA_N_762005',
#        'cat__ID_OCUPA_N_762110', 'cat__ID_OCUPA_N_762205',
#        'cat__ID_OCUPA_N_762315', 'cat__ID_OCUPA_N_762345',
#        'cat__ID_OCUPA_N_7630.1', 'cat__ID_OCUPA_N_763010',
#        'cat__ID_OCUPA_N_763015', 'cat__ID_OCUPA_N_763105',
#        'cat__ID_OCUPA_N_763110', 'cat__ID_OCUPA_N_763125',
#        'cat__ID_OCUPA_N_763205', 'cat__ID_OCUPA_N_763210',
#        'cat__ID_OCUPA_N_763215', 'cat__ID_OCUPA_N_763320',
#        'cat__ID_OCUPA_N_764005', 'cat__ID_OCUPA_N_764205',
#        'cat__ID_OCUPA_N_764305', 'cat__ID_OCUPA_N_765110',
#        'cat__ID_OCUPA_N_7652.3', 'cat__ID_OCUPA_N_765235',
#        'cat__ID_OCUPA_N_765315', 'cat__ID_OCUPA_N_765405',
#        'cat__ID_OCUPA_N_766205', 'cat__ID_OCUPA_N_768110',
#        'cat__ID_OCUPA_N_768315', 'cat__ID_OCUPA_N_768320',
#        'cat__ID_OCUPA_N_768625', 'cat__ID_OCUPA_N_771105',
#        'cat__ID_OCUPA_N_771110', 'cat__ID_OCUPA_N_771115',
#        'cat__ID_OCUPA_N_772105', 'cat__ID_OCUPA_N_773105',
#        'cat__ID_OCUPA_N_773120', 'cat__ID_OCUPA_N_773130',
#        'cat__ID_OCUPA_N_773325', 'cat__ID_OCUPA_N_773505',
#        'cat__ID_OCUPA_N_773510', 'cat__ID_OCUPA_N_774105',
#        'cat__ID_OCUPA_N_775105', 'cat__ID_OCUPA_N_776430',
#        'cat__ID_OCUPA_N_777105', 'cat__ID_OCUPA_N_781705',
#        'cat__ID_OCUPA_N_782105', 'cat__ID_OCUPA_N_782110',
#        'cat__ID_OCUPA_N_782125', 'cat__ID_OCUPA_N_782220',
#        'cat__ID_OCUPA_N_7823.0', 'cat__ID_OCUPA_N_7823.1',
#        'cat__ID_OCUPA_N_782305', 'cat__ID_OCUPA_N_782310',
#        'cat__ID_OCUPA_N_782315', 'cat__ID_OCUPA_N_7824.1',
#        'cat__ID_OCUPA_N_782405', 'cat__ID_OCUPA_N_782410',
#        'cat__ID_OCUPA_N_782415', 'cat__ID_OCUPA_N_7825.0',
#        'cat__ID_OCUPA_N_7825.1', 'cat__ID_OCUPA_N_782505',
#        'cat__ID_OCUPA_N_782510', 'cat__ID_OCUPA_N_782515',
#        'cat__ID_OCUPA_N_782610', 'cat__ID_OCUPA_N_782620',
#        'cat__ID_OCUPA_N_782625', 'cat__ID_OCUPA_N_782705',
#        'cat__ID_OCUPA_N_782710', 'cat__ID_OCUPA_N_782805',
#        'cat__ID_OCUPA_N_782815', 'cat__ID_OCUPA_N_782820',
#        'cat__ID_OCUPA_N_783110', 'cat__ID_OCUPA_N_7832.1',
#        'cat__ID_OCUPA_N_7832.2', 'cat__ID_OCUPA_N_783205',
#        'cat__ID_OCUPA_N_783210', 'cat__ID_OCUPA_N_783215',
#        'cat__ID_OCUPA_N_783220', 'cat__ID_OCUPA_N_783225',
#        'cat__ID_OCUPA_N_784105', 'cat__ID_OCUPA_N_784110',
#        'cat__ID_OCUPA_N_784205', 'cat__ID_OCUPA_N_791105',
#        'cat__ID_OCUPA_N_791115', 'cat__ID_OCUPA_N_791130',
#        'cat__ID_OCUPA_N_791140', 'cat__ID_OCUPA_N_811110',
#        'cat__ID_OCUPA_N_811115', 'cat__ID_OCUPA_N_813125',
#        'cat__ID_OCUPA_N_821105', 'cat__ID_OCUPA_N_821305',
#        'cat__ID_OCUPA_N_821405', 'cat__ID_OCUPA_N_821410',
#        'cat__ID_OCUPA_N_821415', 'cat__ID_OCUPA_N_821430',
#        'cat__ID_OCUPA_N_821435', 'cat__ID_OCUPA_N_821445',
#        'cat__ID_OCUPA_N_822110', 'cat__ID_OCUPA_N_822120',
#        'cat__ID_OCUPA_N_823130', 'cat__ID_OCUPA_N_823315',
#        'cat__ID_OCUPA_N_823320', 'cat__ID_OCUPA_N_828110',
#        'cat__ID_OCUPA_N_832115', 'cat__ID_OCUPA_N_840110',
#        'cat__ID_OCUPA_N_841115', 'cat__ID_OCUPA_N_841310',
#        'cat__ID_OCUPA_N_841408', 'cat__ID_OCUPA_N_841416',
#        'cat__ID_OCUPA_N_841456', 'cat__ID_OCUPA_N_841460',
#        'cat__ID_OCUPA_N_841505', 'cat__ID_OCUPA_N_841705',
#        'cat__ID_OCUPA_N_841710', 'cat__ID_OCUPA_N_842110',
#        'cat__ID_OCUPA_N_848210', 'cat__ID_OCUPA_N_8483.0',
#        'cat__ID_OCUPA_N_848305', 'cat__ID_OCUPA_N_848310',
#        'cat__ID_OCUPA_N_848405', 'cat__ID_OCUPA_N_848425',
#        'cat__ID_OCUPA_N_8485.1', 'cat__ID_OCUPA_N_848505',
#        'cat__ID_OCUPA_N_848510', 'cat__ID_OCUPA_N_848515',
#        'cat__ID_OCUPA_N_848520', 'cat__ID_OCUPA_N_848605',
#        'cat__ID_OCUPA_N_860105', 'cat__ID_OCUPA_N_860110',
#        'cat__ID_OCUPA_N_862110', 'cat__ID_OCUPA_N_862120',
#        'cat__ID_OCUPA_N_862140', 'cat__ID_OCUPA_N_862150',
#        'cat__ID_OCUPA_N_862205', 'cat__ID_OCUPA_N_862305',
#        'cat__ID_OCUPA_N_862310', 'cat__ID_OCUPA_N_862515',
#        'cat__ID_OCUPA_N_910105', 'cat__ID_OCUPA_N_911115',
#        'cat__ID_OCUPA_N_911120', 'cat__ID_OCUPA_N_911205',
#        'cat__ID_OCUPA_N_911305', 'cat__ID_OCUPA_N_911320',
#        'cat__ID_OCUPA_N_9131.1', 'cat__ID_OCUPA_N_913110',
#        'cat__ID_OCUPA_N_913115', 'cat__ID_OCUPA_N_914105',
#        'cat__ID_OCUPA_N_914205', 'cat__ID_OCUPA_N_914305',
#        'cat__ID_OCUPA_N_9144.0', 'cat__ID_OCUPA_N_9144.2',
#        'cat__ID_OCUPA_N_914405', 'cat__ID_OCUPA_N_914410',
#        'cat__ID_OCUPA_N_914415', 'cat__ID_OCUPA_N_914420',
#        'cat__ID_OCUPA_N_914425', 'cat__ID_OCUPA_N_915115',
#        'cat__ID_OCUPA_N_915305', 'cat__ID_OCUPA_N_919110',
#        'cat__ID_OCUPA_N_919310', 'cat__ID_OCUPA_N_919315',
#        'cat__ID_OCUPA_N_950205', 'cat__ID_OCUPA_N_951105',
#        'cat__ID_OCUPA_N_951305', 'cat__ID_OCUPA_N_953115',
#        'cat__ID_OCUPA_N_954105', 'cat__ID_OCUPA_N_954120',
#        'cat__ID_OCUPA_N_991105', 'cat__ID_OCUPA_N_991110',
#        'cat__ID_OCUPA_N_991115', 'cat__ID_OCUPA_N_991205',
#        'cat__ID_OCUPA_N_991305', 'cat__ID_OCUPA_N_991310',
#        'cat__ID_OCUPA_N_991315', 'cat__ID_OCUPA_N_991405',
#        'cat__ID_OCUPA_N_991415', 'cat__ID_OCUPA_N_992115',
#        'cat__ID_OCUPA_N_992205', 'cat__ID_OCUPA_N_992210',
#        'cat__ID_OCUPA_N_992220', 'cat__ID_OCUPA_N_992225',
#        'cat__ID_OCUPA_N_998999', 'cat__ID_OCUPA_N_9999.9',
#        'cat__ID_OCUPA_N_999991', 'cat__ID_OCUPA_N_999992',
#        'cat__ID_OCUPA_N_999993', 'cat__ID_OCUPA_N_999994',
#        'cat__ID_OCUPA_N_999995', 'cat__ID_OCUPA_N_Não informado',
#        'cat__ID_OCUPA_N_XXX', 'cat__CON_AREA_Não informado',
#        'cat__CON_AREA_Periurbana', 'cat__CON_AREA_Rural',
#        'cat__CON_AREA_Urbana', 'cat__CON_AMBIEN_Domicílio',
#        'cat__CON_AMBIEN_Lazer', 'cat__CON_AMBIEN_Não informado',
#        'cat__CON_AMBIEN_Outro', 'cat__CON_AMBIEN_Trabalho',
#        'cat__ANT_CB_LAM_Não', 'cat__ANT_CB_LAM_Não informado',
#        'cat__ANT_CB_LAM_Sim', 'cat__ANT_CB_CRI_Não',
#        'cat__ANT_CB_CRI_Não informado', 'cat__ANT_CB_CRI_Sim',
#        'cat__ANT_CB_SIN_Não', 'cat__ANT_CB_SIN_Não informado',
#        'cat__ANT_CB_SIN_Sim', 'cat__ANT_CB_COR_Não',
#        'cat__ANT_CB_COR_Não informado', 'cat__ANT_CB_COR_Sim',
#        'cat__ANT_CB_ROE_Não', 'cat__ANT_CB_ROE_Não informado',
#        'cat__ANT_CB_ROE_Sim', 'cat__ANT_CB_TER_Não',
#        'cat__ANT_CB_TER_Não informado', 'cat__ANT_CB_TER_Sim',
#        'cat__ANT_CB_LIX_Não', 'cat__ANT_CB_LIX_Não informado',
#        'cat__ANT_CB_LIX_Sim', 'cat__ANT_CB_OUT_Não',
#        'cat__ANT_CB_OUT_Não informado', 'cat__ANT_CB_OUT_Sim',
#        'cat__ANT_ANIMAI_Não', 'cat__ANT_ANIMAI_Não informado',
#        'cat__ANT_ANIMAI_Sim', 'cat__ANT_HUMANO_Não',
#        'cat__ANT_HUMANO_Não informado', 'cat__ANT_HUMANO_Sim',
#        'cat__CLI_FEBRE_Não', 'cat__CLI_FEBRE_Não informado',
#        'cat__CLI_FEBRE_Sim', 'cat__CLI_MIALGI_Não',
#        'cat__CLI_MIALGI_Não informado', 'cat__CLI_MIALGI_Sim',
#        'cat__CLI_CEFALE_Não', 'cat__CLI_CEFALE_Não informado',
#        'cat__CLI_CEFALE_Sim', 'cat__CLI_PROST_Não',
#        'cat__CLI_PROST_Não informado', 'cat__CLI_PROST_Sim',
#        'cat__CLI_CONGES_Não', 'cat__CLI_CONGES_Não informado',
#        'cat__CLI_CONGES_Sim', 'cat__CLI_PANTUR_Não',
#        'cat__CLI_PANTUR_Não informado', 'cat__CLI_PANTUR_Sim',
#        'cat__CLI_VOMITO_Não', 'cat__CLI_VOMITO_Não informado',
#        'cat__CLI_VOMITO_Sim', 'cat__CLI_DIARRE_Não',
#        'cat__CLI_DIARRE_Não informado', 'cat__CLI_DIARRE_Sim',
#        'cat__CLI_OUTROS_Não', 'cat__CLI_OUTROS_Não informado',
#        'cat__CLI_OUTROS_Sim', 'cat__SG_UF_AC', 'cat__SG_UF_AL',
#        'cat__SG_UF_AM', 'cat__SG_UF_AP', 'cat__SG_UF_BA', 'cat__SG_UF_CE',
#        'cat__SG_UF_DF', 'cat__SG_UF_ES', 'cat__SG_UF_GO', 'cat__SG_UF_MA',
#        'cat__SG_UF_MG', 'cat__SG_UF_MS', 'cat__SG_UF_MT',
#        'cat__SG_UF_Não informado', 'cat__SG_UF_PA', 'cat__SG_UF_PB',
#        'cat__SG_UF_PE', 'cat__SG_UF_PI', 'cat__SG_UF_PR', 'cat__SG_UF_RJ',
#        'cat__SG_UF_RN', 'cat__SG_UF_RO', 'cat__SG_UF_RR', 'cat__SG_UF_RS',
#        'cat__SG_UF_SC', 'cat__SG_UF_SE', 'cat__SG_UF_SP', 'cat__SG_UF_TO',
#        'cat__nivel_vulnerabilidade_Alta',
#        'cat__nivel_vulnerabilidade_Baixa',
#        'cat__nivel_vulnerabilidade_Moderada', 'cat__estacao_Inverno',
#        'cat__estacao_Outono', 'cat__estacao_Primavera',
#        'cat__estacao_Verão'], dtype=object)

# %%
modelo.predict(X_data.iloc[-10:])
# Out:
# array([2, 2, 2, 2, 2, 0, 2, 0, 2, 0])

# %% [markdown]
# ## Avaliando modelo

# %% [markdown]
# ## Avaliação de desempenho e custo computacional
#
# Nesta seção são avaliados os modelos selecionados ao longo dos folds da validação cruzada externa,
# considerando simultaneamente **qualidade preditiva** e **custo computacional**.
# Essa análise conjunta é fundamental para evitar escolhas baseadas apenas em desempenho,
# desconsiderando viabilidade prática de treinamento e manutenção do modelo.
#
# ### Métricas de desempenho preditivo
#
# O desempenho dos modelos é avaliado por meio de múltiplas métricas,
# permitindo uma análise abrangente do comportamento preditivo:
#
# - **ROC-AUC (OvR, weighted)**: métrica principal de comparação, pois avalia a capacidade de separação entre classes
# em cenários multiclasse e desbalanceados, utilizando probabilidades preditas.
# - **Accuracy**: fornece uma visão global de acerto, mas pode ser influenciada por classes majoritárias.
# - **F1-score (weighted)**: equilibra precisão e recall, sendo mais informativo quando há assimetria entre classes.
# - **Recall (weighted)**: mede a capacidade do modelo em identificar corretamente instâncias relevantes,
# importante em contextos onde falsos negativos possuem maior custo.
# - **Precision (weighted)**: avalia a confiabilidade das predições positivas,
# sendo relevante quando falsos positivos impactam decisões downstream.
#
# A análise por fold permite verificar não apenas o valor médio das métricas,
# mas também sua **estabilidade**, reduzindo o risco de overfitting a uma partição específica dos dados.

# %%
def read_and_consolidate_optuna_logs(
    log_dir: str = "log_opt",
    pattern: str = "trials_log_fold_*.csv",
    fold_col_name: str = "outer_fold",
    keep_only_complete: bool = False,
) -> pd.DataFrame:
    """
    Lê todos os arquivos de log do Optuna (1 por fold) e consolida em um único DataFrame.

    Espera arquivos no formato: trials_log_fold_{k}.csv (gerados por dump_trials).

    Parâmetros
    ----------
    log_dir : str
        Diretório onde os logs estão salvos.
    pattern : str
        Padrão dos arquivos dentro do log_dir.
    fold_col_name : str
        Nome da coluna que será criada para identificar o fold externo.
    keep_only_complete : bool
        Se True, mantém apenas trials com state == 'COMPLETE' (quando existir essa coluna).

    Retorna
    -------
    pd.DataFrame
        DataFrame consolidado com colunas originais + coluna de fold.
    """
    path_pattern = os.path.join(log_dir, pattern)
    files = sorted(glob.glob(path_pattern))

    if not files:
        raise FileNotFoundError(f"Nenhum arquivo encontrado em: {path_pattern}")

    dfs = []
    for fp in files:
        df = pd.read_csv(fp)

        # Extrai fold do nome do arquivo (ex.: trials_log_fold_3.csv -> 3)
        m = re.search(r"fold_(\d+)", os.path.basename(fp))
        fold = int(m.group(1)) if m else None

        df[fold_col_name] = fold
        df["source_file"] = os.path.basename(fp)


        # Normaliza duration se estiver como string do tipo "0 days 00:00:12.345"
        if "duration" in df.columns:
            try:
                df["duration"] = pd.to_timedelta(df["duration"])
                df["duration_seconds"] = df["duration"].dt.total_seconds()
            except Exception:
                pass

        dfs.append(df)

    df_all = pd.concat(dfs, ignore_index=True)

    # Ordenação útil (se existir)
    sort_cols = [c for c in [fold_col_name, "number"] if c in df_all.columns]
    if sort_cols:
        df_all = df_all.sort_values(sort_cols).reset_index(drop=True)

    return df_all


df_metrics = read_and_consolidate_optuna_logs(log_dir="log_opt", keep_only_complete=True)

# 2. Basic overview
print("=== Shape of DataFrame ===")
print(df_metrics.shape)

display(df_metrics)
# Out:
# === Shape of DataFrame ===
# (250, 16)
#      number     value  params_C  params_colsample_bytree  \
# 0         0  0.708630       NaN                 0.523945
# 1         1  0.685263       NaN                      NaN
# 2         2  0.694138  1.077847                      NaN
# 3         3  0.685548       NaN                      NaN
# 4         4  0.664559       NaN                      NaN
# ..      ...       ...       ...                      ...
# 245      45  0.711444       NaN                 0.994821
# 246      46  0.696191  1.082323                      NaN
# 247      47  0.696235  1.045041                      NaN
# 248      48  0.710894       NaN                 0.814089
# 249      49  0.710215       NaN                 0.823173
#
#      params_learning_rate  params_max_depth  params_min_samples_leaf  \
# 0                0.299744               6.0                      NaN
# 1                     NaN               9.0                      2.0
# 2                     NaN               NaN                      NaN
# 3                     NaN               8.0                      1.0
# 4                     NaN               5.0                      5.0
# ..                    ...               ...                      ...
# 245              0.242708               5.0                      NaN
# 246                   NaN               NaN                      NaN
# 247                   NaN               NaN                      NaN
# 248              0.196845               6.0                      NaN
# 249              0.190740               6.0                      NaN
#
#      params_min_samples_split params_model_name  params_n_estimators  \
# 0                         NaN          lightgbm                 28.0
# 1                         5.0     random_forest                 20.0
# 2                         NaN               svm                  NaN
# 3                         4.0     random_forest                 29.0
# 4                         8.0     random_forest                 10.0
# ..                        ...               ...                  ...
# 245                       NaN          lightgbm                 24.0
# 246                       NaN               svm                  NaN
# 247                       NaN               svm                  NaN
# 248                       NaN          lightgbm                 27.0
# 249                       NaN          lightgbm                 27.0
#
#      params_subsample     state               duration  outer_fold  \
# 0            0.713933  COMPLETE 0 days 00:00:38.976509           1
# 1                 NaN  COMPLETE 0 days 00:00:37.889318           1
# 2                 NaN  COMPLETE 0 days 00:01:38.964259           1
# 3                 NaN  COMPLETE 0 days 00:00:23.958383           1
# 4                 NaN  COMPLETE 0 days 00:00:21.584312           1
# ..                ...       ...                    ...         ...
# 245          0.615272  COMPLETE 0 days 00:00:24.501928           5
# 246               NaN  COMPLETE 0 days 00:01:34.905126           5
# 247               NaN  COMPLETE 0 days 00:01:33.424730           5
# 248          0.569318  COMPLETE 0 days 00:00:24.427708           5
# 249          0.570473  COMPLETE 0 days 00:00:17.686608           5
#
#                source_file  duration_seconds
# 0    trials_log_fold_1.csv         38.976509
# 1    trials_log_fold_1.csv         37.889318
# 2    trials_log_fold_1.csv         98.964259
# 3    trials_log_fold_1.csv         23.958383
# 4    trials_log_fold_1.csv         21.584312
# ..                     ...               ...
# 245  trials_log_fold_5.csv         24.501928
# 246  trials_log_fold_5.csv         94.905126
# 247  trials_log_fold_5.csv         93.424730
# 248  trials_log_fold_5.csv         24.427708
# 249  trials_log_fold_5.csv         17.686608
#
# [250 rows x 16 columns]

# %%
# Total de trials por modelo
total_trials = (df_metrics.groupby("params_model_name").size().reset_index(name="total_trials"))

plt.figure(figsize=(8, 6))
sns.barplot(data=total_trials,x="params_model_name",y="total_trials",)
plt.title("Total de tentativas por modelo")
plt.xlabel("Modelo")
plt.ylabel("Tentativas")
plt.tight_layout()
plt.show()

# %%
# Gráfico das tentativas de modelos completas e abortadas
counts_state = df_metrics.groupby(["params_model_name", "state"]).size().reset_index(name="count")

plt.figure(figsize=(8, 6))
sns.barplot(data=counts_state,x="params_model_name",y="count",hue="state",)
plt.title("Resultado das tentativas entre Pruned e Complete")
plt.xlabel("Modelo")
plt.ylabel("Número de tentativas")
plt.tight_layout()
plt.show()

# %%
# Distribuição de performance (value) por modelo
plt.figure(figsize=(8, 6))
sns.boxplot(data=df_metrics, x="params_model_name", y="value")
plt.title("Desempenho por modelo")
plt.xlabel("Modelo")
plt.ylabel("Área por baixo da curva ROC (AUC)")
plt.tight_layout()
plt.show()

# %%
# Duração média de treino por modelo
df_metrics["duration_sec"] = pd.to_timedelta(df_metrics["duration"]).dt.total_seconds()
mean_duration = df_metrics.groupby("params_model_name")["duration_sec"].mean().reset_index()

# Distribuição do tempo de processamento por modelo

plt.figure(figsize=(8, 6))
sns.boxplot(data=df_metrics, x="params_model_name", y="duration_sec")
plt.title("Média do tempo de treinamento por modelo")
plt.xlabel("Modelo")
plt.ylabel("Segundos")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Treinamento do modelo final

# %%
df_hyper =pd.DataFrame(df_results['hyperparameters'].to_list())
df_hyper
# Out:
#   model_name  n_estimators  learning_rate  max_depth  subsample  \
# 0   lightgbm            27       0.177683          9   0.630724
# 1   lightgbm            25       0.219184          8   0.858717
# 2    xgboost            30       0.216889          6   0.661351
# 3   lightgbm            30       0.246701          8   0.983649
# 4   lightgbm            27       0.256044          6   0.706602
#
#    colsample_bytree
# 0          0.889726
# 1          0.821533
# 2          0.741326
# 3          0.715560
# 4          0.960362

# %%
final_params=df_hyper.iloc[:,1:].median().to_dict()
final_params
# Out:
# {'n_estimators': 27.0,
#  'learning_rate': 0.2191838526364053,
#  'max_depth': 8.0,
#  'subsample': 0.7066020029053007,
#  'colsample_bytree': 0.8215326060039783}

# %%
def cast_params(params: dict) -> dict:
    p = dict(params)  # cópia

    # chaves que devem ser int no LightGBM
    int_keys = {
        "n_estimators", "num_iterations",
        "max_depth", "num_leaves",
        "min_child_samples", "min_data_in_leaf",
        "max_bin",
        "bagging_freq",
    }

    for k in list(p.keys()):
        if k in int_keys and p[k] is not None and not (isinstance(p[k], bool)):
            p[k] = int(round(float(p[k])))

    # max_depth: LightGBM aceita -1 como "sem limite"
    if "max_depth" in p and p["max_depth"] is not None:
        p["max_depth"] = int(p["max_depth"])

    return p

final_params = cast_params(final_params)
final_params
# Out:
# {'n_estimators': 27,
#  'learning_rate': 0.2191838526364053,
#  'max_depth': 8,
#  'subsample': 0.7066020029053007,
#  'colsample_bytree': 0.8215326060039783}

# %%
# Dicionário base para reconstrução
models = {
    'RandomForest': RandomForestClassifier(random_state=42),
    'XGBoost': xgb.XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42),
    'LightGBM': lgb.LGBMClassifier(random_state=42),
    'SVM': CalibratedClassifierCV(LinearSVC( random_state=42))
}

# %%
# Reconstruir modelo
final_model = models['LightGBM']
final_model.set_params(**final_params)

cat_cols, num_cols = get_feature_types(X_data)

final_pipeline = build_pipeline(final_model, cat_cols, num_cols)

# %% [markdown]
# ### Avaliando modelo final

# %% [markdown]
# ## Interpretabilidade: importância de variáveis após pré-processamento (OHE) e mapeamento para colunas originais
#
# Modelos treinados sobre pipelines com `ColumnTransformer` e `OneHotEncoder` operam em um espaço de features
# expandido (múltiplas colunas por variável categórica). Para manter interpretabilidade, esta seção:
# 1) recupera os nomes finais das features no espaço transformado,
# 2) extrai uma medida de importância/coeficiente do modelo treinado,
# 3) mapeia as features transformadas de volta para as variáveis originais,
# 4) consolida a importância no nível da coluna original.
#
# Isso permite reportar resultados em termos das variáveis do dataset original, facilitando comunicação e análise.

# %% [markdown]
# ### Extração de nomes das features pós-`ColumnTransformer`
#
# A função `get_feature_names` reconstrói o vetor de nomes de features gerado após o pré-processamento,
# incluindo:
# - variáveis numéricas (após imputação/escala),
# - variáveis categóricas expandidas via One-Hot Encoding,
# - e, opcionalmente, colunas passadas via `remainder='passthrough'`.
#
# Essa etapa é necessária porque, após o `fit_transform`, a matriz final perde o vínculo direto com o nome
# das colunas originais, e a identificação correta das features é condição para qualquer análise de importância.

# %%
# 1. FUNÇÃO PARA EXTRAIR NOMES DAS FEATURES PÓS-OHE
def get_feature_names(column_transformer):
    """
    Extrai nomes finais das features após ColumnTransformer,
    incluindo OneHotEncoder e transformações numéricas.
    """
    output_features = []

    for name, transformer, features in column_transformer.transformers_:

        # Caso 'remainder=passthrough'
        if name == "remainder":
            output_features.extend(features)
            continue

        # Transformers com get_feature_names_out() (OneHotEncoder, etc)
        if hasattr(transformer, "get_feature_names_out"):
            try:
                names = transformer.get_feature_names_out(features)
            except:
                names = transformer.get_feature_names_out()
            output_features.extend(names)

        # Caso não possua o método
        else:
            output_features.extend(features)

    return output_features

# %% [markdown]
# ### Mapeamento para variáveis originais via fuzzy matching
#
# Após o One-Hot Encoding, uma mesma variável categórica pode gerar dezenas de colunas com nomes derivados.
# Para consolidar resultados no nível da variável original, é aplicado *fuzzy matching* entre o nome da feature
# pós-OHE e a lista de variáveis originais de interesse (`features_explicativas`).
#
# O objetivo do fuzzy matching é lidar com diferenças de sufixos/prefixos criados pelo encoding e manter
# um vínculo prático entre “feature transformada” e “coluna original”. O parâmetro `threshold`
# controla o quão estrita é a correspondência:
# - valores maiores reduzem falsos positivos (match errado),
# - valores menores aumentam cobertura, mas elevam risco de mapeamentos incorretos.
#
# Após o matching, apenas features com correspondência válida são mantidas para agregação.

# %%
def fuzzy_match_original(feature_name, triage_features, threshold=70):
    """
    Realiza fuzzy matching buscando qual variável ORIGINAL
    está mais relacionada com o nome da feature pós-OHE.
    """
    best_match, score, _ = process.extractOne(
        feature_name,
        triage_features,
        scorer=fuzz.partial_ratio
    )
    return best_match if score >= threshold else None

# %% [markdown]
# ## Validação cruzada externa: avaliação e interpretabilidade por fold
#
# Nesta etapa, aplica-se uma `StratifiedKFold` externa para avaliar o desempenho do pipeline e também
# inspecionar a importância de variáveis por fold. A estratificação preserva a proporção das classes,
# reduzindo instabilidade em bases desbalanceadas.
#
# Para cada fold:
# - o pipeline final é treinado no conjunto de treino,
# - a importância das features é extraída do modelo treinado,
# - as importâncias são consolidadas no nível da variável original e visualizadas,
# - e o desempenho é medido no conjunto de teste com métricas e curvas.

# %%
# =========================
# Parâmetros
# =========================
n_splits = 4
top_k = 20        # top features por fold (para tabelas)
top_overall = 30  # top features gerais (para tabela final)

outer_cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

# =========================
# Coletores (tabelas)
# =========================
fold_metrics = []          # 1 linha por fold com métricas + conf matrix flatten
fold_top_features = []     # top_k features por fold (já agrupadas em original_var)
all_features_long = []     # todas features (agrupadas) por fold -> resumo geral

fold = 1
for train_idx, test_idx in outer_cv.split(X_data, y_data):

    print(f"\n==============================")
    print(f"  Fold Externo {fold}/{n_splits}")
    print(f"==============================")

    X_train, X_test = X_data.iloc[train_idx], X_data.iloc[test_idx]
    y_train, y_test = y_data.iloc[train_idx], y_data.iloc[test_idx]

    # =========================
    # 1) Fit do pipeline no fold
    # =========================
    final_pipeline.fit(X_train, y_train)

    # =========================
    # 2) Importâncias
    # =========================
    model = final_pipeline.named_steps["model"]

    if hasattr(model, "feature_importances_"):
        importances = model.feature_importances_
    elif hasattr(model, "coef_"):
        coef = model.coef_
        # binary: (n_features,) ou (1, n_features)
        # multiclass: (n_classes, n_features) -> agregamos por média do abs
        importances = coef.ravel() if coef.ndim == 1 else np.mean(np.abs(coef), axis=0)
    else:
        raise ValueError("Este modelo não possui atributo de importância (feature_importances_ ou coef_).")

    # =========================
    # 3) Nomes pós-preprocessamento
    # =========================
    preproc = final_pipeline.named_steps["preprocessor"]
    feature_names = get_feature_names(preproc)

    if len(feature_names) != len(importances):
        raise ValueError(
            f"Mismatch: {len(feature_names)} nomes de features vs {len(importances)} importâncias. "
            "Cheque get_feature_names() / preprocessor."
        )

    df_imp = pd.DataFrame({"feature": feature_names, "importance": importances})

    # =========================
    # 4) Fuzzy match para variáveis originais e agregação
    # =========================
    df_imp["original_var"] = df_imp["feature"].apply(lambda x: fuzzy_match_original(x, features_explicativas))
    df_imp = df_imp[df_imp["original_var"].notna()].copy()

    df_grouped = (
        df_imp.groupby("original_var", as_index=False)["importance"]
              .sum()
              .sort_values("importance", ascending=False)
              .rename(columns={"original_var": "feature"})
              .reset_index(drop=True)
    )

    # =========================
    # 4.1) Plot: Feature importance (por fold)
    # =========================
    plt.figure(figsize=(6, 14))
    plt.barh(df_grouped["feature"][::-1], df_grouped["importance"][::-1])
    plt.xlabel("Importância (agregada por variável original)")
    plt.title(f"Feature importance – {type(model).__name__} – Fold {fold}")
    plt.tight_layout()
    plt.show()

    # guarda top features do fold (top_k)
    df_top = df_grouped.head(top_k).copy()
    df_top["fold"] = fold
    df_top["rank_in_fold"] = np.arange(1, len(df_top) + 1)
    fold_top_features.append(df_top)

    # guarda TODAS as features agregadas do fold (para resumo geral)
    df_grouped_long = df_grouped.copy()
    df_grouped_long["fold"] = fold
    all_features_long.append(df_grouped_long)

    # =========================
    # 5) Predições / probabilidades
    # =========================
    y_pred = final_pipeline.predict(X_test)

    y_proba = None
    if hasattr(final_pipeline, "predict_proba"):
        try:
            y_proba =  final_pipeline.predict_proba(X_test)
        except Exception:
            y_proba = None

    # =========================
    # 6) Matriz de confusão (plot)
    # =========================
    cm = confusion_matrix(y_test, y_pred)

    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.title(f"Matriz de Confusão – Fold {fold}")
    plt.xlabel("Predito")
    plt.ylabel("Real")
    plt.tight_layout()
    plt.show()

    # =========================
    # 7) Métricas (plot + tabela)
    # =========================
    metrics_dict_plot = {
        "Accuracy": accuracy_score(y_test, y_pred),
        "Precision": precision_score(y_test, y_pred, average='weighted', zero_division=0),
        "Recall": recall_score(y_test, y_pred, average='weighted', zero_division=0),
        "F1 Score": f1_score(y_test, y_pred, average='weighted', zero_division=0),
        "AUC":  roc_auc_score(y_test, y_proba,multi_class='ovr', average='weighted') if y_proba is not None else np.nan
    }

    plt.figure(figsize=(8, 5))
    sns.barplot(x=list(metrics_dict_plot.keys()), y=list(metrics_dict_plot.values()), palette="Set2")
    plt.ylim(0, 1.05)
    plt.title(f"Métricas de Classificação – Fold {fold}")
    for i, v in enumerate(metrics_dict_plot.values()):
        if np.isfinite(v):
            plt.text(i, v + 0.02, f"{v:.2f}", ha='center')
        else:
            plt.text(i, 0.02, "NA", ha='center')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    # salva métricas estruturadas (para df_metrics)
    fold_metrics.append({
        "fold": fold,
        "n_train": len(train_idx),
        "n_test": len(test_idx),
        "accuracy": metrics_dict_plot["Accuracy"],
        "precision": metrics_dict_plot["Precision"],
        "recall": metrics_dict_plot["Recall"],
        "f1": metrics_dict_plot["F1 Score"],
        "auc": metrics_dict_plot["AUC"],
        "tn": cm[0, 0], "fp": cm[0, 1], "fn": cm[1, 0], "tp": cm[1, 1],
        "model_name": type(model).__name__,
    })


    # Curva ROC (One-vs-Rest for each class)
    if y_proba is not None:
        # Convert y_test to one-hot encoding for multi-class ROC curve plotting
        from sklearn.preprocessing import LabelBinarizer
        lb = LabelBinarizer()
        y_test_bin = lb.fit_transform(y_test)
        n_classes = y_test_bin.shape[1]

        plt.figure(figsize=(8, 6))
        for i in range(n_classes):
            fpr, tpr, _ = roc_curve(y_test_bin[:, i], y_proba[:, i])
            roc_auc = auc(fpr, tpr)
            plt.plot(fpr, tpr, label=f'ROC curve (class {i}) (AUC = {roc_auc:.2f})')

        plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Random Classifier')
        plt.xlabel("False Positive Rate")
        plt.ylabel("True Positive Rate")
        plt.title("Multi-class ROC Curve (One-vs-Rest)")
        plt.legend(loc='lower right')
        plt.grid(True)
        plt.show()

    # Curva Precision-Recall (One-vs-Rest for each class)
    if y_proba is not None:
        # y_test_bin from above can be reused
        plt.figure(figsize=(8, 6))
        for i in range(n_classes):
            precision, recall, _ = precision_recall_curve(y_test_bin[:, i], y_proba[:, i])
            auprc_trap = auc(recall, precision)
            plt.plot(recall, precision, label=f'PR curve (class {i}) (AUPRC = {auprc_trap:.2f})')

        plt.xlabel("Recall")
        plt.ylabel("Precision")
        plt.title("Multi-class Precision-Recall Curve (One-vs-Rest)")
        plt.legend(loc='lower left')
        plt.grid(True)
        plt.show()

    fold += 1


# =========================
# 10) DF: métricas por fold
# =========================
df_metrics = pd.DataFrame(fold_metrics).sort_values("fold").reset_index(drop=True)

# resumo (média e desvio padrão) das métricas
metric_cols = ["accuracy", "precision", "recall", "f1", "auc"]
df_metrics_summary = (
    df_metrics[metric_cols]
    .agg(["mean", "std"])
    .T
    .rename(columns={"mean": "mean", "std": "std"})
    .reset_index()
    .rename(columns={"index": "metric"})
)

# =========================
# 11) DF: top features por fold
# =========================
df_top_by_fold = pd.concat(fold_top_features, ignore_index=True)

# =========================
# 12) DF: resumo geral das features (média/std + rank)
# =========================
df_all_features_long = pd.concat(all_features_long, ignore_index=True)

df_feature_summary = (
    df_all_features_long
    .groupby("feature", as_index=False)
    .agg(
        mean_importance=("importance", "mean"),
        std_importance=("importance", "std"),
        folds_present=("fold", "nunique"),
    )
)

# ranking médio por fold (quanto menor, mais importante)
df_ranks = (
    df_all_features_long
    .assign(rank_in_fold=lambda d: d.groupby("fold")["importance"].rank(ascending=False, method="average"))
)

df_rank_summary = (
    df_ranks.groupby("feature", as_index=False)
            .agg(mean_rank=("rank_in_fold", "mean"), std_rank=("rank_in_fold", "std"))
)

df_feature_summary = (
    df_feature_summary.merge(df_rank_summary, on="feature", how="left")
                      .sort_values(["mean_importance", "folds_present"], ascending=[False, False])
                      .reset_index(drop=True)
)

df_top_features_overall = df_feature_summary.head(top_overall).copy()

# =========================
# 13) OUTPUT final (tabelas)
# =========================
print("\n\n==============================")
print("MÉTRICAS POR FOLD")
print("==============================")
display(df_metrics)

print("\n\n==============================")
print("RESUMO GERAL DAS MÉTRICAS (média e desvio padrão)")
print("==============================")
display(df_metrics_summary)

print("\n\n==============================")
print(f"TOP {top_k} FEATURES POR FOLD (agregadas em variável original)")
print("==============================")
display(df_top_by_fold.sort_values(["fold", "rank_in_fold"]))

print("\n\n==============================")
print(f"TOP {top_overall} FEATURES GERAIS (média/std das importâncias + estabilidade via rank)")
print("==============================")
display(df_top_features_overall)

# Se quiser salvar:
# df_metrics.to_csv("cv_metrics_by_fold.csv", index=False)
# df_metrics_summary.to_csv("cv_metrics_summary.csv", index=False)
# df_top_by_fold.to_csv("cv_top_features_by_fold.csv", index=False)
# df_feature_summary.to_csv("cv_feature_importance_summary.csv", index=False)
# Out:
# ==============================
#   Fold Externo 1/4
# ==============================
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.036600 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 20686
# [LightGBM] [Info] Number of data points in the train set: 27444, number of used features: 217
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# ==============================
#   Fold Externo 2/4
# ==============================
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.035977 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 20841
# [LightGBM] [Info] Number of data points in the train set: 27444, number of used features: 224
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ==============================
#   Fold Externo 3/4
# ==============================
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.038367 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 21032
# [LightGBM] [Info] Number of data points in the train set: 27447, number of used features: 219
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ==============================
#   Fold Externo 4/4
# ==============================
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.035790 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 21631
# [LightGBM] [Info] Number of data points in the train set: 27447, number of used features: 216
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ==============================
# MÉTRICAS POR FOLD
# ==============================
#    fold  n_train  n_test  accuracy  precision    recall        f1       auc  \
# 0     1    23743    7915  0.540872   0.506398  0.540872  0.496414  0.702212
# 1     2    23743    7915  0.547063   0.514040  0.547063  0.508565  0.712780
# 2     3    23744    7914  0.534496   0.508813  0.534496  0.502618  0.699242
# 3     4    23744    7914  0.528178   0.508016  0.528178  0.496829  0.688913
#
#      tn   fp   fn   tp      model_name
# 0  2194   98  802  158  LGBMClassifier
# 1  1955  169  593  192  LGBMClassifier
# 2  1895  170  576  237  LGBMClassifier
# 3  1962  144  676  251  LGBMClassifier
# ==============================
# RESUMO GERAL DAS MÉTRICAS (média e desvio padrão)
# ==============================
#       metric      mean       std
# 0   accuracy  0.537652  0.008137
# 1  precision  0.509317  0.003306
# 2     recall  0.537652  0.008137
# 3         f1  0.501106  0.005722
# 4        auc  0.700787  0.009819
# ==============================
# TOP 20 FEATURES POR FOLD (agregadas em variável original)
# ==============================
#        feature  importance  fold  rank_in_fold
# 0        SG_UF         407     1             1
# 1   NU_IDADE_N         226     1             2
# 2   ID_OCUPA_N         190     1             3
# 3   CS_ESCOL_N         109     1             4
# 4   CLI_OUTROS          98     1             5
# ..         ...         ...   ...           ...
# 75  ANT_CB_LAM          55     4            16
# 76  ANT_CB_SIN          48     4            17
# 77     CS_RACA          47     4            18
# 78  CLI_MIALGI          43     4            19
# 79  ANT_CB_ROE          42     4            20
#
# [80 rows x 4 columns]
# ==============================
# TOP 30 FEATURES GERAIS (média/std das importâncias + estabilidade via rank)
# ==============================
#          feature  mean_importance  std_importance  folds_present  mean_rank  \
# 0          SG_UF           414.25       14.863266              4      1.000
# 1     NU_IDADE_N           218.75       14.268263              4      2.000
# 2     ID_OCUPA_N           174.50       21.439838              4      3.000
# 3     CS_ESCOL_N           108.50        6.952218              4      4.125
# 4     CLI_OUTROS            97.00        6.976150              4      6.000
# 5     CON_AMBIEN            90.25        9.810708              4      6.250
# 6     CLI_CEFALE            83.75        6.751543              4      8.000
# 7      CLI_PROST            83.25       10.372239              4      7.875
# 8     CLI_CONGES            78.75        9.105859              4      9.500
# 9   mes_sintomas            75.50       11.590226              4      9.875
# 10      CON_AREA            68.75       15.628500              4     11.125
# 11    CLI_VOMITO            68.25        6.075909              4     11.625
# 12    CLI_PANTUR            68.00        5.773503              4     11.875
# 13    CLI_DIARRE            60.00        8.831761              4     14.625
# 14    ANT_CB_SIN            53.00        5.597619              4     15.625
# 15    ANT_CB_LAM            51.75        6.601767              4     17.250
# 16    ANT_CB_LIX            51.50        5.259911              4     17.250
# 17       CS_RACA            49.75        9.464847              4     19.000
# 18       estacao            48.50       12.369317              4     18.750
# 19    ANT_CB_ROE            45.25        3.403430              4     19.000
# 20    CLI_MIALGI            43.25        1.892969              4     20.375
# 21       CS_SEXO            38.50        2.380476              4     23.750
# 22     CLI_FEBRE            38.00        2.309401              4     24.125
# 23    ANT_HUMANO            37.75        1.707825              4     24.250
# 24    ANT_CB_CRI            36.25        3.774917              4     25.000
# 25    ANT_CB_COR            35.75        6.075909              4     25.000
# 26    CS_GESTANT            35.25        7.762087              4     25.000
# 27    ANT_CB_TER            33.50        5.259911              4     26.250
# 28    ANT_ANIMAI            27.00        8.831761              4     28.750
# 29    ANT_CB_OUT            24.00        6.976150              4     29.875
#
#     std_rank
# 0   0.000000
# 1   0.000000
# 2   0.000000
# 3   0.250000
# 4   1.414214
# 5   1.936492
# 6   1.414214
# 7   2.954516
# 8   1.290994
# 9   2.174665
# 10  3.275541
# 11  2.056494
# 12  1.796988
# 13  3.544362
# 14  1.701715
# 15  2.020726
# 16  1.707825
# 17  5.033223
# 18  5.605057
# 19  2.160247
# 20  1.108678
# 21  2.327373
# 22  2.657536
# 23  2.661453
# 24  2.483277
# 25  2.738613
# 26  3.674235
# 27  1.936492
# 28  2.958040
# 29  2.322893

# %% [markdown]
# ## Salvando checkpoints no Drive

# %% [markdown]
# ### Salvar métricas

# %%
src = "/content/checkpoints_best_models"
dst = f"/content/drive/MyDrive/ITA/TCC/Resultados/{experimento}/checkpoints_best_models"

os.makedirs(os.path.dirname(dst), exist_ok=True)
shutil.copytree(src, dst, dirs_exist_ok=True)
# Out:
# '/content/drive/MyDrive/ITA/TCC/Resultados/severidade_comFeatureSelection/checkpoints_best_models'

# %% [markdown]
# ### Salvar modelos

# %%
src = "/content/log_opt"
dst = f"/content/drive/MyDrive/ITA/TCC/Resultados/{experimento}/log_opt"

os.makedirs(os.path.dirname(dst), exist_ok=True)
shutil.copytree(src, dst, dirs_exist_ok=True)
# Out:
# '/content/drive/MyDrive/ITA/TCC/Resultados/severidade_comFeatureSelection/log_opt'
