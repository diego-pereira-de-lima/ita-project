# %%
# !pip uninstall xgboost -y
# Out:
# Found existing installation: xgboost 3.1.1
# Uninstalling xgboost-3.1.1:
#   Successfully uninstalled xgboost-3.1.1

# %%
# !pip install optuna xgboost==3.1.1 lightgbm fastparquet imbalanced-learn torch rapidfuzz
# Out:
# Requirement already satisfied: optuna in /usr/local/lib/python3.12/dist-packages (4.7.0)
# Collecting xgboost==3.1.1
#   Using cached xgboost-3.1.1-py3-none-manylinux_2_28_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.12/dist-packages (4.6.0)
# Requirement already satisfied: fastparquet in /usr/local/lib/python3.12/dist-packages (2025.12.0)
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.12/dist-packages (0.14.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.9.0+cpu)
# Requirement already satisfied: rapidfuzz in /usr/local/lib/python3.12/dist-packages (3.14.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from xgboost==3.1.1) (2.0.2)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.12/dist-packages (from xgboost==3.1.1) (2.29.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from xgboost==3.1.1) (1.16.3)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.18.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.12/dist-packages (from optuna) (6.10.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.46)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: pandas>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from fastparquet) (2.2.2)
# Requirement already satisfied: cramjam>=2.3 in /usr/local/lib/python3.12/dist-packages (from fastparquet) (2.11.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from fastparquet) (2025.3.0)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (1.6.1)
# Requirement already satisfied: sklearn-compat<0.2,>=0.1.5 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (0.1.5)
# Requirement already satisfied: joblib<2,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->fastparquet) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->fastparquet) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->fastparquet) (2025.3)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->fastparquet) (1.17.0)
# Using cached xgboost-3.1.1-py3-none-manylinux_2_28_x86_64.whl (115.9 MB)
# Installing collected packages: xgboost
# Successfully installed xgboost-3.1.1

# %%
import numpy as np
import pandas as pd
import os, joblib,time


from sklearn.model_selection import StratifiedKFold, cross_val_score,train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.calibration import CalibratedClassifierCV

import optuna
from optuna.pruners import SuccessiveHalvingPruner
from optuna.exceptions import TrialPruned

#from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.impute import SimpleImputer
from functools import partial


#Feature selection
from __future__ import annotations

from sklearn.model_selection import KFold, StratifiedKFold, cross_val_score
from sklearn.feature_selection import VarianceThreshold, SelectKBest
from sklearn.feature_selection import mutual_info_classif, mutual_info_regression
from sklearn.feature_selection import f_classif, f_regression

from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.multiclass import OneVsRestClassifier, OneVsOneClassifier

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler




from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, confusion_matrix, matthews_corrcoef,
    cohen_kappa_score, balanced_accuracy_score,
    classification_report, brier_score_loss, log_loss,
    confusion_matrix, ConfusionMatrixDisplay,
    precision_recall_curve, RocCurveDisplay,roc_curve,auc
)

from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE

import matplotlib.pyplot as plt
import seaborn as sns

import subprocess
import xgboost as xgb
import lightgbm as lgb
import torch

import re
from rapidfuzz import fuzz, process

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Carregando base de dados

# %% [markdown]
# Carregamento do conjunto de dados processado a partir de um arquivo no formato Parquet.
# Esse formato colunar é otimizado para leitura eficiente, reduz uso de memória e preserva os tipos de dados,
# sendo adequado para pipelines analíticos e etapas posteriores de modelagem.

# %%
df =pd.read_parquet('df_hepat_processed_v1.parquet',engine='fastparquet')

# %% [markdown]
# ### Selecionar variáveis relevantes para triagem

# %% [markdown]
# Definição das variáveis explicativas e da variável alvo utilizadas no modelo.
# As features incluem características sociodemográficas, condições ambientais, antecedentes clínicos e sintomas,
# além de variáveis derivadas de vulnerabilidade social e sazonalidade, enquanto a variável alvo representa a severidade do caso.

# %%
triage_features = [
    'NU_IDADE_N','CS_SEXO','CS_GESTANT','CS_RACA','CS_ESCOL_N',
    'ID_OCUPA_N','CON_AREA','CON_AMBIEN',
    'ANT_CB_LAM','ANT_CB_CRI','ANT_CB_SIN','ANT_CB_COR','ANT_CB_ROE',
    'ANT_CB_TER','ANT_CB_LIX','ANT_CB_OUT','ANT_ANIMAI','ANT_HUMANO',
    'CLI_FEBRE','CLI_MIALGI','CLI_CEFALE','CLI_PROST','CLI_CONGES',
    'CLI_PANTUR','CLI_VOMITO','CLI_DIARRE','CLI_ICTERI','CLI_RENAL',
    'CLI_RESPIR','CLI_CARDIA','CLI_HEMOPU','CLI_HEMORR','CLI_MENING',
    'CLI_OUTROS','SG_UF', 'baixa_escolaridade','raca_vulneravel','faixa_vulneravel',
    'vulnerabilidade_social', 'nivel_vulnerabilidade','mes_sintomas','estacao', 'periodo_chuvoso'
]



target_col = 'CLASSI_FIN'  # rótulo: confirmado vs descartado

if target_col == 'CLASSI_FIN':
    df = df[df['CLASSI_FIN'].isin(['Confirmado', 'Descartado'])].copy()

    # Criar variável alvo binária
    df['alvo'] = df['CLASSI_FIN'].map({
        'Confirmado': 1,
        'Descartado': 0
    })

# %% [markdown]
# ### Amostragem estratificada dos dados
#
# Nesta etapa é realizada uma amostragem estratificada da base de dados,
# preservando a proporção das classes da variável alvo.
# O procedimento consiste em aplicar uma amostragem aleatória dentro de cada classe,
# extraindo uma fração representativa do conjunto original.
#
# Em seguida, a base amostrada é separada em variáveis explicativas (X)
# e variável resposta (y), que serão utilizadas nas etapas subsequentes de modelagem.
#
# Essa abordagem reduz o volume de dados processados,
# mantendo a representatividade estatística das classes e garantindo reprodutibilidade
# por meio do uso de uma semente aleatória fixa.

# %%
## Amostragem estratificada
amostragem = df.groupby("alvo").sample(frac=0.05, random_state=42).copy()

X_data=amostragem[triage_features]
y_data = amostragem['alvo']

# %% [markdown]
# ## Pipeline de seleção de variáveis com suporte a tarefas (binária, multiclasse e regressão)
#
# Esta seção implementa um pipeline completo de *feature selection* que funciona para problemas de
# classificação (binária e multiclasse) e regressão. O fluxo combina pré-processamento (numérico e categórico),
# múltiplos métodos de seleção em camadas (filter → embedded → wrapper) e, ao final, reconcilia as variáveis
# selecionadas no espaço transformado com seus nomes originais no dataset.
#
# A motivação é obter um conjunto final de variáveis com bom poder preditivo e maior estabilidade,
# evitando depender de um único critério (ex.: apenas mutual information ou apenas importância de árvore),
# e garantindo rastreabilidade entre “features após encoding” e “colunas originais”.

# %% [markdown]
# ### Detecção automática do tipo de tarefa e escolha de validação cruzada
#
# Antes da seleção, o pipeline identifica se o problema é de classificação ou regressão a partir do parâmetro `task`.
# Com isso, define automaticamente o esquema de validação cruzada:
# - **StratifiedKFold** para classificação, preservando a proporção de classes em cada fold;
# - **KFold** para regressão, adequado quando não há estratificação por rótulo.
#
# Além disso, é definido um *scoring* padrão coerente com cada cenário (ex.: AUC-ROC para binário,
# F1-macro para multiclasse, e RMSE negativo para regressão), reduzindo risco de escolhas inconsistentes
# na avaliação do wrapper.

# %%
# -------------------------
# Helpers: task detection
# -------------------------
def _is_classification(task: str) -> bool:
    return task.lower() in ["binary", "multiclass", "classification", "clf"]

def _is_multiclass(task: str) -> bool:
    return task.lower() == "multiclass"

def _make_cv(y, task: str, n_splits: int = 5, random_state: int = 42):
    if _is_classification(task):
        return StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=random_state)
    return KFold(n_splits=n_splits, shuffle=True, random_state=random_state)

def _default_scoring(task: str) -> str:
    t = task.lower()
    if t == "binary":
        return "roc_auc"
    if t == "multiclass":
        return "f1_macro"
    if t in ["regression", "reg"]:
        return "neg_root_mean_squared_error"
    # fallback
    return "f1_macro" if _is_classification(task) else "neg_root_mean_squared_error"

def _selectkbest_score_func(task: str):
    return mutual_info_classif if _is_classification(task) else mutual_info_regression

def _anova_score_func(task: str):
    return f_classif if _is_classification(task) else f_regression

# %% [markdown]
# ### Identificação e pré-processamento de variáveis numéricas e categóricas
#
# Nesta etapa, as colunas são separadas por tipo:
# - categóricas (object/category/bool),
# - numéricas (np.number).
#
# Em seguida, aplica-se um pré-processamento unificado via `ColumnTransformer`:
# - **StandardScaler** para variáveis numéricas (normalização para modelos lineares e métricas);
# - **OneHotEncoder** para variáveis categóricas, com `handle_unknown="ignore"` para robustez.
#
# O resultado é uma matriz de features totalmente numérica, adequada para métodos de seleção e modelos do scikit-learn.

# %%
# ------------------------------------------------
# Preprocess: detect column types (customize here)
# ------------------------------------------------
def get_feature_types(X: pd.DataFrame):
    cat_cols = X.select_dtypes(include=["object", "category", "bool"]).columns.tolist()
    num_cols = X.select_dtypes(include=[np.number]).columns.tolist()
    return cat_cols, num_cols


# -------------------------------------------------------
# Mapping transformed -> original (robust for '_' in names)
# -------------------------------------------------------
def map_transformed_to_original_robust(feature_names_after_preproc, cat_cols):
    cat_cols_sorted = sorted(cat_cols, key=len, reverse=True)  # longest first
    orig = []

    for fn in feature_names_after_preproc:
        if "__" in fn:
            block, rest = fn.split("__", 1)
        else:
            block, rest = "remainder", fn

        if block == "cat":
            matched = None
            for c in cat_cols_sorted:
                if rest == c or rest.startswith(c + "_"):
                    matched = c
                    break
            orig.append(matched if matched is not None else rest.split("_", 1)[0])
        else:
            orig.append(rest)

    return np.array(orig)

# %% [markdown]
# ### Seleção wrapper com validação cruzada (desempenho real por feature)
#
# Como etapa final, aplica-se um *wrapper* que avalia cada variável individualmente usando validação cruzada.
# Ou seja, cada feature é testada em um modelo preditivo simples (Linear/Logistic),
# e é medido o desempenho médio (scoring) ao longo dos folds.
#
# A lógica do wrapper é aproximar o critério de seleção do objetivo final do projeto: desempenho preditivo,
# reduzindo o risco de selecionar variáveis “estatisticamente relevantes” mas com baixo ganho prático no modelo.
#
# O ranking final (`variaveis_finais`) corresponde às `final_wrapper` variáveis com melhor performance no wrapper.

# %%
def _make_wrapper_model(task: str, multiclass_strategy: str = "multinomial", random_state: int = 42):
    """
    multiclass_strategy:
      - "multinomial": LogisticRegression(multi_class="multinomial")
      - "ovr": OneVsRestClassifier(LogisticRegression(...))
      - "ovo": OneVsOneClassifier(LogisticRegression(...))
    """
    t = task.lower()
    m = multiclass_strategy.lower()

    if _is_classification(t):
        base_lr = LogisticRegression(
            max_iter=4000,
            solver="lbfgs",
            n_jobs=None,  # lbfgs ignores n_jobs
        )

        if t == "multiclass":
            if m == "multinomial":
                return LogisticRegression(max_iter=4000, solver="lbfgs", multi_class="multinomial")
            if m == "ovr":
                return OneVsRestClassifier(base_lr)
            if m == "ovo":
                return OneVsOneClassifier(base_lr)
            raise ValueError("multiclass_strategy must be one of: 'multinomial', 'ovr', 'ovo'")

        # binary
        return LogisticRegression(max_iter=4000, solver="lbfgs")

    # regression
    return LinearRegression()

# %% [markdown]
# ### Estratégias para classificação multiclasse: multinomial, OvR e OvO
#
# Para problemas multiclasse, o pipeline permite três estratégias:
# - **multinomial**: regressão logística multiclasse nativa (softmax),
# - **OvR (One-vs-Rest)**: treina um classificador por classe contra o resto,
# - **OvO (One-vs-One)**: treina classificadores para cada par de classes.
#
# A estratégia pode influenciar a avaliação do wrapper (principalmente com F1-macro),
# pois altera como o modelo aprende fronteiras de decisão e lida com classes minoritárias.
#
# ## Pipeline
#
# O pipeline retorna:
# - a matriz processada (`X_processado_df`) e nomes de features após pré-processamento,
# - rankings por método (Mutual Information, ANOVA/F-regression, Random Forest e Wrapper),
# - lista final de variáveis selecionadas no espaço transformado,
# - lista consolidada de variáveis no espaço original (para interpretação),
# - ranking agregado no nível da feature original (melhor score do wrapper entre suas dummies).
#
# Com isso, é possível:
# - justificar tecnicamente a seleção,
# - reproduzir resultados,
# - e comunicar as variáveis relevantes com interpretabilidade.

# %%
def pipeline_selecao_variaveis(
    X: pd.DataFrame,
    y: pd.Series,
    task: str = "binary",              # "binary", "multiclass", "regression"
    var_threshold: float = 0.0,
    k_mi: int = 80,
    k_anova: int = 80,
    top_rf: int = 50,
    final_wrapper: int = 20,
    scoring_wrapper: str | None = None,
    n_splits: int = 5,
    random_state: int = 42,
    multiclass_strategy: str = "multinomial",  # "multinomial", "ovr", "ovo"
):
    # 1) baixa variância
    selector_var = VarianceThreshold(threshold=var_threshold)
    selector_var.fit(X)
    cols_var = X.columns[selector_var.get_support()]
    X1 = X[cols_var]

    # 2) mutual info (rank)
    score_func_mi = _selectkbest_score_func(task)
    if score_func_mi is mutual_info_classif:
        selector_mi = SelectKBest(
            score_func=lambda X_, y_: mutual_info_classif(X_, y_, random_state=random_state),
            k=min(k_mi, X1.shape[1])
        )
    else:
        selector_mi = SelectKBest(score_func=mutual_info_regression, k=min(k_mi, X1.shape[1]))

    selector_mi.fit(X1, y)
    cols_mi = X1.columns[selector_mi.get_support()]
    scores_mi = selector_mi.scores_[selector_mi.get_support()]

    mi_rank = (pd.DataFrame({"variavel": cols_mi, "score_mutual_info": scores_mi})
               .sort_values("score_mutual_info", ascending=False))

    # 3) anova / f-regression (rank)
    score_func_anova = _anova_score_func(task)
    selector_anova = SelectKBest(score_func=score_func_anova, k=min(k_anova, X1.shape[1]))
    selector_anova.fit(X1, y)

    cols_anova = X1.columns[selector_anova.get_support()]
    scores_anova = selector_anova.scores_[selector_anova.get_support()]

    col_score = "score_anova_f" if _is_classification(task) else "score_f_regression"
    anova_rank = (pd.DataFrame({"variavel": cols_anova, col_score: scores_anova})
                  .sort_values(col_score, ascending=False))

    # candidatos (ordem: MI depois ANOVA; sem duplicar)
    candidatos = list(dict.fromkeys(mi_rank["variavel"].tolist() + anova_rank["variavel"].tolist()))
    Xcand = X1[candidatos] if len(candidatos) else X1.copy()

    # 4) RF importance (rank)
    if _is_classification(task):
        rf = RandomForestClassifier(
            n_estimators=400,
            random_state=random_state,
            n_jobs=-1
        )
    else:
        rf = RandomForestRegressor(
            n_estimators=400,
            random_state=random_state,
            n_jobs=-1
        )

    rf.fit(Xcand, y)

    rf_rank = (pd.DataFrame({"variavel": Xcand.columns, "importancia": rf.feature_importances_})
               .sort_values("importancia", ascending=False))

    vars_rf = rf_rank.head(min(top_rf, rf_rank.shape[0]))["variavel"].tolist()

    # 5) wrapper CV (rank) — mede desempenho real por feature (univariado)
    if scoring_wrapper is None:
        scoring_wrapper = _default_scoring(task)

    cv = _make_cv(y, task, n_splits=n_splits, random_state=random_state)
    model = _make_wrapper_model(task, multiclass_strategy=multiclass_strategy, random_state=random_state)

    resultados = []
    for var in vars_rf:
        score = cross_val_score(model, X1[[var]], y, cv=cv, scoring=scoring_wrapper).mean()
        resultados.append((var, score))

    wrap_rank = (pd.DataFrame(resultados, columns=["variavel", scoring_wrapper])
                 .sort_values(scoring_wrapper, ascending=False)
                 .head(min(final_wrapper, len(resultados))))

    return {
        "X_filtrado": X1,
        "ranking_mutual_info": mi_rank,
        "ranking_anova_ou_freg": anova_rank,
        "ranking_rf": rf_rank,
        "ranking_wrapper": wrap_rank,
        "variaveis_finais": wrap_rank["variavel"].tolist(),
        "scoring_wrapper": scoring_wrapper,
    }

# %% [markdown]
# ### Selecionando as variáveis automaticamente
#
# Esta função orquestra um pipeline completo de preparação e seleção de variáveis a partir de um `DataFrame` original,
# suportando tarefas de **classificação (binária/multiclasse)** e **regressão**.
#
# O fluxo é composto por três blocos principais:
#
# 1) **Detecção de tipos de variáveis**
# As colunas de entrada são separadas em **categóricas** e **numéricas** (via `get_feature_types_fn`),
# permitindo aplicar transformações apropriadas a cada tipo.
#
# 2) **Pré-processamento com `ColumnTransformer`**
# - Variáveis numéricas são padronizadas com `StandardScaler`, garantindo escala comparável para métodos e modelos lineares.
# - Variáveis categóricas são transformadas via `OneHotEncoder(handle_unknown="ignore")`, produzindo uma representação numérica robusta.
# Há um tratamento de compatibilidade entre versões do scikit-learn (`sparse_output` vs `sparse`).
#
# O resultado é uma matriz totalmente numérica no “espaço transformado”, acompanhada dos nomes das features geradas (`get_feature_names_out`).
#
# 3) **Seleção de variáveis no espaço transformado + mapeamento para o espaço original**
# A seleção é delegada para `pipeline_selecao_variaveis`, que ranqueia e filtra features usando múltiplos critérios
# (filtros estatísticos, importância por Random Forest e wrapper com validação cruzada).
#
# Como o One-Hot Encoding fragmenta variáveis categóricas em múltiplas colunas, a função reconstrói a rastreabilidade
# mapeando cada feature transformada para sua **coluna original** (`map_transformed_to_original_robust`).
# Além disso, é gerado um ranking agregado por feature original (max do score do wrapper entre suas dummies),
# facilitando interpretação e comunicação dos resultados.
#
# A função retorna tanto artefatos do pré-processamento (preprocessor, matriz transformada) quanto rankings e listas finais
# de variáveis selecionadas no espaço transformado e no espaço original.

# %%
def selecionar_variaveis_auto(
    X_data: pd.DataFrame,
    y_data: pd.Series,
    task: str = "binary",
    multiclass_strategy: str = "multinomial",   # multinomial | ovr | ovo
    scoring_wrapper: str | None = None,
    get_feature_types_fn=get_feature_types,
    var_threshold: float = 0.0,
    k_mi: int = 80,
    k_anova: int = 80,
    top_rf: int = 50,
    final_wrapper: int = 20,
    n_splits: int = 5,
    random_state: int = 42,
    remainder: str = "drop",  # "drop" ou "passthrough"
):
    # 1) tipos
    cat_cols, num_cols = get_feature_types_fn(X_data)

    # 2) preprocessor
    # compatibilidade entre versões sklearn:
    # em versões antigas, OneHotEncoder usa sparse=False; nas novas, sparse_output=False
    try:
        ohe = OneHotEncoder(handle_unknown="ignore", sparse_output=False)
    except TypeError:
        ohe = OneHotEncoder(handle_unknown="ignore", sparse=False)

    preprocessor = ColumnTransformer(
        transformers=[
            ("num", StandardScaler(), num_cols),
            ("cat", ohe, cat_cols),
        ],
        remainder=remainder
    )

    # 3) fit/transform
    X_processed = preprocessor.fit_transform(X_data)
    feature_names = preprocessor.get_feature_names_out()

    X_processed_df = pd.DataFrame(X_processed, columns=feature_names, index=X_data.index)

    # 4) seleção no espaço transformado
    selected = pipeline_selecao_variaveis(
        X_processed_df,
        y_data,
        task=task,
        var_threshold=var_threshold,
        k_mi=k_mi,
        k_anova=k_anova,
        top_rf=top_rf,
        final_wrapper=final_wrapper,
        scoring_wrapper=scoring_wrapper,
        n_splits=n_splits,
        random_state=random_state,
        multiclass_strategy=multiclass_strategy,
    )

    # 5) map back transformed -> original
    transformed_to_original = map_transformed_to_original_robust(feature_names, cat_cols)
    map_dict = dict(zip(feature_names, transformed_to_original))

    vars_transformadas = selected["variaveis_finais"]
    vars_originais = sorted({str(map_dict[v]) for v in vars_transformadas if v in map_dict})

    # agregação opcional: score do wrapper por feature original
    scoring_col = selected["ranking_wrapper"].columns[1]
    df_wrap = selected["ranking_wrapper"].copy()
    df_wrap["feature_original"] = df_wrap["variavel"].map(map_dict)

    ranking_original = (
        df_wrap.groupby("feature_original", dropna=False)[scoring_col]
        .max()
        .sort_values(ascending=False)
        .reset_index()
        .rename(columns={scoring_col: f"{scoring_col}_max"})
    )

    return {
        "preprocessor": preprocessor,
        "X_processado_df": X_processed_df,
        "feature_names_after_preproc": feature_names,
        "resultado_selecao_transformado": selected,
        "variaveis_finais_transformadas": vars_transformadas,
        "variaveis_finais_originais": vars_originais,
        "ranking_wrapper_por_feature_original": ranking_original,
        "cat_cols": cat_cols,
        "num_cols": num_cols,
        "map_transformada_para_original": map_dict,
    }

# %%
var_selected = selecionar_variaveis_auto(
     X_data, y_data,
     task="binary",
     scoring_wrapper="f1",
)


print(f"Variáveis selecionadas({len(var_selected["variaveis_finais_originais"])} variáveis):{var_selected["variaveis_finais_originais"]}")
print(f"Variáveis Originais({len(X_data.columns)} variáveis):{X_data.columns}")
# Out:
# Variáveis selecionadas(12 variáveis):['ANT_CB_LAM', 'CLI_ICTERI', 'CLI_PANTUR', 'CLI_PROST', 'CLI_RENAL', 'CLI_VOMITO', 'CON_AMBIEN', 'CON_AREA', 'CS_ESCOL_N', 'CS_RACA', 'NU_IDADE_N', 'estacao']
# Variáveis Originais(43 variáveis):Index(['NU_IDADE_N', 'CS_SEXO', 'CS_GESTANT', 'CS_RACA', 'CS_ESCOL_N',
#        'ID_OCUPA_N', 'CON_AREA', 'CON_AMBIEN', 'ANT_CB_LAM', 'ANT_CB_CRI',
#        'ANT_CB_SIN', 'ANT_CB_COR', 'ANT_CB_ROE', 'ANT_CB_TER', 'ANT_CB_LIX',
#        'ANT_CB_OUT', 'ANT_ANIMAI', 'ANT_HUMANO', 'CLI_FEBRE', 'CLI_MIALGI',
#        'CLI_CEFALE', 'CLI_PROST', 'CLI_CONGES', 'CLI_PANTUR', 'CLI_VOMITO',
#        'CLI_DIARRE', 'CLI_ICTERI', 'CLI_RENAL', 'CLI_RESPIR', 'CLI_CARDIA',
#        'CLI_HEMOPU', 'CLI_HEMORR', 'CLI_MENING', 'CLI_OUTROS', 'SG_UF',
#        'baixa_escolaridade', 'raca_vulneravel', 'faixa_vulneravel',
#        'vulnerabilidade_social', 'nivel_vulnerabilidade', 'mes_sintomas',
#        'estacao', 'periodo_chuvoso'],
#       dtype='object')

# %% [markdown]
# Filtrando as variáveis a serem utilizadas

# %%
X_data = X_data[var_selected['variaveis_finais_originais']]
X_data.shape
# Out:
# (7873, 12)

# %% [markdown]
# ## Train framework

# %% [markdown]
# ### Funções de apoio

# %% [markdown]
# Detecta automaticamente a disponibilidade de GPU no ambiente,
# verificando suporte a CUDA, compatibilidade do LightGBM com GPU
# e informações do hardware via `nvidia-smi`.

# %%
def detect_gpu():
    """
    Detecta corretamente suporte a GPU para CUDA, XGBoost e LightGBM.
    Retorna um dicionário completo.
    """

    # 1. Verificar CUDA geral
    try:
        cuda_available = torch.cuda.is_available()
    except:
        cuda_available = False


    # 2. Testar LightGBM GPU

    try:
        # Testa se LightGBM foi compilado com suporte a GPU
        lgb_gpu = lgb.register_logger(lambda x: x)  # dummy
        booster = lgb.LGBMClassifier(device="gpu")
        lgb_gpu = True
    except:
        lgb_gpu = False


    # 3. Detalhes da GPU via nvidia-smi

    try:
        smi_output = subprocess.check_output("nvidia-smi", shell=True).decode()
        gpu_info = smi_output.split("\n")[2].strip()
    except:
        gpu_info = "Nenhuma GPU detectada (nvidia-smi não disponível)"

    return {
        "cuda_available": cuda_available,
        "lightgbm_gpu": lgb_gpu,
        "gpu_info": gpu_info
    }

# %%
def get_model_params_gpu(model_name, gpu_info):
    """
    Retorna hiperparâmetros base apropriados para CPU ou GPU.
    """
    use_gpu = gpu_info["cuda_available"]

    if model_name == "xgboost":
        if use_gpu:
            return {
                "tree_method": "gpu_hist",
                "predictor": "gpu_predictor"
            }
        else:
            return {
                "tree_method": "hist",
                "predictor": "cpu_predictor"
            }

    elif model_name == "lightgbm":
        if use_gpu:
            return {
                "device": "gpu",
                "gpu_platform_id": 0,
                "gpu_device_id": 0
            }
        else:
            return {
                "device": "cpu"
            }

    elif model_name in ["random_forest", "svm"]:
        # sklearn não usa GPU
        return {}

    return {}

# %%
def get_feature_types(df):
    """
    Identifica automaticamente colunas categóricas e numéricas de um dataframe.

    Retorna:
        cat_cols  -> lista de colunas categóricas
        num_cols  -> lista de colunas numéricas
    """

    # CATEGÓRICAS: object, category ou boolean
    cat_cols = df.select_dtypes(include=['object', 'category', 'bool']).columns.tolist()

    # NUMÉRICAS: int, float
    num_cols = df.select_dtypes(include=['int', 'float', 'int64', 'float64']).columns.tolist()

    return cat_cols, num_cols

# %% [markdown]
# ###  1. FUNÇÃO PARA CRIAR O MODELO A PARTIR DO TRIAL (Optuna)

# %% [markdown]
# Esta função encapsula a criação do modelo a ser otimizado por uma *trial* do Optuna,
# permitindo que diferentes famílias de classificadores sejam avaliadas dentro do mesmo processo de busca.
#
# O fluxo é composto por duas decisões principais:
#
# 1) **Seleção do algoritmo**
# A cada iteração, o Optuna escolhe o modelo a ser testado (`svm`, `xgboost`, `lightgbm` ou `random_forest`)
# por meio de uma variável categórica (`model_name`). Isso viabiliza uma busca conjunta que compara
# arquiteturas distintas sob o mesmo protocolo de avaliação.
#
# 2) **Amostragem de hiperparâmetros e configuração dinâmica de GPU**
# Para cada algoritmo, são sugeridos hiperparâmetros relevantes (ex.: profundidade, número de árvores, taxa de aprendizado,
# subsample e colsample), definindo um espaço de busca controlado e reproduzível.
# Em paralelo, a função consulta `get_model_params_gpu(model_name, gpu_info)` para injetar automaticamente
# parâmetros específicos de aceleração (CPU/GPU) quando suportado pelo ambiente, garantindo portabilidade do pipeline.
#
# Além disso, é aplicada uma estratégia de mitigação de desbalanceamento:
# - `class_weight="balanced"` para Random Forest e SVM,
# - `is_unbalance=True` para LightGBM,
# visando reduzir viés em cenários com classes minoritárias.
#
# No caso da SVM, utiliza-se `LinearSVC` com calibração (`CalibratedClassifierCV`),
# permitindo a obtenção de probabilidades calibradas, úteis para métricas baseadas em ranking (ex.: ROC-AUC)
# e para tomada de decisão com limiar de classificação.

# %%
def create_model(trial, gpu_info):
    model_name = trial.suggest_categorical(
        "model_name", ["svm","xgboost", "lightgbm", "random_forest"]
    )

    gpu_params = get_model_params_gpu(model_name, gpu_info)

    # RANDOM FOREST
    if model_name == "random_forest":
        return RandomForestClassifier(
            n_estimators=trial.suggest_int("n_estimators", 5, 30),
            max_depth=trial.suggest_int("max_depth", 3, 9),
            min_samples_split=trial.suggest_int("min_samples_split", 2, 10),
            min_samples_leaf=trial.suggest_int("min_samples_leaf", 1, 5),
            random_state=42,
            class_weight= 'balanced',
            **gpu_params
        )

    # SVM
    elif model_name == "svm":
        svm= LinearSVC(
            C=trial.suggest_float("C", 0.1, 3.0),
            max_iter=5000,
            class_weight= 'balanced'
        )
        return CalibratedClassifierCV(svm, method="sigmoid")

    # XGBOOST
    elif model_name == "xgboost":
        return XGBClassifier(
            n_estimators=trial.suggest_int("n_estimators", 5, 30),
            max_depth=trial.suggest_int("max_depth", 3, 9),
            learning_rate=trial.suggest_float("learning_rate", 0.01, 0.3),
            subsample=trial.suggest_float("subsample", 0.5, 1.0),
            colsample_bytree=trial.suggest_float("colsample_bytree", 0.5, 1.0),
            eval_metric="logloss",
            random_state=42,
            class_weight= 'balanced',
            n_jobs=-1,
            #**gpu_params
        )

    # LIGHTGBM
    elif model_name == "lightgbm":
        return LGBMClassifier(
            n_estimators=trial.suggest_int("n_estimators", 5, 30),
            learning_rate=trial.suggest_float("learning_rate", 0.01, 0.3),
            max_depth=trial.suggest_int("max_depth", 3, 9),
            subsample=trial.suggest_float("subsample", 0.5, 1.0),
            colsample_bytree=trial.suggest_float("colsample_bytree", 0.5, 1.0),
            random_state=42,
            is_unbalance=True,
           force_col_wise=True,
            **gpu_params
        )

# %% [markdown]
# ### 2. FUNÇÃO OBJETIVO DO OPTUNA (COM CROSS-VALIDATION)

# %% [markdown]
# ### Função `build_pipeline`: pré-processamento, balanceamento e modelagem em um fluxo único
#
# Esta função constrói um pipeline completo de treinamento, integrando pré-processamento dos dados,
# tratamento de desbalanceamento e ajuste do modelo em uma única estrutura reprodutível.
#
# O pipeline é organizado em três blocos sequenciais:
#
# 1) **Pré-processamento por tipo de variável**
# - Variáveis numéricas passam por imputação da mediana, reduzindo sensibilidade a outliers,
# seguida de padronização (`StandardScaler`), garantindo escalas compatíveis para modelos sensíveis à magnitude.
# - Variáveis categóricas passam por imputação do valor mais frequente e codificação via `OneHotEncoder`,
# com tratamento explícito de categorias raras (`handle_unknown='infrequent_if_exist'`),
# o que reduz dimensionalidade excessiva e melhora estabilidade do modelo.
#
# 2) **Balanceamento de classes (SMOTE)**
# Após o pré-processamento, aplica-se o SMOTE para gerar amostras sintéticas da classe minoritária
# exclusivamente no conjunto de treino dentro do pipeline,
# evitando vazamento de informação (*data leakage*) e melhorando a capacidade do modelo
# em aprender fronteiras de decisão mais equilibradas.
#
# 3) **Modelo preditivo**
# O estimador final é injetado de forma modular, permitindo que diferentes algoritmos
# (Random Forest, SVM, XGBoost, LightGBM, etc.) sejam testados sob exatamente o mesmo fluxo de dados.
#
# Ao encapsular todas as etapas em um único objeto `Pipeline`,
# a função garante consistência entre treino, validação e inferência,
# além de facilitar integração com validação cruzada e otimização de hiperparâmetros.

# %%
def build_pipeline(model, cat_cols, num_cols):

    # construindo o preprocessor
    num_preprocessor = Pipeline(steps=[
        ("imputer", SimpleImputer(strategy="median")),
        ("scaler", StandardScaler())
    ])

    cat_preprocessor = Pipeline(steps=[
        ("imputer", SimpleImputer(strategy="most_frequent")),
        ("onehot", OneHotEncoder(handle_unknown='infrequent_if_exist'))
    ])

    preprocessor = ColumnTransformer(
        transformers=[
            ("num", num_preprocessor, num_cols),
            ("cat", cat_preprocessor, cat_cols)
        ]
    )

    # construindo pipe
    pipe = Pipeline([
        ("preprocessor", preprocessor),
        ("smote", SMOTE(random_state=42)),
        ("model", model)
    ])

    return pipe

# %% [markdown]
# ### Função `objective`: avaliação do modelo por validação cruzada e otimização com Optuna (com pruning)
#
# Esta função define a métrica objetivo utilizada pelo Optuna durante a busca de hiperparâmetros.
# Para cada `trial`, ela instancia um modelo candidato (via `create_model`) e o encapsula em um pipeline completo
# de pré-processamento + balanceamento (via `build_pipeline`), garantindo que todas as transformações
# sejam aplicadas corretamente dentro de cada fold e evitando *data leakage*.
#
# A avaliação é realizada com **validação cruzada estratificada** (`StratifiedKFold`),
# preservando a proporção de classes em treino e validação. Em cada fold:
# - o pipeline é treinado no subconjunto de treino (`fit`),
# - e a performance é medida no subconjunto de validação por **ROC-AUC** calculado a partir de probabilidades (`predict_proba`).
#
# Para suportar cenários multiclasse, o AUC é calculado com `multi_class='ovr'`
# e agregação `average='weighted'`, o que pondera o desempenho pelo suporte de cada classe
# e reduz distorções em bases desbalanceadas.
#
# Além disso, a função utiliza mecanismos de *early stopping* do Optuna:
# - `trial.report` comunica a métrica parcial por fold,
# - `trial.should_prune()` permite interromper tentativas com desempenho fraco,
# economizando tempo computacional e acelerando a convergência do processo de otimização.
#
# Ao final, a função retorna a média do AUC entre os folds, que é o valor maximizado pelo Optuna.

# %%
def objective(trial, X_train, y_train, cat_cols, num_cols,feature_names, gpu_info):

    model = create_model(trial, gpu_info)

    pipe = build_pipeline(model ,cat_cols, num_cols)


    cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

    scores = []
    for step, (train_idx, val_idx) in enumerate(cv.split(X_train, y_train)):

        X_tr, X_val = X_train.iloc[train_idx], X_train.iloc[val_idx]
        y_tr, y_val = y_train.iloc[train_idx], y_train.iloc[val_idx]


        pipe.fit(X_tr, y_tr)
        fold_auc = roc_auc_score(y_val, pipe.predict_proba(X_val)[:, 1])
        scores.append(fold_auc)

        #  reporta o valor parcial ao Optuna
        trial.report(fold_auc, step=step)

        #  aborta a tentativa dado a avaliação do pruner
        if trial.should_prune():
            raise TrialPruned()


    return np.mean(scores)

# %% [markdown]
# Salva o histórico das trials do Optuna (métrica, parâmetros, estado e duração)
# em arquivo CSV para análise e rastreabilidade do processo de otimização.

# %%
# salva os logs das tentativas com métricas, tempo de treinamento, e parametros utilizados pelos modelos
def dump_trials(study, trial):
    df_metrics = study.trials_dataframe(attrs=("number", "value", "params", "state","duration"))
    df_metrics.to_csv("log_opt/trials_log_v2.csv", index=False)

# %% [markdown]
# ### 3. VALIDAÇÃO EXTERNA (OUTER CV) + OPTUNA INTERNO

# %% [markdown]
# ### Função `outer_cv_training_with_results`: nested CV com Optuna, checkpoint e métricas por fold
#
# Esta função executa um processo completo de treinamento e avaliação com **validação cruzada externa**
# (*outer cross-validation*), integrando **otimização de hiperparâmetros com Optuna** dentro de cada fold
# e registrando resultados detalhados (modelo escolhido, métricas, tempo e artefatos salvos).
#
# O fluxo segue a lógica de *nested cross-validation*:
#
# 1) **Diagnóstico do ambiente (GPU)**
# Antes do treinamento, a função identifica a disponibilidade de GPU (`detect_gpu`), permitindo que a criação dos modelos
# ative parâmetros específicos de aceleração quando suportado.
#
# 2) **Validação cruzada externa (generalização)**
# É aplicada uma `StratifiedKFold` externa com `n_splits`, garantindo que a proporção das classes seja preservada em cada divisão.
# Em cada fold externo, o conjunto é particionado em `X_train/y_train` (para otimização e treino) e `X_test/y_test` (avaliação final).
#
# 3) **Otimização interna com Optuna (seleção de modelo + hiperparâmetros)**
# Para cada fold externo, um `study` é criado com objetivo de maximizar a métrica definida na função `objective`.
# A função `objective` é “fixada” via `partial`, injetando os dados do fold e metadados do pipeline (colunas numéricas e categóricas,
# GPU, etc.), de forma que cada trial avalie modelos e hiperparâmetros sob o mesmo protocolo.
#
# O estudo é executado com:
# - `n_trials` tentativas,
# - controle de tempo (`timeout`),
# - paralelismo (`n_jobs=-1`),
# - callback de logging (`dump_trials`) para persistir histórico das trials.
#
# 4) **Treinamento final do melhor modelo no fold e checkpoint**
# Após a otimização, a melhor configuração é recuperada (`study.best_params`) e o melhor modelo é reconstruído (`create_model`),
# sendo então encapsulado em um pipeline (`build_pipeline`) com pré-processamento e SMOTE.
# O pipeline é treinado no conjunto de treino do fold com medição de tempo, e o artefato final é salvo em disco (`joblib.dump`)
# como checkpoint (`best_model_fold_k.pkl`), garantindo reprodutibilidade e possibilidade de reuso posterior.
#
# 5) **Avaliação no conjunto de teste do fold (métricas completas)**
# O modelo treinado é avaliado no `X_test/y_test` do fold externo usando:
# - **ROC-AUC multiclasse** com estratégia OvR e média ponderada (`average='weighted'`),
# - além de `accuracy`, `f1`, `recall` e `precision` (também ponderadas), adequadas para cenários desbalanceados.
#
# Ao final, a função retorna uma lista de dicionários com os resultados de cada fold,
# incluindo o modelo vencedor, hiperparâmetros, métricas, tempo de treino e caminho do checkpoint.
# Isso permite comparar estabilidade do desempenho entre folds e estimar capacidade real de generalização.

# %%
def outer_cv_training_with_results(
    X, y, cat_cols, num_cols, n_trials=30, n_splits=5
):

    gpu_info = detect_gpu()
    print("\n🔍 GPU detectada:", gpu_info)

    outer_cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
    results = []
    feature_names = X.columns
    fold = 1
    for train_idx, test_idx in outer_cv.split(X, y):

        print(f"\n==============================")
        print(f"  Fold Externo {fold}/{n_splits}")
        print(f"==============================")

        X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

        pruner = SuccessiveHalvingPruner(min_resource=1,
                                 reduction_factor=3,
                                 min_early_stopping_rate=1)

        study = optuna.create_study(direction="maximize")

        objective_fixed = partial(objective,
                          X_train=X_train,
                          y_train=y_train,
                          cat_cols=cat_cols,
                          num_cols=num_cols,
                          feature_names=feature_names,
                          gpu_info=gpu_info)

        study.optimize(objective_fixed,
                      n_trials=n_trials,
                      callbacks=[dump_trials],
                      timeout=1800,
                      n_jobs=-1,
                      )

        best_params = study.best_params
        best_model_name = best_params["model_name"]
        best_model = create_model(study.best_trial, gpu_info)


        pipe = build_pipeline(best_model ,cat_cols, num_cols)

        # treino com timer
        start_time = time.time()
        pipe.fit(X_train, y_train)
        train_time = time.time() - start_time

        # CHECKPOINT
        checkpoint_dir = "checkpoints_best_models"
        if not os.path.exists(checkpoint_dir):
            os.makedirs(checkpoint_dir)

        checkpoint_path = os.path.join(
            checkpoint_dir, f"best_model_fold_{fold}.pkl"
        )
        joblib.dump(pipe, checkpoint_path)

        # predição
        y_pred = pipe.predict(X_test)
        y_pred_prob = pipe.predict_proba(X_test)[:, 1]

        # métricas
        auc = roc_auc_score(y_test, y_pred_prob)
        acc = accuracy_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)
        rec = recall_score(y_test, y_pred)
        prec = precision_score(y_test, y_pred)

        # salvar dados do fold
        results.append({
            "fold": fold,
            "best_model": best_model_name,
            "auc": auc,
            "accuracy": acc,
            "f1": f1,
            "recall": rec,
            "precision": prec,
            "hyperparameters": best_params,
            "checkpoint_path": checkpoint_path,
            "train_time_seconds": train_time,
            #"test_data": {
            #    "X_test": X_test.copy(),
            #    "y_test": y_test.reset_index(drop=True),
            #    "y_pred": pd.Series(y_pred)
            #}
        })

        fold += 1

    return results

# %% [markdown]
# # Execute Framework

# %% [markdown]
# Cria os diretórios de checkpoints de modelos e logs de otimização,
# caso não existam, garantindo persistência e organização dos artefatos do experimento.

# %%
import os, joblib
checkpoint_dir = "checkpoints_best_models"

if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)

checkpoint_dir = "log_opt"
if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)


# ================================================

# %% [markdown]
# ### Execução do treinamento com validação cruzada externa e otimização de hiperparâmetros
#
# Nesta etapa, o conjunto de dados é preparado para o processo completo de treinamento e avaliação.
# Inicialmente, as colunas são classificadas em **categóricas** e **numéricas** por meio da função
# `get_feature_types`, garantindo que o pré-processamento subsequente seja aplicado de forma adequada
# a cada tipo de variável.
#
# Em seguida, é executado o procedimento de **validação cruzada externa** (*outer cross-validation*),
# no qual, para cada fold, ocorre uma otimização interna de hiperparâmetros via Optuna.
# Esse desenho experimental permite avaliar o desempenho dos modelos de forma mais realista,
# uma vez que o conjunto de teste de cada fold permanece completamente isolado do processo de tuning.
#
# Os parâmetros utilizados (`n_trials=30` e `n_splits=5`) definem, respectivamente,
# o orçamento de busca de hiperparâmetros em cada fold e o número de partições externas,
# balanceando custo computacional e robustez estatística.
#
# O resultado final (`df_results`) contém métricas, hiperparâmetros selecionados,
# tempos de treinamento e caminhos dos checkpoints para cada fold,
# servindo como base para análises comparativas e seleção do modelo final.

# %%
cat_cols, num_cols = get_feature_types(X_data)
df_results = outer_cv_training_with_results(
    X_data, y_data,
    cat_cols=cat_cols,
    num_cols=num_cols,
    n_trials=30,
    n_splits=5
)
# Out:
# [I 2026-02-01 05:18:00,285] A new study created in memory with name: no-name-a02d9b5b-83fe-4a30-a032-44f32a60d3f9
# 🔍 GPU detectada: {'cuda_available': False, 'lightgbm_gpu': False, 'gpu_info': 'Nenhuma GPU detectada (nvidia-smi não disponível)'}
#
# ==============================
#   Fold Externo 1/5
# ==============================
# [I 2026-02-01 05:18:01,519] Trial 0 finished with value: 0.8990579699268441 and parameters: {'model_name': 'random_forest', 'n_estimators': 18, 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 5}. Best is trial 0 with value: 0.8990579699268441.
# [I 2026-02-01 05:18:02,145] Trial 1 finished with value: 0.8868589974184188 and parameters: {'model_name': 'xgboost', 'n_estimators': 13, 'max_depth': 8, 'learning_rate': 0.054558438037912355, 'subsample': 0.9432800297955632, 'colsample_bytree': 0.926828688277578}. Best is trial 0 with value: 0.8990579699268441.
# [I 2026-02-01 05:18:02,488] Trial 2 finished with value: 0.8881732257624586 and parameters: {'model_name': 'xgboost', 'n_estimators': 24, 'max_depth': 3, 'learning_rate': 0.05875460346382016, 'subsample': 0.594949861783645, 'colsample_bytree': 0.5578681354218826}. Best is trial 0 with value: 0.8990579699268441.
# [I 2026-02-01 05:18:03,898] Trial 3 finished with value: 0.9013161658987853 and parameters: {'model_name': 'random_forest', 'n_estimators': 21, 'max_depth': 7, 'min_samples_split': 5, 'min_samples_leaf': 3}. Best is trial 3 with value: 0.9013161658987853.
# [I 2026-02-01 05:18:03,901] Trial 4 finished with value: 0.9033101859681022 and parameters: {'model_name': 'svm', 'C': 0.5174403767946556}. Best is trial 4 with value: 0.9033101859681022.
# [I 2026-02-01 05:18:04,145] Trial 6 pruned.
# [I 2026-02-01 05:18:04,898] Trial 7 finished with value: 0.9011861163855346 and parameters: {'model_name': 'lightgbm', 'n_estimators': 16, 'learning_rate': 0.26894221217062697, 'max_depth': 8, 'subsample': 0.6645493261952209, 'colsample_bytree': 0.8944337314189119}. Best is trial 4 with value: 0.9033101859681022.
# [I 2026-02-01 05:18:06,135] Trial 5 finished with value: 0.9019765103579448 and parameters: {'model_name': 'random_forest', 'n_estimators': 27, 'max_depth': 7, 'min_samples_split': 4, 'min_samples_leaf': 2}. Best is trial 4 with value: 0.9033101859681022.
# [I 2026-02-01 05:18:06,287] Trial 8 finished with value: 0.9014122875725928 and parameters: {'model_name': 'lightgbm', 'n_estimators': 17, 'learning_rate': 0.15758606167653444, 'max_depth': 7, 'subsample': 0.7689989660066036, 'colsample_bytree': 0.6675754698652753}. Best is trial 4 with value: 0.9033101859681022.
# [I 2026-02-01 05:18:06,529] Trial 9 pruned.
# [I 2026-02-01 05:18:06,760] Trial 10 pruned.
# [I 2026-02-01 05:18:09,053] Trial 11 finished with value: 0.9033196025863401 and parameters: {'model_name': 'svm', 'C': 0.41938471918288306}. Best is trial 11 with value: 0.9033196025863401.
# [I 2026-02-01 05:18:09,121] Trial 12 finished with value: 0.9033195997793476 and parameters: {'model_name': 'svm', 'C': 0.36765001986467455}. Best is trial 11 with value: 0.9033196025863401.
# [I 2026-02-01 05:18:10,561] Trial 14 finished with value: 0.9033431263075316 and parameters: {'model_name': 'svm', 'C': 0.1723618721425008}. Best is trial 14 with value: 0.9033431263075316.
# [I 2026-02-01 05:18:10,768] Trial 13 finished with value: 0.903334190246435 and parameters: {'model_name': 'svm', 'C': 0.26291516171046064}. Best is trial 14 with value: 0.9033431263075316.
# [I 2026-02-01 05:18:12,100] Trial 16 pruned.
# [I 2026-02-01 05:18:12,116] Trial 15 finished with value: 0.9033497182490673 and parameters: {'model_name': 'svm', 'C': 0.13860008781807281}. Best is trial 15 with value: 0.9033497182490673.
# [I 2026-02-01 05:18:13,261] Trial 18 pruned.
# [I 2026-02-01 05:18:13,265] Trial 17 pruned.
# [I 2026-02-01 05:18:14,308] Trial 19 pruned.
# [I 2026-02-01 05:18:14,475] Trial 20 pruned.
# [I 2026-02-01 05:18:14,940] Trial 21 pruned.
# [I 2026-02-01 05:18:15,979] Trial 22 finished with value: 0.9033483046475695 and parameters: {'model_name': 'svm', 'C': 0.14506077812748813}. Best is trial 15 with value: 0.9033497182490673.
# [I 2026-02-01 05:18:15,995] Trial 23 pruned.
# [I 2026-02-01 05:18:17,126] Trial 24 pruned.
# [I 2026-02-01 05:18:17,139] Trial 25 pruned.
# [I 2026-02-01 05:18:18,177] Trial 27 pruned.
# [I 2026-02-01 05:18:18,269] Trial 26 pruned.
# [I 2026-02-01 05:18:18,614] Trial 29 pruned.
# [I 2026-02-01 05:18:19,050] Trial 28 pruned.
# [I 2026-02-01 05:18:19,820] A new study created in memory with name: no-name-d10295dd-1109-4ead-acfa-51e70c58efde
# ==============================
#   Fold Externo 2/5
# ==============================
# [I 2026-02-01 05:18:21,745] Trial 0 finished with value: 0.8938512452985413 and parameters: {'model_name': 'random_forest', 'n_estimators': 19, 'max_depth': 3, 'min_samples_split': 8, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.8938512452985413.
# [I 2026-02-01 05:18:22,615] Trial 2 finished with value: 0.8979042850010418 and parameters: {'model_name': 'lightgbm', 'n_estimators': 6, 'learning_rate': 0.11890306812271419, 'max_depth': 4, 'subsample': 0.5874657052021173, 'colsample_bytree': 0.6544905239266168}. Best is trial 2 with value: 0.8979042850010418.
# [I 2026-02-01 05:18:23,653] Trial 3 finished with value: 0.8987457909411901 and parameters: {'model_name': 'lightgbm', 'n_estimators': 21, 'learning_rate': 0.24540823933611097, 'max_depth': 8, 'subsample': 0.8482558027847835, 'colsample_bytree': 0.5058490839310186}. Best is trial 3 with value: 0.8987457909411901.
# [I 2026-02-01 05:18:23,768] Trial 1 finished with value: 0.9042467276969521 and parameters: {'model_name': 'xgboost', 'n_estimators': 27, 'max_depth': 6, 'learning_rate': 0.25150961341341516, 'subsample': 0.9827412877826931, 'colsample_bytree': 0.6849693983163312}. Best is trial 1 with value: 0.9042467276969521.
# [I 2026-02-01 05:18:24,682] Trial 5 finished with value: 0.8778894860922941 and parameters: {'model_name': 'xgboost', 'n_estimators': 10, 'max_depth': 6, 'learning_rate': 0.012789899114010813, 'subsample': 0.6768209884894204, 'colsample_bytree': 0.7712059253471506}. Best is trial 1 with value: 0.9042467276969521.
# [I 2026-02-01 05:18:25,158] Trial 6 pruned.
# [I 2026-02-01 05:18:25,621] Trial 4 finished with value: 0.9016413854705361 and parameters: {'model_name': 'xgboost', 'n_estimators': 14, 'max_depth': 9, 'learning_rate': 0.18479798487901383, 'subsample': 0.9401357896511917, 'colsample_bytree': 0.7849103312598995}. Best is trial 1 with value: 0.9042467276969521.
# [I 2026-02-01 05:18:26,041] Trial 7 finished with value: 0.8993816550560637 and parameters: {'model_name': 'xgboost', 'n_estimators': 23, 'max_depth': 3, 'learning_rate': 0.20071080041878606, 'subsample': 0.6186005161113256, 'colsample_bytree': 0.6067629803496637}. Best is trial 1 with value: 0.9042467276969521.
# [I 2026-02-01 05:18:26,120] Trial 8 pruned.
# [I 2026-02-01 05:18:26,334] Trial 9 pruned.
# [I 2026-02-01 05:18:26,908] Trial 11 pruned.
# [I 2026-02-01 05:18:27,124] Trial 10 finished with value: 0.8995436843558595 and parameters: {'model_name': 'random_forest', 'n_estimators': 12, 'max_depth': 5, 'min_samples_split': 8, 'min_samples_leaf': 1}. Best is trial 1 with value: 0.9042467276969521.
# [I 2026-02-01 05:18:28,571] Trial 12 finished with value: 0.904098946411141 and parameters: {'model_name': 'xgboost', 'n_estimators': 29, 'max_depth': 5, 'learning_rate': 0.2520079139716115, 'subsample': 0.9800996383272491, 'colsample_bytree': 0.9206300988934373}. Best is trial 1 with value: 0.9042467276969521.
# [I 2026-02-01 05:18:28,963] Trial 13 finished with value: 0.9024711024626096 and parameters: {'model_name': 'xgboost', 'n_estimators': 28, 'max_depth': 6, 'learning_rate': 0.2848571118789647, 'subsample': 0.9935024155221415, 'colsample_bytree': 0.9299659484548015}. Best is trial 1 with value: 0.9042467276969521.
# [I 2026-02-01 05:18:29,597] Trial 15 pruned.
# [I 2026-02-01 05:18:30,198] Trial 16 pruned.
# [I 2026-02-01 05:18:30,377] Trial 14 finished with value: 0.9037589168654773 and parameters: {'model_name': 'xgboost', 'n_estimators': 30, 'max_depth': 5, 'learning_rate': 0.2925989430509077, 'subsample': 0.9967711798256905, 'colsample_bytree': 0.9749874105471767}. Best is trial 1 with value: 0.9042467276969521.
# [I 2026-02-01 05:18:30,762] Trial 17 pruned.
# [I 2026-02-01 05:18:31,280] Trial 19 pruned.
# [I 2026-02-01 05:18:33,682] Trial 18 finished with value: 0.9019620113988176 and parameters: {'model_name': 'xgboost', 'n_estimators': 25, 'max_depth': 7, 'learning_rate': 0.12133278733721847, 'subsample': 0.9000333359580439, 'colsample_bytree': 0.8656229917165115}. Best is trial 1 with value: 0.9042467276969521.
# [I 2026-02-01 05:18:33,696] Trial 20 finished with value: 0.9033486826091295 and parameters: {'model_name': 'xgboost', 'n_estimators': 26, 'max_depth': 6, 'learning_rate': 0.24182323703699876, 'subsample': 0.8890615695807226, 'colsample_bytree': 0.8562427199998804}. Best is trial 1 with value: 0.9042467276969521.
# [I 2026-02-01 05:18:34,505] Trial 22 pruned.
# [I 2026-02-01 05:18:36,112] Trial 21 finished with value: 0.9031331485207127 and parameters: {'model_name': 'xgboost', 'n_estimators': 30, 'max_depth': 4, 'learning_rate': 0.24742643880899037, 'subsample': 0.9584741477156362, 'colsample_bytree': 0.9980414678595044}. Best is trial 1 with value: 0.9042467276969521.
# [I 2026-02-01 05:18:36,413] Trial 23 finished with value: 0.9042860052433342 and parameters: {'model_name': 'xgboost', 'n_estimators': 28, 'max_depth': 4, 'learning_rate': 0.2942719370385007, 'subsample': 0.940921949720434, 'colsample_bytree': 0.9173429890141318}. Best is trial 23 with value: 0.9042860052433342.
# [I 2026-02-01 05:18:36,659] Trial 24 pruned.
# [I 2026-02-01 05:18:36,851] Trial 25 pruned.
# [I 2026-02-01 05:18:37,067] Trial 26 pruned.
# [I 2026-02-01 05:18:38,219] Trial 27 finished with value: 0.9010232395143086 and parameters: {'model_name': 'random_forest', 'n_estimators': 22, 'max_depth': 7, 'min_samples_split': 3, 'min_samples_leaf': 5}. Best is trial 23 with value: 0.9042860052433342.
# [I 2026-02-01 05:18:38,325] Trial 28 finished with value: 0.9001769329149832 and parameters: {'model_name': 'random_forest', 'n_estimators': 23, 'max_depth': 6, 'min_samples_split': 3, 'min_samples_leaf': 5}. Best is trial 23 with value: 0.9042860052433342.
# [I 2026-02-01 05:18:38,620] Trial 29 pruned.
# [I 2026-02-01 05:18:39,004] A new study created in memory with name: no-name-341b219f-ed68-4733-a8ec-116b48f39d60
# ==============================
#   Fold Externo 3/5
# ==============================
# [I 2026-02-01 05:18:40,373] Trial 0 finished with value: 0.8926461178816166 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.04497252182716732, 'max_depth': 7, 'subsample': 0.713622709066468, 'colsample_bytree': 0.755123749694246}. Best is trial 0 with value: 0.8926461178816166.
# [I 2026-02-01 05:18:40,640] Trial 1 finished with value: 0.8903138112687211 and parameters: {'model_name': 'svm', 'C': 1.007731901797742}. Best is trial 0 with value: 0.8926461178816166.
# [I 2026-02-01 05:18:41,416] Trial 2 finished with value: 0.8911850390505281 and parameters: {'model_name': 'lightgbm', 'n_estimators': 24, 'learning_rate': 0.04749772085750197, 'max_depth': 6, 'subsample': 0.8854680914449495, 'colsample_bytree': 0.8730423773052025}. Best is trial 0 with value: 0.8926461178816166.
# [I 2026-02-01 05:18:41,735] Trial 3 finished with value: 0.890077901922417 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.10928762548743419, 'max_depth': 9, 'subsample': 0.6992485785417698, 'colsample_bytree': 0.9248566252129509}. Best is trial 0 with value: 0.8926461178816166.
# [I 2026-02-01 05:18:42,556] Trial 4 finished with value: 0.889126535903992 and parameters: {'model_name': 'lightgbm', 'n_estimators': 17, 'learning_rate': 0.1374937149592508, 'max_depth': 9, 'subsample': 0.8451569902951195, 'colsample_bytree': 0.9943941900506685}. Best is trial 0 with value: 0.8926461178816166.
# [I 2026-02-01 05:18:42,794] Trial 6 pruned.
# [I 2026-02-01 05:18:43,065] Trial 5 finished with value: 0.8903420695444128 and parameters: {'model_name': 'svm', 'C': 0.6403454816610272}. Best is trial 0 with value: 0.8926461178816166.
# [I 2026-02-01 05:18:43,234] Trial 7 pruned.
# [I 2026-02-01 05:18:43,352] Trial 8 pruned.
# [I 2026-02-01 05:18:43,610] Trial 9 pruned.
# [I 2026-02-01 05:18:43,811] Trial 10 pruned.
# [I 2026-02-01 05:18:44,297] Trial 11 pruned.
# [I 2026-02-01 05:18:44,616] Trial 13 pruned.
# [I 2026-02-01 05:18:44,833] Trial 12 finished with value: 0.8901956688779357 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.01512779397358438, 'max_depth': 7, 'subsample': 0.890774901680235, 'colsample_bytree': 0.7992712619574132}. Best is trial 0 with value: 0.8926461178816166.
# [I 2026-02-01 05:18:45,532] Trial 14 finished with value: 0.8901801504190785 and parameters: {'model_name': 'lightgbm', 'n_estimators': 23, 'learning_rate': 0.04435892549119858, 'max_depth': 7, 'subsample': 0.8963979715243462, 'colsample_bytree': 0.8176798377274902}. Best is trial 0 with value: 0.8926461178816166.
# [I 2026-02-01 05:18:45,777] Trial 15 finished with value: 0.8936925020046895 and parameters: {'model_name': 'lightgbm', 'n_estimators': 23, 'learning_rate': 0.21649167233246053, 'max_depth': 5, 'subsample': 0.8065350165579735, 'colsample_bytree': 0.8583877685551567}. Best is trial 15 with value: 0.8936925020046895.
# [I 2026-02-01 05:18:46,278] Trial 16 pruned.
# [I 2026-02-01 05:18:47,097] Trial 17 finished with value: 0.8978363860944688 and parameters: {'model_name': 'lightgbm', 'n_estimators': 19, 'learning_rate': 0.22687022759237022, 'max_depth': 5, 'subsample': 0.6010049755741065, 'colsample_bytree': 0.7364818473725262}. Best is trial 17 with value: 0.8978363860944688.
# [I 2026-02-01 05:18:47,842] Trial 18 finished with value: 0.8967532755602822 and parameters: {'model_name': 'lightgbm', 'n_estimators': 18, 'learning_rate': 0.21221322455567942, 'max_depth': 5, 'subsample': 0.7880083035539921, 'colsample_bytree': 0.7317991082328433}. Best is trial 17 with value: 0.8978363860944688.
# [I 2026-02-01 05:18:48,299] Trial 19 pruned.
# [I 2026-02-01 05:18:48,995] Trial 20 pruned.
# [I 2026-02-01 05:18:49,527] Trial 21 finished with value: 0.8955243054074516 and parameters: {'model_name': 'lightgbm', 'n_estimators': 18, 'learning_rate': 0.2647275698175814, 'max_depth': 4, 'subsample': 0.6289971078129684, 'colsample_bytree': 0.6037624797577432}. Best is trial 17 with value: 0.8978363860944688.
# [I 2026-02-01 05:18:50,046] Trial 22 finished with value: 0.8968701343133295 and parameters: {'model_name': 'lightgbm', 'n_estimators': 20, 'learning_rate': 0.22547541388657874, 'max_depth': 5, 'subsample': 0.7830193237500492, 'colsample_bytree': 0.6633878462517281}. Best is trial 17 with value: 0.8978363860944688.
# [I 2026-02-01 05:18:50,250] Trial 23 finished with value: 0.8949518383443412 and parameters: {'model_name': 'lightgbm', 'n_estimators': 15, 'learning_rate': 0.26429891316367926, 'max_depth': 4, 'subsample': 0.6247070453371358, 'colsample_bytree': 0.6037540352832741}. Best is trial 17 with value: 0.8978363860944688.
# [I 2026-02-01 05:18:50,596] Trial 24 pruned.
# [I 2026-02-01 05:18:51,079] Trial 25 finished with value: 0.8960944272282041 and parameters: {'model_name': 'lightgbm', 'n_estimators': 20, 'learning_rate': 0.2092070818887161, 'max_depth': 5, 'subsample': 0.7787654540738141, 'colsample_bytree': 0.7118147195330201}. Best is trial 17 with value: 0.8978363860944688.
# [I 2026-02-01 05:18:51,459] Trial 26 finished with value: 0.8971414280475619 and parameters: {'model_name': 'lightgbm', 'n_estimators': 20, 'learning_rate': 0.1777056710160652, 'max_depth': 5, 'subsample': 0.8187380831904678, 'colsample_bytree': 0.6747108063514329}. Best is trial 17 with value: 0.8978363860944688.
# [I 2026-02-01 05:18:51,908] Trial 28 pruned.
# [I 2026-02-01 05:18:52,062] Trial 27 finished with value: 0.8973413845899264 and parameters: {'model_name': 'lightgbm', 'n_estimators': 21, 'learning_rate': 0.18064674639593756, 'max_depth': 5, 'subsample': 0.834222663713473, 'colsample_bytree': 0.6622267138819721}. Best is trial 17 with value: 0.8978363860944688.
# [I 2026-02-01 05:18:52,525] Trial 29 pruned.
# [I 2026-02-01 05:18:52,716] A new study created in memory with name: no-name-cc07c952-d0c8-48b2-ad55-00a4339e9217
# [LightGBM] [Info] Number of positive: 5032, number of negative: 5032
# [LightGBM] [Info] Total Bins 8498
# [LightGBM] [Info] Number of data points in the train set: 10064, number of used features: 49
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# ==============================
#   Fold Externo 4/5
# ==============================
# [I 2026-02-01 05:18:53,996] Trial 0 finished with value: 0.8951362391409657 and parameters: {'model_name': 'random_forest', 'n_estimators': 30, 'max_depth': 5, 'min_samples_split': 6, 'min_samples_leaf': 3}. Best is trial 0 with value: 0.8951362391409657.
# [I 2026-02-01 05:18:54,704] Trial 1 finished with value: 0.9007921489107175 and parameters: {'model_name': 'xgboost', 'n_estimators': 23, 'max_depth': 8, 'learning_rate': 0.19893963579134072, 'subsample': 0.5220962429553435, 'colsample_bytree': 0.8183149711727931}. Best is trial 1 with value: 0.9007921489107175.
# [I 2026-02-01 05:18:55,863] Trial 2 finished with value: 0.9004830906509004 and parameters: {'model_name': 'random_forest', 'n_estimators': 23, 'max_depth': 8, 'min_samples_split': 4, 'min_samples_leaf': 4}. Best is trial 1 with value: 0.9007921489107175.
# [I 2026-02-01 05:18:56,111] Trial 3 finished with value: 0.8940167008892131 and parameters: {'model_name': 'svm', 'C': 1.430886011499982}. Best is trial 1 with value: 0.9007921489107175.
# [I 2026-02-01 05:18:57,459] Trial 4 finished with value: 0.8940421257772352 and parameters: {'model_name': 'svm', 'C': 0.7366838046667746}. Best is trial 1 with value: 0.9007921489107175.
# [I 2026-02-01 05:18:57,957] Trial 6 pruned.
# [I 2026-02-01 05:18:57,992] Trial 5 finished with value: 0.9003493122211136 and parameters: {'model_name': 'random_forest', 'n_estimators': 15, 'max_depth': 9, 'min_samples_split': 10, 'min_samples_leaf': 2}. Best is trial 1 with value: 0.9007921489107175.
# [I 2026-02-01 05:18:58,309] Trial 8 pruned.
# [I 2026-02-01 05:18:58,878] Trial 9 pruned.
# [I 2026-02-01 05:18:59,142] Trial 7 pruned.
# [I 2026-02-01 05:18:59,410] Trial 11 pruned.
# [I 2026-02-01 05:19:00,713] Trial 12 pruned.
# [I 2026-02-01 05:19:01,873] Trial 13 pruned.
# [I 2026-02-01 05:19:01,926] Trial 10 finished with value: 0.8999481261735136 and parameters: {'model_name': 'xgboost', 'n_estimators': 22, 'max_depth': 7, 'learning_rate': 0.272416789588844, 'subsample': 0.7301977043848009, 'colsample_bytree': 0.8735730453707917}. Best is trial 1 with value: 0.9007921489107175.
# [I 2026-02-01 05:19:03,227] Trial 14 finished with value: 0.8996838201481997 and parameters: {'model_name': 'lightgbm', 'n_estimators': 29, 'learning_rate': 0.1584759868696091, 'max_depth': 6, 'subsample': 0.6882573353405509, 'colsample_bytree': 0.5009583874948473}. Best is trial 1 with value: 0.9007921489107175.
# [I 2026-02-01 05:19:03,258] Trial 15 pruned.
# [I 2026-02-01 05:19:04,507] Trial 17 pruned.
# [I 2026-02-01 05:19:04,549] Trial 16 pruned.
# [I 2026-02-01 05:19:05,658] Trial 18 pruned.
# [I 2026-02-01 05:19:06,053] Trial 20 pruned.
# [I 2026-02-01 05:19:06,413] Trial 21 pruned.
# [I 2026-02-01 05:19:06,815] Trial 22 pruned.
# [I 2026-02-01 05:19:07,182] Trial 19 finished with value: 0.9029855442214285 and parameters: {'model_name': 'xgboost', 'n_estimators': 27, 'max_depth': 9, 'learning_rate': 0.20356859348411085, 'subsample': 0.8851223958658165, 'colsample_bytree': 0.7512374118259411}. Best is trial 19 with value: 0.9029855442214285.
# [I 2026-02-01 05:19:07,267] Trial 23 pruned.
# [I 2026-02-01 05:19:09,210] Trial 24 pruned.
# [I 2026-02-01 05:19:09,479] Trial 25 finished with value: 0.9035600890540088 and parameters: {'model_name': 'xgboost', 'n_estimators': 26, 'max_depth': 8, 'learning_rate': 0.20576790179594928, 'subsample': 0.8260006415910568, 'colsample_bytree': 0.7720957124951093}. Best is trial 25 with value: 0.9035600890540088.
# [I 2026-02-01 05:19:09,901] Trial 26 pruned.
# [I 2026-02-01 05:19:10,223] Trial 27 pruned.
# [I 2026-02-01 05:19:12,652] Trial 28 pruned.
# [I 2026-02-01 05:19:12,654] Trial 29 pruned.
# [I 2026-02-01 05:19:16,865] A new study created in memory with name: no-name-bd3a709e-385e-4422-a32d-6fc3ec2e0661
# ==============================
#   Fold Externo 5/5
# ==============================
# [I 2026-02-01 05:19:17,418] Trial 1 finished with value: 0.8923336540502453 and parameters: {'model_name': 'lightgbm', 'n_estimators': 6, 'learning_rate': 0.06096026482404812, 'max_depth': 4, 'subsample': 0.5088610648033856, 'colsample_bytree': 0.9787672425742374}. Best is trial 1 with value: 0.8923336540502453.
# [I 2026-02-01 05:19:18,223] Trial 2 finished with value: 0.8971947139637516 and parameters: {'model_name': 'random_forest', 'n_estimators': 17, 'max_depth': 4, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 2 with value: 0.8971947139637516.
# [I 2026-02-01 05:19:18,518] Trial 0 finished with value: 0.9013208339312092 and parameters: {'model_name': 'random_forest', 'n_estimators': 27, 'max_depth': 7, 'min_samples_split': 9, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.9013208339312092.
# [I 2026-02-01 05:19:19,257] Trial 3 finished with value: 0.8843105247731448 and parameters: {'model_name': 'xgboost', 'n_estimators': 15, 'max_depth': 5, 'learning_rate': 0.08460050760116063, 'subsample': 0.8245130645952051, 'colsample_bytree': 0.7495957635780681}. Best is trial 0 with value: 0.9013208339312092.
# [I 2026-02-01 05:19:19,323] Trial 4 finished with value: 0.8972630550121456 and parameters: {'model_name': 'lightgbm', 'n_estimators': 14, 'learning_rate': 0.1155070675013404, 'max_depth': 7, 'subsample': 0.5914074829860876, 'colsample_bytree': 0.7274286202087181}. Best is trial 0 with value: 0.9013208339312092.
# [I 2026-02-01 05:19:19,820] Trial 5 pruned.
# [I 2026-02-01 05:19:19,833] Trial 6 pruned.
# [I 2026-02-01 05:19:20,084] Trial 7 pruned.
# [I 2026-02-01 05:19:20,200] Trial 8 pruned.
# [I 2026-02-01 05:19:20,461] Trial 9 pruned.
# [I 2026-02-01 05:19:20,734] Trial 10 pruned.
# [I 2026-02-01 05:19:22,701] Trial 11 finished with value: 0.9001454472656508 and parameters: {'model_name': 'random_forest', 'n_estimators': 29, 'max_depth': 9, 'min_samples_split': 9, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.9013208339312092.
# [I 2026-02-01 05:19:22,979] Trial 12 finished with value: 0.9002256226945898 and parameters: {'model_name': 'random_forest', 'n_estimators': 30, 'max_depth': 9, 'min_samples_split': 9, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.9013208339312092.
# [I 2026-02-01 05:19:24,162] Trial 14 pruned.
# [I 2026-02-01 05:19:24,921] Trial 13 finished with value: 0.9002256226945898 and parameters: {'model_name': 'random_forest', 'n_estimators': 30, 'max_depth': 9, 'min_samples_split': 9, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.9013208339312092.
# [I 2026-02-01 05:19:25,882] Trial 15 finished with value: 0.9012644891126981 and parameters: {'model_name': 'random_forest', 'n_estimators': 30, 'max_depth': 7, 'min_samples_split': 7, 'min_samples_leaf': 3}. Best is trial 0 with value: 0.9013208339312092.
# [I 2026-02-01 05:19:26,274] Trial 16 finished with value: 0.9012905467837936 and parameters: {'model_name': 'random_forest', 'n_estimators': 22, 'max_depth': 7, 'min_samples_split': 7, 'min_samples_leaf': 3}. Best is trial 0 with value: 0.9013208339312092.
# [I 2026-02-01 05:19:27,943] Trial 17 finished with value: 0.9022322846027624 and parameters: {'model_name': 'random_forest', 'n_estimators': 22, 'max_depth': 7, 'min_samples_split': 6, 'min_samples_leaf': 3}. Best is trial 17 with value: 0.9022322846027624.
# [I 2026-02-01 05:19:28,409] Trial 18 finished with value: 0.9009603561060341 and parameters: {'model_name': 'random_forest', 'n_estimators': 21, 'max_depth': 6, 'min_samples_split': 5, 'min_samples_leaf': 3}. Best is trial 17 with value: 0.9022322846027624.
# [I 2026-02-01 05:19:28,916] Trial 19 pruned.
# [I 2026-02-01 05:19:29,347] Trial 20 pruned.
# [I 2026-02-01 05:19:30,778] Trial 22 finished with value: 0.8997691424748776 and parameters: {'model_name': 'random_forest', 'n_estimators': 20, 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 4}. Best is trial 17 with value: 0.9022322846027624.
# [I 2026-02-01 05:19:30,886] Trial 21 finished with value: 0.9010258522826419 and parameters: {'model_name': 'random_forest', 'n_estimators': 27, 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 5}. Best is trial 17 with value: 0.9022322846027624.
# [I 2026-02-01 05:19:32,515] Trial 23 finished with value: 0.9023023126016464 and parameters: {'model_name': 'random_forest', 'n_estimators': 26, 'max_depth': 8, 'min_samples_split': 7, 'min_samples_leaf': 2}. Best is trial 23 with value: 0.9023023126016464.
# [I 2026-02-01 05:19:32,584] Trial 24 finished with value: 0.902390424173546 and parameters: {'model_name': 'random_forest', 'n_estimators': 24, 'max_depth': 8, 'min_samples_split': 7, 'min_samples_leaf': 2}. Best is trial 24 with value: 0.902390424173546.
# [I 2026-02-01 05:19:33,665] Trial 25 pruned.
# [I 2026-02-01 05:19:33,669] Trial 26 pruned.
# [I 2026-02-01 05:19:33,980] Trial 27 pruned.
# [I 2026-02-01 05:19:34,265] Trial 28 pruned.
# [I 2026-02-01 05:19:34,440] Trial 29 pruned.

# %% [markdown]
# #### Conferir checkpoints intermediarios

# %% [markdown]
# Consolida os resultados da validação cruzada externa em um DataFrame,
# salva o resumo em formato Parquet e carrega os logs das trials do Optuna
# para inspeção e análise do processo de otimização.

# %%
df_results=pd.DataFrame(df_results)

# %%
df_results.to_parquet('df_results.parquet')

# %%
df_metrics = pd.read_csv('log_opt/trials_log_v2.csv')
display(df_metrics)
# Out:
#     number     value  params_C  params_colsample_bytree  params_learning_rate  \
# 0        0  0.901321       NaN                      NaN                   NaN
# 1        1  0.892334       NaN                 0.978767              0.060960
# 2        2  0.897195       NaN                      NaN                   NaN
# 3        3  0.884311       NaN                 0.749596              0.084601
# 4        4  0.897263       NaN                 0.727429              0.115507
# 5        5  0.874613       NaN                 0.986076              0.051519
# 6        6  0.891997  2.019184                      NaN                   NaN
# 7        7  0.892804       NaN                 0.823047              0.124383
# 8        8  0.868708       NaN                 0.894627              0.171022
# 9        9  0.889705       NaN                      NaN                   NaN
# 10      10  0.892000  1.142994                      NaN                   NaN
# 11      11  0.900145       NaN                      NaN                   NaN
# 12      12  0.900226       NaN                      NaN                   NaN
# 13      13  0.900226       NaN                      NaN                   NaN
# 14      14  0.907084       NaN                      NaN                   NaN
# 15      15  0.901264       NaN                      NaN                   NaN
# 16      16  0.901291       NaN                      NaN                   NaN
# 17      17  0.902232       NaN                      NaN                   NaN
# 18      18  0.900960       NaN                      NaN                   NaN
# 19      19  0.892041  0.373297                      NaN                   NaN
# 20      20  0.892064  0.229287                      NaN                   NaN
# 21      21  0.901026       NaN                      NaN                   NaN
# 22      22  0.899769       NaN                      NaN                   NaN
# 23      23  0.902302       NaN                      NaN                   NaN
# 24      24  0.902390       NaN                      NaN                   NaN
# 25      25  0.908144       NaN                      NaN                   NaN
# 26      26  0.907691       NaN                      NaN                   NaN
# 27      27  0.897554       NaN                 0.518594              0.292541
# 28      28  0.900896       NaN                 0.500624              0.294708
# 29      29  0.894137       NaN                 0.512719              0.217872
#
#     params_max_depth  params_min_samples_leaf  params_min_samples_split  \
# 0                7.0                      1.0                       9.0
# 1                4.0                      NaN                       NaN
# 2                4.0                      1.0                      10.0
# 3                5.0                      NaN                       NaN
# 4                7.0                      NaN                       NaN
# 5                5.0                      NaN                       NaN
# 6                NaN                      NaN                       NaN
# 7                7.0                      NaN                       NaN
# 8                8.0                      NaN                       NaN
# 9                3.0                      5.0                       4.0
# 10               NaN                      NaN                       NaN
# 11               9.0                      1.0                       9.0
# 12               9.0                      1.0                       9.0
# 13               9.0                      1.0                       9.0
# 14               9.0                      1.0                       7.0
# 15               7.0                      3.0                       7.0
# 16               7.0                      3.0                       7.0
# 17               7.0                      3.0                       6.0
# 18               6.0                      3.0                       5.0
# 19               NaN                      NaN                       NaN
# 20               NaN                      NaN                       NaN
# 21               6.0                      5.0                       2.0
# 22               6.0                      4.0                       2.0
# 23               8.0                      2.0                       7.0
# 24               8.0                      2.0                       7.0
# 25               8.0                      2.0                       6.0
# 26               8.0                      2.0                       6.0
# 27               8.0                      NaN                       NaN
# 28               8.0                      NaN                       NaN
# 29               8.0                      NaN                       NaN
#
#    params_model_name  params_n_estimators  params_subsample     state  \
# 0      random_forest                 27.0               NaN  COMPLETE
# 1           lightgbm                  6.0          0.508861  COMPLETE
# 2      random_forest                 17.0               NaN  COMPLETE
# 3            xgboost                 15.0          0.824513  COMPLETE
# 4           lightgbm                 14.0          0.591407  COMPLETE
# 5            xgboost                 16.0          0.931965    PRUNED
# 6                svm                  NaN               NaN    PRUNED
# 7           lightgbm                 11.0          0.917074    PRUNED
# 8            xgboost                  7.0          0.745050    PRUNED
# 9      random_forest                 25.0               NaN    PRUNED
# 10               svm                  NaN               NaN    PRUNED
# 11     random_forest                 29.0               NaN  COMPLETE
# 12     random_forest                 30.0               NaN  COMPLETE
# 13     random_forest                 30.0               NaN  COMPLETE
# 14     random_forest                 23.0               NaN    PRUNED
# 15     random_forest                 30.0               NaN  COMPLETE
# 16     random_forest                 22.0               NaN  COMPLETE
# 17     random_forest                 22.0               NaN  COMPLETE
# 18     random_forest                 21.0               NaN  COMPLETE
# 19               svm                  NaN               NaN    PRUNED
# 20               svm                  NaN               NaN    PRUNED
# 21     random_forest                 27.0               NaN  COMPLETE
# 22     random_forest                 20.0               NaN  COMPLETE
# 23     random_forest                 26.0               NaN  COMPLETE
# 24     random_forest                 24.0               NaN  COMPLETE
# 25     random_forest                 25.0               NaN    PRUNED
# 26     random_forest                 24.0               NaN    PRUNED
# 27          lightgbm                 19.0          0.701486    PRUNED
# 28          lightgbm                 19.0          0.681885    PRUNED
# 29           xgboost                 26.0          0.983416    PRUNED
#
#                   duration
# 0   0 days 00:00:01.650689
# 1   0 days 00:00:00.545389
# 2   0 days 00:00:00.797118
# 3   0 days 00:00:01.024489
# 4   0 days 00:00:00.793806
# 5   0 days 00:00:00.552528
# 6   0 days 00:00:00.502707
# 7   0 days 00:00:00.241444
# 8   0 days 00:00:00.355250
# 9   0 days 00:00:00.369334
# 10  0 days 00:00:00.526929
# 11  0 days 00:00:02.230356
# 12  0 days 00:00:02.226925
# 13  0 days 00:00:02.209781
# 14  0 days 00:00:01.172773
# 15  0 days 00:00:01.711587
# 16  0 days 00:00:01.344035
# 17  0 days 00:00:02.050251
# 18  0 days 00:00:02.121906
# 19  0 days 00:00:00.957254
# 20  0 days 00:00:00.905979
# 21  0 days 00:00:01.942730
# 22  0 days 00:00:01.407118
# 23  0 days 00:00:01.727255
# 24  0 days 00:00:01.687812
# 25  0 days 00:00:01.135755
# 26  0 days 00:00:01.074205
# 27  0 days 00:00:00.300481
# 28  0 days 00:00:00.580702
# 29  0 days 00:00:00.442455

# %% [markdown]
# Carregando o pkl

# %%
import joblib

modelo = joblib.load("checkpoints_best_models/best_model_fold_1.pkl")

# %%
modelo
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['NU_IDADE_N']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='infrequent_if_exist'))]),
#                                                   ['ANT_CB_LAM', 'CLI_ICTERI',
#                                                    'CLI_PANTUR', 'CLI_PROST',
#                                                    'CLI_RENAL', 'CLI_VOMITO',
#                                                    'CON_AMBIEN', 'CON_AREA',
#                                                    'CS_ESCOL_N', 'CS_RACA',
#                                                    'estacao'])])),
#                 ('smote', SMOTE(random_state=42)),
#                 ('model',
#                  CalibratedClassifierCV(estimator=LinearSVC(C=0.13860008781807281,
#                                                             class_weight='balanced',
#                                                             max_iter=5000)))])

# %%
modelo.named_steps["preprocessor"].get_feature_names_out()
# Out:
# array(['num__NU_IDADE_N', 'cat__ANT_CB_LAM_Não',
#        'cat__ANT_CB_LAM_Não informado', 'cat__ANT_CB_LAM_Sim',
#        'cat__CLI_ICTERI_Não', 'cat__CLI_ICTERI_Não informado',
#        'cat__CLI_ICTERI_Sim', 'cat__CLI_PANTUR_Não',
#        'cat__CLI_PANTUR_Não informado', 'cat__CLI_PANTUR_Sim',
#        'cat__CLI_PROST_Não', 'cat__CLI_PROST_Não informado',
#        'cat__CLI_PROST_Sim', 'cat__CLI_RENAL_Não',
#        'cat__CLI_RENAL_Não informado', 'cat__CLI_RENAL_Sim',
#        'cat__CLI_VOMITO_Não', 'cat__CLI_VOMITO_Não informado',
#        'cat__CLI_VOMITO_Sim', 'cat__CON_AMBIEN_Domicílio',
#        'cat__CON_AMBIEN_Lazer', 'cat__CON_AMBIEN_Não informado',
#        'cat__CON_AMBIEN_Outro', 'cat__CON_AMBIEN_Trabalho',
#        'cat__CON_AREA_Não informado', 'cat__CON_AREA_Periurbana',
#        'cat__CON_AREA_Rural', 'cat__CON_AREA_Urbana',
#        'cat__CS_ESCOL_N_10',
#        'cat__CS_ESCOL_N_1ª a 4ª série incompleta do EF',
#        'cat__CS_ESCOL_N_4ª série completa do EF',
#        'cat__CS_ESCOL_N_5ª a 8ª série incompleta do EF',
#        'cat__CS_ESCOL_N_Ensino fundamental completo',
#        'cat__CS_ESCOL_N_Ensino médio completo',
#        'cat__CS_ESCOL_N_Ensino médio incompleto',
#        'cat__CS_ESCOL_N_Não informado',
#        'cat__CS_ESCOL_N_Sem escolaridade',
#        'cat__CS_ESCOL_N_Superior completo',
#        'cat__CS_ESCOL_N_Superior incompleto', 'cat__CS_RACA_Amarela',
#        'cat__CS_RACA_Branca', 'cat__CS_RACA_Indígena',
#        'cat__CS_RACA_Não informado', 'cat__CS_RACA_Parda',
#        'cat__CS_RACA_Preta', 'cat__estacao_Inverno',
#        'cat__estacao_Outono', 'cat__estacao_Primavera',
#        'cat__estacao_Verão'], dtype=object)

# %%
modelo.predict(X_data.iloc[-10:])
# Out:
# array([1, 1, 1, 1, 1, 0, 1, 0, 0, 1])

# %% [markdown]
# ## Avaliação de desempenho e custo computacional
#
# Nesta seção são avaliados os modelos selecionados ao longo dos folds da validação cruzada externa,
# considerando simultaneamente **qualidade preditiva** e **custo computacional**.
# Essa análise conjunta é fundamental para evitar escolhas baseadas apenas em desempenho,
# desconsiderando viabilidade prática de treinamento e manutenção do modelo.
#
# ### Métricas de desempenho preditivo
#
# O desempenho dos modelos é avaliado por meio de múltiplas métricas,
# permitindo uma análise abrangente do comportamento preditivo:
#
# - **ROC-AUC (OvR, weighted)**: métrica principal de comparação, pois avalia a capacidade de separação entre classes
# em cenários multiclasse e desbalanceados, utilizando probabilidades preditas.
# - **Accuracy**: fornece uma visão global de acerto, mas pode ser influenciada por classes majoritárias.
# - **F1-score (weighted)**: equilibra precisão e recall, sendo mais informativo quando há assimetria entre classes.
# - **Recall (weighted)**: mede a capacidade do modelo em identificar corretamente instâncias relevantes,
# importante em contextos onde falsos negativos possuem maior custo.
# - **Precision (weighted)**: avalia a confiabilidade das predições positivas,
# sendo relevante quando falsos positivos impactam decisões downstream.
#
# A análise por fold permite verificar não apenas o valor médio das métricas,
# mas também sua **estabilidade**, reduzindo o risco de overfitting a uma partição específica dos dados.

# %%
# 2. Basic overview
print("=== Shape of DataFrame ===")
print(df_metrics.shape)

display(df_metrics)
# Out:
# === Shape of DataFrame ===
# (30, 13)
#     number     value  params_C  params_colsample_bytree  params_learning_rate  \
# 0        0  0.901321       NaN                      NaN                   NaN
# 1        1  0.892334       NaN                 0.978767              0.060960
# 2        2  0.897195       NaN                      NaN                   NaN
# 3        3  0.884311       NaN                 0.749596              0.084601
# 4        4  0.897263       NaN                 0.727429              0.115507
# 5        5  0.874613       NaN                 0.986076              0.051519
# 6        6  0.891997  2.019184                      NaN                   NaN
# 7        7  0.892804       NaN                 0.823047              0.124383
# 8        8  0.868708       NaN                 0.894627              0.171022
# 9        9  0.889705       NaN                      NaN                   NaN
# 10      10  0.892000  1.142994                      NaN                   NaN
# 11      11  0.900145       NaN                      NaN                   NaN
# 12      12  0.900226       NaN                      NaN                   NaN
# 13      13  0.900226       NaN                      NaN                   NaN
# 14      14  0.907084       NaN                      NaN                   NaN
# 15      15  0.901264       NaN                      NaN                   NaN
# 16      16  0.901291       NaN                      NaN                   NaN
# 17      17  0.902232       NaN                      NaN                   NaN
# 18      18  0.900960       NaN                      NaN                   NaN
# 19      19  0.892041  0.373297                      NaN                   NaN
# 20      20  0.892064  0.229287                      NaN                   NaN
# 21      21  0.901026       NaN                      NaN                   NaN
# 22      22  0.899769       NaN                      NaN                   NaN
# 23      23  0.902302       NaN                      NaN                   NaN
# 24      24  0.902390       NaN                      NaN                   NaN
# 25      25  0.908144       NaN                      NaN                   NaN
# 26      26  0.907691       NaN                      NaN                   NaN
# 27      27  0.897554       NaN                 0.518594              0.292541
# 28      28  0.900896       NaN                 0.500624              0.294708
# 29      29  0.894137       NaN                 0.512719              0.217872
#
#     params_max_depth  params_min_samples_leaf  params_min_samples_split  \
# 0                7.0                      1.0                       9.0
# 1                4.0                      NaN                       NaN
# 2                4.0                      1.0                      10.0
# 3                5.0                      NaN                       NaN
# 4                7.0                      NaN                       NaN
# 5                5.0                      NaN                       NaN
# 6                NaN                      NaN                       NaN
# 7                7.0                      NaN                       NaN
# 8                8.0                      NaN                       NaN
# 9                3.0                      5.0                       4.0
# 10               NaN                      NaN                       NaN
# 11               9.0                      1.0                       9.0
# 12               9.0                      1.0                       9.0
# 13               9.0                      1.0                       9.0
# 14               9.0                      1.0                       7.0
# 15               7.0                      3.0                       7.0
# 16               7.0                      3.0                       7.0
# 17               7.0                      3.0                       6.0
# 18               6.0                      3.0                       5.0
# 19               NaN                      NaN                       NaN
# 20               NaN                      NaN                       NaN
# 21               6.0                      5.0                       2.0
# 22               6.0                      4.0                       2.0
# 23               8.0                      2.0                       7.0
# 24               8.0                      2.0                       7.0
# 25               8.0                      2.0                       6.0
# 26               8.0                      2.0                       6.0
# 27               8.0                      NaN                       NaN
# 28               8.0                      NaN                       NaN
# 29               8.0                      NaN                       NaN
#
#    params_model_name  params_n_estimators  params_subsample     state  \
# 0      random_forest                 27.0               NaN  COMPLETE
# 1           lightgbm                  6.0          0.508861  COMPLETE
# 2      random_forest                 17.0               NaN  COMPLETE
# 3            xgboost                 15.0          0.824513  COMPLETE
# 4           lightgbm                 14.0          0.591407  COMPLETE
# 5            xgboost                 16.0          0.931965    PRUNED
# 6                svm                  NaN               NaN    PRUNED
# 7           lightgbm                 11.0          0.917074    PRUNED
# 8            xgboost                  7.0          0.745050    PRUNED
# 9      random_forest                 25.0               NaN    PRUNED
# 10               svm                  NaN               NaN    PRUNED
# 11     random_forest                 29.0               NaN  COMPLETE
# 12     random_forest                 30.0               NaN  COMPLETE
# 13     random_forest                 30.0               NaN  COMPLETE
# 14     random_forest                 23.0               NaN    PRUNED
# 15     random_forest                 30.0               NaN  COMPLETE
# 16     random_forest                 22.0               NaN  COMPLETE
# 17     random_forest                 22.0               NaN  COMPLETE
# 18     random_forest                 21.0               NaN  COMPLETE
# 19               svm                  NaN               NaN    PRUNED
# 20               svm                  NaN               NaN    PRUNED
# 21     random_forest                 27.0               NaN  COMPLETE
# 22     random_forest                 20.0               NaN  COMPLETE
# 23     random_forest                 26.0               NaN  COMPLETE
# 24     random_forest                 24.0               NaN  COMPLETE
# 25     random_forest                 25.0               NaN    PRUNED
# 26     random_forest                 24.0               NaN    PRUNED
# 27          lightgbm                 19.0          0.701486    PRUNED
# 28          lightgbm                 19.0          0.681885    PRUNED
# 29           xgboost                 26.0          0.983416    PRUNED
#
#                   duration
# 0   0 days 00:00:01.650689
# 1   0 days 00:00:00.545389
# 2   0 days 00:00:00.797118
# 3   0 days 00:00:01.024489
# 4   0 days 00:00:00.793806
# 5   0 days 00:00:00.552528
# 6   0 days 00:00:00.502707
# 7   0 days 00:00:00.241444
# 8   0 days 00:00:00.355250
# 9   0 days 00:00:00.369334
# 10  0 days 00:00:00.526929
# 11  0 days 00:00:02.230356
# 12  0 days 00:00:02.226925
# 13  0 days 00:00:02.209781
# 14  0 days 00:00:01.172773
# 15  0 days 00:00:01.711587
# 16  0 days 00:00:01.344035
# 17  0 days 00:00:02.050251
# 18  0 days 00:00:02.121906
# 19  0 days 00:00:00.957254
# 20  0 days 00:00:00.905979
# 21  0 days 00:00:01.942730
# 22  0 days 00:00:01.407118
# 23  0 days 00:00:01.727255
# 24  0 days 00:00:01.687812
# 25  0 days 00:00:01.135755
# 26  0 days 00:00:01.074205
# 27  0 days 00:00:00.300481
# 28  0 days 00:00:00.580702
# 29  0 days 00:00:00.442455

# %%
df_metrics
# Out:
#     number     value  params_C  params_colsample_bytree  params_learning_rate  \
# 0        0  0.901321       NaN                      NaN                   NaN
# 1        1  0.892334       NaN                 0.978767              0.060960
# 2        2  0.897195       NaN                      NaN                   NaN
# 3        3  0.884311       NaN                 0.749596              0.084601
# 4        4  0.897263       NaN                 0.727429              0.115507
# 5        5  0.874613       NaN                 0.986076              0.051519
# 6        6  0.891997  2.019184                      NaN                   NaN
# 7        7  0.892804       NaN                 0.823047              0.124383
# 8        8  0.868708       NaN                 0.894627              0.171022
# 9        9  0.889705       NaN                      NaN                   NaN
# 10      10  0.892000  1.142994                      NaN                   NaN
# 11      11  0.900145       NaN                      NaN                   NaN
# 12      12  0.900226       NaN                      NaN                   NaN
# 13      13  0.900226       NaN                      NaN                   NaN
# 14      14  0.907084       NaN                      NaN                   NaN
# 15      15  0.901264       NaN                      NaN                   NaN
# 16      16  0.901291       NaN                      NaN                   NaN
# 17      17  0.902232       NaN                      NaN                   NaN
# 18      18  0.900960       NaN                      NaN                   NaN
# 19      19  0.892041  0.373297                      NaN                   NaN
# 20      20  0.892064  0.229287                      NaN                   NaN
# 21      21  0.901026       NaN                      NaN                   NaN
# 22      22  0.899769       NaN                      NaN                   NaN
# 23      23  0.902302       NaN                      NaN                   NaN
# 24      24  0.902390       NaN                      NaN                   NaN
# 25      25  0.908144       NaN                      NaN                   NaN
# 26      26  0.907691       NaN                      NaN                   NaN
# 27      27  0.897554       NaN                 0.518594              0.292541
# 28      28  0.900896       NaN                 0.500624              0.294708
# 29      29  0.894137       NaN                 0.512719              0.217872
#
#     params_max_depth  params_min_samples_leaf  params_min_samples_split  \
# 0                7.0                      1.0                       9.0
# 1                4.0                      NaN                       NaN
# 2                4.0                      1.0                      10.0
# 3                5.0                      NaN                       NaN
# 4                7.0                      NaN                       NaN
# 5                5.0                      NaN                       NaN
# 6                NaN                      NaN                       NaN
# 7                7.0                      NaN                       NaN
# 8                8.0                      NaN                       NaN
# 9                3.0                      5.0                       4.0
# 10               NaN                      NaN                       NaN
# 11               9.0                      1.0                       9.0
# 12               9.0                      1.0                       9.0
# 13               9.0                      1.0                       9.0
# 14               9.0                      1.0                       7.0
# 15               7.0                      3.0                       7.0
# 16               7.0                      3.0                       7.0
# 17               7.0                      3.0                       6.0
# 18               6.0                      3.0                       5.0
# 19               NaN                      NaN                       NaN
# 20               NaN                      NaN                       NaN
# 21               6.0                      5.0                       2.0
# 22               6.0                      4.0                       2.0
# 23               8.0                      2.0                       7.0
# 24               8.0                      2.0                       7.0
# 25               8.0                      2.0                       6.0
# 26               8.0                      2.0                       6.0
# 27               8.0                      NaN                       NaN
# 28               8.0                      NaN                       NaN
# 29               8.0                      NaN                       NaN
#
#    params_model_name  params_n_estimators  params_subsample     state  \
# 0      random_forest                 27.0               NaN  COMPLETE
# 1           lightgbm                  6.0          0.508861  COMPLETE
# 2      random_forest                 17.0               NaN  COMPLETE
# 3            xgboost                 15.0          0.824513  COMPLETE
# 4           lightgbm                 14.0          0.591407  COMPLETE
# 5            xgboost                 16.0          0.931965    PRUNED
# 6                svm                  NaN               NaN    PRUNED
# 7           lightgbm                 11.0          0.917074    PRUNED
# 8            xgboost                  7.0          0.745050    PRUNED
# 9      random_forest                 25.0               NaN    PRUNED
# 10               svm                  NaN               NaN    PRUNED
# 11     random_forest                 29.0               NaN  COMPLETE
# 12     random_forest                 30.0               NaN  COMPLETE
# 13     random_forest                 30.0               NaN  COMPLETE
# 14     random_forest                 23.0               NaN    PRUNED
# 15     random_forest                 30.0               NaN  COMPLETE
# 16     random_forest                 22.0               NaN  COMPLETE
# 17     random_forest                 22.0               NaN  COMPLETE
# 18     random_forest                 21.0               NaN  COMPLETE
# 19               svm                  NaN               NaN    PRUNED
# 20               svm                  NaN               NaN    PRUNED
# 21     random_forest                 27.0               NaN  COMPLETE
# 22     random_forest                 20.0               NaN  COMPLETE
# 23     random_forest                 26.0               NaN  COMPLETE
# 24     random_forest                 24.0               NaN  COMPLETE
# 25     random_forest                 25.0               NaN    PRUNED
# 26     random_forest                 24.0               NaN    PRUNED
# 27          lightgbm                 19.0          0.701486    PRUNED
# 28          lightgbm                 19.0          0.681885    PRUNED
# 29           xgboost                 26.0          0.983416    PRUNED
#
#                   duration
# 0   0 days 00:00:01.650689
# 1   0 days 00:00:00.545389
# 2   0 days 00:00:00.797118
# 3   0 days 00:00:01.024489
# 4   0 days 00:00:00.793806
# 5   0 days 00:00:00.552528
# 6   0 days 00:00:00.502707
# 7   0 days 00:00:00.241444
# 8   0 days 00:00:00.355250
# 9   0 days 00:00:00.369334
# 10  0 days 00:00:00.526929
# 11  0 days 00:00:02.230356
# 12  0 days 00:00:02.226925
# 13  0 days 00:00:02.209781
# 14  0 days 00:00:01.172773
# 15  0 days 00:00:01.711587
# 16  0 days 00:00:01.344035
# 17  0 days 00:00:02.050251
# 18  0 days 00:00:02.121906
# 19  0 days 00:00:00.957254
# 20  0 days 00:00:00.905979
# 21  0 days 00:00:01.942730
# 22  0 days 00:00:01.407118
# 23  0 days 00:00:01.727255
# 24  0 days 00:00:01.687812
# 25  0 days 00:00:01.135755
# 26  0 days 00:00:01.074205
# 27  0 days 00:00:00.300481
# 28  0 days 00:00:00.580702
# 29  0 days 00:00:00.442455

# %%
# Total de trials por modelo
total_trials = (df_metrics.groupby("params_model_name").size().reset_index(name="total_trials"))

plt.figure(figsize=(8, 6))
sns.barplot(data=total_trials,x="params_model_name",y="total_trials",)
plt.title("Total de tentativas por modelo")
plt.xlabel("Modelo")
plt.ylabel("Tentativas")
plt.tight_layout()
plt.show()

# %%
# Gráfico das tentativas de modelos completas e abortadas
counts_state = df_metrics.groupby(["params_model_name", "state"]).size().reset_index(name="count")

plt.figure(figsize=(8, 6))
sns.barplot(data=counts_state,x="params_model_name",y="count",hue="state",)
plt.title("Resultado das tentativas entre Pruned e Complete")
plt.xlabel("Modelo")
plt.ylabel("Número de tentativas")
plt.tight_layout()
plt.show()

# %%
# Distribuição de performance (value) por modelo
plt.figure(figsize=(8, 6))
sns.boxplot(data=df_metrics, x="params_model_name", y="value")
plt.title("Desempenho por modelo")
plt.xlabel("Modelo")
plt.ylabel("Área por baixo da curva ROC (AUC)")
plt.tight_layout()
plt.show()

# %%
# Duração média de treino por modelo
df_metrics["duration_sec"] = pd.to_timedelta(df_metrics["duration"]).dt.total_seconds()
mean_duration = df_metrics.groupby("params_model_name")["duration_sec"].mean().reset_index()

# Distribuição do tempo de processamento por modelo

plt.figure(figsize=(8, 6))
sns.boxplot(data=df_metrics, x="params_model_name", y="duration_sec")
plt.title("Média do tempo de treinamento por modelo")
plt.xlabel("Modelo")
plt.ylabel("Segundos")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Treinamento do modelo final

# %%
df_hyper =pd.DataFrame(df_results['hyperparameters'].to_list())
df_hyper
# Out:
#       model_name       C  n_estimators  max_depth  learning_rate  subsample  \
# 0            svm  0.1386           NaN        NaN            NaN        NaN
# 1        xgboost     NaN          28.0        4.0       0.294272   0.940922
# 2       lightgbm     NaN          19.0        5.0       0.226870   0.601005
# 3        xgboost     NaN          26.0        8.0       0.205768   0.826001
# 4  random_forest     NaN          24.0        8.0            NaN        NaN
#
#    colsample_bytree  min_samples_split  min_samples_leaf
# 0               NaN                NaN               NaN
# 1          0.917343                NaN               NaN
# 2          0.736482                NaN               NaN
# 3          0.772096                NaN               NaN
# 4               NaN                7.0               2.0

# %%
final_params=df_hyper.iloc[:,1:].median().to_dict()
final_params
# Out:
# {'C': 0.13860008781807281,
#  'n_estimators': 25.0,
#  'max_depth': 6.5,
#  'learning_rate': 0.22687022759237022,
#  'subsample': 0.8260006415910568,
#  'colsample_bytree': 0.7720957124951093,
#  'min_samples_split': 7.0,
#  'min_samples_leaf': 2.0}

# %%
final_params = {'n_estimators': 26,
 'learning_rate': 0.226,
 'max_depth': 7,
 'subsample': 0.662,
 'colsample_bytree': 0.6968}

# %%
# Dicionário base para reconstrução
models = {
    'RandomForest': RandomForestClassifier(random_state=42),
    'XGBoost': xgb.XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42),
    'LightGBM': lgb.LGBMClassifier(random_state=42),
    'SVM': CalibratedClassifierCV(LinearSVC( random_state=42))
}

# %%
# Reconstruir modelo
final_model = models['LightGBM']
final_model.set_params(**final_params)

cat_cols, num_cols = get_feature_types(X_data)

final_pipeline = build_pipeline(final_model, cat_cols, num_cols)

# %% [markdown]
# ### Avaliando modelo final

# %% [markdown]
# ## Interpretabilidade: importância de variáveis após pré-processamento (OHE) e mapeamento para colunas originais
#
# Modelos treinados sobre pipelines com `ColumnTransformer` e `OneHotEncoder` operam em um espaço de features
# expandido (múltiplas colunas por variável categórica). Para manter interpretabilidade, esta seção:
# 1) recupera os nomes finais das features no espaço transformado,
# 2) extrai uma medida de importância/coeficiente do modelo treinado,
# 3) mapeia as features transformadas de volta para as variáveis originais,
# 4) consolida a importância no nível da coluna original.
#
# Isso permite reportar resultados em termos das variáveis do dataset original, facilitando comunicação e análise.

# %% [markdown]
# ### Extração de nomes das features pós-`ColumnTransformer`
#
# A função `get_feature_names` reconstrói o vetor de nomes de features gerado após o pré-processamento,
# incluindo:
# - variáveis numéricas (após imputação/escala),
# - variáveis categóricas expandidas via One-Hot Encoding,
# - e, opcionalmente, colunas passadas via `remainder='passthrough'`.
#
# Essa etapa é necessária porque, após o `fit_transform`, a matriz final perde o vínculo direto com o nome
# das colunas originais, e a identificação correta das features é condição para qualquer análise de importância.

# %%
# 1. FUNÇÃO PARA EXTRAIR NOMES DAS FEATURES PÓS-OHE
def get_feature_names(column_transformer):
    """
    Extrai nomes finais das features após ColumnTransformer,
    incluindo OneHotEncoder e transformações numéricas.
    """
    output_features = []

    for name, transformer, features in column_transformer.transformers_:

        # Caso 'remainder=passthrough'
        if name == "remainder":
            output_features.extend(features)
            continue

        # Transformers com get_feature_names_out() (OneHotEncoder, etc)
        if hasattr(transformer, "get_feature_names_out"):
            try:
                names = transformer.get_feature_names_out(features)
            except:
                names = transformer.get_feature_names_out()
            output_features.extend(names)

        # Caso não possua o método
        else:
            output_features.extend(features)

    return output_features

# %%
def fuzzy_match_original(feature_name, triage_features, threshold=70):
    """
    Realiza fuzzy matching buscando qual variável ORIGINAL
    está mais relacionada com o nome da feature pós-OHE.
    """
    best_match, score, _ = process.extractOne(
        feature_name,
        triage_features,
        scorer=fuzz.partial_ratio
    )
    return best_match if score >= threshold else None

# %%
n_splits = 4
outer_cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
results = []
fold = 1
for train_idx, test_idx in outer_cv.split(X_data, y_data):

    print(f"\n==============================")
    print(f"  Fold Externo {fold}/{n_splits}")
    print(f"==============================")

    X_train, X_test = X_data.iloc[train_idx], X_data.iloc[test_idx]
    y_train, y_test = y_data.iloc[train_idx], y_data.iloc[test_idx]

    # Treinando o pipeline final com todo o conjunto de dados
    final_pipeline.fit(X_train,y_train)


    model = final_pipeline.named_steps["model"]   # <-- trocado aqui

    if hasattr(model, "feature_importances_"):
        importances = model.feature_importances_

    elif hasattr(model, "coef_"):
        importances = model.coef_.ravel()

    else:
        raise ValueError("Este modelo não possui atributo de importância.")



    # 3. DF DE IMPORTÂNCIAS COM FEATURES PÓS-PREPROCESSAMENTO


    preproc = final_pipeline.named_steps["preprocessor"]   # <-- trocado aqui
    feature_names = get_feature_names(preproc)

    df_imp = pd.DataFrame({
        "feature": feature_names,
        "importance": importances
    })


    # 5. APLICA FUZZY MATCH EM TODAS AS FEATURES
    df_imp["original_var"] = df_imp["feature"].apply(
        lambda x: fuzzy_match_original(x, triage_features)
    )

    # Remove features que não encontraram correspondência
    df_imp = df_imp[df_imp["original_var"].notna()].copy()

    # 6. AGRUPA IMPORTÂNCIA POR VARIÁVEL ORIGINAL


    df_grouped = (
        df_imp.groupby("original_var")["importance"]
              .sum()
              .sort_values(ascending=False)
              .reset_index()
    )
    df_grouped.rename({'original_var':'feature'},axis=1,inplace=True)

    #Plotando o gráfico
    plt.figure(figsize=(6, 14))
    plt.barh(df_grouped["feature"][::-1],
            df_grouped["importance"][::-1])
    plt.xlabel("Importância")
    plt.title(f"Features importance – {type(model).__name__}")
    plt.tight_layout()
    plt.show()



    # Gerar previsões finais
    y_pred = final_pipeline.predict(X_test)
    y_proba = final_pipeline.predict_proba(X_test)[:, 1] if hasattr(final_model, "predict_proba") else None

    # Matriz de confusão
    cm = confusion_matrix(y_test, y_pred)

    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.title("Matriz de Confusão - Dados Completos")
    plt.xlabel("Predito")
    plt.ylabel("Real")
    plt.show()

    # Barplot com métricas
    metrics_dict = {
        "Accuracy": accuracy_score(y_test, y_pred),
        "Precision": precision_score(y_test, y_pred),
        "Recall": recall_score(y_test, y_pred),
        "F1 Score": f1_score(y_test, y_pred),
        "AUC": roc_auc_score(y_test, y_proba) if y_proba is not None else np.nan
    }

    plt.figure(figsize=(8, 5))
    sns.barplot(x=list(metrics_dict.keys()), y=list(metrics_dict.values()), palette="Set2")
    plt.ylim(0, 1.05)
    plt.title("Métricas de Classificação - Dados Completos")
    for i, v in enumerate(metrics_dict.values()):
        plt.text(i, v + 0.02, f"{v:.2f}", ha='center')
    plt.grid(True)
    plt.show()

    # Curva ROC
    if y_proba is not None:
        fpr, tpr, _ = roc_curve(y_test, y_proba)
        roc_auc = auc(fpr, tpr)

        plt.figure(figsize=(6, 5))
        plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.2f}")
        plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
        plt.xlabel("Falso Positivo")
        plt.ylabel("Verdadeiro Positivo")
        plt.title("Curva ROC")
        plt.legend(loc='lower right')
        plt.grid(True)
        plt.show()

    # Curva Precision-Recall
    if y_proba is not None:
        precision, recall, _ = precision_recall_curve(y_test, y_proba)
        auprc_trap = auc(recall, precision)
        plt.figure(figsize=(6, 5))
        plt.plot(recall, precision, label=f"AUPRC = {auprc_trap:.2f}")
        plt.xlabel("Recall")
        plt.ylabel("Precision")
        plt.title("Curva Precision-Recall")
        plt.legend(loc='lower right')
        plt.grid(True)
        plt.show()
# Out:
# ==============================
#   Fold Externo 1/4
# ==============================
# [LightGBM] [Info] Number of positive: 4717, number of negative: 4717
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003844 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 8520
# [LightGBM] [Info] Number of data points in the train set: 9434, number of used features: 49
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ==============================
#   Fold Externo 1/4
# ==============================
# [LightGBM] [Info] Number of positive: 4717, number of negative: 4717
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.016345 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 8288
# [LightGBM] [Info] Number of data points in the train set: 9434, number of used features: 49
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# ==============================
#   Fold Externo 1/4
# ==============================
# [LightGBM] [Info] Number of positive: 4718, number of negative: 4718
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.030026 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 8302
# [LightGBM] [Info] Number of data points in the train set: 9436, number of used features: 49
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# ==============================
#   Fold Externo 1/4
# ==============================
# [LightGBM] [Info] Number of positive: 4718, number of negative: 4718
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.014288 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 8282
# [LightGBM] [Info] Number of data points in the train set: 9436, number of used features: 49
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
