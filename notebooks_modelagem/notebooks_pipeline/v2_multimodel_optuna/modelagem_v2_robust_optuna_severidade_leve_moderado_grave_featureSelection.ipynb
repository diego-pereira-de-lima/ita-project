# %%
# !pip uninstall xgboost -y
# Out:
# Found existing installation: xgboost 3.1.1
# Uninstalling xgboost-3.1.1:
#   Successfully uninstalled xgboost-3.1.1

# %%
# !pip install optuna xgboost==3.1.1 lightgbm fastparquet imbalanced-learn torch rapidfuzz
# Out:
# Requirement already satisfied: optuna in /usr/local/lib/python3.12/dist-packages (4.7.0)
# Collecting xgboost==3.1.1
#   Using cached xgboost-3.1.1-py3-none-manylinux_2_28_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.12/dist-packages (4.6.0)
# Requirement already satisfied: fastparquet in /usr/local/lib/python3.12/dist-packages (2025.12.0)
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.12/dist-packages (0.14.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.9.0+cpu)
# Requirement already satisfied: rapidfuzz in /usr/local/lib/python3.12/dist-packages (3.14.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from xgboost==3.1.1) (2.0.2)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.12/dist-packages (from xgboost==3.1.1) (2.29.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from xgboost==3.1.1) (1.16.3)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.18.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.12/dist-packages (from optuna) (6.10.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.46)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: pandas>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from fastparquet) (2.2.2)
# Requirement already satisfied: cramjam>=2.3 in /usr/local/lib/python3.12/dist-packages (from fastparquet) (2.11.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from fastparquet) (2025.3.0)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (1.6.1)
# Requirement already satisfied: sklearn-compat<0.2,>=0.1.5 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (0.1.5)
# Requirement already satisfied: joblib<2,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->fastparquet) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->fastparquet) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->fastparquet) (2025.3)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->fastparquet) (1.17.0)
# Using cached xgboost-3.1.1-py3-none-manylinux_2_28_x86_64.whl (115.9 MB)
# Installing collected packages: xgboost
# Successfully installed xgboost-3.1.1

# %%
import numpy as np
import pandas as pd
import os, joblib,time


from sklearn.model_selection import StratifiedKFold, cross_val_score,train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.calibration import CalibratedClassifierCV

import optuna
from optuna.pruners import SuccessiveHalvingPruner
from optuna.exceptions import TrialPruned

#from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.impute import SimpleImputer
from functools import partial


#Feature selection
from __future__ import annotations

from sklearn.model_selection import KFold, StratifiedKFold, cross_val_score
from sklearn.feature_selection import VarianceThreshold, SelectKBest
from sklearn.feature_selection import mutual_info_classif, mutual_info_regression
from sklearn.feature_selection import f_classif, f_regression

from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.multiclass import OneVsRestClassifier, OneVsOneClassifier

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler




from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, confusion_matrix, matthews_corrcoef,
    cohen_kappa_score, balanced_accuracy_score,
    classification_report, brier_score_loss, log_loss,
    confusion_matrix, ConfusionMatrixDisplay,
    precision_recall_curve, RocCurveDisplay,roc_curve,auc
)

from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE

import matplotlib.pyplot as plt
import seaborn as sns

import subprocess
import xgboost as xgb
import lightgbm as lgb
import torch

import re
from rapidfuzz import fuzz, process

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Carregando base de dados

# %% [markdown]
# Carregamento do conjunto de dados processado a partir de um arquivo no formato Parquet.
# Esse formato colunar é otimizado para leitura eficiente, reduz uso de memória e preserva os tipos de dados,
# sendo adequado para pipelines analíticos e etapas posteriores de modelagem.

# %%
df =pd.read_parquet('df_hepat_processed_v1.parquet',engine='fastparquet')

# %% [markdown]
# ### Selecionar variáveis relevantes para triagem

# %% [markdown]
# Definição das variáveis explicativas e da variável alvo utilizadas no modelo.
# As features incluem características sociodemográficas, condições ambientais, antecedentes clínicos e sintomas,
# além de variáveis derivadas de vulnerabilidade social e sazonalidade, enquanto a variável alvo representa a severidade do caso.

# %%
features_explicativas = [
    'NU_IDADE_N','CS_SEXO','CS_GESTANT','CS_RACA','CS_ESCOL_N',
    'ID_OCUPA_N','CON_AREA','CON_AMBIEN',
    'ANT_CB_LAM','ANT_CB_CRI','ANT_CB_SIN','ANT_CB_COR','ANT_CB_ROE',
    'ANT_CB_TER','ANT_CB_LIX','ANT_CB_OUT','ANT_ANIMAI','ANT_HUMANO',
    'CLI_FEBRE','CLI_MIALGI','CLI_CEFALE','CLI_PROST','CLI_CONGES',
    'CLI_PANTUR','CLI_VOMITO','CLI_DIARRE','CLI_OUTROS','SG_UF', 'baixa_escolaridade','raca_vulneravel','faixa_vulneravel',
    'vulnerabilidade_social', 'nivel_vulnerabilidade','mes_sintomas','estacao', 'periodo_chuvoso'
]

target = 'SEVERIDADE'

# %% [markdown]
# ### Classificação da Severidade da Leptospirose (variavel alvo **Forma Clinica**)
#
# * Classifica a severidade clínica dos casos de leptospirose com base em critérios médicos descritos na literatura, distinguindo entre formas leve, moderada e grave.
# * Cria variáveis auxiliares para identificar comprometimento de órgãos graves (respiratório, cardíaco e sistema nervoso central) e presença de hemorragias.
# * Define critérios de gravidade a partir da combinação de sinais clínicos como hemorragia pulmonar, disfunção renal associada, icterícia e envolvimento de múltiplos órgãos.
# * Identifica casos moderados a partir de manifestações como icterícia isolada, comprometimento renal leve e hemorragias cutâneas.
# * Converte a classificação categórica de severidade em rótulos numéricos (0 = Leve, 1 = Moderado, 2 = Grave), tornando a variável adequada para uso em modelos de machine learning.
# * Remove colunas clínicas e variáveis auxiliares utilizadas exclusivamente na lógica de classificação, garantindo um DataFrame final mais limpo e focado na modelagem.

# %%
def classificar_severidade_leptospirose(df):
    """
    Classificação de severidade da leptospirose
    Alinhada à definição clínica do artigo (leve, moderada, grave)
    Valores esperados: "Sim" / "Não"
    """

    # Flags auxiliares
    df["orgao_grave"] = (
        (df["CLI_RESPIR"] == "Sim") |
        (df["CLI_CARDIA"] == "Sim") |
        (df["CLI_MENING"] == "Sim")
    )

    df["hemorragia"] = (
        (df["CLI_HEMORR"] == "Sim") |
        (df["CLI_HEMOPU"] == "Sim")
    )

    # Critérios de gravidade
    criterio_grave = (
        (df["CLI_HEMOPU"] == "Sim") |                           # hemorragia pulmonar
        (df["CLI_RESPIR"] == "Sim") |                           # respiratório grave
        (df["CLI_CARDIA"] == "Sim") |                           # miocardite
        (df["CLI_MENING"] == "Sim") |                           # SNC
        ((df["CLI_RENAL"] == "Sim") & df["orgao_grave"]) |      # renal + outro órgão
        (df["hemorragia"] & df["orgao_grave"]) |                # hemorragia + órgão
        ((df["CLI_ICTERI"] == "Sim") & (df["CLI_RENAL"] == "Sim"))  # síndrome de Weil
    )

    # Critérios moderados
    criterio_moderado = (
        (df["CLI_ICTERI"] == "Sim") |     # icterícia sem gravidade
        (df["CLI_RENAL"] == "Sim") |      # renal leve / reversível
        (df["CLI_HEMORR"] == "Sim")       # hemorragia cutânea
    )

    # Classificação final
    df["SEVERIDADE"] = np.select(
        [criterio_grave, criterio_moderado],
        ["Grave", "Moderado"],
        default="Leve"
    )


    severidade_map = {
        "Leve": 0,
        "Moderado": 1,
        "Grave": 2
    }

    df["SEVERIDADE"] = df["SEVERIDADE"].map(severidade_map)
    # Remover colunas auxiliares
    df.drop(
        [
            "CLI_RESPIR", "CLI_HEMORR", "CLI_HEMOPU",
            "CLI_CARDIA", "CLI_MENING", "CLI_ICTERI",
            "CLI_RENAL", "hemorragia", "orgao_grave"
        ],
        axis=1,
        inplace=True
    )



    return df

# %%
df_feat_select=classificar_severidade_leptospirose(df)

# %% [markdown]
# ### Amostragem estratificada dos dados
#
# Nesta etapa é realizada uma amostragem estratificada da base de dados,
# preservando a proporção das classes da variável alvo.
# O procedimento consiste em aplicar uma amostragem aleatória dentro de cada classe,
# extraindo uma fração representativa do conjunto original.
#
# Em seguida, a base amostrada é separada em variáveis explicativas (X)
# e variável resposta (y), que serão utilizadas nas etapas subsequentes de modelagem.
#
# Essa abordagem reduz o volume de dados processados,
# mantendo a representatividade estatística das classes e garantindo reprodutibilidade
# por meio do uso de uma semente aleatória fixa.

# %%
amostragem = df_feat_select.groupby(target).sample(frac=0.15, random_state=42).copy()
X_data=amostragem[features_explicativas]
y_data = amostragem[target]

# %% [markdown]
# ### Seleção de variáveis

# %% [markdown]
# ## Pipeline de seleção de variáveis com suporte a tarefas (binária, multiclasse e regressão)
#
# Esta seção implementa um pipeline completo de *feature selection* que funciona para problemas de
# classificação (binária e multiclasse) e regressão. O fluxo combina pré-processamento (numérico e categórico),
# múltiplos métodos de seleção em camadas (filter → embedded → wrapper) e, ao final, reconcilia as variáveis
# selecionadas no espaço transformado com seus nomes originais no dataset.
#
# A motivação é obter um conjunto final de variáveis com bom poder preditivo e maior estabilidade,
# evitando depender de um único critério (ex.: apenas mutual information ou apenas importância de árvore),
# e garantindo rastreabilidade entre “features após encoding” e “colunas originais”.

# %% [markdown]
# ### Detecção automática do tipo de tarefa e escolha de validação cruzada
#
# Antes da seleção, o pipeline identifica se o problema é de classificação ou regressão a partir do parâmetro `task`.
# Com isso, define automaticamente o esquema de validação cruzada:
# - **StratifiedKFold** para classificação, preservando a proporção de classes em cada fold;
# - **KFold** para regressão, adequado quando não há estratificação por rótulo.
#
# Além disso, é definido um *scoring* padrão coerente com cada cenário (ex.: AUC-ROC para binário,
# F1-macro para multiclasse, e RMSE negativo para regressão), reduzindo risco de escolhas inconsistentes
# na avaliação do wrapper.

# %%
# -------------------------
# Helpers: task detection
# -------------------------
def _is_classification(task: str) -> bool:
    return task.lower() in ["binary", "multiclass", "classification", "clf"]

def _is_multiclass(task: str) -> bool:
    return task.lower() == "multiclass"

def _make_cv(y, task: str, n_splits: int = 5, random_state: int = 42):
    if _is_classification(task):
        return StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=random_state)
    return KFold(n_splits=n_splits, shuffle=True, random_state=random_state)

def _default_scoring(task: str) -> str:
    t = task.lower()
    if t == "binary":
        return "roc_auc"
    if t == "multiclass":
        return "f1_macro"
    if t in ["regression", "reg"]:
        return "neg_root_mean_squared_error"
    # fallback
    return "f1_macro" if _is_classification(task) else "neg_root_mean_squared_error"

def _selectkbest_score_func(task: str):
    return mutual_info_classif if _is_classification(task) else mutual_info_regression

def _anova_score_func(task: str):
    return f_classif if _is_classification(task) else f_regression

# %% [markdown]
# ### Identificação e pré-processamento de variáveis numéricas e categóricas
#
# Nesta etapa, as colunas são separadas por tipo:
# - categóricas (object/category/bool),
# - numéricas (np.number).
#
# Em seguida, aplica-se um pré-processamento unificado via `ColumnTransformer`:
# - **StandardScaler** para variáveis numéricas (normalização para modelos lineares e métricas);
# - **OneHotEncoder** para variáveis categóricas, com `handle_unknown="ignore"` para robustez.
#
# O resultado é uma matriz de features totalmente numérica, adequada para métodos de seleção e modelos do scikit-learn.

# %%
# ------------------------------------------------
# Preprocess: detect column types (customize here)
# ------------------------------------------------
def get_feature_types(X: pd.DataFrame):
    cat_cols = X.select_dtypes(include=["object", "category", "bool"]).columns.tolist()
    num_cols = X.select_dtypes(include=[np.number]).columns.tolist()
    return cat_cols, num_cols


# -------------------------------------------------------
# Mapping transformed -> original (robust for '_' in names)
# -------------------------------------------------------
def map_transformed_to_original_robust(feature_names_after_preproc, cat_cols):
    cat_cols_sorted = sorted(cat_cols, key=len, reverse=True)  # longest first
    orig = []

    for fn in feature_names_after_preproc:
        if "__" in fn:
            block, rest = fn.split("__", 1)
        else:
            block, rest = "remainder", fn

        if block == "cat":
            matched = None
            for c in cat_cols_sorted:
                if rest == c or rest.startswith(c + "_"):
                    matched = c
                    break
            orig.append(matched if matched is not None else rest.split("_", 1)[0])
        else:
            orig.append(rest)

    return np.array(orig)

# %% [markdown]
# ### Seleção wrapper com validação cruzada (desempenho real por feature)
#
# Como etapa final, aplica-se um *wrapper* que avalia cada variável individualmente usando validação cruzada.
# Ou seja, cada feature é testada em um modelo preditivo simples (Linear/Logistic),
# e é medido o desempenho médio (scoring) ao longo dos folds.
#
# A lógica do wrapper é aproximar o critério de seleção do objetivo final do projeto: desempenho preditivo,
# reduzindo o risco de selecionar variáveis “estatisticamente relevantes” mas com baixo ganho prático no modelo.
#
# O ranking final (`variaveis_finais`) corresponde às `final_wrapper` variáveis com melhor performance no wrapper.

# %%
def _make_wrapper_model(task: str, multiclass_strategy: str = "multinomial", random_state: int = 42):
    """
    multiclass_strategy:
      - "multinomial": LogisticRegression(multi_class="multinomial")
      - "ovr": OneVsRestClassifier(LogisticRegression(...))
      - "ovo": OneVsOneClassifier(LogisticRegression(...))
    """
    t = task.lower()
    m = multiclass_strategy.lower()

    if _is_classification(t):
        base_lr = LogisticRegression(
            max_iter=4000,
            solver="lbfgs",
            n_jobs=None,  # lbfgs ignores n_jobs
        )

        if t == "multiclass":
            if m == "multinomial":
                return LogisticRegression(max_iter=4000, solver="lbfgs", multi_class="multinomial")
            if m == "ovr":
                return OneVsRestClassifier(base_lr)
            if m == "ovo":
                return OneVsOneClassifier(base_lr)
            raise ValueError("multiclass_strategy must be one of: 'multinomial', 'ovr', 'ovo'")

        # binary
        return LogisticRegression(max_iter=4000, solver="lbfgs")

    # regression
    return LinearRegression()

# %% [markdown]
# ### Estratégias para classificação multiclasse: multinomial, OvR e OvO
#
# Para problemas multiclasse, o pipeline permite três estratégias:
# - **multinomial**: regressão logística multiclasse nativa (softmax),
# - **OvR (One-vs-Rest)**: treina um classificador por classe contra o resto,
# - **OvO (One-vs-One)**: treina classificadores para cada par de classes.
#
# A estratégia pode influenciar a avaliação do wrapper (principalmente com F1-macro),
# pois altera como o modelo aprende fronteiras de decisão e lida com classes minoritárias.
#
# ## Pipeline
#
# O pipeline retorna:
# - a matriz processada (`X_processado_df`) e nomes de features após pré-processamento,
# - rankings por método (Mutual Information, ANOVA/F-regression, Random Forest e Wrapper),
# - lista final de variáveis selecionadas no espaço transformado,
# - lista consolidada de variáveis no espaço original (para interpretação),
# - ranking agregado no nível da feature original (melhor score do wrapper entre suas dummies).
#
# Com isso, é possível:
# - justificar tecnicamente a seleção,
# - reproduzir resultados,
# - e comunicar as variáveis relevantes com interpretabilidade.

# %%
def pipeline_selecao_variaveis(
    X: pd.DataFrame,
    y: pd.Series,
    task: str = "binary",              # "binary", "multiclass", "regression"
    var_threshold: float = 0.0,
    k_mi: int = 80,
    k_anova: int = 80,
    top_rf: int = 50,
    final_wrapper: int = 20,
    scoring_wrapper: str | None = None,
    n_splits: int = 5,
    random_state: int = 42,
    multiclass_strategy: str = "multinomial",  # "multinomial", "ovr", "ovo"
):
    # 1) baixa variância
    selector_var = VarianceThreshold(threshold=var_threshold)
    selector_var.fit(X)
    cols_var = X.columns[selector_var.get_support()]
    X1 = X[cols_var]

    # 2) mutual info (rank)
    score_func_mi = _selectkbest_score_func(task)
    if score_func_mi is mutual_info_classif:
        selector_mi = SelectKBest(
            score_func=lambda X_, y_: mutual_info_classif(X_, y_, random_state=random_state),
            k=min(k_mi, X1.shape[1])
        )
    else:
        selector_mi = SelectKBest(score_func=mutual_info_regression, k=min(k_mi, X1.shape[1]))

    selector_mi.fit(X1, y)
    cols_mi = X1.columns[selector_mi.get_support()]
    scores_mi = selector_mi.scores_[selector_mi.get_support()]

    mi_rank = (pd.DataFrame({"variavel": cols_mi, "score_mutual_info": scores_mi})
               .sort_values("score_mutual_info", ascending=False))

    # 3) anova / f-regression (rank)
    score_func_anova = _anova_score_func(task)
    selector_anova = SelectKBest(score_func=score_func_anova, k=min(k_anova, X1.shape[1]))
    selector_anova.fit(X1, y)

    cols_anova = X1.columns[selector_anova.get_support()]
    scores_anova = selector_anova.scores_[selector_anova.get_support()]

    col_score = "score_anova_f" if _is_classification(task) else "score_f_regression"
    anova_rank = (pd.DataFrame({"variavel": cols_anova, col_score: scores_anova})
                  .sort_values(col_score, ascending=False))

    # candidatos (ordem: MI depois ANOVA; sem duplicar)
    candidatos = list(dict.fromkeys(mi_rank["variavel"].tolist() + anova_rank["variavel"].tolist()))
    Xcand = X1[candidatos] if len(candidatos) else X1.copy()

    # 4) RF importance (rank)
    if _is_classification(task):
        rf = RandomForestClassifier(
            n_estimators=400,
            random_state=random_state,
            n_jobs=-1
        )
    else:
        rf = RandomForestRegressor(
            n_estimators=400,
            random_state=random_state,
            n_jobs=-1
        )

    rf.fit(Xcand, y)

    rf_rank = (pd.DataFrame({"variavel": Xcand.columns, "importancia": rf.feature_importances_})
               .sort_values("importancia", ascending=False))

    vars_rf = rf_rank.head(min(top_rf, rf_rank.shape[0]))["variavel"].tolist()

    # 5) wrapper CV (rank) — mede desempenho real por feature (univariado)
    if scoring_wrapper is None:
        scoring_wrapper = _default_scoring(task)

    cv = _make_cv(y, task, n_splits=n_splits, random_state=random_state)
    model = _make_wrapper_model(task, multiclass_strategy=multiclass_strategy, random_state=random_state)

    resultados = []
    for var in vars_rf:
        score = cross_val_score(model, X1[[var]], y, cv=cv, scoring=scoring_wrapper).mean()
        resultados.append((var, score))

    wrap_rank = (pd.DataFrame(resultados, columns=["variavel", scoring_wrapper])
                 .sort_values(scoring_wrapper, ascending=False)
                 .head(min(final_wrapper, len(resultados))))

    return {
        "X_filtrado": X1,
        "ranking_mutual_info": mi_rank,
        "ranking_anova_ou_freg": anova_rank,
        "ranking_rf": rf_rank,
        "ranking_wrapper": wrap_rank,
        "variaveis_finais": wrap_rank["variavel"].tolist(),
        "scoring_wrapper": scoring_wrapper,
    }

# %% [markdown]
# ### Selecionando as variáveis automaticamente
#
# Esta função orquestra um pipeline completo de preparação e seleção de variáveis a partir de um `DataFrame` original,
# suportando tarefas de **classificação (binária/multiclasse)** e **regressão**.
#
# O fluxo é composto por três blocos principais:
#
# 1) **Detecção de tipos de variáveis**
# As colunas de entrada são separadas em **categóricas** e **numéricas** (via `get_feature_types_fn`),
# permitindo aplicar transformações apropriadas a cada tipo.
#
# 2) **Pré-processamento com `ColumnTransformer`**
# - Variáveis numéricas são padronizadas com `StandardScaler`, garantindo escala comparável para métodos e modelos lineares.
# - Variáveis categóricas são transformadas via `OneHotEncoder(handle_unknown="ignore")`, produzindo uma representação numérica robusta.
# Há um tratamento de compatibilidade entre versões do scikit-learn (`sparse_output` vs `sparse`).
#
# O resultado é uma matriz totalmente numérica no “espaço transformado”, acompanhada dos nomes das features geradas (`get_feature_names_out`).
#
# 3) **Seleção de variáveis no espaço transformado + mapeamento para o espaço original**
# A seleção é delegada para `pipeline_selecao_variaveis`, que ranqueia e filtra features usando múltiplos critérios
# (filtros estatísticos, importância por Random Forest e wrapper com validação cruzada).
#
# Como o One-Hot Encoding fragmenta variáveis categóricas em múltiplas colunas, a função reconstrói a rastreabilidade
# mapeando cada feature transformada para sua **coluna original** (`map_transformed_to_original_robust`).
# Além disso, é gerado um ranking agregado por feature original (max do score do wrapper entre suas dummies),
# facilitando interpretação e comunicação dos resultados.
#
# A função retorna tanto artefatos do pré-processamento (preprocessor, matriz transformada) quanto rankings e listas finais
# de variáveis selecionadas no espaço transformado e no espaço original.

# %%
def selecionar_variaveis_auto(
    X_data: pd.DataFrame,
    y_data: pd.Series,
    task: str = "binary",
    multiclass_strategy: str = "multinomial",   # multinomial | ovr | ovo
    scoring_wrapper: str | None = None,
    get_feature_types_fn=get_feature_types,
    var_threshold: float = 0.0,
    k_mi: int = 80,
    k_anova: int = 80,
    top_rf: int = 50,
    final_wrapper: int = 20,
    n_splits: int = 5,
    random_state: int = 42,
    remainder: str = "drop",  # "drop" ou "passthrough"
):
    # 1) tipos
    cat_cols, num_cols = get_feature_types_fn(X_data)

    # 2) preprocessor
    # compatibilidade entre versões sklearn:
    # em versões antigas, OneHotEncoder usa sparse=False; nas novas, sparse_output=False
    try:
        ohe = OneHotEncoder(handle_unknown="ignore", sparse_output=False)
    except TypeError:
        ohe = OneHotEncoder(handle_unknown="ignore", sparse=False)

    preprocessor = ColumnTransformer(
        transformers=[
            ("num", StandardScaler(), num_cols),
            ("cat", ohe, cat_cols),
        ],
        remainder=remainder
    )

    # 3) fit/transform
    X_processed = preprocessor.fit_transform(X_data)
    feature_names = preprocessor.get_feature_names_out()

    X_processed_df = pd.DataFrame(X_processed, columns=feature_names, index=X_data.index)

    # 4) seleção no espaço transformado
    selected = pipeline_selecao_variaveis(
        X_processed_df,
        y_data,
        task=task,
        var_threshold=var_threshold,
        k_mi=k_mi,
        k_anova=k_anova,
        top_rf=top_rf,
        final_wrapper=final_wrapper,
        scoring_wrapper=scoring_wrapper,
        n_splits=n_splits,
        random_state=random_state,
        multiclass_strategy=multiclass_strategy,
    )

    # 5) map back transformed -> original
    transformed_to_original = map_transformed_to_original_robust(feature_names, cat_cols)
    map_dict = dict(zip(feature_names, transformed_to_original))

    vars_transformadas = selected["variaveis_finais"]
    vars_originais = sorted({str(map_dict[v]) for v in vars_transformadas if v in map_dict})

    # agregação opcional: score do wrapper por feature original
    scoring_col = selected["ranking_wrapper"].columns[1]
    df_wrap = selected["ranking_wrapper"].copy()
    df_wrap["feature_original"] = df_wrap["variavel"].map(map_dict)

    ranking_original = (
        df_wrap.groupby("feature_original", dropna=False)[scoring_col]
        .max()
        .sort_values(ascending=False)
        .reset_index()
        .rename(columns={scoring_col: f"{scoring_col}_max"})
    )

    return {
        "preprocessor": preprocessor,
        "X_processado_df": X_processed_df,
        "feature_names_after_preproc": feature_names,
        "resultado_selecao_transformado": selected,
        "variaveis_finais_transformadas": vars_transformadas,
        "variaveis_finais_originais": vars_originais,
        "ranking_wrapper_por_feature_original": ranking_original,
        "cat_cols": cat_cols,
        "num_cols": num_cols,
        "map_transformada_para_original": map_dict,
    }

# %%
var_selected = selecionar_variaveis_auto(
     X_data, y_data,
     task="multiclass",
     multiclass_strategy="multinomial",
     scoring_wrapper="f1_macro",
)


print(f"Variáveis selecionadas({len(var_selected["variaveis_finais_originais"])} variáveis):{var_selected["variaveis_finais_originais"]}")
print(f"Variáveis Originais({len(X_data.columns)} variáveis):{X_data.columns}")
# Out:
# Variáveis selecionadas(17 variáveis):['ANT_CB_COR', 'ANT_CB_LAM', 'ANT_CB_LIX', 'ANT_CB_OUT', 'ANT_CB_SIN', 'CLI_CONGES', 'CLI_DIARRE', 'CLI_MIALGI', 'CLI_OUTROS', 'CLI_PANTUR', 'CLI_PROST', 'CS_ESCOL_N', 'ID_OCUPA_N', 'NU_IDADE_N', 'SG_UF', 'estacao', 'nivel_vulnerabilidade']
# Variáveis Originais(36 variáveis):Index(['NU_IDADE_N', 'CS_SEXO', 'CS_GESTANT', 'CS_RACA', 'CS_ESCOL_N',
#        'ID_OCUPA_N', 'CON_AREA', 'CON_AMBIEN', 'ANT_CB_LAM', 'ANT_CB_CRI',
#        'ANT_CB_SIN', 'ANT_CB_COR', 'ANT_CB_ROE', 'ANT_CB_TER', 'ANT_CB_LIX',
#        'ANT_CB_OUT', 'ANT_ANIMAI', 'ANT_HUMANO', 'CLI_FEBRE', 'CLI_MIALGI',
#        'CLI_CEFALE', 'CLI_PROST', 'CLI_CONGES', 'CLI_PANTUR', 'CLI_VOMITO',
#        'CLI_DIARRE', 'CLI_OUTROS', 'SG_UF', 'baixa_escolaridade',
#        'raca_vulneravel', 'faixa_vulneravel', 'vulnerabilidade_social',
#        'nivel_vulnerabilidade', 'mes_sintomas', 'estacao', 'periodo_chuvoso'],
#       dtype='object')

# %% [markdown]
# Filtrando as variáveis a serem utilizadas

# %%
X_data = X_data[var_selected['variaveis_finais_originais']]
X_data.shape
# Out:
# (25490, 17)

# %% [markdown]
# ## Train framework

# %% [markdown]
# ### Funções de apoio

# %% [markdown]
# Detecta automaticamente a disponibilidade de GPU no ambiente,
# verificando suporte a CUDA, compatibilidade do LightGBM com GPU
# e informações do hardware via `nvidia-smi`.

# %%
def detect_gpu():
    """
    Detecta corretamente suporte a GPU para CUDA, XGBoost e LightGBM.
    Retorna um dicionário completo.
    """

    # 1. Verificar CUDA geral
    try:
        cuda_available = torch.cuda.is_available()
    except:
        cuda_available = False


    # 2. Testar LightGBM GPU

    try:
        # Testa se LightGBM foi compilado com suporte a GPU
        lgb_gpu = lgb.register_logger(lambda x: x)  # dummy
        booster = lgb.LGBMClassifier(device="gpu")
        lgb_gpu = True
    except:
        lgb_gpu = False


    # 3. Detalhes da GPU via nvidia-smi

    try:
        smi_output = subprocess.check_output("nvidia-smi", shell=True).decode()
        gpu_info = smi_output.split("\n")[2].strip()
    except:
        gpu_info = "Nenhuma GPU detectada (nvidia-smi não disponível)"

    return {
        "cuda_available": cuda_available,
        "lightgbm_gpu": lgb_gpu,
        "gpu_info": gpu_info
    }

# %%
def get_model_params_gpu(model_name, gpu_info):
    """
    Retorna hiperparâmetros base apropriados para CPU ou GPU.
    """
    use_gpu = gpu_info["cuda_available"]

    if model_name == "xgboost":
        if use_gpu:
            return {
                "tree_method": "gpu_hist",
                "predictor": "gpu_predictor"
            }
        else:
            return {
                "tree_method": "hist",
                "predictor": "cpu_predictor"
            }

    elif model_name == "lightgbm":
        if use_gpu:
            return {
                "device": "gpu",
                "gpu_platform_id": 0,
                "gpu_device_id": 0
            }
        else:
            return {
                "device": "cpu"
            }

    elif model_name in ["random_forest", "svm"]:
        # sklearn não usa GPU
        return {}

    return {}

# %% [markdown]
# ###  1. FUNÇÃO PARA CRIAR O MODELO A PARTIR DO TRIAL (Optuna)

# %% [markdown]
# Esta função encapsula a criação do modelo a ser otimizado por uma *trial* do Optuna,
# permitindo que diferentes famílias de classificadores sejam avaliadas dentro do mesmo processo de busca.
#
# O fluxo é composto por duas decisões principais:
#
# 1) **Seleção do algoritmo**
# A cada iteração, o Optuna escolhe o modelo a ser testado (`svm`, `xgboost`, `lightgbm` ou `random_forest`)
# por meio de uma variável categórica (`model_name`). Isso viabiliza uma busca conjunta que compara
# arquiteturas distintas sob o mesmo protocolo de avaliação.
#
# 2) **Amostragem de hiperparâmetros e configuração dinâmica de GPU**
# Para cada algoritmo, são sugeridos hiperparâmetros relevantes (ex.: profundidade, número de árvores, taxa de aprendizado,
# subsample e colsample), definindo um espaço de busca controlado e reproduzível.
# Em paralelo, a função consulta `get_model_params_gpu(model_name, gpu_info)` para injetar automaticamente
# parâmetros específicos de aceleração (CPU/GPU) quando suportado pelo ambiente, garantindo portabilidade do pipeline.
#
# Além disso, é aplicada uma estratégia de mitigação de desbalanceamento:
# - `class_weight="balanced"` para Random Forest e SVM,
# - `is_unbalance=True` para LightGBM,
# visando reduzir viés em cenários com classes minoritárias.
#
# No caso da SVM, utiliza-se `LinearSVC` com calibração (`CalibratedClassifierCV`),
# permitindo a obtenção de probabilidades calibradas, úteis para métricas baseadas em ranking (ex.: ROC-AUC)
# e para tomada de decisão com limiar de classificação.

# %%
def create_model(trial, gpu_info):
    model_name = trial.suggest_categorical(
        "model_name", ["svm","xgboost", "lightgbm", "random_forest"]
    )

    gpu_params = get_model_params_gpu(model_name, gpu_info)

    # RANDOM FOREST
    if model_name == "random_forest":
        return RandomForestClassifier(
            n_estimators=trial.suggest_int("n_estimators", 5, 30),
            max_depth=trial.suggest_int("max_depth", 3, 9),
            min_samples_split=trial.suggest_int("min_samples_split", 2, 10),
            min_samples_leaf=trial.suggest_int("min_samples_leaf", 1, 5),
            random_state=42,
            class_weight= 'balanced',
            **gpu_params
        )

    # SVM
    elif model_name == "svm":
        svm= LinearSVC(
            C=trial.suggest_float("C", 0.1, 3.0),
            max_iter=5000,
            class_weight= 'balanced'
        )
        return CalibratedClassifierCV(svm, method="sigmoid")

    # XGBOOST
    elif model_name == "xgboost":
        return XGBClassifier(
            n_estimators=trial.suggest_int("n_estimators", 5, 30),
            max_depth=trial.suggest_int("max_depth", 3, 9),
            learning_rate=trial.suggest_float("learning_rate", 0.01, 0.3),
            subsample=trial.suggest_float("subsample", 0.5, 1.0),
            colsample_bytree=trial.suggest_float("colsample_bytree", 0.5, 1.0),
            eval_metric="logloss",
            random_state=42,
            class_weight= 'balanced',
            n_jobs=-1,
            #**gpu_params
        )

    # LIGHTGBM
    elif model_name == "lightgbm":
        return LGBMClassifier(
            n_estimators=trial.suggest_int("n_estimators", 5, 30),
            learning_rate=trial.suggest_float("learning_rate", 0.01, 0.3),
            max_depth=trial.suggest_int("max_depth", 3, 9),
            subsample=trial.suggest_float("subsample", 0.5, 1.0),
            colsample_bytree=trial.suggest_float("colsample_bytree", 0.5, 1.0),
            random_state=42,
            is_unbalance=True,
           force_col_wise=True,
            **gpu_params
        )

# %% [markdown]
# ### 2. FUNÇÃO OBJETIVO DO OPTUNA (COM CROSS-VALIDATION)

# %% [markdown]
# ### Função `build_pipeline`: pré-processamento, balanceamento e modelagem em um fluxo único
#
# Esta função constrói um pipeline completo de treinamento, integrando pré-processamento dos dados,
# tratamento de desbalanceamento e ajuste do modelo em uma única estrutura reprodutível.
#
# O pipeline é organizado em três blocos sequenciais:
#
# 1) **Pré-processamento por tipo de variável**
# - Variáveis numéricas passam por imputação da mediana, reduzindo sensibilidade a outliers,
# seguida de padronização (`StandardScaler`), garantindo escalas compatíveis para modelos sensíveis à magnitude.
# - Variáveis categóricas passam por imputação do valor mais frequente e codificação via `OneHotEncoder`,
# com tratamento explícito de categorias raras (`handle_unknown='infrequent_if_exist'`),
# o que reduz dimensionalidade excessiva e melhora estabilidade do modelo.
#
# 2) **Balanceamento de classes (SMOTE)**
# Após o pré-processamento, aplica-se o SMOTE para gerar amostras sintéticas da classe minoritária
# exclusivamente no conjunto de treino dentro do pipeline,
# evitando vazamento de informação (*data leakage*) e melhorando a capacidade do modelo
# em aprender fronteiras de decisão mais equilibradas.
#
# 3) **Modelo preditivo**
# O estimador final é injetado de forma modular, permitindo que diferentes algoritmos
# (Random Forest, SVM, XGBoost, LightGBM, etc.) sejam testados sob exatamente o mesmo fluxo de dados.
#
# Ao encapsular todas as etapas em um único objeto `Pipeline`,
# a função garante consistência entre treino, validação e inferência,
# além de facilitar integração com validação cruzada e otimização de hiperparâmetros.

# %%
def build_pipeline(model, cat_cols, num_cols):

    # construindo o preprocessor
    num_preprocessor = Pipeline(steps=[
        ("imputer", SimpleImputer(strategy="median")),
        ("scaler", StandardScaler())
    ])

    cat_preprocessor = Pipeline(steps=[
        ("imputer", SimpleImputer(strategy="most_frequent")),
        ("onehot", OneHotEncoder(handle_unknown='infrequent_if_exist'))
    ])

    preprocessor = ColumnTransformer(
        transformers=[
            ("num", num_preprocessor, num_cols),
            ("cat", cat_preprocessor, cat_cols)
        ]
    )

    # construindo pipe
    pipe = Pipeline([
        ("preprocessor", preprocessor),
        ("smote", SMOTE(random_state=42)),
        ("model", model)
    ])

    return pipe

# %% [markdown]
# ### Função `objective`: avaliação do modelo por validação cruzada e otimização com Optuna (com pruning)
#
# Esta função define a métrica objetivo utilizada pelo Optuna durante a busca de hiperparâmetros.
# Para cada `trial`, ela instancia um modelo candidato (via `create_model`) e o encapsula em um pipeline completo
# de pré-processamento + balanceamento (via `build_pipeline`), garantindo que todas as transformações
# sejam aplicadas corretamente dentro de cada fold e evitando *data leakage*.
#
# A avaliação é realizada com **validação cruzada estratificada** (`StratifiedKFold`),
# preservando a proporção de classes em treino e validação. Em cada fold:
# - o pipeline é treinado no subconjunto de treino (`fit`),
# - e a performance é medida no subconjunto de validação por **ROC-AUC** calculado a partir de probabilidades (`predict_proba`).
#
# Para suportar cenários multiclasse, o AUC é calculado com `multi_class='ovr'`
# e agregação `average='weighted'`, o que pondera o desempenho pelo suporte de cada classe
# e reduz distorções em bases desbalanceadas.
#
# Além disso, a função utiliza mecanismos de *early stopping* do Optuna:
# - `trial.report` comunica a métrica parcial por fold,
# - `trial.should_prune()` permite interromper tentativas com desempenho fraco,
# economizando tempo computacional e acelerando a convergência do processo de otimização.
#
# Ao final, a função retorna a média do AUC entre os folds, que é o valor maximizado pelo Optuna.

# %%
def objective(trial, X_train, y_train, cat_cols, num_cols,feature_names, gpu_info):

    model = create_model(trial, gpu_info)

    pipe = build_pipeline(model ,cat_cols, num_cols)


    cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

    scores = []
    for step, (train_idx, val_idx) in enumerate(cv.split(X_train, y_train)):

        X_tr, X_val = X_train.iloc[train_idx], X_train.iloc[val_idx]
        y_tr, y_val = y_train.iloc[train_idx], y_train.iloc[val_idx]


        pipe.fit(X_tr, y_tr)
        # Modified roc_auc_score to handle multi-class classification
        fold_auc = roc_auc_score(y_val, pipe.predict_proba(X_val), multi_class='ovr', average='weighted')
        scores.append(fold_auc)

        #  reporta o valor parcial ao Optuna
        trial.report(fold_auc, step=step)

        #  aborta a tentativa dado a avaliação do pruner
        if trial.should_prune():
            raise TrialPruned()


    return np.mean(scores)

# %% [markdown]
# Salva o histórico das trials do Optuna (métrica, parâmetros, estado e duração)
# em arquivo CSV para análise e rastreabilidade do processo de otimização.

# %%
# salva os logs das tentativas com métricas, tempo de treinamento, e parametros utilizados pelos modelos
def dump_trials(study, trial):
    df_metrics = study.trials_dataframe(attrs=("number", "value", "params", "state","duration"))
    df_metrics.to_csv("log_opt/trials_log_v2.csv", index=False)

# %% [markdown]
# ### 3. VALIDAÇÃO EXTERNA (OUTER CV) + OPTUNA INTERNO

# %% [markdown]
# ### Função `outer_cv_training_with_results`: nested CV com Optuna, checkpoint e métricas por fold
#
# Esta função executa um processo completo de treinamento e avaliação com **validação cruzada externa**
# (*outer cross-validation*), integrando **otimização de hiperparâmetros com Optuna** dentro de cada fold
# e registrando resultados detalhados (modelo escolhido, métricas, tempo e artefatos salvos).
#
# O fluxo segue a lógica de *nested cross-validation*:
#
# 1) **Diagnóstico do ambiente (GPU)**
# Antes do treinamento, a função identifica a disponibilidade de GPU (`detect_gpu`), permitindo que a criação dos modelos
# ative parâmetros específicos de aceleração quando suportado.
#
# 2) **Validação cruzada externa (generalização)**
# É aplicada uma `StratifiedKFold` externa com `n_splits`, garantindo que a proporção das classes seja preservada em cada divisão.
# Em cada fold externo, o conjunto é particionado em `X_train/y_train` (para otimização e treino) e `X_test/y_test` (avaliação final).
#
# 3) **Otimização interna com Optuna (seleção de modelo + hiperparâmetros)**
# Para cada fold externo, um `study` é criado com objetivo de maximizar a métrica definida na função `objective`.
# A função `objective` é “fixada” via `partial`, injetando os dados do fold e metadados do pipeline (colunas numéricas e categóricas,
# GPU, etc.), de forma que cada trial avalie modelos e hiperparâmetros sob o mesmo protocolo.
#
# O estudo é executado com:
# - `n_trials` tentativas,
# - controle de tempo (`timeout`),
# - paralelismo (`n_jobs=-1`),
# - callback de logging (`dump_trials`) para persistir histórico das trials.
#
# 4) **Treinamento final do melhor modelo no fold e checkpoint**
# Após a otimização, a melhor configuração é recuperada (`study.best_params`) e o melhor modelo é reconstruído (`create_model`),
# sendo então encapsulado em um pipeline (`build_pipeline`) com pré-processamento e SMOTE.
# O pipeline é treinado no conjunto de treino do fold com medição de tempo, e o artefato final é salvo em disco (`joblib.dump`)
# como checkpoint (`best_model_fold_k.pkl`), garantindo reprodutibilidade e possibilidade de reuso posterior.
#
# 5) **Avaliação no conjunto de teste do fold (métricas completas)**
# O modelo treinado é avaliado no `X_test/y_test` do fold externo usando:
# - **ROC-AUC multiclasse** com estratégia OvR e média ponderada (`average='weighted'`),
# - além de `accuracy`, `f1`, `recall` e `precision` (também ponderadas), adequadas para cenários desbalanceados.
#
# Ao final, a função retorna uma lista de dicionários com os resultados de cada fold,
# incluindo o modelo vencedor, hiperparâmetros, métricas, tempo de treino e caminho do checkpoint.
# Isso permite comparar estabilidade do desempenho entre folds e estimar capacidade real de generalização.

# %%
def outer_cv_training_with_results(
    X, y, cat_cols, num_cols, n_trials=30, n_splits=5
):

    gpu_info = detect_gpu()
    print("\n🔍 GPU detectada:", gpu_info)

    outer_cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
    results = []
    feature_names = X.columns
    fold = 1
    for train_idx, test_idx in outer_cv.split(X, y):

        print(f"\n==============================")
        print(f"  Fold Externo {fold}/{n_splits}")
        print(f"==============================")

        X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

        pruner = SuccessiveHalvingPruner(min_resource=1,
                                 reduction_factor=3,
                                 min_early_stopping_rate=1)

        study = optuna.create_study(direction="maximize")

        objective_fixed = partial(objective,
                          X_train=X_train,
                          y_train=y_train,
                          cat_cols=cat_cols,
                          num_cols=num_cols,
                          feature_names=feature_names,
                          gpu_info=gpu_info)

        study.optimize(objective_fixed,
                      n_trials=n_trials,
                      callbacks=[dump_trials],
                      timeout=1800,
                      n_jobs=-1,
                      )

        best_params = study.best_params
        best_model_name = best_params["model_name"]
        best_model = create_model(study.best_trial, gpu_info)


        pipe = build_pipeline(best_model ,cat_cols, num_cols)

        # treino com timer
        start_time = time.time()
        pipe.fit(X_train, y_train)
        train_time = time.time() - start_time

        # CHECKPOINT
        checkpoint_dir = "checkpoints_best_models"
        if not os.path.exists(checkpoint_dir):
            os.makedirs(checkpoint_dir)

        checkpoint_path = os.path.join(
            checkpoint_dir, f"best_model_fold_{fold}.pkl"
        )
        joblib.dump(pipe, checkpoint_path)

        # predição
        y_pred = pipe.predict(X_test)
        # For multi-class AUC, pass the full probability matrix and specify multi_class and average
        y_pred_prob = pipe.predict_proba(X_test)

        # métricas
        auc = roc_auc_score(y_test, y_pred_prob, multi_class='ovr', average='weighted')
        acc = accuracy_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred, average='weighted')
        rec = recall_score(y_test, y_pred, average='weighted')
        prec = precision_score(y_test, y_pred, average='weighted')

        # salvar dados do fold
        results.append({
            "fold": fold,
            "best_model": best_model_name,
            "auc": auc,
            "accuracy": acc,
            "f1": f1,
            "recall": rec,
            "precision": prec,
            "hyperparameters": best_params,
            "checkpoint_path": checkpoint_path,
            "train_time_seconds": train_time,
            #"test_data": {
            #    "X_test": X_test.copy(),
            #    "y_test": y_test.reset_index(drop=True),
            #    "y_pred": pd.Series(y_pred)
            #}
        })

        fold += 1

    return results

# %% [markdown]
# # Execute Framework

# %% [markdown]
# Cria os diretórios de checkpoints de modelos e logs de otimização,
# caso não existam, garantindo persistência e organização dos artefatos do experimento.

# %%
import os, joblib
checkpoint_dir = "checkpoints_best_models"

if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)

checkpoint_dir = "log_opt"
if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)

# %% [markdown]
# ### Execução do treinamento com validação cruzada externa e otimização de hiperparâmetros
#
# Nesta etapa, o conjunto de dados é preparado para o processo completo de treinamento e avaliação.
# Inicialmente, as colunas são classificadas em **categóricas** e **numéricas** por meio da função
# `get_feature_types`, garantindo que o pré-processamento subsequente seja aplicado de forma adequada
# a cada tipo de variável.
#
# Em seguida, é executado o procedimento de **validação cruzada externa** (*outer cross-validation*),
# no qual, para cada fold, ocorre uma otimização interna de hiperparâmetros via Optuna.
# Esse desenho experimental permite avaliar o desempenho dos modelos de forma mais realista,
# uma vez que o conjunto de teste de cada fold permanece completamente isolado do processo de tuning.
#
# Os parâmetros utilizados (`n_trials=30` e `n_splits=5`) definem, respectivamente,
# o orçamento de busca de hiperparâmetros em cada fold e o número de partições externas,
# balanceando custo computacional e robustez estatística.
#
# O resultado final (`df_results`) contém métricas, hiperparâmetros selecionados,
# tempos de treinamento e caminhos dos checkpoints para cada fold,
# servindo como base para análises comparativas e seleção do modelo final.

# %%
cat_cols, num_cols = get_feature_types(X_data)
df_results = outer_cv_training_with_results(
    X_data, y_data,
    cat_cols=cat_cols,
    num_cols=num_cols,
    n_trials=30,
    n_splits=5
)
# Out:
# 🔍 GPU detectada: {'cuda_available': False, 'lightgbm_gpu': False, 'gpu_info': 'Nenhuma GPU detectada (nvidia-smi não disponível)'}
#
# ==============================
#   Fold Externo 1/5
# ==============================
# [I 2026-02-01 04:11:41,363] A new study created in memory with name: no-name-ef458ce1-3a0a-4d9d-9d03-9636d4b6e05c
# [I 2026-02-01 04:11:52,019] Trial 1 finished with value: 0.6354815317106727 and parameters: {'model_name': 'xgboost', 'n_estimators': 11, 'max_depth': 4, 'learning_rate': 0.09296524384572234, 'subsample': 0.5391108401473579, 'colsample_bytree': 0.8166132746782263}. Best is trial 1 with value: 0.6354815317106727.
# [I 2026-02-01 04:12:03,368] Trial 2 finished with value: 0.6975749671356342 and parameters: {'model_name': 'lightgbm', 'n_estimators': 20, 'learning_rate': 0.1103094345974988, 'max_depth': 8, 'subsample': 0.8600423842176841, 'colsample_bytree': 0.6049792542501136}. Best is trial 2 with value: 0.6975749671356342.
# [I 2026-02-01 04:12:42,149] Trial 0 finished with value: 0.6700730079072971 and parameters: {'model_name': 'svm', 'C': 2.2960290009104476}. Best is trial 2 with value: 0.6975749671356342.
# [I 2026-02-01 04:12:53,440] Trial 4 finished with value: 0.7013909016554226 and parameters: {'model_name': 'lightgbm', 'n_estimators': 22, 'learning_rate': 0.2173918742121701, 'max_depth': 9, 'subsample': 0.7809494505782879, 'colsample_bytree': 0.5646381999409726}. Best is trial 4 with value: 0.7013909016554226.
# [I 2026-02-01 04:13:00,024] Trial 5 finished with value: 0.6581749617276924 and parameters: {'model_name': 'random_forest', 'n_estimators': 14, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 4}. Best is trial 4 with value: 0.7013909016554226.
# [I 2026-02-01 04:13:09,219] Trial 6 pruned.
# [I 2026-02-01 04:13:13,138] Trial 3 finished with value: 0.6699003869216454 and parameters: {'model_name': 'svm', 'C': 2.7277532097596575}. Best is trial 4 with value: 0.7013909016554226.
# [I 2026-02-01 04:13:18,843] Trial 8 pruned.
# [I 2026-02-01 04:13:22,841] Trial 9 pruned.
# [I 2026-02-01 04:13:30,345] Trial 10 finished with value: 0.6650864193424285 and parameters: {'model_name': 'random_forest', 'n_estimators': 16, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 5}. Best is trial 4 with value: 0.7013909016554226.
# [I 2026-02-01 04:13:42,150] Trial 11 finished with value: 0.7012829858095828 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.2959494925565415, 'max_depth': 9, 'subsample': 0.5955528702939484, 'colsample_bytree': 0.5188690504178111}. Best is trial 4 with value: 0.7013909016554226.
# [I 2026-02-01 04:13:49,910] Trial 7 finished with value: 0.672371640853946 and parameters: {'model_name': 'svm', 'C': 0.6005051300541993}. Best is trial 4 with value: 0.7013909016554226.
# [I 2026-02-01 04:13:54,927] Trial 12 finished with value: 0.7017139595645038 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.29265779474639625, 'max_depth': 9, 'subsample': 0.5603403304671045, 'colsample_bytree': 0.5061639791228232}. Best is trial 12 with value: 0.7017139595645038.
# [I 2026-02-01 04:14:01,758] Trial 13 finished with value: 0.7019228059371124 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.2963804096897798, 'max_depth': 9, 'subsample': 0.5549528791477842, 'colsample_bytree': 0.503688033669308}. Best is trial 13 with value: 0.7019228059371124.
# [I 2026-02-01 04:14:07,477] Trial 14 finished with value: 0.7005851156835039 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.29500064786022023, 'max_depth': 9, 'subsample': 0.6796371430183618, 'colsample_bytree': 0.5078195084957198}. Best is trial 13 with value: 0.7019228059371124.
# [I 2026-02-01 04:14:13,503] Trial 15 finished with value: 0.7017122932690013 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.29238788069733007, 'max_depth': 7, 'subsample': 0.6127901150500601, 'colsample_bytree': 0.500719688594328}. Best is trial 13 with value: 0.7019228059371124.
# [I 2026-02-01 04:14:15,979] Trial 17 pruned.
# [I 2026-02-01 04:14:16,260] Trial 16 finished with value: 0.6883454567234865 and parameters: {'model_name': 'lightgbm', 'n_estimators': 6, 'learning_rate': 0.2470665812404148, 'max_depth': 7, 'subsample': 0.5037031322429826, 'colsample_bytree': 0.6331070424256409}. Best is trial 13 with value: 0.7019228059371124.
# [I 2026-02-01 04:14:27,081] Trial 18 finished with value: 0.7003603074260711 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.24097085333541318, 'max_depth': 7, 'subsample': 0.626725958651358, 'colsample_bytree': 0.8462466347872954}. Best is trial 13 with value: 0.7019228059371124.
# [I 2026-02-01 04:14:27,723] Trial 19 finished with value: 0.700471560563602 and parameters: {'model_name': 'lightgbm', 'n_estimators': 25, 'learning_rate': 0.2484248152546165, 'max_depth': 8, 'subsample': 0.6203430155218321, 'colsample_bytree': 0.8355136740212162}. Best is trial 13 with value: 0.7019228059371124.
# [I 2026-02-01 04:14:29,804] Trial 20 pruned.
# [I 2026-02-01 04:14:30,205] Trial 21 pruned.
# [I 2026-02-01 04:14:41,526] Trial 22 finished with value: 0.7007770695518293 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.29520184682364037, 'max_depth': 6, 'subsample': 0.577769995422589, 'colsample_bytree': 0.5012828917788682}. Best is trial 13 with value: 0.7019228059371124.
# [I 2026-02-01 04:14:41,966] Trial 23 finished with value: 0.7020230106294242 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.29327588330037324, 'max_depth': 6, 'subsample': 0.5768594946683168, 'colsample_bytree': 0.5026712018329216}. Best is trial 23 with value: 0.7020230106294242.
# [I 2026-02-01 04:14:45,155] Trial 24 pruned.
# [I 2026-02-01 04:14:54,031] Trial 25 finished with value: 0.7028750580578205 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.2671886281840481, 'max_depth': 9, 'subsample': 0.6707603723319076, 'colsample_bytree': 0.5804224378184604}. Best is trial 25 with value: 0.7028750580578205.
# [I 2026-02-01 04:14:56,638] Trial 26 finished with value: 0.7008307526798222 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.18980897105644376, 'max_depth': 6, 'subsample': 0.557551804539394, 'colsample_bytree': 0.5841700984530639}. Best is trial 25 with value: 0.7028750580578205.
# [I 2026-02-01 04:15:04,416] Trial 27 finished with value: 0.7003659046122981 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.2085343180968166, 'max_depth': 6, 'subsample': 0.7024903475847173, 'colsample_bytree': 0.5669423675859517}. Best is trial 25 with value: 0.7028750580578205.
# [I 2026-02-01 04:15:07,339] Trial 28 finished with value: 0.6996551811564987 and parameters: {'model_name': 'lightgbm', 'n_estimators': 23, 'learning_rate': 0.2633080383565372, 'max_depth': 6, 'subsample': 0.7108986125467673, 'colsample_bytree': 0.5556284159516204}. Best is trial 25 with value: 0.7028750580578205.
# [I 2026-02-01 04:15:12,053] Trial 29 pruned.
# [LightGBM] [Info] Total Bins 19328
# [LightGBM] [Info] Number of data points in the train set: 33738, number of used features: 190
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [I 2026-02-01 04:15:15,730] A new study created in memory with name: no-name-eb770727-cbd5-44df-9226-c7db82ffd2c6
# ==============================
#   Fold Externo 2/5
# ==============================
# [I 2026-02-01 04:15:25,812] Trial 1 finished with value: 0.6867779970528289 and parameters: {'model_name': 'lightgbm', 'n_estimators': 11, 'learning_rate': 0.21319253396928495, 'max_depth': 5, 'subsample': 0.7794707547900179, 'colsample_bytree': 0.9456247631811756}. Best is trial 1 with value: 0.6867779970528289.
# [I 2026-02-01 04:15:29,974] Trial 0 finished with value: 0.6254332728189143 and parameters: {'model_name': 'xgboost', 'n_estimators': 28, 'max_depth': 3, 'learning_rate': 0.028908679597114434, 'subsample': 0.6272470464567108, 'colsample_bytree': 0.7808473629373642}. Best is trial 1 with value: 0.6867779970528289.
# [I 2026-02-01 04:15:34,486] Trial 2 finished with value: 0.6612745334439848 and parameters: {'model_name': 'random_forest', 'n_estimators': 8, 'max_depth': 9, 'min_samples_split': 9, 'min_samples_leaf': 5}. Best is trial 1 with value: 0.6867779970528289.
# [I 2026-02-01 04:16:18,136] Trial 3 finished with value: 0.6695432790739876 and parameters: {'model_name': 'svm', 'C': 1.019767486686538}. Best is trial 1 with value: 0.6867779970528289.
# [I 2026-02-01 04:16:25,139] Trial 5 finished with value: 0.663720969621039 and parameters: {'model_name': 'random_forest', 'n_estimators': 11, 'max_depth': 7, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 1 with value: 0.6867779970528289.
# [I 2026-02-01 04:16:29,890] Trial 4 finished with value: 0.6689451550006561 and parameters: {'model_name': 'svm', 'C': 1.642987158712551}. Best is trial 1 with value: 0.6867779970528289.
# [I 2026-02-01 04:16:36,131] Trial 6 finished with value: 0.6983932001305256 and parameters: {'model_name': 'lightgbm', 'n_estimators': 18, 'learning_rate': 0.20701426081259433, 'max_depth': 9, 'subsample': 0.9014362829621976, 'colsample_bytree': 0.7934800374171098}. Best is trial 6 with value: 0.6983932001305256.
# [I 2026-02-01 04:16:37,927] Trial 7 finished with value: 0.689007708890037 and parameters: {'model_name': 'lightgbm', 'n_estimators': 7, 'learning_rate': 0.26892355146285263, 'max_depth': 9, 'subsample': 0.9137578776698262, 'colsample_bytree': 0.9026777740756071}. Best is trial 6 with value: 0.6983932001305256.
# [I 2026-02-01 04:16:46,327] Trial 9 finished with value: 0.6668149920477946 and parameters: {'model_name': 'random_forest', 'n_estimators': 24, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 5}. Best is trial 6 with value: 0.6983932001305256.
# [I 2026-02-01 04:16:46,842] Trial 8 finished with value: 0.6861577655031388 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.1642569775034361, 'max_depth': 3, 'subsample': 0.805235524692293, 'colsample_bytree': 0.5092935829471235}. Best is trial 6 with value: 0.6983932001305256.
# [I 2026-02-01 04:16:49,392] Trial 10 pruned.
# [I 2026-02-01 04:16:53,240] Trial 11 pruned.
# [I 2026-02-01 04:16:59,878] Trial 12 finished with value: 0.6972991680829649 and parameters: {'model_name': 'lightgbm', 'n_estimators': 17, 'learning_rate': 0.2924240166476737, 'max_depth': 9, 'subsample': 0.9618901652158431, 'colsample_bytree': 0.9451775282635553}. Best is trial 6 with value: 0.6983932001305256.
# [I 2026-02-01 04:17:04,310] Trial 13 finished with value: 0.6965570375167127 and parameters: {'model_name': 'lightgbm', 'n_estimators': 18, 'learning_rate': 0.29342467886827506, 'max_depth': 9, 'subsample': 0.875923656240983, 'colsample_bytree': 0.9248787700315078}. Best is trial 6 with value: 0.6983932001305256.
# [I 2026-02-01 04:17:10,744] Trial 14 finished with value: 0.696069085012306 and parameters: {'model_name': 'lightgbm', 'n_estimators': 18, 'learning_rate': 0.29791897773955894, 'max_depth': 8, 'subsample': 0.8664439444328422, 'colsample_bytree': 0.9914833467244685}. Best is trial 6 with value: 0.6983932001305256.
# [I 2026-02-01 04:17:15,180] Trial 15 finished with value: 0.6974876984515221 and parameters: {'model_name': 'lightgbm', 'n_estimators': 21, 'learning_rate': 0.2204718025801175, 'max_depth': 8, 'subsample': 0.6503859099078853, 'colsample_bytree': 0.8182822918528869}. Best is trial 6 with value: 0.6983932001305256.
# [I 2026-02-01 04:17:20,580] Trial 16 finished with value: 0.6987084438149037 and parameters: {'model_name': 'lightgbm', 'n_estimators': 22, 'learning_rate': 0.21475337771405492, 'max_depth': 8, 'subsample': 0.6659226317671845, 'colsample_bytree': 0.8198216643397764}. Best is trial 16 with value: 0.6987084438149037.
# [I 2026-02-01 04:17:26,576] Trial 17 finished with value: 0.6979454838470628 and parameters: {'model_name': 'lightgbm', 'n_estimators': 23, 'learning_rate': 0.2076993588994446, 'max_depth': 7, 'subsample': 0.65342882430501, 'colsample_bytree': 0.8290945360919637}. Best is trial 16 with value: 0.6987084438149037.
# [I 2026-02-01 04:17:31,437] Trial 18 finished with value: 0.6976425872265658 and parameters: {'model_name': 'lightgbm', 'n_estimators': 23, 'learning_rate': 0.182579003951167, 'max_depth': 7, 'subsample': 0.5109074512698042, 'colsample_bytree': 0.637191838362386}. Best is trial 16 with value: 0.6987084438149037.
# [I 2026-02-01 04:17:47,884] Trial 19 pruned.
# [I 2026-02-01 04:17:53,868] Trial 20 pruned.
# [I 2026-02-01 04:17:58,085] Trial 21 finished with value: 0.6903343839764831 and parameters: {'model_name': 'lightgbm', 'n_estimators': 14, 'learning_rate': 0.13523944493979892, 'max_depth': 8, 'subsample': 0.7161990940868038, 'colsample_bytree': 0.6794394211792442}. Best is trial 16 with value: 0.6987084438149037.
# [I 2026-02-01 04:18:05,227] Trial 22 finished with value: 0.6986980134615172 and parameters: {'model_name': 'lightgbm', 'n_estimators': 24, 'learning_rate': 0.21280682309900972, 'max_depth': 8, 'subsample': 0.6857530133733483, 'colsample_bytree': 0.8459612970999889}. Best is trial 16 with value: 0.6987084438149037.
# [I 2026-02-01 04:18:09,212] Trial 23 finished with value: 0.697300872252748 and parameters: {'model_name': 'lightgbm', 'n_estimators': 25, 'learning_rate': 0.23639847710554573, 'max_depth': 6, 'subsample': 0.645423716857262, 'colsample_bytree': 0.8534358464353259}. Best is trial 16 with value: 0.6987084438149037.
# [I 2026-02-01 04:18:15,978] Trial 24 finished with value: 0.6975888536793026 and parameters: {'model_name': 'lightgbm', 'n_estimators': 26, 'learning_rate': 0.24409410670361698, 'max_depth': 8, 'subsample': 0.7254420570844473, 'colsample_bytree': 0.8577866407096888}. Best is trial 16 with value: 0.6987084438149037.
# [I 2026-02-01 04:18:19,924] Trial 25 finished with value: 0.6974293023914147 and parameters: {'model_name': 'lightgbm', 'n_estimators': 21, 'learning_rate': 0.25284006140697207, 'max_depth': 8, 'subsample': 0.7235287860857409, 'colsample_bytree': 0.7253107212942693}. Best is trial 16 with value: 0.6987084438149037.
# [I 2026-02-01 04:18:20,533] Trial 26 pruned.
# [I 2026-02-01 04:18:25,394] Trial 28 pruned.
# [I 2026-02-01 04:18:28,377] Trial 29 pruned.
# [I 2026-02-01 04:18:29,440] Trial 27 finished with value: 0.6968968084034627 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.1867061527927717, 'max_depth': 6, 'subsample': 0.5890924587487049, 'colsample_bytree': 0.7830891806670787}. Best is trial 16 with value: 0.6987084438149037.
# [LightGBM] [Info] Total Bins 19502
# [LightGBM] [Info] Number of data points in the train set: 33738, number of used features: 192
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [I 2026-02-01 04:18:33,610] A new study created in memory with name: no-name-0af31d92-ab21-4b49-ab5a-e7463bc25502
# ==============================
#   Fold Externo 3/5
# ==============================
# [I 2026-02-01 04:18:41,519] Trial 0 finished with value: 0.6690961873373579 and parameters: {'model_name': 'random_forest', 'n_estimators': 8, 'max_depth': 9, 'min_samples_split': 7, 'min_samples_leaf': 4}. Best is trial 0 with value: 0.6690961873373579.
# [I 2026-02-01 04:18:47,737] Trial 1 finished with value: 0.6724911678274975 and parameters: {'model_name': 'xgboost', 'n_estimators': 19, 'max_depth': 5, 'learning_rate': 0.295546593349833, 'subsample': 0.7157005526107332, 'colsample_bytree': 0.5250928181177495}. Best is trial 1 with value: 0.6724911678274975.
# [I 2026-02-01 04:18:50,907] Trial 2 finished with value: 0.6689384912993771 and parameters: {'model_name': 'random_forest', 'n_estimators': 17, 'max_depth': 7, 'min_samples_split': 4, 'min_samples_leaf': 2}. Best is trial 1 with value: 0.6724911678274975.
# [I 2026-02-01 04:18:59,514] Trial 3 finished with value: 0.634596560392609 and parameters: {'model_name': 'xgboost', 'n_estimators': 18, 'max_depth': 4, 'learning_rate': 0.03059743253588084, 'subsample': 0.8918559143627827, 'colsample_bytree': 0.6487018447951225}. Best is trial 1 with value: 0.6724911678274975.
# [I 2026-02-01 04:19:17,258] Trial 4 finished with value: 0.6641110931806824 and parameters: {'model_name': 'xgboost', 'n_estimators': 15, 'max_depth': 9, 'learning_rate': 0.14693866339908906, 'subsample': 0.7866986279496615, 'colsample_bytree': 0.6463644964490236}. Best is trial 1 with value: 0.6724911678274975.
# [I 2026-02-01 04:19:27,543] Trial 6 finished with value: 0.6907915451138643 and parameters: {'model_name': 'lightgbm', 'n_estimators': 18, 'learning_rate': 0.21883549720444392, 'max_depth': 4, 'subsample': 0.7724949275726019, 'colsample_bytree': 0.5390604928399674}. Best is trial 6 with value: 0.6907915451138643.
# [I 2026-02-01 04:19:30,551] Trial 5 finished with value: 0.689230442446846 and parameters: {'model_name': 'xgboost', 'n_estimators': 28, 'max_depth': 8, 'learning_rate': 0.2271997549286, 'subsample': 0.896146672537149, 'colsample_bytree': 0.6737885359917826}. Best is trial 6 with value: 0.6907915451138643.
# [I 2026-02-01 04:19:37,823] Trial 8 pruned.
# [I 2026-02-01 04:19:44,593] Trial 9 pruned.
# [I 2026-02-01 04:19:46,875] Trial 10 pruned.
# [I 2026-02-01 04:19:56,746] Trial 11 finished with value: 0.690863681174489 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.2241843812679758, 'max_depth': 3, 'subsample': 0.5254482635092718, 'colsample_bytree': 0.9005209173707208}. Best is trial 11 with value: 0.690863681174489.
# [I 2026-02-01 04:20:06,781] Trial 12 finished with value: 0.6918663164995182 and parameters: {'model_name': 'lightgbm', 'n_estimators': 29, 'learning_rate': 0.21974851348550797, 'max_depth': 3, 'subsample': 0.5113858618234384, 'colsample_bytree': 0.980393483827672}. Best is trial 12 with value: 0.6918663164995182.
# [I 2026-02-01 04:20:09,542] Trial 7 finished with value: 0.6743684398987768 and parameters: {'model_name': 'svm', 'C': 0.6782196204840325}. Best is trial 12 with value: 0.6918663164995182.
# [I 2026-02-01 04:20:15,915] Trial 13 finished with value: 0.6928027036047517 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.2275586652049834, 'max_depth': 3, 'subsample': 0.5236210354433599, 'colsample_bytree': 0.986864740286912}. Best is trial 13 with value: 0.6928027036047517.
# [I 2026-02-01 04:20:18,655] Trial 14 finished with value: 0.6911773699744983 and parameters: {'model_name': 'lightgbm', 'n_estimators': 29, 'learning_rate': 0.22305647733588632, 'max_depth': 3, 'subsample': 0.5007416075058415, 'colsample_bytree': 0.9900118902027947}. Best is trial 13 with value: 0.6928027036047517.
# [I 2026-02-01 04:20:25,750] Trial 15 finished with value: 0.69404799239984 and parameters: {'model_name': 'lightgbm', 'n_estimators': 30, 'learning_rate': 0.2803819396754339, 'max_depth': 3, 'subsample': 0.511690522662506, 'colsample_bytree': 0.9980540354323012}. Best is trial 15 with value: 0.69404799239984.
# [I 2026-02-01 04:20:29,038] Trial 16 finished with value: 0.6985028587670506 and parameters: {'model_name': 'lightgbm', 'n_estimators': 23, 'learning_rate': 0.29513814128860383, 'max_depth': 5, 'subsample': 0.5993593865356169, 'colsample_bytree': 0.9089265257555399}. Best is trial 16 with value: 0.6985028587670506.
# [I 2026-02-01 04:20:36,222] Trial 17 finished with value: 0.6970002244158402 and parameters: {'model_name': 'lightgbm', 'n_estimators': 24, 'learning_rate': 0.2989161944690927, 'max_depth': 5, 'subsample': 0.6188230609366889, 'colsample_bytree': 0.8778521125563727}. Best is trial 16 with value: 0.6985028587670506.
# [I 2026-02-01 04:20:51,692] Trial 18 pruned.
# [I 2026-02-01 04:20:57,785] Trial 19 pruned.
# [I 2026-02-01 04:21:02,415] Trial 20 finished with value: 0.6969163081518558 and parameters: {'model_name': 'lightgbm', 'n_estimators': 24, 'learning_rate': 0.2713483132793709, 'max_depth': 5, 'subsample': 0.6304501909440643, 'colsample_bytree': 0.8802488126676042}. Best is trial 16 with value: 0.6985028587670506.
# [I 2026-02-01 04:21:08,134] Trial 21 finished with value: 0.6976177297849221 and parameters: {'model_name': 'lightgbm', 'n_estimators': 23, 'learning_rate': 0.2701029065745031, 'max_depth': 5, 'subsample': 0.6403419571103148, 'colsample_bytree': 0.8611551315904301}. Best is trial 16 with value: 0.6985028587670506.
# [I 2026-02-01 04:21:11,920] Trial 22 finished with value: 0.6968339603637741 and parameters: {'model_name': 'lightgbm', 'n_estimators': 24, 'learning_rate': 0.2714134324086853, 'max_depth': 5, 'subsample': 0.626412425795619, 'colsample_bytree': 0.8656069220654194}. Best is trial 16 with value: 0.6985028587670506.
# [I 2026-02-01 04:21:18,500] Trial 23 finished with value: 0.6977029629240192 and parameters: {'model_name': 'lightgbm', 'n_estimators': 23, 'learning_rate': 0.26745681034129215, 'max_depth': 5, 'subsample': 0.611489715848477, 'colsample_bytree': 0.8632959777455199}. Best is trial 16 with value: 0.6985028587670506.
# [I 2026-02-01 04:21:22,533] Trial 24 finished with value: 0.6978976417803618 and parameters: {'model_name': 'lightgbm', 'n_estimators': 23, 'learning_rate': 0.29004672210377686, 'max_depth': 6, 'subsample': 0.6062341455872057, 'colsample_bytree': 0.822067676208611}. Best is trial 16 with value: 0.6985028587670506.
# [I 2026-02-01 04:21:28,328] Trial 25 finished with value: 0.6973500583246356 and parameters: {'model_name': 'lightgbm', 'n_estimators': 22, 'learning_rate': 0.25594123385659906, 'max_depth': 6, 'subsample': 0.583887469214323, 'colsample_bytree': 0.7895866572590846}. Best is trial 16 with value: 0.6985028587670506.
# [I 2026-02-01 04:21:32,919] Trial 26 finished with value: 0.6981881375575658 and parameters: {'model_name': 'lightgbm', 'n_estimators': 21, 'learning_rate': 0.2514038795857948, 'max_depth': 6, 'subsample': 0.5872317530737887, 'colsample_bytree': 0.7955146596240128}. Best is trial 16 with value: 0.6985028587670506.
# [I 2026-02-01 04:21:38,382] Trial 27 finished with value: 0.697784164345145 and parameters: {'model_name': 'lightgbm', 'n_estimators': 21, 'learning_rate': 0.17084472590124716, 'max_depth': 6, 'subsample': 0.5766371743462335, 'colsample_bytree': 0.7896083814085783}. Best is trial 16 with value: 0.6985028587670506.
# [I 2026-02-01 04:21:41,863] Trial 29 pruned.
# [I 2026-02-01 04:21:41,908] Trial 28 finished with value: 0.6939350761091356 and parameters: {'model_name': 'lightgbm', 'n_estimators': 14, 'learning_rate': 0.17231543644809338, 'max_depth': 6, 'subsample': 0.5617560806084597, 'colsample_bytree': 0.7959667050220699}. Best is trial 16 with value: 0.6985028587670506.
# [LightGBM] [Info] Total Bins 19500
# [LightGBM] [Info] Number of data points in the train set: 33738, number of used features: 196
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [I 2026-02-01 04:21:45,575] A new study created in memory with name: no-name-10133d71-d23f-4d83-a8be-155ecc17158b
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# ==============================
#   Fold Externo 4/5
# ==============================
# [I 2026-02-01 04:22:11,947] Trial 0 finished with value: 0.6878786953531861 and parameters: {'model_name': 'xgboost', 'n_estimators': 30, 'max_depth': 6, 'learning_rate': 0.2188635216524912, 'subsample': 0.7864825435689626, 'colsample_bytree': 0.726648641729237}. Best is trial 0 with value: 0.6878786953531861.
# [I 2026-02-01 04:22:20,295] Trial 2 finished with value: 0.6523276779624987 and parameters: {'model_name': 'lightgbm', 'n_estimators': 19, 'learning_rate': 0.018278417940939387, 'max_depth': 3, 'subsample': 0.8022585228214781, 'colsample_bytree': 0.6775653477923915}. Best is trial 0 with value: 0.6878786953531861.
# [I 2026-02-01 04:22:39,547] Trial 3 finished with value: 0.6406657170349793 and parameters: {'model_name': 'xgboost', 'n_estimators': 26, 'max_depth': 5, 'learning_rate': 0.0686838001235889, 'subsample': 0.7916055184289527, 'colsample_bytree': 0.6429650405540175}. Best is trial 0 with value: 0.6878786953531861.
# [I 2026-02-01 04:22:43,470] Trial 1 finished with value: 0.6764435735784793 and parameters: {'model_name': 'svm', 'C': 1.009225787051879}. Best is trial 0 with value: 0.6878786953531861.
# [I 2026-02-01 04:22:53,832] Trial 4 finished with value: 0.6246801142558827 and parameters: {'model_name': 'xgboost', 'n_estimators': 28, 'max_depth': 3, 'learning_rate': 0.014240165401704955, 'subsample': 0.6177880888403514, 'colsample_bytree': 0.8776393542043025}. Best is trial 0 with value: 0.6878786953531861.
# [I 2026-02-01 04:22:54,137] Trial 5 finished with value: 0.696157900532032 and parameters: {'model_name': 'lightgbm', 'n_estimators': 16, 'learning_rate': 0.2450144917665679, 'max_depth': 5, 'subsample': 0.7706696034014111, 'colsample_bytree': 0.5345251613272852}. Best is trial 5 with value: 0.696157900532032.
# [I 2026-02-01 04:22:58,164] Trial 6 pruned.
# [I 2026-02-01 04:23:03,875] Trial 7 finished with value: 0.6837128755503646 and parameters: {'model_name': 'random_forest', 'n_estimators': 27, 'max_depth': 8, 'min_samples_split': 6, 'min_samples_leaf': 5}. Best is trial 5 with value: 0.696157900532032.
# [I 2026-02-01 04:23:08,084] Trial 9 pruned.
# [I 2026-02-01 04:23:15,603] Trial 10 pruned.
# [I 2026-02-01 04:23:16,451] Trial 8 pruned.
# [I 2026-02-01 04:23:24,268] Trial 11 finished with value: 0.6984062990214683 and parameters: {'model_name': 'lightgbm', 'n_estimators': 10, 'learning_rate': 0.29588175218716944, 'max_depth': 9, 'subsample': 0.9956596469364591, 'colsample_bytree': 0.5143138741777277}. Best is trial 11 with value: 0.6984062990214683.
# [I 2026-02-01 04:23:24,777] Trial 12 finished with value: 0.694926933338497 and parameters: {'model_name': 'lightgbm', 'n_estimators': 11, 'learning_rate': 0.28674673627488034, 'max_depth': 6, 'subsample': 0.9781515010966487, 'colsample_bytree': 0.546040526911341}. Best is trial 11 with value: 0.6984062990214683.
# [I 2026-02-01 04:23:33,317] Trial 13 finished with value: 0.6982907843679369 and parameters: {'model_name': 'lightgbm', 'n_estimators': 10, 'learning_rate': 0.2983088490665387, 'max_depth': 9, 'subsample': 0.9908132224602204, 'colsample_bytree': 0.5046171386402659}. Best is trial 11 with value: 0.6984062990214683.
# [I 2026-02-01 04:23:34,403] Trial 14 finished with value: 0.7001555796138174 and parameters: {'model_name': 'lightgbm', 'n_estimators': 11, 'learning_rate': 0.2979819455656443, 'max_depth': 9, 'subsample': 0.9798431967328661, 'colsample_bytree': 0.5006054541232222}. Best is trial 14 with value: 0.7001555796138174.
# [I 2026-02-01 04:23:36,933] Trial 16 pruned.
# [I 2026-02-01 04:23:37,987] Trial 15 pruned.
# [I 2026-02-01 04:23:39,329] Trial 17 pruned.
# [I 2026-02-01 04:23:40,307] Trial 18 pruned.
# [I 2026-02-01 04:23:49,175] Trial 19 finished with value: 0.7002236242788933 and parameters: {'model_name': 'lightgbm', 'n_estimators': 15, 'learning_rate': 0.2555950324670904, 'max_depth': 8, 'subsample': 0.8842189452443451, 'colsample_bytree': 0.5821658309478837}. Best is trial 19 with value: 0.7002236242788933.
# [I 2026-02-01 04:23:50,435] Trial 20 finished with value: 0.7000747565969162 and parameters: {'model_name': 'lightgbm', 'n_estimators': 16, 'learning_rate': 0.24935127771189936, 'max_depth': 7, 'subsample': 0.8884266431270536, 'colsample_bytree': 0.6061047154802954}. Best is trial 19 with value: 0.7002236242788933.
# [I 2026-02-01 04:23:59,160] Trial 21 finished with value: 0.7009885084771909 and parameters: {'model_name': 'lightgbm', 'n_estimators': 16, 'learning_rate': 0.24336999223034364, 'max_depth': 7, 'subsample': 0.8829742234932808, 'colsample_bytree': 0.5996851739001581}. Best is trial 21 with value: 0.7009885084771909.
# [I 2026-02-01 04:24:00,386] Trial 22 finished with value: 0.7012422149957325 and parameters: {'model_name': 'lightgbm', 'n_estimators': 16, 'learning_rate': 0.24647963188843894, 'max_depth': 7, 'subsample': 0.8823396907488513, 'colsample_bytree': 0.5922316858952613}. Best is trial 22 with value: 0.7012422149957325.
# [I 2026-02-01 04:24:08,323] Trial 23 finished with value: 0.7014144691547393 and parameters: {'model_name': 'lightgbm', 'n_estimators': 19, 'learning_rate': 0.24794182952531582, 'max_depth': 7, 'subsample': 0.8885213523711297, 'colsample_bytree': 0.5940321971108924}. Best is trial 23 with value: 0.7014144691547393.
# [I 2026-02-01 04:24:10,306] Trial 24 finished with value: 0.699429550253293 and parameters: {'model_name': 'lightgbm', 'n_estimators': 18, 'learning_rate': 0.17452308865810479, 'max_depth': 7, 'subsample': 0.8690194197822291, 'colsample_bytree': 0.5772564890686691}. Best is trial 23 with value: 0.7014144691547393.
# [I 2026-02-01 04:24:30,283] Trial 25 pruned.
# [I 2026-02-01 04:24:31,185] Trial 26 pruned.
# [I 2026-02-01 04:24:40,821] Trial 27 finished with value: 0.700756213380942 and parameters: {'model_name': 'lightgbm', 'n_estimators': 21, 'learning_rate': 0.21426942417882439, 'max_depth': 7, 'subsample': 0.8302942691483652, 'colsample_bytree': 0.6682947187949009}. Best is trial 23 with value: 0.7014144691547393.
# [I 2026-02-01 04:24:41,614] Trial 28 finished with value: 0.6998194447220625 and parameters: {'model_name': 'lightgbm', 'n_estimators': 21, 'learning_rate': 0.20632945627199523, 'max_depth': 7, 'subsample': 0.5086899182959412, 'colsample_bytree': 0.6640991870942609}. Best is trial 23 with value: 0.7014144691547393.
# [I 2026-02-01 04:24:46,775] Trial 29 finished with value: 0.6995742982118047 and parameters: {'model_name': 'lightgbm', 'n_estimators': 20, 'learning_rate': 0.21085066551790907, 'max_depth': 6, 'subsample': 0.92521478273427, 'colsample_bytree': 0.6403126925099647}. Best is trial 23 with value: 0.7014144691547393.
# [LightGBM] [Info] Total Bins 19532
# [LightGBM] [Info] Number of data points in the train set: 33741, number of used features: 193
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [I 2026-02-01 04:24:50,396] A new study created in memory with name: no-name-d9bc3020-ae07-4308-a436-ff63ec4de4de
# ==============================
#   Fold Externo 5/5
# ==============================
# [I 2026-02-01 04:25:12,737] Trial 1 finished with value: 0.6823314300613926 and parameters: {'model_name': 'xgboost', 'n_estimators': 20, 'max_depth': 6, 'learning_rate': 0.29616127699558, 'subsample': 0.815051109233343, 'colsample_bytree': 0.9047163526326801}. Best is trial 1 with value: 0.6823314300613926.
# [I 2026-02-01 04:25:20,265] Trial 2 finished with value: 0.619353270556667 and parameters: {'model_name': 'random_forest', 'n_estimators': 5, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 3}. Best is trial 1 with value: 0.6823314300613926.
# [I 2026-02-01 04:25:35,583] Trial 3 finished with value: 0.6404669530283148 and parameters: {'model_name': 'xgboost', 'n_estimators': 21, 'max_depth': 5, 'learning_rate': 0.04499420137321348, 'subsample': 0.5030554290616446, 'colsample_bytree': 0.5630703482436448}. Best is trial 1 with value: 0.6823314300613926.
# [I 2026-02-01 04:25:47,705] Trial 4 finished with value: 0.6271049071706539 and parameters: {'model_name': 'xgboost', 'n_estimators': 17, 'max_depth': 3, 'learning_rate': 0.023020583626283488, 'subsample': 0.6315304311412725, 'colsample_bytree': 0.8419740590408578}. Best is trial 1 with value: 0.6823314300613926.
# [I 2026-02-01 04:25:49,678] Trial 0 finished with value: 0.6701375656852456 and parameters: {'model_name': 'svm', 'C': 1.5741194548324458}. Best is trial 1 with value: 0.6823314300613926.
# [I 2026-02-01 04:25:52,063] Trial 5 pruned.
# [I 2026-02-01 04:26:06,034] Trial 7 finished with value: 0.6567833945406075 and parameters: {'model_name': 'xgboost', 'n_estimators': 29, 'max_depth': 3, 'learning_rate': 0.21440096207527246, 'subsample': 0.9861920678192195, 'colsample_bytree': 0.8187490089268863}. Best is trial 1 with value: 0.6823314300613926.
# [I 2026-02-01 04:26:08,263] Trial 8 pruned.
# [I 2026-02-01 04:26:23,142] Trial 9 finished with value: 0.6760611456837465 and parameters: {'model_name': 'xgboost', 'n_estimators': 30, 'max_depth': 4, 'learning_rate': 0.2506750951651359, 'subsample': 0.5421238326849889, 'colsample_bytree': 0.5465421826902956}. Best is trial 1 with value: 0.6823314300613926.
# [I 2026-02-01 04:26:32,752] Trial 10 finished with value: 0.6885558936736715 and parameters: {'model_name': 'lightgbm', 'n_estimators': 12, 'learning_rate': 0.15438689749369744, 'max_depth': 6, 'subsample': 0.9479611901334348, 'colsample_bytree': 0.7780434171887953}. Best is trial 10 with value: 0.6885558936736715.
# [I 2026-02-01 04:26:42,619] Trial 11 finished with value: 0.6935624274118236 and parameters: {'model_name': 'lightgbm', 'n_estimators': 13, 'learning_rate': 0.1359246161038608, 'max_depth': 9, 'subsample': 0.7916091256430919, 'colsample_bytree': 0.696528577171698}. Best is trial 11 with value: 0.6935624274118236.
# [I 2026-02-01 04:26:49,585] Trial 6 finished with value: 0.669950042628976 and parameters: {'model_name': 'svm', 'C': 1.8979267856482758}. Best is trial 11 with value: 0.6935624274118236.
# [I 2026-02-01 04:26:51,530] Trial 12 finished with value: 0.6938481759858727 and parameters: {'model_name': 'lightgbm', 'n_estimators': 12, 'learning_rate': 0.15057846574701153, 'max_depth': 9, 'subsample': 0.8149182673589593, 'colsample_bytree': 0.7078726343135274}. Best is trial 12 with value: 0.6938481759858727.
# [I 2026-02-01 04:26:59,457] Trial 13 finished with value: 0.6936136719370073 and parameters: {'model_name': 'lightgbm', 'n_estimators': 13, 'learning_rate': 0.13853673360932922, 'max_depth': 9, 'subsample': 0.8042713509837564, 'colsample_bytree': 0.6972336164119356}. Best is trial 12 with value: 0.6938481759858727.
# [I 2026-02-01 04:27:01,585] Trial 14 finished with value: 0.6950538937126228 and parameters: {'model_name': 'lightgbm', 'n_estimators': 15, 'learning_rate': 0.1263083893358567, 'max_depth': 9, 'subsample': 0.7587599633170701, 'colsample_bytree': 0.6617667542109901}. Best is trial 14 with value: 0.6950538937126228.
# [I 2026-02-01 04:27:08,424] Trial 15 finished with value: 0.6846813032039885 and parameters: {'model_name': 'lightgbm', 'n_estimators': 7, 'learning_rate': 0.1103611623219859, 'max_depth': 9, 'subsample': 0.702285490076139, 'colsample_bytree': 0.7053593858649083}. Best is trial 14 with value: 0.6950538937126228.
# [I 2026-02-01 04:27:12,249] Trial 16 finished with value: 0.6953022344248406 and parameters: {'model_name': 'lightgbm', 'n_estimators': 18, 'learning_rate': 0.09679374193680665, 'max_depth': 8, 'subsample': 0.6958146943886975, 'colsample_bytree': 0.6465992049660019}. Best is trial 16 with value: 0.6953022344248406.
# [I 2026-02-01 04:27:17,735] Trial 17 finished with value: 0.6928493465473994 and parameters: {'model_name': 'lightgbm', 'n_estimators': 17, 'learning_rate': 0.08235014513474187, 'max_depth': 8, 'subsample': 0.6958321281279094, 'colsample_bytree': 0.6118301104117452}. Best is trial 16 with value: 0.6953022344248406.
# [I 2026-02-01 04:27:23,892] Trial 18 finished with value: 0.6979767114891743 and parameters: {'model_name': 'lightgbm', 'n_estimators': 24, 'learning_rate': 0.09212145540025504, 'max_depth': 8, 'subsample': 0.6873971039116582, 'colsample_bytree': 0.6145036998526812}. Best is trial 18 with value: 0.6979767114891743.
# [I 2026-02-01 04:27:28,955] Trial 19 finished with value: 0.701900215684419 and parameters: {'model_name': 'lightgbm', 'n_estimators': 25, 'learning_rate': 0.1952983659109566, 'max_depth': 7, 'subsample': 0.6211409993026178, 'colsample_bytree': 0.6183138796775189}. Best is trial 19 with value: 0.701900215684419.
# [I 2026-02-01 04:27:35,545] Trial 20 finished with value: 0.6942989457394297 and parameters: {'model_name': 'lightgbm', 'n_estimators': 25, 'learning_rate': 0.08522264640331732, 'max_depth': 7, 'subsample': 0.620399888173749, 'colsample_bytree': 0.5050108298636619}. Best is trial 19 with value: 0.701900215684419.
# [I 2026-02-01 04:27:38,253] Trial 21 pruned.
# [I 2026-02-01 04:27:45,807] Trial 22 finished with value: 0.7005146786018202 and parameters: {'model_name': 'lightgbm', 'n_estimators': 25, 'learning_rate': 0.20748154877856823, 'max_depth': 7, 'subsample': 0.6172558584045869, 'colsample_bytree': 0.6200630384197761}. Best is trial 19 with value: 0.701900215684419.
# [I 2026-02-01 04:27:49,318] Trial 23 finished with value: 0.7005846189611667 and parameters: {'model_name': 'lightgbm', 'n_estimators': 25, 'learning_rate': 0.180859793232294, 'max_depth': 7, 'subsample': 0.6247468115168895, 'colsample_bytree': 0.6214651905958677}. Best is trial 19 with value: 0.701900215684419.
# [I 2026-02-01 04:27:51,858] Trial 25 pruned.
# [I 2026-02-01 04:27:57,125] Trial 24 finished with value: 0.7020168344390997 and parameters: {'model_name': 'lightgbm', 'n_estimators': 25, 'learning_rate': 0.20912062209327983, 'max_depth': 7, 'subsample': 0.6014504344548548, 'colsample_bytree': 0.6043898749597125}. Best is trial 24 with value: 0.7020168344390997.
# [I 2026-02-01 04:28:03,112] Trial 26 finished with value: 0.6995650757326864 and parameters: {'model_name': 'lightgbm', 'n_estimators': 23, 'learning_rate': 0.19658951168463154, 'max_depth': 7, 'subsample': 0.5906188911721131, 'colsample_bytree': 0.5796021889715967}. Best is trial 24 with value: 0.7020168344390997.
# [I 2026-02-01 04:28:08,195] Trial 27 finished with value: 0.6983721090062506 and parameters: {'model_name': 'lightgbm', 'n_estimators': 22, 'learning_rate': 0.19537654392100035, 'max_depth': 7, 'subsample': 0.568938431616062, 'colsample_bytree': 0.546284519771158}. Best is trial 24 with value: 0.7020168344390997.
# [I 2026-02-01 04:28:13,607] Trial 28 finished with value: 0.700468899125497 and parameters: {'model_name': 'lightgbm', 'n_estimators': 28, 'learning_rate': 0.18261309856737215, 'max_depth': 6, 'subsample': 0.5674941081020699, 'colsample_bytree': 0.5194521130862231}. Best is trial 24 with value: 0.7020168344390997.
# [I 2026-02-01 04:28:17,006] Trial 29 finished with value: 0.699063572692368 and parameters: {'model_name': 'lightgbm', 'n_estimators': 27, 'learning_rate': 0.2388805566291028, 'max_depth': 6, 'subsample': 0.6587672866074147, 'colsample_bytree': 0.7518242289051402}. Best is trial 24 with value: 0.7020168344390997.
# [LightGBM] [Info] Total Bins 19282
# [LightGBM] [Info] Number of data points in the train set: 33741, number of used features: 194
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %% [markdown]
# #### Conferir checkpoints intermediarios

# %% [markdown]
# Consolida os resultados da validação cruzada externa em um DataFrame,
# salva o resumo em formato Parquet e carrega os logs das trials do Optuna
# para inspeção e análise do processo de otimização.

# %%
df_results=pd.DataFrame(df_results)

# %%
df_results.to_parquet('df_results.parquet')

# %%
df_metrics = pd.read_csv('log_opt/trials_log_v2.csv')
display(df_metrics)
# Out:
#     number     value  params_C  params_colsample_bytree  params_learning_rate  \
# 0        0  0.670138  1.574119                      NaN                   NaN
# 1        1  0.682331       NaN                 0.904716              0.296161
# 2        2  0.619353       NaN                      NaN                   NaN
# 3        3  0.640467       NaN                 0.563070              0.044994
# 4        4  0.627105       NaN                 0.841974              0.023021
# 5        5  0.630283       NaN                 0.934697              0.051125
# 6        6  0.669950  1.897927                      NaN                   NaN
# 7        7  0.656783       NaN                 0.818749              0.214401
# 8        8  0.637540       NaN                      NaN                   NaN
# 9        9  0.676061       NaN                 0.546542              0.250675
# 10      10  0.688556       NaN                 0.778043              0.154387
# 11      11  0.693562       NaN                 0.696529              0.135925
# 12      12  0.693848       NaN                 0.707873              0.150578
# 13      13  0.693614       NaN                 0.697234              0.138537
# 14      14  0.695054       NaN                 0.661767              0.126308
# 15      15  0.684681       NaN                 0.705359              0.110361
# 16      16  0.695302       NaN                 0.646599              0.096794
# 17      17  0.692849       NaN                 0.611830              0.082350
# 18      18  0.697977       NaN                 0.614504              0.092121
# 19      19  0.701900       NaN                 0.618314              0.195298
# 20      20  0.694299       NaN                 0.505011              0.085223
# 21      21  0.675044  0.106813                      NaN                   NaN
# 22      22  0.700515       NaN                 0.620063              0.207482
# 23      23  0.700585       NaN                 0.621465              0.180860
# 24      24  0.702017       NaN                 0.604390              0.209121
# 25      25  0.681874       NaN                      NaN                   NaN
# 26      26  0.699565       NaN                 0.579602              0.196590
# 27      27  0.698372       NaN                 0.546285              0.195377
# 28      28  0.700469       NaN                 0.519452              0.182613
# 29      29  0.699064       NaN                 0.751824              0.238881
#
#     params_max_depth  params_min_samples_leaf  params_min_samples_split  \
# 0                NaN                      NaN                       NaN
# 1                6.0                      NaN                       NaN
# 2                4.0                      3.0                       3.0
# 3                5.0                      NaN                       NaN
# 4                3.0                      NaN                       NaN
# 5                5.0                      NaN                       NaN
# 6                NaN                      NaN                       NaN
# 7                3.0                      NaN                       NaN
# 8                5.0                      5.0                       9.0
# 9                4.0                      NaN                       NaN
# 10               6.0                      NaN                       NaN
# 11               9.0                      NaN                       NaN
# 12               9.0                      NaN                       NaN
# 13               9.0                      NaN                       NaN
# 14               9.0                      NaN                       NaN
# 15               9.0                      NaN                       NaN
# 16               8.0                      NaN                       NaN
# 17               8.0                      NaN                       NaN
# 18               8.0                      NaN                       NaN
# 19               7.0                      NaN                       NaN
# 20               7.0                      NaN                       NaN
# 21               NaN                      NaN                       NaN
# 22               7.0                      NaN                       NaN
# 23               7.0                      NaN                       NaN
# 24               7.0                      NaN                       NaN
# 25               7.0                      1.0                      10.0
# 26               7.0                      NaN                       NaN
# 27               7.0                      NaN                       NaN
# 28               6.0                      NaN                       NaN
# 29               6.0                      NaN                       NaN
#
#    params_model_name  params_n_estimators  params_subsample     state  \
# 0                svm                  NaN               NaN  COMPLETE
# 1            xgboost                 20.0          0.815051  COMPLETE
# 2      random_forest                  5.0               NaN  COMPLETE
# 3            xgboost                 21.0          0.503055  COMPLETE
# 4            xgboost                 17.0          0.631530  COMPLETE
# 5            xgboost                 13.0          0.920315    PRUNED
# 6                svm                  NaN               NaN  COMPLETE
# 7            xgboost                 29.0          0.986192  COMPLETE
# 8      random_forest                  9.0               NaN    PRUNED
# 9            xgboost                 30.0          0.542124  COMPLETE
# 10          lightgbm                 12.0          0.947961  COMPLETE
# 11          lightgbm                 13.0          0.791609  COMPLETE
# 12          lightgbm                 12.0          0.814918  COMPLETE
# 13          lightgbm                 13.0          0.804271  COMPLETE
# 14          lightgbm                 15.0          0.758760  COMPLETE
# 15          lightgbm                  7.0          0.702285  COMPLETE
# 16          lightgbm                 18.0          0.695815  COMPLETE
# 17          lightgbm                 17.0          0.695832  COMPLETE
# 18          lightgbm                 24.0          0.687397  COMPLETE
# 19          lightgbm                 25.0          0.621141  COMPLETE
# 20          lightgbm                 25.0          0.620400  COMPLETE
# 21               svm                  NaN               NaN    PRUNED
# 22          lightgbm                 25.0          0.617256  COMPLETE
# 23          lightgbm                 25.0          0.624747  COMPLETE
# 24          lightgbm                 25.0          0.601450  COMPLETE
# 25     random_forest                 27.0               NaN    PRUNED
# 26          lightgbm                 23.0          0.590619  COMPLETE
# 27          lightgbm                 22.0          0.568938  COMPLETE
# 28          lightgbm                 28.0          0.567494  COMPLETE
# 29          lightgbm                 27.0          0.658767  COMPLETE
#
#                   duration
# 0   0 days 00:00:59.273853
# 1   0 days 00:00:22.327239
# 2   0 days 00:00:07.515547
# 3   0 days 00:00:15.306102
# 4   0 days 00:00:12.112963
# 5   0 days 00:00:04.344005
# 6   0 days 00:00:59.894827
# 7   0 days 00:00:13.959281
# 8   0 days 00:00:02.220071
# 9   0 days 00:00:14.864648
# 10  0 days 00:00:09.593247
# 11  0 days 00:00:09.853371
# 12  0 days 00:00:08.896275
# 13  0 days 00:00:09.863532
# 14  0 days 00:00:10.033898
# 15  0 days 00:00:08.954826
# 16  0 days 00:00:10.651519
# 17  0 days 00:00:09.294292
# 18  0 days 00:00:11.634097
# 19  0 days 00:00:11.210591
# 20  0 days 00:00:11.639463
# 21  0 days 00:00:09.288664
# 22  0 days 00:00:10.243106
# 23  0 days 00:00:11.051367
# 24  0 days 00:00:11.305703
# 25  0 days 00:00:02.523874
# 26  0 days 00:00:11.233765
# 27  0 days 00:00:11.056363
# 28  0 days 00:00:10.472815
# 29  0 days 00:00:08.800331

# %% [markdown]
# Carregando o pkl

# %%
import joblib

modelo = joblib.load("checkpoints_best_models/best_model_fold_1.pkl")

# %%
modelo
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['NU_IDADE_N']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='infrequent_if_exist'))]),
#                                                   ['ANT_CB_COR', 'ANT_CB_LAM',
#                                                    'ANT_...
#                                                    'CLI_OUTROS', 'CLI_PANTUR',
#                                                    'CLI_PROST', 'CS_ESCOL_N',
#                                                    'ID_OCUPA_N', 'SG_UF',
#                                                    'estacao',
#                                                    'nivel_vulnerabilidade'])])),
#                 ('smote', SMOTE(random_state=42)),
#                 ('model',
#                  LGBMClassifier(colsample_bytree=0.5804224378184604,
#                                 device='cpu', force_col_wise=True,
#                                 is_unbalance=True,
#                                 learning_rate=0.2671886281840481, max_depth=9,
#                                 n_estimators=27, random_state=42,
#                                 subsample=0.6707603723319076))])

# %%
modelo.named_steps["preprocessor"].get_feature_names_out()
# Out:
# array(['num__NU_IDADE_N', 'cat__ANT_CB_COR_Não',
#        'cat__ANT_CB_COR_Não informado', 'cat__ANT_CB_COR_Sim',
#        'cat__ANT_CB_LAM_Não', 'cat__ANT_CB_LAM_Não informado',
#        'cat__ANT_CB_LAM_Sim', 'cat__ANT_CB_LIX_Não',
#        'cat__ANT_CB_LIX_Não informado', 'cat__ANT_CB_LIX_Sim',
#        'cat__ANT_CB_OUT_Não', 'cat__ANT_CB_OUT_Não informado',
#        'cat__ANT_CB_OUT_Sim', 'cat__ANT_CB_SIN_Não',
#        'cat__ANT_CB_SIN_Não informado', 'cat__ANT_CB_SIN_Sim',
#        'cat__CLI_CONGES_Não', 'cat__CLI_CONGES_Não informado',
#        'cat__CLI_CONGES_Sim', 'cat__CLI_DIARRE_Não',
#        'cat__CLI_DIARRE_Não informado', 'cat__CLI_DIARRE_Sim',
#        'cat__CLI_MIALGI_Não', 'cat__CLI_MIALGI_Não informado',
#        'cat__CLI_MIALGI_Sim', 'cat__CLI_OUTROS_Não',
#        'cat__CLI_OUTROS_Não informado', 'cat__CLI_OUTROS_Sim',
#        'cat__CLI_PANTUR_Não', 'cat__CLI_PANTUR_Não informado',
#        'cat__CLI_PANTUR_Sim', 'cat__CLI_PROST_Não',
#        'cat__CLI_PROST_Não informado', 'cat__CLI_PROST_Sim',
#        'cat__CS_ESCOL_N_10',
#        'cat__CS_ESCOL_N_1ª a 4ª série incompleta do EF',
#        'cat__CS_ESCOL_N_4ª série completa do EF',
#        'cat__CS_ESCOL_N_5ª a 8ª série incompleta do EF',
#        'cat__CS_ESCOL_N_Ensino fundamental completo',
#        'cat__CS_ESCOL_N_Ensino médio completo',
#        'cat__CS_ESCOL_N_Ensino médio incompleto',
#        'cat__CS_ESCOL_N_Não informado',
#        'cat__CS_ESCOL_N_Sem escolaridade',
#        'cat__CS_ESCOL_N_Superior completo',
#        'cat__CS_ESCOL_N_Superior incompleto', 'cat__ID_OCUPA_N_000000',
#        'cat__ID_OCUPA_N_010205', 'cat__ID_OCUPA_N_010210',
#        'cat__ID_OCUPA_N_010310', 'cat__ID_OCUPA_N_010315',
#        'cat__ID_OCUPA_N_020105', 'cat__ID_OCUPA_N_021110',
#        'cat__ID_OCUPA_N_021205', 'cat__ID_OCUPA_N_021210',
#        'cat__ID_OCUPA_N_030110', 'cat__ID_OCUPA_N_031205',
#        'cat__ID_OCUPA_N_031210', 'cat__ID_OCUPA_N_100.01',
#        'cat__ID_OCUPA_N_111220', 'cat__ID_OCUPA_N_111250',
#        'cat__ID_OCUPA_N_111410', 'cat__ID_OCUPA_N_111415',
#        'cat__ID_OCUPA_N_121010', 'cat__ID_OCUPA_N_122405',
#        'cat__ID_OCUPA_N_122520', 'cat__ID_OCUPA_N_122610',
#        'cat__ID_OCUPA_N_123110', 'cat__ID_OCUPA_N_123305',
#        'cat__ID_OCUPA_N_123805', 'cat__ID_OCUPA_N_131310',
#        'cat__ID_OCUPA_N_131320', 'cat__ID_OCUPA_N_1411.1',
#        'cat__ID_OCUPA_N_141205', 'cat__ID_OCUPA_N_141305',
#        'cat__ID_OCUPA_N_1414.1', 'cat__ID_OCUPA_N_141405',
#        'cat__ID_OCUPA_N_141410', 'cat__ID_OCUPA_N_141515',
#        'cat__ID_OCUPA_N_141605', 'cat__ID_OCUPA_N_141615',
#        'cat__ID_OCUPA_N_141705', 'cat__ID_OCUPA_N_141720',
#        'cat__ID_OCUPA_N_142105', 'cat__ID_OCUPA_N_1423.1',
#        'cat__ID_OCUPA_N_142305', 'cat__ID_OCUPA_N_142310',
#        'cat__ID_OCUPA_N_142315', 'cat__ID_OCUPA_N_142320',
#        'cat__ID_OCUPA_N_142405', 'cat__ID_OCUPA_N_142410',
#        'cat__ID_OCUPA_N_142415', 'cat__ID_OCUPA_N_142515',
#        'cat__ID_OCUPA_N_142520', 'cat__ID_OCUPA_N_142530',
#        'cat__ID_OCUPA_N_142605', 'cat__ID_OCUPA_N_142705',
#        'cat__ID_OCUPA_N_203015', 'cat__ID_OCUPA_N_212315',
#        'cat__ID_OCUPA_N_2124.1', 'cat__ID_OCUPA_N_212405',
#        'cat__ID_OCUPA_N_212410', 'cat__ID_OCUPA_N_212415',
#        'cat__ID_OCUPA_N_212420', 'cat__ID_OCUPA_N_213205',
#        'cat__ID_OCUPA_N_213210', 'cat__ID_OCUPA_N_213405',
#        'cat__ID_OCUPA_N_214005', 'cat__ID_OCUPA_N_214105',
#        'cat__ID_OCUPA_N_214110', 'cat__ID_OCUPA_N_214120',
#        'cat__ID_OCUPA_N_214125', 'cat__ID_OCUPA_N_214205',
#        'cat__ID_OCUPA_N_214305', 'cat__ID_OCUPA_N_214405',
#        'cat__ID_OCUPA_N_214410', 'cat__ID_OCUPA_N_214430',
#        'cat__ID_OCUPA_N_214505', 'cat__ID_OCUPA_N_214530',
#        'cat__ID_OCUPA_N_214610', 'cat__ID_OCUPA_N_214805',
#        'cat__ID_OCUPA_N_214905', 'cat__ID_OCUPA_N_215115',
#        'cat__ID_OCUPA_N_215125', 'cat__ID_OCUPA_N_215150',
#        'cat__ID_OCUPA_N_221105', 'cat__ID_OCUPA_N_221205',
#        'cat__ID_OCUPA_N_2221.1', 'cat__ID_OCUPA_N_222105',
#        'cat__ID_OCUPA_N_222110', 'cat__ID_OCUPA_N_222120',
#        'cat__ID_OCUPA_N_2231.1', 'cat__ID_OCUPA_N_223104',
#        'cat__ID_OCUPA_N_223106', 'cat__ID_OCUPA_N_223110',
#        'cat__ID_OCUPA_N_223115', 'cat__ID_OCUPA_N_223124',
#        'cat__ID_OCUPA_N_223132', 'cat__ID_OCUPA_N_223149',
#        'cat__ID_OCUPA_N_223151', 'cat__ID_OCUPA_N_223157',
#        'cat__ID_OCUPA_N_223204', 'cat__ID_OCUPA_N_223208',
#        'cat__ID_OCUPA_N_2233.0', 'cat__ID_OCUPA_N_223305',
#        'cat__ID_OCUPA_N_223310', 'cat__ID_OCUPA_N_2234.0',
#        'cat__ID_OCUPA_N_223405', 'cat__ID_OCUPA_N_223505',
#        'cat__ID_OCUPA_N_2236.0', 'cat__ID_OCUPA_N_223605',
#        'cat__ID_OCUPA_N_223620', 'cat__ID_OCUPA_N_223705',
#        'cat__ID_OCUPA_N_223710', 'cat__ID_OCUPA_N_231105',
#        'cat__ID_OCUPA_N_231110', 'cat__ID_OCUPA_N_2312.0',
#        'cat__ID_OCUPA_N_231205', 'cat__ID_OCUPA_N_231310',
#        'cat__ID_OCUPA_N_231315', 'cat__ID_OCUPA_N_231325',
#        'cat__ID_OCUPA_N_231335', 'cat__ID_OCUPA_N_231340',
#        'cat__ID_OCUPA_N_232105', 'cat__ID_OCUPA_N_232110',
#        'cat__ID_OCUPA_N_232115', 'cat__ID_OCUPA_N_232120',
#        'cat__ID_OCUPA_N_232135', 'cat__ID_OCUPA_N_232140',
#        'cat__ID_OCUPA_N_232145', 'cat__ID_OCUPA_N_233105',
#        'cat__ID_OCUPA_N_234305', 'cat__ID_OCUPA_N_234505',
#        'cat__ID_OCUPA_N_234510', 'cat__ID_OCUPA_N_234515',
#        'cat__ID_OCUPA_N_234520', 'cat__ID_OCUPA_N_234616',
#        'cat__ID_OCUPA_N_234624', 'cat__ID_OCUPA_N_234664',
#        'cat__ID_OCUPA_N_2348.1', 'cat__ID_OCUPA_N_234810',
#        'cat__ID_OCUPA_N_234915', 'cat__ID_OCUPA_N_239220',
#        'cat__ID_OCUPA_N_239405', 'cat__ID_OCUPA_N_239410',
#        'cat__ID_OCUPA_N_239415', 'cat__ID_OCUPA_N_239425',
#        'cat__ID_OCUPA_N_2410.4', 'cat__ID_OCUPA_N_241005',
#        'cat__ID_OCUPA_N_242305', 'cat__ID_OCUPA_N_242910',
#        'cat__ID_OCUPA_N_251105', 'cat__ID_OCUPA_N_251205',
#        'cat__ID_OCUPA_N_251215', 'cat__ID_OCUPA_N_251220',
#        'cat__ID_OCUPA_N_251510', 'cat__ID_OCUPA_N_251530',
#        'cat__ID_OCUPA_N_251605', 'cat__ID_OCUPA_N_2521.0',
#        'cat__ID_OCUPA_N_252105', 'cat__ID_OCUPA_N_252205',
#        'cat__ID_OCUPA_N_252210', 'cat__ID_OCUPA_N_252305',
#        'cat__ID_OCUPA_N_252405', 'cat__ID_OCUPA_N_252515',
#        'cat__ID_OCUPA_N_252525', 'cat__ID_OCUPA_N_252605',
#        'cat__ID_OCUPA_N_253115', 'cat__ID_OCUPA_N_253120',
#        'cat__ID_OCUPA_N_253125', 'cat__ID_OCUPA_N_254305',
#        'cat__ID_OCUPA_N_254310', 'cat__ID_OCUPA_N_254405',
#        'cat__ID_OCUPA_N_261110', 'cat__ID_OCUPA_N_261125',
#        'cat__ID_OCUPA_N_2612.1', 'cat__ID_OCUPA_N_261205',
#        'cat__ID_OCUPA_N_261215', 'cat__ID_OCUPA_N_261305',
#        'cat__ID_OCUPA_N_261430', 'cat__ID_OCUPA_N_261715',
#        'cat__ID_OCUPA_N_261805', 'cat__ID_OCUPA_N_262105',
#        'cat__ID_OCUPA_N_262115', 'cat__ID_OCUPA_N_262405',
#        'cat__ID_OCUPA_N_262410', 'cat__ID_OCUPA_N_262610',
#        'cat__ID_OCUPA_N_262615', 'cat__ID_OCUPA_N_262705',
#        'cat__ID_OCUPA_N_262710', 'cat__ID_OCUPA_N_262830',
#        'cat__ID_OCUPA_N_263105', 'cat__ID_OCUPA_N_263110',
#        'cat__ID_OCUPA_N_300305', 'cat__ID_OCUPA_N_301110',
#        'cat__ID_OCUPA_N_311105', 'cat__ID_OCUPA_N_311520',
#        'cat__ID_OCUPA_N_312105', 'cat__ID_OCUPA_N_312210',
#        'cat__ID_OCUPA_N_3123.2', 'cat__ID_OCUPA_N_312320',
#        'cat__ID_OCUPA_N_313105', 'cat__ID_OCUPA_N_313120',
#        'cat__ID_OCUPA_N_313125', 'cat__ID_OCUPA_N_313205',
#        'cat__ID_OCUPA_N_313215', 'cat__ID_OCUPA_N_313220',
#        'cat__ID_OCUPA_N_313305', 'cat__ID_OCUPA_N_313310',
#        'cat__ID_OCUPA_N_313315', 'cat__ID_OCUPA_N_314105',
#        'cat__ID_OCUPA_N_314110', 'cat__ID_OCUPA_N_314120',
#        'cat__ID_OCUPA_N_314125', 'cat__ID_OCUPA_N_314405',
#        'cat__ID_OCUPA_N_314410', 'cat__ID_OCUPA_N_317105',
#        'cat__ID_OCUPA_N_317110', 'cat__ID_OCUPA_N_317210',
#        'cat__ID_OCUPA_N_318015', 'cat__ID_OCUPA_N_318305',
#        'cat__ID_OCUPA_N_318610', 'cat__ID_OCUPA_N_318805',
#        'cat__ID_OCUPA_N_321105', 'cat__ID_OCUPA_N_321110',
#        'cat__ID_OCUPA_N_322110', 'cat__ID_OCUPA_N_322120',
#        'cat__ID_OCUPA_N_3222.0', 'cat__ID_OCUPA_N_322205',
#        'cat__ID_OCUPA_N_322215', 'cat__ID_OCUPA_N_322230',
#        'cat__ID_OCUPA_N_3222B3', 'cat__ID_OCUPA_N_322305',
#        'cat__ID_OCUPA_N_322410', 'cat__ID_OCUPA_N_322415',
#        'cat__ID_OCUPA_N_322420', 'cat__ID_OCUPA_N_322425',
#        'cat__ID_OCUPA_N_3224F2', 'cat__ID_OCUPA_N_324115',
#        'cat__ID_OCUPA_N_324205', 'cat__ID_OCUPA_N_325105',
#        'cat__ID_OCUPA_N_325205', 'cat__ID_OCUPA_N_328110',
#        'cat__ID_OCUPA_N_331105', 'cat__ID_OCUPA_N_331110',
#        'cat__ID_OCUPA_N_331205', 'cat__ID_OCUPA_N_3331.1',
#        'cat__ID_OCUPA_N_333105', 'cat__ID_OCUPA_N_333115',
#        'cat__ID_OCUPA_N_334105', 'cat__ID_OCUPA_N_334110',
#        'cat__ID_OCUPA_N_334115', 'cat__ID_OCUPA_N_341120',
#        'cat__ID_OCUPA_N_341230', 'cat__ID_OCUPA_N_3421.0',
#        'cat__ID_OCUPA_N_342105', 'cat__ID_OCUPA_N_342205',
#        'cat__ID_OCUPA_N_342305', 'cat__ID_OCUPA_N_342310',
#        'cat__ID_OCUPA_N_342520', 'cat__ID_OCUPA_N_351115',
#        'cat__ID_OCUPA_N_351305', 'cat__ID_OCUPA_N_351405',
#        'cat__ID_OCUPA_N_351420', 'cat__ID_OCUPA_N_351425',
#        'cat__ID_OCUPA_N_351605', 'cat__ID_OCUPA_N_351715',
#        'cat__ID_OCUPA_N_351720', 'cat__ID_OCUPA_N_351725',
#        'cat__ID_OCUPA_N_3518.1', 'cat__ID_OCUPA_N_351810',
#        'cat__ID_OCUPA_N_352205', 'cat__ID_OCUPA_N_352210',
#        'cat__ID_OCUPA_N_353235', 'cat__ID_OCUPA_N_3541.2',
#        'cat__ID_OCUPA_N_354125', 'cat__ID_OCUPA_N_354140',
#        'cat__ID_OCUPA_N_354145', 'cat__ID_OCUPA_N_354150',
#        'cat__ID_OCUPA_N_354205', 'cat__ID_OCUPA_N_354210',
#        'cat__ID_OCUPA_N_354415', 'cat__ID_OCUPA_N_354505',
#        'cat__ID_OCUPA_N_354605', 'cat__ID_OCUPA_N_354705',
#        'cat__ID_OCUPA_N_354815', 'cat__ID_OCUPA_N_371310',
#        'cat__ID_OCUPA_N_374110', 'cat__ID_OCUPA_N_375105',
#        'cat__ID_OCUPA_N_375110', 'cat__ID_OCUPA_N_375115',
#        'cat__ID_OCUPA_N_376240', 'cat__ID_OCUPA_N_377110',
#        'cat__ID_OCUPA_N_391115', 'cat__ID_OCUPA_N_391205',
#        'cat__ID_OCUPA_N_391230', 'cat__ID_OCUPA_N_410105',
#        'cat__ID_OCUPA_N_410205', 'cat__ID_OCUPA_N_4110.0',
#        'cat__ID_OCUPA_N_4110.1', 'cat__ID_OCUPA_N_411005',
#        'cat__ID_OCUPA_N_411010', 'cat__ID_OCUPA_N_411020',
#        'cat__ID_OCUPA_N_411025', 'cat__ID_OCUPA_N_411030',
#        'cat__ID_OCUPA_N_411035', 'cat__ID_OCUPA_N_411045',
#        'cat__ID_OCUPA_N_412110', 'cat__ID_OCUPA_N_412205',
#        'cat__ID_OCUPA_N_413105', 'cat__ID_OCUPA_N_413110',
#        'cat__ID_OCUPA_N_413115', 'cat__ID_OCUPA_N_413205',
#        'cat__ID_OCUPA_N_413210', 'cat__ID_OCUPA_N_413230',
#        'cat__ID_OCUPA_N_414105', 'cat__ID_OCUPA_N_414110',
#        'cat__ID_OCUPA_N_414115', 'cat__ID_OCUPA_N_4142.1',
#        'cat__ID_OCUPA_N_414205', 'cat__ID_OCUPA_N_414210',
#        'cat__ID_OCUPA_N_414215', 'cat__ID_OCUPA_N_415130',
#        'cat__ID_OCUPA_N_415205', 'cat__ID_OCUPA_N_420105',
#        'cat__ID_OCUPA_N_4211.2', 'cat__ID_OCUPA_N_421105',
#        'cat__ID_OCUPA_N_421125', 'cat__ID_OCUPA_N_421305',
#        'cat__ID_OCUPA_N_421310', 'cat__ID_OCUPA_N_422105',
#        'cat__ID_OCUPA_N_422120', 'cat__ID_OCUPA_N_422205',
#        'cat__ID_OCUPA_N_422305', 'cat__ID_OCUPA_N_422310',
#        'cat__ID_OCUPA_N_422315', 'cat__ID_OCUPA_N_423105',
#        'cat__ID_OCUPA_N_424110', 'cat__ID_OCUPA_N_5101.2',
#        'cat__ID_OCUPA_N_510125', 'cat__ID_OCUPA_N_511205',
#        'cat__ID_OCUPA_N_511215', 'cat__ID_OCUPA_N_511405',
#        'cat__ID_OCUPA_N_5121.1', 'cat__ID_OCUPA_N_5121.2',
#        'cat__ID_OCUPA_N_512105', 'cat__ID_OCUPA_N_512110',
#        'cat__ID_OCUPA_N_512115', 'cat__ID_OCUPA_N_512120',
#        'cat__ID_OCUPA_N_5132.1', 'cat__ID_OCUPA_N_513205',
#        'cat__ID_OCUPA_N_513210', 'cat__ID_OCUPA_N_513215',
#        'cat__ID_OCUPA_N_513220', 'cat__ID_OCUPA_N_513315',
#        'cat__ID_OCUPA_N_5134.3', 'cat__ID_OCUPA_N_513405',
#        'cat__ID_OCUPA_N_513420', 'cat__ID_OCUPA_N_513425',
#        'cat__ID_OCUPA_N_513430', 'cat__ID_OCUPA_N_513435',
#        'cat__ID_OCUPA_N_513505', 'cat__ID_OCUPA_N_513605',
#        'cat__ID_OCUPA_N_513610', 'cat__ID_OCUPA_N_514105',
#        'cat__ID_OCUPA_N_514120', 'cat__ID_OCUPA_N_5142.1',
#        'cat__ID_OCUPA_N_514205', 'cat__ID_OCUPA_N_514210',
#        'cat__ID_OCUPA_N_514215', 'cat__ID_OCUPA_N_514220',
#        'cat__ID_OCUPA_N_514225', 'cat__ID_OCUPA_N_514230',
#        'cat__ID_OCUPA_N_514310', 'cat__ID_OCUPA_N_514330',
#        'cat__ID_OCUPA_N_5151.0', 'cat__ID_OCUPA_N_515105',
#        'cat__ID_OCUPA_N_515110', 'cat__ID_OCUPA_N_515120',
#        'cat__ID_OCUPA_N_515135', 'cat__ID_OCUPA_N_515210',
#        'cat__ID_OCUPA_N_515215', 'cat__ID_OCUPA_N_515220',
#        'cat__ID_OCUPA_N_515225', 'cat__ID_OCUPA_N_515305',
#        'cat__ID_OCUPA_N_5161.2', 'cat__ID_OCUPA_N_516105',
#        'cat__ID_OCUPA_N_516110', 'cat__ID_OCUPA_N_516115',
#        'cat__ID_OCUPA_N_516120', 'cat__ID_OCUPA_N_516135',
#        'cat__ID_OCUPA_N_5162.1', 'cat__ID_OCUPA_N_516205',
#        'cat__ID_OCUPA_N_516210', 'cat__ID_OCUPA_N_516220',
#        'cat__ID_OCUPA_N_5163.4', 'cat__ID_OCUPA_N_516305',
#        'cat__ID_OCUPA_N_516330', 'cat__ID_OCUPA_N_516335',
#        'cat__ID_OCUPA_N_516505', 'cat__ID_OCUPA_N_516610',
#        'cat__ID_OCUPA_N_517105', 'cat__ID_OCUPA_N_517110',
#        'cat__ID_OCUPA_N_517210', 'cat__ID_OCUPA_N_517215',
#        'cat__ID_OCUPA_N_517220', 'cat__ID_OCUPA_N_517310',
#        'cat__ID_OCUPA_N_517315', 'cat__ID_OCUPA_N_517330',
#        'cat__ID_OCUPA_N_5174.1', 'cat__ID_OCUPA_N_5174.2',
#        'cat__ID_OCUPA_N_517405', 'cat__ID_OCUPA_N_517410',
#        'cat__ID_OCUPA_N_517415', 'cat__ID_OCUPA_N_517420',
#        'cat__ID_OCUPA_N_5191.1', 'cat__ID_OCUPA_N_519110',
#        'cat__ID_OCUPA_N_519205', 'cat__ID_OCUPA_N_519210',
#        'cat__ID_OCUPA_N_519320', 'cat__ID_OCUPA_N_519935',
#        'cat__ID_OCUPA_N_519940', 'cat__ID_OCUPA_N_5211.2',
#        'cat__ID_OCUPA_N_5211.3', 'cat__ID_OCUPA_N_521105',
#        'cat__ID_OCUPA_N_521110', 'cat__ID_OCUPA_N_521115',
#        'cat__ID_OCUPA_N_521120', 'cat__ID_OCUPA_N_521125',
#        'cat__ID_OCUPA_N_521130', 'cat__ID_OCUPA_N_521135',
#        'cat__ID_OCUPA_N_523110', 'cat__ID_OCUPA_N_523115',
#        'cat__ID_OCUPA_N_524105', 'cat__ID_OCUPA_N_524205',
#        'cat__ID_OCUPA_N_524215', 'cat__ID_OCUPA_N_524305',
#        'cat__ID_OCUPA_N_611005', 'cat__ID_OCUPA_N_612005',
#        'cat__ID_OCUPA_N_612105', 'cat__ID_OCUPA_N_612125',
#        'cat__ID_OCUPA_N_612305', 'cat__ID_OCUPA_N_612505',
#        'cat__ID_OCUPA_N_612605', 'cat__ID_OCUPA_N_612615',
#        'cat__ID_OCUPA_N_612620', 'cat__ID_OCUPA_N_612740',
#        'cat__ID_OCUPA_N_613005', 'cat__ID_OCUPA_N_613010',
#        'cat__ID_OCUPA_N_613110', 'cat__ID_OCUPA_N_613115',
#        'cat__ID_OCUPA_N_613130', 'cat__ID_OCUPA_N_613215',
#        'cat__ID_OCUPA_N_613305', 'cat__ID_OCUPA_N_613405',
#        'cat__ID_OCUPA_N_620110', 'cat__ID_OCUPA_N_6210.0',
#        'cat__ID_OCUPA_N_621005', 'cat__ID_OCUPA_N_6220.2',
#        'cat__ID_OCUPA_N_622005', 'cat__ID_OCUPA_N_622010',
#        'cat__ID_OCUPA_N_622020', 'cat__ID_OCUPA_N_622105',
#        'cat__ID_OCUPA_N_622110', 'cat__ID_OCUPA_N_622115',
#        'cat__ID_OCUPA_N_622120', 'cat__ID_OCUPA_N_622310',
#        'cat__ID_OCUPA_N_622320', 'cat__ID_OCUPA_N_622415',
#        'cat__ID_OCUPA_N_622505', 'cat__ID_OCUPA_N_6226.1',
#        'cat__ID_OCUPA_N_622610', 'cat__ID_OCUPA_N_622615',
#        'cat__ID_OCUPA_N_622620', 'cat__ID_OCUPA_N_622720',
#        'cat__ID_OCUPA_N_622730', 'cat__ID_OCUPA_N_622805',
#        'cat__ID_OCUPA_N_623005', 'cat__ID_OCUPA_N_623010',
#        'cat__ID_OCUPA_N_623015', 'cat__ID_OCUPA_N_623020',
#        'cat__ID_OCUPA_N_623105', 'cat__ID_OCUPA_N_623110',
#        'cat__ID_OCUPA_N_623115', 'cat__ID_OCUPA_N_623125',
#        'cat__ID_OCUPA_N_623215', 'cat__ID_OCUPA_N_623305',
#        'cat__ID_OCUPA_N_623405', 'cat__ID_OCUPA_N_631010',
#        'cat__ID_OCUPA_N_631020', 'cat__ID_OCUPA_N_631105',
#        'cat__ID_OCUPA_N_631210', 'cat__ID_OCUPA_N_631325',
#        'cat__ID_OCUPA_N_632115', 'cat__ID_OCUPA_N_632120',
#        'cat__ID_OCUPA_N_632125', 'cat__ID_OCUPA_N_632205',
#        'cat__ID_OCUPA_N_632215', 'cat__ID_OCUPA_N_632405',
#        'cat__ID_OCUPA_N_632605', 'cat__ID_OCUPA_N_641010',
#        'cat__ID_OCUPA_N_641015', 'cat__ID_OCUPA_N_642010',
#        'cat__ID_OCUPA_N_643025', 'cat__ID_OCUPA_N_710205',
#        'cat__ID_OCUPA_N_710220', 'cat__ID_OCUPA_N_711110',
#        'cat__ID_OCUPA_N_711130', 'cat__ID_OCUPA_N_7112.4',
#        'cat__ID_OCUPA_N_711205', 'cat__ID_OCUPA_N_711210',
#        'cat__ID_OCUPA_N_711310', 'cat__ID_OCUPA_N_711405',
#        'cat__ID_OCUPA_N_712205', 'cat__ID_OCUPA_N_712225',
#        'cat__ID_OCUPA_N_712230', 'cat__ID_OCUPA_N_7151.4',
#        'cat__ID_OCUPA_N_715115', 'cat__ID_OCUPA_N_715120',
#        'cat__ID_OCUPA_N_715125', 'cat__ID_OCUPA_N_715135',
#        'cat__ID_OCUPA_N_715140', 'cat__ID_OCUPA_N_7152.1',
#        'cat__ID_OCUPA_N_715205', 'cat__ID_OCUPA_N_715210',
#        'cat__ID_OCUPA_N_715220', 'cat__ID_OCUPA_N_715230',
#        'cat__ID_OCUPA_N_715305', 'cat__ID_OCUPA_N_715410',
#        'cat__ID_OCUPA_N_715505', 'cat__ID_OCUPA_N_715510',
#        'cat__ID_OCUPA_N_715520', 'cat__ID_OCUPA_N_715545',
#        'cat__ID_OCUPA_N_7156.1', 'cat__ID_OCUPA_N_715610',
#        'cat__ID_OCUPA_N_715615', 'cat__ID_OCUPA_N_715725',
#        'cat__ID_OCUPA_N_716105', 'cat__ID_OCUPA_N_716305',
#        'cat__ID_OCUPA_N_716315', 'cat__ID_OCUPA_N_716405',
#        'cat__ID_OCUPA_N_716525', 'cat__ID_OCUPA_N_7166.1',
#        'cat__ID_OCUPA_N_716610', 'cat__ID_OCUPA_N_7170.2',
#        'cat__ID_OCUPA_N_717005', 'cat__ID_OCUPA_N_717020',
#        'cat__ID_OCUPA_N_720155', 'cat__ID_OCUPA_N_720220',
#        'cat__ID_OCUPA_N_721110', 'cat__ID_OCUPA_N_721210',
#        'cat__ID_OCUPA_N_721215', 'cat__ID_OCUPA_N_721225',
#        'cat__ID_OCUPA_N_721325', 'cat__ID_OCUPA_N_721405',
#        'cat__ID_OCUPA_N_722205', 'cat__ID_OCUPA_N_722215',
#        'cat__ID_OCUPA_N_722220', 'cat__ID_OCUPA_N_722330',
#        'cat__ID_OCUPA_N_723220', 'cat__ID_OCUPA_N_723225',
#        'cat__ID_OCUPA_N_7233.2', 'cat__ID_OCUPA_N_723310',
#        'cat__ID_OCUPA_N_723315', 'cat__ID_OCUPA_N_723320',
#        'cat__ID_OCUPA_N_724110', 'cat__ID_OCUPA_N_724115',
#        'cat__ID_OCUPA_N_724205', 'cat__ID_OCUPA_N_724315',
#        'cat__ID_OCUPA_N_724405', 'cat__ID_OCUPA_N_724410',
#        'cat__ID_OCUPA_N_724415', 'cat__ID_OCUPA_N_724435',
#        'cat__ID_OCUPA_N_724440', 'cat__ID_OCUPA_N_724510',
#        'cat__ID_OCUPA_N_724515', 'cat__ID_OCUPA_N_7250.1',
#        'cat__ID_OCUPA_N_725005', 'cat__ID_OCUPA_N_725010',
#        'cat__ID_OCUPA_N_725205', 'cat__ID_OCUPA_N_725225',
#        'cat__ID_OCUPA_N_725310', 'cat__ID_OCUPA_N_725415',
#        'cat__ID_OCUPA_N_725705', 'cat__ID_OCUPA_N_7311.4',
#        'cat__ID_OCUPA_N_731135', 'cat__ID_OCUPA_N_731145',
#        'cat__ID_OCUPA_N_731150', 'cat__ID_OCUPA_N_731155',
#        'cat__ID_OCUPA_N_731160', 'cat__ID_OCUPA_N_731165',
#        'cat__ID_OCUPA_N_731325', 'cat__ID_OCUPA_N_732105',
#        'cat__ID_OCUPA_N_741125', 'cat__ID_OCUPA_N_751010',
#        'cat__ID_OCUPA_N_751110', 'cat__ID_OCUPA_N_751125',
#        'cat__ID_OCUPA_N_752105', 'cat__ID_OCUPA_N_752425',
#        'cat__ID_OCUPA_N_752430', 'cat__ID_OCUPA_N_761306',
#        'cat__ID_OCUPA_N_761309', 'cat__ID_OCUPA_N_761327',
#        'cat__ID_OCUPA_N_761410', 'cat__ID_OCUPA_N_761810',
#        'cat__ID_OCUPA_N_762205', 'cat__ID_OCUPA_N_762345',
#        'cat__ID_OCUPA_N_7630.1', 'cat__ID_OCUPA_N_763005',
#        'cat__ID_OCUPA_N_763010', 'cat__ID_OCUPA_N_763015',
#        'cat__ID_OCUPA_N_763110', 'cat__ID_OCUPA_N_763125',
#        'cat__ID_OCUPA_N_763205', 'cat__ID_OCUPA_N_763210',
#        'cat__ID_OCUPA_N_763215', 'cat__ID_OCUPA_N_763310',
#        'cat__ID_OCUPA_N_763320', 'cat__ID_OCUPA_N_764005',
#        'cat__ID_OCUPA_N_764115', 'cat__ID_OCUPA_N_764205',
#        'cat__ID_OCUPA_N_764210', 'cat__ID_OCUPA_N_764305',
#        'cat__ID_OCUPA_N_765110', 'cat__ID_OCUPA_N_766205',
#        'cat__ID_OCUPA_N_766305', 'cat__ID_OCUPA_N_768105',
#        'cat__ID_OCUPA_N_768110', 'cat__ID_OCUPA_N_768205',
#        'cat__ID_OCUPA_N_768315', 'cat__ID_OCUPA_N_768320',
#        'cat__ID_OCUPA_N_768605', 'cat__ID_OCUPA_N_771105',
#        'cat__ID_OCUPA_N_7731.2', 'cat__ID_OCUPA_N_773105',
#        'cat__ID_OCUPA_N_773110', 'cat__ID_OCUPA_N_773120',
#        'cat__ID_OCUPA_N_773205', 'cat__ID_OCUPA_N_773320',
#        'cat__ID_OCUPA_N_773355', 'cat__ID_OCUPA_N_773415',
#        'cat__ID_OCUPA_N_774105', 'cat__ID_OCUPA_N_777105',
#        'cat__ID_OCUPA_N_777115', 'cat__ID_OCUPA_N_781705',
#        'cat__ID_OCUPA_N_782220', 'cat__ID_OCUPA_N_7823.0',
#        'cat__ID_OCUPA_N_782305', 'cat__ID_OCUPA_N_782310',
#        'cat__ID_OCUPA_N_782315', 'cat__ID_OCUPA_N_7824.1',
#        'cat__ID_OCUPA_N_782405', 'cat__ID_OCUPA_N_782410',
#        'cat__ID_OCUPA_N_7825.1', 'cat__ID_OCUPA_N_782505',
#        'cat__ID_OCUPA_N_782510', 'cat__ID_OCUPA_N_782515',
#        'cat__ID_OCUPA_N_782705', 'cat__ID_OCUPA_N_782710',
#        'cat__ID_OCUPA_N_782820', 'cat__ID_OCUPA_N_783110',
#        'cat__ID_OCUPA_N_7832.2', 'cat__ID_OCUPA_N_783210',
#        'cat__ID_OCUPA_N_783215', 'cat__ID_OCUPA_N_783220',
#        'cat__ID_OCUPA_N_783225', 'cat__ID_OCUPA_N_784105',
#        'cat__ID_OCUPA_N_784205', 'cat__ID_OCUPA_N_791105',
#        'cat__ID_OCUPA_N_791110', 'cat__ID_OCUPA_N_791115',
#        'cat__ID_OCUPA_N_791140', 'cat__ID_OCUPA_N_811215',
#        'cat__ID_OCUPA_N_813125', 'cat__ID_OCUPA_N_8211.1',
#        'cat__ID_OCUPA_N_821105', 'cat__ID_OCUPA_N_821205',
#        'cat__ID_OCUPA_N_821305', 'cat__ID_OCUPA_N_821320',
#        'cat__ID_OCUPA_N_821405', 'cat__ID_OCUPA_N_821415',
#        'cat__ID_OCUPA_N_822110', 'cat__ID_OCUPA_N_823315',
#        'cat__ID_OCUPA_N_828110', 'cat__ID_OCUPA_N_832125',
#        'cat__ID_OCUPA_N_840105', 'cat__ID_OCUPA_N_8414.0',
#        'cat__ID_OCUPA_N_841408', 'cat__ID_OCUPA_N_841416',
#        'cat__ID_OCUPA_N_841420', 'cat__ID_OCUPA_N_841710',
#        'cat__ID_OCUPA_N_842115', 'cat__ID_OCUPA_N_842120',
#        'cat__ID_OCUPA_N_848210', 'cat__ID_OCUPA_N_848305',
#        'cat__ID_OCUPA_N_848310', 'cat__ID_OCUPA_N_848325',
#        'cat__ID_OCUPA_N_848405', 'cat__ID_OCUPA_N_848425',
#        'cat__ID_OCUPA_N_8485.1', 'cat__ID_OCUPA_N_848505',
#        'cat__ID_OCUPA_N_848510', 'cat__ID_OCUPA_N_848525',
#        'cat__ID_OCUPA_N_848605', 'cat__ID_OCUPA_N_861105',
#        'cat__ID_OCUPA_N_862120', 'cat__ID_OCUPA_N_862150',
#        'cat__ID_OCUPA_N_862205', 'cat__ID_OCUPA_N_862305',
#        'cat__ID_OCUPA_N_910105', 'cat__ID_OCUPA_N_911110',
#        'cat__ID_OCUPA_N_911120', 'cat__ID_OCUPA_N_911305',
#        'cat__ID_OCUPA_N_911320', 'cat__ID_OCUPA_N_913115',
#        'cat__ID_OCUPA_N_914105', 'cat__ID_OCUPA_N_914205',
#        'cat__ID_OCUPA_N_914305', 'cat__ID_OCUPA_N_9144.0',
#        'cat__ID_OCUPA_N_914405', 'cat__ID_OCUPA_N_914410',
#        'cat__ID_OCUPA_N_914425', 'cat__ID_OCUPA_N_919110',
#        'cat__ID_OCUPA_N_919310', 'cat__ID_OCUPA_N_951105',
#        'cat__ID_OCUPA_N_951305', 'cat__ID_OCUPA_N_953115',
#        'cat__ID_OCUPA_N_991305', 'cat__ID_OCUPA_N_991310',
#        'cat__ID_OCUPA_N_991315', 'cat__ID_OCUPA_N_991405',
#        'cat__ID_OCUPA_N_991415', 'cat__ID_OCUPA_N_992115',
#        'cat__ID_OCUPA_N_992220', 'cat__ID_OCUPA_N_992225',
#        'cat__ID_OCUPA_N_998999', 'cat__ID_OCUPA_N_9999.9',
#        'cat__ID_OCUPA_N_999991', 'cat__ID_OCUPA_N_999992',
#        'cat__ID_OCUPA_N_999993', 'cat__ID_OCUPA_N_999994',
#        'cat__ID_OCUPA_N_999995', 'cat__ID_OCUPA_N_Não informado',
#        'cat__ID_OCUPA_N_XXX', 'cat__SG_UF_AC', 'cat__SG_UF_AL',
#        'cat__SG_UF_AM', 'cat__SG_UF_AP', 'cat__SG_UF_BA', 'cat__SG_UF_CE',
#        'cat__SG_UF_DF', 'cat__SG_UF_ES', 'cat__SG_UF_GO', 'cat__SG_UF_MA',
#        'cat__SG_UF_MG', 'cat__SG_UF_MS', 'cat__SG_UF_MT',
#        'cat__SG_UF_Não informado', 'cat__SG_UF_PA', 'cat__SG_UF_PB',
#        'cat__SG_UF_PE', 'cat__SG_UF_PI', 'cat__SG_UF_PR', 'cat__SG_UF_RJ',
#        'cat__SG_UF_RN', 'cat__SG_UF_RO', 'cat__SG_UF_RR', 'cat__SG_UF_RS',
#        'cat__SG_UF_SC', 'cat__SG_UF_SE', 'cat__SG_UF_SP', 'cat__SG_UF_TO',
#        'cat__estacao_Inverno', 'cat__estacao_Outono',
#        'cat__estacao_Primavera', 'cat__estacao_Verão',
#        'cat__nivel_vulnerabilidade_Alta',
#        'cat__nivel_vulnerabilidade_Baixa',
#        'cat__nivel_vulnerabilidade_Moderada'], dtype=object)

# %% [markdown]
# Testando o artefato do modelo carregado

# %%
modelo.predict(X_data.iloc[-10:])
# Out:
# array([0, 0, 2, 2, 0, 2, 0, 2, 0, 0])

# %% [markdown]
# ## Avaliação de desempenho e custo computacional
#
# Nesta seção são avaliados os modelos selecionados ao longo dos folds da validação cruzada externa,
# considerando simultaneamente **qualidade preditiva** e **custo computacional**.
# Essa análise conjunta é fundamental para evitar escolhas baseadas apenas em desempenho,
# desconsiderando viabilidade prática de treinamento e manutenção do modelo.
#
# ### Métricas de desempenho preditivo
#
# O desempenho dos modelos é avaliado por meio de múltiplas métricas,
# permitindo uma análise abrangente do comportamento preditivo:
#
# - **ROC-AUC (OvR, weighted)**: métrica principal de comparação, pois avalia a capacidade de separação entre classes
# em cenários multiclasse e desbalanceados, utilizando probabilidades preditas.
# - **Accuracy**: fornece uma visão global de acerto, mas pode ser influenciada por classes majoritárias.
# - **F1-score (weighted)**: equilibra precisão e recall, sendo mais informativo quando há assimetria entre classes.
# - **Recall (weighted)**: mede a capacidade do modelo em identificar corretamente instâncias relevantes,
# importante em contextos onde falsos negativos possuem maior custo.
# - **Precision (weighted)**: avalia a confiabilidade das predições positivas,
# sendo relevante quando falsos positivos impactam decisões downstream.
#
# A análise por fold permite verificar não apenas o valor médio das métricas,
# mas também sua **estabilidade**, reduzindo o risco de overfitting a uma partição específica dos dados.

# %%
# 2. Basic overview
print("=== Shape of DataFrame ===")
print(df_metrics.shape)

display(df_metrics)
# Out:
# === Shape of DataFrame ===
# (30, 13)
#     number     value  params_C  params_colsample_bytree  params_learning_rate  \
# 0        0  0.670138  1.574119                      NaN                   NaN
# 1        1  0.682331       NaN                 0.904716              0.296161
# 2        2  0.619353       NaN                      NaN                   NaN
# 3        3  0.640467       NaN                 0.563070              0.044994
# 4        4  0.627105       NaN                 0.841974              0.023021
# 5        5  0.630283       NaN                 0.934697              0.051125
# 6        6  0.669950  1.897927                      NaN                   NaN
# 7        7  0.656783       NaN                 0.818749              0.214401
# 8        8  0.637540       NaN                      NaN                   NaN
# 9        9  0.676061       NaN                 0.546542              0.250675
# 10      10  0.688556       NaN                 0.778043              0.154387
# 11      11  0.693562       NaN                 0.696529              0.135925
# 12      12  0.693848       NaN                 0.707873              0.150578
# 13      13  0.693614       NaN                 0.697234              0.138537
# 14      14  0.695054       NaN                 0.661767              0.126308
# 15      15  0.684681       NaN                 0.705359              0.110361
# 16      16  0.695302       NaN                 0.646599              0.096794
# 17      17  0.692849       NaN                 0.611830              0.082350
# 18      18  0.697977       NaN                 0.614504              0.092121
# 19      19  0.701900       NaN                 0.618314              0.195298
# 20      20  0.694299       NaN                 0.505011              0.085223
# 21      21  0.675044  0.106813                      NaN                   NaN
# 22      22  0.700515       NaN                 0.620063              0.207482
# 23      23  0.700585       NaN                 0.621465              0.180860
# 24      24  0.702017       NaN                 0.604390              0.209121
# 25      25  0.681874       NaN                      NaN                   NaN
# 26      26  0.699565       NaN                 0.579602              0.196590
# 27      27  0.698372       NaN                 0.546285              0.195377
# 28      28  0.700469       NaN                 0.519452              0.182613
# 29      29  0.699064       NaN                 0.751824              0.238881
#
#     params_max_depth  params_min_samples_leaf  params_min_samples_split  \
# 0                NaN                      NaN                       NaN
# 1                6.0                      NaN                       NaN
# 2                4.0                      3.0                       3.0
# 3                5.0                      NaN                       NaN
# 4                3.0                      NaN                       NaN
# 5                5.0                      NaN                       NaN
# 6                NaN                      NaN                       NaN
# 7                3.0                      NaN                       NaN
# 8                5.0                      5.0                       9.0
# 9                4.0                      NaN                       NaN
# 10               6.0                      NaN                       NaN
# 11               9.0                      NaN                       NaN
# 12               9.0                      NaN                       NaN
# 13               9.0                      NaN                       NaN
# 14               9.0                      NaN                       NaN
# 15               9.0                      NaN                       NaN
# 16               8.0                      NaN                       NaN
# 17               8.0                      NaN                       NaN
# 18               8.0                      NaN                       NaN
# 19               7.0                      NaN                       NaN
# 20               7.0                      NaN                       NaN
# 21               NaN                      NaN                       NaN
# 22               7.0                      NaN                       NaN
# 23               7.0                      NaN                       NaN
# 24               7.0                      NaN                       NaN
# 25               7.0                      1.0                      10.0
# 26               7.0                      NaN                       NaN
# 27               7.0                      NaN                       NaN
# 28               6.0                      NaN                       NaN
# 29               6.0                      NaN                       NaN
#
#    params_model_name  params_n_estimators  params_subsample     state  \
# 0                svm                  NaN               NaN  COMPLETE
# 1            xgboost                 20.0          0.815051  COMPLETE
# 2      random_forest                  5.0               NaN  COMPLETE
# 3            xgboost                 21.0          0.503055  COMPLETE
# 4            xgboost                 17.0          0.631530  COMPLETE
# 5            xgboost                 13.0          0.920315    PRUNED
# 6                svm                  NaN               NaN  COMPLETE
# 7            xgboost                 29.0          0.986192  COMPLETE
# 8      random_forest                  9.0               NaN    PRUNED
# 9            xgboost                 30.0          0.542124  COMPLETE
# 10          lightgbm                 12.0          0.947961  COMPLETE
# 11          lightgbm                 13.0          0.791609  COMPLETE
# 12          lightgbm                 12.0          0.814918  COMPLETE
# 13          lightgbm                 13.0          0.804271  COMPLETE
# 14          lightgbm                 15.0          0.758760  COMPLETE
# 15          lightgbm                  7.0          0.702285  COMPLETE
# 16          lightgbm                 18.0          0.695815  COMPLETE
# 17          lightgbm                 17.0          0.695832  COMPLETE
# 18          lightgbm                 24.0          0.687397  COMPLETE
# 19          lightgbm                 25.0          0.621141  COMPLETE
# 20          lightgbm                 25.0          0.620400  COMPLETE
# 21               svm                  NaN               NaN    PRUNED
# 22          lightgbm                 25.0          0.617256  COMPLETE
# 23          lightgbm                 25.0          0.624747  COMPLETE
# 24          lightgbm                 25.0          0.601450  COMPLETE
# 25     random_forest                 27.0               NaN    PRUNED
# 26          lightgbm                 23.0          0.590619  COMPLETE
# 27          lightgbm                 22.0          0.568938  COMPLETE
# 28          lightgbm                 28.0          0.567494  COMPLETE
# 29          lightgbm                 27.0          0.658767  COMPLETE
#
#                   duration
# 0   0 days 00:00:59.273853
# 1   0 days 00:00:22.327239
# 2   0 days 00:00:07.515547
# 3   0 days 00:00:15.306102
# 4   0 days 00:00:12.112963
# 5   0 days 00:00:04.344005
# 6   0 days 00:00:59.894827
# 7   0 days 00:00:13.959281
# 8   0 days 00:00:02.220071
# 9   0 days 00:00:14.864648
# 10  0 days 00:00:09.593247
# 11  0 days 00:00:09.853371
# 12  0 days 00:00:08.896275
# 13  0 days 00:00:09.863532
# 14  0 days 00:00:10.033898
# 15  0 days 00:00:08.954826
# 16  0 days 00:00:10.651519
# 17  0 days 00:00:09.294292
# 18  0 days 00:00:11.634097
# 19  0 days 00:00:11.210591
# 20  0 days 00:00:11.639463
# 21  0 days 00:00:09.288664
# 22  0 days 00:00:10.243106
# 23  0 days 00:00:11.051367
# 24  0 days 00:00:11.305703
# 25  0 days 00:00:02.523874
# 26  0 days 00:00:11.233765
# 27  0 days 00:00:11.056363
# 28  0 days 00:00:10.472815
# 29  0 days 00:00:08.800331

# %%
# Total de trials por modelo
total_trials = (df_metrics.groupby("params_model_name").size().reset_index(name="total_trials"))

plt.figure(figsize=(8, 6))
sns.barplot(data=total_trials,x="params_model_name",y="total_trials",)
plt.title("Total de tentativas por modelo")
plt.xlabel("Modelo")
plt.ylabel("Tentativas")
plt.tight_layout()
plt.show()

# %%
# Gráfico das tentativas de modelos completas e abortadas
counts_state = df_metrics.groupby(["params_model_name", "state"]).size().reset_index(name="count")

plt.figure(figsize=(8, 6))
sns.barplot(data=counts_state,x="params_model_name",y="count",hue="state",)
plt.title("Resultado das tentativas entre Pruned e Complete")
plt.xlabel("Modelo")
plt.ylabel("Número de tentativas")
plt.tight_layout()
plt.show()

# %%
# Distribuição de performance (value) por modelo
plt.figure(figsize=(8, 6))
sns.boxplot(data=df_metrics, x="params_model_name", y="value")
plt.title("Desempenho por modelo")
plt.xlabel("Modelo")
plt.ylabel("Área por baixo da curva ROC (AUC)")
plt.tight_layout()
plt.show()

# %%
# Duração média de treino por modelo
df_metrics["duration_sec"] = pd.to_timedelta(df_metrics["duration"]).dt.total_seconds()
mean_duration = df_metrics.groupby("params_model_name")["duration_sec"].mean().reset_index()

# Distribuição do tempo de processamento por modelo

plt.figure(figsize=(8, 6))
sns.boxplot(data=df_metrics, x="params_model_name", y="duration_sec")
plt.title("Média do tempo de treinamento por modelo")
plt.xlabel("Modelo")
plt.ylabel("Segundos")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Treinamento do modelo final

# %%
df_hyper =pd.DataFrame(df_results['hyperparameters'].to_list())
df_hyper
# Out:
#   model_name  n_estimators  learning_rate  max_depth  subsample  \
# 0   lightgbm            27       0.267189          9   0.670760
# 1   lightgbm            22       0.214753          8   0.665923
# 2   lightgbm            23       0.295138          5   0.599359
# 3   lightgbm            19       0.247942          7   0.888521
# 4   lightgbm            25       0.209121          7   0.601450
#
#    colsample_bytree
# 0          0.580422
# 1          0.819822
# 2          0.908927
# 3          0.594032
# 4          0.604390

# %%
final_params=df_hyper.iloc[:,1:].median().to_dict()
final_params
# Out:
# {'n_estimators': 23.0,
#  'learning_rate': 0.24794182952531582,
#  'max_depth': 7.0,
#  'subsample': 0.6659226317671845,
#  'colsample_bytree': 0.6043898749597125}

# %%
final_params = {'n_estimators': 26,
 'learning_rate': 0.226,
 'max_depth': 7,
 'subsample': 0.662,
 'colsample_bytree': 0.6968}

# %%
# Dicionário base para reconstrução
models = {
    'RandomForest': RandomForestClassifier(random_state=42),
    'XGBoost': xgb.XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42),
    'LightGBM': lgb.LGBMClassifier(random_state=42),
    'SVM': CalibratedClassifierCV(LinearSVC( random_state=42))
}

# %%
# Reconstruir modelo
final_model = models['LightGBM']
final_model.set_params(**final_params)

cat_cols, num_cols = get_feature_types(X_data)

final_pipeline = build_pipeline(final_model, cat_cols, num_cols)

# %% [markdown]
# ### Avaliando modelo final

# %% [markdown]
# ## Interpretabilidade: importância de variáveis após pré-processamento (OHE) e mapeamento para colunas originais
#
# Modelos treinados sobre pipelines com `ColumnTransformer` e `OneHotEncoder` operam em um espaço de features
# expandido (múltiplas colunas por variável categórica). Para manter interpretabilidade, esta seção:
# 1) recupera os nomes finais das features no espaço transformado,
# 2) extrai uma medida de importância/coeficiente do modelo treinado,
# 3) mapeia as features transformadas de volta para as variáveis originais,
# 4) consolida a importância no nível da coluna original.
#
# Isso permite reportar resultados em termos das variáveis do dataset original, facilitando comunicação e análise.

# %% [markdown]
# ### Extração de nomes das features pós-`ColumnTransformer`
#
# A função `get_feature_names` reconstrói o vetor de nomes de features gerado após o pré-processamento,
# incluindo:
# - variáveis numéricas (após imputação/escala),
# - variáveis categóricas expandidas via One-Hot Encoding,
# - e, opcionalmente, colunas passadas via `remainder='passthrough'`.
#
# Essa etapa é necessária porque, após o `fit_transform`, a matriz final perde o vínculo direto com o nome
# das colunas originais, e a identificação correta das features é condição para qualquer análise de importância.

# %%
# 1. FUNÇÃO PARA EXTRAIR NOMES DAS FEATURES PÓS-OHE
def get_feature_names(column_transformer):
    """
    Extrai nomes finais das features após ColumnTransformer,
    incluindo OneHotEncoder e transformações numéricas.
    """
    output_features = []

    for name, transformer, features in column_transformer.transformers_:

        # Caso 'remainder=passthrough'
        if name == "remainder":
            output_features.extend(features)
            continue

        # Transformers com get_feature_names_out() (OneHotEncoder, etc)
        if hasattr(transformer, "get_feature_names_out"):
            try:
                names = transformer.get_feature_names_out(features)
            except:
                names = transformer.get_feature_names_out()
            output_features.extend(names)

        # Caso não possua o método
        else:
            output_features.extend(features)

    return output_features

# %% [markdown]
# ### Mapeamento para variáveis originais via fuzzy matching
#
# Após o One-Hot Encoding, uma mesma variável categórica pode gerar dezenas de colunas com nomes derivados.
# Para consolidar resultados no nível da variável original, é aplicado *fuzzy matching* entre o nome da feature
# pós-OHE e a lista de variáveis originais de interesse (`features_explicativas`).
#
# O objetivo do fuzzy matching é lidar com diferenças de sufixos/prefixos criados pelo encoding e manter
# um vínculo prático entre “feature transformada” e “coluna original”. O parâmetro `threshold`
# controla o quão estrita é a correspondência:
# - valores maiores reduzem falsos positivos (match errado),
# - valores menores aumentam cobertura, mas elevam risco de mapeamentos incorretos.
#
# Após o matching, apenas features com correspondência válida são mantidas para agregação.

# %%
def fuzzy_match_original(feature_name, triage_features, threshold=70):
    """
    Realiza fuzzy matching buscando qual variável ORIGINAL
    está mais relacionada com o nome da feature pós-OHE.
    """
    best_match, score, _ = process.extractOne(
        feature_name,
        triage_features,
        scorer=fuzz.partial_ratio
    )
    return best_match if score >= threshold else None

# %% [markdown]
# ## Validação cruzada externa: avaliação e interpretabilidade por fold
#
# Nesta etapa, aplica-se uma `StratifiedKFold` externa para avaliar o desempenho do pipeline e também
# inspecionar a importância de variáveis por fold. A estratificação preserva a proporção das classes,
# reduzindo instabilidade em bases desbalanceadas.
#
# Para cada fold:
# - o pipeline final é treinado no conjunto de treino,
# - a importância das features é extraída do modelo treinado,
# - as importâncias são consolidadas no nível da variável original e visualizadas,
# - e o desempenho é medido no conjunto de teste com métricas e curvas.

# %%
n_splits = 4
outer_cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
results = []
fold = 1
for train_idx, test_idx in outer_cv.split(X_data, y_data):

    print(f"\n==============================")
    print(f"  Fold Externo {fold}/{n_splits}")
    print(f"==============================")

    X_train, X_test = X_data.iloc[train_idx], X_data.iloc[test_idx]
    y_train, y_test = y_data.iloc[train_idx], y_data.iloc[test_idx]

    # Treinando o pipeline final com todo o conjunto de dados
    final_pipeline.fit(X_train,y_train)


    model = final_pipeline.named_steps["model"]   # <-- trocado aqui

    if hasattr(model, "feature_importances_"):
        importances = model.feature_importances_

    elif hasattr(model, "coef_"):
        # For LinearSVC, coef_ is (n_classes, n_features) for multiclass
        # Need to handle it as sum of absolute values or a specific class
        # For simplicity, will use the magnitude of coefficients for now
        importances = np.sum(np.abs(model.coef_), axis=0)

    else:
        # Handle cases where model might not have feature_importances_ or coef_
        # For example, if it's a CalibratedClassifierCV wrapper, get from its base estimator
        if hasattr(model, 'estimator') and hasattr(model.estimator, 'coef_'):
            importances = np.sum(np.abs(model.estimator.coef_), axis=0)
        elif hasattr(model, 'estimator') and hasattr(model.estimator, 'feature_importances_'):
            importances = model.estimator.feature_importances_
        else:
            raise ValueError("Este modelo não possui atributo de importância ou coeficientes diretos.")


    # 3. DF DE IMPORTÂNCIAS COM FEATURES PÓS-PREPROCESSAMENTO


    preproc = final_pipeline.named_steps["preprocessor"]   # <-- trocado aqui
    feature_names = get_feature_names(preproc)

    df_imp = pd.DataFrame({
        "feature": feature_names,
        "importance": importances
    })


    # 5. APLICA FUZZY MATCH EM TODAS AS FEATURES
    df_imp["original_var"] = df_imp["feature"].apply(
        lambda x: fuzzy_match_original(x, features_explicativas)
    )

    # Remove features que não encontraram correspondência
    df_imp = df_imp[df_imp["original_var"].notna()].copy()

    # 6. AGRUPA IMPORTÂNCIA POR VARIÁVEL ORIGINAL


    df_grouped = (
        df_imp.groupby("original_var")["importance"]
              .sum()
              .sort_values(ascending=False)
              .reset_index()
    )
    df_grouped.rename({'original_var':'feature'},axis=1,inplace=True)

    #Plotando o gráfico
    plt.figure(figsize=(6, 14))
    plt.barh(df_grouped["feature"][::-1],
            df_grouped["importance"][::-1])
    plt.xlabel("Importância")
    plt.title(f"Features importance – {type(model).__name__}")
    plt.tight_layout()
    plt.show()



    # Gerar previsões finais
    y_pred = final_pipeline.predict(X_test)
    # Get full probability matrix for multi-class
    y_proba = final_pipeline.predict_proba(X_test) if hasattr(final_model, "predict_proba") else None

    # Matriz de confusão
    cm = confusion_matrix(y_test, y_pred)

    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.title("Matriz de Confusão - Dados Completos")
    plt.xlabel("Predito")
    plt.ylabel("Real")
    plt.show()

    # Barplot com métricas
    metrics_dict = {
        "Accuracy": accuracy_score(y_test, y_pred),
        "Precision": precision_score(y_test, y_pred, average='weighted'),
        "Recall": recall_score(y_test, y_pred, average='weighted'),
        "F1 Score": f1_score(y_test, y_pred, average='weighted'),
        "AUC": roc_auc_score(y_test, y_proba, multi_class='ovr', average='weighted') if y_proba is not None else np.nan # Add multi_class and average
    }

    plt.figure(figsize=(8, 5))
    sns.barplot(x=list(metrics_dict.keys()), y=list(metrics_dict.values()), palette="Set2")
    plt.ylim(0, 1.05)
    plt.title("Métricas de Classificação - Dados Completos")
    for i, v in enumerate(metrics_dict.values()):
        plt.text(i, v + 0.02, f"{v:.2f}", ha='center')
    plt.grid(True)
    plt.show()

    # Curva ROC (One-vs-Rest for each class)
    if y_proba is not None:
        # Convert y_test to one-hot encoding for multi-class ROC curve plotting
        from sklearn.preprocessing import LabelBinarizer
        lb = LabelBinarizer()
        y_test_bin = lb.fit_transform(y_test)
        n_classes = y_test_bin.shape[1]

        plt.figure(figsize=(8, 6))
        for i in range(n_classes):
            fpr, tpr, _ = roc_curve(y_test_bin[:, i], y_proba[:, i])
            roc_auc = auc(fpr, tpr)
            plt.plot(fpr, tpr, label=f'ROC curve (class {i}) (AUC = {roc_auc:.2f})')

        plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Random Classifier')
        plt.xlabel("False Positive Rate")
        plt.ylabel("True Positive Rate")
        plt.title("Multi-class ROC Curve (One-vs-Rest)")
        plt.legend(loc='lower right')
        plt.grid(True)
        plt.show()

    # Curva Precision-Recall (One-vs-Rest for each class)
    if y_proba is not None:
        # y_test_bin from above can be reused
        plt.figure(figsize=(8, 6))
        for i in range(n_classes):
            precision, recall, _ = precision_recall_curve(y_test_bin[:, i], y_proba[:, i])
            auprc_trap = auc(recall, precision)
            plt.plot(recall, precision, label=f'PR curve (class {i}) (AUPRC = {auprc_trap:.2f})')

        plt.xlabel("Recall")
        plt.ylabel("Precision")
        plt.title("Multi-class Precision-Recall Curve (One-vs-Rest)")
        plt.legend(loc='lower left')
        plt.grid(True)
        plt.show()
# Out:
# ==============================
#   Fold Externo 1/4
# ==============================
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.045704 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 18786
# [LightGBM] [Info] Number of data points in the train set: 31629, number of used features: 190
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ==============================
#   Fold Externo 1/4
# ==============================
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.070535 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 19014
# [LightGBM] [Info] Number of data points in the train set: 31629, number of used features: 191
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ==============================
#   Fold Externo 1/4
# ==============================
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.042900 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 18713
# [LightGBM] [Info] Number of data points in the train set: 31632, number of used features: 183
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ==============================
#   Fold Externo 1/4
# ==============================
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.043824 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 18976
# [LightGBM] [Info] Number of data points in the train set: 31632, number of used features: 185
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
